# %%
# import os

# # 目录路径
# folder_path = r'C:\Users\MSI-PC\Desktop\Level 6 curriculum\大四下\Final Year Project\Z. ProgressBackup\40XResized Datasets for Model\40XForFinalPresentation\train\malignant'

# # 要删除的图片名字列表
# images_to_delete = [
#     "aug_1169_SOB_M_DC-14-10926-40-008.png",
#     "aug_1172_SOB_M_DC-14-11031-40-001.png",
#     "aug_1173_SOB_M_DC-14-11031-40-002.png",
#     "aug_1174_SOB_M_DC-14-11031-40-003.png",
#     "aug_1177_SOB_M_DC-14-11031-40-006.png",
#     "aug_1180_SOB_M_DC-14-11031-40-010.png",
#     "aug_1202_SOB_M_DC-14-11520-40-022.png",
#     "aug_1207_SOB_M_DC-14-11951-40-003.png",
#     "aug_1286_SOB_M_DC-14-13993-40-006.png",
#     "aug_1287_SOB_M_DC-14-13993-40-008.png",
#     "SOB_M_DC-14-10926-40-008.png",
#     "SOB_M_DC-14-11031-40-006.png",
#     "SOB_M_DC-14-11031-40-010.png",
#     "SOB_M_DC-14-11520-40-022.png",
#     "SOB_M_DC-14-11951-40-003.png",
#     "SOB_M_DC-14-13993-40-006.png",
#     "SOB_M_DC-14-13993-40-008.png",
#     "SOB_M_DC-14-13993-40-024.png",
#     "SOB_M_DC-14-13993-40-027.png",
#     "SOB_M_DC-14-14015-40-007.png",
#     "SOB_M_DC-14-14946-40-020.png",
#     "SOB_M_DC-14-15572-40-012.png",
#     "SOB_M_DC-14-15792-40-005.png",
#     "SOB_M_DC-14-15792-40-006.png",
#     "SOB_M_DC-14-20629-40-001.png",
#     "SOB_M_DC-14-20629-40-004.png",
#     "SOB_M_DC-14-20629-40-016.png",
#     "SOB_M_DC-14-20629-40-017.png",
#     "SOB_M_DC-14-2985-40-020.png",
#     "SOB_M_DC-14-3909-40-006.png",
#     "SOB_M_DC-14-3909-40-009.png",
#     "SOB_M_DC-14-3909-40-023.png",
#     "SOB_M_DC-14-5695-40-012.png",
#     "SOB_M_DC-14-5695-40-014.png",
#     "SOB_M_DC-14-6241-40-004.png",
#     "SOB_M_DC-14-6241-40-051.png",
#     "SOB_M_DC-14-9461-40-013.png",
#     "SOB_M_DC-14-9461-40-023.png",
#     "SOB_M_DC-14-9461-40-024.png",
#     "SOB_M_LC-14-15570-40-014.png",
#     "SOB_M_LC-14-15570-40-018.png",
#     "SOB_M_LC-14-15570-40-020.png",
#     "SOB_M_LC-14-15570-40-021.png",
#     "SOB_M_LC-14-15570-40-025.png",
#     "SOB_M_LC-14-15570-40-027.png",
#     "SOB_M_LC-14-15570C-40-013.png",
#     "SOB_M_LC-14-15570C-40-014.png",
#     "SOB_M_LC-14-15570C-40-015.png",
#     "SOB_M_LC-14-15570C-40-020.png",
#     "SOB_M_LC-14-16196-40-015.png",
#     "SOB_M_MC-14-10147-40-003.png",
#     "SOB_M_MC-14-10147-40-005.png",
#     "SOB_M_MC-14-10147-40-006.png",
#     "SOB_M_MC-14-10147-40-009.png",
#     "SOB_M_MC-14-10147-40-012.png",
#     "SOB_M_MC-14-10147-40-013.png",
#     "SOB_M_MC-14-10147-40-014.png",
#     "SOB_M_MC-14-12773-40-009.png",
#     "SOB_M_MC-14-12773-40-022.png",
#     "SOB_M_MC-14-12773-40-023.png",
#     "SOB_M_MC-14-13413-40-017.png",
#     "SOB_M_MC-14-13413-40-018.png",
#     "SOB_M_MC-14-13413-40-019.png",
#     "SOB_M_MC-14-13418DE-40-006.png",
#     "SOB_M_MC-14-13418DE-40-011.png",
#     "SOB_M_MC-14-16456-40-010.png",
#     "SOB_M_MC-14-16456-40-062.png",
#     "SOB_M_MC-14-16456-40-067.png",
#     "SOB_M_MC-14-18842D-40-012.png",
#     "SOB_M_MC-14-18842D-40-015.png",
#     "SOB_M_PC-14-12465-40-010.png",
#     "SOB_M_PC-14-19440-40-028.png",
# ]

# # 遍历要删除的图片名字
# for img_name in images_to_delete:
#     img_path = os.path.join(folder_path, img_name)  # 构造完整路径
#     if os.path.exists(img_path):  # 确保文件存在
#         os.remove(img_path)  # 删除文件
#         print(f"Deleted {img_name}")
#     else:
#         print(f"{img_name} does not exist")

# print("Deletion complete.")

# %%
# import os

# # 目录路径
# folder_path = r'C:\Users\MSI-PC\Desktop\Level 6 curriculum\大四下\Final Year Project\Z. ProgressBackup\40XResized Datasets for Model\40XForFinalPresentation\test\malignant'

# # 要删除的图片名字列表
# images_to_delete = [
#     "SOB_M_DC-14-13993-40-036.png",
#     "SOB_M_DC-14-14946-40-012.png",
#     "SOB_M_DC-14-15792-40-008.png",
#     "SOB_M_DC-14-16336-40-006.png",
#     "SOB_M_DC-14-3909-40-026.png",
#     "SOB_M_DC-14-6241-40-056.png",
#     "SOB_M_DC-14-9461-40-022.png",
#     "SOB_M_LC-14-15570-40-013.png",
#     "SOB_M_LC-14-15570-40-026.png",
#     "SOB_M_LC-14-15570C-40-028.png",
#     "SOB_M_LC-14-15570C-40-031.png",
# ]


# # 遍历要删除的图片名字
# for img_name in images_to_delete:
#     img_path = os.path.join(folder_path, img_name)  # 构造完整路径
#     if os.path.exists(img_path):  # 确保文件存在
#         os.remove(img_path)  # 删除文件
#         print(f"Deleted {img_name}")
#     else:
#         print(f"{img_name} does not exist")

# print("Deletion complete.")
# Out:
# Deleted SOB_M_DC-14-13993-40-036.png
# Deleted SOB_M_DC-14-14946-40-012.png
# Deleted SOB_M_DC-14-15792-40-008.png
# Deleted SOB_M_DC-14-16336-40-006.png
# Deleted SOB_M_DC-14-3909-40-026.png
# Deleted SOB_M_DC-14-6241-40-056.png
# Deleted SOB_M_DC-14-9461-40-022.png
# Deleted SOB_M_LC-14-15570-40-013.png
# Deleted SOB_M_LC-14-15570-40-026.png
# Deleted SOB_M_LC-14-15570C-40-028.png
# Deleted SOB_M_LC-14-15570C-40-031.png
# Deletion complete.
