# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/100X/test'
train_dir = '/root/BreastCancer/100X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/40X/train/malignant'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2129 images belonging to 2 classes.
# Found 316 images belonging to 2 classes.
# Found 311 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %% [markdown]
# <h1>Model Construction<h1>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Concatenate, Flatten, Dense

def inception_block(x, filters):
    conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(x)

    conv3x3 = Conv2D(filters[1], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv3x3)

    conv5x5 = Conv2D(filters[3], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv5x5)

    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    maxpool = Conv2D(filters[5], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(maxpool)

    inception_block = Concatenate(axis=-1)([conv1x1, conv3x3, conv5x5, maxpool])
    return inception_block

def inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer = 'he_normal')(input_tensor)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception blocks
    x = inception_block(x, filters=[64, 128, 128, 32, 96, 32])
    # x = inception_block(x, filters=[128, 128, 96, 64, 64, 64])

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=x)

    return model


# Create the InceptionNet model
model = inception_net(input_shape, num_classes)

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  8320        ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 128)  147584      ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 96)   76896       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 320)  0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 320)  0          ['concatenate[0][0]']
#
#  global_average_pooling2d (Glob  (None, 320)         0           ['max_pooling2d_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            642         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 251,234
# Trainable params: 251,234
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2023-12-23 18:38:43.765535: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-23 18:38:44.338354: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:a1:00.0, compute capability: 8.6

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "InceptionNet40X"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/InceptionNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-23 18:38:48.503074: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-23 18:38:49.918562: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 67/67 [==============================] - 49s 682ms/step - loss: 0.6682 - accuracy: 0.6411 - precision: 0.6411 - recall: 0.6411 - auc: 0.6954 - f1_score: 0.6411 - val_loss: 0.4949 - val_accuracy: 0.7215 - val_precision: 0.7215 - val_recall: 0.7215 - val_auc: 0.8445 - val_f1_score: 0.7215 - lr: 0.0010
# Epoch 2/100
# 67/67 [==============================] - 44s 660ms/step - loss: 0.5148 - accuracy: 0.7576 - precision: 0.7576 - recall: 0.7576 - auc: 0.8251 - f1_score: 0.7576 - val_loss: 0.5323 - val_accuracy: 0.7310 - val_precision: 0.7310 - val_recall: 0.7310 - val_auc: 0.8188 - val_f1_score: 0.7310 - lr: 0.0010
# Epoch 3/100
# 67/67 [==============================] - 44s 661ms/step - loss: 0.5226 - accuracy: 0.7417 - precision: 0.7417 - recall: 0.7417 - auc: 0.8183 - f1_score: 0.7417 - val_loss: 0.4235 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9378 - val_f1_score: 0.8639 - lr: 0.0010
# Epoch 4/100
# 67/67 [==============================] - 44s 661ms/step - loss: 0.5155 - accuracy: 0.7511 - precision: 0.7511 - recall: 0.7511 - auc: 0.8264 - f1_score: 0.7511 - val_loss: 0.4444 - val_accuracy: 0.8354 - val_precision: 0.8354 - val_recall: 0.8354 - val_auc: 0.9186 - val_f1_score: 0.8354 - lr: 0.0010
# Epoch 5/100
# 67/67 [==============================] - 44s 658ms/step - loss: 0.4938 - accuracy: 0.7698 - precision: 0.7698 - recall: 0.7698 - auc: 0.8433 - f1_score: 0.7698 - val_loss: 0.4484 - val_accuracy: 0.8165 - val_precision: 0.8165 - val_recall: 0.8165 - val_auc: 0.9121 - val_f1_score: 0.8165 - lr: 0.0010
# Epoch 6/100
# 67/67 [==============================] - 44s 658ms/step - loss: 0.5144 - accuracy: 0.7586 - precision: 0.7586 - recall: 0.7586 - auc: 0.8301 - f1_score: 0.7586 - val_loss: 0.3860 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9377 - val_f1_score: 0.8513 - lr: 0.0010
# Epoch 7/100
# 67/67 [==============================] - 45s 669ms/step - loss: 0.4819 - accuracy: 0.7844 - precision: 0.7844 - recall: 0.7844 - auc: 0.8518 - f1_score: 0.7844 - val_loss: 0.4063 - val_accuracy: 0.8924 - val_precision: 0.8924 - val_recall: 0.8924 - val_auc: 0.9547 - val_f1_score: 0.8924 - lr: 0.0010
# Epoch 8/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.5049 - accuracy: 0.7576 - precision: 0.7576 - recall: 0.7576 - auc: 0.8344 - f1_score: 0.7576 - val_loss: 0.3905 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9568 - val_f1_score: 0.8987 - lr: 0.0010
# Epoch 9/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.4862 - accuracy: 0.7872 - precision: 0.7872 - recall: 0.7872 - auc: 0.8491 - f1_score: 0.7872 - val_loss: 0.5044 - val_accuracy: 0.7595 - val_precision: 0.7595 - val_recall: 0.7595 - val_auc: 0.8655 - val_f1_score: 0.7595 - lr: 0.0010
# Epoch 10/100
# 67/67 [==============================] - 44s 664ms/step - loss: 0.4705 - accuracy: 0.7943 - precision: 0.7943 - recall: 0.7943 - auc: 0.8610 - f1_score: 0.7943 - val_loss: 0.4385 - val_accuracy: 0.8354 - val_precision: 0.8354 - val_recall: 0.8354 - val_auc: 0.9210 - val_f1_score: 0.8354 - lr: 0.0010
# Epoch 11/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.4852 - accuracy: 0.7684 - precision: 0.7684 - recall: 0.7684 - auc: 0.8502 - f1_score: 0.7684 - val_loss: 0.3935 - val_accuracy: 0.8734 - val_precision: 0.8734 - val_recall: 0.8734 - val_auc: 0.9426 - val_f1_score: 0.8734 - lr: 0.0010
# Epoch 12/100
# 67/67 [==============================] - 44s 661ms/step - loss: 0.4649 - accuracy: 0.7858 - precision: 0.7858 - recall: 0.7858 - auc: 0.8644 - f1_score: 0.7858 - val_loss: 0.3635 - val_accuracy: 0.8418 - val_precision: 0.8418 - val_recall: 0.8418 - val_auc: 0.9390 - val_f1_score: 0.8418 - lr: 0.0010
# Epoch 13/100
# 67/67 [==============================] - 44s 660ms/step - loss: 0.4884 - accuracy: 0.7811 - precision: 0.7811 - recall: 0.7811 - auc: 0.8515 - f1_score: 0.7811 - val_loss: 0.4888 - val_accuracy: 0.8228 - val_precision: 0.8228 - val_recall: 0.8228 - val_auc: 0.9110 - val_f1_score: 0.8228 - lr: 0.0010
# Epoch 14/100
# 67/67 [==============================] - 44s 662ms/step - loss: 0.4726 - accuracy: 0.7985 - precision: 0.7985 - recall: 0.7985 - auc: 0.8584 - f1_score: 0.7985 - val_loss: 0.5150 - val_accuracy: 0.7184 - val_precision: 0.7184 - val_recall: 0.7184 - val_auc: 0.8477 - val_f1_score: 0.7184 - lr: 0.0010
# Epoch 15/100
# 67/67 [==============================] - 44s 663ms/step - loss: 0.4744 - accuracy: 0.7905 - precision: 0.7905 - recall: 0.7905 - auc: 0.8603 - f1_score: 0.7905 - val_loss: 0.4387 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9612 - val_f1_score: 0.8892 - lr: 0.0010
# Epoch 16/100
# 67/67 [==============================] - 44s 659ms/step - loss: 0.4604 - accuracy: 0.7943 - precision: 0.7943 - recall: 0.7943 - auc: 0.8685 - f1_score: 0.7943 - val_loss: 0.5583 - val_accuracy: 0.6551 - val_precision: 0.6551 - val_recall: 0.6551 - val_auc: 0.8005 - val_f1_score: 0.6551 - lr: 0.0010
# Epoch 17/100
# 67/67 [==============================] - 45s 668ms/step - loss: 0.4933 - accuracy: 0.7675 - precision: 0.7675 - recall: 0.7675 - auc: 0.8458 - f1_score: 0.7675 - val_loss: 0.3841 - val_accuracy: 0.9051 - val_precision: 0.9051 - val_recall: 0.9051 - val_auc: 0.9617 - val_f1_score: 0.9051 - lr: 0.0010
# Epoch 18/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.4818 - accuracy: 0.7797 - precision: 0.7797 - recall: 0.7797 - auc: 0.8546 - f1_score: 0.7797 - val_loss: 0.4090 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9289 - val_f1_score: 0.8513 - lr: 0.0010
# Epoch 19/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.4680 - accuracy: 0.7971 - precision: 0.7971 - recall: 0.7971 - auc: 0.8619 - f1_score: 0.7971 - val_loss: 0.3542 - val_accuracy: 0.8861 - val_precision: 0.8861 - val_recall: 0.8861 - val_auc: 0.9619 - val_f1_score: 0.8861 - lr: 0.0010
# Epoch 20/100
# 67/67 [==============================] - 44s 664ms/step - loss: 0.4813 - accuracy: 0.7830 - precision: 0.7830 - recall: 0.7830 - auc: 0.8543 - f1_score: 0.7830 - val_loss: 0.3803 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_auc: 0.9720 - val_f1_score: 0.9114 - lr: 0.0010
# Epoch 21/100
# 67/67 [==============================] - 44s 664ms/step - loss: 0.4513 - accuracy: 0.8051 - precision: 0.8051 - recall: 0.8051 - auc: 0.8748 - f1_score: 0.8051 - val_loss: 0.4605 - val_accuracy: 0.7373 - val_precision: 0.7373 - val_recall: 0.7373 - val_auc: 0.8629 - val_f1_score: 0.7373 - lr: 0.0010
# Epoch 22/100
# 67/67 [==============================] - 44s 663ms/step - loss: 0.4587 - accuracy: 0.7947 - precision: 0.7947 - recall: 0.7947 - auc: 0.8670 - f1_score: 0.7947 - val_loss: 0.3241 - val_accuracy: 0.9335 - val_precision: 0.9335 - val_recall: 0.9335 - val_auc: 0.9782 - val_f1_score: 0.9335 - lr: 0.0010
# Epoch 23/100
# 67/67 [==============================] - 44s 658ms/step - loss: 0.4631 - accuracy: 0.8018 - precision: 0.8018 - recall: 0.8018 - auc: 0.8664 - f1_score: 0.8018 - val_loss: 0.3366 - val_accuracy: 0.9051 - val_precision: 0.9051 - val_recall: 0.9051 - val_auc: 0.9720 - val_f1_score: 0.9051 - lr: 0.0010
# Epoch 24/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.4482 - accuracy: 0.7900 - precision: 0.7900 - recall: 0.7900 - auc: 0.8749 - f1_score: 0.7900 - val_loss: 0.4491 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9580 - val_f1_score: 0.8987 - lr: 0.0010
# Epoch 25/100
# 67/67 [==============================] - 45s 669ms/step - loss: 0.4352 - accuracy: 0.7980 - precision: 0.7980 - recall: 0.7980 - auc: 0.8830 - f1_score: 0.7980 - val_loss: 0.3355 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_auc: 0.9684 - val_f1_score: 0.9114 - lr: 0.0010
# Epoch 26/100
# 67/67 [==============================] - 44s 661ms/step - loss: 0.4438 - accuracy: 0.8060 - precision: 0.8060 - recall: 0.8060 - auc: 0.8785 - f1_score: 0.8060 - val_loss: 0.4170 - val_accuracy: 0.8133 - val_precision: 0.8133 - val_recall: 0.8133 - val_auc: 0.9129 - val_f1_score: 0.8133 - lr: 0.0010
# Epoch 27/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.4283 - accuracy: 0.8060 - precision: 0.8060 - recall: 0.8060 - auc: 0.8872 - f1_score: 0.8060 - val_loss: 0.5094 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9090 - val_f1_score: 0.8513 - lr: 0.0010
# Epoch 28/100
# 67/67 [==============================] - 44s 663ms/step - loss: 0.4380 - accuracy: 0.8135 - precision: 0.8135 - recall: 0.8135 - auc: 0.8819 - f1_score: 0.8135 - val_loss: 0.2881 - val_accuracy: 0.9209 - val_precision: 0.9209 - val_recall: 0.9209 - val_auc: 0.9685 - val_f1_score: 0.9209 - lr: 0.0010
# Epoch 29/100
# 67/67 [==============================] - 44s 660ms/step - loss: 0.4120 - accuracy: 0.8243 - precision: 0.8243 - recall: 0.8243 - auc: 0.8951 - f1_score: 0.8243 - val_loss: 0.4834 - val_accuracy: 0.7785 - val_precision: 0.7785 - val_recall: 0.7785 - val_auc: 0.8577 - val_f1_score: 0.7785 - lr: 0.0010
# Epoch 30/100
# 67/67 [==============================] - 44s 659ms/step - loss: 0.4853 - accuracy: 0.7764 - precision: 0.7764 - recall: 0.7764 - auc: 0.8512 - f1_score: 0.7764 - val_loss: 0.4555 - val_accuracy: 0.8703 - val_precision: 0.8703 - val_recall: 0.8703 - val_auc: 0.9355 - val_f1_score: 0.8703 - lr: 0.0010
# Epoch 31/100
# 67/67 [==============================] - 44s 668ms/step - loss: 0.4302 - accuracy: 0.8046 - precision: 0.8046 - recall: 0.8046 - auc: 0.8853 - f1_score: 0.8046 - val_loss: 0.3935 - val_accuracy: 0.8766 - val_precision: 0.8766 - val_recall: 0.8766 - val_auc: 0.9471 - val_f1_score: 0.8766 - lr: 0.0010
# Epoch 32/100
# 67/67 [==============================] - 44s 663ms/step - loss: 0.4065 - accuracy: 0.8070 - precision: 0.8070 - recall: 0.8070 - auc: 0.8970 - f1_score: 0.8070 - val_loss: 0.3637 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9441 - val_f1_score: 0.8576 - lr: 0.0010
# Epoch 33/100
# 67/67 [==============================] - 44s 661ms/step - loss: 0.3895 - accuracy: 0.8318 - precision: 0.8318 - recall: 0.8318 - auc: 0.9084 - f1_score: 0.8318 - val_loss: 0.4022 - val_accuracy: 0.8956 - val_precision: 0.8956 - val_recall: 0.8956 - val_auc: 0.9633 - val_f1_score: 0.8956 - lr: 0.0010
# Epoch 34/100
# 67/67 [==============================] - 44s 661ms/step - loss: 0.3879 - accuracy: 0.8300 - precision: 0.8300 - recall: 0.8300 - auc: 0.9079 - f1_score: 0.8300 - val_loss: 0.3096 - val_accuracy: 0.9462 - val_precision: 0.9462 - val_recall: 0.9462 - val_auc: 0.9817 - val_f1_score: 0.9462 - lr: 0.0010
# Epoch 35/100
# 67/67 [==============================] - 44s 660ms/step - loss: 0.3623 - accuracy: 0.8342 - precision: 0.8342 - recall: 0.8342 - auc: 0.9186 - f1_score: 0.8342 - val_loss: 0.3461 - val_accuracy: 0.9146 - val_precision: 0.9146 - val_recall: 0.9146 - val_auc: 0.9777 - val_f1_score: 0.9146 - lr: 0.0010
# Epoch 36/100
# 67/67 [==============================] - 44s 663ms/step - loss: 0.3625 - accuracy: 0.8412 - precision: 0.8412 - recall: 0.8412 - auc: 0.9198 - f1_score: 0.8412 - val_loss: 0.4119 - val_accuracy: 0.8259 - val_precision: 0.8259 - val_recall: 0.8259 - val_auc: 0.8957 - val_f1_score: 0.8259 - lr: 0.0010
# Epoch 37/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.3520 - accuracy: 0.8506 - precision: 0.8506 - recall: 0.8506 - auc: 0.9250 - f1_score: 0.8506 - val_loss: 0.4400 - val_accuracy: 0.8133 - val_precision: 0.8133 - val_recall: 0.8133 - val_auc: 0.9089 - val_f1_score: 0.8133 - lr: 0.0010
# Epoch 38/100
# 67/67 [==============================] - ETA: 0s - loss: 0.3729 - accuracy: 0.8394 - precision: 0.8394 - recall: 0.8394 - auc: 0.9148 - f1_score: 0.8394
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 44s 664ms/step - loss: 0.3729 - accuracy: 0.8394 - precision: 0.8394 - recall: 0.8394 - auc: 0.9148 - f1_score: 0.8394 - val_loss: 0.4073 - val_accuracy: 0.8449 - val_precision: 0.8449 - val_recall: 0.8449 - val_auc: 0.9133 - val_f1_score: 0.8449 - lr: 0.0010
# Epoch 39/100
# 67/67 [==============================] - 45s 667ms/step - loss: 0.3176 - accuracy: 0.8647 - precision: 0.8647 - recall: 0.8647 - auc: 0.9408 - f1_score: 0.8647 - val_loss: 0.3743 - val_accuracy: 0.8703 - val_precision: 0.8703 - val_recall: 0.8703 - val_auc: 0.9364 - val_f1_score: 0.8703 - lr: 1.0000e-04
# Epoch 40/100
# 67/67 [==============================] - 44s 663ms/step - loss: 0.3024 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9468 - f1_score: 0.8779 - val_loss: 0.3950 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9317 - val_f1_score: 0.8576 - lr: 1.0000e-04
# Epoch 41/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.2948 - accuracy: 0.8835 - precision: 0.8835 - recall: 0.8835 - auc: 0.9504 - f1_score: 0.8835 - val_loss: 0.3579 - val_accuracy: 0.8797 - val_precision: 0.8797 - val_recall: 0.8797 - val_auc: 0.9448 - val_f1_score: 0.8797 - lr: 1.0000e-04
# Epoch 42/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.2946 - accuracy: 0.8760 - precision: 0.8760 - recall: 0.8760 - auc: 0.9492 - f1_score: 0.8760 - val_loss: 0.3309 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9520 - val_f1_score: 0.8892 - lr: 1.0000e-04
# Epoch 43/100
# 67/67 [==============================] - 44s 665ms/step - loss: 0.2919 - accuracy: 0.8816 - precision: 0.8816 - recall: 0.8816 - auc: 0.9504 - f1_score: 0.8816 - val_loss: 0.3771 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_auc: 0.9330 - val_f1_score: 0.8608 - lr: 1.0000e-04
# Epoch 44/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.2947 - accuracy: 0.8840 - precision: 0.8840 - recall: 0.8840 - auc: 0.9492 - f1_score: 0.8840 - val_loss: 0.3861 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9293 - val_f1_score: 0.8513 - lr: 1.0000e-04
# Epoch 45/100
# 67/67 [==============================] - 45s 669ms/step - loss: 0.2904 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9506 - f1_score: 0.8793 - val_loss: 0.3823 - val_accuracy: 0.8354 - val_precision: 0.8354 - val_recall: 0.8354 - val_auc: 0.9115 - val_f1_score: 0.8354 - lr: 1.0000e-04
# Epoch 46/100
# 67/67 [==============================] - 44s 662ms/step - loss: 0.2836 - accuracy: 0.8840 - precision: 0.8840 - recall: 0.8840 - auc: 0.9536 - f1_score: 0.8840 - val_loss: 0.3510 - val_accuracy: 0.8861 - val_precision: 0.8861 - val_recall: 0.8861 - val_auc: 0.9448 - val_f1_score: 0.8861 - lr: 1.0000e-04
# Epoch 47/100
# 67/67 [==============================] - 44s 663ms/step - loss: 0.2844 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9538 - f1_score: 0.8873 - val_loss: 0.3814 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9272 - val_f1_score: 0.8513 - lr: 1.0000e-04
# Epoch 48/100
# 67/67 [==============================] - ETA: 0s - loss: 0.2840 - accuracy: 0.8877 - precision: 0.8877 - recall: 0.8877 - auc: 0.9539 - f1_score: 0.8877
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 67/67 [==============================] - 45s 665ms/step - loss: 0.2840 - accuracy: 0.8877 - precision: 0.8877 - recall: 0.8877 - auc: 0.9539 - f1_score: 0.8877 - val_loss: 0.3602 - val_accuracy: 0.8671 - val_precision: 0.8671 - val_recall: 0.8671 - val_auc: 0.9313 - val_f1_score: 0.8671 - lr: 1.0000e-04
# Epoch 49/100
# 67/67 [==============================] - 45s 668ms/step - loss: 0.2740 - accuracy: 0.8887 - precision: 0.8887 - recall: 0.8887 - auc: 0.9561 - f1_score: 0.8887 - val_loss: 0.3736 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9314 - val_f1_score: 0.8639 - lr: 1.0000e-05
# Epoch 50/100
# 67/67 [==============================] - 45s 674ms/step - loss: 0.2715 - accuracy: 0.8901 - precision: 0.8901 - recall: 0.8901 - auc: 0.9581 - f1_score: 0.8901 - val_loss: 0.3838 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_auc: 0.9181 - val_f1_score: 0.8608 - lr: 1.0000e-05
# Epoch 51/100
# 67/67 [==============================] - 44s 662ms/step - loss: 0.2732 - accuracy: 0.8924 - precision: 0.8924 - recall: 0.8924 - auc: 0.9576 - f1_score: 0.8924 - val_loss: 0.3924 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_auc: 0.9149 - val_f1_score: 0.8481 - lr: 1.0000e-05
# Epoch 52/100
# 67/67 [==============================] - 44s 661ms/step - loss: 0.2707 - accuracy: 0.8934 - precision: 0.8934 - recall: 0.8934 - auc: 0.9585 - f1_score: 0.8934 - val_loss: 0.3944 - val_accuracy: 0.8386 - val_precision: 0.8386 - val_recall: 0.8386 - val_auc: 0.9168 - val_f1_score: 0.8386 - lr: 1.0000e-05
# Epoch 53/100
# 67/67 [==============================] - 44s 657ms/step - loss: 0.2738 - accuracy: 0.8948 - precision: 0.8948 - recall: 0.8948 - auc: 0.9572 - f1_score: 0.8948 - val_loss: 0.3661 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_auc: 0.9337 - val_f1_score: 0.8608 - lr: 1.0000e-05
# Epoch 54/100
# 67/67 [==============================] - 44s 661ms/step - loss: 0.2709 - accuracy: 0.8924 - precision: 0.8924 - recall: 0.8924 - auc: 0.9583 - f1_score: 0.8924 - val_loss: 0.3842 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9231 - val_f1_score: 0.8513 - lr: 1.0000e-05
# Epoch 55/100
# 67/67 [==============================] - 45s 669ms/step - loss: 0.2730 - accuracy: 0.8896 - precision: 0.8896 - recall: 0.8896 - auc: 0.9573 - f1_score: 0.8896 - val_loss: 0.3767 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_auc: 0.9258 - val_f1_score: 0.8481 - lr: 1.0000e-05
# Epoch 56/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.2709 - accuracy: 0.8868 - precision: 0.8868 - recall: 0.8868 - auc: 0.9579 - f1_score: 0.8868 - val_loss: 0.3851 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_auc: 0.9194 - val_f1_score: 0.8481 - lr: 1.0000e-05
# Epoch 57/100
# 67/67 [==============================] - 45s 667ms/step - loss: 0.2718 - accuracy: 0.8901 - precision: 0.8901 - recall: 0.8901 - auc: 0.9581 - f1_score: 0.8901 - val_loss: 0.3765 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9267 - val_f1_score: 0.8513 - lr: 1.0000e-05
# Epoch 58/100
# 67/67 [==============================] - ETA: 0s - loss: 0.2708 - accuracy: 0.8934 - precision: 0.8934 - recall: 0.8934 - auc: 0.9583 - f1_score: 0.8934
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1e-05.
# 67/67 [==============================] - 45s 666ms/step - loss: 0.2708 - accuracy: 0.8934 - precision: 0.8934 - recall: 0.8934 - auc: 0.9583 - f1_score: 0.8934 - val_loss: 0.3935 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9161 - val_f1_score: 0.8513 - lr: 1.0000e-05
# Epoch 59/100
# 67/67 [==============================] - 44s 658ms/step - loss: 0.2730 - accuracy: 0.8938 - precision: 0.8938 - recall: 0.8938 - auc: 0.9576 - f1_score: 0.8938 - val_loss: 0.3750 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9262 - val_f1_score: 0.8576 - lr: 1.0000e-05
# Epoch 60/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.2720 - accuracy: 0.8924 - precision: 0.8924 - recall: 0.8924 - auc: 0.9578 - f1_score: 0.8924 - val_loss: 0.3897 - val_accuracy: 0.8291 - val_precision: 0.8291 - val_recall: 0.8291 - val_auc: 0.9213 - val_f1_score: 0.8291 - lr: 1.0000e-05
# Epoch 61/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.2712 - accuracy: 0.8943 - precision: 0.8943 - recall: 0.8943 - auc: 0.9585 - f1_score: 0.8943 - val_loss: 0.3767 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_auc: 0.9219 - val_f1_score: 0.8608 - lr: 1.0000e-05
# Epoch 62/100
# 67/67 [==============================] - 45s 667ms/step - loss: 0.2686 - accuracy: 0.8943 - precision: 0.8943 - recall: 0.8943 - auc: 0.9588 - f1_score: 0.8943 - val_loss: 0.3832 - val_accuracy: 0.8449 - val_precision: 0.8449 - val_recall: 0.8449 - val_auc: 0.9248 - val_f1_score: 0.8449 - lr: 1.0000e-05
# Epoch 63/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.2690 - accuracy: 0.8985 - precision: 0.8985 - recall: 0.8985 - auc: 0.9594 - f1_score: 0.8985 - val_loss: 0.3910 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9167 - val_f1_score: 0.8639 - lr: 1.0000e-05
# Epoch 64/100
# 67/67 [==============================] - 44s 664ms/step - loss: 0.2723 - accuracy: 0.8901 - precision: 0.8901 - recall: 0.8901 - auc: 0.9574 - f1_score: 0.8901 - val_loss: 0.3797 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_auc: 0.9250 - val_f1_score: 0.8481 - lr: 1.0000e-05
# Epoch 65/100
# 67/67 [==============================] - 44s 660ms/step - loss: 0.2699 - accuracy: 0.8934 - precision: 0.8934 - recall: 0.8934 - auc: 0.9587 - f1_score: 0.8934 - val_loss: 0.3692 - val_accuracy: 0.8544 - val_precision: 0.8544 - val_recall: 0.8544 - val_auc: 0.9322 - val_f1_score: 0.8544 - lr: 1.0000e-05
# Epoch 66/100
# 67/67 [==============================] - 45s 671ms/step - loss: 0.2691 - accuracy: 0.8910 - precision: 0.8910 - recall: 0.8910 - auc: 0.9585 - f1_score: 0.8910 - val_loss: 0.3834 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_auc: 0.9215 - val_f1_score: 0.8481 - lr: 1.0000e-05
# Epoch 67/100
# 67/67 [==============================] - 44s 659ms/step - loss: 0.2706 - accuracy: 0.8953 - precision: 0.8953 - recall: 0.8953 - auc: 0.9582 - f1_score: 0.8953 - val_loss: 0.3725 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9288 - val_f1_score: 0.8576 - lr: 1.0000e-05
# Epoch 68/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.2684 - accuracy: 0.8891 - precision: 0.8891 - recall: 0.8891 - auc: 0.9590 - f1_score: 0.8891 - val_loss: 0.3802 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9206 - val_f1_score: 0.8576 - lr: 1.0000e-05
# Epoch 69/100
# 67/67 [==============================] - 45s 669ms/step - loss: 0.2701 - accuracy: 0.8910 - precision: 0.8910 - recall: 0.8910 - auc: 0.9582 - f1_score: 0.8910 - val_loss: 0.3856 - val_accuracy: 0.8386 - val_precision: 0.8386 - val_recall: 0.8386 - val_auc: 0.9162 - val_f1_score: 0.8386 - lr: 1.0000e-05
# Epoch 70/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.2703 - accuracy: 0.8967 - precision: 0.8967 - recall: 0.8967 - auc: 0.9585 - f1_score: 0.8967 - val_loss: 0.3811 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_auc: 0.9241 - val_f1_score: 0.8481 - lr: 1.0000e-05
# Epoch 71/100
# 67/67 [==============================] - 45s 670ms/step - loss: 0.2662 - accuracy: 0.9004 - precision: 0.9004 - recall: 0.9004 - auc: 0.9600 - f1_score: 0.9004 - val_loss: 0.3862 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9168 - val_f1_score: 0.8639 - lr: 1.0000e-05
# Epoch 72/100
# 67/67 [==============================] - 44s 663ms/step - loss: 0.2703 - accuracy: 0.8943 - precision: 0.8943 - recall: 0.8943 - auc: 0.9582 - f1_score: 0.8943 - val_loss: 0.3708 - val_accuracy: 0.8703 - val_precision: 0.8703 - val_recall: 0.8703 - val_auc: 0.9312 - val_f1_score: 0.8703 - lr: 1.0000e-05
# Epoch 73/100
# 67/67 [==============================] - 44s 659ms/step - loss: 0.2678 - accuracy: 0.8924 - precision: 0.8924 - recall: 0.8924 - auc: 0.9596 - f1_score: 0.8924 - val_loss: 0.3759 - val_accuracy: 0.8671 - val_precision: 0.8671 - val_recall: 0.8671 - val_auc: 0.9229 - val_f1_score: 0.8671 - lr: 1.0000e-05
# Epoch 74/100
# 67/67 [==============================] - 45s 671ms/step - loss: 0.2684 - accuracy: 0.8934 - precision: 0.8934 - recall: 0.8934 - auc: 0.9583 - f1_score: 0.8934 - val_loss: 0.3841 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9213 - val_f1_score: 0.8576 - lr: 1.0000e-05
# Epoch 75/100
# 67/67 [==============================] - 45s 667ms/step - loss: 0.2635 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9614 - f1_score: 0.9023 - val_loss: 0.3795 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9213 - val_f1_score: 0.8639 - lr: 1.0000e-05
# Epoch 76/100
# 67/67 [==============================] - 44s 662ms/step - loss: 0.2669 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9595 - f1_score: 0.8962 - val_loss: 0.3831 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9181 - val_f1_score: 0.8513 - lr: 1.0000e-05
# Epoch 77/100
# 67/67 [==============================] - 44s 660ms/step - loss: 0.2678 - accuracy: 0.8971 - precision: 0.8971 - recall: 0.8971 - auc: 0.9593 - f1_score: 0.8971 - val_loss: 0.3675 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9295 - val_f1_score: 0.8576 - lr: 1.0000e-05
# Epoch 78/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.2645 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9604 - f1_score: 0.8962 - val_loss: 0.3830 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_auc: 0.9207 - val_f1_score: 0.8608 - lr: 1.0000e-05
# Epoch 79/100
# 67/67 [==============================] - 44s 662ms/step - loss: 0.2622 - accuracy: 0.8953 - precision: 0.8953 - recall: 0.8953 - auc: 0.9612 - f1_score: 0.8953 - val_loss: 0.3802 - val_accuracy: 0.8576 - val_precision: 0.8576 - val_recall: 0.8576 - val_auc: 0.9209 - val_f1_score: 0.8576 - lr: 1.0000e-05
# Epoch 80/100
# 67/67 [==============================] - 44s 661ms/step - loss: 0.2681 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9595 - f1_score: 0.8962 - val_loss: 0.3969 - val_accuracy: 0.8418 - val_precision: 0.8418 - val_recall: 0.8418 - val_auc: 0.9101 - val_f1_score: 0.8418 - lr: 1.0000e-05
# Epoch 81/100
# 67/67 [==============================] - 45s 671ms/step - loss: 0.2708 - accuracy: 0.8971 - precision: 0.8971 - recall: 0.8971 - auc: 0.9579 - f1_score: 0.8971 - val_loss: 0.3815 - val_accuracy: 0.8418 - val_precision: 0.8418 - val_recall: 0.8418 - val_auc: 0.9183 - val_f1_score: 0.8418 - lr: 1.0000e-05
# Epoch 82/100
# 67/67 [==============================] - 44s 660ms/step - loss: 0.2662 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9595 - f1_score: 0.8962 - val_loss: 0.3864 - val_accuracy: 0.8418 - val_precision: 0.8418 - val_recall: 0.8418 - val_auc: 0.9197 - val_f1_score: 0.8418 - lr: 1.0000e-05
# Epoch 83/100
# 67/67 [==============================] - 45s 667ms/step - loss: 0.2607 - accuracy: 0.8976 - precision: 0.8976 - recall: 0.8976 - auc: 0.9616 - f1_score: 0.8976 - val_loss: 0.3952 - val_accuracy: 0.8418 - val_precision: 0.8418 - val_recall: 0.8418 - val_auc: 0.9090 - val_f1_score: 0.8418 - lr: 1.0000e-05
# Epoch 84/100
# 67/67 [==============================] - 44s 661ms/step - loss: 0.2682 - accuracy: 0.8971 - precision: 0.8971 - recall: 0.8971 - auc: 0.9587 - f1_score: 0.8971 - val_loss: 0.3931 - val_accuracy: 0.8544 - val_precision: 0.8544 - val_recall: 0.8544 - val_auc: 0.9128 - val_f1_score: 0.8544 - lr: 1.0000e-05
# Epoch 85/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.2656 - accuracy: 0.8967 - precision: 0.8967 - recall: 0.8967 - auc: 0.9601 - f1_score: 0.8967 - val_loss: 0.3950 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9120 - val_f1_score: 0.8513 - lr: 1.0000e-05
# Epoch 86/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.2661 - accuracy: 0.8938 - precision: 0.8938 - recall: 0.8938 - auc: 0.9593 - f1_score: 0.8938 - val_loss: 0.3948 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_auc: 0.9160 - val_f1_score: 0.8481 - lr: 1.0000e-05
# Epoch 87/100
# 67/67 [==============================] - 44s 659ms/step - loss: 0.2645 - accuracy: 0.9000 - precision: 0.9000 - recall: 0.9000 - auc: 0.9607 - f1_score: 0.9000 - val_loss: 0.3834 - val_accuracy: 0.8544 - val_precision: 0.8544 - val_recall: 0.8544 - val_auc: 0.9204 - val_f1_score: 0.8544 - lr: 1.0000e-05
# Epoch 88/100
# 67/67 [==============================] - 44s 662ms/step - loss: 0.2635 - accuracy: 0.8971 - precision: 0.8971 - recall: 0.8971 - auc: 0.9608 - f1_score: 0.8971 - val_loss: 0.4021 - val_accuracy: 0.8259 - val_precision: 0.8259 - val_recall: 0.8259 - val_auc: 0.9053 - val_f1_score: 0.8259 - lr: 1.0000e-05
# Epoch 89/100
# 67/67 [==============================] - 44s 662ms/step - loss: 0.2621 - accuracy: 0.8985 - precision: 0.8985 - recall: 0.8985 - auc: 0.9609 - f1_score: 0.8985 - val_loss: 0.3971 - val_accuracy: 0.8449 - val_precision: 0.8449 - val_recall: 0.8449 - val_auc: 0.9140 - val_f1_score: 0.8449 - lr: 1.0000e-05
# Epoch 90/100
# 67/67 [==============================] - 44s 662ms/step - loss: 0.2644 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9598 - f1_score: 0.8962 - val_loss: 0.3903 - val_accuracy: 0.8323 - val_precision: 0.8323 - val_recall: 0.8323 - val_auc: 0.9108 - val_f1_score: 0.8323 - lr: 1.0000e-05
# Epoch 91/100
# 67/67 [==============================] - 44s 658ms/step - loss: 0.2657 - accuracy: 0.8990 - precision: 0.8990 - recall: 0.8990 - auc: 0.9600 - f1_score: 0.8990 - val_loss: 0.3854 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9206 - val_f1_score: 0.8513 - lr: 1.0000e-05
# Epoch 92/100
# 67/67 [==============================] - 44s 656ms/step - loss: 0.2629 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9606 - f1_score: 0.8962 - val_loss: 0.3961 - val_accuracy: 0.8259 - val_precision: 0.8259 - val_recall: 0.8259 - val_auc: 0.9113 - val_f1_score: 0.8259 - lr: 1.0000e-05
# Epoch 93/100
# 67/67 [==============================] - 45s 673ms/step - loss: 0.2628 - accuracy: 0.8985 - precision: 0.8985 - recall: 0.8985 - auc: 0.9608 - f1_score: 0.8985 - val_loss: 0.3835 - val_accuracy: 0.8449 - val_precision: 0.8449 - val_recall: 0.8449 - val_auc: 0.9200 - val_f1_score: 0.8449 - lr: 1.0000e-05
# Epoch 94/100
# 67/67 [==============================] - 45s 665ms/step - loss: 0.2664 - accuracy: 0.8929 - precision: 0.8929 - recall: 0.8929 - auc: 0.9588 - f1_score: 0.8929 - val_loss: 0.3917 - val_accuracy: 0.8544 - val_precision: 0.8544 - val_recall: 0.8544 - val_auc: 0.9099 - val_f1_score: 0.8544 - lr: 1.0000e-05
# Epoch 95/100
# 67/67 [==============================] - 45s 666ms/step - loss: 0.2631 - accuracy: 0.8981 - precision: 0.8981 - recall: 0.8981 - auc: 0.9607 - f1_score: 0.8981 - val_loss: 0.3889 - val_accuracy: 0.8323 - val_precision: 0.8323 - val_recall: 0.8323 - val_auc: 0.9121 - val_f1_score: 0.8323 - lr: 1.0000e-05
# Epoch 96/100
# 67/67 [==============================] - 45s 668ms/step - loss: 0.2660 - accuracy: 0.9014 - precision: 0.9014 - recall: 0.9014 - auc: 0.9598 - f1_score: 0.9014 - val_loss: 0.3986 - val_accuracy: 0.8544 - val_precision: 0.8544 - val_recall: 0.8544 - val_auc: 0.9086 - val_f1_score: 0.8544 - lr: 1.0000e-05
# Epoch 97/100
# 67/67 [==============================] - 44s 664ms/step - loss: 0.2603 - accuracy: 0.8976 - precision: 0.8976 - recall: 0.8976 - auc: 0.9620 - f1_score: 0.8976 - val_loss: 0.3763 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9180 - val_f1_score: 0.8513 - lr: 1.0000e-05
# Epoch 98/100
# 67/67 [==============================] - 44s 664ms/step - loss: 0.2625 - accuracy: 0.8990 - precision: 0.8990 - recall: 0.8990 - auc: 0.9602 - f1_score: 0.8990 - val_loss: 0.3766 - val_accuracy: 0.8608 - val_precision: 0.8608 - val_recall: 0.8608 - val_auc: 0.9231 - val_f1_score: 0.8608 - lr: 1.0000e-05
# Epoch 99/100
# 67/67 [==============================] - 45s 668ms/step - loss: 0.2621 - accuracy: 0.8967 - precision: 0.8967 - recall: 0.8967 - auc: 0.9611 - f1_score: 0.8967 - val_loss: 0.3834 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9224 - val_f1_score: 0.8513 - lr: 1.0000e-05
# Epoch 100/100
# 67/67 [==============================] - 45s 672ms/step - loss: 0.2617 - accuracy: 0.8985 - precision: 0.8985 - recall: 0.8985 - auc: 0.9613 - f1_score: 0.8985 - val_loss: 0.3980 - val_accuracy: 0.8323 - val_precision: 0.8323 - val_recall: 0.8323 - val_auc: 0.9105 - val_f1_score: 0.8323 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 0s 9ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.8592691398460096
# F1-Score for each class: [0.81773399 0.90080429]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.8527918781725888
# specificity: 0.9120879120879121

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 9ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 4s 342ms/step - loss: 0.3711 - accuracy: 0.8650 - precision: 0.8650 - recall: 0.8650 - auc: 0.9156 - f1_score: 0.8650
# Test loss: 0.3710945248603821
# Test accuracy: 0.8649517893791199
# Test precision: 0.8649517893791199
# Test recall: 0.8649517893791199
# Test AUC: 0.9155664443969727
# Test F1 Score: 0.8649517893791199

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 9ms/step
#               precision    recall  f1-score   support
#
#            0       0.74      0.91      0.82        91
#            1       0.95      0.85      0.90       197
#
#     accuracy                           0.87       288
#    macro avg       0.85      0.88      0.86       288
# weighted avg       0.89      0.87      0.87       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
