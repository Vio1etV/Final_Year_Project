# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/400X/test'
train_dir = '/root/BreastCancer/400X/train'


batch_size = 16
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/400X/train/malignant'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1782 images belonging to 2 classes.
# Found 266 images belonging to 2 classes.
# Found 272 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %% [markdown]
# <h1>Model Construction<h1>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Concatenate, Flatten, Dense

def inception_block(x, filters):
    conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(x)

    conv3x3 = Conv2D(filters[1], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv3x3)

    conv5x5 = Conv2D(filters[3], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv5x5)

    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    maxpool = Conv2D(filters[5], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(maxpool)

    inception_block = Concatenate(axis=-1)([conv1x1, conv3x3, conv5x5, maxpool])
    return inception_block

def inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer = 'he_normal')(input_tensor)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception blocks
    x = inception_block(x, filters=[64, 128, 128, 32, 96, 32])
    # x = inception_block(x, filters=[128, 128, 96, 64, 64, 64])

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=x)

    return model


# Create the InceptionNet model
model = inception_net(input_shape, num_classes)

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  8320        ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 128)  147584      ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 96)   76896       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 320)  0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 320)  0          ['concatenate[0][0]']
#
#  global_average_pooling2d (Glob  (None, 320)         0           ['max_pooling2d_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            642         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 251,234
# Trainable params: 251,234
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2023-12-24 21:02:40.420005: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 21:02:40.969184: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'macro')
    ]
)

MODEL_NAME = "InceptionNet400XResized"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/1. InceptionNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-24 21:02:44.579288: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-24 21:02:45.982907: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 112/112 [==============================] - 41s 337ms/step - loss: 0.5790 - accuracy: 0.7172 - precision: 0.7172 - recall: 0.7172 - auc: 0.7758 - f1_score: 0.7170 - val_loss: 0.4642 - val_accuracy: 0.7820 - val_precision: 0.7820 - val_recall: 0.7820 - val_auc: 0.8852 - val_f1_score: 0.7686 - lr: 0.0010
# Epoch 2/100
# 112/112 [==============================] - 37s 333ms/step - loss: 0.5441 - accuracy: 0.7413 - precision: 0.7413 - recall: 0.7413 - auc: 0.8028 - f1_score: 0.7409 - val_loss: 0.3985 - val_accuracy: 0.9173 - val_precision: 0.9173 - val_recall: 0.9173 - val_auc: 0.9670 - val_f1_score: 0.9168 - lr: 0.0010
# Epoch 3/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.5092 - accuracy: 0.7750 - precision: 0.7750 - recall: 0.7750 - auc: 0.8328 - f1_score: 0.7742 - val_loss: 0.4208 - val_accuracy: 0.8271 - val_precision: 0.8271 - val_recall: 0.8271 - val_auc: 0.9316 - val_f1_score: 0.8212 - lr: 0.0010
# Epoch 4/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.4855 - accuracy: 0.7811 - precision: 0.7811 - recall: 0.7811 - auc: 0.8483 - f1_score: 0.7807 - val_loss: 0.4481 - val_accuracy: 0.8459 - val_precision: 0.8459 - val_recall: 0.8459 - val_auc: 0.9343 - val_f1_score: 0.8445 - lr: 0.0010
# Epoch 5/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.4718 - accuracy: 0.7890 - precision: 0.7890 - recall: 0.7890 - auc: 0.8590 - f1_score: 0.7885 - val_loss: 0.3997 - val_accuracy: 0.8985 - val_precision: 0.8985 - val_recall: 0.8985 - val_auc: 0.9615 - val_f1_score: 0.8977 - lr: 0.0010
# Epoch 6/100
# 112/112 [==============================] - 37s 334ms/step - loss: 0.4691 - accuracy: 0.7935 - precision: 0.7935 - recall: 0.7935 - auc: 0.8601 - f1_score: 0.7924 - val_loss: 0.3945 - val_accuracy: 0.8835 - val_precision: 0.8835 - val_recall: 0.8835 - val_auc: 0.9558 - val_f1_score: 0.8833 - lr: 0.0010
# Epoch 7/100
# 112/112 [==============================] - 37s 334ms/step - loss: 0.4512 - accuracy: 0.8042 - precision: 0.8042 - recall: 0.8042 - auc: 0.8724 - f1_score: 0.8036 - val_loss: 0.5337 - val_accuracy: 0.7857 - val_precision: 0.7857 - val_recall: 0.7857 - val_auc: 0.8387 - val_f1_score: 0.7857 - lr: 0.0010
# Epoch 8/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.4867 - accuracy: 0.7671 - precision: 0.7671 - recall: 0.7671 - auc: 0.8490 - f1_score: 0.7662 - val_loss: 0.6180 - val_accuracy: 0.6541 - val_precision: 0.6541 - val_recall: 0.6541 - val_auc: 0.7421 - val_f1_score: 0.6216 - lr: 0.0010
# Epoch 9/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.4772 - accuracy: 0.7890 - precision: 0.7890 - recall: 0.7890 - auc: 0.8565 - f1_score: 0.7889 - val_loss: 0.4750 - val_accuracy: 0.7895 - val_precision: 0.7895 - val_recall: 0.7895 - val_auc: 0.8707 - val_f1_score: 0.7885 - lr: 0.0010
# Epoch 10/100
# 112/112 [==============================] - 37s 329ms/step - loss: 0.4385 - accuracy: 0.8165 - precision: 0.8165 - recall: 0.8165 - auc: 0.8813 - f1_score: 0.8162 - val_loss: 0.7444 - val_accuracy: 0.5977 - val_precision: 0.5977 - val_recall: 0.5977 - val_auc: 0.7256 - val_f1_score: 0.5331 - lr: 0.0010
# Epoch 11/100
# 112/112 [==============================] - 37s 329ms/step - loss: 0.4245 - accuracy: 0.8171 - precision: 0.8171 - recall: 0.8171 - auc: 0.8860 - f1_score: 0.8166 - val_loss: 0.4676 - val_accuracy: 0.7932 - val_precision: 0.7932 - val_recall: 0.7932 - val_auc: 0.8655 - val_f1_score: 0.7833 - lr: 0.0010
# Epoch 12/100
# 112/112 [==============================] - 37s 329ms/step - loss: 0.4396 - accuracy: 0.7991 - precision: 0.7991 - recall: 0.7991 - auc: 0.8782 - f1_score: 0.7986 - val_loss: 0.6495 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_auc: 0.7604 - val_f1_score: 0.6853 - lr: 0.0010
# Epoch 13/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.4189 - accuracy: 0.8215 - precision: 0.8215 - recall: 0.8215 - auc: 0.8903 - f1_score: 0.8211 - val_loss: 0.3542 - val_accuracy: 0.8797 - val_precision: 0.8797 - val_recall: 0.8797 - val_auc: 0.9350 - val_f1_score: 0.8796 - lr: 0.0010
# Epoch 14/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.4349 - accuracy: 0.8064 - precision: 0.8064 - recall: 0.8064 - auc: 0.8814 - f1_score: 0.8057 - val_loss: 0.4309 - val_accuracy: 0.8045 - val_precision: 0.8045 - val_recall: 0.8045 - val_auc: 0.8829 - val_f1_score: 0.7995 - lr: 0.0010
# Epoch 15/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.4137 - accuracy: 0.8204 - precision: 0.8204 - recall: 0.8204 - auc: 0.8932 - f1_score: 0.8198 - val_loss: 0.5463 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.8317 - val_f1_score: 0.7569 - lr: 0.0010
# Epoch 16/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.4113 - accuracy: 0.8305 - precision: 0.8305 - recall: 0.8305 - auc: 0.8945 - f1_score: 0.8301 - val_loss: 0.5159 - val_accuracy: 0.7857 - val_precision: 0.7857 - val_recall: 0.7857 - val_auc: 0.8578 - val_f1_score: 0.7856 - lr: 0.0010
# Epoch 17/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.4063 - accuracy: 0.8305 - precision: 0.8305 - recall: 0.8305 - auc: 0.8964 - f1_score: 0.8299 - val_loss: 0.4582 - val_accuracy: 0.8496 - val_precision: 0.8496 - val_recall: 0.8496 - val_auc: 0.8936 - val_f1_score: 0.8496 - lr: 0.0010
# Epoch 18/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.4213 - accuracy: 0.8277 - precision: 0.8277 - recall: 0.8277 - auc: 0.8918 - f1_score: 0.8272 - val_loss: 0.8003 - val_accuracy: 0.7068 - val_precision: 0.7068 - val_recall: 0.7068 - val_auc: 0.7448 - val_f1_score: 0.7068 - lr: 0.0010
# Epoch 19/100
# 112/112 [==============================] - 38s 336ms/step - loss: 0.4129 - accuracy: 0.8283 - precision: 0.8283 - recall: 0.8283 - auc: 0.8926 - f1_score: 0.8278 - val_loss: 0.5714 - val_accuracy: 0.7406 - val_precision: 0.7406 - val_recall: 0.7406 - val_auc: 0.8174 - val_f1_score: 0.7355 - lr: 0.0010
# Epoch 20/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.3985 - accuracy: 0.8266 - precision: 0.8266 - recall: 0.8266 - auc: 0.9016 - f1_score: 0.8262 - val_loss: 0.7246 - val_accuracy: 0.6090 - val_precision: 0.6090 - val_recall: 0.6090 - val_auc: 0.6676 - val_f1_score: 0.5762 - lr: 0.0010
# Epoch 21/100
# 112/112 [==============================] - 37s 333ms/step - loss: 0.3930 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.9033 - f1_score: 0.8287 - val_loss: 0.4705 - val_accuracy: 0.8459 - val_precision: 0.8459 - val_recall: 0.8459 - val_auc: 0.8844 - val_f1_score: 0.8457 - lr: 0.0010
# Epoch 22/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.3959 - accuracy: 0.8356 - precision: 0.8356 - recall: 0.8356 - auc: 0.9042 - f1_score: 0.8350 - val_loss: 0.8338 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.7589 - val_f1_score: 0.7711 - lr: 0.0010
# Epoch 23/100
# 112/112 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.8496 - precision: 0.8496 - recall: 0.8496 - auc: 0.9160 - f1_score: 0.8492
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 112/112 [==============================] - 38s 336ms/step - loss: 0.3711 - accuracy: 0.8496 - precision: 0.8496 - recall: 0.8496 - auc: 0.9160 - f1_score: 0.8492 - val_loss: 0.5669 - val_accuracy: 0.8083 - val_precision: 0.8083 - val_recall: 0.8083 - val_auc: 0.8427 - val_f1_score: 0.8082 - lr: 0.0010
# Epoch 24/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.3348 - accuracy: 0.8676 - precision: 0.8676 - recall: 0.8676 - auc: 0.9321 - f1_score: 0.8671 - val_loss: 0.7348 - val_accuracy: 0.7857 - val_precision: 0.7857 - val_recall: 0.7857 - val_auc: 0.7953 - val_f1_score: 0.7841 - lr: 1.0000e-04
# Epoch 25/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.3280 - accuracy: 0.8687 - precision: 0.8687 - recall: 0.8687 - auc: 0.9361 - f1_score: 0.8683 - val_loss: 0.7247 - val_accuracy: 0.7218 - val_precision: 0.7218 - val_recall: 0.7218 - val_auc: 0.7625 - val_f1_score: 0.7218 - lr: 1.0000e-04
# Epoch 26/100
# 112/112 [==============================] - 37s 334ms/step - loss: 0.3274 - accuracy: 0.8653 - precision: 0.8653 - recall: 0.8653 - auc: 0.9358 - f1_score: 0.8650 - val_loss: 0.7908 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7702 - val_f1_score: 0.7635 - lr: 1.0000e-04
# Epoch 27/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.3231 - accuracy: 0.8732 - precision: 0.8732 - recall: 0.8732 - auc: 0.9379 - f1_score: 0.8729 - val_loss: 0.6768 - val_accuracy: 0.7632 - val_precision: 0.7632 - val_recall: 0.7632 - val_auc: 0.7988 - val_f1_score: 0.7626 - lr: 1.0000e-04
# Epoch 28/100
# 112/112 [==============================] - 38s 336ms/step - loss: 0.3203 - accuracy: 0.8760 - precision: 0.8760 - recall: 0.8760 - auc: 0.9384 - f1_score: 0.8756 - val_loss: 0.7479 - val_accuracy: 0.7857 - val_precision: 0.7857 - val_recall: 0.7857 - val_auc: 0.7861 - val_f1_score: 0.7831 - lr: 1.0000e-04
# Epoch 29/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.3182 - accuracy: 0.8721 - precision: 0.8721 - recall: 0.8721 - auc: 0.9402 - f1_score: 0.8717 - val_loss: 0.7057 - val_accuracy: 0.8083 - val_precision: 0.8083 - val_recall: 0.8083 - val_auc: 0.8172 - val_f1_score: 0.8068 - lr: 1.0000e-04
# Epoch 30/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.3178 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9402 - f1_score: 0.8747 - val_loss: 0.6029 - val_accuracy: 0.7632 - val_precision: 0.7632 - val_recall: 0.7632 - val_auc: 0.8213 - val_f1_score: 0.7630 - lr: 1.0000e-04
# Epoch 31/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.3160 - accuracy: 0.8659 - precision: 0.8659 - recall: 0.8659 - auc: 0.9406 - f1_score: 0.8654 - val_loss: 0.6983 - val_accuracy: 0.7932 - val_precision: 0.7932 - val_recall: 0.7932 - val_auc: 0.8108 - val_f1_score: 0.7904 - lr: 1.0000e-04
# Epoch 32/100
# 112/112 [==============================] - 37s 333ms/step - loss: 0.3141 - accuracy: 0.8799 - precision: 0.8799 - recall: 0.8799 - auc: 0.9414 - f1_score: 0.8796 - val_loss: 0.7158 - val_accuracy: 0.7820 - val_precision: 0.7820 - val_recall: 0.7820 - val_auc: 0.7915 - val_f1_score: 0.7799 - lr: 1.0000e-04
# Epoch 33/100
# 112/112 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9436 - f1_score: 0.8830
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 112/112 [==============================] - 37s 331ms/step - loss: 0.3092 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9436 - f1_score: 0.8830 - val_loss: 0.7162 - val_accuracy: 0.7632 - val_precision: 0.7632 - val_recall: 0.7632 - val_auc: 0.7783 - val_f1_score: 0.7614 - lr: 1.0000e-04
# Epoch 34/100
# 112/112 [==============================] - 37s 328ms/step - loss: 0.3024 - accuracy: 0.8861 - precision: 0.8861 - recall: 0.8861 - auc: 0.9468 - f1_score: 0.8858 - val_loss: 0.7208 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.7811 - val_f1_score: 0.7723 - lr: 1.0000e-05
# Epoch 35/100
# 112/112 [==============================] - 37s 335ms/step - loss: 0.2986 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9481 - f1_score: 0.8830 - val_loss: 0.6994 - val_accuracy: 0.7970 - val_precision: 0.7970 - val_recall: 0.7970 - val_auc: 0.7910 - val_f1_score: 0.7953 - lr: 1.0000e-05
# Epoch 36/100
# 112/112 [==============================] - 37s 333ms/step - loss: 0.2959 - accuracy: 0.8883 - precision: 0.8883 - recall: 0.8883 - auc: 0.9493 - f1_score: 0.8881 - val_loss: 0.7411 - val_accuracy: 0.7594 - val_precision: 0.7594 - val_recall: 0.7594 - val_auc: 0.7926 - val_f1_score: 0.7567 - lr: 1.0000e-05
# Epoch 37/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2980 - accuracy: 0.8844 - precision: 0.8844 - recall: 0.8844 - auc: 0.9480 - f1_score: 0.8842 - val_loss: 0.7655 - val_accuracy: 0.7594 - val_precision: 0.7594 - val_recall: 0.7594 - val_auc: 0.7685 - val_f1_score: 0.7571 - lr: 1.0000e-05
# Epoch 38/100
# 112/112 [==============================] - 37s 329ms/step - loss: 0.2992 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9477 - f1_score: 0.8898 - val_loss: 0.7192 - val_accuracy: 0.7556 - val_precision: 0.7556 - val_recall: 0.7556 - val_auc: 0.7870 - val_f1_score: 0.7538 - lr: 1.0000e-05
# Epoch 39/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2983 - accuracy: 0.8866 - precision: 0.8866 - recall: 0.8866 - auc: 0.9480 - f1_score: 0.8864 - val_loss: 0.7269 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7798 - val_f1_score: 0.7639 - lr: 1.0000e-05
# Epoch 40/100
# 112/112 [==============================] - 37s 333ms/step - loss: 0.2998 - accuracy: 0.8889 - precision: 0.8889 - recall: 0.8889 - auc: 0.9476 - f1_score: 0.8887 - val_loss: 0.7738 - val_accuracy: 0.7782 - val_precision: 0.7782 - val_recall: 0.7782 - val_auc: 0.7676 - val_f1_score: 0.7755 - lr: 1.0000e-05
# Epoch 41/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2982 - accuracy: 0.8889 - precision: 0.8889 - recall: 0.8889 - auc: 0.9476 - f1_score: 0.8887 - val_loss: 0.7569 - val_accuracy: 0.7857 - val_precision: 0.7857 - val_recall: 0.7857 - val_auc: 0.7827 - val_f1_score: 0.7831 - lr: 1.0000e-05
# Epoch 42/100
# 112/112 [==============================] - 37s 334ms/step - loss: 0.2983 - accuracy: 0.8923 - precision: 0.8923 - recall: 0.8923 - auc: 0.9482 - f1_score: 0.8920 - val_loss: 0.7685 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7660 - val_f1_score: 0.7671 - lr: 1.0000e-05
# Epoch 43/100
# 112/112 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.8878 - precision: 0.8878 - recall: 0.8878 - auc: 0.9494 - f1_score: 0.8876
# Epoch 43: ReduceLROnPlateau reducing learning rate to 1e-05.
# 112/112 [==============================] - 37s 331ms/step - loss: 0.2947 - accuracy: 0.8878 - precision: 0.8878 - recall: 0.8878 - auc: 0.9494 - f1_score: 0.8876 - val_loss: 0.7475 - val_accuracy: 0.7632 - val_precision: 0.7632 - val_recall: 0.7632 - val_auc: 0.7746 - val_f1_score: 0.7614 - lr: 1.0000e-05
# Epoch 44/100
# 112/112 [==============================] - 38s 340ms/step - loss: 0.2969 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9485 - f1_score: 0.8898 - val_loss: 0.7575 - val_accuracy: 0.7594 - val_precision: 0.7594 - val_recall: 0.7594 - val_auc: 0.7724 - val_f1_score: 0.7567 - lr: 1.0000e-05
# Epoch 45/100
# 112/112 [==============================] - 37s 334ms/step - loss: 0.2968 - accuracy: 0.8906 - precision: 0.8906 - recall: 0.8906 - auc: 0.9483 - f1_score: 0.8903 - val_loss: 0.7680 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7714 - val_f1_score: 0.7683 - lr: 1.0000e-05
# Epoch 46/100
# 112/112 [==============================] - 37s 333ms/step - loss: 0.2948 - accuracy: 0.8861 - precision: 0.8861 - recall: 0.8861 - auc: 0.9493 - f1_score: 0.8858 - val_loss: 0.7349 - val_accuracy: 0.7594 - val_precision: 0.7594 - val_recall: 0.7594 - val_auc: 0.7825 - val_f1_score: 0.7563 - lr: 1.0000e-05
# Epoch 47/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2948 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9490 - f1_score: 0.8831 - val_loss: 0.7338 - val_accuracy: 0.7519 - val_precision: 0.7519 - val_recall: 0.7519 - val_auc: 0.7700 - val_f1_score: 0.7498 - lr: 1.0000e-05
# Epoch 48/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2958 - accuracy: 0.8872 - precision: 0.8872 - recall: 0.8872 - auc: 0.9488 - f1_score: 0.8869 - val_loss: 0.7850 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.7648 - val_f1_score: 0.7711 - lr: 1.0000e-05
# Epoch 49/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2941 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9495 - f1_score: 0.8893 - val_loss: 0.7618 - val_accuracy: 0.7594 - val_precision: 0.7594 - val_recall: 0.7594 - val_auc: 0.7750 - val_f1_score: 0.7567 - lr: 1.0000e-05
# Epoch 50/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.2938 - accuracy: 0.8861 - precision: 0.8861 - recall: 0.8861 - auc: 0.9495 - f1_score: 0.8858 - val_loss: 0.7815 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7792 - val_f1_score: 0.7630 - lr: 1.0000e-05
# Epoch 51/100
# 112/112 [==============================] - 37s 328ms/step - loss: 0.2961 - accuracy: 0.8861 - precision: 0.8861 - recall: 0.8861 - auc: 0.9486 - f1_score: 0.8858 - val_loss: 0.7500 - val_accuracy: 0.7556 - val_precision: 0.7556 - val_recall: 0.7556 - val_auc: 0.7754 - val_f1_score: 0.7527 - lr: 1.0000e-05
# Epoch 52/100
# 112/112 [==============================] - 37s 329ms/step - loss: 0.2942 - accuracy: 0.8911 - precision: 0.8911 - recall: 0.8911 - auc: 0.9500 - f1_score: 0.8909 - val_loss: 0.7455 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.7861 - val_f1_score: 0.7711 - lr: 1.0000e-05
# Epoch 53/100
# 112/112 [==============================] - 37s 334ms/step - loss: 0.2930 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9500 - f1_score: 0.8892 - val_loss: 0.7620 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7766 - val_f1_score: 0.7679 - lr: 1.0000e-05
# Epoch 54/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2923 - accuracy: 0.8878 - precision: 0.8878 - recall: 0.8878 - auc: 0.9501 - f1_score: 0.8875 - val_loss: 0.7661 - val_accuracy: 0.7556 - val_precision: 0.7556 - val_recall: 0.7556 - val_auc: 0.7744 - val_f1_score: 0.7518 - lr: 1.0000e-05
# Epoch 55/100
# 112/112 [==============================] - 37s 333ms/step - loss: 0.2911 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9504 - f1_score: 0.8893 - val_loss: 0.7768 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7781 - val_f1_score: 0.7647 - lr: 1.0000e-05
# Epoch 56/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2923 - accuracy: 0.8911 - precision: 0.8911 - recall: 0.8911 - auc: 0.9503 - f1_score: 0.8909 - val_loss: 0.7914 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.7678 - val_f1_score: 0.7715 - lr: 1.0000e-05
# Epoch 57/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2929 - accuracy: 0.8934 - precision: 0.8934 - recall: 0.8934 - auc: 0.9502 - f1_score: 0.8932 - val_loss: 0.7949 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7734 - val_f1_score: 0.7675 - lr: 1.0000e-05
# Epoch 58/100
# 112/112 [==============================] - 37s 333ms/step - loss: 0.2952 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9488 - f1_score: 0.8938 - val_loss: 0.7479 - val_accuracy: 0.7481 - val_precision: 0.7481 - val_recall: 0.7481 - val_auc: 0.7757 - val_f1_score: 0.7459 - lr: 1.0000e-05
# Epoch 59/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.2936 - accuracy: 0.8883 - precision: 0.8883 - recall: 0.8883 - auc: 0.9496 - f1_score: 0.8880 - val_loss: 0.7409 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7841 - val_f1_score: 0.7639 - lr: 1.0000e-05
# Epoch 60/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2912 - accuracy: 0.8917 - precision: 0.8917 - recall: 0.8917 - auc: 0.9504 - f1_score: 0.8915 - val_loss: 0.7565 - val_accuracy: 0.7632 - val_precision: 0.7632 - val_recall: 0.7632 - val_auc: 0.7770 - val_f1_score: 0.7607 - lr: 1.0000e-05
# Epoch 61/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2935 - accuracy: 0.8928 - precision: 0.8928 - recall: 0.8928 - auc: 0.9500 - f1_score: 0.8926 - val_loss: 0.7566 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.7774 - val_f1_score: 0.7719 - lr: 1.0000e-05
# Epoch 62/100
# 112/112 [==============================] - 37s 334ms/step - loss: 0.2918 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9501 - f1_score: 0.8893 - val_loss: 0.7401 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7831 - val_f1_score: 0.7643 - lr: 1.0000e-05
# Epoch 63/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.2921 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9501 - f1_score: 0.8898 - val_loss: 0.8010 - val_accuracy: 0.7594 - val_precision: 0.7594 - val_recall: 0.7594 - val_auc: 0.7648 - val_f1_score: 0.7559 - lr: 1.0000e-05
# Epoch 64/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.2912 - accuracy: 0.8956 - precision: 0.8956 - recall: 0.8956 - auc: 0.9504 - f1_score: 0.8955 - val_loss: 0.7704 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7768 - val_f1_score: 0.7635 - lr: 1.0000e-05
# Epoch 65/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2881 - accuracy: 0.8928 - precision: 0.8928 - recall: 0.8928 - auc: 0.9518 - f1_score: 0.8926 - val_loss: 0.7931 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7750 - val_f1_score: 0.7679 - lr: 1.0000e-05
# Epoch 66/100
# 112/112 [==============================] - 37s 329ms/step - loss: 0.2923 - accuracy: 0.8889 - precision: 0.8889 - recall: 0.8889 - auc: 0.9499 - f1_score: 0.8887 - val_loss: 0.7841 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7722 - val_f1_score: 0.7643 - lr: 1.0000e-05
# Epoch 67/100
# 112/112 [==============================] - 37s 328ms/step - loss: 0.2915 - accuracy: 0.8934 - precision: 0.8934 - recall: 0.8934 - auc: 0.9503 - f1_score: 0.8932 - val_loss: 0.7522 - val_accuracy: 0.7782 - val_precision: 0.7782 - val_recall: 0.7782 - val_auc: 0.7782 - val_f1_score: 0.7755 - lr: 1.0000e-05
# Epoch 68/100
# 112/112 [==============================] - 37s 329ms/step - loss: 0.2889 - accuracy: 0.8967 - precision: 0.8967 - recall: 0.8967 - auc: 0.9515 - f1_score: 0.8966 - val_loss: 0.7413 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7822 - val_f1_score: 0.7671 - lr: 1.0000e-05
# Epoch 69/100
# 112/112 [==============================] - 38s 335ms/step - loss: 0.2898 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9507 - f1_score: 0.8898 - val_loss: 0.7787 - val_accuracy: 0.7632 - val_precision: 0.7632 - val_recall: 0.7632 - val_auc: 0.7718 - val_f1_score: 0.7603 - lr: 1.0000e-05
# Epoch 70/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2884 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9520 - f1_score: 0.8960 - val_loss: 0.7937 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.7820 - val_f1_score: 0.7711 - lr: 1.0000e-05
# Epoch 71/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.2884 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9510 - f1_score: 0.8938 - val_loss: 0.7652 - val_accuracy: 0.7481 - val_precision: 0.7481 - val_recall: 0.7481 - val_auc: 0.7743 - val_f1_score: 0.7455 - lr: 1.0000e-05
# Epoch 72/100
# 112/112 [==============================] - 37s 335ms/step - loss: 0.2893 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9510 - f1_score: 0.8899 - val_loss: 0.7880 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7735 - val_f1_score: 0.7675 - lr: 1.0000e-05
# Epoch 73/100
# 112/112 [==============================] - 37s 329ms/step - loss: 0.2924 - accuracy: 0.8934 - precision: 0.8934 - recall: 0.8934 - auc: 0.9505 - f1_score: 0.8932 - val_loss: 0.7830 - val_accuracy: 0.7820 - val_precision: 0.7820 - val_recall: 0.7820 - val_auc: 0.7839 - val_f1_score: 0.7788 - lr: 1.0000e-05
# Epoch 74/100
# 112/112 [==============================] - 37s 334ms/step - loss: 0.2884 - accuracy: 0.9012 - precision: 0.9012 - recall: 0.9012 - auc: 0.9518 - f1_score: 0.9011 - val_loss: 0.7284 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7885 - val_f1_score: 0.7643 - lr: 1.0000e-05
# Epoch 75/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2898 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9505 - f1_score: 0.8938 - val_loss: 0.7567 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7783 - val_f1_score: 0.7675 - lr: 1.0000e-05
# Epoch 76/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2866 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9522 - f1_score: 0.8938 - val_loss: 0.7814 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7822 - val_f1_score: 0.7689 - lr: 1.0000e-05
# Epoch 77/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2876 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9519 - f1_score: 0.8938 - val_loss: 0.7752 - val_accuracy: 0.7594 - val_precision: 0.7594 - val_recall: 0.7594 - val_auc: 0.7750 - val_f1_score: 0.7567 - lr: 1.0000e-05
# Epoch 78/100
# 112/112 [==============================] - 37s 335ms/step - loss: 0.2876 - accuracy: 0.8923 - precision: 0.8923 - recall: 0.8923 - auc: 0.9515 - f1_score: 0.8921 - val_loss: 0.7298 - val_accuracy: 0.7857 - val_precision: 0.7857 - val_recall: 0.7857 - val_auc: 0.7925 - val_f1_score: 0.7831 - lr: 1.0000e-05
# Epoch 79/100
# 112/112 [==============================] - 38s 336ms/step - loss: 0.2854 - accuracy: 0.8928 - precision: 0.8928 - recall: 0.8928 - auc: 0.9524 - f1_score: 0.8926 - val_loss: 0.8020 - val_accuracy: 0.7519 - val_precision: 0.7519 - val_recall: 0.7519 - val_auc: 0.7658 - val_f1_score: 0.7487 - lr: 1.0000e-05
# Epoch 80/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2854 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9526 - f1_score: 0.8977 - val_loss: 0.8042 - val_accuracy: 0.7632 - val_precision: 0.7632 - val_recall: 0.7632 - val_auc: 0.7737 - val_f1_score: 0.7599 - lr: 1.0000e-05
# Epoch 81/100
# 112/112 [==============================] - 38s 337ms/step - loss: 0.2866 - accuracy: 0.8945 - precision: 0.8945 - recall: 0.8945 - auc: 0.9521 - f1_score: 0.8943 - val_loss: 0.7936 - val_accuracy: 0.7556 - val_precision: 0.7556 - val_recall: 0.7556 - val_auc: 0.7750 - val_f1_score: 0.7513 - lr: 1.0000e-05
# Epoch 82/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.2843 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9533 - f1_score: 0.8961 - val_loss: 0.7451 - val_accuracy: 0.7857 - val_precision: 0.7857 - val_recall: 0.7857 - val_auc: 0.7803 - val_f1_score: 0.7831 - lr: 1.0000e-05
# Epoch 83/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2835 - accuracy: 0.9007 - precision: 0.9007 - recall: 0.9007 - auc: 0.9529 - f1_score: 0.9005 - val_loss: 0.7930 - val_accuracy: 0.7594 - val_precision: 0.7594 - val_recall: 0.7594 - val_auc: 0.7741 - val_f1_score: 0.7563 - lr: 1.0000e-05
# Epoch 84/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2861 - accuracy: 0.9029 - precision: 0.9029 - recall: 0.9029 - auc: 0.9525 - f1_score: 0.9028 - val_loss: 0.7499 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7832 - val_f1_score: 0.7675 - lr: 1.0000e-05
# Epoch 85/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2856 - accuracy: 0.8956 - precision: 0.8956 - recall: 0.8956 - auc: 0.9523 - f1_score: 0.8955 - val_loss: 0.7633 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.7841 - val_f1_score: 0.7715 - lr: 1.0000e-05
# Epoch 86/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.2800 - accuracy: 0.8990 - precision: 0.8990 - recall: 0.8990 - auc: 0.9543 - f1_score: 0.8989 - val_loss: 0.7542 - val_accuracy: 0.7820 - val_precision: 0.7820 - val_recall: 0.7820 - val_auc: 0.7768 - val_f1_score: 0.7783 - lr: 1.0000e-05
# Epoch 87/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2862 - accuracy: 0.9001 - precision: 0.9001 - recall: 0.9001 - auc: 0.9523 - f1_score: 0.9000 - val_loss: 0.7786 - val_accuracy: 0.7594 - val_precision: 0.7594 - val_recall: 0.7594 - val_auc: 0.7620 - val_f1_score: 0.7571 - lr: 1.0000e-05
# Epoch 88/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.2835 - accuracy: 0.8990 - precision: 0.8990 - recall: 0.8990 - auc: 0.9530 - f1_score: 0.8988 - val_loss: 0.7538 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.7858 - val_f1_score: 0.7723 - lr: 1.0000e-05
# Epoch 89/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.2843 - accuracy: 0.8967 - precision: 0.8967 - recall: 0.8967 - auc: 0.9530 - f1_score: 0.8966 - val_loss: 0.7982 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7695 - val_f1_score: 0.7679 - lr: 1.0000e-05
# Epoch 90/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2831 - accuracy: 0.9040 - precision: 0.9040 - recall: 0.9040 - auc: 0.9539 - f1_score: 0.9039 - val_loss: 0.7736 - val_accuracy: 0.7857 - val_precision: 0.7857 - val_recall: 0.7857 - val_auc: 0.7774 - val_f1_score: 0.7828 - lr: 1.0000e-05
# Epoch 91/100
# 112/112 [==============================] - 38s 336ms/step - loss: 0.2848 - accuracy: 0.8917 - precision: 0.8917 - recall: 0.8917 - auc: 0.9526 - f1_score: 0.8915 - val_loss: 0.7882 - val_accuracy: 0.7895 - val_precision: 0.7895 - val_recall: 0.7895 - val_auc: 0.7816 - val_f1_score: 0.7864 - lr: 1.0000e-05
# Epoch 92/100
# 112/112 [==============================] - 37s 333ms/step - loss: 0.2834 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9529 - f1_score: 0.8961 - val_loss: 0.7195 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7862 - val_f1_score: 0.7683 - lr: 1.0000e-05
# Epoch 93/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2849 - accuracy: 0.9046 - precision: 0.9046 - recall: 0.9046 - auc: 0.9526 - f1_score: 0.9045 - val_loss: 0.7703 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7710 - val_f1_score: 0.7650 - lr: 1.0000e-05
# Epoch 94/100
# 112/112 [==============================] - 37s 331ms/step - loss: 0.2827 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9532 - f1_score: 0.8977 - val_loss: 0.7748 - val_accuracy: 0.7782 - val_precision: 0.7782 - val_recall: 0.7782 - val_auc: 0.7821 - val_f1_score: 0.7759 - lr: 1.0000e-05
# Epoch 95/100
# 112/112 [==============================] - 37s 327ms/step - loss: 0.2804 - accuracy: 0.9001 - precision: 0.9001 - recall: 0.9001 - auc: 0.9544 - f1_score: 0.9000 - val_loss: 0.7507 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.7730 - val_f1_score: 0.7729 - lr: 1.0000e-05
# Epoch 96/100
# 112/112 [==============================] - 37s 333ms/step - loss: 0.2847 - accuracy: 0.8951 - precision: 0.8951 - recall: 0.8951 - auc: 0.9527 - f1_score: 0.8949 - val_loss: 0.7638 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7723 - val_f1_score: 0.7639 - lr: 1.0000e-05
# Epoch 97/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2825 - accuracy: 0.8984 - precision: 0.8984 - recall: 0.8984 - auc: 0.9535 - f1_score: 0.8983 - val_loss: 0.7933 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7703 - val_f1_score: 0.7671 - lr: 1.0000e-05
# Epoch 98/100
# 112/112 [==============================] - 37s 330ms/step - loss: 0.2815 - accuracy: 0.9018 - precision: 0.9018 - recall: 0.9018 - auc: 0.9537 - f1_score: 0.9017 - val_loss: 0.8048 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.7674 - val_f1_score: 0.7643 - lr: 1.0000e-05
# Epoch 99/100
# 112/112 [==============================] - 37s 329ms/step - loss: 0.2807 - accuracy: 0.8973 - precision: 0.8973 - recall: 0.8973 - auc: 0.9542 - f1_score: 0.8972 - val_loss: 0.8078 - val_accuracy: 0.7632 - val_precision: 0.7632 - val_recall: 0.7632 - val_auc: 0.7764 - val_f1_score: 0.7610 - lr: 1.0000e-05
# Epoch 100/100
# 112/112 [==============================] - 37s 332ms/step - loss: 0.2804 - accuracy: 0.9012 - precision: 0.9012 - recall: 0.9012 - auc: 0.9541 - f1_score: 0.9012 - val_loss: 0.8079 - val_accuracy: 0.7782 - val_precision: 0.7782 - val_recall: 0.7782 - val_auc: 0.7804 - val_f1_score: 0.7755 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 0s 8ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.8484679665738162
# F1-Score for each class: [0.8        0.89693593]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.875
# specificity: 0.8409090909090909

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 9ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 17/17 [==============================] - 3s 170ms/step - loss: 0.4710 - accuracy: 0.8640 - precision: 0.8640 - recall: 0.8640 - auc: 0.9068 - f1_score: 0.8485
# Test loss: 0.47104746103286743
# Test accuracy: 0.8639705777168274
# Test precision: 0.8639705777168274
# Test recall: 0.8639705777168274
# Test AUC: 0.9068176746368408
# Test F1 Score: 0.8484679460525513

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 9ms/step
#               precision    recall  f1-score   support
#
#            0       0.76      0.84      0.80        88
#            1       0.92      0.88      0.90       184
#
#     accuracy                           0.86       272
#    macro avg       0.84      0.86      0.85       272
# weighted avg       0.87      0.86      0.87       272

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
