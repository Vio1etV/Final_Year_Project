# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/BCResize/40X/test'
train_dir = '/root/BreastCancer/BCResize/40X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/BCResize/40X/train/malignant'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2262 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 298 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %% [markdown]
# <h1>Model Construction<h1>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Concatenate, Flatten, Dense

def inception_block(x, filters):
    conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(x)

    conv3x3 = Conv2D(filters[1], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv3x3)

    conv5x5 = Conv2D(filters[3], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv5x5)

    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    maxpool = Conv2D(filters[5], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(maxpool)

    inception_block = Concatenate(axis=-1)([conv1x1, conv3x3, conv5x5, maxpool])
    return inception_block

def inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer = 'he_normal')(input_tensor)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception blocks
    x = inception_block(x, filters=[64, 128, 128, 32, 96, 32])
    # x = inception_block(x, filters=[128, 128, 96, 64, 64, 64])

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=x)

    return model


# Create the InceptionNet model
model = inception_net(input_shape, num_classes)

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  8320        ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 128)  147584      ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 96)   76896       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 320)  0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 320)  0          ['concatenate[0][0]']
#
#  global_average_pooling2d (Glob  (None, 320)         0           ['max_pooling2d_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            642         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 251,234
# Trainable params: 251,234
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2023-12-23 23:50:33.418540: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-23 23:50:33.981273: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:a1:00.0, compute capability: 8.6

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "InceptionNetResized40X"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/1. InceptionNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-23 23:50:37.692819: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-23 23:50:39.070266: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - 30s 371ms/step - loss: 0.6271 - accuracy: 0.6923 - precision: 0.6923 - recall: 0.6923 - auc: 0.7333 - f1_score: 0.6923 - val_loss: 0.6138 - val_accuracy: 0.6509 - val_precision: 0.6509 - val_recall: 0.6509 - val_auc: 0.7568 - val_f1_score: 0.6509 - lr: 0.0010
# Epoch 2/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.5438 - accuracy: 0.7480 - precision: 0.7480 - recall: 0.7480 - auc: 0.8029 - f1_score: 0.7480 - val_loss: 0.3994 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9155 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 3/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.5146 - accuracy: 0.7644 - precision: 0.7644 - recall: 0.7644 - auc: 0.8268 - f1_score: 0.7644 - val_loss: 0.5038 - val_accuracy: 0.8491 - val_precision: 0.8491 - val_recall: 0.8491 - val_auc: 0.9111 - val_f1_score: 0.8491 - lr: 0.0010
# Epoch 4/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.5215 - accuracy: 0.7670 - precision: 0.7670 - recall: 0.7670 - auc: 0.8206 - f1_score: 0.7670 - val_loss: 0.4123 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9346 - val_f1_score: 0.8846 - lr: 0.0010
# Epoch 5/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.5076 - accuracy: 0.7635 - precision: 0.7635 - recall: 0.7635 - auc: 0.8298 - f1_score: 0.7635 - val_loss: 0.6296 - val_accuracy: 0.6036 - val_precision: 0.6036 - val_recall: 0.6036 - val_auc: 0.7574 - val_f1_score: 0.6036 - lr: 0.0010
# Epoch 6/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.5085 - accuracy: 0.7657 - precision: 0.7657 - recall: 0.7657 - auc: 0.8298 - f1_score: 0.7657 - val_loss: 0.3757 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9343 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 7/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.4966 - accuracy: 0.7790 - precision: 0.7790 - recall: 0.7790 - auc: 0.8397 - f1_score: 0.7790 - val_loss: 0.4459 - val_accuracy: 0.7663 - val_precision: 0.7663 - val_recall: 0.7663 - val_auc: 0.8764 - val_f1_score: 0.7663 - lr: 0.0010
# Epoch 8/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.4816 - accuracy: 0.7741 - precision: 0.7741 - recall: 0.7741 - auc: 0.8511 - f1_score: 0.7741 - val_loss: 0.3913 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9403 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 9/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.5047 - accuracy: 0.7767 - precision: 0.7767 - recall: 0.7767 - auc: 0.8341 - f1_score: 0.7767 - val_loss: 0.4166 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9397 - val_f1_score: 0.8402 - lr: 0.0010
# Epoch 10/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.4948 - accuracy: 0.7816 - precision: 0.7816 - recall: 0.7816 - auc: 0.8423 - f1_score: 0.7816 - val_loss: 0.5779 - val_accuracy: 0.6893 - val_precision: 0.6893 - val_recall: 0.6893 - val_auc: 0.7910 - val_f1_score: 0.6893 - lr: 0.0010
# Epoch 11/100
# 71/71 [==============================] - 26s 369ms/step - loss: 0.5385 - accuracy: 0.7392 - precision: 0.7392 - recall: 0.7392 - auc: 0.8090 - f1_score: 0.7392 - val_loss: 0.7048 - val_accuracy: 0.5059 - val_precision: 0.5059 - val_recall: 0.5059 - val_auc: 0.6942 - val_f1_score: 0.5059 - lr: 0.0010
# Epoch 12/100
# 71/71 [==============================] - 26s 372ms/step - loss: 0.5427 - accuracy: 0.7378 - precision: 0.7378 - recall: 0.7378 - auc: 0.8026 - f1_score: 0.7378 - val_loss: 0.3945 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9264 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 13/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.4947 - accuracy: 0.7785 - precision: 0.7785 - recall: 0.7785 - auc: 0.8413 - f1_score: 0.7785 - val_loss: 0.3596 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9303 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 14/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.5061 - accuracy: 0.7692 - precision: 0.7692 - recall: 0.7692 - auc: 0.8356 - f1_score: 0.7692 - val_loss: 0.4039 - val_accuracy: 0.7959 - val_precision: 0.7959 - val_recall: 0.7959 - val_auc: 0.9203 - val_f1_score: 0.7959 - lr: 0.0010
# Epoch 15/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.4778 - accuracy: 0.7838 - precision: 0.7838 - recall: 0.7838 - auc: 0.8530 - f1_score: 0.7838 - val_loss: 0.3269 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9441 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 16/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.4784 - accuracy: 0.7838 - precision: 0.7838 - recall: 0.7838 - auc: 0.8521 - f1_score: 0.7838 - val_loss: 0.3736 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9533 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 17/100
# 71/71 [==============================] - 25s 358ms/step - loss: 0.4871 - accuracy: 0.7860 - precision: 0.7860 - recall: 0.7860 - auc: 0.8473 - f1_score: 0.7860 - val_loss: 0.3572 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9481 - val_f1_score: 0.9142 - lr: 0.0010
# Epoch 18/100
# 71/71 [==============================] - 25s 359ms/step - loss: 0.4782 - accuracy: 0.7856 - precision: 0.7856 - recall: 0.7856 - auc: 0.8534 - f1_score: 0.7856 - val_loss: 0.3503 - val_accuracy: 0.8491 - val_precision: 0.8491 - val_recall: 0.8491 - val_auc: 0.9413 - val_f1_score: 0.8491 - lr: 0.0010
# Epoch 19/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.4778 - accuracy: 0.7900 - precision: 0.7900 - recall: 0.7900 - auc: 0.8531 - f1_score: 0.7900 - val_loss: 0.4219 - val_accuracy: 0.7840 - val_precision: 0.7840 - val_recall: 0.7840 - val_auc: 0.9093 - val_f1_score: 0.7840 - lr: 0.0010
# Epoch 20/100
# 71/71 [==============================] - 25s 359ms/step - loss: 0.4660 - accuracy: 0.7922 - precision: 0.7922 - recall: 0.7922 - auc: 0.8619 - f1_score: 0.7922 - val_loss: 0.4237 - val_accuracy: 0.7899 - val_precision: 0.7899 - val_recall: 0.7899 - val_auc: 0.9120 - val_f1_score: 0.7899 - lr: 0.0010
# Epoch 21/100
# 71/71 [==============================] - 27s 375ms/step - loss: 0.4906 - accuracy: 0.7763 - precision: 0.7763 - recall: 0.7763 - auc: 0.8455 - f1_score: 0.7763 - val_loss: 0.3501 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9546 - val_f1_score: 0.8994 - lr: 0.0010
# Epoch 22/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.4626 - accuracy: 0.7989 - precision: 0.7989 - recall: 0.7989 - auc: 0.8626 - f1_score: 0.7989 - val_loss: 0.3884 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9559 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 23/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.4530 - accuracy: 0.8015 - precision: 0.8015 - recall: 0.8015 - auc: 0.8706 - f1_score: 0.8015 - val_loss: 0.3337 - val_accuracy: 0.8669 - val_precision: 0.8669 - val_recall: 0.8669 - val_auc: 0.9436 - val_f1_score: 0.8669 - lr: 0.0010
# Epoch 24/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.4602 - accuracy: 0.8033 - precision: 0.8033 - recall: 0.8033 - auc: 0.8620 - f1_score: 0.8033 - val_loss: 0.3956 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.9343 - val_f1_score: 0.8166 - lr: 0.0010
# Epoch 25/100
# 71/71 [==============================] - ETA: 0s - loss: 0.4395 - accuracy: 0.8046 - precision: 0.8046 - recall: 0.8046 - auc: 0.8787 - f1_score: 0.8046
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 71/71 [==============================] - 26s 365ms/step - loss: 0.4395 - accuracy: 0.8046 - precision: 0.8046 - recall: 0.8046 - auc: 0.8787 - f1_score: 0.8046 - val_loss: 0.3880 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9523 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 26/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.4165 - accuracy: 0.8156 - precision: 0.8156 - recall: 0.8156 - auc: 0.8940 - f1_score: 0.8156 - val_loss: 0.3410 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9602 - val_f1_score: 0.8609 - lr: 1.0000e-04
# Epoch 27/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.4079 - accuracy: 0.8156 - precision: 0.8156 - recall: 0.8156 - auc: 0.8993 - f1_score: 0.8156 - val_loss: 0.3274 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9645 - val_f1_score: 0.8757 - lr: 1.0000e-04
# Epoch 28/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.4076 - accuracy: 0.8139 - precision: 0.8139 - recall: 0.8139 - auc: 0.8993 - f1_score: 0.8139 - val_loss: 0.3446 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9538 - val_f1_score: 0.8609 - lr: 1.0000e-04
# Epoch 29/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.4035 - accuracy: 0.8134 - precision: 0.8134 - recall: 0.8134 - auc: 0.9015 - f1_score: 0.8134 - val_loss: 0.4175 - val_accuracy: 0.7870 - val_precision: 0.7870 - val_recall: 0.7870 - val_auc: 0.9214 - val_f1_score: 0.7870 - lr: 1.0000e-04
# Epoch 30/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.4007 - accuracy: 0.8170 - precision: 0.8170 - recall: 0.8170 - auc: 0.9020 - f1_score: 0.8170 - val_loss: 0.3440 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9605 - val_f1_score: 0.8817 - lr: 1.0000e-04
# Epoch 31/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.4002 - accuracy: 0.8156 - precision: 0.8156 - recall: 0.8156 - auc: 0.9033 - f1_score: 0.8156 - val_loss: 0.3814 - val_accuracy: 0.8225 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.9390 - val_f1_score: 0.8225 - lr: 1.0000e-04
# Epoch 32/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3942 - accuracy: 0.8152 - precision: 0.8152 - recall: 0.8152 - auc: 0.9063 - f1_score: 0.8152 - val_loss: 0.3586 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9460 - val_f1_score: 0.8402 - lr: 1.0000e-04
# Epoch 33/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3943 - accuracy: 0.8187 - precision: 0.8187 - recall: 0.8187 - auc: 0.9054 - f1_score: 0.8187 - val_loss: 0.3517 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9650 - val_f1_score: 0.8846 - lr: 1.0000e-04
# Epoch 34/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3953 - accuracy: 0.8161 - precision: 0.8161 - recall: 0.8161 - auc: 0.9063 - f1_score: 0.8161 - val_loss: 0.3186 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9707 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 35/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.3876 - accuracy: 0.8236 - precision: 0.8236 - recall: 0.8236 - auc: 0.9100 - f1_score: 0.8236 - val_loss: 0.2936 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9760 - val_f1_score: 0.9231 - lr: 1.0000e-04
# Epoch 36/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.3905 - accuracy: 0.8187 - precision: 0.8187 - recall: 0.8187 - auc: 0.9088 - f1_score: 0.8187 - val_loss: 0.3962 - val_accuracy: 0.8254 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.9333 - val_f1_score: 0.8254 - lr: 1.0000e-04
# Epoch 37/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3838 - accuracy: 0.8201 - precision: 0.8201 - recall: 0.8201 - auc: 0.9122 - f1_score: 0.8201 - val_loss: 0.2812 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9760 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 38/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3859 - accuracy: 0.8218 - precision: 0.8218 - recall: 0.8218 - auc: 0.9100 - f1_score: 0.8218 - val_loss: 0.3848 - val_accuracy: 0.8077 - val_precision: 0.8077 - val_recall: 0.8077 - val_auc: 0.9318 - val_f1_score: 0.8077 - lr: 1.0000e-04
# Epoch 39/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.3806 - accuracy: 0.8249 - precision: 0.8249 - recall: 0.8249 - auc: 0.9123 - f1_score: 0.8249 - val_loss: 0.3121 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9728 - val_f1_score: 0.8935 - lr: 1.0000e-04
# Epoch 40/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3813 - accuracy: 0.8245 - precision: 0.8245 - recall: 0.8245 - auc: 0.9135 - f1_score: 0.8245 - val_loss: 0.3287 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9670 - val_f1_score: 0.8935 - lr: 1.0000e-04
# Epoch 41/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.3714 - accuracy: 0.8311 - precision: 0.8311 - recall: 0.8311 - auc: 0.9173 - f1_score: 0.8311 - val_loss: 0.3380 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9780 - val_f1_score: 0.9112 - lr: 1.0000e-04
# Epoch 42/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3775 - accuracy: 0.8267 - precision: 0.8267 - recall: 0.8267 - auc: 0.9148 - f1_score: 0.8267 - val_loss: 0.3603 - val_accuracy: 0.8432 - val_precision: 0.8432 - val_recall: 0.8432 - val_auc: 0.9516 - val_f1_score: 0.8432 - lr: 1.0000e-04
# Epoch 43/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3686 - accuracy: 0.8276 - precision: 0.8276 - recall: 0.8276 - auc: 0.9193 - f1_score: 0.8276 - val_loss: 0.2951 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9773 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 44/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3738 - accuracy: 0.8240 - precision: 0.8240 - recall: 0.8240 - auc: 0.9175 - f1_score: 0.8240 - val_loss: 0.2947 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9823 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 45/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3670 - accuracy: 0.8333 - precision: 0.8333 - recall: 0.8333 - auc: 0.9196 - f1_score: 0.8333 - val_loss: 0.3190 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9764 - val_f1_score: 0.9083 - lr: 1.0000e-04
# Epoch 46/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.3644 - accuracy: 0.8289 - precision: 0.8289 - recall: 0.8289 - auc: 0.9217 - f1_score: 0.8289 - val_loss: 0.3739 - val_accuracy: 0.8225 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.9415 - val_f1_score: 0.8225 - lr: 1.0000e-04
# Epoch 47/100
# 71/71 [==============================] - ETA: 0s - loss: 0.3656 - accuracy: 0.8386 - precision: 0.8386 - recall: 0.8386 - auc: 0.9208 - f1_score: 0.8386
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 71/71 [==============================] - 26s 361ms/step - loss: 0.3656 - accuracy: 0.8386 - precision: 0.8386 - recall: 0.8386 - auc: 0.9208 - f1_score: 0.8386 - val_loss: 0.3344 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9649 - val_f1_score: 0.8817 - lr: 1.0000e-04
# Epoch 48/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.3536 - accuracy: 0.8355 - precision: 0.8355 - recall: 0.8355 - auc: 0.9269 - f1_score: 0.8355 - val_loss: 0.3118 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9764 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 49/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3540 - accuracy: 0.8391 - precision: 0.8391 - recall: 0.8391 - auc: 0.9270 - f1_score: 0.8391 - val_loss: 0.3032 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9797 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 50/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3532 - accuracy: 0.8413 - precision: 0.8413 - recall: 0.8413 - auc: 0.9267 - f1_score: 0.8413 - val_loss: 0.3208 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9756 - val_f1_score: 0.9112 - lr: 1.0000e-05
# Epoch 51/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3512 - accuracy: 0.8382 - precision: 0.8382 - recall: 0.8382 - auc: 0.9282 - f1_score: 0.8382 - val_loss: 0.3115 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9785 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 52/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3568 - accuracy: 0.8391 - precision: 0.8391 - recall: 0.8391 - auc: 0.9262 - f1_score: 0.8391 - val_loss: 0.3219 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9718 - val_f1_score: 0.8905 - lr: 1.0000e-05
# Epoch 53/100
# 71/71 [==============================] - 26s 370ms/step - loss: 0.3527 - accuracy: 0.8400 - precision: 0.8400 - recall: 0.8400 - auc: 0.9271 - f1_score: 0.8400 - val_loss: 0.3159 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9765 - val_f1_score: 0.9112 - lr: 1.0000e-05
# Epoch 54/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3540 - accuracy: 0.8395 - precision: 0.8395 - recall: 0.8395 - auc: 0.9274 - f1_score: 0.8395 - val_loss: 0.3226 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9703 - val_f1_score: 0.8994 - lr: 1.0000e-05
# Epoch 55/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3512 - accuracy: 0.8391 - precision: 0.8391 - recall: 0.8391 - auc: 0.9278 - f1_score: 0.8391 - val_loss: 0.3182 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9726 - val_f1_score: 0.8935 - lr: 1.0000e-05
# Epoch 56/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3521 - accuracy: 0.8408 - precision: 0.8408 - recall: 0.8408 - auc: 0.9280 - f1_score: 0.8408 - val_loss: 0.3136 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9764 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 57/100
# 71/71 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8444 - precision: 0.8444 - recall: 0.8444 - auc: 0.9279 - f1_score: 0.8444
# Epoch 57: ReduceLROnPlateau reducing learning rate to 1e-05.
# 71/71 [==============================] - 26s 368ms/step - loss: 0.3499 - accuracy: 0.8444 - precision: 0.8444 - recall: 0.8444 - auc: 0.9279 - f1_score: 0.8444 - val_loss: 0.3225 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9715 - val_f1_score: 0.8905 - lr: 1.0000e-05
# Epoch 58/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3538 - accuracy: 0.8378 - precision: 0.8378 - recall: 0.8378 - auc: 0.9261 - f1_score: 0.8378 - val_loss: 0.3227 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9727 - val_f1_score: 0.9024 - lr: 1.0000e-05
# Epoch 59/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3518 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9286 - f1_score: 0.8462 - val_loss: 0.3212 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9769 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 60/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3504 - accuracy: 0.8395 - precision: 0.8395 - recall: 0.8395 - auc: 0.9295 - f1_score: 0.8395 - val_loss: 0.3191 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9721 - val_f1_score: 0.8994 - lr: 1.0000e-05
# Epoch 61/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3489 - accuracy: 0.8400 - precision: 0.8400 - recall: 0.8400 - auc: 0.9288 - f1_score: 0.8400 - val_loss: 0.3227 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9724 - val_f1_score: 0.8905 - lr: 1.0000e-05
# Epoch 62/100
# 71/71 [==============================] - 27s 375ms/step - loss: 0.3497 - accuracy: 0.8448 - precision: 0.8448 - recall: 0.8448 - auc: 0.9291 - f1_score: 0.8448 - val_loss: 0.3234 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9747 - val_f1_score: 0.9053 - lr: 1.0000e-05
# Epoch 63/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3484 - accuracy: 0.8439 - precision: 0.8439 - recall: 0.8439 - auc: 0.9301 - f1_score: 0.8439 - val_loss: 0.3159 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9751 - val_f1_score: 0.9172 - lr: 1.0000e-05
# Epoch 64/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3489 - accuracy: 0.8448 - precision: 0.8448 - recall: 0.8448 - auc: 0.9294 - f1_score: 0.8448 - val_loss: 0.3156 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9753 - val_f1_score: 0.8994 - lr: 1.0000e-05
# Epoch 65/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3491 - accuracy: 0.8435 - precision: 0.8435 - recall: 0.8435 - auc: 0.9284 - f1_score: 0.8435 - val_loss: 0.3356 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9630 - val_f1_score: 0.8905 - lr: 1.0000e-05
# Epoch 66/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3501 - accuracy: 0.8422 - precision: 0.8422 - recall: 0.8422 - auc: 0.9288 - f1_score: 0.8422 - val_loss: 0.3171 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9771 - val_f1_score: 0.9053 - lr: 1.0000e-05
# Epoch 67/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3495 - accuracy: 0.8439 - precision: 0.8439 - recall: 0.8439 - auc: 0.9286 - f1_score: 0.8439 - val_loss: 0.3123 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9768 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 68/100
# 71/71 [==============================] - 26s 369ms/step - loss: 0.3479 - accuracy: 0.8413 - precision: 0.8413 - recall: 0.8413 - auc: 0.9291 - f1_score: 0.8413 - val_loss: 0.3120 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9773 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 69/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3512 - accuracy: 0.8435 - precision: 0.8435 - recall: 0.8435 - auc: 0.9289 - f1_score: 0.8435 - val_loss: 0.3202 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9738 - val_f1_score: 0.9053 - lr: 1.0000e-05
# Epoch 70/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3477 - accuracy: 0.8444 - precision: 0.8444 - recall: 0.8444 - auc: 0.9292 - f1_score: 0.8444 - val_loss: 0.3199 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9750 - val_f1_score: 0.9172 - lr: 1.0000e-05
# Epoch 71/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3490 - accuracy: 0.8457 - precision: 0.8457 - recall: 0.8457 - auc: 0.9308 - f1_score: 0.8457 - val_loss: 0.3050 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9799 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 72/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.3477 - accuracy: 0.8497 - precision: 0.8497 - recall: 0.8497 - auc: 0.9293 - f1_score: 0.8497 - val_loss: 0.3107 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9799 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 73/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3475 - accuracy: 0.8426 - precision: 0.8426 - recall: 0.8426 - auc: 0.9296 - f1_score: 0.8426 - val_loss: 0.3180 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9765 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 74/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3470 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9307 - f1_score: 0.8462 - val_loss: 0.3166 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9745 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 75/100
# 71/71 [==============================] - 26s 372ms/step - loss: 0.3449 - accuracy: 0.8475 - precision: 0.8475 - recall: 0.8475 - auc: 0.9310 - f1_score: 0.8475 - val_loss: 0.3267 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9722 - val_f1_score: 0.8935 - lr: 1.0000e-05
# Epoch 76/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3446 - accuracy: 0.8453 - precision: 0.8453 - recall: 0.8453 - auc: 0.9309 - f1_score: 0.8453 - val_loss: 0.3183 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9765 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 77/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3459 - accuracy: 0.8479 - precision: 0.8479 - recall: 0.8479 - auc: 0.9307 - f1_score: 0.8479 - val_loss: 0.3174 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9716 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 78/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.3444 - accuracy: 0.8466 - precision: 0.8466 - recall: 0.8466 - auc: 0.9309 - f1_score: 0.8466 - val_loss: 0.3408 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9593 - val_f1_score: 0.8846 - lr: 1.0000e-05
# Epoch 79/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3481 - accuracy: 0.8439 - precision: 0.8439 - recall: 0.8439 - auc: 0.9295 - f1_score: 0.8439 - val_loss: 0.3220 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9734 - val_f1_score: 0.8994 - lr: 1.0000e-05
# Epoch 80/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3472 - accuracy: 0.8426 - precision: 0.8426 - recall: 0.8426 - auc: 0.9299 - f1_score: 0.8426 - val_loss: 0.3132 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9758 - val_f1_score: 0.9112 - lr: 1.0000e-05
# Epoch 81/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3420 - accuracy: 0.8523 - precision: 0.8523 - recall: 0.8523 - auc: 0.9324 - f1_score: 0.8523 - val_loss: 0.3175 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9730 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 82/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3445 - accuracy: 0.8466 - precision: 0.8466 - recall: 0.8466 - auc: 0.9310 - f1_score: 0.8466 - val_loss: 0.3160 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9767 - val_f1_score: 0.9053 - lr: 1.0000e-05
# Epoch 83/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.3428 - accuracy: 0.8453 - precision: 0.8453 - recall: 0.8453 - auc: 0.9320 - f1_score: 0.8453 - val_loss: 0.3127 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9764 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 84/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3426 - accuracy: 0.8501 - precision: 0.8501 - recall: 0.8501 - auc: 0.9322 - f1_score: 0.8501 - val_loss: 0.3270 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9686 - val_f1_score: 0.8935 - lr: 1.0000e-05
# Epoch 85/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3451 - accuracy: 0.8448 - precision: 0.8448 - recall: 0.8448 - auc: 0.9310 - f1_score: 0.8448 - val_loss: 0.3057 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9792 - val_f1_score: 0.9172 - lr: 1.0000e-05
# Epoch 86/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.3440 - accuracy: 0.8470 - precision: 0.8470 - recall: 0.8470 - auc: 0.9307 - f1_score: 0.8470 - val_loss: 0.3034 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9801 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 87/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3440 - accuracy: 0.8528 - precision: 0.8528 - recall: 0.8528 - auc: 0.9311 - f1_score: 0.8528 - val_loss: 0.3141 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9775 - val_f1_score: 0.9112 - lr: 1.0000e-05
# Epoch 88/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.3443 - accuracy: 0.8488 - precision: 0.8488 - recall: 0.8488 - auc: 0.9310 - f1_score: 0.8488 - val_loss: 0.3118 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9735 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 89/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3447 - accuracy: 0.8466 - precision: 0.8466 - recall: 0.8466 - auc: 0.9311 - f1_score: 0.8466 - val_loss: 0.3021 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9818 - val_f1_score: 0.9231 - lr: 1.0000e-05
# Epoch 90/100
# 71/71 [==============================] - 25s 357ms/step - loss: 0.3444 - accuracy: 0.8479 - precision: 0.8479 - recall: 0.8479 - auc: 0.9310 - f1_score: 0.8479 - val_loss: 0.3232 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9727 - val_f1_score: 0.8994 - lr: 1.0000e-05
# Epoch 91/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.3416 - accuracy: 0.8488 - precision: 0.8488 - recall: 0.8488 - auc: 0.9321 - f1_score: 0.8488 - val_loss: 0.3172 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9746 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 92/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3422 - accuracy: 0.8466 - precision: 0.8466 - recall: 0.8466 - auc: 0.9318 - f1_score: 0.8466 - val_loss: 0.3244 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9736 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 93/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3404 - accuracy: 0.8515 - precision: 0.8515 - recall: 0.8515 - auc: 0.9328 - f1_score: 0.8515 - val_loss: 0.3225 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9731 - val_f1_score: 0.8905 - lr: 1.0000e-05
# Epoch 94/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3406 - accuracy: 0.8510 - precision: 0.8510 - recall: 0.8510 - auc: 0.9334 - f1_score: 0.8510 - val_loss: 0.3112 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9764 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 95/100
# 71/71 [==============================] - 25s 358ms/step - loss: 0.3449 - accuracy: 0.8413 - precision: 0.8413 - recall: 0.8413 - auc: 0.9303 - f1_score: 0.8413 - val_loss: 0.3026 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9818 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 96/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3422 - accuracy: 0.8466 - precision: 0.8466 - recall: 0.8466 - auc: 0.9320 - f1_score: 0.8466 - val_loss: 0.3300 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9680 - val_f1_score: 0.8846 - lr: 1.0000e-05
# Epoch 97/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3429 - accuracy: 0.8417 - precision: 0.8417 - recall: 0.8417 - auc: 0.9315 - f1_score: 0.8417 - val_loss: 0.3112 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9800 - val_f1_score: 0.9231 - lr: 1.0000e-05
# Epoch 98/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3402 - accuracy: 0.8528 - precision: 0.8528 - recall: 0.8528 - auc: 0.9336 - f1_score: 0.8528 - val_loss: 0.3151 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9760 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 99/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3454 - accuracy: 0.8435 - precision: 0.8435 - recall: 0.8435 - auc: 0.9297 - f1_score: 0.8435 - val_loss: 0.3280 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9660 - val_f1_score: 0.8994 - lr: 1.0000e-05
# Epoch 100/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3381 - accuracy: 0.8528 - precision: 0.8528 - recall: 0.8528 - auc: 0.9346 - f1_score: 0.8528 - val_loss: 0.3299 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9670 - val_f1_score: 0.8964 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 0s 9ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.8507772020725388
# F1-Score for each class: [0.8       0.9015544]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.883248730964467
# specificity: 0.8351648351648352

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 9ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 1s 77ms/step - loss: 0.3445 - accuracy: 0.8725 - precision: 0.8725 - recall: 0.8725 - auc: 0.9355 - f1_score: 0.8725
# Test loss: 0.3445320725440979
# Test accuracy: 0.8724831938743591
# Test precision: 0.8724831938743591
# Test recall: 0.8724831938743591
# Test AUC: 0.9355265498161316
# Test F1 Score: 0.8724832534790039

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 9ms/step
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80        91
#            1       0.92      0.88      0.90       197
#
#     accuracy                           0.87       288
#    macro avg       0.84      0.86      0.85       288
# weighted avg       0.87      0.87      0.87       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
