# %%
from tensorflow.keras.applications import ResNet50V2
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.regularizers import l2

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.
# Out:
# 2024-03-24 15:01:52.838770: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2264 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 304 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=input_shape)
# Out:
# 2024-03-24 15:01:57.762639: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-24 15:01:58.568526: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22134 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:99:00.0, compute capability: 8.9
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 95s 1us/step

# %%
# 冻结基础模型的所有层，这样它们在训练过程中不会被更新
for layer in base_model.layers:
    layer.trainable = False

# %%
# 添加自定义层
x = base_model.output
x = GlobalAveragePooling2D()(x)  # 添加全局平均池化层
x = Dense(512, activation='relu')(x)  # 添加一个全连接层
# 根据您的任务添加最后一层，这里是二分类任务
predictions = Dense(num_classes, activation='softmax')(x)

# %%
model = Model(inputs=base_model.input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block3_out[0][0]']
#
#  conv3_block4_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block4_2_pad[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_out (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_conv[0][0]']
#
#  conv4_block5_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block4_out[0][0]']
#  ormalization)                  )
#
#  conv4_block5_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block5_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block5_1_relu[0][0]']
#  g2D)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block5_2_pad[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_out (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_conv[0][0]']
#
#  conv4_block6_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block5_out[0][0]']
#  ormalization)                  )
#
#  conv4_block6_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block6_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block6_1_relu[0][0]']
#  g2D)
#
#  conv4_block6_2_conv (Conv2D)   (None, 7, 7, 256)    589824      ['conv4_block6_2_pad[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 7, 7, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 7, 7, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block5_out[0][0]']
#
#  conv4_block6_3_conv (Conv2D)   (None, 7, 7, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_out (Add)         (None, 7, 7, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block6_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block6_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['post_relu[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 512)          1049088     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  dense_1 (Dense)                (None, 2)            1026        ['dense[0][0]']
#
# ==================================================================================================
# Total params: 24,614,914
# Trainable params: 1,050,114
# Non-trainable params: 23,564,800
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(),
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "ResNet50V2"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)


lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', 
                                 factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# f1_score_callback = F1ScoreCallback(train_generator = train_generator, 
#                                     validation_generator=validation_generator, 
#                                     num_classes=num_classes)


from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = model.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)


# history = DIR.fit(
#     train_generator,
#     epochs=150,
#     validation_data=validation_generator,
#     callbacks=[csv_logger, lr_reduction, model_checkpoint_callback, f1_score_callback]
# )
# Out:
# Epoch 1/150
# 2024-03-24 15:06:59.405847: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-24 15:07:00.652152: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-03-24 15:07:00.652194: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2024-03-24 15:07:00.652324: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
#  1/71 [..............................] - ETA: 8:21 - loss: 0.6580 - accuracy: 0.5938 - precision: 0.5938 - recall: 0.5938 - auc: 0.6592 - f1_score: 0.5938
# 2024-03-24 15:07:01.746896: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 0.5302 - accuracy: 0.7681 - precision: 0.7681 - recall: 0.7681 - auc: 0.8331 - f1_score: 0.7681
# Epoch 1: val_loss improved from inf to 0.48515, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 46s 551ms/step - loss: 0.5302 - accuracy: 0.7681 - precision: 0.7681 - recall: 0.7681 - auc: 0.8331 - f1_score: 0.7681 - val_loss: 0.4851 - val_accuracy: 0.7692 - val_precision: 0.7692 - val_recall: 0.7692 - val_auc: 0.8482 - val_f1_score: 0.7692 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3465 - accuracy: 0.8458 - precision: 0.8458 - recall: 0.8458 - auc: 0.9264 - f1_score: 0.8458
# Epoch 2: val_loss improved from 0.48515 to 0.38190, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 32s 445ms/step - loss: 0.3465 - accuracy: 0.8458 - precision: 0.8458 - recall: 0.8458 - auc: 0.9264 - f1_score: 0.8458 - val_loss: 0.3819 - val_accuracy: 0.7988 - val_precision: 0.7988 - val_recall: 0.7988 - val_auc: 0.9063 - val_f1_score: 0.7988 - lr: 0.0010
# Epoch 3/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2803 - accuracy: 0.8807 - precision: 0.8807 - recall: 0.8807 - auc: 0.9522 - f1_score: 0.8807
# Epoch 3: val_loss improved from 0.38190 to 0.27892, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 30s 414ms/step - loss: 0.2803 - accuracy: 0.8807 - precision: 0.8807 - recall: 0.8807 - auc: 0.9522 - f1_score: 0.8807 - val_loss: 0.2789 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9551 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 4/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2423 - accuracy: 0.8984 - precision: 0.8984 - recall: 0.8984 - auc: 0.9643 - f1_score: 0.8984
# Epoch 4: val_loss improved from 0.27892 to 0.21472, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 31s 441ms/step - loss: 0.2423 - accuracy: 0.8984 - precision: 0.8984 - recall: 0.8984 - auc: 0.9643 - f1_score: 0.8984 - val_loss: 0.2147 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9773 - val_f1_score: 0.9142 - lr: 0.0010
# Epoch 5/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2206 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9710 - f1_score: 0.9134
# Epoch 5: val_loss did not improve from 0.21472
# 71/71 [==============================] - 33s 462ms/step - loss: 0.2206 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9710 - f1_score: 0.9134 - val_loss: 0.2418 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9645 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 6/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2189 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9707 - f1_score: 0.9134
# Epoch 6: val_loss improved from 0.21472 to 0.19662, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 33s 464ms/step - loss: 0.2189 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9707 - f1_score: 0.9134 - val_loss: 0.1966 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9768 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 7/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1690 - accuracy: 0.9364 - precision: 0.9364 - recall: 0.9364 - auc: 0.9827 - f1_score: 0.9364
# Epoch 7: val_loss did not improve from 0.19662
# 71/71 [==============================] - 35s 498ms/step - loss: 0.1690 - accuracy: 0.9364 - precision: 0.9364 - recall: 0.9364 - auc: 0.9827 - f1_score: 0.9364 - val_loss: 0.2673 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9564 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 8/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1743 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9817 - f1_score: 0.9346
# Epoch 8: val_loss improved from 0.19662 to 0.11323, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 35s 493ms/step - loss: 0.1743 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9817 - f1_score: 0.9346 - val_loss: 0.1132 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9949 - val_f1_score: 0.9586 - lr: 0.0010
# Epoch 9/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1536 - accuracy: 0.9404 - precision: 0.9404 - recall: 0.9404 - auc: 0.9856 - f1_score: 0.9404
# Epoch 9: val_loss did not improve from 0.11323
# 71/71 [==============================] - 32s 447ms/step - loss: 0.1536 - accuracy: 0.9404 - precision: 0.9404 - recall: 0.9404 - auc: 0.9856 - f1_score: 0.9404 - val_loss: 0.1337 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9895 - val_f1_score: 0.9527 - lr: 0.0010
# Epoch 10/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9867 - f1_score: 0.9421
# Epoch 10: val_loss did not improve from 0.11323
# 71/71 [==============================] - 36s 503ms/step - loss: 0.1484 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9867 - f1_score: 0.9421 - val_loss: 0.1560 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9848 - val_f1_score: 0.9379 - lr: 0.0010
# Epoch 11/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9519 - precision: 0.9519 - recall: 0.9519 - auc: 0.9907 - f1_score: 0.9519
# Epoch 11: val_loss did not improve from 0.11323
# 71/71 [==============================] - 37s 519ms/step - loss: 0.1255 - accuracy: 0.9519 - precision: 0.9519 - recall: 0.9519 - auc: 0.9907 - f1_score: 0.9519 - val_loss: 0.1686 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9827 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 12/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.9523 - precision: 0.9523 - recall: 0.9523 - auc: 0.9903 - f1_score: 0.9523
# Epoch 12: val_loss did not improve from 0.11323
# 71/71 [==============================] - 38s 541ms/step - loss: 0.1217 - accuracy: 0.9523 - precision: 0.9523 - recall: 0.9523 - auc: 0.9903 - f1_score: 0.9523 - val_loss: 0.1817 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9781 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 13/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9536 - precision: 0.9536 - recall: 0.9536 - auc: 0.9912 - f1_score: 0.9536
# Epoch 13: val_loss did not improve from 0.11323
# 71/71 [==============================] - 32s 449ms/step - loss: 0.1198 - accuracy: 0.9536 - precision: 0.9536 - recall: 0.9536 - auc: 0.9912 - f1_score: 0.9536 - val_loss: 0.1199 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9918 - val_f1_score: 0.9497 - lr: 0.0010
# Epoch 14/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1278 - accuracy: 0.9545 - precision: 0.9545 - recall: 0.9545 - auc: 0.9897 - f1_score: 0.9545
# Epoch 14: val_loss did not improve from 0.11323
# 71/71 [==============================] - 32s 454ms/step - loss: 0.1278 - accuracy: 0.9545 - precision: 0.9545 - recall: 0.9545 - auc: 0.9897 - f1_score: 0.9545 - val_loss: 0.1998 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9758 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 15/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1221 - accuracy: 0.9532 - precision: 0.9532 - recall: 0.9532 - auc: 0.9906 - f1_score: 0.9532
# Epoch 15: val_loss did not improve from 0.11323
# 71/71 [==============================] - 33s 467ms/step - loss: 0.1221 - accuracy: 0.9532 - precision: 0.9532 - recall: 0.9532 - auc: 0.9906 - f1_score: 0.9532 - val_loss: 0.1215 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9916 - val_f1_score: 0.9527 - lr: 0.0010
# Epoch 16/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.9541 - precision: 0.9541 - recall: 0.9541 - auc: 0.9912 - f1_score: 0.9541
# Epoch 16: val_loss did not improve from 0.11323
# 71/71 [==============================] - 32s 456ms/step - loss: 0.1199 - accuracy: 0.9541 - precision: 0.9541 - recall: 0.9541 - auc: 0.9912 - f1_score: 0.9541 - val_loss: 0.2125 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9730 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 17/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9678 - precision: 0.9678 - recall: 0.9678 - auc: 0.9936 - f1_score: 0.9678
# Epoch 17: val_loss improved from 0.11323 to 0.10466, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 33s 460ms/step - loss: 0.0991 - accuracy: 0.9678 - precision: 0.9678 - recall: 0.9678 - auc: 0.9936 - f1_score: 0.9678 - val_loss: 0.1047 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9942 - val_f1_score: 0.9586 - lr: 0.0010
# Epoch 18/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.9669 - precision: 0.9669 - recall: 0.9669 - auc: 0.9946 - f1_score: 0.9669
# Epoch 18: val_loss did not improve from 0.10466
# 71/71 [==============================] - 34s 485ms/step - loss: 0.0941 - accuracy: 0.9669 - precision: 0.9669 - recall: 0.9669 - auc: 0.9946 - f1_score: 0.9669 - val_loss: 0.1204 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9916 - val_f1_score: 0.9408 - lr: 0.0010
# Epoch 19/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1119 - accuracy: 0.9580 - precision: 0.9580 - recall: 0.9580 - auc: 0.9921 - f1_score: 0.9580
# Epoch 19: val_loss improved from 0.10466 to 0.09032, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 29s 404ms/step - loss: 0.1119 - accuracy: 0.9580 - precision: 0.9580 - recall: 0.9580 - auc: 0.9921 - f1_score: 0.9580 - val_loss: 0.0903 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9949 - val_f1_score: 0.9734 - lr: 0.0010
# Epoch 20/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0967 - accuracy: 0.9616 - precision: 0.9616 - recall: 0.9616 - auc: 0.9941 - f1_score: 0.9616
# Epoch 20: val_loss did not improve from 0.09032
# 71/71 [==============================] - 29s 400ms/step - loss: 0.0967 - accuracy: 0.9616 - precision: 0.9616 - recall: 0.9616 - auc: 0.9941 - f1_score: 0.9616 - val_loss: 0.1603 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9850 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 21/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0959 - accuracy: 0.9655 - precision: 0.9655 - recall: 0.9655 - auc: 0.9940 - f1_score: 0.9655
# Epoch 21: val_loss improved from 0.09032 to 0.08322, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 33s 463ms/step - loss: 0.0959 - accuracy: 0.9655 - precision: 0.9655 - recall: 0.9655 - auc: 0.9940 - f1_score: 0.9655 - val_loss: 0.0832 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9969 - val_f1_score: 0.9675 - lr: 0.0010
# Epoch 22/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9633 - precision: 0.9633 - recall: 0.9633 - auc: 0.9937 - f1_score: 0.9633
# Epoch 22: val_loss did not improve from 0.08322
# 71/71 [==============================] - 35s 498ms/step - loss: 0.0985 - accuracy: 0.9633 - precision: 0.9633 - recall: 0.9633 - auc: 0.9937 - f1_score: 0.9633 - val_loss: 0.1090 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9932 - val_f1_score: 0.9497 - lr: 0.0010
# Epoch 23/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9589 - precision: 0.9589 - recall: 0.9589 - auc: 0.9940 - f1_score: 0.9589
# Epoch 23: val_loss improved from 0.08322 to 0.08287, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 36s 505ms/step - loss: 0.0993 - accuracy: 0.9589 - precision: 0.9589 - recall: 0.9589 - auc: 0.9940 - f1_score: 0.9589 - val_loss: 0.0829 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9956 - val_f1_score: 0.9734 - lr: 0.0010
# Epoch 24/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1098 - accuracy: 0.9607 - precision: 0.9607 - recall: 0.9607 - auc: 0.9921 - f1_score: 0.9607
# Epoch 24: val_loss improved from 0.08287 to 0.07018, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 35s 486ms/step - loss: 0.1098 - accuracy: 0.9607 - precision: 0.9607 - recall: 0.9607 - auc: 0.9921 - f1_score: 0.9607 - val_loss: 0.0702 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9969 - val_f1_score: 0.9763 - lr: 0.0010
# Epoch 25/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0775 - accuracy: 0.9722 - precision: 0.9722 - recall: 0.9722 - auc: 0.9961 - f1_score: 0.9722
# Epoch 25: val_loss did not improve from 0.07018
# 71/71 [==============================] - 31s 442ms/step - loss: 0.0775 - accuracy: 0.9722 - precision: 0.9722 - recall: 0.9722 - auc: 0.9961 - f1_score: 0.9722 - val_loss: 0.1369 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9889 - val_f1_score: 0.9408 - lr: 0.0010
# Epoch 26/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0743 - accuracy: 0.9717 - precision: 0.9717 - recall: 0.9717 - auc: 0.9967 - f1_score: 0.9717
# Epoch 26: val_loss did not improve from 0.07018
# 71/71 [==============================] - 30s 419ms/step - loss: 0.0743 - accuracy: 0.9717 - precision: 0.9717 - recall: 0.9717 - auc: 0.9967 - f1_score: 0.9717 - val_loss: 0.0714 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9962 - val_f1_score: 0.9793 - lr: 0.0010
# Epoch 27/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9611 - precision: 0.9611 - recall: 0.9611 - auc: 0.9951 - f1_score: 0.9611
# Epoch 27: val_loss did not improve from 0.07018
# 71/71 [==============================] - 30s 424ms/step - loss: 0.0909 - accuracy: 0.9611 - precision: 0.9611 - recall: 0.9611 - auc: 0.9951 - f1_score: 0.9611 - val_loss: 0.0920 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9948 - val_f1_score: 0.9734 - lr: 0.0010
# Epoch 28/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9713 - precision: 0.9713 - recall: 0.9713 - auc: 0.9944 - f1_score: 0.9713
# Epoch 28: val_loss did not improve from 0.07018
# 71/71 [==============================] - 28s 387ms/step - loss: 0.0900 - accuracy: 0.9713 - precision: 0.9713 - recall: 0.9713 - auc: 0.9944 - f1_score: 0.9713 - val_loss: 0.1816 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9805 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 29/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0717 - accuracy: 0.9713 - precision: 0.9713 - recall: 0.9713 - auc: 0.9966 - f1_score: 0.9713
# Epoch 29: val_loss did not improve from 0.07018
# 71/71 [==============================] - 30s 423ms/step - loss: 0.0717 - accuracy: 0.9713 - precision: 0.9713 - recall: 0.9713 - auc: 0.9966 - f1_score: 0.9713 - val_loss: 0.0893 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9958 - val_f1_score: 0.9586 - lr: 0.0010
# Epoch 30/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9962 - f1_score: 0.9704
# Epoch 30: val_loss did not improve from 0.07018
# 71/71 [==============================] - 32s 444ms/step - loss: 0.0756 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9962 - f1_score: 0.9704 - val_loss: 0.1313 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9895 - val_f1_score: 0.9497 - lr: 0.0010
# Epoch 31/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0782 - accuracy: 0.9686 - precision: 0.9686 - recall: 0.9686 - auc: 0.9964 - f1_score: 0.9686
# Epoch 31: val_loss did not improve from 0.07018
# 71/71 [==============================] - 30s 417ms/step - loss: 0.0782 - accuracy: 0.9686 - precision: 0.9686 - recall: 0.9686 - auc: 0.9964 - f1_score: 0.9686 - val_loss: 0.1155 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9922 - val_f1_score: 0.9675 - lr: 0.0010
# Epoch 32/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0563 - accuracy: 0.9797 - precision: 0.9797 - recall: 0.9797 - auc: 0.9979 - f1_score: 0.9797
# Epoch 32: val_loss improved from 0.07018 to 0.04316, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 31s 441ms/step - loss: 0.0563 - accuracy: 0.9797 - precision: 0.9797 - recall: 0.9797 - auc: 0.9979 - f1_score: 0.9797 - val_loss: 0.0432 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9995 - val_f1_score: 0.9822 - lr: 0.0010
# Epoch 33/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0712 - accuracy: 0.9744 - precision: 0.9744 - recall: 0.9744 - auc: 0.9968 - f1_score: 0.9744
# Epoch 33: val_loss did not improve from 0.04316
# 71/71 [==============================] - 29s 412ms/step - loss: 0.0712 - accuracy: 0.9744 - precision: 0.9744 - recall: 0.9744 - auc: 0.9968 - f1_score: 0.9744 - val_loss: 0.0594 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9980 - val_f1_score: 0.9793 - lr: 0.0010
# Epoch 34/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0593 - accuracy: 0.9806 - precision: 0.9806 - recall: 0.9806 - auc: 0.9971 - f1_score: 0.9806
# Epoch 34: val_loss did not improve from 0.04316
# 71/71 [==============================] - 29s 405ms/step - loss: 0.0593 - accuracy: 0.9806 - precision: 0.9806 - recall: 0.9806 - auc: 0.9971 - f1_score: 0.9806 - val_loss: 0.0691 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9971 - val_f1_score: 0.9615 - lr: 0.0010
# Epoch 35/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0573 - accuracy: 0.9828 - precision: 0.9828 - recall: 0.9828 - auc: 0.9980 - f1_score: 0.9828
# Epoch 35: val_loss did not improve from 0.04316
# 71/71 [==============================] - 29s 414ms/step - loss: 0.0573 - accuracy: 0.9828 - precision: 0.9828 - recall: 0.9828 - auc: 0.9980 - f1_score: 0.9828 - val_loss: 0.0635 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9970 - val_f1_score: 0.9822 - lr: 0.0010
# Epoch 36/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0656 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9970 - f1_score: 0.9775
# Epoch 36: val_loss did not improve from 0.04316
# 71/71 [==============================] - 32s 450ms/step - loss: 0.0656 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9970 - f1_score: 0.9775 - val_loss: 0.0568 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9983 - val_f1_score: 0.9704 - lr: 0.0010
# Epoch 37/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0600 - accuracy: 0.9748 - precision: 0.9748 - recall: 0.9748 - auc: 0.9979 - f1_score: 0.9748
# Epoch 37: val_loss did not improve from 0.04316
# 71/71 [==============================] - 31s 442ms/step - loss: 0.0600 - accuracy: 0.9748 - precision: 0.9748 - recall: 0.9748 - auc: 0.9979 - f1_score: 0.9748 - val_loss: 0.0806 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9963 - val_f1_score: 0.9645 - lr: 0.0010
# Epoch 38/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0502 - accuracy: 0.9850 - precision: 0.9850 - recall: 0.9850 - auc: 0.9981 - f1_score: 0.9850
# Epoch 38: val_loss did not improve from 0.04316
# 71/71 [==============================] - 31s 432ms/step - loss: 0.0502 - accuracy: 0.9850 - precision: 0.9850 - recall: 0.9850 - auc: 0.9981 - f1_score: 0.9850 - val_loss: 0.0807 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9963 - val_f1_score: 0.9556 - lr: 0.0010
# Epoch 39/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9983 - f1_score: 0.9775
# Epoch 39: val_loss did not improve from 0.04316
# 71/71 [==============================] - 32s 455ms/step - loss: 0.0536 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9983 - f1_score: 0.9775 - val_loss: 0.0575 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9956 - val_f1_score: 0.9822 - lr: 0.0010
# Epoch 40/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9950 - f1_score: 0.9704
# Epoch 40: val_loss did not improve from 0.04316
# 71/71 [==============================] - 32s 456ms/step - loss: 0.0799 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9950 - f1_score: 0.9704 - val_loss: 0.1051 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9932 - val_f1_score: 0.9645 - lr: 0.0010
# Epoch 41/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0655 - accuracy: 0.9726 - precision: 0.9726 - recall: 0.9726 - auc: 0.9974 - f1_score: 0.9726
# Epoch 41: val_loss did not improve from 0.04316
# 71/71 [==============================] - 31s 441ms/step - loss: 0.0655 - accuracy: 0.9726 - precision: 0.9726 - recall: 0.9726 - auc: 0.9974 - f1_score: 0.9726 - val_loss: 0.0538 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9984 - val_f1_score: 0.9882 - lr: 0.0010
# Epoch 42/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0601 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9977 - f1_score: 0.9775
# Epoch 42: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 42: val_loss did not improve from 0.04316
# 71/71 [==============================] - 31s 438ms/step - loss: 0.0601 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9977 - f1_score: 0.9775 - val_loss: 0.1038 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9934 - val_f1_score: 0.9645 - lr: 0.0010
# Epoch 43/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9806 - precision: 0.9806 - recall: 0.9806 - auc: 0.9974 - f1_score: 0.9806
# Epoch 43: val_loss did not improve from 0.04316
# 71/71 [==============================] - 31s 436ms/step - loss: 0.0545 - accuracy: 0.9806 - precision: 0.9806 - recall: 0.9806 - auc: 0.9974 - f1_score: 0.9806 - val_loss: 0.0673 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9973 - val_f1_score: 0.9734 - lr: 1.0000e-04
# Epoch 44/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0430 - accuracy: 0.9859 - precision: 0.9859 - recall: 0.9859 - auc: 0.9990 - f1_score: 0.9859
# Epoch 44: val_loss improved from 0.04316 to 0.04035, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 32s 456ms/step - loss: 0.0430 - accuracy: 0.9859 - precision: 0.9859 - recall: 0.9859 - auc: 0.9990 - f1_score: 0.9859 - val_loss: 0.0404 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9993 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 45/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0425 - accuracy: 0.9854 - precision: 0.9854 - recall: 0.9854 - auc: 0.9984 - f1_score: 0.9854
# Epoch 45: val_loss did not improve from 0.04035
# 71/71 [==============================] - 32s 454ms/step - loss: 0.0425 - accuracy: 0.9854 - precision: 0.9854 - recall: 0.9854 - auc: 0.9984 - f1_score: 0.9854 - val_loss: 0.0886 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9932 - val_f1_score: 0.9675 - lr: 1.0000e-04
# Epoch 46/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0339 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9993 - f1_score: 0.9872
# Epoch 46: val_loss did not improve from 0.04035
# 71/71 [==============================] - 33s 464ms/step - loss: 0.0339 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9993 - f1_score: 0.9872 - val_loss: 0.0564 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9982 - val_f1_score: 0.9793 - lr: 1.0000e-04
# Epoch 47/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9845 - precision: 0.9845 - recall: 0.9845 - auc: 0.9986 - f1_score: 0.9845
# Epoch 47: val_loss did not improve from 0.04035
# 71/71 [==============================] - 31s 441ms/step - loss: 0.0414 - accuracy: 0.9845 - precision: 0.9845 - recall: 0.9845 - auc: 0.9986 - f1_score: 0.9845 - val_loss: 0.0533 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9984 - val_f1_score: 0.9793 - lr: 1.0000e-04
# Epoch 48/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9854 - precision: 0.9854 - recall: 0.9854 - auc: 0.9993 - f1_score: 0.9854
# Epoch 48: val_loss improved from 0.04035 to 0.04020, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 30s 422ms/step - loss: 0.0358 - accuracy: 0.9854 - precision: 0.9854 - recall: 0.9854 - auc: 0.9993 - f1_score: 0.9854 - val_loss: 0.0402 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9991 - val_f1_score: 0.9822 - lr: 1.0000e-04
# Epoch 49/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9885 - precision: 0.9885 - recall: 0.9885 - auc: 0.9993 - f1_score: 0.9885
# Epoch 49: val_loss did not improve from 0.04020
# 71/71 [==============================] - 30s 425ms/step - loss: 0.0354 - accuracy: 0.9885 - precision: 0.9885 - recall: 0.9885 - auc: 0.9993 - f1_score: 0.9885 - val_loss: 0.0444 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9990 - val_f1_score: 0.9793 - lr: 1.0000e-04
# Epoch 50/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0311 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9994 - f1_score: 0.9894
# Epoch 50: val_loss improved from 0.04020 to 0.03841, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 33s 466ms/step - loss: 0.0311 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9994 - f1_score: 0.9894 - val_loss: 0.0384 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9992 - val_f1_score: 0.9882 - lr: 1.0000e-04
# Epoch 51/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.9890 - precision: 0.9890 - recall: 0.9890 - auc: 0.9995 - f1_score: 0.9890
# Epoch 51: val_loss did not improve from 0.03841
# 71/71 [==============================] - 29s 411ms/step - loss: 0.0295 - accuracy: 0.9890 - precision: 0.9890 - recall: 0.9890 - auc: 0.9995 - f1_score: 0.9890 - val_loss: 0.0578 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9978 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 52/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0355 - accuracy: 0.9876 - precision: 0.9876 - recall: 0.9876 - auc: 0.9991 - f1_score: 0.9876
# Epoch 52: val_loss improved from 0.03841 to 0.02786, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 34s 475ms/step - loss: 0.0355 - accuracy: 0.9876 - precision: 0.9876 - recall: 0.9876 - auc: 0.9991 - f1_score: 0.9876 - val_loss: 0.0279 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9997 - val_f1_score: 0.9911 - lr: 1.0000e-04
# Epoch 53/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0257 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9996 - f1_score: 0.9916
# Epoch 53: val_loss did not improve from 0.02786
# 71/71 [==============================] - 32s 455ms/step - loss: 0.0257 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9996 - f1_score: 0.9916 - val_loss: 0.0412 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9991 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 54/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9994 - f1_score: 0.9894
# Epoch 54: val_loss did not improve from 0.02786
# 71/71 [==============================] - 33s 461ms/step - loss: 0.0327 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9994 - f1_score: 0.9894 - val_loss: 0.0384 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9992 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 55/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9998 - f1_score: 0.9943
# Epoch 55: val_loss did not improve from 0.02786
# 71/71 [==============================] - 32s 443ms/step - loss: 0.0241 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9998 - f1_score: 0.9943 - val_loss: 0.0364 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9994 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 56/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0236 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9997 - f1_score: 0.9916
# Epoch 56: val_loss did not improve from 0.02786
# 71/71 [==============================] - 32s 452ms/step - loss: 0.0236 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9997 - f1_score: 0.9916 - val_loss: 0.0443 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9990 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 57/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - auc: 0.9998 - f1_score: 0.9938
# Epoch 57: val_loss did not improve from 0.02786
# 71/71 [==============================] - 33s 457ms/step - loss: 0.0227 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - auc: 0.9998 - f1_score: 0.9938 - val_loss: 0.0316 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9997 - val_f1_score: 0.9882 - lr: 1.0000e-04
# Epoch 58/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9997 - f1_score: 0.9947
# Epoch 58: val_loss did not improve from 0.02786
# 71/71 [==============================] - 32s 453ms/step - loss: 0.0237 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9997 - f1_score: 0.9947 - val_loss: 0.0502 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9983 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 59/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9993 - f1_score: 0.9872
# Epoch 59: val_loss did not improve from 0.02786
# 71/71 [==============================] - 34s 485ms/step - loss: 0.0345 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9993 - f1_score: 0.9872 - val_loss: 0.0595 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9976 - val_f1_score: 0.9793 - lr: 1.0000e-04
# Epoch 60/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9885 - precision: 0.9885 - recall: 0.9885 - auc: 0.9995 - f1_score: 0.9885
# Epoch 60: val_loss did not improve from 0.02786
# 71/71 [==============================] - 33s 461ms/step - loss: 0.0294 - accuracy: 0.9885 - precision: 0.9885 - recall: 0.9885 - auc: 0.9995 - f1_score: 0.9885 - val_loss: 0.0465 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9988 - val_f1_score: 0.9822 - lr: 1.0000e-04
# Epoch 61/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9998 - f1_score: 0.9947
# Epoch 61: val_loss did not improve from 0.02786
# 71/71 [==============================] - 34s 476ms/step - loss: 0.0205 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9998 - f1_score: 0.9947 - val_loss: 0.0286 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9996 - val_f1_score: 0.9911 - lr: 1.0000e-04
# Epoch 62/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0320 - accuracy: 0.9885 - precision: 0.9885 - recall: 0.9885 - auc: 0.9991 - f1_score: 0.9885
# Epoch 62: val_loss improved from 0.02786 to 0.02342, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 34s 477ms/step - loss: 0.0320 - accuracy: 0.9885 - precision: 0.9885 - recall: 0.9885 - auc: 0.9991 - f1_score: 0.9885 - val_loss: 0.0234 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9998 - val_f1_score: 0.9911 - lr: 1.0000e-04
# Epoch 63/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - auc: 0.9988 - f1_score: 0.9907
# Epoch 63: val_loss did not improve from 0.02342
# 71/71 [==============================] - 39s 544ms/step - loss: 0.0338 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - auc: 0.9988 - f1_score: 0.9907 - val_loss: 0.0275 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9996 - val_f1_score: 0.9911 - lr: 1.0000e-04
# Epoch 64/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9997 - f1_score: 0.9912
# Epoch 64: val_loss did not improve from 0.02342
# 71/71 [==============================] - 38s 540ms/step - loss: 0.0252 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9997 - f1_score: 0.9912 - val_loss: 0.0467 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9986 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 65/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - auc: 0.9996 - f1_score: 0.9907
# Epoch 65: val_loss did not improve from 0.02342
# 71/71 [==============================] - 37s 527ms/step - loss: 0.0261 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - auc: 0.9996 - f1_score: 0.9907 - val_loss: 0.0408 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9992 - val_f1_score: 0.9822 - lr: 1.0000e-04
# Epoch 66/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9996 - f1_score: 0.9916
# Epoch 66: val_loss did not improve from 0.02342
# 71/71 [==============================] - 36s 510ms/step - loss: 0.0256 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9996 - f1_score: 0.9916 - val_loss: 0.0406 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9992 - val_f1_score: 0.9822 - lr: 1.0000e-04
# Epoch 67/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9881 - precision: 0.9881 - recall: 0.9881 - auc: 0.9988 - f1_score: 0.9881
# Epoch 67: val_loss did not improve from 0.02342
# 71/71 [==============================] - 35s 494ms/step - loss: 0.0351 - accuracy: 0.9881 - precision: 0.9881 - recall: 0.9881 - auc: 0.9988 - f1_score: 0.9881 - val_loss: 0.0366 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9993 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 68/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9994 - f1_score: 0.9912
# Epoch 68: val_loss did not improve from 0.02342
# 71/71 [==============================] - 39s 548ms/step - loss: 0.0290 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9994 - f1_score: 0.9912 - val_loss: 0.0383 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9995 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 69/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9997 - f1_score: 0.9934
# Epoch 69: val_loss did not improve from 0.02342
# 71/71 [==============================] - 36s 499ms/step - loss: 0.0214 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9997 - f1_score: 0.9934 - val_loss: 0.0345 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9993 - val_f1_score: 0.9882 - lr: 1.0000e-04
# Epoch 70/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0284 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9995 - f1_score: 0.9894
# Epoch 70: val_loss did not improve from 0.02342
# 71/71 [==============================] - 35s 492ms/step - loss: 0.0284 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9995 - f1_score: 0.9894 - val_loss: 0.0252 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9997 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 71/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0302 - accuracy: 0.9885 - precision: 0.9885 - recall: 0.9885 - auc: 0.9995 - f1_score: 0.9885
# Epoch 71: val_loss did not improve from 0.02342
# 71/71 [==============================] - 35s 496ms/step - loss: 0.0302 - accuracy: 0.9885 - precision: 0.9885 - recall: 0.9885 - auc: 0.9995 - f1_score: 0.9885 - val_loss: 0.0362 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9987 - val_f1_score: 0.9941 - lr: 1.0000e-04
# Epoch 72/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9996 - f1_score: 0.9943
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 72: val_loss did not improve from 0.02342
# 71/71 [==============================] - 34s 480ms/step - loss: 0.0254 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9996 - f1_score: 0.9943 - val_loss: 0.0593 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9950 - val_f1_score: 0.9882 - lr: 1.0000e-04
# Epoch 73/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0269 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9988 - f1_score: 0.9916
# Epoch 73: val_loss improved from 0.02342 to 0.01533, saving model to /root/Breast Cancer/Model Code/ModelFileH5/ResNet50V2.h5
# 71/71 [==============================] - 35s 496ms/step - loss: 0.0269 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9988 - f1_score: 0.9916 - val_loss: 0.0153 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 74/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9997 - f1_score: 0.9916
# Epoch 74: val_loss did not improve from 0.01533
# 71/71 [==============================] - 36s 509ms/step - loss: 0.0233 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9997 - f1_score: 0.9916 - val_loss: 0.0195 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 0.9999 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 75/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9885 - precision: 0.9885 - recall: 0.9885 - auc: 0.9996 - f1_score: 0.9885
# Epoch 75: val_loss did not improve from 0.01533
# 71/71 [==============================] - 36s 503ms/step - loss: 0.0264 - accuracy: 0.9885 - precision: 0.9885 - recall: 0.9885 - auc: 0.9996 - f1_score: 0.9885 - val_loss: 0.0334 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9995 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 76/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9997 - f1_score: 0.9916
# Epoch 76: val_loss did not improve from 0.01533
# 71/71 [==============================] - 35s 491ms/step - loss: 0.0242 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9997 - f1_score: 0.9916 - val_loss: 0.0405 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9988 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 77/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0299 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9994 - f1_score: 0.9894
# Epoch 77: val_loss did not improve from 0.01533
# 71/71 [==============================] - 37s 517ms/step - loss: 0.0299 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9994 - f1_score: 0.9894 - val_loss: 0.0322 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9992 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 78/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9996 - f1_score: 0.9934
# Epoch 78: val_loss did not improve from 0.01533
# 71/71 [==============================] - 35s 494ms/step - loss: 0.0252 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9996 - f1_score: 0.9934 - val_loss: 0.0354 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9994 - val_f1_score: 0.9882 - lr: 1.0000e-05
# Epoch 79/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9996 - f1_score: 0.9903
# Epoch 79: val_loss did not improve from 0.01533
# 71/71 [==============================] - 36s 503ms/step - loss: 0.0280 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9996 - f1_score: 0.9903 - val_loss: 0.0276 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9997 - val_f1_score: 0.9911 - lr: 1.0000e-05
# Epoch 80/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9898 - precision: 0.9898 - recall: 0.9898 - auc: 0.9997 - f1_score: 0.9898
# Epoch 80: val_loss did not improve from 0.01533
# 71/71 [==============================] - 36s 504ms/step - loss: 0.0249 - accuracy: 0.9898 - precision: 0.9898 - recall: 0.9898 - auc: 0.9997 - f1_score: 0.9898 - val_loss: 0.0295 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9994 - val_f1_score: 0.9911 - lr: 1.0000e-05
# Epoch 81/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9998 - f1_score: 0.9916
# Epoch 81: val_loss did not improve from 0.01533
# 71/71 [==============================] - 37s 525ms/step - loss: 0.0212 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9998 - f1_score: 0.9916 - val_loss: 0.0246 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9997 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 82/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9999 - f1_score: 0.9943
# Epoch 82: val_loss did not improve from 0.01533
# 71/71 [==============================] - 38s 531ms/step - loss: 0.0195 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9999 - f1_score: 0.9943 - val_loss: 0.0601 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9956 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 83/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9997 - f1_score: 0.9929
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 83: val_loss did not improve from 0.01533
# 71/71 [==============================] - 36s 508ms/step - loss: 0.0231 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9997 - f1_score: 0.9929 - val_loss: 0.0321 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9995 - val_f1_score: 0.9822 - lr: 1.0000e-05
# Epoch 84/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - auc: 0.9997 - f1_score: 0.9907
# Epoch 84: val_loss did not improve from 0.01533
# 71/71 [==============================] - 38s 541ms/step - loss: 0.0250 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - auc: 0.9997 - f1_score: 0.9907 - val_loss: 0.0266 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9997 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 85/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9925 - precision: 0.9925 - recall: 0.9925 - auc: 0.9997 - f1_score: 0.9925
# Epoch 85: val_loss did not improve from 0.01533
# 71/71 [==============================] - 35s 486ms/step - loss: 0.0228 - accuracy: 0.9925 - precision: 0.9925 - recall: 0.9925 - auc: 0.9997 - f1_score: 0.9925 - val_loss: 0.0191 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9999 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 86/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9996 - f1_score: 0.9943
# Epoch 86: val_loss did not improve from 0.01533
# 71/71 [==============================] - 35s 487ms/step - loss: 0.0235 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9996 - f1_score: 0.9943 - val_loss: 0.0344 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9994 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 87/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0201 - accuracy: 0.9956 - precision: 0.9956 - recall: 0.9956 - auc: 0.9998 - f1_score: 0.9956
# Epoch 87: val_loss did not improve from 0.01533
# 71/71 [==============================] - 35s 495ms/step - loss: 0.0201 - accuracy: 0.9956 - precision: 0.9956 - recall: 0.9956 - auc: 0.9998 - f1_score: 0.9956 - val_loss: 0.0277 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9997 - val_f1_score: 0.9911 - lr: 1.0000e-05
# Epoch 88/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9996 - f1_score: 0.9934
# Epoch 88: val_loss did not improve from 0.01533
# ...
# Epoch 120: val_loss did not improve from 0.01533
# 71/71 [==============================] - 37s 516ms/step - loss: 0.0239 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9997 - f1_score: 0.9929 - val_loss: 0.0282 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9997 - val_f1_score: 0.9911 - lr: 1.0000e-05
# Epoch 121/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9998 - f1_score: 0.9916
# Epoch 121: val_loss did not improve from 0.01533
# 71/71 [==============================] - 32s 454ms/step - loss: 0.0192 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9998 - f1_score: 0.9916 - val_loss: 0.0229 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 0.9997 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 122/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0186 - accuracy: 0.9956 - precision: 0.9956 - recall: 0.9956 - auc: 0.9998 - f1_score: 0.9956
# Epoch 122: val_loss did not improve from 0.01533
# 71/71 [==============================] - 35s 494ms/step - loss: 0.0186 - accuracy: 0.9956 - precision: 0.9956 - recall: 0.9956 - auc: 0.9998 - f1_score: 0.9956 - val_loss: 0.0361 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9993 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 123/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9998 - f1_score: 0.9943
# Epoch 123: val_loss did not improve from 0.01533
# 71/71 [==============================] - 35s 494ms/step - loss: 0.0191 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9998 - f1_score: 0.9943 - val_loss: 0.0237 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9998 - val_f1_score: 0.9911 - lr: 1.0000e-05
# Epoch 124/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0194 - accuracy: 0.9951 - precision: 0.9951 - recall: 0.9951 - auc: 0.9999 - f1_score: 0.9951
# Epoch 124: val_loss did not improve from 0.01533
# 71/71 [==============================] - 36s 505ms/step - loss: 0.0194 - accuracy: 0.9951 - precision: 0.9951 - recall: 0.9951 - auc: 0.9999 - f1_score: 0.9951 - val_loss: 0.0369 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9991 - val_f1_score: 0.9822 - lr: 1.0000e-05
# Epoch 125/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9997 - f1_score: 0.9912
# Epoch 125: val_loss did not improve from 0.01533
# 71/71 [==============================] - 35s 490ms/step - loss: 0.0235 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9997 - f1_score: 0.9912 - val_loss: 0.0251 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9998 - val_f1_score: 0.9882 - lr: 1.0000e-05
# Epoch 126/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9998 - f1_score: 0.9947
# Epoch 126: val_loss did not improve from 0.01533
# 71/71 [==============================] - 30s 421ms/step - loss: 0.0185 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9998 - f1_score: 0.9947 - val_loss: 0.0352 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9993 - val_f1_score: 0.9882 - lr: 1.0000e-05
# Epoch 127/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9998 - f1_score: 0.9929
# Epoch 127: val_loss did not improve from 0.01533
# 71/71 [==============================] - 32s 443ms/step - loss: 0.0204 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9998 - f1_score: 0.9929 - val_loss: 0.0376 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9964 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 128/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - auc: 0.9998 - f1_score: 0.9938
# Epoch 128: val_loss did not improve from 0.01533
# 71/71 [==============================] - 32s 451ms/step - loss: 0.0192 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - auc: 0.9998 - f1_score: 0.9938 - val_loss: 0.0234 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9998 - val_f1_score: 0.9882 - lr: 1.0000e-05
# Epoch 129/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9998 - f1_score: 0.9912
# Epoch 129: val_loss did not improve from 0.01533
# 71/71 [==============================] - 32s 454ms/step - loss: 0.0220 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9998 - f1_score: 0.9912 - val_loss: 0.0208 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 0.9999 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 130/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0205 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9997 - f1_score: 0.9934
# Epoch 130: val_loss did not improve from 0.01533
# 71/71 [==============================] - 31s 435ms/step - loss: 0.0205 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9997 - f1_score: 0.9934 - val_loss: 0.0341 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9995 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 131/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9995 - f1_score: 0.9916
# Epoch 131: val_loss did not improve from 0.01533
# 71/71 [==============================] - 31s 441ms/step - loss: 0.0270 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9995 - f1_score: 0.9916 - val_loss: 0.0168 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 1.0000 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 132/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9996 - f1_score: 0.9894
# Epoch 132: val_loss did not improve from 0.01533
# 71/71 [==============================] - 32s 443ms/step - loss: 0.0267 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9996 - f1_score: 0.9894 - val_loss: 0.0370 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9989 - val_f1_score: 0.9882 - lr: 1.0000e-05
# Epoch 133/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9998 - f1_score: 0.9934
# Epoch 133: val_loss did not improve from 0.01533
# 71/71 [==============================] - 30s 427ms/step - loss: 0.0203 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9998 - f1_score: 0.9934 - val_loss: 0.0416 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9989 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 134/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9998 - f1_score: 0.9934
# Epoch 134: val_loss did not improve from 0.01533
# 71/71 [==============================] - 30s 420ms/step - loss: 0.0204 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9998 - f1_score: 0.9934 - val_loss: 0.0248 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9997 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 135/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0247 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9996 - f1_score: 0.9916
# Epoch 135: val_loss did not improve from 0.01533
# 71/71 [==============================] - 31s 437ms/step - loss: 0.0247 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9996 - f1_score: 0.9916 - val_loss: 0.0175 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9999 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 136/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9998 - f1_score: 0.9912
# Epoch 136: val_loss did not improve from 0.01533
# 71/71 [==============================] - 32s 446ms/step - loss: 0.0215 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9998 - f1_score: 0.9912 - val_loss: 0.0225 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 0.9995 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 137/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9994 - f1_score: 0.9929
# Epoch 137: val_loss did not improve from 0.01533
# 71/71 [==============================] - 31s 433ms/step - loss: 0.0190 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9994 - f1_score: 0.9929 - val_loss: 0.0172 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9999 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 138/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - auc: 0.9998 - f1_score: 0.9938
# Epoch 138: val_loss did not improve from 0.01533
# 71/71 [==============================] - 30s 419ms/step - loss: 0.0206 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - auc: 0.9998 - f1_score: 0.9938 - val_loss: 0.0218 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9998 - val_f1_score: 0.9911 - lr: 1.0000e-05
# Epoch 139/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9996 - f1_score: 0.9916
# Epoch 139: val_loss did not improve from 0.01533
# 71/71 [==============================] - 34s 472ms/step - loss: 0.0246 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9996 - f1_score: 0.9916 - val_loss: 0.0176 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 0.9999 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 140/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0210 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9998 - f1_score: 0.9929
# Epoch 140: val_loss did not improve from 0.01533
# 71/71 [==============================] - 30s 418ms/step - loss: 0.0210 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9998 - f1_score: 0.9929 - val_loss: 0.0186 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9998 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 141/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0228 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9997 - f1_score: 0.9920
# Epoch 141: val_loss did not improve from 0.01533
# 71/71 [==============================] - 29s 405ms/step - loss: 0.0228 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9997 - f1_score: 0.9920 - val_loss: 0.0156 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9999 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 142/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0219 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - auc: 0.9997 - f1_score: 0.9938
# Epoch 142: val_loss did not improve from 0.01533
# 71/71 [==============================] - 32s 452ms/step - loss: 0.0219 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - auc: 0.9997 - f1_score: 0.9938 - val_loss: 0.0212 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9999 - val_f1_score: 0.9911 - lr: 1.0000e-05
# Epoch 143/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9925 - precision: 0.9925 - recall: 0.9925 - auc: 0.9997 - f1_score: 0.9925
# Epoch 143: val_loss did not improve from 0.01533
# 71/71 [==============================] - 31s 441ms/step - loss: 0.0226 - accuracy: 0.9925 - precision: 0.9925 - recall: 0.9925 - auc: 0.9997 - f1_score: 0.9925 - val_loss: 0.0316 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9995 - val_f1_score: 0.9911 - lr: 1.0000e-05
# Epoch 144/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0190 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9998 - f1_score: 0.9947
# Epoch 144: val_loss did not improve from 0.01533
# 71/71 [==============================] - 29s 409ms/step - loss: 0.0190 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9998 - f1_score: 0.9947 - val_loss: 0.0199 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9999 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 145/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0277 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - auc: 0.9995 - f1_score: 0.9907
# Epoch 145: val_loss did not improve from 0.01533
# 71/71 [==============================] - 29s 403ms/step - loss: 0.0277 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - auc: 0.9995 - f1_score: 0.9907 - val_loss: 0.0328 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9995 - val_f1_score: 0.9882 - lr: 1.0000e-05
# Epoch 146/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9998 - f1_score: 0.9920
# Epoch 146: val_loss did not improve from 0.01533
# 71/71 [==============================] - 30s 427ms/step - loss: 0.0218 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9998 - f1_score: 0.9920 - val_loss: 0.0343 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9994 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 147/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0233 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9997 - f1_score: 0.9912
# Epoch 147: val_loss did not improve from 0.01533
# 71/71 [==============================] - 30s 422ms/step - loss: 0.0233 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9997 - f1_score: 0.9912 - val_loss: 0.0332 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9995 - val_f1_score: 0.9882 - lr: 1.0000e-05
# Epoch 148/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - auc: 0.9998 - f1_score: 0.9938
# Epoch 148: val_loss did not improve from 0.01533
# 71/71 [==============================] - 32s 446ms/step - loss: 0.0206 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - auc: 0.9998 - f1_score: 0.9938 - val_loss: 0.0394 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9991 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 149/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9925 - precision: 0.9925 - recall: 0.9925 - auc: 0.9997 - f1_score: 0.9925
# Epoch 149: val_loss did not improve from 0.01533
# 71/71 [==============================] - 30s 426ms/step - loss: 0.0231 - accuracy: 0.9925 - precision: 0.9925 - recall: 0.9925 - auc: 0.9997 - f1_score: 0.9925 - val_loss: 0.0255 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9998 - val_f1_score: 0.9911 - lr: 1.0000e-05
# Epoch 150/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9998 - f1_score: 0.9929
# Epoch 150: val_loss did not improve from 0.01533
# 71/71 [==============================] - 30s 420ms/step - loss: 0.0202 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9998 - f1_score: 0.9929 - val_loss: 0.0257 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9998 - val_f1_score: 0.9941 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

# plt.subplot(2, 3, 5)
# plt.plot(range(1, len(f1_score_callback.train_f1_scores) + 1), f1_score_callback.train_f1_scores, label='Training F1 Score')
# plt.plot(range(1, len(f1_score_callback.val_f1_scores) + 1), f1_score_callback.val_f1_scores, label='Validation F1 Score')
# plt.title('Model F1-Score')
# plt.xlabel('Epoch')
# plt.ylabel('F1-Score')
# plt.legend(['F1 Score'], loc='lower right')


plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["benign", "malignant"], yticklabels=["benign", "malignant"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 1s 43ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9418028604815747
# F1-Score for each class: [0.91719745 0.96640827]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9842105263157894
# specificity: 0.8780487804878049

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 21ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)

# test_loss, test_acc, test_precision, test_recall, test_auc = DIR.evaluate(test_generator)
# print('Test loss:', test_loss)
# print('Test accuracy:', test_acc)
# print('Test precision:', test_precision)
# print('Test recall:', test_recall)
# print('Test AUC:', test_auc)


# from sklearn.metrics import f1_score
# import numpy as np

# # 预测测试集
# y_pred = DIR.predict(test_generator)
# y_pred = np.argmax(y_pred, axis=1)

# # 真实标签
# y_true = test_generator.classes

# # 计算F1分数
# test_f1_score = f1_score(y_true, y_pred, average='micro')  # 或者根据你的需要选择其他average参数
# print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 1s 111ms/step - loss: 0.2097 - accuracy: 0.9507 - precision: 0.9507 - recall: 0.9507 - auc: 0.9793 - f1_score: 0.9507
# Test loss: 0.20968076586723328
# Test accuracy: 0.9506579041481018
# Test precision: 0.9506579041481018
# Test recall: 0.9506579041481018
# Test AUC: 0.9793002009391785
# Test F1 Score: 0.9506579637527466

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 22ms/step
#               precision    recall  f1-score   support
#
#            0       0.96      0.88      0.92        82
#            1       0.95      0.98      0.97       190
#
#     accuracy                           0.95       272
#    macro avg       0.95      0.93      0.94       272
# weighted avg       0.95      0.95      0.95       272

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

# del DIR


from numba import cuda

cuda.select_device(0)
cuda.close()
