# %% [markdown]
# 再version 6的基础上，batchsize = 32， stem第一层变为4，用leaky relu，将inception a的函数里面的分支第一层神经元改为8
#
# 在Version 7的及基础上，加入L1正则化

# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.regularizers import l2

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.
# Out:
# 2024-03-12 01:17:51.580171: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 304 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

l2_reg = 0.001



def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='leaky_relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)
    
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    # a = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same', kernel_regularizer = l2(l2_reg))(x)
    # a = attention_block_2(x)

    
    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    c = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = attention_block_2(x)

    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    # c = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 5
num_B_blocks = 10
num_C_blocks = 5

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.3)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax', kernel_regularizer = l2(l2_reg))(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# 2024-03-12 01:17:55.870477: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-12 01:17:56.592584: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22134 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:b1:00.0, compute capability: 8.9
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 4)  112         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 222, 222, 96  3552        ['conv2d[0][0]']
#                                 )
#
#  activation (Activation)        (None, 222, 222, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 222, 222, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 222, 222, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 222, 222, 4)  0           ['conv2d[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 220, 220, 4)  148         ['multiply[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 220, 220, 96  3552        ['conv2d_3[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 220, 220, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 220, 220, 1)  97          ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 220, 220, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 220, 220, 4)  0           ['conv2d_3[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 220, 220, 8)  296         ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 220, 220, 96  7008        ['conv2d_6[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 220, 220, 96  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 220, 220, 1)  97          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 220, 220, 1)  0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 220, 220, 8)  0           ['conv2d_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['multiply_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 218, 218, 12  876         ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_13[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_16[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_6 (Activation)      (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 16  160        ['conv2d_18[0][0]']
#  v2D)                           )
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_17[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['activation_6[0][0]',
#                                 )                                 'conv2d_21[0][0]']
#
#  activation_7 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_23[0][0]']
#  onv2D)                         )
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_24[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_22[0][0]',
#                                 )                                 'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 214, 214, 48  0           ['activation_7[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  activation_8 (Activation)      (None, 214, 214, 48  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_28[0][0]']
#  onv2D)                         )
#
#  conv2d_30 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_29[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_27[0][0]',
#                                 )                                 'depthwise_conv2d_2[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_5[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 214, 214, 48  0           ['activation_8[0][0]',
#                                 )                                 'conv2d_31[0][0]']
#
#  activation_9 (Activation)      (None, 214, 214, 48  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_33[0][0]']
#  onv2D)                         )
#
#  conv2d_35 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_34[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_32[0][0]',
#                                 )                                 'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_6[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 214, 214, 48  0           ['activation_9[0][0]',
#                                 )                                 'conv2d_36[0][0]']
#
#  activation_10 (Activation)     (None, 214, 214, 48  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_38[0][0]']
#  onv2D)                         )
#
#  conv2d_40 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_39[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_37[0][0]',
#                                 )                                 'depthwise_conv2d_4[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_7[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 214, 214, 48  0           ['activation_10[0][0]',
#                                 )                                 'conv2d_41[0][0]']
#
#  activation_11 (Activation)     (None, 214, 214, 48  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 214, 214, 32  1568        ['activation_11[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_43[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_11[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 106, 106, 48  20784       ['activation_11[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_44[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_42[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_49[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_46[0][0]',
#                                 )                                 'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_9[0][0]']
#                                 4)
#
#  add_5 (Add)                    (None, 106, 106, 14  0           ['concatenate_8[0][0]',
#                                 4)                                'conv2d_51[0][0]']
#
#  activation_12 (Activation)     (None, 106, 106, 14  0           ['add_5[0][0]']
#                                 4)
#
#  conv2d_53 (Conv2D)             (None, 106, 106, 16  2320        ['activation_12[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 106, 106, 24  3480        ['activation_12[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_55[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_52[0][0]',
#                                 )                                 'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_10[0][0]']
#                                 4)
#
#  add_6 (Add)                    (None, 106, 106, 14  0           ['activation_12[0][0]',
#                                 4)                                'conv2d_57[0][0]']
#
#  activation_13 (Activation)     (None, 106, 106, 14  0           ['add_6[0][0]']
#                                 4)
#
#  conv2d_59 (Conv2D)             (None, 106, 106, 16  2320        ['activation_13[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_59[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_60[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 106, 106, 24  3480        ['activation_13[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_61[0][0]']
#                                 )
#
#  concatenate_11 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_58[0][0]',
#                                 )                                 'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_11[0][0]']
#                                 4)
#
#  add_7 (Add)                    (None, 106, 106, 14  0           ['activation_13[0][0]',
#                                 4)                                'conv2d_63[0][0]']
#
#  activation_14 (Activation)     (None, 106, 106, 14  0           ['add_7[0][0]']
#                                 4)
#
#  conv2d_65 (Conv2D)             (None, 106, 106, 16  2320        ['activation_14[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_65[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_66[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 106, 106, 24  3480        ['activation_14[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_67[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_64[0][0]',
#                                 )                                 'conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_12[0][0]']
#                                 4)
#
#  add_8 (Add)                    (None, 106, 106, 14  0           ['activation_14[0][0]',
#                                 4)                                'conv2d_69[0][0]']
#
#  activation_15 (Activation)     (None, 106, 106, 14  0           ['add_8[0][0]']
#                                 4)
#
#  conv2d_71 (Conv2D)             (None, 106, 106, 16  2320        ['activation_15[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_71[0][0]']
#                                 )
#
#  conv2d_73 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_72[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 106, 106, 24  3480        ['activation_15[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_73[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_70[0][0]',
#                                 )                                 'conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_13[0][0]']
#                                 4)
#
#  add_9 (Add)                    (None, 106, 106, 14  0           ['activation_15[0][0]',
#                                 4)                                'conv2d_75[0][0]']
#
#  activation_16 (Activation)     (None, 106, 106, 14  0           ['add_9[0][0]']
#                                 4)
#
#  conv2d_77 (Conv2D)             (None, 106, 106, 16  2320        ['activation_16[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_77[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_78[0][0]']
#                                 )
#
#  conv2d_76 (Conv2D)             (None, 106, 106, 24  3480        ['activation_16[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_79[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_76[0][0]',
#                                 )                                 'conv2d_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_14[0][0]']
#                                 4)
#
#  add_10 (Add)                   (None, 106, 106, 14  0           ['activation_16[0][0]',
#                                 4)                                'conv2d_81[0][0]']
#
#  activation_17 (Activation)     (None, 106, 106, 14  0           ['add_10[0][0]']
#                                 4)
#
#  conv2d_83 (Conv2D)             (None, 106, 106, 16  2320        ['activation_17[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_83[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_84[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 106, 106, 24  3480        ['activation_17[0][0]']
#                                 )
#
#  conv2d_86 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_85[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_82[0][0]',
#                                 )                                 'conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_15[0][0]']
#                                 4)
#
#  add_11 (Add)                   (None, 106, 106, 14  0           ['activation_17[0][0]',
#                                 4)                                'conv2d_87[0][0]']
#
#  activation_18 (Activation)     (None, 106, 106, 14  0           ['add_11[0][0]']
#                                 4)
#
#  conv2d_89 (Conv2D)             (None, 106, 106, 16  2320        ['activation_18[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_89[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_90[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 106, 106, 24  3480        ['activation_18[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_91[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_88[0][0]',
#                                 )                                 'conv2d_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_16[0][0]']
#                                 4)
#
#  add_12 (Add)                   (None, 106, 106, 14  0           ['activation_18[0][0]',
#                                 4)                                'conv2d_93[0][0]']
#
#  activation_19 (Activation)     (None, 106, 106, 14  0           ['add_12[0][0]']
#                                 4)
#
#  conv2d_95 (Conv2D)             (None, 106, 106, 16  2320        ['activation_19[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_95[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_96[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 106, 106, 24  3480        ['activation_19[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_97[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_94[0][0]',
#                                 )                                 'conv2d_98[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_17[0][0]']
#                                 4)
#
#  add_13 (Add)                   (None, 106, 106, 14  0           ['activation_19[0][0]',
#                                 4)                                'conv2d_99[0][0]']
#
#  activation_20 (Activation)     (None, 106, 106, 14  0           ['add_13[0][0]']
#                                 4)
#
#  conv2d_101 (Conv2D)            (None, 106, 106, 16  2320        ['activation_20[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 106, 106, 20  2260        ['conv2d_101[0][0]']
#                                 )
#
#  conv2d_103 (Conv2D)            (None, 106, 106, 24  3384        ['conv2d_102[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 106, 106, 24  3480        ['activation_20[0][0]']
#                                 )
#
#  conv2d_104 (Conv2D)            (None, 106, 106, 24  600         ['conv2d_103[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_100[0][0]',
#                                 )                                 'conv2d_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 106, 106, 14  7056        ['concatenate_18[0][0]']
#                                 4)
#
#  add_14 (Add)                   (None, 106, 106, 14  0           ['activation_20[0][0]',
#                                 4)                                'conv2d_105[0][0]']
#
#  activation_21 (Activation)     (None, 106, 106, 14  0           ['add_14[0][0]']
#                                 4)
#
#  conv2d_110 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_106 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_108 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_111 (Conv2D)            (None, 106, 106, 36  10404       ['conv2d_110[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_21[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_106[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_108[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 52, 52, 40)   13000       ['conv2d_111[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_107[0][0]',
#                                                                   'conv2d_109[0][0]',
#                                                                   'conv2d_112[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_114[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_115[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_113[0][0]',
#                                                                   'conv2d_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_20[0][0]']
#
#  add_15 (Add)                   (None, 52, 52, 256)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_117[0][0]']
#
#  activation_22 (Activation)     (None, 52, 52, 256)  0           ['add_15[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_119[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_120[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_118[0][0]',
#                                                                   'conv2d_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_21[0][0]']
#
#  add_16 (Add)                   (None, 52, 52, 256)  0           ['activation_22[0][0]',
#                                                                   'conv2d_122[0][0]']
#
#  activation_23 (Activation)     (None, 52, 52, 256)  0           ['add_16[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_124[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_125[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_123[0][0]',
#                                                                   'conv2d_126[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_22[0][0]']
#
#  add_17 (Add)                   (None, 52, 52, 256)  0           ['activation_23[0][0]',
#                                                                   'conv2d_127[0][0]']
#
#  activation_24 (Activation)     (None, 52, 52, 256)  0           ['add_17[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_129[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_130[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_128[0][0]',
#                                                                   'conv2d_131[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_23[0][0]']
#
#  add_18 (Add)                   (None, 52, 52, 256)  0           ['activation_24[0][0]',
#                                                                   'conv2d_132[0][0]']
#
#  activation_25 (Activation)     (None, 52, 52, 256)  0           ['add_18[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_134[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_135[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_133[0][0]',
#                                                                   'conv2d_136[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_24[0][0]']
#
#  add_19 (Add)                   (None, 52, 52, 256)  0           ['activation_25[0][0]',
#                                                                   'conv2d_137[0][0]']
#
#  activation_26 (Activation)     (None, 52, 52, 256)  0           ['add_19[0][0]']
#
#  dropout (Dropout)              (None, 52, 52, 256)  0           ['activation_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 505,821
# Trainable params: 505,821
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# import numpy as np
# from sklearn.metrics import f1_score
# from tensorflow.keras.callbacks import Callback

# class F1ScoreCallback(Callback):
#     def __init__(self, train_generator, validation_generator, num_classes):
#         super(F1ScoreCallback, self).__init__()
#         self.train_generator = train_generator
#         self.validation_generator = validation_generator
#         self.num_classes = num_classes
#         self.train_f1_scores = []
#         self.val_f1_scores = []

#     def on_epoch_end(self, epoch, logs=None):
#         # 计算训练集F1分数
#         train_predict, train_true = self._get_predictions_and_true_labels(self.train_generator)
#         train_f1 = f1_score(train_true, train_predict, average='micro')
#         self.train_f1_scores.append(train_f1)
        
#         # 计算验证集F1分数
#         val_predict, val_true = self._get_predictions_and_true_labels(self.validation_generator)
#         val_f1 = f1_score(val_true, val_predict, average='micro')
#         self.val_f1_scores.append(val_f1)
        
#         print(f'Epoch {epoch+1}: Training F1 Score: {train_f1}, Validation F1 Score: {val_f1}')

#     def _get_predictions_and_true_labels(self, generator):
#         predictions = []
#         true_labels = []
#         for i in range(len(generator)):
#             x_batch, y_batch_true = next(generator)
#             y_batch_pred = self.model.predict(x_batch, verbose=0)
#             y_batch_pred = np.argmax(y_batch_pred, axis=1)
#             y_true = np.argmax(y_batch_true, axis=1)
#             predictions.extend(y_batch_pred)
#             true_labels.extend(y_true)
#         return predictions, true_labels


# # 继续使用之前的方式将回调添加到你的模型训练中

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(),
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version911-DIR"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)


lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', 
                                 factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# f1_score_callback = F1ScoreCallback(train_generator = train_generator, 
#                                     validation_generator=validation_generator, 
#                                     num_classes=num_classes)


from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = DIR.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)


# history = DIR.fit(
#     train_generator,
#     epochs=150,
#     validation_data=validation_generator,
#     callbacks=[csv_logger, lr_reduction, model_checkpoint_callback, f1_score_callback]
# )
# Out:
# Epoch 1/150
# 2024-03-12 01:18:09.949625: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-12 01:18:10.992764: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-03-12 01:18:10.992784: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2024-03-12 01:18:10.992843: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-03-12 01:18:12.451433: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 14.4805 - accuracy: 0.5144 - precision: 0.5144 - recall: 0.5144 - auc: 0.5139 - f1_score: 0.5144
# Epoch 1: val_loss improved from inf to 0.89606, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 70s 802ms/step - loss: 14.4805 - accuracy: 0.5144 - precision: 0.5144 - recall: 0.5144 - auc: 0.5139 - f1_score: 0.5144 - val_loss: 0.8961 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5866 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.8578 - accuracy: 0.5236 - precision: 0.5236 - recall: 0.5236 - auc: 0.5284 - f1_score: 0.5236
# Epoch 2: val_loss improved from 0.89606 to 0.83338, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 52s 728ms/step - loss: 0.8578 - accuracy: 0.5236 - precision: 0.5236 - recall: 0.5236 - auc: 0.5284 - f1_score: 0.5236 - val_loss: 0.8334 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6357 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 3/150
# 71/71 [==============================] - ETA: 0s - loss: 0.8161 - accuracy: 0.5731 - precision: 0.5731 - recall: 0.5731 - auc: 0.6133 - f1_score: 0.5731
# Epoch 3: val_loss improved from 0.83338 to 0.75572, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 53s 736ms/step - loss: 0.8161 - accuracy: 0.5731 - precision: 0.5731 - recall: 0.5731 - auc: 0.6133 - f1_score: 0.5731 - val_loss: 0.7557 - val_accuracy: 0.6716 - val_precision: 0.6716 - val_recall: 0.6716 - val_auc: 0.7662 - val_f1_score: 0.6716 - lr: 0.0010
# Epoch 4/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7899 - accuracy: 0.6253 - precision: 0.6253 - recall: 0.6253 - auc: 0.6504 - f1_score: 0.6253
# Epoch 4: val_loss improved from 0.75572 to 0.72109, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 52s 724ms/step - loss: 0.7899 - accuracy: 0.6253 - precision: 0.6253 - recall: 0.6253 - auc: 0.6504 - f1_score: 0.6253 - val_loss: 0.7211 - val_accuracy: 0.7012 - val_precision: 0.7012 - val_recall: 0.7012 - val_auc: 0.7777 - val_f1_score: 0.7012 - lr: 0.0010
# Epoch 5/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7563 - accuracy: 0.6712 - precision: 0.6712 - recall: 0.6712 - auc: 0.7033 - f1_score: 0.6712
# Epoch 5: val_loss did not improve from 0.72109
# 71/71 [==============================] - 53s 735ms/step - loss: 0.7563 - accuracy: 0.6712 - precision: 0.6712 - recall: 0.6712 - auc: 0.7033 - f1_score: 0.6712 - val_loss: 0.8171 - val_accuracy: 0.5385 - val_precision: 0.5385 - val_recall: 0.5385 - val_auc: 0.7247 - val_f1_score: 0.5385 - lr: 0.0010
# Epoch 6/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7834 - accuracy: 0.6164 - precision: 0.6164 - recall: 0.6164 - auc: 0.6506 - f1_score: 0.6164
# Epoch 6: val_loss improved from 0.72109 to 0.64263, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 52s 730ms/step - loss: 0.7834 - accuracy: 0.6164 - precision: 0.6164 - recall: 0.6164 - auc: 0.6506 - f1_score: 0.6164 - val_loss: 0.6426 - val_accuracy: 0.7899 - val_precision: 0.7899 - val_recall: 0.7899 - val_auc: 0.9029 - val_f1_score: 0.7899 - lr: 0.0010
# Epoch 7/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6781 - accuracy: 0.7282 - precision: 0.7282 - recall: 0.7282 - auc: 0.7806 - f1_score: 0.7282
# Epoch 7: val_loss improved from 0.64263 to 0.51790, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 53s 736ms/step - loss: 0.6781 - accuracy: 0.7282 - precision: 0.7282 - recall: 0.7282 - auc: 0.7806 - f1_score: 0.7282 - val_loss: 0.5179 - val_accuracy: 0.8314 - val_precision: 0.8314 - val_recall: 0.8314 - val_auc: 0.9146 - val_f1_score: 0.8314 - lr: 0.0010
# Epoch 8/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6917 - accuracy: 0.7278 - precision: 0.7278 - recall: 0.7278 - auc: 0.7680 - f1_score: 0.7278
# Epoch 8: val_loss did not improve from 0.51790
# 71/71 [==============================] - 52s 721ms/step - loss: 0.6917 - accuracy: 0.7278 - precision: 0.7278 - recall: 0.7278 - auc: 0.7680 - f1_score: 0.7278 - val_loss: 0.5482 - val_accuracy: 0.7959 - val_precision: 0.7959 - val_recall: 0.7959 - val_auc: 0.9081 - val_f1_score: 0.7959 - lr: 0.0010
# Epoch 9/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6177 - accuracy: 0.7711 - precision: 0.7711 - recall: 0.7711 - auc: 0.8292 - f1_score: 0.7711
# Epoch 9: val_loss did not improve from 0.51790
# 71/71 [==============================] - 52s 727ms/step - loss: 0.6177 - accuracy: 0.7711 - precision: 0.7711 - recall: 0.7711 - auc: 0.8292 - f1_score: 0.7711 - val_loss: 0.5652 - val_accuracy: 0.8491 - val_precision: 0.8491 - val_recall: 0.8491 - val_auc: 0.9218 - val_f1_score: 0.8491 - lr: 0.0010
# Epoch 10/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6169 - accuracy: 0.7640 - precision: 0.7640 - recall: 0.7640 - auc: 0.8304 - f1_score: 0.7640
# Epoch 10: val_loss improved from 0.51790 to 0.46044, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 53s 743ms/step - loss: 0.6169 - accuracy: 0.7640 - precision: 0.7640 - recall: 0.7640 - auc: 0.8304 - f1_score: 0.7640 - val_loss: 0.4604 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9460 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 11/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6284 - accuracy: 0.7543 - precision: 0.7543 - recall: 0.7543 - auc: 0.8210 - f1_score: 0.7543
# Epoch 11: val_loss did not improve from 0.46044
# 71/71 [==============================] - 52s 725ms/step - loss: 0.6284 - accuracy: 0.7543 - precision: 0.7543 - recall: 0.7543 - auc: 0.8210 - f1_score: 0.7543 - val_loss: 0.4920 - val_accuracy: 0.8314 - val_precision: 0.8314 - val_recall: 0.8314 - val_auc: 0.9360 - val_f1_score: 0.8314 - lr: 0.0010
# Epoch 12/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6125 - accuracy: 0.7592 - precision: 0.7592 - recall: 0.7592 - auc: 0.8321 - f1_score: 0.7592
# Epoch 12: val_loss did not improve from 0.46044
# 71/71 [==============================] - 51s 718ms/step - loss: 0.6125 - accuracy: 0.7592 - precision: 0.7592 - recall: 0.7592 - auc: 0.8321 - f1_score: 0.7592 - val_loss: 0.8077 - val_accuracy: 0.5799 - val_precision: 0.5799 - val_recall: 0.5799 - val_auc: 0.5638 - val_f1_score: 0.5799 - lr: 0.0010
# Epoch 13/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6363 - accuracy: 0.7477 - precision: 0.7477 - recall: 0.7477 - auc: 0.8121 - f1_score: 0.7477
# Epoch 13: val_loss did not improve from 0.46044
# 71/71 [==============================] - 53s 734ms/step - loss: 0.6363 - accuracy: 0.7477 - precision: 0.7477 - recall: 0.7477 - auc: 0.8121 - f1_score: 0.7477 - val_loss: 0.4986 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9505 - val_f1_score: 0.8639 - lr: 0.0010
# Epoch 14/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5900 - accuracy: 0.7746 - precision: 0.7746 - recall: 0.7746 - auc: 0.8466 - f1_score: 0.7746
# Epoch 14: val_loss did not improve from 0.46044
# 71/71 [==============================] - 52s 729ms/step - loss: 0.5900 - accuracy: 0.7746 - precision: 0.7746 - recall: 0.7746 - auc: 0.8466 - f1_score: 0.7746 - val_loss: 0.4839 - val_accuracy: 0.8225 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.9323 - val_f1_score: 0.8225 - lr: 0.0010
# Epoch 15/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5600 - accuracy: 0.7901 - precision: 0.7901 - recall: 0.7901 - auc: 0.8662 - f1_score: 0.7901
# Epoch 15: val_loss did not improve from 0.46044
# 71/71 [==============================] - 52s 722ms/step - loss: 0.5600 - accuracy: 0.7901 - precision: 0.7901 - recall: 0.7901 - auc: 0.8662 - f1_score: 0.7901 - val_loss: 0.5490 - val_accuracy: 0.7751 - val_precision: 0.7751 - val_recall: 0.7751 - val_auc: 0.9016 - val_f1_score: 0.7751 - lr: 0.0010
# Epoch 16/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5891 - accuracy: 0.7870 - precision: 0.7870 - recall: 0.7870 - auc: 0.8458 - f1_score: 0.7870
# Epoch 16: val_loss did not improve from 0.46044
# 71/71 [==============================] - 52s 724ms/step - loss: 0.5891 - accuracy: 0.7870 - precision: 0.7870 - recall: 0.7870 - auc: 0.8458 - f1_score: 0.7870 - val_loss: 0.4684 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.9347 - val_f1_score: 0.8166 - lr: 0.0010
# Epoch 17/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5677 - accuracy: 0.7883 - precision: 0.7883 - recall: 0.7883 - auc: 0.8598 - f1_score: 0.7883
# Epoch 17: val_loss did not improve from 0.46044
# 71/71 [==============================] - 52s 724ms/step - loss: 0.5677 - accuracy: 0.7883 - precision: 0.7883 - recall: 0.7883 - auc: 0.8598 - f1_score: 0.7883 - val_loss: 0.5128 - val_accuracy: 0.7840 - val_precision: 0.7840 - val_recall: 0.7840 - val_auc: 0.9150 - val_f1_score: 0.7840 - lr: 0.0010
# Epoch 18/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5654 - accuracy: 0.7777 - precision: 0.7777 - recall: 0.7777 - auc: 0.8614 - f1_score: 0.7777
# Epoch 18: val_loss did not improve from 0.46044
# 71/71 [==============================] - 52s 730ms/step - loss: 0.5654 - accuracy: 0.7777 - precision: 0.7777 - recall: 0.7777 - auc: 0.8614 - f1_score: 0.7777 - val_loss: 0.4918 - val_accuracy: 0.8107 - val_precision: 0.8107 - val_recall: 0.8107 - val_auc: 0.9191 - val_f1_score: 0.8107 - lr: 0.0010
# Epoch 19/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5851 - accuracy: 0.7720 - precision: 0.7720 - recall: 0.7720 - auc: 0.8494 - f1_score: 0.7720
# Epoch 19: val_loss did not improve from 0.46044
# 71/71 [==============================] - 52s 726ms/step - loss: 0.5851 - accuracy: 0.7720 - precision: 0.7720 - recall: 0.7720 - auc: 0.8494 - f1_score: 0.7720 - val_loss: 0.4725 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9249 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 20/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5937 - accuracy: 0.7715 - precision: 0.7715 - recall: 0.7715 - auc: 0.8407 - f1_score: 0.7715
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 20: val_loss did not improve from 0.46044
# 71/71 [==============================] - 53s 736ms/step - loss: 0.5937 - accuracy: 0.7715 - precision: 0.7715 - recall: 0.7715 - auc: 0.8407 - f1_score: 0.7715 - val_loss: 0.4861 - val_accuracy: 0.7988 - val_precision: 0.7988 - val_recall: 0.7988 - val_auc: 0.9158 - val_f1_score: 0.7988 - lr: 0.0010
# Epoch 21/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5493 - accuracy: 0.7945 - precision: 0.7945 - recall: 0.7945 - auc: 0.8709 - f1_score: 0.7945
# Epoch 21: val_loss improved from 0.46044 to 0.44951, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 53s 737ms/step - loss: 0.5493 - accuracy: 0.7945 - precision: 0.7945 - recall: 0.7945 - auc: 0.8709 - f1_score: 0.7945 - val_loss: 0.4495 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9397 - val_f1_score: 0.8876 - lr: 1.0000e-04
# Epoch 22/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5394 - accuracy: 0.7989 - precision: 0.7989 - recall: 0.7989 - auc: 0.8765 - f1_score: 0.7989
# Epoch 22: val_loss did not improve from 0.44951
# 71/71 [==============================] - 52s 731ms/step - loss: 0.5394 - accuracy: 0.7989 - precision: 0.7989 - recall: 0.7989 - auc: 0.8765 - f1_score: 0.7989 - val_loss: 0.4680 - val_accuracy: 0.8225 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.9325 - val_f1_score: 0.8225 - lr: 1.0000e-04
# Epoch 23/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5324 - accuracy: 0.8029 - precision: 0.8029 - recall: 0.8029 - auc: 0.8814 - f1_score: 0.8029
# Epoch 23: val_loss improved from 0.44951 to 0.41816, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 52s 727ms/step - loss: 0.5324 - accuracy: 0.8029 - precision: 0.8029 - recall: 0.8029 - auc: 0.8814 - f1_score: 0.8029 - val_loss: 0.4182 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9494 - val_f1_score: 0.8935 - lr: 1.0000e-04
# Epoch 24/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5303 - accuracy: 0.7994 - precision: 0.7994 - recall: 0.7994 - auc: 0.8815 - f1_score: 0.7994
# Epoch 24: val_loss did not improve from 0.41816
# 71/71 [==============================] - 52s 726ms/step - loss: 0.5303 - accuracy: 0.7994 - precision: 0.7994 - recall: 0.7994 - auc: 0.8815 - f1_score: 0.7994 - val_loss: 0.4539 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9385 - val_f1_score: 0.8402 - lr: 1.0000e-04
# Epoch 25/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5189 - accuracy: 0.8144 - precision: 0.8144 - recall: 0.8144 - auc: 0.8893 - f1_score: 0.8144
# Epoch 25: val_loss did not improve from 0.41816
# 71/71 [==============================] - 51s 716ms/step - loss: 0.5189 - accuracy: 0.8144 - precision: 0.8144 - recall: 0.8144 - auc: 0.8893 - f1_score: 0.8144 - val_loss: 0.4315 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9465 - val_f1_score: 0.8639 - lr: 1.0000e-04
# Epoch 26/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5232 - accuracy: 0.7998 - precision: 0.7998 - recall: 0.7998 - auc: 0.8863 - f1_score: 0.7998
# Epoch 26: val_loss did not improve from 0.41816
# 71/71 [==============================] - 52s 719ms/step - loss: 0.5232 - accuracy: 0.7998 - precision: 0.7998 - recall: 0.7998 - auc: 0.8863 - f1_score: 0.7998 - val_loss: 0.4197 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9533 - val_f1_score: 0.8846 - lr: 1.0000e-04
# Epoch 27/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5174 - accuracy: 0.8109 - precision: 0.8109 - recall: 0.8109 - auc: 0.8887 - f1_score: 0.8109
# Epoch 27: val_loss did not improve from 0.41816
# 71/71 [==============================] - 51s 716ms/step - loss: 0.5174 - accuracy: 0.8109 - precision: 0.8109 - recall: 0.8109 - auc: 0.8887 - f1_score: 0.8109 - val_loss: 0.5379 - val_accuracy: 0.7692 - val_precision: 0.7692 - val_recall: 0.7692 - val_auc: 0.8937 - val_f1_score: 0.7692 - lr: 1.0000e-04
# Epoch 28/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5172 - accuracy: 0.8069 - precision: 0.8069 - recall: 0.8069 - auc: 0.8901 - f1_score: 0.8069
# Epoch 28: val_loss did not improve from 0.41816
# 71/71 [==============================] - 51s 716ms/step - loss: 0.5172 - accuracy: 0.8069 - precision: 0.8069 - recall: 0.8069 - auc: 0.8901 - f1_score: 0.8069 - val_loss: 0.4443 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9432 - val_f1_score: 0.8402 - lr: 1.0000e-04
# Epoch 29/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5144 - accuracy: 0.8109 - precision: 0.8109 - recall: 0.8109 - auc: 0.8905 - f1_score: 0.8109
# Epoch 29: val_loss did not improve from 0.41816
# 71/71 [==============================] - 52s 724ms/step - loss: 0.5144 - accuracy: 0.8109 - precision: 0.8109 - recall: 0.8109 - auc: 0.8905 - f1_score: 0.8109 - val_loss: 0.4757 - val_accuracy: 0.8107 - val_precision: 0.8107 - val_recall: 0.8107 - val_auc: 0.9242 - val_f1_score: 0.8107 - lr: 1.0000e-04
# Epoch 30/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5183 - accuracy: 0.8140 - precision: 0.8140 - recall: 0.8140 - auc: 0.8884 - f1_score: 0.8140
# Epoch 30: val_loss did not improve from 0.41816
# 71/71 [==============================] - 52s 727ms/step - loss: 0.5183 - accuracy: 0.8140 - precision: 0.8140 - recall: 0.8140 - auc: 0.8884 - f1_score: 0.8140 - val_loss: 0.4852 - val_accuracy: 0.8107 - val_precision: 0.8107 - val_recall: 0.8107 - val_auc: 0.9222 - val_f1_score: 0.8107 - lr: 1.0000e-04
# Epoch 31/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5131 - accuracy: 0.8078 - precision: 0.8078 - recall: 0.8078 - auc: 0.8909 - f1_score: 0.8078
# Epoch 31: val_loss improved from 0.41816 to 0.41006, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 52s 732ms/step - loss: 0.5131 - accuracy: 0.8078 - precision: 0.8078 - recall: 0.8078 - auc: 0.8909 - f1_score: 0.8078 - val_loss: 0.4101 - val_accuracy: 0.8669 - val_precision: 0.8669 - val_recall: 0.8669 - val_auc: 0.9523 - val_f1_score: 0.8669 - lr: 1.0000e-04
# Epoch 32/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5117 - accuracy: 0.8126 - precision: 0.8126 - recall: 0.8126 - auc: 0.8926 - f1_score: 0.8126
# Epoch 32: val_loss did not improve from 0.41006
# 71/71 [==============================] - 52s 722ms/step - loss: 0.5117 - accuracy: 0.8126 - precision: 0.8126 - recall: 0.8126 - auc: 0.8926 - f1_score: 0.8126 - val_loss: 0.4165 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9563 - val_f1_score: 0.8964 - lr: 1.0000e-04
# Epoch 33/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5114 - accuracy: 0.8118 - precision: 0.8118 - recall: 0.8118 - auc: 0.8922 - f1_score: 0.8118
# Epoch 33: val_loss did not improve from 0.41006
# 71/71 [==============================] - 52s 732ms/step - loss: 0.5114 - accuracy: 0.8118 - precision: 0.8118 - recall: 0.8118 - auc: 0.8922 - f1_score: 0.8118 - val_loss: 0.4430 - val_accuracy: 0.8491 - val_precision: 0.8491 - val_recall: 0.8491 - val_auc: 0.9436 - val_f1_score: 0.8491 - lr: 1.0000e-04
# Epoch 34/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5005 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.8987 - f1_score: 0.8197
# Epoch 34: val_loss did not improve from 0.41006
# 71/71 [==============================] - 52s 729ms/step - loss: 0.5005 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.8987 - f1_score: 0.8197 - val_loss: 0.4417 - val_accuracy: 0.8254 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.9357 - val_f1_score: 0.8254 - lr: 1.0000e-04
# Epoch 35/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.8210 - precision: 0.8210 - recall: 0.8210 - auc: 0.8923 - f1_score: 0.8210
# Epoch 35: val_loss did not improve from 0.41006
# 71/71 [==============================] - 51s 716ms/step - loss: 0.5098 - accuracy: 0.8210 - precision: 0.8210 - recall: 0.8210 - auc: 0.8923 - f1_score: 0.8210 - val_loss: 0.4437 - val_accuracy: 0.8343 - val_precision: 0.8343 - val_recall: 0.8343 - val_auc: 0.9401 - val_f1_score: 0.8343 - lr: 1.0000e-04
# Epoch 36/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5106 - accuracy: 0.8073 - precision: 0.8073 - recall: 0.8073 - auc: 0.8924 - f1_score: 0.8073
# Epoch 36: val_loss improved from 0.41006 to 0.40763, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 52s 723ms/step - loss: 0.5106 - accuracy: 0.8073 - precision: 0.8073 - recall: 0.8073 - auc: 0.8924 - f1_score: 0.8073 - val_loss: 0.4076 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9697 - val_f1_score: 0.9083 - lr: 1.0000e-04
# Epoch 37/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5078 - accuracy: 0.8184 - precision: 0.8184 - recall: 0.8184 - auc: 0.8937 - f1_score: 0.8184
# Epoch 37: val_loss did not improve from 0.40763
# 71/71 [==============================] - 52s 723ms/step - loss: 0.5078 - accuracy: 0.8184 - precision: 0.8184 - recall: 0.8184 - auc: 0.8937 - f1_score: 0.8184 - val_loss: 0.4692 - val_accuracy: 0.8077 - val_precision: 0.8077 - val_recall: 0.8077 - val_auc: 0.9292 - val_f1_score: 0.8077 - lr: 1.0000e-04
# Epoch 38/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4987 - accuracy: 0.8210 - precision: 0.8210 - recall: 0.8210 - auc: 0.8987 - f1_score: 0.8210
# Epoch 38: val_loss improved from 0.40763 to 0.36964, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 52s 726ms/step - loss: 0.4987 - accuracy: 0.8210 - precision: 0.8210 - recall: 0.8210 - auc: 0.8987 - f1_score: 0.8210 - val_loss: 0.3696 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9669 - val_f1_score: 0.9024 - lr: 1.0000e-04
# Epoch 39/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5107 - accuracy: 0.8095 - precision: 0.8095 - recall: 0.8095 - auc: 0.8919 - f1_score: 0.8095
# Epoch 39: val_loss did not improve from 0.36964
# 71/71 [==============================] - 52s 721ms/step - loss: 0.5107 - accuracy: 0.8095 - precision: 0.8095 - recall: 0.8095 - auc: 0.8919 - f1_score: 0.8095 - val_loss: 0.3908 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9624 - val_f1_score: 0.8905 - lr: 1.0000e-04
# Epoch 40/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4972 - accuracy: 0.8171 - precision: 0.8171 - recall: 0.8171 - auc: 0.8993 - f1_score: 0.8171
# Epoch 40: val_loss did not improve from 0.36964
# 71/71 [==============================] - 52s 727ms/step - loss: 0.4972 - accuracy: 0.8171 - precision: 0.8171 - recall: 0.8171 - auc: 0.8993 - f1_score: 0.8171 - val_loss: 0.3970 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9669 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 41/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5030 - accuracy: 0.8232 - precision: 0.8232 - recall: 0.8232 - auc: 0.8957 - f1_score: 0.8232
# Epoch 41: val_loss did not improve from 0.36964
# 71/71 [==============================] - 51s 718ms/step - loss: 0.5030 - accuracy: 0.8232 - precision: 0.8232 - recall: 0.8232 - auc: 0.8957 - f1_score: 0.8232 - val_loss: 0.4134 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9501 - val_f1_score: 0.8787 - lr: 1.0000e-04
# Epoch 42/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4973 - accuracy: 0.8259 - precision: 0.8259 - recall: 0.8259 - auc: 0.8988 - f1_score: 0.8259
# Epoch 42: val_loss did not improve from 0.36964
# 71/71 [==============================] - 52s 723ms/step - loss: 0.4973 - accuracy: 0.8259 - precision: 0.8259 - recall: 0.8259 - auc: 0.8988 - f1_score: 0.8259 - val_loss: 0.3804 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9705 - val_f1_score: 0.9290 - lr: 1.0000e-04
# Epoch 43/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5028 - accuracy: 0.8224 - precision: 0.8224 - recall: 0.8224 - auc: 0.8954 - f1_score: 0.8224
# Epoch 43: val_loss did not improve from 0.36964
# 71/71 [==============================] - 51s 712ms/step - loss: 0.5028 - accuracy: 0.8224 - precision: 0.8224 - recall: 0.8224 - auc: 0.8954 - f1_score: 0.8224 - val_loss: 0.4096 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9520 - val_f1_score: 0.8639 - lr: 1.0000e-04
# Epoch 44/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.8983 - f1_score: 0.8197
# Epoch 44: val_loss did not improve from 0.36964
# 71/71 [==============================] - 51s 718ms/step - loss: 0.4994 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.8983 - f1_score: 0.8197 - val_loss: 0.4026 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9637 - val_f1_score: 0.9024 - lr: 1.0000e-04
# Epoch 45/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4967 - accuracy: 0.8210 - precision: 0.8210 - recall: 0.8210 - auc: 0.8993 - f1_score: 0.8210
# Epoch 45: val_loss did not improve from 0.36964
# 71/71 [==============================] - 52s 733ms/step - loss: 0.4967 - accuracy: 0.8210 - precision: 0.8210 - recall: 0.8210 - auc: 0.8993 - f1_score: 0.8210 - val_loss: 0.4313 - val_accuracy: 0.8491 - val_precision: 0.8491 - val_recall: 0.8491 - val_auc: 0.9378 - val_f1_score: 0.8491 - lr: 1.0000e-04
# Epoch 46/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5041 - accuracy: 0.8202 - precision: 0.8202 - recall: 0.8202 - auc: 0.8954 - f1_score: 0.8202
# Epoch 46: val_loss did not improve from 0.36964
# 71/71 [==============================] - 52s 722ms/step - loss: 0.5041 - accuracy: 0.8202 - precision: 0.8202 - recall: 0.8202 - auc: 0.8954 - f1_score: 0.8202 - val_loss: 0.4209 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9521 - val_f1_score: 0.8580 - lr: 1.0000e-04
# Epoch 47/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4957 - accuracy: 0.8268 - precision: 0.8268 - recall: 0.8268 - auc: 0.8991 - f1_score: 0.8268
# Epoch 47: val_loss did not improve from 0.36964
# 71/71 [==============================] - 52s 731ms/step - loss: 0.4957 - accuracy: 0.8268 - precision: 0.8268 - recall: 0.8268 - auc: 0.8991 - f1_score: 0.8268 - val_loss: 0.4446 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9387 - val_f1_score: 0.8550 - lr: 1.0000e-04
# Epoch 48/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5044 - accuracy: 0.8109 - precision: 0.8109 - recall: 0.8109 - auc: 0.8949 - f1_score: 0.8109
# Epoch 48: val_loss improved from 0.36964 to 0.35914, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 52s 730ms/step - loss: 0.5044 - accuracy: 0.8109 - precision: 0.8109 - recall: 0.8109 - auc: 0.8949 - f1_score: 0.8109 - val_loss: 0.3591 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9628 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 49/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4964 - accuracy: 0.8237 - precision: 0.8237 - recall: 0.8237 - auc: 0.8987 - f1_score: 0.8237
# Epoch 49: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 712ms/step - loss: 0.4964 - accuracy: 0.8237 - precision: 0.8237 - recall: 0.8237 - auc: 0.8987 - f1_score: 0.8237 - val_loss: 0.3984 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9708 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 50/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4931 - accuracy: 0.8259 - precision: 0.8259 - recall: 0.8259 - auc: 0.9007 - f1_score: 0.8259
# Epoch 50: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 717ms/step - loss: 0.4931 - accuracy: 0.8259 - precision: 0.8259 - recall: 0.8259 - auc: 0.9007 - f1_score: 0.8259 - val_loss: 0.4096 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9554 - val_f1_score: 0.8787 - lr: 1.0000e-04
# Epoch 51/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5038 - accuracy: 0.8153 - precision: 0.8153 - recall: 0.8153 - auc: 0.8944 - f1_score: 0.8153
# Epoch 51: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 724ms/step - loss: 0.5038 - accuracy: 0.8153 - precision: 0.8153 - recall: 0.8153 - auc: 0.8944 - f1_score: 0.8153 - val_loss: 0.4212 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9595 - val_f1_score: 0.8817 - lr: 1.0000e-04
# Epoch 52/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4931 - accuracy: 0.8232 - precision: 0.8232 - recall: 0.8232 - auc: 0.9002 - f1_score: 0.8232
# Epoch 52: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 721ms/step - loss: 0.4931 - accuracy: 0.8232 - precision: 0.8232 - recall: 0.8232 - auc: 0.9002 - f1_score: 0.8232 - val_loss: 0.3678 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9706 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 53/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4980 - accuracy: 0.8144 - precision: 0.8144 - recall: 0.8144 - auc: 0.8975 - f1_score: 0.8144
# Epoch 53: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 718ms/step - loss: 0.4980 - accuracy: 0.8144 - precision: 0.8144 - recall: 0.8144 - auc: 0.8975 - f1_score: 0.8144 - val_loss: 0.3785 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9665 - val_f1_score: 0.8935 - lr: 1.0000e-04
# Epoch 54/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4904 - accuracy: 0.8259 - precision: 0.8259 - recall: 0.8259 - auc: 0.9017 - f1_score: 0.8259
# Epoch 54: val_loss did not improve from 0.35914
# 71/71 [==============================] - 53s 734ms/step - loss: 0.4904 - accuracy: 0.8259 - precision: 0.8259 - recall: 0.8259 - auc: 0.9017 - f1_score: 0.8259 - val_loss: 0.4188 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9556 - val_f1_score: 0.8757 - lr: 1.0000e-04
# Epoch 55/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5006 - accuracy: 0.8166 - precision: 0.8166 - recall: 0.8166 - auc: 0.8963 - f1_score: 0.8166
# Epoch 55: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 718ms/step - loss: 0.5006 - accuracy: 0.8166 - precision: 0.8166 - recall: 0.8166 - auc: 0.8963 - f1_score: 0.8166 - val_loss: 0.3744 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9641 - val_f1_score: 0.8905 - lr: 1.0000e-04
# Epoch 56/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4867 - accuracy: 0.8312 - precision: 0.8312 - recall: 0.8312 - auc: 0.9031 - f1_score: 0.8312
# Epoch 56: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 725ms/step - loss: 0.4867 - accuracy: 0.8312 - precision: 0.8312 - recall: 0.8312 - auc: 0.9031 - f1_score: 0.8312 - val_loss: 0.3986 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9517 - val_f1_score: 0.8550 - lr: 1.0000e-04
# Epoch 57/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4903 - accuracy: 0.8277 - precision: 0.8277 - recall: 0.8277 - auc: 0.9008 - f1_score: 0.8277
# Epoch 57: val_loss did not improve from 0.35914
# 71/71 [==============================] - 53s 735ms/step - loss: 0.4903 - accuracy: 0.8277 - precision: 0.8277 - recall: 0.8277 - auc: 0.9008 - f1_score: 0.8277 - val_loss: 0.3685 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9579 - val_f1_score: 0.8846 - lr: 1.0000e-04
# Epoch 58/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4899 - accuracy: 0.8277 - precision: 0.8277 - recall: 0.8277 - auc: 0.9015 - f1_score: 0.8277
# Epoch 58: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 58: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 721ms/step - loss: 0.4899 - accuracy: 0.8277 - precision: 0.8277 - recall: 0.8277 - auc: 0.9015 - f1_score: 0.8277 - val_loss: 0.3808 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9657 - val_f1_score: 0.9024 - lr: 1.0000e-04
# Epoch 59/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4791 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - auc: 0.9067 - f1_score: 0.8325
# Epoch 59: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 717ms/step - loss: 0.4791 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - auc: 0.9067 - f1_score: 0.8325 - val_loss: 0.3839 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9633 - val_f1_score: 0.8817 - lr: 1.0000e-05
# Epoch 60/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4735 - accuracy: 0.8334 - precision: 0.8334 - recall: 0.8334 - auc: 0.9098 - f1_score: 0.8334
# Epoch 60: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 727ms/step - loss: 0.4735 - accuracy: 0.8334 - precision: 0.8334 - recall: 0.8334 - auc: 0.9098 - f1_score: 0.8334 - val_loss: 0.3748 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9625 - val_f1_score: 0.8905 - lr: 1.0000e-05
# Epoch 61/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4800 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - auc: 0.9063 - f1_score: 0.8325
# Epoch 61: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 732ms/step - loss: 0.4800 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - auc: 0.9063 - f1_score: 0.8325 - val_loss: 0.3839 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9649 - val_f1_score: 0.9053 - lr: 1.0000e-05
# Epoch 62/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4807 - accuracy: 0.8330 - precision: 0.8330 - recall: 0.8330 - auc: 0.9057 - f1_score: 0.8330
# Epoch 62: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 729ms/step - loss: 0.4807 - accuracy: 0.8330 - precision: 0.8330 - recall: 0.8330 - auc: 0.9057 - f1_score: 0.8330 - val_loss: 0.3845 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9624 - val_f1_score: 0.8935 - lr: 1.0000e-05
# Epoch 63/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4758 - accuracy: 0.8396 - precision: 0.8396 - recall: 0.8396 - auc: 0.9082 - f1_score: 0.8396
# Epoch 63: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 718ms/step - loss: 0.4758 - accuracy: 0.8396 - precision: 0.8396 - recall: 0.8396 - auc: 0.9082 - f1_score: 0.8396 - val_loss: 0.3810 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9610 - val_f1_score: 0.8994 - lr: 1.0000e-05
# Epoch 64/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4806 - accuracy: 0.8277 - precision: 0.8277 - recall: 0.8277 - auc: 0.9064 - f1_score: 0.8277
# Epoch 64: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 727ms/step - loss: 0.4806 - accuracy: 0.8277 - precision: 0.8277 - recall: 0.8277 - auc: 0.9064 - f1_score: 0.8277 - val_loss: 0.3609 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9721 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 65/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4740 - accuracy: 0.8365 - precision: 0.8365 - recall: 0.8365 - auc: 0.9094 - f1_score: 0.8365
# Epoch 65: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 719ms/step - loss: 0.4740 - accuracy: 0.8365 - precision: 0.8365 - recall: 0.8365 - auc: 0.9094 - f1_score: 0.8365 - val_loss: 0.3701 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9710 - val_f1_score: 0.8994 - lr: 1.0000e-05
# Epoch 66/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4755 - accuracy: 0.8378 - precision: 0.8378 - recall: 0.8378 - auc: 0.9083 - f1_score: 0.8378
# Epoch 66: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 724ms/step - loss: 0.4755 - accuracy: 0.8378 - precision: 0.8378 - recall: 0.8378 - auc: 0.9083 - f1_score: 0.8378 - val_loss: 0.3931 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9559 - val_f1_score: 0.8935 - lr: 1.0000e-05
# Epoch 67/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4758 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.9088 - f1_score: 0.8374
# Epoch 67: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 712ms/step - loss: 0.4758 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.9088 - f1_score: 0.8374 - val_loss: 0.3956 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9592 - val_f1_score: 0.8728 - lr: 1.0000e-05
# Epoch 68/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4790 - accuracy: 0.8334 - precision: 0.8334 - recall: 0.8334 - auc: 0.9065 - f1_score: 0.8334
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 68: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 712ms/step - loss: 0.4790 - accuracy: 0.8334 - precision: 0.8334 - recall: 0.8334 - auc: 0.9065 - f1_score: 0.8334 - val_loss: 0.3730 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9662 - val_f1_score: 0.9024 - lr: 1.0000e-05
# Epoch 69/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4775 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.9076 - f1_score: 0.8294
# Epoch 69: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 720ms/step - loss: 0.4775 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.9076 - f1_score: 0.8294 - val_loss: 0.3845 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9666 - val_f1_score: 0.9053 - lr: 1.0000e-05
# Epoch 70/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4776 - accuracy: 0.8321 - precision: 0.8321 - recall: 0.8321 - auc: 0.9075 - f1_score: 0.8321
# Epoch 70: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 714ms/step - loss: 0.4776 - accuracy: 0.8321 - precision: 0.8321 - recall: 0.8321 - auc: 0.9075 - f1_score: 0.8321 - val_loss: 0.3733 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9674 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 71/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4758 - accuracy: 0.8343 - precision: 0.8343 - recall: 0.8343 - auc: 0.9083 - f1_score: 0.8343
# Epoch 71: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 713ms/step - loss: 0.4758 - accuracy: 0.8343 - precision: 0.8343 - recall: 0.8343 - auc: 0.9083 - f1_score: 0.8343 - val_loss: 0.3736 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9654 - val_f1_score: 0.8964 - lr: 1.0000e-05
# Epoch 72/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4761 - accuracy: 0.8352 - precision: 0.8352 - recall: 0.8352 - auc: 0.9083 - f1_score: 0.8352
# Epoch 72: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 706ms/step - loss: 0.4761 - accuracy: 0.8352 - precision: 0.8352 - recall: 0.8352 - auc: 0.9083 - f1_score: 0.8352 - val_loss: 0.3879 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9583 - val_f1_score: 0.8876 - lr: 1.0000e-05
# Epoch 73/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4769 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9079 - f1_score: 0.8369
# Epoch 73: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 720ms/step - loss: 0.4769 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9079 - f1_score: 0.8369 - val_loss: 0.3790 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9631 - val_f1_score: 0.9024 - lr: 1.0000e-05
# Epoch 74/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4803 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.9060 - f1_score: 0.8294
# Epoch 74: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 724ms/step - loss: 0.4803 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.9060 - f1_score: 0.8294 - val_loss: 0.3665 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9679 - val_f1_score: 0.8905 - lr: 1.0000e-05
# Epoch 75/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4767 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9078 - f1_score: 0.8369
# Epoch 75: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 714ms/step - loss: 0.4767 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9078 - f1_score: 0.8369 - val_loss: 0.3870 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9571 - val_f1_score: 0.8935 - lr: 1.0000e-05
# Epoch 76/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4779 - accuracy: 0.8347 - precision: 0.8347 - recall: 0.8347 - auc: 0.9071 - f1_score: 0.8347
# Epoch 76: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 722ms/step - loss: 0.4779 - accuracy: 0.8347 - precision: 0.8347 - recall: 0.8347 - auc: 0.9071 - f1_score: 0.8347 - val_loss: 0.3902 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9589 - val_f1_score: 0.8935 - lr: 1.0000e-05
# Epoch 77/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4741 - accuracy: 0.8321 - precision: 0.8321 - recall: 0.8321 - auc: 0.9090 - f1_score: 0.8321
# Epoch 77: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 720ms/step - loss: 0.4741 - accuracy: 0.8321 - precision: 0.8321 - recall: 0.8321 - auc: 0.9090 - f1_score: 0.8321 - val_loss: 0.4030 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9531 - val_f1_score: 0.8787 - lr: 1.0000e-05
# Epoch 78/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4721 - accuracy: 0.8392 - precision: 0.8392 - recall: 0.8392 - auc: 0.9103 - f1_score: 0.8392
# Epoch 78: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 714ms/step - loss: 0.4721 - accuracy: 0.8392 - precision: 0.8392 - recall: 0.8392 - auc: 0.9103 - f1_score: 0.8392 - val_loss: 0.3866 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9605 - val_f1_score: 0.8905 - lr: 1.0000e-05
# Epoch 79/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4702 - accuracy: 0.8361 - precision: 0.8361 - recall: 0.8361 - auc: 0.9110 - f1_score: 0.8361
# Epoch 79: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 715ms/step - loss: 0.4702 - accuracy: 0.8361 - precision: 0.8361 - recall: 0.8361 - auc: 0.9110 - f1_score: 0.8361 - val_loss: 0.3813 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9653 - val_f1_score: 0.9053 - lr: 1.0000e-05
# Epoch 80/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4766 - accuracy: 0.8387 - precision: 0.8387 - recall: 0.8387 - auc: 0.9074 - f1_score: 0.8387
# Epoch 80: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 725ms/step - loss: 0.4766 - accuracy: 0.8387 - precision: 0.8387 - recall: 0.8387 - auc: 0.9074 - f1_score: 0.8387 - val_loss: 0.3706 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9664 - val_f1_score: 0.8935 - lr: 1.0000e-05
# Epoch 81/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4749 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - auc: 0.9089 - f1_score: 0.8325
# Epoch 81: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 723ms/step - loss: 0.4749 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - auc: 0.9089 - f1_score: 0.8325 - val_loss: 0.3970 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9553 - val_f1_score: 0.8876 - lr: 1.0000e-05
# Epoch 82/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4727 - accuracy: 0.8347 - precision: 0.8347 - recall: 0.8347 - auc: 0.9096 - f1_score: 0.8347
# Epoch 82: val_loss did not improve from 0.35914
# 71/71 [==============================] - 53s 738ms/step - loss: 0.4727 - accuracy: 0.8347 - precision: 0.8347 - recall: 0.8347 - auc: 0.9096 - f1_score: 0.8347 - val_loss: 0.3657 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9693 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 83/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4760 - accuracy: 0.8361 - precision: 0.8361 - recall: 0.8361 - auc: 0.9081 - f1_score: 0.8361
# Epoch 83: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 730ms/step - loss: 0.4760 - accuracy: 0.8361 - precision: 0.8361 - recall: 0.8361 - auc: 0.9081 - f1_score: 0.8361 - val_loss: 0.3686 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9659 - val_f1_score: 0.8876 - lr: 1.0000e-05
# Epoch 84/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4740 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - auc: 0.9091 - f1_score: 0.8325
# Epoch 84: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 726ms/step - loss: 0.4740 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - auc: 0.9091 - f1_score: 0.8325 - val_loss: 0.3831 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9611 - val_f1_score: 0.8846 - lr: 1.0000e-05
# Epoch 85/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4735 - accuracy: 0.8321 - precision: 0.8321 - recall: 0.8321 - auc: 0.9094 - f1_score: 0.8321
# Epoch 85: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 729ms/step - loss: 0.4735 - accuracy: 0.8321 - precision: 0.8321 - recall: 0.8321 - auc: 0.9094 - f1_score: 0.8321 - val_loss: 0.3651 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9674 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 86/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4724 - accuracy: 0.8356 - precision: 0.8356 - recall: 0.8356 - auc: 0.9097 - f1_score: 0.8356
# Epoch 86: val_loss did not improve from 0.35914
# 71/71 [==============================] - 51s 723ms/step - loss: 0.4724 - accuracy: 0.8356 - precision: 0.8356 - recall: 0.8356 - auc: 0.9097 - f1_score: 0.8356 - val_loss: 0.3735 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9662 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 87/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4668 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.9125 - f1_score: 0.8374
# Epoch 87: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 729ms/step - loss: 0.4668 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.9125 - f1_score: 0.8374 - val_loss: 0.3632 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9666 - val_f1_score: 0.9024 - lr: 1.0000e-05
# Epoch 88/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4720 - accuracy: 0.8405 - precision: 0.8405 - recall: 0.8405 - auc: 0.9098 - f1_score: 0.8405
# Epoch 88: val_loss did not improve from 0.35914
# 71/71 [==============================] - 52s 723ms/step - loss: 0.4720 - accuracy: 0.8405 - precision: 0.8405 - recall: 0.8405 - auc: 0.9098 - f1_score: 0.8405 - val_loss: 0.4183 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9421 - val_f1_score: 0.8550 - lr: 1.0000e-05
# Epoch 89/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4707 - accuracy: 0.8392 - precision: 0.8392 - recall: 0.8392 - auc: 0.9105 - f1_score: 0.8392
# Epoch 89: val_loss did not improve from 0.35914
# ...
# Epoch 121/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4703 - accuracy: 0.8378 - precision: 0.8378 - recall: 0.8378 - auc: 0.9097 - f1_score: 0.8378
# Epoch 121: val_loss improved from 0.35530 to 0.35270, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 52s 730ms/step - loss: 0.4703 - accuracy: 0.8378 - precision: 0.8378 - recall: 0.8378 - auc: 0.9097 - f1_score: 0.8378 - val_loss: 0.3527 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9705 - val_f1_score: 0.9231 - lr: 1.0000e-05
# Epoch 122/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.8378 - precision: 0.8378 - recall: 0.8378 - auc: 0.9120 - f1_score: 0.8378
# Epoch 122: val_loss did not improve from 0.35270
# 71/71 [==============================] - 52s 722ms/step - loss: 0.4656 - accuracy: 0.8378 - precision: 0.8378 - recall: 0.8378 - auc: 0.9120 - f1_score: 0.8378 - val_loss: 0.4153 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9455 - val_f1_score: 0.8757 - lr: 1.0000e-05
# Epoch 123/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4672 - accuracy: 0.8436 - precision: 0.8436 - recall: 0.8436 - auc: 0.9113 - f1_score: 0.8436
# Epoch 123: val_loss did not improve from 0.35270
# 71/71 [==============================] - 53s 734ms/step - loss: 0.4672 - accuracy: 0.8436 - precision: 0.8436 - recall: 0.8436 - auc: 0.9113 - f1_score: 0.8436 - val_loss: 0.3574 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9684 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 124/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4676 - accuracy: 0.8387 - precision: 0.8387 - recall: 0.8387 - auc: 0.9107 - f1_score: 0.8387
# Epoch 124: val_loss did not improve from 0.35270
# 71/71 [==============================] - 51s 713ms/step - loss: 0.4676 - accuracy: 0.8387 - precision: 0.8387 - recall: 0.8387 - auc: 0.9107 - f1_score: 0.8387 - val_loss: 0.3716 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9691 - val_f1_score: 0.9231 - lr: 1.0000e-05
# Epoch 125/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4618 - accuracy: 0.8409 - precision: 0.8409 - recall: 0.8409 - auc: 0.9140 - f1_score: 0.8409
# Epoch 125: val_loss did not improve from 0.35270
# 71/71 [==============================] - 52s 731ms/step - loss: 0.4618 - accuracy: 0.8409 - precision: 0.8409 - recall: 0.8409 - auc: 0.9140 - f1_score: 0.8409 - val_loss: 0.3897 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9543 - val_f1_score: 0.8876 - lr: 1.0000e-05
# Epoch 126/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4654 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9119 - f1_score: 0.8369
# Epoch 126: val_loss did not improve from 0.35270
# 71/71 [==============================] - 51s 718ms/step - loss: 0.4654 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9119 - f1_score: 0.8369 - val_loss: 0.3966 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9546 - val_f1_score: 0.9053 - lr: 1.0000e-05
# Epoch 127/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4665 - accuracy: 0.8338 - precision: 0.8338 - recall: 0.8338 - auc: 0.9116 - f1_score: 0.8338
# Epoch 127: val_loss did not improve from 0.35270
# 71/71 [==============================] - 51s 718ms/step - loss: 0.4665 - accuracy: 0.8338 - precision: 0.8338 - recall: 0.8338 - auc: 0.9116 - f1_score: 0.8338 - val_loss: 0.3684 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9646 - val_f1_score: 0.8964 - lr: 1.0000e-05
# Epoch 128/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4687 - accuracy: 0.8343 - precision: 0.8343 - recall: 0.8343 - auc: 0.9102 - f1_score: 0.8343
# Epoch 128: val_loss did not improve from 0.35270
# 71/71 [==============================] - 52s 719ms/step - loss: 0.4687 - accuracy: 0.8343 - precision: 0.8343 - recall: 0.8343 - auc: 0.9102 - f1_score: 0.8343 - val_loss: 0.3978 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9516 - val_f1_score: 0.8580 - lr: 1.0000e-05
# Epoch 129/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4681 - accuracy: 0.8400 - precision: 0.8400 - recall: 0.8400 - auc: 0.9104 - f1_score: 0.8400
# Epoch 129: val_loss did not improve from 0.35270
# 71/71 [==============================] - 51s 719ms/step - loss: 0.4681 - accuracy: 0.8400 - precision: 0.8400 - recall: 0.8400 - auc: 0.9104 - f1_score: 0.8400 - val_loss: 0.3882 - val_accuracy: 0.8669 - val_precision: 0.8669 - val_recall: 0.8669 - val_auc: 0.9553 - val_f1_score: 0.8669 - lr: 1.0000e-05
# Epoch 130/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4654 - accuracy: 0.8356 - precision: 0.8356 - recall: 0.8356 - auc: 0.9121 - f1_score: 0.8356
# Epoch 130: val_loss did not improve from 0.35270
# 71/71 [==============================] - 52s 721ms/step - loss: 0.4654 - accuracy: 0.8356 - precision: 0.8356 - recall: 0.8356 - auc: 0.9121 - f1_score: 0.8356 - val_loss: 0.3698 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9690 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 131/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4665 - accuracy: 0.8338 - precision: 0.8338 - recall: 0.8338 - auc: 0.9115 - f1_score: 0.8338
# Epoch 131: val_loss did not improve from 0.35270
# 71/71 [==============================] - 52s 720ms/step - loss: 0.4665 - accuracy: 0.8338 - precision: 0.8338 - recall: 0.8338 - auc: 0.9115 - f1_score: 0.8338 - val_loss: 0.3923 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9583 - val_f1_score: 0.9024 - lr: 1.0000e-05
# Epoch 132/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4635 - accuracy: 0.8409 - precision: 0.8409 - recall: 0.8409 - auc: 0.9127 - f1_score: 0.8409
# Epoch 132: val_loss did not improve from 0.35270
# 71/71 [==============================] - 52s 724ms/step - loss: 0.4635 - accuracy: 0.8409 - precision: 0.8409 - recall: 0.8409 - auc: 0.9127 - f1_score: 0.8409 - val_loss: 0.3828 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9600 - val_f1_score: 0.8846 - lr: 1.0000e-05
# Epoch 133/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.8418 - precision: 0.8418 - recall: 0.8418 - auc: 0.9116 - f1_score: 0.8418
# Epoch 133: val_loss improved from 0.35270 to 0.33275, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version911-DIR.h5
# 71/71 [==============================] - 52s 731ms/step - loss: 0.4656 - accuracy: 0.8418 - precision: 0.8418 - recall: 0.8418 - auc: 0.9116 - f1_score: 0.8418 - val_loss: 0.3327 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9748 - val_f1_score: 0.9231 - lr: 1.0000e-05
# Epoch 134/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4657 - accuracy: 0.8352 - precision: 0.8352 - recall: 0.8352 - auc: 0.9117 - f1_score: 0.8352
# Epoch 134: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 721ms/step - loss: 0.4657 - accuracy: 0.8352 - precision: 0.8352 - recall: 0.8352 - auc: 0.9117 - f1_score: 0.8352 - val_loss: 0.3657 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9688 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 135/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.8414 - precision: 0.8414 - recall: 0.8414 - auc: 0.9126 - f1_score: 0.8414
# Epoch 135: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 724ms/step - loss: 0.4636 - accuracy: 0.8414 - precision: 0.8414 - recall: 0.8414 - auc: 0.9126 - f1_score: 0.8414 - val_loss: 0.3923 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9531 - val_f1_score: 0.8728 - lr: 1.0000e-05
# Epoch 136/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4661 - accuracy: 0.8418 - precision: 0.8418 - recall: 0.8418 - auc: 0.9111 - f1_score: 0.8418
# Epoch 136: val_loss did not improve from 0.33275
# 71/71 [==============================] - 51s 709ms/step - loss: 0.4661 - accuracy: 0.8418 - precision: 0.8418 - recall: 0.8418 - auc: 0.9111 - f1_score: 0.8418 - val_loss: 0.3700 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9657 - val_f1_score: 0.9024 - lr: 1.0000e-05
# Epoch 137/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4635 - accuracy: 0.8365 - precision: 0.8365 - recall: 0.8365 - auc: 0.9125 - f1_score: 0.8365
# Epoch 137: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 723ms/step - loss: 0.4635 - accuracy: 0.8365 - precision: 0.8365 - recall: 0.8365 - auc: 0.9125 - f1_score: 0.8365 - val_loss: 0.3464 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9720 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 138/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4605 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.9138 - f1_score: 0.8374
# Epoch 138: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 724ms/step - loss: 0.4605 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.9138 - f1_score: 0.8374 - val_loss: 0.3715 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9697 - val_f1_score: 0.9172 - lr: 1.0000e-05
# Epoch 139/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4635 - accuracy: 0.8383 - precision: 0.8383 - recall: 0.8383 - auc: 0.9123 - f1_score: 0.8383
# Epoch 139: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 725ms/step - loss: 0.4635 - accuracy: 0.8383 - precision: 0.8383 - recall: 0.8383 - auc: 0.9123 - f1_score: 0.8383 - val_loss: 0.3776 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9582 - val_f1_score: 0.8935 - lr: 1.0000e-05
# Epoch 140/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4634 - accuracy: 0.8396 - precision: 0.8396 - recall: 0.8396 - auc: 0.9123 - f1_score: 0.8396
# Epoch 140: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 724ms/step - loss: 0.4634 - accuracy: 0.8396 - precision: 0.8396 - recall: 0.8396 - auc: 0.9123 - f1_score: 0.8396 - val_loss: 0.3541 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9649 - val_f1_score: 0.8994 - lr: 1.0000e-05
# Epoch 141/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4627 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.9127 - f1_score: 0.8374
# Epoch 141: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 731ms/step - loss: 0.4627 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.9127 - f1_score: 0.8374 - val_loss: 0.3720 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9620 - val_f1_score: 0.8905 - lr: 1.0000e-05
# Epoch 142/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4606 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9137 - f1_score: 0.8369
# Epoch 142: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 722ms/step - loss: 0.4606 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9137 - f1_score: 0.8369 - val_loss: 0.3766 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9602 - val_f1_score: 0.9024 - lr: 1.0000e-05
# Epoch 143/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4605 - accuracy: 0.8392 - precision: 0.8392 - recall: 0.8392 - auc: 0.9136 - f1_score: 0.8392
# Epoch 143: val_loss did not improve from 0.33275
# 71/71 [==============================] - 53s 740ms/step - loss: 0.4605 - accuracy: 0.8392 - precision: 0.8392 - recall: 0.8392 - auc: 0.9136 - f1_score: 0.8392 - val_loss: 0.3530 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9708 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 144/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4646 - accuracy: 0.8383 - precision: 0.8383 - recall: 0.8383 - auc: 0.9115 - f1_score: 0.8383
# Epoch 144: val_loss did not improve from 0.33275
# 71/71 [==============================] - 51s 713ms/step - loss: 0.4646 - accuracy: 0.8383 - precision: 0.8383 - recall: 0.8383 - auc: 0.9115 - f1_score: 0.8383 - val_loss: 0.3909 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9550 - val_f1_score: 0.8846 - lr: 1.0000e-05
# Epoch 145/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4623 - accuracy: 0.8414 - precision: 0.8414 - recall: 0.8414 - auc: 0.9127 - f1_score: 0.8414
# Epoch 145: val_loss did not improve from 0.33275
# 71/71 [==============================] - 51s 714ms/step - loss: 0.4623 - accuracy: 0.8414 - precision: 0.8414 - recall: 0.8414 - auc: 0.9127 - f1_score: 0.8414 - val_loss: 0.3626 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9687 - val_f1_score: 0.8964 - lr: 1.0000e-05
# Epoch 146/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.8387 - precision: 0.8387 - recall: 0.8387 - auc: 0.9109 - f1_score: 0.8387
# Epoch 146: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 719ms/step - loss: 0.4656 - accuracy: 0.8387 - precision: 0.8387 - recall: 0.8387 - auc: 0.9109 - f1_score: 0.8387 - val_loss: 0.3717 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9610 - val_f1_score: 0.8876 - lr: 1.0000e-05
# Epoch 147/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4557 - accuracy: 0.8449 - precision: 0.8449 - recall: 0.8449 - auc: 0.9154 - f1_score: 0.8449
# Epoch 147: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 726ms/step - loss: 0.4557 - accuracy: 0.8449 - precision: 0.8449 - recall: 0.8449 - auc: 0.9154 - f1_score: 0.8449 - val_loss: 0.3985 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9485 - val_f1_score: 0.8787 - lr: 1.0000e-05
# Epoch 148/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4643 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9117 - f1_score: 0.8369
# Epoch 148: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 721ms/step - loss: 0.4643 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9117 - f1_score: 0.8369 - val_loss: 0.3545 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9707 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 149/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4636 - accuracy: 0.8312 - precision: 0.8312 - recall: 0.8312 - auc: 0.9118 - f1_score: 0.8312
# Epoch 149: val_loss did not improve from 0.33275
# 71/71 [==============================] - 52s 731ms/step - loss: 0.4636 - accuracy: 0.8312 - precision: 0.8312 - recall: 0.8312 - auc: 0.9118 - f1_score: 0.8312 - val_loss: 0.3596 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9674 - val_f1_score: 0.9053 - lr: 1.0000e-05
# Epoch 150/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4574 - accuracy: 0.8453 - precision: 0.8453 - recall: 0.8453 - auc: 0.9148 - f1_score: 0.8453
# Epoch 150: val_loss did not improve from 0.33275
# 71/71 [==============================] - 51s 719ms/step - loss: 0.4574 - accuracy: 0.8453 - precision: 0.8453 - recall: 0.8453 - auc: 0.9148 - f1_score: 0.8453 - val_loss: 0.3637 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9659 - val_f1_score: 0.9053 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

# plt.subplot(2, 3, 5)
# plt.plot(range(1, len(f1_score_callback.train_f1_scores) + 1), f1_score_callback.train_f1_scores, label='Training F1 Score')
# plt.plot(range(1, len(f1_score_callback.val_f1_scores) + 1), f1_score_callback.val_f1_scores, label='Validation F1 Score')
# plt.title('Model F1-Score')
# plt.xlabel('Epoch')
# plt.ylabel('F1-Score')
# plt.legend(['F1 Score'], loc='lower right')


plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = DIR.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 2s 117ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.8118729096989966
# F1-Score for each class: [0.75961538 0.86413043]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.8071065989847716
# specificity: 0.8681318681318682

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  DIR.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 1s 119ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = DIR.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)

# test_loss, test_acc, test_precision, test_recall, test_auc = DIR.evaluate(test_generator)
# print('Test loss:', test_loss)
# print('Test accuracy:', test_acc)
# print('Test precision:', test_precision)
# print('Test recall:', test_recall)
# print('Test AUC:', test_auc)


# from sklearn.metrics import f1_score
# import numpy as np

# # 预测测试集
# y_pred = DIR.predict(test_generator)
# y_pred = np.argmax(y_pred, axis=1)

# # 真实标签
# y_true = test_generator.classes

# # 计算F1分数
# test_f1_score = f1_score(y_true, y_pred, average='micro')  # 或者根据你的需要选择其他average参数
# print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 2s 160ms/step - loss: 0.5119 - accuracy: 0.8289 - precision: 0.8289 - recall: 0.8289 - auc: 0.8880 - f1_score: 0.8289
# Test loss: 0.5118513703346252
# Test accuracy: 0.8289473652839661
# Test precision: 0.8289473652839661
# Test recall: 0.8289473652839661
# Test AUC: 0.8880497813224792
# Test F1 Score: 0.8289473652839661

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = DIR.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 1s 119ms/step
#               precision    recall  f1-score   support
#
#            0       0.68      0.87      0.76        91
#            1       0.93      0.81      0.86       197
#
#     accuracy                           0.83       288
#    macro avg       0.80      0.84      0.81       288
# weighted avg       0.85      0.83      0.83       288

# %% [markdown]
# #delete the model to prevent memory costs
#
# from keras import backend as K
# import gc
#
# K.clear_session()
# gc.collect()
#
# # del DIR
#
#
# from numba import cuda
#
# cuda.select_device(0)
# cuda.close()
