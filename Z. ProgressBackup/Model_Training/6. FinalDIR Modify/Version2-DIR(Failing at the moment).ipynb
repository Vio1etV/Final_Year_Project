# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.
# Out:
# 2024-03-06 00:43:49.005306: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 298 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 4

def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32, (3, 3), strides = (1, 1), activation = 'leaky_relu',
               kernel_initializer='he_normal', padding='same')(x)
    x = attention_block_2(x)
    
    x = Conv2D(32, (3, 3), strides = (1, 1), activation = 'relu',
              kernel_initializer='he_normal', padding='same')(x)
    x = attention_block_2(x)
    
    x = Conv2D(64, (3, 3), strides = (1, 1), activation = 'relu',
              kernel_initializer='he_normal', padding='same')(x)
    x = attention_block_2(x)
    
    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(32, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])
    
    a = Conv2D(32, (1, 1), strides = (1, 1), activation = 'relu',
              kernel_initializer='he_normal', padding='same')(x)
    # x = attention_block_2(x)
    
    a = Conv2D(32, (1, 1), strides = (1, 1), activation = 'relu',padding='same')(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # x = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # x = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    
    x = Concatenate(axis=-1)([a, b])
    
    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(128, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    b = Conv2D(64, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    
    c = Conv2D(32, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(16, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    shortcut = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
                      kernel_initializer='he_normal', padding='same')(shortcut)
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    #Added
    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(32, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    b = Conv2D(32, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(32, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(32, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    
    b = Conv2D(32, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(128, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    shortcut = Conv2D(128, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(shortcut)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)

    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(64, (3, 3), strides=(1, 1), activation='relu',
            kernel_initializer='he_normal', padding='same')(x)
    
    b = Conv2D(32, (3, 3), strides=(1, 1), activation='relu',
            kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(32, (1, 1), strides=(1, 1), activation='relu',
            kernel_initializer='he_normal', padding='same')(b)
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    shortcut = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(shortcut)
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 2
num_B_blocks = 5
num_C_blocks = 2

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.5)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax')(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# 2024-03-06 00:43:52.362760: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-06 00:43:52.869902: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22309 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:04:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 96  27744       ['conv2d[0][0]']
#                                 )
#
#  activation (Activation)        (None, 224, 224, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 224, 224, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 224, 224, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 224, 224, 32  0           ['conv2d[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 224, 224, 32  9248        ['multiply[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 224, 224, 96  27744       ['conv2d_3[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 224, 224, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 224, 224, 1)  97          ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 224, 224, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 224, 224, 32  0           ['conv2d_3[0][0]',
#                                 )                                 'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 224, 224, 64  18496       ['multiply_1[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 224, 224, 96  55392       ['conv2d_6[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 224, 224, 96  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 224, 224, 1)  97          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 224, 224, 1)  0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 224, 224, 64  0           ['conv2d_6[0][0]',
#                                 )                                 'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 222, 222, 64  0           ['multiply_2[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 222, 222, 32  18464       ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 222, 222, 96  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 222, 222, 16  13840       ['concatenate[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 222, 222, 16  272         ['conv2d_12[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 222, 222, 32  3104        ['concatenate[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 222, 222, 16  272         ['conv2d_13[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 222, 222, 48  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 220, 220, 48  20784       ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 220, 220, 48  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 220, 220, 96  0           ['conv2d_15[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_6 (Activation)      (None, 220, 220, 96  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 220, 220, 64  6208        ['activation_6[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 220, 220, 32  3104        ['activation_6[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 220, 220, 12  12416       ['activation_6[0][0]']
#                                 8)
#
#  depthwise_conv2d (DepthwiseCon  (None, 220, 220, 64  640        ['conv2d_17[0][0]']
#  v2D)                           )
#
#  conv2d_19 (Conv2D)             (None, 220, 220, 16  4624        ['conv2d_18[0][0]']
#                                 )
#
#  concatenate_3 (Concatenate)    (None, 220, 220, 20  0           ['conv2d_16[0][0]',
#                                 8)                                'depthwise_conv2d[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 220, 220, 64  6208        ['activation_6[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 220, 220, 64  13376       ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 220, 220, 64  0           ['conv2d_21[0][0]',
#                                 )                                 'conv2d_20[0][0]']
#
#  activation_7 (Activation)      (None, 220, 220, 64  0           ['add[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 220, 220, 64  4160        ['activation_7[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 220, 220, 32  2080        ['activation_7[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 220, 220, 12  8320        ['activation_7[0][0]']
#                                 8)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 220, 220, 64  640        ['conv2d_23[0][0]']
#  onv2D)                         )
#
#  conv2d_25 (Conv2D)             (None, 220, 220, 16  4624        ['conv2d_24[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 220, 220, 20  0           ['conv2d_22[0][0]',
#                                 8)                                'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 220, 220, 64  4160        ['activation_7[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 220, 220, 64  13376       ['concatenate_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 220, 220, 64  0           ['conv2d_27[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  activation_8 (Activation)      (None, 220, 220, 64  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 220, 220, 64  4160        ['activation_8[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 220, 220, 64  36928       ['conv2d_29[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 110, 110, 64  0          ['activation_8[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 110, 110, 96  55392       ['activation_8[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 110, 110, 96  55392       ['conv2d_30[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 110, 110, 25  0           ['max_pooling2d_2[0][0]',
#                                 6)                                'conv2d_28[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 110, 110, 32  73760       ['concatenate_5[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_33[0][0]']
#                                 )
#
#  conv2d_35 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_34[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 110, 110, 32  73760       ['concatenate_5[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_35[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 110, 110, 64  0           ['conv2d_32[0][0]',
#                                 )                                 'conv2d_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 110, 110, 12  32896       ['concatenate_5[0][0]']
#                                 8)
#
#  conv2d_37 (Conv2D)             (None, 110, 110, 12  8320        ['concatenate_6[0][0]']
#                                 8)
#
#  add_2 (Add)                    (None, 110, 110, 12  0           ['conv2d_38[0][0]',
#                                 8)                                'conv2d_37[0][0]']
#
#  activation_9 (Activation)      (None, 110, 110, 12  0           ['add_2[0][0]']
#                                 8)
#
#  conv2d_40 (Conv2D)             (None, 110, 110, 32  36896       ['activation_9[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_40[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_41[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 110, 110, 32  36896       ['activation_9[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_42[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 110, 110, 64  0           ['conv2d_39[0][0]',
#                                 )                                 'conv2d_43[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 110, 110, 12  16512       ['activation_9[0][0]']
#                                 8)
#
#  conv2d_44 (Conv2D)             (None, 110, 110, 12  8320        ['concatenate_7[0][0]']
#                                 8)
#
#  add_3 (Add)                    (None, 110, 110, 12  0           ['conv2d_45[0][0]',
#                                 8)                                'conv2d_44[0][0]']
#
#  activation_10 (Activation)     (None, 110, 110, 12  0           ['add_3[0][0]']
#                                 8)
#
#  conv2d_47 (Conv2D)             (None, 110, 110, 32  36896       ['activation_10[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 110, 110, 32  36896       ['activation_10[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_49[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 110, 110, 64  0           ['conv2d_46[0][0]',
#                                 )                                 'conv2d_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 110, 110, 12  16512       ['activation_10[0][0]']
#                                 8)
#
#  conv2d_51 (Conv2D)             (None, 110, 110, 12  8320        ['concatenate_8[0][0]']
#                                 8)
#
#  add_4 (Add)                    (None, 110, 110, 12  0           ['conv2d_52[0][0]',
#                                 8)                                'conv2d_51[0][0]']
#
#  activation_11 (Activation)     (None, 110, 110, 12  0           ['add_4[0][0]']
#                                 8)
#
#  conv2d_54 (Conv2D)             (None, 110, 110, 32  36896       ['activation_11[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_55[0][0]']
#                                 )
#
#  conv2d_53 (Conv2D)             (None, 110, 110, 32  36896       ['activation_11[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_56[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 110, 110, 64  0           ['conv2d_53[0][0]',
#                                 )                                 'conv2d_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 110, 110, 12  16512       ['activation_11[0][0]']
#                                 8)
#
#  conv2d_58 (Conv2D)             (None, 110, 110, 12  8320        ['concatenate_9[0][0]']
#                                 8)
#
#  add_5 (Add)                    (None, 110, 110, 12  0           ['conv2d_59[0][0]',
#                                 8)                                'conv2d_58[0][0]']
#
#  activation_12 (Activation)     (None, 110, 110, 12  0           ['add_5[0][0]']
#                                 8)
#
#  conv2d_61 (Conv2D)             (None, 110, 110, 32  36896       ['activation_12[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_61[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_62[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 110, 110, 32  36896       ['activation_12[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 110, 110, 32  1056        ['conv2d_63[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 110, 110, 64  0           ['conv2d_60[0][0]',
#                                 )                                 'conv2d_64[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 110, 110, 12  16512       ['activation_12[0][0]']
#                                 8)
#
#  conv2d_65 (Conv2D)             (None, 110, 110, 12  8320        ['concatenate_10[0][0]']
#                                 8)
#
#  add_6 (Add)                    (None, 110, 110, 12  0           ['conv2d_66[0][0]',
#                                 8)                                'conv2d_65[0][0]']
#
#  activation_13 (Activation)     (None, 110, 110, 12  0           ['add_6[0][0]']
#                                 8)
#
#  conv2d_71 (Conv2D)             (None, 110, 110, 64  8256        ['activation_13[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 110, 110, 64  8256        ['activation_13[0][0]']
#                                 )
#
#  conv2d_69 (Conv2D)             (None, 110, 110, 64  8256        ['activation_13[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 110, 110, 72  41544       ['conv2d_71[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 54, 54, 128)  0          ['activation_13[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 54, 54, 72)   41544       ['conv2d_67[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 54, 54, 72)   41544       ['conv2d_69[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 54, 54, 80)   51920       ['conv2d_72[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 54, 54, 352)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_68[0][0]',
#                                                                   'conv2d_70[0][0]',
#                                                                   'conv2d_73[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 54, 54, 32)   101408      ['concatenate_11[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 54, 54, 64)   202816      ['concatenate_11[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 54, 54, 32)   1056        ['conv2d_75[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 54, 54, 96)   0           ['conv2d_74[0][0]',
#                                                                   'conv2d_76[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 54, 54, 32)   11296       ['concatenate_11[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 54, 54, 32)   3104        ['concatenate_12[0][0]']
#
#  add_7 (Add)                    (None, 54, 54, 32)   0           ['conv2d_78[0][0]',
#                                                                   'conv2d_77[0][0]']
#
#  activation_14 (Activation)     (None, 54, 54, 32)   0           ['add_7[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 54, 54, 32)   9248        ['activation_14[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 54, 54, 64)   18496       ['activation_14[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 54, 54, 32)   1056        ['conv2d_80[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 54, 54, 96)   0           ['conv2d_79[0][0]',
#                                                                   'conv2d_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 54, 54, 32)   1056        ['activation_14[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 54, 54, 32)   3104        ['concatenate_13[0][0]']
#
#  add_8 (Add)                    (None, 54, 54, 32)   0           ['conv2d_83[0][0]',
#                                                                   'conv2d_82[0][0]']
#
#  activation_15 (Activation)     (None, 54, 54, 32)   0           ['add_8[0][0]']
#
#  dropout (Dropout)              (None, 54, 54, 32)   0           ['activation_15[0][0]']
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            66          ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 1,585,453
# Trainable params: 1,585,453
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version2-DIR"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)



lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Versioin2-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = DIR.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)
# Out:
# Epoch 1/150
# 2024-03-06 00:43:59.749252: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-06 00:44:02.742228: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.54GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-06 00:44:02.742265: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.54GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-06 00:44:02.774498: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 866.78MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-06 00:44:02.774523: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 866.78MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-06 00:44:02.774531: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 861.16MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-06 00:44:02.774538: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 861.16MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-06 00:44:02.805888: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 742.04MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-06 00:44:02.805913: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 742.04MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-06 00:44:02.821873: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.12GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-06 00:44:02.821894: W tensorflow/core/common_runtime/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.12GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-03-06 00:44:02.883251: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-03-06 00:44:03.280816: W tensorflow/core/kernels/gpu_utils.cc:50] Failed to allocate memory for convolution redzone checking; skipping this check. This is benign and only means that we won't check cudnn for out-of-bounds reads and writes. This message will only be printed once.
# 2024-03-06 00:44:13.306552: W tensorflow/core/common_runtime/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 189.06MiB (rounded to 198246400)requested by op gradient_tape/model/conv2d_67/Conv2D/Conv2DBackpropInput
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-03-06 00:44:13.306611: I tensorflow/core/common_runtime/bfc_allocator.cc:1027] BFCAllocator dump for GPU_0_bfc
# 2024-03-06 00:44:13.306626: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (256): 	Total Chunks: 286, Chunks in use: 283. 71.5KiB allocated for chunks. 70.8KiB in use in bin. 29.6KiB client-requested in use in bin.
# 2024-03-06 00:44:13.306636: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (512): 	Total Chunks: 72, Chunks in use: 72. 36.0KiB allocated for chunks. 36.0KiB in use in bin. 30.5KiB client-requested in use in bin.
# 2024-03-06 00:44:13.306645: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1024): 	Total Chunks: 14, Chunks in use: 11. 14.8KiB allocated for chunks. 11.2KiB in use in bin. 10.1KiB client-requested in use in bin.
# 2024-03-06 00:44:13.306653: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2048): 	Total Chunks: 9, Chunks in use: 9. 24.0KiB allocated for chunks. 24.0KiB in use in bin. 23.6KiB client-requested in use in bin.
# 2024-03-06 00:44:13.306662: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4096): 	Total Chunks: 54, Chunks in use: 54. 220.5KiB allocated for chunks. 220.5KiB in use in bin. 216.0KiB client-requested in use in bin.
# 2024-03-06 00:44:13.306670: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8192): 	Total Chunks: 14, Chunks in use: 14. 156.0KiB allocated for chunks. 156.0KiB in use in bin. 156.0KiB client-requested in use in bin.
# 2024-03-06 00:44:13.306678: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16384): 	Total Chunks: 23, Chunks in use: 23. 453.2KiB allocated for chunks. 453.2KiB in use in bin. 420.0KiB client-requested in use in bin.
# 2024-03-06 00:44:13.306686: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (32768): 	Total Chunks: 50, Chunks in use: 50. 1.96MiB allocated for chunks. 1.96MiB in use in bin. 1.85MiB client-requested in use in bin.
# 2024-03-06 00:44:13.306694: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (65536): 	Total Chunks: 29, Chunks in use: 29. 2.23MiB allocated for chunks. 2.23MiB in use in bin. 2.15MiB client-requested in use in bin.
# 2024-03-06 00:44:13.306701: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (131072): 	Total Chunks: 50, Chunks in use: 50. 7.85MiB allocated for chunks. 7.85MiB in use in bin. 7.77MiB client-requested in use in bin.
# 2024-03-06 00:44:13.306709: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (262144): 	Total Chunks: 11, Chunks in use: 11. 3.45MiB allocated for chunks. 3.45MiB in use in bin. 3.27MiB client-requested in use in bin.
# 2024-03-06 00:44:13.306716: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (524288): 	Total Chunks: 3, Chunks in use: 3. 2.32MiB allocated for chunks. 2.32MiB in use in bin. 2.32MiB client-requested in use in bin.
# 2024-03-06 00:44:13.306724: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-06 00:44:13.306735: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2024-03-06 00:44:13.306744: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (4194304): 	Total Chunks: 2, Chunks in use: 2. 12.25MiB allocated for chunks. 12.25MiB in use in bin. 12.25MiB client-requested in use in bin.
# 2024-03-06 00:44:13.306753: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (8388608): 	Total Chunks: 1, Chunks in use: 1. 12.25MiB allocated for chunks. 12.25MiB in use in bin. 6.12MiB client-requested in use in bin.
# 2024-03-06 00:44:13.306761: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (16777216): 	Total Chunks: 1, Chunks in use: 1. 18.38MiB allocated for chunks. 18.38MiB in use in bin. 18.38MiB client-requested in use in bin.
# 2024-03-06 00:44:13.306769: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (33554432): 	Total Chunks: 25, Chunks in use: 25. 1.15GiB allocated for chunks. 1.15GiB in use in bin. 1.15GiB client-requested in use in bin.
# 2024-03-06 00:44:13.306777: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (67108864): 	Total Chunks: 17, Chunks in use: 14. 1.59GiB allocated for chunks. 1.30GiB in use in bin. 1.30GiB client-requested in use in bin.
# 2024-03-06 00:44:13.306790: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (134217728): 	Total Chunks: 30, Chunks in use: 29. 5.48GiB allocated for chunks. 5.33GiB in use in bin. 5.22GiB client-requested in use in bin.
# 2024-03-06 00:44:13.306799: I tensorflow/core/common_runtime/bfc_allocator.cc:1034] Bin (268435456): 	Total Chunks: 28, Chunks in use: 28. 13.50GiB allocated for chunks. 13.50GiB in use in bin. 13.50GiB client-requested in use in bin.
# 2024-03-06 00:44:13.306806: I tensorflow/core/common_runtime/bfc_allocator.cc:1050] Bin for 189.06MiB was 128.00MiB, Chunk State:
# 2024-03-06 00:44:13.306823: I tensorflow/core/common_runtime/bfc_allocator.cc:1056]   Size: 157.61MiB | Requested Size: 25.63MiB | in_use: 0 | bin_num: 19, prev:   Size: 94.53MiB | Requested Size: 94.53MiB | in_use: 1 | bin_num: -1, next:   Size: 189.06MiB | Requested Size: 189.06MiB | in_use: 1 | bin_num: -1
# 2024-03-06 00:44:13.306829: I tensorflow/core/common_runtime/bfc_allocator.cc:1063] Next region of size 23393402880
# 2024-03-06 00:44:13.306838: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44000000 of size 1280 next 1
# 2024-03-06 00:44:13.306844: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44000500 of size 256 next 2
# 2024-03-06 00:44:13.306849: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44000600 of size 256 next 3
# 2024-03-06 00:44:13.306854: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44000700 of size 256 next 4
# 2024-03-06 00:44:13.306859: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44000800 of size 256 next 7
# 2024-03-06 00:44:13.306865: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44000900 of size 256 next 8
# 2024-03-06 00:44:13.306870: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44000a00 of size 256 next 9
# 2024-03-06 00:44:13.306876: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44000b00 of size 512 next 10
# 2024-03-06 00:44:13.306893: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44000d00 of size 256 next 13
# 2024-03-06 00:44:13.306899: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44000e00 of size 256 next 14
# 2024-03-06 00:44:13.306903: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44000f00 of size 256 next 15
# 2024-03-06 00:44:13.306909: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001000 of size 256 next 16
# 2024-03-06 00:44:13.306914: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001100 of size 256 next 19
# 2024-03-06 00:44:13.306919: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001200 of size 512 next 17
# 2024-03-06 00:44:13.306924: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001400 of size 512 next 18
# 2024-03-06 00:44:13.306929: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001600 of size 256 next 24
# 2024-03-06 00:44:13.306934: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001700 of size 256 next 25
# 2024-03-06 00:44:13.306939: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001800 of size 256 next 28
# 2024-03-06 00:44:13.306944: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001900 of size 256 next 29
# 2024-03-06 00:44:13.306948: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001a00 of size 256 next 26
# 2024-03-06 00:44:13.306953: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001b00 of size 512 next 27
# 2024-03-06 00:44:13.306959: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001d00 of size 512 next 30
# 2024-03-06 00:44:13.306964: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44001f00 of size 256 next 33
# 2024-03-06 00:44:13.306970: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44002000 of size 256 next 37
# 2024-03-06 00:44:13.306975: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44002100 of size 256 next 38
# 2024-03-06 00:44:13.306980: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44002200 of size 256 next 5
# 2024-03-06 00:44:13.306986: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44002300 of size 3584 next 6
# 2024-03-06 00:44:13.306991: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44003100 of size 512 next 34
# 2024-03-06 00:44:13.306996: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44003300 of size 256 next 39
# 2024-03-06 00:44:13.307001: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44003400 of size 256 next 42
# 2024-03-06 00:44:13.307007: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44003500 of size 2304 next 64
# 2024-03-06 00:44:13.307013: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44003e00 of size 4096 next 125
# 2024-03-06 00:44:13.307019: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44004e00 of size 256 next 155
# 2024-03-06 00:44:13.307024: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44004f00 of size 512 next 157
# 2024-03-06 00:44:13.307029: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44005100 of size 512 next 159
# 2024-03-06 00:44:13.307034: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44005300 of size 256 next 162
# 2024-03-06 00:44:13.307039: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44005400 of size 256 next 164
# 2024-03-06 00:44:13.307044: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44005500 of size 256 next 167
# 2024-03-06 00:44:13.307049: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44005600 of size 256 next 169
# 2024-03-06 00:44:13.307054: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44005700 of size 256 next 171
# 2024-03-06 00:44:13.307059: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44005800 of size 512 next 173
# 2024-03-06 00:44:13.307064: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44005a00 of size 512 next 175
# 2024-03-06 00:44:13.307069: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44005c00 of size 256 next 177
# 2024-03-06 00:44:13.307074: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44005d00 of size 256 next 136
# 2024-03-06 00:44:13.307080: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44005e00 of size 4096 next 137
# 2024-03-06 00:44:13.307085: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44006e00 of size 4096 next 139
# 2024-03-06 00:44:13.307090: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44007e00 of size 256 next 227
# 2024-03-06 00:44:13.307095: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44007f00 of size 256 next 228
# 2024-03-06 00:44:13.307100: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008000 of size 256 next 229
# 2024-03-06 00:44:13.307105: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008100 of size 256 next 230
# 2024-03-06 00:44:13.307110: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008200 of size 256 next 231
# 2024-03-06 00:44:13.307115: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008300 of size 256 next 232
# 2024-03-06 00:44:13.307120: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008400 of size 256 next 233
# 2024-03-06 00:44:13.307125: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008500 of size 256 next 234
# 2024-03-06 00:44:13.307130: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008600 of size 256 next 235
# 2024-03-06 00:44:13.307136: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008700 of size 256 next 236
# 2024-03-06 00:44:13.307142: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008800 of size 256 next 237
# 2024-03-06 00:44:13.307147: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008900 of size 256 next 238
# 2024-03-06 00:44:13.307152: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008a00 of size 256 next 240
# 2024-03-06 00:44:13.307157: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008b00 of size 512 next 241
# 2024-03-06 00:44:13.307162: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008d00 of size 512 next 242
# 2024-03-06 00:44:13.307167: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44008f00 of size 256 next 243
# 2024-03-06 00:44:13.307172: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44009000 of size 256 next 244
# 2024-03-06 00:44:13.307177: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44009100 of size 512 next 40
# 2024-03-06 00:44:13.307182: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44009300 of size 12288 next 41
# 2024-03-06 00:44:13.307187: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400c300 of size 256 next 43
# 2024-03-06 00:44:13.307193: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400c400 of size 256 next 45
# 2024-03-06 00:44:13.307198: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400c500 of size 256 next 47
# 2024-03-06 00:44:13.307203: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400c600 of size 256 next 48
# 2024-03-06 00:44:13.307207: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400c700 of size 256 next 49
# 2024-03-06 00:44:13.307214: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400c800 of size 512 next 59
# 2024-03-06 00:44:13.307219: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400ca00 of size 256 next 60
# 2024-03-06 00:44:13.307224: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400cb00 of size 256 next 62
# 2024-03-06 00:44:13.307229: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400cc00 of size 256 next 63
# 2024-03-06 00:44:13.307234: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400cd00 of size 256 next 67
# 2024-03-06 00:44:13.307239: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400ce00 of size 256 next 50
# 2024-03-06 00:44:13.307244: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400cf00 of size 1024 next 51
# 2024-03-06 00:44:13.307251: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400d300 of size 256 next 54
# 2024-03-06 00:44:13.307256: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400d400 of size 256 next 55
# 2024-03-06 00:44:13.307261: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400d500 of size 256 next 56
# 2024-03-06 00:44:13.307266: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400d600 of size 256 next 52
# 2024-03-06 00:44:13.307271: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400d700 of size 1024 next 53
# 2024-03-06 00:44:13.307276: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400db00 of size 256 next 69
# 2024-03-06 00:44:13.307281: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400dc00 of size 256 next 70
# 2024-03-06 00:44:13.307286: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400dd00 of size 256 next 73
# 2024-03-06 00:44:13.307291: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400de00 of size 256 next 74
# 2024-03-06 00:44:13.307296: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400df00 of size 512 next 76
# 2024-03-06 00:44:13.307301: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400e100 of size 256 next 78
# 2024-03-06 00:44:13.307303: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400e200 of size 256 next 81
# 2024-03-06 00:44:13.307305: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400e300 of size 256 next 82
# 2024-03-06 00:44:13.307308: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400e400 of size 256 next 84
# 2024-03-06 00:44:13.307310: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400e500 of size 256 next 85
# 2024-03-06 00:44:13.307312: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400e600 of size 256 next 88
# 2024-03-06 00:44:13.307314: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400e700 of size 512 next 89
# 2024-03-06 00:44:13.307317: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400e900 of size 256 next 93
# 2024-03-06 00:44:13.307319: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400ea00 of size 256 next 79
# 2024-03-06 00:44:13.307321: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400eb00 of size 2304 next 44
# 2024-03-06 00:44:13.307323: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4400f400 of size 23808 next 20
# 2024-03-06 00:44:13.307326: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44015100 of size 36864 next 21
# 2024-03-06 00:44:13.307328: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4401e100 of size 18432 next 68
# 2024-03-06 00:44:13.307330: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44022900 of size 18432 next 83
# 2024-03-06 00:44:13.307332: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44027100 of size 4096 next 108
# 2024-03-06 00:44:13.307335: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44028100 of size 4096 next 110
# 2024-03-06 00:44:13.307337: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44029100 of size 4096 next 122
# 2024-03-06 00:44:13.307339: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4402a100 of size 6144 next 46
# 2024-03-06 00:44:13.307341: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4402b900 of size 55296 next 12
# 2024-03-06 00:44:13.307344: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44039100 of size 110592 next 11
# 2024-03-06 00:44:13.307347: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44054100 of size 110592 next 23
# 2024-03-06 00:44:13.307350: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4406f100 of size 110592 next 22
# 2024-03-06 00:44:13.307352: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4408a100 of size 24576 next 61
# 2024-03-06 00:44:13.307355: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090100 of size 256 next 107
# 2024-03-06 00:44:13.307357: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090200 of size 256 next 109
# 2024-03-06 00:44:13.307360: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090300 of size 256 next 111
# 2024-03-06 00:44:13.307362: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090400 of size 512 next 112
# 2024-03-06 00:44:13.307364: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090600 of size 256 next 114
# 2024-03-06 00:44:13.307366: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090700 of size 512 next 116
# 2024-03-06 00:44:13.307368: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090900 of size 256 next 117
# 2024-03-06 00:44:13.307370: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090a00 of size 256 next 119
# 2024-03-06 00:44:13.307373: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090b00 of size 256 next 121
# 2024-03-06 00:44:13.307375: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090c00 of size 256 next 123
# 2024-03-06 00:44:13.307377: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090d00 of size 256 next 124
# 2024-03-06 00:44:13.307379: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090e00 of size 256 next 126
# 2024-03-06 00:44:13.307382: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44090f00 of size 512 next 105
# 2024-03-06 00:44:13.307384: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44091100 of size 4096 next 106
# 2024-03-06 00:44:13.307386: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092100 of size 256 next 127
# 2024-03-06 00:44:13.307389: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092200 of size 512 next 130
# 2024-03-06 00:44:13.307391: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092400 of size 256 next 133
# 2024-03-06 00:44:13.307393: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092500 of size 256 next 135
# 2024-03-06 00:44:13.307395: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092600 of size 256 next 138
# 2024-03-06 00:44:13.307398: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092700 of size 256 next 140
# 2024-03-06 00:44:13.307400: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092800 of size 256 next 141
# 2024-03-06 00:44:13.307402: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092900 of size 512 next 142
# 2024-03-06 00:44:13.307404: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092b00 of size 512 next 145
# 2024-03-06 00:44:13.307406: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092d00 of size 256 next 148
# 2024-03-06 00:44:13.307408: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092e00 of size 256 next 150
# 2024-03-06 00:44:13.307411: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44092f00 of size 256 next 152
# 2024-03-06 00:44:13.307413: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44093000 of size 256 next 65
# 2024-03-06 00:44:13.307415: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44093100 of size 12288 next 66
# 2024-03-06 00:44:13.307417: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44096100 of size 24576 next 35
# 2024-03-06 00:44:13.307420: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4409c100 of size 73728 next 36
# 2024-03-06 00:44:13.307423: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440ae100 of size 49152 next 58
# 2024-03-06 00:44:13.307425: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440ba100 of size 24576 next 72
# 2024-03-06 00:44:13.307428: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440c0100 of size 16384 next 77
# 2024-03-06 00:44:13.307431: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440c4100 of size 512 next 97
# 2024-03-06 00:44:13.307433: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440c4300 of size 256 next 98
# 2024-03-06 00:44:13.307435: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440c4400 of size 256 next 101
# 2024-03-06 00:44:13.307437: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440c4500 of size 256 next 103
# 2024-03-06 00:44:13.307439: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440c4600 of size 256 next 104
# 2024-03-06 00:44:13.307442: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440c4700 of size 6656 next 80
# 2024-03-06 00:44:13.307444: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440c6100 of size 8192 next 75
# 2024-03-06 00:44:13.307447: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440c8100 of size 59392 next 57
# 2024-03-06 00:44:13.307450: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440d6900 of size 129024 next 31
# 2024-03-06 00:44:13.307452: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe440f6100 of size 221184 next 32
# 2024-03-06 00:44:13.307455: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4412c100 of size 53248 next 71
# 2024-03-06 00:44:13.307457: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44139100 of size 16384 next 92
# 2024-03-06 00:44:13.307460: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4413d100 of size 32768 next 143
# 2024-03-06 00:44:13.307462: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44145100 of size 4096 next 151
# 2024-03-06 00:44:13.307464: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44146100 of size 4096 next 153
# 2024-03-06 00:44:13.307467: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44147100 of size 4096 next 154
# 2024-03-06 00:44:13.307469: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44148100 of size 12288 next 202
# 2024-03-06 00:44:13.307471: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4414b100 of size 12288 next 258
# 2024-03-06 00:44:13.307474: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4414e100 of size 20480 next 86
# 2024-03-06 00:44:13.307476: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44153100 of size 53248 next 87
# 2024-03-06 00:44:13.307478: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44160100 of size 32768 next 128
# 2024-03-06 00:44:13.307480: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44168100 of size 45056 next 203
# 2024-03-06 00:44:13.307483: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44173100 of size 53248 next 115
# 2024-03-06 00:44:13.307485: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44180100 of size 163840 next 95
# 2024-03-06 00:44:13.307487: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe441a8100 of size 147456 next 90
# 2024-03-06 00:44:13.307490: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe441cc100 of size 221184 next 91
# 2024-03-06 00:44:13.307492: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44202100 of size 32768 next 113
# 2024-03-06 00:44:13.307494: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4420a100 of size 73728 next 206
# 2024-03-06 00:44:13.307496: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4421c100 of size 36864 next 207
# 2024-03-06 00:44:13.307499: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44225100 of size 77824 next 94
# 2024-03-06 00:44:13.307501: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44238100 of size 221184 next 96
# 2024-03-06 00:44:13.307503: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4426e100 of size 65536 next 129
# 2024-03-06 00:44:13.307506: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427e100 of size 512 next 180
# 2024-03-06 00:44:13.307508: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427e300 of size 512 next 182
# 2024-03-06 00:44:13.307510: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427e500 of size 256 next 184
# 2024-03-06 00:44:13.307512: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427e600 of size 512 next 186
# 2024-03-06 00:44:13.307515: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427e800 of size 256 next 187
# 2024-03-06 00:44:13.307517: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427e900 of size 512 next 188
# 2024-03-06 00:44:13.307519: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427eb00 of size 256 next 191
# 2024-03-06 00:44:13.307521: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427ec00 of size 256 next 192
# 2024-03-06 00:44:13.307523: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427ed00 of size 256 next 197
# 2024-03-06 00:44:13.307525: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427ee00 of size 256 next 200
# 2024-03-06 00:44:13.307527: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427ef00 of size 256 next 201
# 2024-03-06 00:44:13.307530: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427f000 of size 256 next 165
# 2024-03-06 00:44:13.307532: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4427f100 of size 4096 next 166
# 2024-03-06 00:44:13.307534: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44280100 of size 4096 next 168
# 2024-03-06 00:44:13.307536: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44281100 of size 4096 next 170
# 2024-03-06 00:44:13.307539: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282100 of size 256 next 204
# 2024-03-06 00:44:13.307541: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282200 of size 256 next 205
# 2024-03-06 00:44:13.307543: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282300 of size 256 next 208
# 2024-03-06 00:44:13.307545: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282400 of size 256 next 210
# 2024-03-06 00:44:13.307547: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282500 of size 256 next 211
# 2024-03-06 00:44:13.307549: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282600 of size 256 next 214
# 2024-03-06 00:44:13.307552: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282700 of size 256 next 215
# 2024-03-06 00:44:13.307554: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282800 of size 256 next 216
# 2024-03-06 00:44:13.307556: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282900 of size 256 next 217
# 2024-03-06 00:44:13.307559: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282a00 of size 256 next 218
# 2024-03-06 00:44:13.307561: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282b00 of size 256 next 219
# 2024-03-06 00:44:13.307563: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282c00 of size 256 next 220
# 2024-03-06 00:44:13.307566: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282d00 of size 256 next 221
# 2024-03-06 00:44:13.307568: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282e00 of size 256 next 222
# 2024-03-06 00:44:13.307570: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44282f00 of size 256 next 223
# 2024-03-06 00:44:13.307573: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44283000 of size 256 next 198
# 2024-03-06 00:44:13.307575: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44283100 of size 4096 next 199
# 2024-03-06 00:44:13.307577: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44284100 of size 1024 next 224
# 2024-03-06 00:44:13.307580: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44284500 of size 1024 next 225
# 2024-03-06 00:44:13.307582: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44284900 of size 1024 next 226
# 2024-03-06 00:44:13.307584: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44284d00 of size 1024 next 209
# 2024-03-06 00:44:13.307586: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44285100 of size 4096 next 156
# 2024-03-06 00:44:13.307589: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44286100 of size 49152 next 118
# 2024-03-06 00:44:13.307591: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44292100 of size 147456 next 99
# 2024-03-06 00:44:13.307593: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe442b6100 of size 294912 next 100
# 2024-03-06 00:44:13.307596: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe442fe100 of size 294912 next 102
# 2024-03-06 00:44:13.307598: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44346100 of size 147456 next 120
# 2024-03-06 00:44:13.307600: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4436a100 of size 65536 next 144
# 2024-03-06 00:44:13.307603: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437a100 of size 12288 next 212
# 2024-03-06 00:44:13.307605: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437d100 of size 4096 next 213
# 2024-03-06 00:44:13.307607: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437e100 of size 3584 next 239
# 2024-03-06 00:44:13.307609: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437ef00 of size 512 next 246
# 2024-03-06 00:44:13.307612: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437f100 of size 256 next 247
# 2024-03-06 00:44:13.307614: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437f200 of size 256 next 248
# 2024-03-06 00:44:13.307616: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437f300 of size 512 next 249
# 2024-03-06 00:44:13.307619: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437f500 of size 512 next 250
# 2024-03-06 00:44:13.307621: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437f700 of size 256 next 251
# 2024-03-06 00:44:13.307623: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437f800 of size 256 next 253
# 2024-03-06 00:44:13.307625: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437f900 of size 256 next 255
# 2024-03-06 00:44:13.307628: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437fa00 of size 1024 next 256
# 2024-03-06 00:44:13.307630: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437fe00 of size 256 next 257
# 2024-03-06 00:44:13.307632: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4437ff00 of size 256 next 259
# 2024-03-06 00:44:13.307634: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44380000 of size 1024 next 260
# 2024-03-06 00:44:13.307637: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44380400 of size 256 next 261
# 2024-03-06 00:44:13.307639: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44380500 of size 256 next 263
# 2024-03-06 00:44:13.307641: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44380600 of size 256 next 265
# 2024-03-06 00:44:13.307643: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44380700 of size 256 next 266
# 2024-03-06 00:44:13.307645: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44380800 of size 512 next 268
# 2024-03-06 00:44:13.307648: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44380a00 of size 2304 next 269
# 2024-03-06 00:44:13.307650: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381300 of size 256 next 270
# 2024-03-06 00:44:13.307652: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381400 of size 256 next 271
# 2024-03-06 00:44:13.307654: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381500 of size 256 next 273
# 2024-03-06 00:44:13.307657: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381600 of size 256 next 275
# 2024-03-06 00:44:13.307659: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381700 of size 256 next 277
# 2024-03-06 00:44:13.307662: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381800 of size 256 next 279
# 2024-03-06 00:44:13.307664: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381900 of size 512 next 280
# 2024-03-06 00:44:13.307666: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381b00 of size 256 next 282
# 2024-03-06 00:44:13.307668: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381c00 of size 256 next 284
# 2024-03-06 00:44:13.307670: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381d00 of size 256 next 286
# 2024-03-06 00:44:13.307673: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381e00 of size 256 next 288
# 2024-03-06 00:44:13.307675: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44381f00 of size 256 next 290
# 2024-03-06 00:44:13.307677: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44382000 of size 256 next 172
# 2024-03-06 00:44:13.307679: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44382100 of size 49152 next 131
# 2024-03-06 00:44:13.307681: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4438e100 of size 147456 next 132
# 2024-03-06 00:44:13.307683: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe443b2100 of size 147456 next 134
# 2024-03-06 00:44:13.307686: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe443d6100 of size 65536 next 158
# 2024-03-06 00:44:13.307688: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe443e6100 of size 32768 next 176
# 2024-03-06 00:44:13.307690: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe443ee100 of size 49152 next 146
# 2024-03-06 00:44:13.307693: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe443fa100 of size 147456 next 147
# 2024-03-06 00:44:13.307695: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4441e100 of size 147456 next 149
# 2024-03-06 00:44:13.307697: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44442100 of size 65536 next 174
# 2024-03-06 00:44:13.307700: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44452100 of size 32768 next 183
# 2024-03-06 00:44:13.307702: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4445a100 of size 24576 next 264
# 2024-03-06 00:44:13.307704: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44460100 of size 24576 next 160
# 2024-03-06 00:44:13.307706: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44466100 of size 147456 next 161
# 2024-03-06 00:44:13.307709: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4448a100 of size 147456 next 163
# 2024-03-06 00:44:13.307711: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe444ae100 of size 165888 next 178
# 2024-03-06 00:44:13.307714: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe444d6900 of size 165888 next 179
# 2024-03-06 00:44:13.307716: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe444ff100 of size 165888 next 181
# 2024-03-06 00:44:13.307718: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44527900 of size 165888 next 185
# 2024-03-06 00:44:13.307720: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44550100 of size 73728 next 252
# 2024-03-06 00:44:13.307723: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44562100 of size 55296 next 254
# 2024-03-06 00:44:13.307725: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4456f900 of size 82944 next 262
# 2024-03-06 00:44:13.307728: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44583d00 of size 49152 next 267
# 2024-03-06 00:44:13.307730: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4458fd00 of size 24576 next 272
# 2024-03-06 00:44:13.307732: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44595d00 of size 53248 next 274
# 2024-03-06 00:44:13.307734: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe445a2d00 of size 16384 next 276
# 2024-03-06 00:44:13.307737: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe445a6d00 of size 8192 next 278
# 2024-03-06 00:44:13.307739: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe445a8d00 of size 51200 next 189
# 2024-03-06 00:44:13.307742: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe445b5500 of size 207360 next 190
# 2024-03-06 00:44:13.307744: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe445e7f00 of size 110592 next 245
# 2024-03-06 00:44:13.307746: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44602f00 of size 294912 next 195
# 2024-03-06 00:44:13.307748: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4464af00 of size 405504 next 196
# 2024-03-06 00:44:13.307751: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe446adf00 of size 2304 next 281
# 2024-03-06 00:44:13.307753: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe446ae800 of size 18432 next 283
# 2024-03-06 00:44:13.307755: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe446b3000 of size 16384 next 285
# 2024-03-06 00:44:13.307758: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe446b7000 of size 53248 next 287
# 2024-03-06 00:44:13.307760: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe446c4000 of size 16384 next 289
# 2024-03-06 00:44:13.307763: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe446c8000 of size 147456 next 291
# 2024-03-06 00:44:13.307765: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe446ec000 of size 221184 next 292
# 2024-03-06 00:44:13.307767: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44722000 of size 512 next 293
# 2024-03-06 00:44:13.307770: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44722200 of size 335104 next 193
# 2024-03-06 00:44:13.307772: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44773f00 of size 811008 next 194
# 2024-03-06 00:44:13.307775: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44839f00 of size 512 next 294
# 2024-03-06 00:44:13.307777: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe4483a100 of size 294912 next 295
# 2024-03-06 00:44:13.307780: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44882100 of size 256 next 296
# 2024-03-06 00:44:13.307782: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44882200 of size 4096 next 297
# 2024-03-06 00:44:13.307784: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44883200 of size 256 next 298
# 2024-03-06 00:44:13.307786: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44883300 of size 4096 next 299
# 2024-03-06 00:44:13.307789: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44884300 of size 256 next 300
# 2024-03-06 00:44:13.307791: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7efe44884400 of size 294912 next 301
# ...
# 2024-03-06 00:44:23.311989: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] InUse at 7f03b0129300 of size 32768 next 725
# 2024-03-06 00:44:23.311991: I tensorflow/core/common_runtime/bfc_allocator.cc:1083] Free  at 7f03b0131300 of size 105377024 next 18446744073709551615
# 2024-03-06 00:44:23.311994: I tensorflow/core/common_runtime/bfc_allocator.cc:1088]      Summary of in-use Chunks by size:
# 2024-03-06 00:44:23.311999: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 284 Chunks of size 256 totalling 71.0KiB
# 2024-03-06 00:44:23.312002: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 72 Chunks of size 512 totalling 36.0KiB
# 2024-03-06 00:44:23.312005: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 10 Chunks of size 1024 totalling 10.0KiB
# 2024-03-06 00:44:23.312008: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 1280 totalling 1.2KiB
# 2024-03-06 00:44:23.312011: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 6 Chunks of size 2304 totalling 13.5KiB
# 2024-03-06 00:44:23.312013: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 3584 totalling 10.5KiB
# 2024-03-06 00:44:23.312016: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 52 Chunks of size 4096 totalling 208.0KiB
# 2024-03-06 00:44:23.312019: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 6144 totalling 6.0KiB
# 2024-03-06 00:44:23.312022: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 6656 totalling 6.5KiB
# 2024-03-06 00:44:23.312024: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 8192 totalling 24.0KiB
# 2024-03-06 00:44:23.312027: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 11 Chunks of size 12288 totalling 132.0KiB
# 2024-03-06 00:44:23.312030: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 8 Chunks of size 16384 totalling 128.0KiB
# 2024-03-06 00:44:23.312033: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 5 Chunks of size 18432 totalling 90.0KiB
# 2024-03-06 00:44:23.312035: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 20480 totalling 20.0KiB
# 2024-03-06 00:44:23.312038: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 23808 totalling 23.2KiB
# 2024-03-06 00:44:23.312041: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 8 Chunks of size 24576 totalling 192.0KiB
# 2024-03-06 00:44:23.312044: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 25 Chunks of size 32768 totalling 800.0KiB
# 2024-03-06 00:44:23.312046: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 5 Chunks of size 36864 totalling 180.0KiB
# 2024-03-06 00:44:23.312049: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 45056 totalling 132.0KiB
# 2024-03-06 00:44:23.312052: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 6 Chunks of size 49152 totalling 288.0KiB
# 2024-03-06 00:44:23.312055: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 51200 totalling 50.0KiB
# 2024-03-06 00:44:23.312058: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 7 Chunks of size 53248 totalling 364.0KiB
# 2024-03-06 00:44:23.312060: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 55296 totalling 162.0KiB
# 2024-03-06 00:44:23.312063: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 59392 totalling 58.0KiB
# 2024-03-06 00:44:23.312066: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 12 Chunks of size 65536 totalling 768.0KiB
# 2024-03-06 00:44:23.312069: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 7 Chunks of size 73728 totalling 504.0KiB
# 2024-03-06 00:44:23.312071: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 77824 totalling 76.0KiB
# 2024-03-06 00:44:23.312074: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 82944 totalling 162.0KiB
# 2024-03-06 00:44:23.312077: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 6 Chunks of size 110592 totalling 648.0KiB
# 2024-03-06 00:44:23.312080: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 129024 totalling 126.0KiB
# 2024-03-06 00:44:23.312082: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 131072 totalling 256.0KiB
# 2024-03-06 00:44:23.312085: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 27 Chunks of size 147456 totalling 3.80MiB
# 2024-03-06 00:44:23.312088: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 163840 totalling 160.0KiB
# 2024-03-06 00:44:23.312090: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 10 Chunks of size 165888 totalling 1.58MiB
# 2024-03-06 00:44:23.312093: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 207360 totalling 607.5KiB
# 2024-03-06 00:44:23.312096: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 7 Chunks of size 221184 totalling 1.48MiB
# 2024-03-06 00:44:23.312099: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 7 Chunks of size 294912 totalling 1.97MiB
# 2024-03-06 00:44:23.312101: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 335104 totalling 327.2KiB
# 2024-03-06 00:44:23.312104: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 405504 totalling 1.16MiB
# 2024-03-06 00:44:23.312107: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 811008 totalling 2.32MiB
# 2024-03-06 00:44:23.312109: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 6422528 totalling 12.25MiB
# 2024-03-06 00:44:23.312112: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 12840960 totalling 12.25MiB
# 2024-03-06 00:44:23.312115: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 19267584 totalling 18.38MiB
# 2024-03-06 00:44:23.312118: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 25 Chunks of size 49561600 totalling 1.15GiB
# 2024-03-06 00:44:23.312121: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 10 Chunks of size 99123200 totalling 945.31MiB
# 2024-03-06 00:44:23.312124: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 100933632 totalling 288.77MiB
# 2024-03-06 00:44:23.312127: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 148684800 totalling 283.59MiB
# 2024-03-06 00:44:23.312130: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 181170176 totalling 172.78MiB
# 2024-03-06 00:44:23.312132: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 18 Chunks of size 198246400 totalling 3.32GiB
# 2024-03-06 00:44:23.312135: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 201867264 totalling 385.03MiB
# 2024-03-06 00:44:23.312138: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 5 Chunks of size 205520896 totalling 980.00MiB
# 2024-03-06 00:44:23.312141: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 246022144 totalling 234.62MiB
# 2024-03-06 00:44:23.312144: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 297369600 totalling 567.19MiB
# 2024-03-06 00:44:23.312147: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 302800896 totalling 288.77MiB
# 2024-03-06 00:44:23.312149: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 13 Chunks of size 396492800 totalling 4.80GiB
# 2024-03-06 00:44:23.312152: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 403734528 totalling 385.03MiB
# 2024-03-06 00:44:23.312155: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 411041792 totalling 784.00MiB
# 2024-03-06 00:44:23.312158: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 594739200 totalling 567.19MiB
# 2024-03-06 00:44:23.312161: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 1 Chunks of size 605601792 totalling 577.55MiB
# 2024-03-06 00:44:23.312164: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 3 Chunks of size 616562688 totalling 1.72GiB
# 2024-03-06 00:44:23.312166: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 792985600 totalling 1.48GiB
# 2024-03-06 00:44:23.312169: I tensorflow/core/common_runtime/bfc_allocator.cc:1091] 2 Chunks of size 1288601600 totalling 2.40GiB
# 2024-03-06 00:44:23.312172: I tensorflow/core/common_runtime/bfc_allocator.cc:1095] Sum Total of in-use chunks: 21.25GiB
# 2024-03-06 00:44:23.312174: I tensorflow/core/common_runtime/bfc_allocator.cc:1097] total_region_allocated_bytes_: 23393402880 memory_limit_: 23393402880 available bytes: 0 curr_region_allocation_bytes_: 46786805760
# 2024-03-06 00:44:23.312181: I tensorflow/core/common_runtime/bfc_allocator.cc:1103] Stats:
# Limit:                     23393402880
# InUse:                     22813033216
# MaxInUse:                  23383076608
# NumAllocs:                        1895
# MaxAllocSize:               3716153344
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-03-06 00:44:23.312202: W tensorflow/core/common_runtime/bfc_allocator.cc:491] ****************************************************************************************************
# 2024-03-06 00:44:23.312232: W tensorflow/core/framework/op_kernel.cc:1745] OP_REQUIRES failed at conv_grad_input_ops.cc:326 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[32,128,110,110] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 history = DIR.fit(
#       2     train_generator,
#       3     epochs=150,  # 根据需要调整epochs数
#       4     validation_data=validation_generator,
#       5     callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
#       6 )
#
# File ~/miniconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py:67, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67   raise e.with_traceback(filtered_tb) from None
#      68 finally:
#      69   del filtered_tb
#
# File ~/miniconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# Detected at node 'gradient_tape/model/conv2d_67/Conv2D/Conv2DBackpropInput' defined at (most recent call last):
#     File "/root/miniconda3/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#       return _run_code(code, main_globals, None,
#     File "/root/miniconda3/lib/python3.8/runpy.py", line 87, in _run_code
#       exec(code, run_globals)
#     File "/root/miniconda3/lib/python3.8/site-packages/ipykernel_launcher.py", line 17, in <module>
#       app.launch_new_instance()
#     File "/root/miniconda3/lib/python3.8/site-packages/traitlets/config/application.py", line 976, in launch_instance
#       app.start()
#     File "/root/miniconda3/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 712, in start
#       self.io_loop.start()
#     File "/root/miniconda3/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#       self.asyncio_loop.run_forever()
#     File "/root/miniconda3/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#       self._run_once()
#     File "/root/miniconda3/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#       handle._run()
#     File "/root/miniconda3/lib/python3.8/asyncio/events.py", line 81, in _run
#       self._context.run(self._callback, *self._args)
#     File "/root/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#       await self.process_one()
#     File "/root/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 499, in process_one
#       await dispatch(*args)
#     File "/root/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#       await result
#     File "/root/miniconda3/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 730, in execute_request
#       reply_content = await reply_content
#     File "/root/miniconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 383, in do_execute
#       res = shell.run_cell(
#     File "/root/miniconda3/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 528, in run_cell
#       return super().run_cell(*args, **kwargs)
#     File "/root/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2880, in run_cell
#       result = self._run_cell(
#     File "/root/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2935, in _run_cell
#       return runner(coro)
#     File "/root/miniconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#       coro.send(None)
#     File "/root/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3134, in run_cell_async
#       has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     File "/root/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3337, in run_ast_nodes
#       if await self.run_code(code, result, async_=asy):
#     File "/root/miniconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3397, in run_code
#       exec(code_obj, self.user_global_ns, self.user_ns)
#     File "/tmp/ipykernel_6826/2736771110.py", line 1, in <cell line: 1>
#       history = DIR.fit(
#     File "/root/miniconda3/lib/python3.8/site-packages/keras/utils/traceback_utils.py", line 64, in error_handler
#       return fn(*args, **kwargs)
#     File "/root/miniconda3/lib/python3.8/site-packages/keras/engine/training.py", line 1409, in fit
#       tmp_logs = self.train_function(iterator)
#     File "/root/miniconda3/lib/python3.8/site-packages/keras/engine/training.py", line 1051, in train_function
#       return step_function(self, iterator)
#     File "/root/miniconda3/lib/python3.8/site-packages/keras/engine/training.py", line 1040, in step_function
#       outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "/root/miniconda3/lib/python3.8/site-packages/keras/engine/training.py", line 1030, in run_step
#       outputs = model.train_step(data)
#     File "/root/miniconda3/lib/python3.8/site-packages/keras/engine/training.py", line 893, in train_step
#       self.optimizer.minimize(loss, self.trainable_variables, tape=tape)
#     File "/root/miniconda3/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/optimizer_v2.py", line 537, in minimize
#       grads_and_vars = self._compute_gradients(
#     File "/root/miniconda3/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/optimizer_v2.py", line 590, in _compute_gradients
#       grads_and_vars = self._get_gradients(tape, loss, var_list, grad_loss)
#     File "/root/miniconda3/lib/python3.8/site-packages/keras/optimizers/optimizer_v2/optimizer_v2.py", line 471, in _get_gradients
#       grads = tape.gradient(loss, var_list, grad_loss)
# Node: 'gradient_tape/model/conv2d_67/Conv2D/Conv2DBackpropInput'
# OOM when allocating tensor with shape[32,128,110,110] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradient_tape/model/conv2d_67/Conv2D/Conv2DBackpropInput}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_10165]

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del DIR


# from numba import cuda

# cuda.select_device(0)
# cuda.close()
