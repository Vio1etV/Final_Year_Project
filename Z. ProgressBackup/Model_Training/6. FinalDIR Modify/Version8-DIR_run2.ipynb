# %% [markdown]
# 再version 6的基础上，batchsize = 32， stem第一层变为4，用leaky relu，将inception a的函数里面的分支第一层神经元改为8
#
# 在Version 7的及基础上，加入L1正则化

# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.regularizers import l2

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.
# Out:
# 2024-03-12 11:35:19.113248: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 304 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

l2_reg = 0.001



def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='leaky_relu',
               kernel_initializer='he_normal', padding='valid', )(x)
    x = attention_block_2(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg * 0.1))(x)
    x = attention_block_2(x)
    
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)
    
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    # a = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    c = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = attention_block_2(x)

    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    # c = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 5
num_B_blocks = 10
num_C_blocks = 5

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.3)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax')(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# 2024-03-12 11:35:23.747247: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-12 11:35:24.341296: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22134 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:b1:00.0, compute capability: 8.9
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 4)  112         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 222, 222, 96  3552        ['conv2d[0][0]']
#                                 )
#
#  activation (Activation)        (None, 222, 222, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 222, 222, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 222, 222, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 222, 222, 4)  0           ['conv2d[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 220, 220, 4)  148         ['multiply[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 220, 220, 96  3552        ['conv2d_3[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 220, 220, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 220, 220, 1)  97          ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 220, 220, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 220, 220, 4)  0           ['conv2d_3[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 220, 220, 8)  296         ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 220, 220, 96  7008        ['conv2d_6[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 220, 220, 96  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 220, 220, 1)  97          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 220, 220, 1)  0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 220, 220, 8)  0           ['conv2d_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['multiply_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 218, 218, 12  876         ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_13[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_16[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_6 (Activation)      (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 16  160        ['conv2d_18[0][0]']
#  v2D)                           )
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_17[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['activation_6[0][0]',
#                                 )                                 'conv2d_21[0][0]']
#
#  activation_7 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_23[0][0]']
#  onv2D)                         )
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_24[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_22[0][0]',
#                                 )                                 'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 214, 214, 48  0           ['activation_7[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  activation_8 (Activation)      (None, 214, 214, 48  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_28[0][0]']
#  onv2D)                         )
#
#  conv2d_30 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_29[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_27[0][0]',
#                                 )                                 'depthwise_conv2d_2[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_5[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 214, 214, 48  0           ['activation_8[0][0]',
#                                 )                                 'conv2d_31[0][0]']
#
#  activation_9 (Activation)      (None, 214, 214, 48  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_33[0][0]']
#  onv2D)                         )
#
#  conv2d_35 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_34[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_32[0][0]',
#                                 )                                 'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_6[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 214, 214, 48  0           ['activation_9[0][0]',
#                                 )                                 'conv2d_36[0][0]']
#
#  activation_10 (Activation)     (None, 214, 214, 48  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_38[0][0]']
#  onv2D)                         )
#
#  conv2d_40 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_39[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_37[0][0]',
#                                 )                                 'depthwise_conv2d_4[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_7[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 214, 214, 48  0           ['activation_10[0][0]',
#                                 )                                 'conv2d_41[0][0]']
#
#  activation_11 (Activation)     (None, 214, 214, 48  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 214, 214, 32  1568        ['activation_11[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_43[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_11[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 106, 106, 48  20784       ['activation_11[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_44[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_42[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_49[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_46[0][0]',
#                                 )                                 'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_9[0][0]']
#                                 4)
#
#  add_5 (Add)                    (None, 106, 106, 14  0           ['concatenate_8[0][0]',
#                                 4)                                'conv2d_51[0][0]']
#
#  activation_12 (Activation)     (None, 106, 106, 14  0           ['add_5[0][0]']
#                                 4)
#
#  conv2d_53 (Conv2D)             (None, 106, 106, 16  2320        ['activation_12[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 106, 106, 24  3480        ['activation_12[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_55[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_52[0][0]',
#                                 )                                 'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_10[0][0]']
#                                 4)
#
#  add_6 (Add)                    (None, 106, 106, 14  0           ['activation_12[0][0]',
#                                 4)                                'conv2d_57[0][0]']
#
#  activation_13 (Activation)     (None, 106, 106, 14  0           ['add_6[0][0]']
#                                 4)
#
#  conv2d_59 (Conv2D)             (None, 106, 106, 16  2320        ['activation_13[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_59[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_60[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 106, 106, 24  3480        ['activation_13[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_61[0][0]']
#                                 )
#
#  concatenate_11 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_58[0][0]',
#                                 )                                 'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_11[0][0]']
#                                 4)
#
#  add_7 (Add)                    (None, 106, 106, 14  0           ['activation_13[0][0]',
#                                 4)                                'conv2d_63[0][0]']
#
#  activation_14 (Activation)     (None, 106, 106, 14  0           ['add_7[0][0]']
#                                 4)
#
#  conv2d_65 (Conv2D)             (None, 106, 106, 16  2320        ['activation_14[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_65[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_66[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 106, 106, 24  3480        ['activation_14[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_67[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_64[0][0]',
#                                 )                                 'conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_12[0][0]']
#                                 4)
#
#  add_8 (Add)                    (None, 106, 106, 14  0           ['activation_14[0][0]',
#                                 4)                                'conv2d_69[0][0]']
#
#  activation_15 (Activation)     (None, 106, 106, 14  0           ['add_8[0][0]']
#                                 4)
#
#  conv2d_71 (Conv2D)             (None, 106, 106, 16  2320        ['activation_15[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_71[0][0]']
#                                 )
#
#  conv2d_73 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_72[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 106, 106, 24  3480        ['activation_15[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_73[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_70[0][0]',
#                                 )                                 'conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_13[0][0]']
#                                 4)
#
#  add_9 (Add)                    (None, 106, 106, 14  0           ['activation_15[0][0]',
#                                 4)                                'conv2d_75[0][0]']
#
#  activation_16 (Activation)     (None, 106, 106, 14  0           ['add_9[0][0]']
#                                 4)
#
#  conv2d_77 (Conv2D)             (None, 106, 106, 16  2320        ['activation_16[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_77[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_78[0][0]']
#                                 )
#
#  conv2d_76 (Conv2D)             (None, 106, 106, 24  3480        ['activation_16[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_79[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_76[0][0]',
#                                 )                                 'conv2d_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_14[0][0]']
#                                 4)
#
#  add_10 (Add)                   (None, 106, 106, 14  0           ['activation_16[0][0]',
#                                 4)                                'conv2d_81[0][0]']
#
#  activation_17 (Activation)     (None, 106, 106, 14  0           ['add_10[0][0]']
#                                 4)
#
#  conv2d_83 (Conv2D)             (None, 106, 106, 16  2320        ['activation_17[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_83[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_84[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 106, 106, 24  3480        ['activation_17[0][0]']
#                                 )
#
#  conv2d_86 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_85[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_82[0][0]',
#                                 )                                 'conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_15[0][0]']
#                                 4)
#
#  add_11 (Add)                   (None, 106, 106, 14  0           ['activation_17[0][0]',
#                                 4)                                'conv2d_87[0][0]']
#
#  activation_18 (Activation)     (None, 106, 106, 14  0           ['add_11[0][0]']
#                                 4)
#
#  conv2d_89 (Conv2D)             (None, 106, 106, 16  2320        ['activation_18[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_89[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_90[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 106, 106, 24  3480        ['activation_18[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_91[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_88[0][0]',
#                                 )                                 'conv2d_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_16[0][0]']
#                                 4)
#
#  add_12 (Add)                   (None, 106, 106, 14  0           ['activation_18[0][0]',
#                                 4)                                'conv2d_93[0][0]']
#
#  activation_19 (Activation)     (None, 106, 106, 14  0           ['add_12[0][0]']
#                                 4)
#
#  conv2d_95 (Conv2D)             (None, 106, 106, 16  2320        ['activation_19[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_95[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_96[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 106, 106, 24  3480        ['activation_19[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_97[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_94[0][0]',
#                                 )                                 'conv2d_98[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_17[0][0]']
#                                 4)
#
#  add_13 (Add)                   (None, 106, 106, 14  0           ['activation_19[0][0]',
#                                 4)                                'conv2d_99[0][0]']
#
#  activation_20 (Activation)     (None, 106, 106, 14  0           ['add_13[0][0]']
#                                 4)
#
#  conv2d_101 (Conv2D)            (None, 106, 106, 16  2320        ['activation_20[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 106, 106, 20  2260        ['conv2d_101[0][0]']
#                                 )
#
#  conv2d_103 (Conv2D)            (None, 106, 106, 24  3384        ['conv2d_102[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 106, 106, 24  3480        ['activation_20[0][0]']
#                                 )
#
#  conv2d_104 (Conv2D)            (None, 106, 106, 24  600         ['conv2d_103[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_100[0][0]',
#                                 )                                 'conv2d_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 106, 106, 14  7056        ['concatenate_18[0][0]']
#                                 4)
#
#  add_14 (Add)                   (None, 106, 106, 14  0           ['activation_20[0][0]',
#                                 4)                                'conv2d_105[0][0]']
#
#  activation_21 (Activation)     (None, 106, 106, 14  0           ['add_14[0][0]']
#                                 4)
#
#  conv2d_110 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_106 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_108 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_111 (Conv2D)            (None, 106, 106, 36  10404       ['conv2d_110[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_21[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_106[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_108[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 52, 52, 40)   13000       ['conv2d_111[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_107[0][0]',
#                                                                   'conv2d_109[0][0]',
#                                                                   'conv2d_112[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_114[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_115[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_113[0][0]',
#                                                                   'conv2d_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_20[0][0]']
#
#  add_15 (Add)                   (None, 52, 52, 256)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_117[0][0]']
#
#  activation_22 (Activation)     (None, 52, 52, 256)  0           ['add_15[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_119[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_120[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_118[0][0]',
#                                                                   'conv2d_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_21[0][0]']
#
#  add_16 (Add)                   (None, 52, 52, 256)  0           ['activation_22[0][0]',
#                                                                   'conv2d_122[0][0]']
#
#  activation_23 (Activation)     (None, 52, 52, 256)  0           ['add_16[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_124[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_125[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_123[0][0]',
#                                                                   'conv2d_126[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_22[0][0]']
#
#  add_17 (Add)                   (None, 52, 52, 256)  0           ['activation_23[0][0]',
#                                                                   'conv2d_127[0][0]']
#
#  activation_24 (Activation)     (None, 52, 52, 256)  0           ['add_17[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_129[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_130[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_128[0][0]',
#                                                                   'conv2d_131[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_23[0][0]']
#
#  add_18 (Add)                   (None, 52, 52, 256)  0           ['activation_24[0][0]',
#                                                                   'conv2d_132[0][0]']
#
#  activation_25 (Activation)     (None, 52, 52, 256)  0           ['add_18[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_134[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_135[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_133[0][0]',
#                                                                   'conv2d_136[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_24[0][0]']
#
#  add_19 (Add)                   (None, 52, 52, 256)  0           ['activation_25[0][0]',
#                                                                   'conv2d_137[0][0]']
#
#  activation_26 (Activation)     (None, 52, 52, 256)  0           ['add_19[0][0]']
#
#  dropout (Dropout)              (None, 52, 52, 256)  0           ['activation_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 505,821
# Trainable params: 505,821
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# import numpy as np
# from sklearn.metrics import f1_score
# from tensorflow.keras.callbacks import Callback

# class F1ScoreCallback(Callback):
#     def __init__(self, train_generator, validation_generator, num_classes):
#         super(F1ScoreCallback, self).__init__()
#         self.train_generator = train_generator
#         self.validation_generator = validation_generator
#         self.num_classes = num_classes
#         self.train_f1_scores = []
#         self.val_f1_scores = []

#     def on_epoch_end(self, epoch, logs=None):
#         # 计算训练集F1分数
#         train_predict, train_true = self._get_predictions_and_true_labels(self.train_generator)
#         train_f1 = f1_score(train_true, train_predict, average='micro')
#         self.train_f1_scores.append(train_f1)
        
#         # 计算验证集F1分数
#         val_predict, val_true = self._get_predictions_and_true_labels(self.validation_generator)
#         val_f1 = f1_score(val_true, val_predict, average='micro')
#         self.val_f1_scores.append(val_f1)
        
#         print(f'Epoch {epoch+1}: Training F1 Score: {train_f1}, Validation F1 Score: {val_f1}')

#     def _get_predictions_and_true_labels(self, generator):
#         predictions = []
#         true_labels = []
#         for i in range(len(generator)):
#             x_batch, y_batch_true = next(generator)
#             y_batch_pred = self.model.predict(x_batch, verbose=0)
#             y_batch_pred = np.argmax(y_batch_pred, axis=1)
#             y_true = np.argmax(y_batch_true, axis=1)
#             predictions.extend(y_batch_pred)
#             true_labels.extend(y_true)
#         return predictions, true_labels


# # 继续使用之前的方式将回调添加到你的模型训练中

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(),
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version8-DIR_run2"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)


lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', 
                                 factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# f1_score_callback = F1ScoreCallback(train_generator = train_generator, 
#                                     validation_generator=validation_generator, 
#                                     num_classes=num_classes)


from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = DIR.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)


# history = DIR.fit(
#     train_generator,
#     epochs=150,
#     validation_data=validation_generator,
#     callbacks=[csv_logger, lr_reduction, model_checkpoint_callback, f1_score_callback]
# )
# Out:
# Epoch 1/150
# 2024-03-12 11:35:37.107713: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-12 11:35:38.091891: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-03-12 11:35:38.091916: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2024-03-12 11:35:38.091980: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-03-12 11:35:39.463431: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 10.6268 - accuracy: 0.4834 - precision: 0.4834 - recall: 0.4834 - auc: 0.4753 - f1_score: 0.4834
# Epoch 1: val_loss improved from inf to 0.69955, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 69s 789ms/step - loss: 10.6268 - accuracy: 0.4834 - precision: 0.4834 - recall: 0.4834 - auc: 0.4753 - f1_score: 0.4834 - val_loss: 0.6995 - val_accuracy: 0.5118 - val_precision: 0.5118 - val_recall: 0.5118 - val_auc: 0.6832 - val_f1_score: 0.5118 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6262 - accuracy: 0.6650 - precision: 0.6650 - recall: 0.6650 - auc: 0.7285 - f1_score: 0.6650
# Epoch 2: val_loss improved from 0.69955 to 0.45868, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 51s 711ms/step - loss: 0.6262 - accuracy: 0.6650 - precision: 0.6650 - recall: 0.6650 - auc: 0.7285 - f1_score: 0.6650 - val_loss: 0.4587 - val_accuracy: 0.8343 - val_precision: 0.8343 - val_recall: 0.8343 - val_auc: 0.9265 - val_f1_score: 0.8343 - lr: 0.0010
# Epoch 3/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5284 - accuracy: 0.7676 - precision: 0.7676 - recall: 0.7676 - auc: 0.8295 - f1_score: 0.7676
# Epoch 3: val_loss did not improve from 0.45868
# 71/71 [==============================] - 51s 709ms/step - loss: 0.5284 - accuracy: 0.7676 - precision: 0.7676 - recall: 0.7676 - auc: 0.8295 - f1_score: 0.7676 - val_loss: 0.4589 - val_accuracy: 0.7988 - val_precision: 0.7988 - val_recall: 0.7988 - val_auc: 0.9074 - val_f1_score: 0.7988 - lr: 0.0010
# Epoch 4/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4807 - accuracy: 0.7905 - precision: 0.7905 - recall: 0.7905 - auc: 0.8623 - f1_score: 0.7905
# Epoch 4: val_loss improved from 0.45868 to 0.41906, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 52s 721ms/step - loss: 0.4807 - accuracy: 0.7905 - precision: 0.7905 - recall: 0.7905 - auc: 0.8623 - f1_score: 0.7905 - val_loss: 0.4191 - val_accuracy: 0.8136 - val_precision: 0.8136 - val_recall: 0.8136 - val_auc: 0.9219 - val_f1_score: 0.8136 - lr: 0.0010
# Epoch 5/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4686 - accuracy: 0.7958 - precision: 0.7958 - recall: 0.7958 - auc: 0.8687 - f1_score: 0.7958
# Epoch 5: val_loss improved from 0.41906 to 0.32687, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 53s 738ms/step - loss: 0.4686 - accuracy: 0.7958 - precision: 0.7958 - recall: 0.7958 - auc: 0.8687 - f1_score: 0.7958 - val_loss: 0.3269 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9739 - val_f1_score: 0.9201 - lr: 0.0010
# Epoch 6/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.7848 - precision: 0.7848 - recall: 0.7848 - auc: 0.8615 - f1_score: 0.7848
# Epoch 6: val_loss improved from 0.32687 to 0.32344, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 54s 750ms/step - loss: 0.4907 - accuracy: 0.7848 - precision: 0.7848 - recall: 0.7848 - auc: 0.8615 - f1_score: 0.7848 - val_loss: 0.3234 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9662 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 7/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4517 - accuracy: 0.8140 - precision: 0.8140 - recall: 0.8140 - auc: 0.8793 - f1_score: 0.8140
# Epoch 7: val_loss did not improve from 0.32344
# 71/71 [==============================] - 50s 704ms/step - loss: 0.4517 - accuracy: 0.8140 - precision: 0.8140 - recall: 0.8140 - auc: 0.8793 - f1_score: 0.8140 - val_loss: 0.3790 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9482 - val_f1_score: 0.8757 - lr: 0.0010
# Epoch 8/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4610 - accuracy: 0.8020 - precision: 0.8020 - recall: 0.8020 - auc: 0.8737 - f1_score: 0.8020
# Epoch 8: val_loss did not improve from 0.32344
# 71/71 [==============================] - 52s 720ms/step - loss: 0.4610 - accuracy: 0.8020 - precision: 0.8020 - recall: 0.8020 - auc: 0.8737 - f1_score: 0.8020 - val_loss: 0.4408 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9073 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 9/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4324 - accuracy: 0.8175 - precision: 0.8175 - recall: 0.8175 - auc: 0.8925 - f1_score: 0.8175
# Epoch 9: val_loss did not improve from 0.32344
# 71/71 [==============================] - 53s 733ms/step - loss: 0.4324 - accuracy: 0.8175 - precision: 0.8175 - recall: 0.8175 - auc: 0.8925 - f1_score: 0.8175 - val_loss: 0.3556 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9477 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 10/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4457 - accuracy: 0.8166 - precision: 0.8166 - recall: 0.8166 - auc: 0.8847 - f1_score: 0.8166
# Epoch 10: val_loss did not improve from 0.32344
# 71/71 [==============================] - 53s 736ms/step - loss: 0.4457 - accuracy: 0.8166 - precision: 0.8166 - recall: 0.8166 - auc: 0.8847 - f1_score: 0.8166 - val_loss: 0.3663 - val_accuracy: 0.8521 - val_precision: 0.8521 - val_recall: 0.8521 - val_auc: 0.9392 - val_f1_score: 0.8521 - lr: 0.0010
# Epoch 11/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4300 - accuracy: 0.8255 - precision: 0.8255 - recall: 0.8255 - auc: 0.8936 - f1_score: 0.8255
# Epoch 11: val_loss did not improve from 0.32344
# 71/71 [==============================] - 51s 710ms/step - loss: 0.4300 - accuracy: 0.8255 - precision: 0.8255 - recall: 0.8255 - auc: 0.8936 - f1_score: 0.8255 - val_loss: 0.3270 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9584 - val_f1_score: 0.8994 - lr: 0.0010
# Epoch 12/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4169 - accuracy: 0.8277 - precision: 0.8277 - recall: 0.8277 - auc: 0.8988 - f1_score: 0.8277
# Epoch 12: val_loss did not improve from 0.32344
# 71/71 [==============================] - 51s 711ms/step - loss: 0.4169 - accuracy: 0.8277 - precision: 0.8277 - recall: 0.8277 - auc: 0.8988 - f1_score: 0.8277 - val_loss: 0.4636 - val_accuracy: 0.7959 - val_precision: 0.7959 - val_recall: 0.7959 - val_auc: 0.8890 - val_f1_score: 0.7959 - lr: 0.0010
# Epoch 13/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4446 - accuracy: 0.8140 - precision: 0.8140 - recall: 0.8140 - auc: 0.8834 - f1_score: 0.8140
# Epoch 13: val_loss did not improve from 0.32344
# 71/71 [==============================] - 52s 726ms/step - loss: 0.4446 - accuracy: 0.8140 - precision: 0.8140 - recall: 0.8140 - auc: 0.8834 - f1_score: 0.8140 - val_loss: 0.7535 - val_accuracy: 0.5976 - val_precision: 0.5976 - val_recall: 0.5976 - val_auc: 0.6877 - val_f1_score: 0.5976 - lr: 0.0010
# Epoch 14/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4369 - accuracy: 0.8237 - precision: 0.8237 - recall: 0.8237 - auc: 0.8889 - f1_score: 0.8237
# Epoch 14: val_loss did not improve from 0.32344
# 71/71 [==============================] - 51s 709ms/step - loss: 0.4369 - accuracy: 0.8237 - precision: 0.8237 - recall: 0.8237 - auc: 0.8889 - f1_score: 0.8237 - val_loss: 0.4312 - val_accuracy: 0.7959 - val_precision: 0.7959 - val_recall: 0.7959 - val_auc: 0.8988 - val_f1_score: 0.7959 - lr: 0.0010
# Epoch 15/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.8405 - precision: 0.8405 - recall: 0.8405 - auc: 0.8993 - f1_score: 0.8405
# Epoch 15: val_loss did not improve from 0.32344
# 71/71 [==============================] - 53s 737ms/step - loss: 0.4146 - accuracy: 0.8405 - precision: 0.8405 - recall: 0.8405 - auc: 0.8993 - f1_score: 0.8405 - val_loss: 0.3550 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9414 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 16/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4058 - accuracy: 0.8356 - precision: 0.8356 - recall: 0.8356 - auc: 0.9028 - f1_score: 0.8356
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 16: val_loss did not improve from 0.32344
# 71/71 [==============================] - 53s 740ms/step - loss: 0.4058 - accuracy: 0.8356 - precision: 0.8356 - recall: 0.8356 - auc: 0.9028 - f1_score: 0.8356 - val_loss: 0.4072 - val_accuracy: 0.8314 - val_precision: 0.8314 - val_recall: 0.8314 - val_auc: 0.9103 - val_f1_score: 0.8314 - lr: 0.0010
# Epoch 17/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3460 - accuracy: 0.8758 - precision: 0.8758 - recall: 0.8758 - auc: 0.9308 - f1_score: 0.8758
# Epoch 17: val_loss improved from 0.32344 to 0.26907, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 52s 721ms/step - loss: 0.3460 - accuracy: 0.8758 - precision: 0.8758 - recall: 0.8758 - auc: 0.9308 - f1_score: 0.8758 - val_loss: 0.2691 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9721 - val_f1_score: 0.9142 - lr: 1.0000e-04
# Epoch 18/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3444 - accuracy: 0.8670 - precision: 0.8670 - recall: 0.8670 - auc: 0.9325 - f1_score: 0.8670
# Epoch 18: val_loss improved from 0.26907 to 0.24173, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 54s 757ms/step - loss: 0.3444 - accuracy: 0.8670 - precision: 0.8670 - recall: 0.8670 - auc: 0.9325 - f1_score: 0.8670 - val_loss: 0.2417 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9781 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 19/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3377 - accuracy: 0.8723 - precision: 0.8723 - recall: 0.8723 - auc: 0.9352 - f1_score: 0.8723
# Epoch 19: val_loss did not improve from 0.24173
# 71/71 [==============================] - 52s 720ms/step - loss: 0.3377 - accuracy: 0.8723 - precision: 0.8723 - recall: 0.8723 - auc: 0.9352 - f1_score: 0.8723 - val_loss: 0.2876 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9614 - val_f1_score: 0.8964 - lr: 1.0000e-04
# Epoch 20/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3386 - accuracy: 0.8745 - precision: 0.8745 - recall: 0.8745 - auc: 0.9346 - f1_score: 0.8745
# Epoch 20: val_loss improved from 0.24173 to 0.23916, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 54s 749ms/step - loss: 0.3386 - accuracy: 0.8745 - precision: 0.8745 - recall: 0.8745 - auc: 0.9346 - f1_score: 0.8745 - val_loss: 0.2392 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9771 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 21/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.8776 - precision: 0.8776 - recall: 0.8776 - auc: 0.9382 - f1_score: 0.8776
# Epoch 21: val_loss improved from 0.23916 to 0.20373, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 53s 740ms/step - loss: 0.3293 - accuracy: 0.8776 - precision: 0.8776 - recall: 0.8776 - auc: 0.9382 - f1_score: 0.8776 - val_loss: 0.2037 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9879 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 22/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3258 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9391 - f1_score: 0.8842
# Epoch 22: val_loss did not improve from 0.20373
# 71/71 [==============================] - 53s 736ms/step - loss: 0.3258 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9391 - f1_score: 0.8842 - val_loss: 0.2314 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9770 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 23/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3263 - accuracy: 0.8811 - precision: 0.8811 - recall: 0.8811 - auc: 0.9389 - f1_score: 0.8811
# Epoch 23: val_loss did not improve from 0.20373
# 71/71 [==============================] - 52s 724ms/step - loss: 0.3263 - accuracy: 0.8811 - precision: 0.8811 - recall: 0.8811 - auc: 0.9389 - f1_score: 0.8811 - val_loss: 0.2273 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9795 - val_f1_score: 0.9349 - lr: 1.0000e-04
# Epoch 24/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3293 - accuracy: 0.8811 - precision: 0.8811 - recall: 0.8811 - auc: 0.9371 - f1_score: 0.8811
# Epoch 24: val_loss did not improve from 0.20373
# 71/71 [==============================] - 54s 749ms/step - loss: 0.3293 - accuracy: 0.8811 - precision: 0.8811 - recall: 0.8811 - auc: 0.9371 - f1_score: 0.8811 - val_loss: 0.2373 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9755 - val_f1_score: 0.9290 - lr: 1.0000e-04
# Epoch 25/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3128 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9436 - f1_score: 0.8895
# Epoch 25: val_loss did not improve from 0.20373
# 71/71 [==============================] - 53s 742ms/step - loss: 0.3128 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9436 - f1_score: 0.8895 - val_loss: 0.2452 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9734 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 26/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3153 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9432 - f1_score: 0.8851
# Epoch 26: val_loss did not improve from 0.20373
# 71/71 [==============================] - 53s 742ms/step - loss: 0.3153 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9432 - f1_score: 0.8851 - val_loss: 0.2077 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9856 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 27/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3144 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9432 - f1_score: 0.8833
# Epoch 27: val_loss improved from 0.20373 to 0.19495, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 52s 731ms/step - loss: 0.3144 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9432 - f1_score: 0.8833 - val_loss: 0.1950 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9868 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 28/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3017 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9491 - f1_score: 0.8873
# Epoch 28: val_loss did not improve from 0.19495
# 71/71 [==============================] - 52s 732ms/step - loss: 0.3017 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9491 - f1_score: 0.8873 - val_loss: 0.2131 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9833 - val_f1_score: 0.9349 - lr: 1.0000e-04
# Epoch 29/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3049 - accuracy: 0.8869 - precision: 0.8869 - recall: 0.8869 - auc: 0.9482 - f1_score: 0.8869
# Epoch 29: val_loss did not improve from 0.19495
# 71/71 [==============================] - 51s 707ms/step - loss: 0.3049 - accuracy: 0.8869 - precision: 0.8869 - recall: 0.8869 - auc: 0.9482 - f1_score: 0.8869 - val_loss: 0.2185 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9776 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 30/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3015 - accuracy: 0.8891 - precision: 0.8891 - recall: 0.8891 - auc: 0.9490 - f1_score: 0.8891
# Epoch 30: val_loss did not improve from 0.19495
# 71/71 [==============================] - 53s 744ms/step - loss: 0.3015 - accuracy: 0.8891 - precision: 0.8891 - recall: 0.8891 - auc: 0.9490 - f1_score: 0.8891 - val_loss: 0.2357 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9726 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 31/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.8772 - precision: 0.8772 - recall: 0.8772 - auc: 0.9477 - f1_score: 0.8772
# Epoch 31: val_loss did not improve from 0.19495
# 71/71 [==============================] - 53s 735ms/step - loss: 0.3064 - accuracy: 0.8772 - precision: 0.8772 - recall: 0.8772 - auc: 0.9477 - f1_score: 0.8772 - val_loss: 0.2937 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9561 - val_f1_score: 0.8994 - lr: 1.0000e-04
# Epoch 32/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3128 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9447 - f1_score: 0.8833
# Epoch 32: val_loss did not improve from 0.19495
# 71/71 [==============================] - 53s 736ms/step - loss: 0.3128 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9447 - f1_score: 0.8833 - val_loss: 0.2510 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9693 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 33/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3009 - accuracy: 0.8847 - precision: 0.8847 - recall: 0.8847 - auc: 0.9490 - f1_score: 0.8847
# Epoch 33: val_loss improved from 0.19495 to 0.18527, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 51s 707ms/step - loss: 0.3009 - accuracy: 0.8847 - precision: 0.8847 - recall: 0.8847 - auc: 0.9490 - f1_score: 0.8847 - val_loss: 0.1853 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9869 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 34/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3040 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9484 - f1_score: 0.8833
# Epoch 34: val_loss improved from 0.18527 to 0.17457, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 54s 749ms/step - loss: 0.3040 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9484 - f1_score: 0.8833 - val_loss: 0.1746 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9889 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 35/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3030 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9485 - f1_score: 0.8798
# Epoch 35: val_loss did not improve from 0.17457
# 71/71 [==============================] - 52s 728ms/step - loss: 0.3030 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9485 - f1_score: 0.8798 - val_loss: 0.1952 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9870 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 36/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2926 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9522 - f1_score: 0.8939
# Epoch 36: val_loss improved from 0.17457 to 0.16539, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 53s 738ms/step - loss: 0.2926 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9522 - f1_score: 0.8939 - val_loss: 0.1654 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9892 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 37/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2873 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9538 - f1_score: 0.8926
# Epoch 37: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 717ms/step - loss: 0.2873 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9538 - f1_score: 0.8926 - val_loss: 0.1865 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9884 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 38/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2869 - accuracy: 0.8917 - precision: 0.8917 - recall: 0.8917 - auc: 0.9543 - f1_score: 0.8917
# Epoch 38: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 728ms/step - loss: 0.2869 - accuracy: 0.8917 - precision: 0.8917 - recall: 0.8917 - auc: 0.9543 - f1_score: 0.8917 - val_loss: 0.2038 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9865 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 39/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2904 - accuracy: 0.8847 - precision: 0.8847 - recall: 0.8847 - auc: 0.9541 - f1_score: 0.8847
# Epoch 39: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 747ms/step - loss: 0.2904 - accuracy: 0.8847 - precision: 0.8847 - recall: 0.8847 - auc: 0.9541 - f1_score: 0.8847 - val_loss: 0.2000 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9792 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 40/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2938 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9511 - f1_score: 0.8939
# Epoch 40: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 725ms/step - loss: 0.2938 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9511 - f1_score: 0.8939 - val_loss: 0.2075 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9850 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 41/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2853 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9553 - f1_score: 0.8904
# Epoch 41: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 736ms/step - loss: 0.2853 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9553 - f1_score: 0.8904 - val_loss: 0.2229 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9756 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 42/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2830 - accuracy: 0.8948 - precision: 0.8948 - recall: 0.8948 - auc: 0.9556 - f1_score: 0.8948
# Epoch 42: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 728ms/step - loss: 0.2830 - accuracy: 0.8948 - precision: 0.8948 - recall: 0.8948 - auc: 0.9556 - f1_score: 0.8948 - val_loss: 0.2315 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9749 - val_f1_score: 0.9290 - lr: 1.0000e-04
# Epoch 43/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2768 - accuracy: 0.8944 - precision: 0.8944 - recall: 0.8944 - auc: 0.9575 - f1_score: 0.8944
# Epoch 43: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 709ms/step - loss: 0.2768 - accuracy: 0.8944 - precision: 0.8944 - recall: 0.8944 - auc: 0.9575 - f1_score: 0.8944 - val_loss: 0.1859 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9844 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 44/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9549 - f1_score: 0.8939
# Epoch 44: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 713ms/step - loss: 0.2844 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9549 - f1_score: 0.8939 - val_loss: 0.1694 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9869 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 45/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2758 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9579 - f1_score: 0.8962
# Epoch 45: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 744ms/step - loss: 0.2758 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9579 - f1_score: 0.8962 - val_loss: 0.1885 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9863 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 46/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2831 - accuracy: 0.8913 - precision: 0.8913 - recall: 0.8913 - auc: 0.9559 - f1_score: 0.8913
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 46: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 739ms/step - loss: 0.2831 - accuracy: 0.8913 - precision: 0.8913 - recall: 0.8913 - auc: 0.9559 - f1_score: 0.8913 - val_loss: 0.1803 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9856 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 47/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2664 - accuracy: 0.9006 - precision: 0.9006 - recall: 0.9006 - auc: 0.9613 - f1_score: 0.9006
# Epoch 47: val_loss did not improve from 0.16539
# 71/71 [==============================] - 50s 701ms/step - loss: 0.2664 - accuracy: 0.9006 - precision: 0.9006 - recall: 0.9006 - auc: 0.9613 - f1_score: 0.9006 - val_loss: 0.1951 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9831 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 48/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2653 - accuracy: 0.8970 - precision: 0.8970 - recall: 0.8970 - auc: 0.9623 - f1_score: 0.8970
# Epoch 48: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 724ms/step - loss: 0.2653 - accuracy: 0.8970 - precision: 0.8970 - recall: 0.8970 - auc: 0.9623 - f1_score: 0.8970 - val_loss: 0.2068 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9822 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 49/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2561 - accuracy: 0.9068 - precision: 0.9068 - recall: 0.9068 - auc: 0.9648 - f1_score: 0.9068
# Epoch 49: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 739ms/step - loss: 0.2561 - accuracy: 0.9068 - precision: 0.9068 - recall: 0.9068 - auc: 0.9648 - f1_score: 0.9068 - val_loss: 0.1979 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9839 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 50/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2548 - accuracy: 0.8988 - precision: 0.8988 - recall: 0.8988 - auc: 0.9656 - f1_score: 0.8988
# Epoch 50: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 714ms/step - loss: 0.2548 - accuracy: 0.8988 - precision: 0.8988 - recall: 0.8988 - auc: 0.9656 - f1_score: 0.8988 - val_loss: 0.2183 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9779 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 51/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2477 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9679 - f1_score: 0.9103
# Epoch 51: val_loss did not improve from 0.16539
# 71/71 [==============================] - 50s 703ms/step - loss: 0.2477 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9679 - f1_score: 0.9103 - val_loss: 0.1907 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9839 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 52/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9642 - f1_score: 0.9019
# Epoch 52: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 723ms/step - loss: 0.2565 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9642 - f1_score: 0.9019 - val_loss: 0.2020 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9822 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 53/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2567 - accuracy: 0.9015 - precision: 0.9015 - recall: 0.9015 - auc: 0.9653 - f1_score: 0.9015
# Epoch 53: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 722ms/step - loss: 0.2567 - accuracy: 0.9015 - precision: 0.9015 - recall: 0.9015 - auc: 0.9653 - f1_score: 0.9015 - val_loss: 0.1979 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9841 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 54/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2515 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9663 - f1_score: 0.9076
# Epoch 54: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 732ms/step - loss: 0.2515 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9663 - f1_score: 0.9076 - val_loss: 0.1894 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9845 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 55/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2491 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9673 - f1_score: 0.9019
# Epoch 55: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 738ms/step - loss: 0.2491 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9673 - f1_score: 0.9019 - val_loss: 0.1969 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9828 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 56/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9028 - precision: 0.9028 - recall: 0.9028 - auc: 0.9669 - f1_score: 0.9028
# Epoch 56: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 56: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 736ms/step - loss: 0.2492 - accuracy: 0.9028 - precision: 0.9028 - recall: 0.9028 - auc: 0.9669 - f1_score: 0.9028 - val_loss: 0.2002 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9826 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 57/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2616 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9632 - f1_score: 0.8926
# Epoch 57: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 724ms/step - loss: 0.2616 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9632 - f1_score: 0.8926 - val_loss: 0.1924 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9842 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 58/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2454 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9685 - f1_score: 0.9063
# Epoch 58: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 705ms/step - loss: 0.2454 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9685 - f1_score: 0.9063 - val_loss: 0.2013 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9817 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 59/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2504 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9663 - f1_score: 0.9063
# Epoch 59: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 720ms/step - loss: 0.2504 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9663 - f1_score: 0.9063 - val_loss: 0.1872 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9844 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 60/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2495 - accuracy: 0.9046 - precision: 0.9046 - recall: 0.9046 - auc: 0.9668 - f1_score: 0.9046
# Epoch 60: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 730ms/step - loss: 0.2495 - accuracy: 0.9046 - precision: 0.9046 - recall: 0.9046 - auc: 0.9668 - f1_score: 0.9046 - val_loss: 0.2031 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9816 - val_f1_score: 0.9172 - lr: 1.0000e-05
# Epoch 61/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2462 - accuracy: 0.9107 - precision: 0.9107 - recall: 0.9107 - auc: 0.9679 - f1_score: 0.9107
# Epoch 61: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 735ms/step - loss: 0.2462 - accuracy: 0.9107 - precision: 0.9107 - recall: 0.9107 - auc: 0.9679 - f1_score: 0.9107 - val_loss: 0.1999 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9792 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 62/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2518 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9660 - f1_score: 0.8992
# Epoch 62: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 709ms/step - loss: 0.2518 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9660 - f1_score: 0.8992 - val_loss: 0.1964 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9840 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 63/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2520 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9662 - f1_score: 0.9054
# Epoch 63: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 742ms/step - loss: 0.2520 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9662 - f1_score: 0.9054 - val_loss: 0.1917 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9833 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 64/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2547 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9656 - f1_score: 0.9019
# Epoch 64: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 724ms/step - loss: 0.2547 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9656 - f1_score: 0.9019 - val_loss: 0.1968 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9824 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 65/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2565 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9647 - f1_score: 0.9054
# Epoch 65: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 733ms/step - loss: 0.2565 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9647 - f1_score: 0.9054 - val_loss: 0.1947 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9810 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 66/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2391 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9700 - f1_score: 0.9085
# Epoch 66: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 737ms/step - loss: 0.2391 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9700 - f1_score: 0.9085 - val_loss: 0.1960 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9812 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 67/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2446 - accuracy: 0.9046 - precision: 0.9046 - recall: 0.9046 - auc: 0.9683 - f1_score: 0.9046
# Epoch 67: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 716ms/step - loss: 0.2446 - accuracy: 0.9046 - precision: 0.9046 - recall: 0.9046 - auc: 0.9683 - f1_score: 0.9046 - val_loss: 0.1865 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9842 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 68/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2462 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9685 - f1_score: 0.9023
# Epoch 68: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 736ms/step - loss: 0.2462 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9685 - f1_score: 0.9023 - val_loss: 0.1938 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9822 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 69/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2447 - accuracy: 0.9046 - precision: 0.9046 - recall: 0.9046 - auc: 0.9681 - f1_score: 0.9046
# Epoch 69: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 731ms/step - loss: 0.2447 - accuracy: 0.9046 - precision: 0.9046 - recall: 0.9046 - auc: 0.9681 - f1_score: 0.9046 - val_loss: 0.2261 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9754 - val_f1_score: 0.9172 - lr: 1.0000e-05
# Epoch 70/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2507 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9666 - f1_score: 0.9010
# Epoch 70: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 713ms/step - loss: 0.2507 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9666 - f1_score: 0.9010 - val_loss: 0.2016 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9826 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 71/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2476 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9672 - f1_score: 0.9063
# Epoch 71: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 722ms/step - loss: 0.2476 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9672 - f1_score: 0.9063 - val_loss: 0.1946 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9817 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 72/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9711 - f1_score: 0.9054
# Epoch 72: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 724ms/step - loss: 0.2360 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9711 - f1_score: 0.9054 - val_loss: 0.2142 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9760 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 73/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2379 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9701 - f1_score: 0.9076
# Epoch 73: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 709ms/step - loss: 0.2379 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9701 - f1_score: 0.9076 - val_loss: 0.2278 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9750 - val_f1_score: 0.9112 - lr: 1.0000e-05
# Epoch 74/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2521 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9660 - f1_score: 0.9023
# Epoch 74: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 730ms/step - loss: 0.2521 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9660 - f1_score: 0.9023 - val_loss: 0.2093 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9777 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 75/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2427 - accuracy: 0.9059 - precision: 0.9059 - recall: 0.9059 - auc: 0.9689 - f1_score: 0.9059
# Epoch 75: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 723ms/step - loss: 0.2427 - accuracy: 0.9059 - precision: 0.9059 - recall: 0.9059 - auc: 0.9689 - f1_score: 0.9059 - val_loss: 0.1927 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9817 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 76/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9032 - precision: 0.9032 - recall: 0.9032 - auc: 0.9700 - f1_score: 0.9032
# Epoch 76: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 721ms/step - loss: 0.2399 - accuracy: 0.9032 - precision: 0.9032 - recall: 0.9032 - auc: 0.9700 - f1_score: 0.9032 - val_loss: 0.2231 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9747 - val_f1_score: 0.9172 - lr: 1.0000e-05
# Epoch 77/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2435 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9683 - f1_score: 0.9037
# Epoch 77: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 721ms/step - loss: 0.2435 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9683 - f1_score: 0.9037 - val_loss: 0.2309 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9737 - val_f1_score: 0.9112 - lr: 1.0000e-05
# Epoch 78/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2457 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9680 - f1_score: 0.9090
# Epoch 78: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 705ms/step - loss: 0.2457 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9680 - f1_score: 0.9090 - val_loss: 0.2282 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9730 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 79/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9694 - f1_score: 0.9085
# Epoch 79: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 731ms/step - loss: 0.2399 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9694 - f1_score: 0.9085 - val_loss: 0.2129 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9780 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 80/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9707 - f1_score: 0.9103
# Epoch 80: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 726ms/step - loss: 0.2352 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9707 - f1_score: 0.9103 - val_loss: 0.1896 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9832 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 81/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2360 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9700 - f1_score: 0.9085
# Epoch 81: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 710ms/step - loss: 0.2360 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9700 - f1_score: 0.9085 - val_loss: 0.1925 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9823 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 82/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2398 - accuracy: 0.9059 - precision: 0.9059 - recall: 0.9059 - auc: 0.9692 - f1_score: 0.9059
# Epoch 82: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 721ms/step - loss: 0.2398 - accuracy: 0.9059 - precision: 0.9059 - recall: 0.9059 - auc: 0.9692 - f1_score: 0.9059 - val_loss: 0.1994 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9815 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 83/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2484 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9666 - f1_score: 0.9054
# Epoch 83: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 720ms/step - loss: 0.2484 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9666 - f1_score: 0.9054 - val_loss: 0.2201 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9756 - val_f1_score: 0.9172 - lr: 1.0000e-05
# Epoch 84/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2442 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9685 - f1_score: 0.9050
# Epoch 84: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 717ms/step - loss: 0.2442 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9685 - f1_score: 0.9050 - val_loss: 0.1946 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9820 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 85/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9059 - precision: 0.9059 - recall: 0.9059 - auc: 0.9713 - f1_score: 0.9059
# Epoch 85: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 734ms/step - loss: 0.2347 - accuracy: 0.9059 - precision: 0.9059 - recall: 0.9059 - auc: 0.9713 - f1_score: 0.9059 - val_loss: 0.1915 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9820 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 86/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2272 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9730 - f1_score: 0.9125
# Epoch 86: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 725ms/step - loss: 0.2272 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9730 - f1_score: 0.9125 - val_loss: 0.1778 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9854 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 87/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2351 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9710 - f1_score: 0.9081
# Epoch 87: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 734ms/step - loss: 0.2351 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9710 - f1_score: 0.9081 - val_loss: 0.2030 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9805 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 88/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9697 - f1_score: 0.9076
# Epoch 88: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 742ms/step - loss: 0.2385 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9697 - f1_score: 0.9076 - val_loss: 0.2070 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9788 - val_f1_score: 0.9172 - lr: 1.0000e-05
# Epoch 89/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2408 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9695 - f1_score: 0.9081
# Epoch 89: val_loss did not improve from 0.16539
# ...
# Epoch 121/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2210 - accuracy: 0.9138 - precision: 0.9138 - recall: 0.9138 - auc: 0.9744 - f1_score: 0.9138
# Epoch 121: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 725ms/step - loss: 0.2210 - accuracy: 0.9138 - precision: 0.9138 - recall: 0.9138 - auc: 0.9744 - f1_score: 0.9138 - val_loss: 0.2019 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9801 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 122/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2209 - accuracy: 0.9183 - precision: 0.9183 - recall: 0.9183 - auc: 0.9741 - f1_score: 0.9183
# Epoch 122: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 707ms/step - loss: 0.2209 - accuracy: 0.9183 - precision: 0.9183 - recall: 0.9183 - auc: 0.9741 - f1_score: 0.9183 - val_loss: 0.1944 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9819 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 123/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2188 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9748 - f1_score: 0.9178
# Epoch 123: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 735ms/step - loss: 0.2188 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9748 - f1_score: 0.9178 - val_loss: 0.1859 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9832 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 124/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2254 - accuracy: 0.9107 - precision: 0.9107 - recall: 0.9107 - auc: 0.9731 - f1_score: 0.9107
# Epoch 124: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 712ms/step - loss: 0.2254 - accuracy: 0.9107 - precision: 0.9107 - recall: 0.9107 - auc: 0.9731 - f1_score: 0.9107 - val_loss: 0.2053 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9795 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 125/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2145 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9755 - f1_score: 0.9191
# Epoch 125: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 717ms/step - loss: 0.2145 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9755 - f1_score: 0.9191 - val_loss: 0.1870 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9825 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 126/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2236 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9734 - f1_score: 0.9112
# Epoch 126: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 737ms/step - loss: 0.2236 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9734 - f1_score: 0.9112 - val_loss: 0.1774 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9843 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 127/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2166 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9755 - f1_score: 0.9134
# Epoch 127: val_loss did not improve from 0.16539
# 71/71 [==============================] - 51s 719ms/step - loss: 0.2166 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9755 - f1_score: 0.9134 - val_loss: 0.1866 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9831 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 128/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2166 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9748 - f1_score: 0.9187
# Epoch 128: val_loss did not improve from 0.16539
# 71/71 [==============================] - 53s 746ms/step - loss: 0.2166 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9748 - f1_score: 0.9187 - val_loss: 0.2003 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9809 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 129/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9129 - precision: 0.9129 - recall: 0.9129 - auc: 0.9739 - f1_score: 0.9129
# Epoch 129: val_loss did not improve from 0.16539
# 71/71 [==============================] - 52s 729ms/step - loss: 0.2217 - accuracy: 0.9129 - precision: 0.9129 - recall: 0.9129 - auc: 0.9739 - f1_score: 0.9129 - val_loss: 0.2283 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9732 - val_f1_score: 0.9083 - lr: 1.0000e-05
# Epoch 130/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2146 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9757 - f1_score: 0.9165
# Epoch 130: val_loss improved from 0.16539 to 0.16153, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 53s 740ms/step - loss: 0.2146 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9757 - f1_score: 0.9165 - val_loss: 0.1615 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9903 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 131/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2156 - accuracy: 0.9143 - precision: 0.9143 - recall: 0.9143 - auc: 0.9755 - f1_score: 0.9143
# Epoch 131: val_loss did not improve from 0.16153
# 71/71 [==============================] - 53s 743ms/step - loss: 0.2156 - accuracy: 0.9143 - precision: 0.9143 - recall: 0.9143 - auc: 0.9755 - f1_score: 0.9143 - val_loss: 0.1696 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9864 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 132/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9739 - f1_score: 0.9125
# Epoch 132: val_loss did not improve from 0.16153
# 71/71 [==============================] - 53s 734ms/step - loss: 0.2224 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9739 - f1_score: 0.9125 - val_loss: 0.1942 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9814 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 133/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2235 - accuracy: 0.9129 - precision: 0.9129 - recall: 0.9129 - auc: 0.9738 - f1_score: 0.9129
# Epoch 133: val_loss improved from 0.16153 to 0.15321, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8-DIR_run2.h5
# 71/71 [==============================] - 53s 744ms/step - loss: 0.2235 - accuracy: 0.9129 - precision: 0.9129 - recall: 0.9129 - auc: 0.9738 - f1_score: 0.9129 - val_loss: 0.1532 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9895 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 134/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2208 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9743 - f1_score: 0.9187
# Epoch 134: val_loss did not improve from 0.15321
# 71/71 [==============================] - 52s 727ms/step - loss: 0.2208 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9743 - f1_score: 0.9187 - val_loss: 0.1784 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9841 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 135/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2214 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9741 - f1_score: 0.9152
# Epoch 135: val_loss did not improve from 0.15321
# 71/71 [==============================] - 51s 719ms/step - loss: 0.2214 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9741 - f1_score: 0.9152 - val_loss: 0.1877 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9832 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 136/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2161 - accuracy: 0.9156 - precision: 0.9156 - recall: 0.9156 - auc: 0.9754 - f1_score: 0.9156
# Epoch 136: val_loss did not improve from 0.15321
# 71/71 [==============================] - 52s 721ms/step - loss: 0.2161 - accuracy: 0.9156 - precision: 0.9156 - recall: 0.9156 - auc: 0.9754 - f1_score: 0.9156 - val_loss: 0.1711 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9861 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 137/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2084 - accuracy: 0.9227 - precision: 0.9227 - recall: 0.9227 - auc: 0.9772 - f1_score: 0.9227
# Epoch 137: val_loss did not improve from 0.15321
# 71/71 [==============================] - 53s 743ms/step - loss: 0.2084 - accuracy: 0.9227 - precision: 0.9227 - recall: 0.9227 - auc: 0.9772 - f1_score: 0.9227 - val_loss: 0.1664 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9874 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 138/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9746 - f1_score: 0.9165
# Epoch 138: val_loss did not improve from 0.15321
# 71/71 [==============================] - 51s 710ms/step - loss: 0.2187 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9746 - f1_score: 0.9165 - val_loss: 0.1678 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9868 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 139/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2095 - accuracy: 0.9121 - precision: 0.9121 - recall: 0.9121 - auc: 0.9773 - f1_score: 0.9121
# Epoch 139: val_loss did not improve from 0.15321
# 71/71 [==============================] - 52s 726ms/step - loss: 0.2095 - accuracy: 0.9121 - precision: 0.9121 - recall: 0.9121 - auc: 0.9773 - f1_score: 0.9121 - val_loss: 0.1891 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9821 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 140/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2136 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9759 - f1_score: 0.9191
# Epoch 140: val_loss did not improve from 0.15321
# 71/71 [==============================] - 51s 713ms/step - loss: 0.2136 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9759 - f1_score: 0.9191 - val_loss: 0.1814 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9848 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 141/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2114 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9762 - f1_score: 0.9178
# Epoch 141: val_loss did not improve from 0.15321
# 71/71 [==============================] - 51s 710ms/step - loss: 0.2114 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9762 - f1_score: 0.9178 - val_loss: 0.1892 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9817 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 142/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2092 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9766 - f1_score: 0.9200
# Epoch 142: val_loss did not improve from 0.15321
# 71/71 [==============================] - 51s 706ms/step - loss: 0.2092 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9766 - f1_score: 0.9200 - val_loss: 0.1836 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9840 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 143/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2163 - accuracy: 0.9196 - precision: 0.9196 - recall: 0.9196 - auc: 0.9750 - f1_score: 0.9196
# Epoch 143: val_loss did not improve from 0.15321
# 71/71 [==============================] - 51s 709ms/step - loss: 0.2163 - accuracy: 0.9196 - precision: 0.9196 - recall: 0.9196 - auc: 0.9750 - f1_score: 0.9196 - val_loss: 0.1679 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9868 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 144/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2152 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9754 - f1_score: 0.9187
# Epoch 144: val_loss did not improve from 0.15321
# 71/71 [==============================] - 52s 726ms/step - loss: 0.2152 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9754 - f1_score: 0.9187 - val_loss: 0.1781 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9857 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 145/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9798 - f1_score: 0.9178
# Epoch 145: val_loss did not improve from 0.15321
# 71/71 [==============================] - 52s 728ms/step - loss: 0.1984 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9798 - f1_score: 0.9178 - val_loss: 0.1876 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9827 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 146/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2128 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9758 - f1_score: 0.9165
# Epoch 146: val_loss did not improve from 0.15321
# 71/71 [==============================] - 51s 717ms/step - loss: 0.2128 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9758 - f1_score: 0.9165 - val_loss: 0.1629 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9870 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 147/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2123 - accuracy: 0.9196 - precision: 0.9196 - recall: 0.9196 - auc: 0.9759 - f1_score: 0.9196
# Epoch 147: val_loss did not improve from 0.15321
# 71/71 [==============================] - 53s 735ms/step - loss: 0.2123 - accuracy: 0.9196 - precision: 0.9196 - recall: 0.9196 - auc: 0.9759 - f1_score: 0.9196 - val_loss: 0.1686 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9862 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 148/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2186 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9749 - f1_score: 0.9134
# Epoch 148: val_loss did not improve from 0.15321
# 71/71 [==============================] - 51s 718ms/step - loss: 0.2186 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9749 - f1_score: 0.9134 - val_loss: 0.1718 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9868 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 149/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2108 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9765 - f1_score: 0.9174
# Epoch 149: val_loss did not improve from 0.15321
# 71/71 [==============================] - 51s 711ms/step - loss: 0.2108 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9765 - f1_score: 0.9174 - val_loss: 0.1604 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9888 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 150/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2133 - accuracy: 0.9156 - precision: 0.9156 - recall: 0.9156 - auc: 0.9760 - f1_score: 0.9156
# Epoch 150: val_loss did not improve from 0.15321
# 71/71 [==============================] - 52s 728ms/step - loss: 0.2133 - accuracy: 0.9156 - precision: 0.9156 - recall: 0.9156 - auc: 0.9760 - f1_score: 0.9156 - val_loss: 0.1582 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9893 - val_f1_score: 0.9408 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

# plt.subplot(2, 3, 5)
# plt.plot(range(1, len(f1_score_callback.train_f1_scores) + 1), f1_score_callback.train_f1_scores, label='Training F1 Score')
# plt.plot(range(1, len(f1_score_callback.val_f1_scores) + 1), f1_score_callback.val_f1_scores, label='Validation F1 Score')
# plt.title('Model F1-Score')
# plt.xlabel('Epoch')
# plt.ylabel('F1-Score')
# plt.legend(['F1 Score'], loc='lower right')


plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = DIR.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 2s 118ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.8984375
# F1-Score for each class: [0.86458333 0.93229167]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9132653061224489
# specificity: 0.9021739130434783

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  DIR.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 1s 117ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = DIR.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)

# test_loss, test_acc, test_precision, test_recall, test_auc = DIR.evaluate(test_generator)
# print('Test loss:', test_loss)
# print('Test accuracy:', test_acc)
# print('Test precision:', test_precision)
# print('Test recall:', test_recall)
# print('Test AUC:', test_auc)


# from sklearn.metrics import f1_score
# import numpy as np

# # 预测测试集
# y_pred = DIR.predict(test_generator)
# y_pred = np.argmax(y_pred, axis=1)

# # 真实标签
# y_true = test_generator.classes

# # 计算F1分数
# test_f1_score = f1_score(y_true, y_pred, average='micro')  # 或者根据你的需要选择其他average参数
# print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 2s 159ms/step - loss: 0.2535 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9647 - f1_score: 0.9112
# Test loss: 0.25352880358695984
# Test accuracy: 0.9111841917037964
# Test precision: 0.9111841917037964
# Test recall: 0.9111841917037964
# Test AUC: 0.9646706581115723
# Test F1 Score: 0.9111841917037964

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = DIR.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 1s 118ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.90      0.86        92
#            1       0.95      0.91      0.93       196
#
#     accuracy                           0.91       288
#    macro avg       0.89      0.91      0.90       288
# weighted avg       0.91      0.91      0.91       288

# %% [markdown]
# #delete the model to prevent memory costs
#
# from keras import backend as K
# import gc
#
# K.clear_session()
# gc.collect()
#
# # del DIR
#
#
# from numba import cuda
#
# cuda.select_device(0)
# cuda.close()
