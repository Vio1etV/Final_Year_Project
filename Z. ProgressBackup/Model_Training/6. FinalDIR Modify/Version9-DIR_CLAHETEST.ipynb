# %% [markdown]
# 再version 6的基础上，batchsize = 32， stem第一层变为4，用leaky relu，将inception a的函数里面的分支第一层神经元改为8
#
# 在Version 7的及基础上，加入L1正则化
#
# 进行CLAHE 图片测试，研究颜色对于图片的识别是否有影响

# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import shutil
import os

directories = ['/root/Breast Cancer/Datasets/40XResizedCLAHE/train',
               '/root/Breast Cancer/Datasets/40XResizedCLAHE/test']

for directory in directories:
    checkpoints_path = os.path.join(directory, '.ipynb_checkpoints')
    if os.path.exists(checkpoints_path):
        shutil.rmtree(checkpoints_path)
        print(f"Removed: {checkpoints_path}")
# Out:
# Removed: /root/Breast Cancer/Datasets/40XResizedCLAHE/train/.ipynb_checkpoints
# Removed: /root/Breast Cancer/Datasets/40XResizedCLAHE/test/.ipynb_checkpoints

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.regularizers import l2

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResizedCLAHE/test'
train_dir = '/root/Breast Cancer/Datasets/40XResizedCLAHE/train'


batch_size = 32
num_classes = 2

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResizedCLAHE/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 298 images belonging to 2 classes.

# %%
# 打印训练集的类别及其索引
print("Training Set Classes:")
print(train_generator.class_indices)

# 打印验证集的类别及其索引
print("Validation Set Classes:")
print(validation_generator.class_indices)

# 打印测试集的类别及其索引
print("Test Set Classes:")
print(test_generator.class_indices)
# Out:
# Training Set Classes:
# {'benign': 0, 'malignant': 1}
# Validation Set Classes:
# {'benign': 0, 'malignant': 1}
# Test Set Classes:
# {'benign': 0, 'malignant': 1}

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

l2_reg = 0.001



def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='leaky_relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)
    
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    # a = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    c = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = attention_block_2(x)

    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    # c = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 5
num_B_blocks = 10
num_C_blocks = 5

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.3)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax', kernel_regularizer = l2(l2_reg))(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# 2024-03-10 17:23:19.166901: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-10 17:23:19.877344: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22134 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:b1:00.0, compute capability: 8.9
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 4)  112         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 222, 222, 96  3552        ['conv2d[0][0]']
#                                 )
#
#  activation (Activation)        (None, 222, 222, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 222, 222, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 222, 222, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 222, 222, 4)  0           ['conv2d[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 220, 220, 4)  148         ['multiply[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 220, 220, 96  3552        ['conv2d_3[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 220, 220, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 220, 220, 1)  97          ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 220, 220, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 220, 220, 4)  0           ['conv2d_3[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 220, 220, 8)  296         ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 220, 220, 96  7008        ['conv2d_6[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 220, 220, 96  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 220, 220, 1)  97          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 220, 220, 1)  0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 220, 220, 8)  0           ['conv2d_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['multiply_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 218, 218, 12  876         ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_13[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_16[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_6 (Activation)      (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 16  160        ['conv2d_18[0][0]']
#  v2D)                           )
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_17[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['activation_6[0][0]',
#                                 )                                 'conv2d_21[0][0]']
#
#  activation_7 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_23[0][0]']
#  onv2D)                         )
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_24[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_22[0][0]',
#                                 )                                 'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 214, 214, 48  0           ['activation_7[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  activation_8 (Activation)      (None, 214, 214, 48  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_28[0][0]']
#  onv2D)                         )
#
#  conv2d_30 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_29[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_27[0][0]',
#                                 )                                 'depthwise_conv2d_2[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_5[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 214, 214, 48  0           ['activation_8[0][0]',
#                                 )                                 'conv2d_31[0][0]']
#
#  activation_9 (Activation)      (None, 214, 214, 48  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_33[0][0]']
#  onv2D)                         )
#
#  conv2d_35 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_34[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_32[0][0]',
#                                 )                                 'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_6[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 214, 214, 48  0           ['activation_9[0][0]',
#                                 )                                 'conv2d_36[0][0]']
#
#  activation_10 (Activation)     (None, 214, 214, 48  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_38[0][0]']
#  onv2D)                         )
#
#  conv2d_40 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_39[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_37[0][0]',
#                                 )                                 'depthwise_conv2d_4[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_7[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 214, 214, 48  0           ['activation_10[0][0]',
#                                 )                                 'conv2d_41[0][0]']
#
#  activation_11 (Activation)     (None, 214, 214, 48  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 214, 214, 32  1568        ['activation_11[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_43[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_11[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 106, 106, 48  20784       ['activation_11[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_44[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_42[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_49[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_46[0][0]',
#                                 )                                 'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_9[0][0]']
#                                 4)
#
#  add_5 (Add)                    (None, 106, 106, 14  0           ['concatenate_8[0][0]',
#                                 4)                                'conv2d_51[0][0]']
#
#  activation_12 (Activation)     (None, 106, 106, 14  0           ['add_5[0][0]']
#                                 4)
#
#  conv2d_53 (Conv2D)             (None, 106, 106, 16  2320        ['activation_12[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 106, 106, 24  3480        ['activation_12[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_55[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_52[0][0]',
#                                 )                                 'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_10[0][0]']
#                                 4)
#
#  add_6 (Add)                    (None, 106, 106, 14  0           ['activation_12[0][0]',
#                                 4)                                'conv2d_57[0][0]']
#
#  activation_13 (Activation)     (None, 106, 106, 14  0           ['add_6[0][0]']
#                                 4)
#
#  conv2d_59 (Conv2D)             (None, 106, 106, 16  2320        ['activation_13[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_59[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_60[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 106, 106, 24  3480        ['activation_13[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_61[0][0]']
#                                 )
#
#  concatenate_11 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_58[0][0]',
#                                 )                                 'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_11[0][0]']
#                                 4)
#
#  add_7 (Add)                    (None, 106, 106, 14  0           ['activation_13[0][0]',
#                                 4)                                'conv2d_63[0][0]']
#
#  activation_14 (Activation)     (None, 106, 106, 14  0           ['add_7[0][0]']
#                                 4)
#
#  conv2d_65 (Conv2D)             (None, 106, 106, 16  2320        ['activation_14[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_65[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_66[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 106, 106, 24  3480        ['activation_14[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_67[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_64[0][0]',
#                                 )                                 'conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_12[0][0]']
#                                 4)
#
#  add_8 (Add)                    (None, 106, 106, 14  0           ['activation_14[0][0]',
#                                 4)                                'conv2d_69[0][0]']
#
#  activation_15 (Activation)     (None, 106, 106, 14  0           ['add_8[0][0]']
#                                 4)
#
#  conv2d_71 (Conv2D)             (None, 106, 106, 16  2320        ['activation_15[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_71[0][0]']
#                                 )
#
#  conv2d_73 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_72[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 106, 106, 24  3480        ['activation_15[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_73[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_70[0][0]',
#                                 )                                 'conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_13[0][0]']
#                                 4)
#
#  add_9 (Add)                    (None, 106, 106, 14  0           ['activation_15[0][0]',
#                                 4)                                'conv2d_75[0][0]']
#
#  activation_16 (Activation)     (None, 106, 106, 14  0           ['add_9[0][0]']
#                                 4)
#
#  conv2d_77 (Conv2D)             (None, 106, 106, 16  2320        ['activation_16[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_77[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_78[0][0]']
#                                 )
#
#  conv2d_76 (Conv2D)             (None, 106, 106, 24  3480        ['activation_16[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_79[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_76[0][0]',
#                                 )                                 'conv2d_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_14[0][0]']
#                                 4)
#
#  add_10 (Add)                   (None, 106, 106, 14  0           ['activation_16[0][0]',
#                                 4)                                'conv2d_81[0][0]']
#
#  activation_17 (Activation)     (None, 106, 106, 14  0           ['add_10[0][0]']
#                                 4)
#
#  conv2d_83 (Conv2D)             (None, 106, 106, 16  2320        ['activation_17[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_83[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_84[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 106, 106, 24  3480        ['activation_17[0][0]']
#                                 )
#
#  conv2d_86 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_85[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_82[0][0]',
#                                 )                                 'conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_15[0][0]']
#                                 4)
#
#  add_11 (Add)                   (None, 106, 106, 14  0           ['activation_17[0][0]',
#                                 4)                                'conv2d_87[0][0]']
#
#  activation_18 (Activation)     (None, 106, 106, 14  0           ['add_11[0][0]']
#                                 4)
#
#  conv2d_89 (Conv2D)             (None, 106, 106, 16  2320        ['activation_18[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_89[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_90[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 106, 106, 24  3480        ['activation_18[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_91[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_88[0][0]',
#                                 )                                 'conv2d_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_16[0][0]']
#                                 4)
#
#  add_12 (Add)                   (None, 106, 106, 14  0           ['activation_18[0][0]',
#                                 4)                                'conv2d_93[0][0]']
#
#  activation_19 (Activation)     (None, 106, 106, 14  0           ['add_12[0][0]']
#                                 4)
#
#  conv2d_95 (Conv2D)             (None, 106, 106, 16  2320        ['activation_19[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_95[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_96[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 106, 106, 24  3480        ['activation_19[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_97[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_94[0][0]',
#                                 )                                 'conv2d_98[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_17[0][0]']
#                                 4)
#
#  add_13 (Add)                   (None, 106, 106, 14  0           ['activation_19[0][0]',
#                                 4)                                'conv2d_99[0][0]']
#
#  activation_20 (Activation)     (None, 106, 106, 14  0           ['add_13[0][0]']
#                                 4)
#
#  conv2d_101 (Conv2D)            (None, 106, 106, 16  2320        ['activation_20[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 106, 106, 20  2260        ['conv2d_101[0][0]']
#                                 )
#
#  conv2d_103 (Conv2D)            (None, 106, 106, 24  3384        ['conv2d_102[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 106, 106, 24  3480        ['activation_20[0][0]']
#                                 )
#
#  conv2d_104 (Conv2D)            (None, 106, 106, 24  600         ['conv2d_103[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_100[0][0]',
#                                 )                                 'conv2d_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 106, 106, 14  7056        ['concatenate_18[0][0]']
#                                 4)
#
#  add_14 (Add)                   (None, 106, 106, 14  0           ['activation_20[0][0]',
#                                 4)                                'conv2d_105[0][0]']
#
#  activation_21 (Activation)     (None, 106, 106, 14  0           ['add_14[0][0]']
#                                 4)
#
#  conv2d_110 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_106 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_108 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_111 (Conv2D)            (None, 106, 106, 36  10404       ['conv2d_110[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_21[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_106[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_108[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 52, 52, 40)   13000       ['conv2d_111[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_107[0][0]',
#                                                                   'conv2d_109[0][0]',
#                                                                   'conv2d_112[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_114[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_115[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_113[0][0]',
#                                                                   'conv2d_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_20[0][0]']
#
#  add_15 (Add)                   (None, 52, 52, 256)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_117[0][0]']
#
#  activation_22 (Activation)     (None, 52, 52, 256)  0           ['add_15[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_119[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_120[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_118[0][0]',
#                                                                   'conv2d_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_21[0][0]']
#
#  add_16 (Add)                   (None, 52, 52, 256)  0           ['activation_22[0][0]',
#                                                                   'conv2d_122[0][0]']
#
#  activation_23 (Activation)     (None, 52, 52, 256)  0           ['add_16[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_124[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_125[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_123[0][0]',
#                                                                   'conv2d_126[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_22[0][0]']
#
#  add_17 (Add)                   (None, 52, 52, 256)  0           ['activation_23[0][0]',
#                                                                   'conv2d_127[0][0]']
#
#  activation_24 (Activation)     (None, 52, 52, 256)  0           ['add_17[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_129[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_130[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_128[0][0]',
#                                                                   'conv2d_131[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_23[0][0]']
#
#  add_18 (Add)                   (None, 52, 52, 256)  0           ['activation_24[0][0]',
#                                                                   'conv2d_132[0][0]']
#
#  activation_25 (Activation)     (None, 52, 52, 256)  0           ['add_18[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_134[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_135[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_133[0][0]',
#                                                                   'conv2d_136[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_24[0][0]']
#
#  add_19 (Add)                   (None, 52, 52, 256)  0           ['activation_25[0][0]',
#                                                                   'conv2d_137[0][0]']
#
#  activation_26 (Activation)     (None, 52, 52, 256)  0           ['add_19[0][0]']
#
#  dropout (Dropout)              (None, 52, 52, 256)  0           ['activation_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 505,821
# Trainable params: 505,821
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# import numpy as np
# from sklearn.metrics import f1_score
# from tensorflow.keras.callbacks import Callback

# class F1ScoreCallback(Callback):
#     def __init__(self, train_generator, validation_generator, num_classes):
#         super(F1ScoreCallback, self).__init__()
#         self.train_generator = train_generator
#         self.validation_generator = validation_generator
#         self.num_classes = num_classes
#         self.train_f1_scores = []
#         self.val_f1_scores = []

#     def on_epoch_end(self, epoch, logs=None):
#         # 计算训练集F1分数
#         train_predict, train_true = self._get_predictions_and_true_labels(self.train_generator)
#         train_f1 = f1_score(train_true, train_predict, average='micro')
#         self.train_f1_scores.append(train_f1)
        
#         # 计算验证集F1分数
#         val_predict, val_true = self._get_predictions_and_true_labels(self.validation_generator)
#         val_f1 = f1_score(val_true, val_predict, average='micro')
#         self.val_f1_scores.append(val_f1)
        
#         print(f'Epoch {epoch+1}: Training F1 Score: {train_f1}, Validation F1 Score: {val_f1}')

#     def _get_predictions_and_true_labels(self, generator):
#         predictions = []
#         true_labels = []
#         for i in range(len(generator)):
#             x_batch, y_batch_true = next(generator)
#             y_batch_pred = self.model.predict(x_batch, verbose=0)
#             y_batch_pred = np.argmax(y_batch_pred, axis=1)
#             y_true = np.argmax(y_batch_true, axis=1)
#             predictions.extend(y_batch_pred)
#             true_labels.extend(y_true)
#         return predictions, true_labels


# # 继续使用之前的方式将回调添加到你的模型训练中

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(),
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version9_CLAHE-DIR"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)


lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', 
                                 factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# f1_score_callback = F1ScoreCallback(train_generator = train_generator, 
#                                     validation_generator=validation_generator, 
#                                     num_classes=num_classes)


from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = DIR.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)


# history = DIR.fit(
#     train_generator,
#     epochs=150,
#     validation_data=validation_generator,
#     callbacks=[csv_logger, lr_reduction, model_checkpoint_callback, f1_score_callback]
# )
# Out:
# Epoch 1/150
# 2024-03-10 17:23:31.636773: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-10 17:23:32.623107: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-03-10 17:23:32.623127: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2024-03-10 17:23:32.623193: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-03-10 17:23:33.991039: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 27.0978 - accuracy: 0.5073 - precision: 0.5073 - recall: 0.5073 - auc: 0.5107 - f1_score: 0.5073
# Epoch 1: val_loss improved from inf to 0.72479, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 66s 770ms/step - loss: 27.0978 - accuracy: 0.5073 - precision: 0.5073 - recall: 0.5073 - auc: 0.5107 - f1_score: 0.5073 - val_loss: 0.7248 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5059 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7312 - accuracy: 0.5254 - precision: 0.5254 - recall: 0.5254 - auc: 0.5326 - f1_score: 0.5254
# Epoch 2: val_loss did not improve from 0.72479
# 71/71 [==============================] - 51s 720ms/step - loss: 0.7312 - accuracy: 0.5254 - precision: 0.5254 - recall: 0.5254 - auc: 0.5326 - f1_score: 0.5254 - val_loss: 0.7307 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5118 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 3/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7283 - accuracy: 0.4967 - precision: 0.4967 - recall: 0.4967 - auc: 0.4970 - f1_score: 0.4967
# Epoch 3: val_loss did not improve from 0.72479
# 71/71 [==============================] - 50s 698ms/step - loss: 0.7283 - accuracy: 0.4967 - precision: 0.4967 - recall: 0.4967 - auc: 0.4970 - f1_score: 0.4967 - val_loss: 0.7340 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.4837 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 4/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7256 - accuracy: 0.5038 - precision: 0.5038 - recall: 0.5038 - auc: 0.4950 - f1_score: 0.5038
# Epoch 4: val_loss did not improve from 0.72479
# 71/71 [==============================] - 51s 713ms/step - loss: 0.7256 - accuracy: 0.5038 - precision: 0.5038 - recall: 0.5038 - auc: 0.4950 - f1_score: 0.5038 - val_loss: 0.7271 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 5/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7242 - accuracy: 0.4825 - precision: 0.4825 - recall: 0.4825 - auc: 0.4854 - f1_score: 0.4825
# Epoch 5: val_loss improved from 0.72479 to 0.72282, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 50s 700ms/step - loss: 0.7242 - accuracy: 0.4825 - precision: 0.4825 - recall: 0.4825 - auc: 0.4854 - f1_score: 0.4825 - val_loss: 0.7228 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 6/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7213 - accuracy: 0.4985 - precision: 0.4985 - recall: 0.4985 - auc: 0.5014 - f1_score: 0.4985
# Epoch 6: val_loss improved from 0.72282 to 0.72072, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 709ms/step - loss: 0.7213 - accuracy: 0.4985 - precision: 0.4985 - recall: 0.4985 - auc: 0.5014 - f1_score: 0.4985 - val_loss: 0.7207 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 7/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7232 - accuracy: 0.4949 - precision: 0.4949 - recall: 0.4949 - auc: 0.4827 - f1_score: 0.4949
# Epoch 7: val_loss improved from 0.72072 to 0.72063, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 718ms/step - loss: 0.7232 - accuracy: 0.4949 - precision: 0.4949 - recall: 0.4949 - auc: 0.4827 - f1_score: 0.4949 - val_loss: 0.7206 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 8/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7221 - accuracy: 0.4976 - precision: 0.4976 - recall: 0.4976 - auc: 0.5029 - f1_score: 0.4976
# Epoch 8: val_loss did not improve from 0.72063
# 71/71 [==============================] - 50s 699ms/step - loss: 0.7221 - accuracy: 0.4976 - precision: 0.4976 - recall: 0.4976 - auc: 0.5029 - f1_score: 0.4976 - val_loss: 0.7207 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 9/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7261 - accuracy: 0.4980 - precision: 0.4980 - recall: 0.4980 - auc: 0.4966 - f1_score: 0.4980
# Epoch 9: val_loss improved from 0.72063 to 0.72040, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 52s 722ms/step - loss: 0.7261 - accuracy: 0.4980 - precision: 0.4980 - recall: 0.4980 - auc: 0.4966 - f1_score: 0.4980 - val_loss: 0.7204 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 10/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7226 - accuracy: 0.5122 - precision: 0.5122 - recall: 0.5122 - auc: 0.5096 - f1_score: 0.5122
# Epoch 10: val_loss did not improve from 0.72040
# 71/71 [==============================] - 51s 711ms/step - loss: 0.7226 - accuracy: 0.5122 - precision: 0.5122 - recall: 0.5122 - auc: 0.5096 - f1_score: 0.5122 - val_loss: 0.7241 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 11/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7218 - accuracy: 0.4874 - precision: 0.4874 - recall: 0.4874 - auc: 0.4843 - f1_score: 0.4874
# Epoch 11: val_loss did not improve from 0.72040
# 71/71 [==============================] - 52s 721ms/step - loss: 0.7218 - accuracy: 0.4874 - precision: 0.4874 - recall: 0.4874 - auc: 0.4843 - f1_score: 0.4874 - val_loss: 0.7216 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 12/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7230 - accuracy: 0.4993 - precision: 0.4993 - recall: 0.4993 - auc: 0.4948 - f1_score: 0.4993
# Epoch 12: val_loss improved from 0.72040 to 0.72000, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 720ms/step - loss: 0.7230 - accuracy: 0.4993 - precision: 0.4993 - recall: 0.4993 - auc: 0.4948 - f1_score: 0.4993 - val_loss: 0.7200 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 13/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7207 - accuracy: 0.5130 - precision: 0.5130 - recall: 0.5130 - auc: 0.4961 - f1_score: 0.5130
# Epoch 13: val_loss did not improve from 0.72000
# 71/71 [==============================] - 51s 714ms/step - loss: 0.7207 - accuracy: 0.5130 - precision: 0.5130 - recall: 0.5130 - auc: 0.4961 - f1_score: 0.5130 - val_loss: 0.7222 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 14/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7223 - accuracy: 0.4958 - precision: 0.4958 - recall: 0.4958 - auc: 0.4975 - f1_score: 0.4958
# Epoch 14: val_loss did not improve from 0.72000
# 71/71 [==============================] - 51s 712ms/step - loss: 0.7223 - accuracy: 0.4958 - precision: 0.4958 - recall: 0.4958 - auc: 0.4975 - f1_score: 0.4958 - val_loss: 0.7212 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5237 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 15/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7215 - accuracy: 0.4839 - precision: 0.4839 - recall: 0.4839 - auc: 0.4820 - f1_score: 0.4839
# Epoch 15: val_loss did not improve from 0.72000
# 71/71 [==============================] - 50s 699ms/step - loss: 0.7215 - accuracy: 0.4839 - precision: 0.4839 - recall: 0.4839 - auc: 0.4820 - f1_score: 0.4839 - val_loss: 0.7201 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.4970 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 16/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7221 - accuracy: 0.4808 - precision: 0.4808 - recall: 0.4808 - auc: 0.4880 - f1_score: 0.4808
# Epoch 16: val_loss did not improve from 0.72000
# 71/71 [==============================] - 52s 727ms/step - loss: 0.7221 - accuracy: 0.4808 - precision: 0.4808 - recall: 0.4808 - auc: 0.4880 - f1_score: 0.4808 - val_loss: 0.7223 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 17/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7231 - accuracy: 0.4852 - precision: 0.4852 - recall: 0.4852 - auc: 0.4789 - f1_score: 0.4852
# Epoch 17: val_loss did not improve from 0.72000
# 71/71 [==============================] - 51s 712ms/step - loss: 0.7231 - accuracy: 0.4852 - precision: 0.4852 - recall: 0.4852 - auc: 0.4789 - f1_score: 0.4852 - val_loss: 0.7208 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 18/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7227 - accuracy: 0.4976 - precision: 0.4976 - recall: 0.4976 - auc: 0.4926 - f1_score: 0.4976
# Epoch 18: val_loss improved from 0.72000 to 0.71966, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 713ms/step - loss: 0.7227 - accuracy: 0.4976 - precision: 0.4976 - recall: 0.4976 - auc: 0.4926 - f1_score: 0.4976 - val_loss: 0.7197 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 19/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7211 - accuracy: 0.4790 - precision: 0.4790 - recall: 0.4790 - auc: 0.4774 - f1_score: 0.4790
# Epoch 19: val_loss improved from 0.71966 to 0.71963, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 719ms/step - loss: 0.7211 - accuracy: 0.4790 - precision: 0.4790 - recall: 0.4790 - auc: 0.4774 - f1_score: 0.4790 - val_loss: 0.7196 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 20/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7234 - accuracy: 0.4856 - precision: 0.4856 - recall: 0.4856 - auc: 0.4759 - f1_score: 0.4856
# Epoch 20: val_loss did not improve from 0.71963
# 71/71 [==============================] - 52s 727ms/step - loss: 0.7234 - accuracy: 0.4856 - precision: 0.4856 - recall: 0.4856 - auc: 0.4759 - f1_score: 0.4856 - val_loss: 0.7230 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 21/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7227 - accuracy: 0.4856 - precision: 0.4856 - recall: 0.4856 - auc: 0.4851 - f1_score: 0.4856
# Epoch 21: val_loss did not improve from 0.71963
# 71/71 [==============================] - 51s 717ms/step - loss: 0.7227 - accuracy: 0.4856 - precision: 0.4856 - recall: 0.4856 - auc: 0.4851 - f1_score: 0.4856 - val_loss: 0.7258 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 22/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7222 - accuracy: 0.4870 - precision: 0.4870 - recall: 0.4870 - auc: 0.4856 - f1_score: 0.4870
# Epoch 22: val_loss did not improve from 0.71963
# 71/71 [==============================] - 51s 707ms/step - loss: 0.7222 - accuracy: 0.4870 - precision: 0.4870 - recall: 0.4870 - auc: 0.4856 - f1_score: 0.4870 - val_loss: 0.7207 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 23/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7213 - accuracy: 0.5046 - precision: 0.5046 - recall: 0.5046 - auc: 0.5052 - f1_score: 0.5046
# Epoch 23: val_loss did not improve from 0.71963
# 71/71 [==============================] - 50s 701ms/step - loss: 0.7213 - accuracy: 0.5046 - precision: 0.5046 - recall: 0.5046 - auc: 0.5052 - f1_score: 0.5046 - val_loss: 0.7216 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5163 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 24/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7226 - accuracy: 0.4834 - precision: 0.4834 - recall: 0.4834 - auc: 0.4759 - f1_score: 0.4834
# Epoch 24: val_loss did not improve from 0.71963
# 71/71 [==============================] - 51s 719ms/step - loss: 0.7226 - accuracy: 0.4834 - precision: 0.4834 - recall: 0.4834 - auc: 0.4759 - f1_score: 0.4834 - val_loss: 0.7197 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 25/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7209 - accuracy: 0.4927 - precision: 0.4927 - recall: 0.4927 - auc: 0.4945 - f1_score: 0.4927
# Epoch 25: val_loss did not improve from 0.71963
# 71/71 [==============================] - 51s 716ms/step - loss: 0.7209 - accuracy: 0.4927 - precision: 0.4927 - recall: 0.4927 - auc: 0.4945 - f1_score: 0.4927 - val_loss: 0.7216 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 26/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7203 - accuracy: 0.4945 - precision: 0.4945 - recall: 0.4945 - auc: 0.4939 - f1_score: 0.4945
# Epoch 26: val_loss improved from 0.71963 to 0.71947, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 53s 735ms/step - loss: 0.7203 - accuracy: 0.4945 - precision: 0.4945 - recall: 0.4945 - auc: 0.4939 - f1_score: 0.4945 - val_loss: 0.7195 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 27/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7206 - accuracy: 0.5064 - precision: 0.5064 - recall: 0.5064 - auc: 0.4938 - f1_score: 0.5064
# Epoch 27: val_loss did not improve from 0.71947
# 71/71 [==============================] - 51s 718ms/step - loss: 0.7206 - accuracy: 0.5064 - precision: 0.5064 - recall: 0.5064 - auc: 0.4938 - f1_score: 0.5064 - val_loss: 0.7196 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 28/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7208 - accuracy: 0.4936 - precision: 0.4936 - recall: 0.4936 - auc: 0.4939 - f1_score: 0.4936
# Epoch 28: val_loss improved from 0.71947 to 0.71940, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 50s 703ms/step - loss: 0.7208 - accuracy: 0.4936 - precision: 0.4936 - recall: 0.4936 - auc: 0.4939 - f1_score: 0.4936 - val_loss: 0.7194 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 29/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7205 - accuracy: 0.5033 - precision: 0.5033 - recall: 0.5033 - auc: 0.4935 - f1_score: 0.5033
# Epoch 29: val_loss did not improve from 0.71940
# 71/71 [==============================] - 50s 703ms/step - loss: 0.7205 - accuracy: 0.5033 - precision: 0.5033 - recall: 0.5033 - auc: 0.4935 - f1_score: 0.5033 - val_loss: 0.7198 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 30/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7199 - accuracy: 0.4998 - precision: 0.4998 - recall: 0.4998 - auc: 0.4874 - f1_score: 0.4998
# Epoch 30: val_loss did not improve from 0.71940
# 71/71 [==============================] - 52s 722ms/step - loss: 0.7199 - accuracy: 0.4998 - precision: 0.4998 - recall: 0.4998 - auc: 0.4874 - f1_score: 0.4998 - val_loss: 0.7195 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 31/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7202 - accuracy: 0.4971 - precision: 0.4971 - recall: 0.4971 - auc: 0.4957 - f1_score: 0.4971
# Epoch 31: val_loss did not improve from 0.71940
# 71/71 [==============================] - 51s 708ms/step - loss: 0.7202 - accuracy: 0.4971 - precision: 0.4971 - recall: 0.4971 - auc: 0.4957 - f1_score: 0.4971 - val_loss: 0.7197 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 32/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7199 - accuracy: 0.4967 - precision: 0.4967 - recall: 0.4967 - auc: 0.4951 - f1_score: 0.4967
# Epoch 32: val_loss improved from 0.71940 to 0.71921, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 713ms/step - loss: 0.7199 - accuracy: 0.4967 - precision: 0.4967 - recall: 0.4967 - auc: 0.4951 - f1_score: 0.4967 - val_loss: 0.7192 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 33/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7198 - accuracy: 0.4812 - precision: 0.4812 - recall: 0.4812 - auc: 0.4788 - f1_score: 0.4812
# Epoch 33: val_loss improved from 0.71921 to 0.71921, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 708ms/step - loss: 0.7198 - accuracy: 0.4812 - precision: 0.4812 - recall: 0.4812 - auc: 0.4788 - f1_score: 0.4812 - val_loss: 0.7192 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 34/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7196 - accuracy: 0.4954 - precision: 0.4954 - recall: 0.4954 - auc: 0.4877 - f1_score: 0.4954
# Epoch 34: val_loss improved from 0.71921 to 0.71906, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 712ms/step - loss: 0.7196 - accuracy: 0.4954 - precision: 0.4954 - recall: 0.4954 - auc: 0.4877 - f1_score: 0.4954 - val_loss: 0.7191 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 35/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7195 - accuracy: 0.4892 - precision: 0.4892 - recall: 0.4892 - auc: 0.4987 - f1_score: 0.4892
# Epoch 35: val_loss did not improve from 0.71906
# 71/71 [==============================] - 50s 705ms/step - loss: 0.7195 - accuracy: 0.4892 - precision: 0.4892 - recall: 0.4892 - auc: 0.4987 - f1_score: 0.4892 - val_loss: 0.7194 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5030 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 36/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7197 - accuracy: 0.5011 - precision: 0.5011 - recall: 0.5011 - auc: 0.4943 - f1_score: 0.5011
# Epoch 36: val_loss did not improve from 0.71906
# 71/71 [==============================] - 50s 704ms/step - loss: 0.7197 - accuracy: 0.5011 - precision: 0.5011 - recall: 0.5011 - auc: 0.4943 - f1_score: 0.5011 - val_loss: 0.7191 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 37/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7202 - accuracy: 0.4985 - precision: 0.4985 - recall: 0.4985 - auc: 0.4899 - f1_score: 0.4985
# Epoch 37: val_loss did not improve from 0.71906
# 71/71 [==============================] - 52s 728ms/step - loss: 0.7202 - accuracy: 0.4985 - precision: 0.4985 - recall: 0.4985 - auc: 0.4899 - f1_score: 0.4985 - val_loss: 0.7191 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5015 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 38/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7199 - accuracy: 0.5020 - precision: 0.5020 - recall: 0.5020 - auc: 0.4902 - f1_score: 0.5020
# Epoch 38: val_loss did not improve from 0.71906
# 71/71 [==============================] - 50s 701ms/step - loss: 0.7199 - accuracy: 0.5020 - precision: 0.5020 - recall: 0.5020 - auc: 0.4902 - f1_score: 0.5020 - val_loss: 0.7191 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 39/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7192 - accuracy: 0.5117 - precision: 0.5117 - recall: 0.5117 - auc: 0.5109 - f1_score: 0.5117
# Epoch 39: val_loss did not improve from 0.71906
# 71/71 [==============================] - 51s 706ms/step - loss: 0.7192 - accuracy: 0.5117 - precision: 0.5117 - recall: 0.5117 - auc: 0.5109 - f1_score: 0.5117 - val_loss: 0.7198 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 40/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7192 - accuracy: 0.5161 - precision: 0.5161 - recall: 0.5161 - auc: 0.5157 - f1_score: 0.5161
# Epoch 40: val_loss did not improve from 0.71906
# 71/71 [==============================] - 50s 695ms/step - loss: 0.7192 - accuracy: 0.5161 - precision: 0.5161 - recall: 0.5161 - auc: 0.5157 - f1_score: 0.5161 - val_loss: 0.7193 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 41/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7199 - accuracy: 0.4803 - precision: 0.4803 - recall: 0.4803 - auc: 0.4697 - f1_score: 0.4803
# Epoch 41: val_loss improved from 0.71906 to 0.71876, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 52s 732ms/step - loss: 0.7199 - accuracy: 0.4803 - precision: 0.4803 - recall: 0.4803 - auc: 0.4697 - f1_score: 0.4803 - val_loss: 0.7188 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5133 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 42/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7198 - accuracy: 0.4821 - precision: 0.4821 - recall: 0.4821 - auc: 0.4784 - f1_score: 0.4821
# Epoch 42: val_loss improved from 0.71876 to 0.71865, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 720ms/step - loss: 0.7198 - accuracy: 0.4821 - precision: 0.4821 - recall: 0.4821 - auc: 0.4784 - f1_score: 0.4821 - val_loss: 0.7187 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 43/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7193 - accuracy: 0.4874 - precision: 0.4874 - recall: 0.4874 - auc: 0.4840 - f1_score: 0.4874
# Epoch 43: val_loss improved from 0.71865 to 0.71853, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 52s 726ms/step - loss: 0.7193 - accuracy: 0.4874 - precision: 0.4874 - recall: 0.4874 - auc: 0.4840 - f1_score: 0.4874 - val_loss: 0.7185 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 44/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7195 - accuracy: 0.4954 - precision: 0.4954 - recall: 0.4954 - auc: 0.4887 - f1_score: 0.4954
# Epoch 44: val_loss improved from 0.71853 to 0.71847, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 718ms/step - loss: 0.7195 - accuracy: 0.4954 - precision: 0.4954 - recall: 0.4954 - auc: 0.4887 - f1_score: 0.4954 - val_loss: 0.7185 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 45/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7193 - accuracy: 0.4781 - precision: 0.4781 - recall: 0.4781 - auc: 0.4695 - f1_score: 0.4781
# Epoch 45: val_loss improved from 0.71847 to 0.71844, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 713ms/step - loss: 0.7193 - accuracy: 0.4781 - precision: 0.4781 - recall: 0.4781 - auc: 0.4695 - f1_score: 0.4781 - val_loss: 0.7184 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 46/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7196 - accuracy: 0.4839 - precision: 0.4839 - recall: 0.4839 - auc: 0.4807 - f1_score: 0.4839
# Epoch 46: val_loss improved from 0.71844 to 0.71828, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 52s 730ms/step - loss: 0.7196 - accuracy: 0.4839 - precision: 0.4839 - recall: 0.4839 - auc: 0.4807 - f1_score: 0.4839 - val_loss: 0.7183 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5484 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 47/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7192 - accuracy: 0.5068 - precision: 0.5068 - recall: 0.5068 - auc: 0.4993 - f1_score: 0.5068
# Epoch 47: val_loss did not improve from 0.71828
# 71/71 [==============================] - 51s 709ms/step - loss: 0.7192 - accuracy: 0.5068 - precision: 0.5068 - recall: 0.5068 - auc: 0.4993 - f1_score: 0.5068 - val_loss: 0.7184 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5015 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 48/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7197 - accuracy: 0.5011 - precision: 0.5011 - recall: 0.5011 - auc: 0.4937 - f1_score: 0.5011
# Epoch 48: val_loss improved from 0.71828 to 0.71826, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 52s 721ms/step - loss: 0.7197 - accuracy: 0.5011 - precision: 0.5011 - recall: 0.5011 - auc: 0.4937 - f1_score: 0.5011 - val_loss: 0.7183 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 49/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7205 - accuracy: 0.4998 - precision: 0.4998 - recall: 0.4998 - auc: 0.4854 - f1_score: 0.4998
# Epoch 49: val_loss did not improve from 0.71826
# 71/71 [==============================] - 52s 723ms/step - loss: 0.7205 - accuracy: 0.4998 - precision: 0.4998 - recall: 0.4998 - auc: 0.4854 - f1_score: 0.4998 - val_loss: 0.7187 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 50/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7201 - accuracy: 0.4896 - precision: 0.4896 - recall: 0.4896 - auc: 0.4954 - f1_score: 0.4896
# Epoch 50: val_loss did not improve from 0.71826
# 71/71 [==============================] - 51s 720ms/step - loss: 0.7201 - accuracy: 0.4896 - precision: 0.4896 - recall: 0.4896 - auc: 0.4954 - f1_score: 0.4896 - val_loss: 0.7238 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5059 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 51/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7191 - accuracy: 0.5029 - precision: 0.5029 - recall: 0.5029 - auc: 0.5096 - f1_score: 0.5029
# Epoch 51: val_loss did not improve from 0.71826
# 71/71 [==============================] - 51s 709ms/step - loss: 0.7191 - accuracy: 0.5029 - precision: 0.5029 - recall: 0.5029 - auc: 0.5096 - f1_score: 0.5029 - val_loss: 0.7384 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 52/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7192 - accuracy: 0.5029 - precision: 0.5029 - recall: 0.5029 - auc: 0.5109 - f1_score: 0.5029
# Epoch 52: val_loss did not improve from 0.71826
# 71/71 [==============================] - 51s 706ms/step - loss: 0.7192 - accuracy: 0.5029 - precision: 0.5029 - recall: 0.5029 - auc: 0.5109 - f1_score: 0.5029 - val_loss: 0.7183 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 53/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7192 - accuracy: 0.5126 - precision: 0.5126 - recall: 0.5126 - auc: 0.5083 - f1_score: 0.5126
# Epoch 53: val_loss improved from 0.71826 to 0.71813, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 719ms/step - loss: 0.7192 - accuracy: 0.5126 - precision: 0.5126 - recall: 0.5126 - auc: 0.5083 - f1_score: 0.5126 - val_loss: 0.7181 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5207 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 54/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7216 - accuracy: 0.4993 - precision: 0.4993 - recall: 0.4993 - auc: 0.5014 - f1_score: 0.4993
# Epoch 54: val_loss did not improve from 0.71813
# 71/71 [==============================] - 51s 708ms/step - loss: 0.7216 - accuracy: 0.4993 - precision: 0.4993 - recall: 0.4993 - auc: 0.5014 - f1_score: 0.4993 - val_loss: 0.7199 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 55/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7195 - accuracy: 0.4985 - precision: 0.4985 - recall: 0.4985 - auc: 0.4946 - f1_score: 0.4985
# Epoch 55: val_loss did not improve from 0.71813
# 71/71 [==============================] - 51s 714ms/step - loss: 0.7195 - accuracy: 0.4985 - precision: 0.4985 - recall: 0.4985 - auc: 0.4946 - f1_score: 0.4985 - val_loss: 0.7187 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 56/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7198 - accuracy: 0.4967 - precision: 0.4967 - recall: 0.4967 - auc: 0.4943 - f1_score: 0.4967
# Epoch 56: val_loss did not improve from 0.71813
# 71/71 [==============================] - 51s 720ms/step - loss: 0.7198 - accuracy: 0.4967 - precision: 0.4967 - recall: 0.4967 - auc: 0.4943 - f1_score: 0.4967 - val_loss: 0.7194 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.4911 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 57/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7195 - accuracy: 0.4878 - precision: 0.4878 - recall: 0.4878 - auc: 0.4914 - f1_score: 0.4878
# Epoch 57: val_loss improved from 0.71813 to 0.71796, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 50s 704ms/step - loss: 0.7195 - accuracy: 0.4878 - precision: 0.4878 - recall: 0.4878 - auc: 0.4914 - f1_score: 0.4878 - val_loss: 0.7180 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 58/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7187 - accuracy: 0.4755 - precision: 0.4755 - recall: 0.4755 - auc: 0.4606 - f1_score: 0.4755
# Epoch 58: val_loss improved from 0.71796 to 0.71756, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 712ms/step - loss: 0.7187 - accuracy: 0.4755 - precision: 0.4755 - recall: 0.4755 - auc: 0.4606 - f1_score: 0.4755 - val_loss: 0.7176 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 59/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7185 - accuracy: 0.4985 - precision: 0.4985 - recall: 0.4985 - auc: 0.4845 - f1_score: 0.4985
# Epoch 59: val_loss improved from 0.71756 to 0.71751, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 718ms/step - loss: 0.7185 - accuracy: 0.4985 - precision: 0.4985 - recall: 0.4985 - auc: 0.4845 - f1_score: 0.4985 - val_loss: 0.7175 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 60/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7208 - accuracy: 0.5064 - precision: 0.5064 - recall: 0.5064 - auc: 0.5130 - f1_score: 0.5064
# Epoch 60: val_loss did not improve from 0.71751
# 71/71 [==============================] - 50s 703ms/step - loss: 0.7208 - accuracy: 0.5064 - precision: 0.5064 - recall: 0.5064 - auc: 0.5130 - f1_score: 0.5064 - val_loss: 0.7242 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.4749 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 61/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7201 - accuracy: 0.4905 - precision: 0.4905 - recall: 0.4905 - auc: 0.4926 - f1_score: 0.4905
# Epoch 61: val_loss did not improve from 0.71751
# 71/71 [==============================] - 49s 692ms/step - loss: 0.7201 - accuracy: 0.4905 - precision: 0.4905 - recall: 0.4905 - auc: 0.4926 - f1_score: 0.4905 - val_loss: 0.7202 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.4970 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 62/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7182 - accuracy: 0.5086 - precision: 0.5086 - recall: 0.5086 - auc: 0.5081 - f1_score: 0.5086
# Epoch 62: val_loss improved from 0.71751 to 0.71738, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 709ms/step - loss: 0.7182 - accuracy: 0.5086 - precision: 0.5086 - recall: 0.5086 - auc: 0.5081 - f1_score: 0.5086 - val_loss: 0.7174 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 63/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7200 - accuracy: 0.4980 - precision: 0.4980 - recall: 0.4980 - auc: 0.4927 - f1_score: 0.4980
# Epoch 63: val_loss did not improve from 0.71738
# 71/71 [==============================] - 51s 720ms/step - loss: 0.7200 - accuracy: 0.4980 - precision: 0.4980 - recall: 0.4980 - auc: 0.4927 - f1_score: 0.4980 - val_loss: 0.7174 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 64/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7192 - accuracy: 0.4936 - precision: 0.4936 - recall: 0.4936 - auc: 0.4924 - f1_score: 0.4936
# Epoch 64: val_loss did not improve from 0.71738
# 71/71 [==============================] - 50s 696ms/step - loss: 0.7192 - accuracy: 0.4936 - precision: 0.4936 - recall: 0.4936 - auc: 0.4924 - f1_score: 0.4936 - val_loss: 0.7174 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 65/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7181 - accuracy: 0.4887 - precision: 0.4887 - recall: 0.4887 - auc: 0.4901 - f1_score: 0.4887
# Epoch 65: val_loss improved from 0.71738 to 0.71692, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 52s 723ms/step - loss: 0.7181 - accuracy: 0.4887 - precision: 0.4887 - recall: 0.4887 - auc: 0.4901 - f1_score: 0.4887 - val_loss: 0.7169 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 66/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7176 - accuracy: 0.4861 - precision: 0.4861 - recall: 0.4861 - auc: 0.4868 - f1_score: 0.4861
# Epoch 66: val_loss improved from 0.71692 to 0.71683, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 52s 728ms/step - loss: 0.7176 - accuracy: 0.4861 - precision: 0.4861 - recall: 0.4861 - auc: 0.4868 - f1_score: 0.4861 - val_loss: 0.7168 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 67/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7179 - accuracy: 0.5038 - precision: 0.5038 - recall: 0.5038 - auc: 0.5031 - f1_score: 0.5038
# Epoch 67: val_loss improved from 0.71683 to 0.71681, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 710ms/step - loss: 0.7179 - accuracy: 0.5038 - precision: 0.5038 - recall: 0.5038 - auc: 0.5031 - f1_score: 0.5038 - val_loss: 0.7168 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 68/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7177 - accuracy: 0.4940 - precision: 0.4940 - recall: 0.4940 - auc: 0.4912 - f1_score: 0.4940
# Epoch 68: val_loss did not improve from 0.71681
# 71/71 [==============================] - 51s 713ms/step - loss: 0.7177 - accuracy: 0.4940 - precision: 0.4940 - recall: 0.4940 - auc: 0.4912 - f1_score: 0.4940 - val_loss: 0.7176 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 69/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7172 - accuracy: 0.5060 - precision: 0.5060 - recall: 0.5060 - auc: 0.5004 - f1_score: 0.5060
# Epoch 69: val_loss improved from 0.71681 to 0.71671, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 720ms/step - loss: 0.7172 - accuracy: 0.5060 - precision: 0.5060 - recall: 0.5060 - auc: 0.5004 - f1_score: 0.5060 - val_loss: 0.7167 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 70/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7176 - accuracy: 0.4962 - precision: 0.4962 - recall: 0.4962 - auc: 0.4859 - f1_score: 0.4962
# Epoch 70: val_loss improved from 0.71671 to 0.71643, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 52s 723ms/step - loss: 0.7176 - accuracy: 0.4962 - precision: 0.4962 - recall: 0.4962 - auc: 0.4859 - f1_score: 0.4962 - val_loss: 0.7164 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 71/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7169 - accuracy: 0.4980 - precision: 0.4980 - recall: 0.4980 - auc: 0.4910 - f1_score: 0.4980
# Epoch 71: val_loss did not improve from 0.71643
# 71/71 [==============================] - 51s 711ms/step - loss: 0.7169 - accuracy: 0.4980 - precision: 0.4980 - recall: 0.4980 - auc: 0.4910 - f1_score: 0.4980 - val_loss: 0.7170 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 72/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7170 - accuracy: 0.5051 - precision: 0.5051 - recall: 0.5051 - auc: 0.4975 - f1_score: 0.5051
# Epoch 72: val_loss did not improve from 0.71643
# 71/71 [==============================] - 50s 697ms/step - loss: 0.7170 - accuracy: 0.5051 - precision: 0.5051 - recall: 0.5051 - auc: 0.4975 - f1_score: 0.5051 - val_loss: 0.7173 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 73/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7166 - accuracy: 0.4976 - precision: 0.4976 - recall: 0.4976 - auc: 0.5040 - f1_score: 0.4976
# Epoch 73: val_loss did not improve from 0.71643
# 71/71 [==============================] - 51s 710ms/step - loss: 0.7166 - accuracy: 0.4976 - precision: 0.4976 - recall: 0.4976 - auc: 0.5040 - f1_score: 0.4976 - val_loss: 0.7178 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 74/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7181 - accuracy: 0.4658 - precision: 0.4658 - recall: 0.4658 - auc: 0.4512 - f1_score: 0.4658
# Epoch 74: val_loss did not improve from 0.71643
# 71/71 [==============================] - 51s 708ms/step - loss: 0.7181 - accuracy: 0.4658 - precision: 0.4658 - recall: 0.4658 - auc: 0.4512 - f1_score: 0.4658 - val_loss: 0.7166 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5266 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 75/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7167 - accuracy: 0.5011 - precision: 0.5011 - recall: 0.5011 - auc: 0.4893 - f1_score: 0.5011
# Epoch 75: val_loss improved from 0.71643 to 0.71591, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 716ms/step - loss: 0.7167 - accuracy: 0.5011 - precision: 0.5011 - recall: 0.5011 - auc: 0.4893 - f1_score: 0.5011 - val_loss: 0.7159 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 76/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7178 - accuracy: 0.4909 - precision: 0.4909 - recall: 0.4909 - auc: 0.4923 - f1_score: 0.4909
# Epoch 76: val_loss improved from 0.71591 to 0.71580, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 713ms/step - loss: 0.7178 - accuracy: 0.4909 - precision: 0.4909 - recall: 0.4909 - auc: 0.4923 - f1_score: 0.4909 - val_loss: 0.7158 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 77/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7168 - accuracy: 0.4817 - precision: 0.4817 - recall: 0.4817 - auc: 0.4869 - f1_score: 0.4817
# Epoch 77: val_loss improved from 0.71580 to 0.71557, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 52s 731ms/step - loss: 0.7168 - accuracy: 0.4817 - precision: 0.4817 - recall: 0.4817 - auc: 0.4869 - f1_score: 0.4817 - val_loss: 0.7156 - val_accuracy: 0.5237 - val_precision: 0.5237 - val_recall: 0.5237 - val_auc: 0.5000 - val_f1_score: 0.5237 - lr: 0.0010
# Epoch 78/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7161 - accuracy: 0.5020 - precision: 0.5020 - recall: 0.5020 - auc: 0.4999 - f1_score: 0.5020
# Epoch 78: val_loss did not improve from 0.71557
# 71/71 [==============================] - 51s 717ms/step - loss: 0.7161 - accuracy: 0.5020 - precision: 0.5020 - recall: 0.5020 - auc: 0.4999 - f1_score: 0.5020 - val_loss: 0.7164 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 79/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7163 - accuracy: 0.5091 - precision: 0.5091 - recall: 0.5091 - auc: 0.4976 - f1_score: 0.5091
# Epoch 79: val_loss did not improve from 0.71557
# 71/71 [==============================] - 50s 700ms/step - loss: 0.7163 - accuracy: 0.5091 - precision: 0.5091 - recall: 0.5091 - auc: 0.4976 - f1_score: 0.5091 - val_loss: 0.7157 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 80/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7162 - accuracy: 0.4971 - precision: 0.4971 - recall: 0.4971 - auc: 0.4936 - f1_score: 0.4971
# Epoch 80: val_loss improved from 0.71557 to 0.71426, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version9_CLAHE-DIR.h5
# 71/71 [==============================] - 51s 717ms/step - loss: 0.7162 - accuracy: 0.4971 - precision: 0.4971 - recall: 0.4971 - auc: 0.4936 - f1_score: 0.4971 - val_loss: 0.7143 - val_accuracy: 0.5680 - val_precision: 0.5680 - val_recall: 0.5680 - val_auc: 0.5785 - val_f1_score: 0.5680 - lr: 0.0010
# Epoch 81/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7158 - accuracy: 0.4998 - precision: 0.4998 - recall: 0.4998 - auc: 0.4956 - f1_score: 0.4998
# Epoch 81: val_loss did not improve from 0.71426
# 71/71 [==============================] - 51s 707ms/step - loss: 0.7158 - accuracy: 0.4998 - precision: 0.4998 - recall: 0.4998 - auc: 0.4956 - f1_score: 0.4998 - val_loss: 0.7150 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5163 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 82/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7161 - accuracy: 0.4834 - precision: 0.4834 - recall: 0.4834 - auc: 0.4888 - f1_score: 0.4834
# Epoch 82: val_loss did not improve from 0.71426
# 71/71 [==============================] - 51s 711ms/step - loss: 0.7161 - accuracy: 0.4834 - precision: 0.4834 - recall: 0.4834 - auc: 0.4888 - f1_score: 0.4834 - val_loss: 0.7153 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 83/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7167 - accuracy: 0.4799 - precision: 0.4799 - recall: 0.4799 - auc: 0.4789 - f1_score: 0.4799
# Epoch 83: val_loss did not improve from 0.71426
# 71/71 [==============================] - 52s 732ms/step - loss: 0.7167 - accuracy: 0.4799 - precision: 0.4799 - recall: 0.4799 - auc: 0.4789 - f1_score: 0.4799 - val_loss: 0.7151 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 84/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7159 - accuracy: 0.4923 - precision: 0.4923 - recall: 0.4923 - auc: 0.4923 - f1_score: 0.4923
# Epoch 84: val_loss did not improve from 0.71426
# 71/71 [==============================] - 51s 714ms/step - loss: 0.7159 - accuracy: 0.4923 - precision: 0.4923 - recall: 0.4923 - auc: 0.4923 - f1_score: 0.4923 - val_loss: 0.7146 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5059 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 85/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7158 - accuracy: 0.5117 - precision: 0.5117 - recall: 0.5117 - auc: 0.5026 - f1_score: 0.5117
# Epoch 85: val_loss did not improve from 0.71426
# 71/71 [==============================] - 51s 706ms/step - loss: 0.7158 - accuracy: 0.5117 - precision: 0.5117 - recall: 0.5117 - auc: 0.5026 - f1_score: 0.5117 - val_loss: 0.7146 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5030 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 86/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7153 - accuracy: 0.4856 - precision: 0.4856 - recall: 0.4856 - auc: 0.4934 - f1_score: 0.4856
# Epoch 86: val_loss did not improve from 0.71426
# ...
# 71/71 [==============================] - 52s 724ms/step - loss: 0.7121 - accuracy: 0.4998 - precision: 0.4998 - recall: 0.4998 - auc: 0.5013 - f1_score: 0.4998 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 121/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.5002 - precision: 0.5002 - recall: 0.5002 - auc: 0.4991 - f1_score: 0.5002
# Epoch 121: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 722ms/step - loss: 0.7121 - accuracy: 0.5002 - precision: 0.5002 - recall: 0.5002 - auc: 0.4991 - f1_score: 0.5002 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 122/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.5007 - precision: 0.5007 - recall: 0.5007 - auc: 0.4987 - f1_score: 0.5007
# Epoch 122: val_loss did not improve from 0.71104
# 71/71 [==============================] - 50s 699ms/step - loss: 0.7121 - accuracy: 0.5007 - precision: 0.5007 - recall: 0.5007 - auc: 0.4987 - f1_score: 0.5007 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 123/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4927 - precision: 0.4927 - recall: 0.4927 - auc: 0.5000 - f1_score: 0.4927
# Epoch 123: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 123: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 708ms/step - loss: 0.7121 - accuracy: 0.4927 - precision: 0.4927 - recall: 0.4927 - auc: 0.5000 - f1_score: 0.4927 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 124/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4958 - precision: 0.4958 - recall: 0.4958 - auc: 0.5000 - f1_score: 0.4958
# Epoch 124: val_loss did not improve from 0.71104
# 71/71 [==============================] - 50s 705ms/step - loss: 0.7121 - accuracy: 0.4958 - precision: 0.4958 - recall: 0.4958 - auc: 0.5000 - f1_score: 0.4958 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 125/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.5015 - precision: 0.5015 - recall: 0.5015 - auc: 0.5000 - f1_score: 0.5015
# Epoch 125: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 709ms/step - loss: 0.7121 - accuracy: 0.5015 - precision: 0.5015 - recall: 0.5015 - auc: 0.5000 - f1_score: 0.5015 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 126/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4993 - precision: 0.4993 - recall: 0.4993 - auc: 0.5000 - f1_score: 0.4993
# Epoch 126: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 708ms/step - loss: 0.7121 - accuracy: 0.4993 - precision: 0.4993 - recall: 0.4993 - auc: 0.5000 - f1_score: 0.4993 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 127/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4985 - precision: 0.4985 - recall: 0.4985 - auc: 0.5000 - f1_score: 0.4985
# Epoch 127: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 709ms/step - loss: 0.7121 - accuracy: 0.4985 - precision: 0.4985 - recall: 0.4985 - auc: 0.5000 - f1_score: 0.4985 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 128/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.5007 - precision: 0.5007 - recall: 0.5007 - auc: 0.5000 - f1_score: 0.5007
# Epoch 128: val_loss did not improve from 0.71104
# 71/71 [==============================] - 50s 705ms/step - loss: 0.7121 - accuracy: 0.5007 - precision: 0.5007 - recall: 0.5007 - auc: 0.5000 - f1_score: 0.5007 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 129/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4967 - precision: 0.4967 - recall: 0.4967 - auc: 0.5000 - f1_score: 0.4967
# Epoch 129: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 712ms/step - loss: 0.7121 - accuracy: 0.4967 - precision: 0.4967 - recall: 0.4967 - auc: 0.5000 - f1_score: 0.4967 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 130/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.5024 - precision: 0.5024 - recall: 0.5024 - auc: 0.5000 - f1_score: 0.5024
# Epoch 130: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 712ms/step - loss: 0.7121 - accuracy: 0.5024 - precision: 0.5024 - recall: 0.5024 - auc: 0.5000 - f1_score: 0.5024 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 131/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4883 - precision: 0.4883 - recall: 0.4883 - auc: 0.5000 - f1_score: 0.4883
# Epoch 131: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 727ms/step - loss: 0.7121 - accuracy: 0.4883 - precision: 0.4883 - recall: 0.4883 - auc: 0.5000 - f1_score: 0.4883 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 132/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4993 - precision: 0.4993 - recall: 0.4993 - auc: 0.5000 - f1_score: 0.4993
# Epoch 132: val_loss did not improve from 0.71104
# 71/71 [==============================] - 53s 737ms/step - loss: 0.7121 - accuracy: 0.4993 - precision: 0.4993 - recall: 0.4993 - auc: 0.5000 - f1_score: 0.4993 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 133/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4803 - precision: 0.4803 - recall: 0.4803 - auc: 0.5000 - f1_score: 0.4803
# Epoch 133: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 719ms/step - loss: 0.7121 - accuracy: 0.4803 - precision: 0.4803 - recall: 0.4803 - auc: 0.5000 - f1_score: 0.4803 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 134/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4980 - precision: 0.4980 - recall: 0.4980 - auc: 0.5000 - f1_score: 0.4980
# Epoch 134: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 707ms/step - loss: 0.7121 - accuracy: 0.4980 - precision: 0.4980 - recall: 0.4980 - auc: 0.5000 - f1_score: 0.4980 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 135/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4848 - precision: 0.4848 - recall: 0.4848 - auc: 0.5000 - f1_score: 0.4848
# Epoch 135: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 722ms/step - loss: 0.7121 - accuracy: 0.4848 - precision: 0.4848 - recall: 0.4848 - auc: 0.5000 - f1_score: 0.4848 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 136/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4980 - precision: 0.4980 - recall: 0.4980 - auc: 0.5000 - f1_score: 0.4980
# Epoch 136: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 732ms/step - loss: 0.7121 - accuracy: 0.4980 - precision: 0.4980 - recall: 0.4980 - auc: 0.5000 - f1_score: 0.4980 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 137/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4777 - precision: 0.4777 - recall: 0.4777 - auc: 0.5000 - f1_score: 0.4777
# Epoch 137: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 715ms/step - loss: 0.7121 - accuracy: 0.4777 - precision: 0.4777 - recall: 0.4777 - auc: 0.5000 - f1_score: 0.4777 - val_loss: 0.7121 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 138/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.5024 - precision: 0.5024 - recall: 0.5024 - auc: 0.5000 - f1_score: 0.5024
# Epoch 138: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 719ms/step - loss: 0.7120 - accuracy: 0.5024 - precision: 0.5024 - recall: 0.5024 - auc: 0.5000 - f1_score: 0.5024 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 139/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4993 - precision: 0.4993 - recall: 0.4993 - auc: 0.5000 - f1_score: 0.4993
# Epoch 139: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 706ms/step - loss: 0.7121 - accuracy: 0.4993 - precision: 0.4993 - recall: 0.4993 - auc: 0.5000 - f1_score: 0.4993 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 140/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.4998 - precision: 0.5000 - recall: 0.4998 - auc: 0.5000 - f1_score: 0.5001
# Epoch 140: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 722ms/step - loss: 0.7120 - accuracy: 0.4998 - precision: 0.5000 - recall: 0.4998 - auc: 0.5000 - f1_score: 0.5001 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 141/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.4976 - precision: 0.4976 - recall: 0.4976 - auc: 0.5000 - f1_score: 0.4976
# Epoch 141: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 721ms/step - loss: 0.7120 - accuracy: 0.4976 - precision: 0.4976 - recall: 0.4976 - auc: 0.5000 - f1_score: 0.4976 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 142/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.4887 - precision: 0.4887 - recall: 0.4887 - auc: 0.5000 - f1_score: 0.4887
# Epoch 142: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 712ms/step - loss: 0.7120 - accuracy: 0.4887 - precision: 0.4887 - recall: 0.4887 - auc: 0.5000 - f1_score: 0.4887 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 143/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.4861 - precision: 0.4861 - recall: 0.4861 - auc: 0.5000 - f1_score: 0.4861
# Epoch 143: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 721ms/step - loss: 0.7120 - accuracy: 0.4861 - precision: 0.4861 - recall: 0.4861 - auc: 0.5000 - f1_score: 0.4861 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 144/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7121 - accuracy: 0.4781 - precision: 0.4781 - recall: 0.4781 - auc: 0.5000 - f1_score: 0.4781
# Epoch 144: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 713ms/step - loss: 0.7121 - accuracy: 0.4781 - precision: 0.4781 - recall: 0.4781 - auc: 0.5000 - f1_score: 0.4781 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 145/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.5029 - precision: 0.5029 - recall: 0.5029 - auc: 0.5000 - f1_score: 0.5029
# Epoch 145: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 731ms/step - loss: 0.7120 - accuracy: 0.5029 - precision: 0.5029 - recall: 0.5029 - auc: 0.5000 - f1_score: 0.5029 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 146/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.5011 - precision: 0.5011 - recall: 0.5011 - auc: 0.5000 - f1_score: 0.5011
# Epoch 146: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 716ms/step - loss: 0.7120 - accuracy: 0.5011 - precision: 0.5011 - recall: 0.5011 - auc: 0.5000 - f1_score: 0.5011 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 147/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.5020 - precision: 0.5020 - recall: 0.5020 - auc: 0.5000 - f1_score: 0.5020
# Epoch 147: val_loss did not improve from 0.71104
# 71/71 [==============================] - 51s 708ms/step - loss: 0.7120 - accuracy: 0.5020 - precision: 0.5020 - recall: 0.5020 - auc: 0.5000 - f1_score: 0.5020 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 148/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.4967 - precision: 0.4967 - recall: 0.4967 - auc: 0.5000 - f1_score: 0.4967
# Epoch 148: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 734ms/step - loss: 0.7120 - accuracy: 0.4967 - precision: 0.4967 - recall: 0.4967 - auc: 0.5000 - f1_score: 0.4967 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 149/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.4962 - precision: 0.4962 - recall: 0.4962 - auc: 0.5000 - f1_score: 0.4962
# Epoch 149: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 730ms/step - loss: 0.7120 - accuracy: 0.4962 - precision: 0.4962 - recall: 0.4962 - auc: 0.5000 - f1_score: 0.4962 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05
# Epoch 150/150
# 71/71 [==============================] - ETA: 0s - loss: 0.7120 - accuracy: 0.4874 - precision: 0.4874 - recall: 0.4874 - auc: 0.5000 - f1_score: 0.4874
# Epoch 150: val_loss did not improve from 0.71104
# 71/71 [==============================] - 52s 730ms/step - loss: 0.7120 - accuracy: 0.4874 - precision: 0.4874 - recall: 0.4874 - auc: 0.5000 - f1_score: 0.4874 - val_loss: 0.7120 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

# plt.subplot(2, 3, 5)
# plt.plot(range(1, len(f1_score_callback.train_f1_scores) + 1), f1_score_callback.train_f1_scores, label='Training F1 Score')
# plt.plot(range(1, len(f1_score_callback.val_f1_scores) + 1), f1_score_callback.val_f1_scores, label='Validation F1 Score')
# plt.title('Model F1-Score')
# plt.xlabel('Epoch')
# plt.ylabel('F1-Score')
# plt.legend(['F1 Score'], loc='lower right')


plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = DIR.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 2s 116ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.4122448979591837
# F1-Score for each class: [0.        0.8244898]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 1.0
# specificity: 0.0

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  DIR.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 1s 119ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = DIR.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)

# test_loss, test_acc, test_precision, test_recall, test_auc = DIR.evaluate(test_generator)
# print('Test loss:', test_loss)
# print('Test accuracy:', test_acc)
# print('Test precision:', test_precision)
# print('Test recall:', test_recall)
# print('Test AUC:', test_auc)


# from sklearn.metrics import f1_score
# import numpy as np

# # 预测测试集
# y_pred = DIR.predict(test_generator)
# y_pred = np.argmax(y_pred, axis=1)

# # 真实标签
# y_true = test_generator.classes

# # 计算F1分数
# test_f1_score = f1_score(y_true, y_pred, average='micro')  # 或者根据你的需要选择其他average参数
# print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 2s 150ms/step - loss: 0.7119 - accuracy: 0.6879 - precision: 0.6879 - recall: 0.6879 - auc: 0.5000 - f1_score: 0.6879
# Test loss: 0.7119314670562744
# Test accuracy: 0.6879194378852844
# Test precision: 0.6879194378852844
# Test recall: 0.6879194378852844
# Test AUC: 0.5
# Test F1 Score: 0.6879194378852844

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = DIR.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 1s 120ms/step
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        86
#            1       0.70      1.00      0.82       202
#
#     accuracy                           0.70       288
#    macro avg       0.35      0.50      0.41       288
# weighted avg       0.49      0.70      0.58       288
# /root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /root/miniconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

# del DIR


from numba import cuda

cuda.select_device(0)
cuda.close()
