# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.
# Out:
# 2024-03-05 21:16:38.167817: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 298 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    b = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    
    c = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 5
num_B_blocks = 10
num_C_blocks = 5

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.3)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=inputs, outputs=predictions)
model.summary()
# Out:
# 2024-03-05 21:16:41.663018: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-05 21:16:42.200954: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22309 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:81:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 4)  112         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 220, 220, 4)  148         ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 220, 220, 8)  296         ['conv2d_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 218, 218, 12  876         ['conv2d_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 218, 218, 8)  456         ['conv2d_6[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 218, 218, 8)  456         ['conv2d_7[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 216, 216, 12  876         ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 216, 216, 12  876         ['conv2d_8[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_5[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_10[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation (Activation)        (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 214, 214, 4)  196         ['activation[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 214, 214, 4)  196         ['activation[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 214, 214, 4)  196         ['activation[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 4)  40         ['conv2d_12[0][0]']
#  v2D)
#
#  conv2d_14 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_13[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_11[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['activation[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  activation_1 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 4)  196         ['activation_1[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 4)  196         ['activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 4)  196         ['activation_1[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_17[0][0]']
#  onv2D)
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_18[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_16[0][0]',
#                                 )                                 'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 214, 214, 48  0           ['activation_1[0][0]',
#                                 )                                 'conv2d_20[0][0]']
#
#  activation_2 (Activation)      (None, 214, 214, 48  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 4)  196         ['activation_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 214, 214, 4)  196         ['activation_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 4)  196         ['activation_2[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_22[0][0]']
#  onv2D)
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_23[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_21[0][0]',
#                                 )                                 'depthwise_conv2d_2[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_5[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 214, 214, 48  0           ['activation_2[0][0]',
#                                 )                                 'conv2d_25[0][0]']
#
#  activation_3 (Activation)      (None, 214, 214, 48  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 214, 214, 4)  196         ['activation_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 214, 214, 4)  196         ['activation_3[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 214, 214, 4)  196         ['activation_3[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_27[0][0]']
#  onv2D)
#
#  conv2d_29 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_28[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_26[0][0]',
#                                 )                                 'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_6[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 214, 214, 48  0           ['activation_3[0][0]',
#                                 )                                 'conv2d_30[0][0]']
#
#  activation_4 (Activation)      (None, 214, 214, 48  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 214, 214, 4)  196         ['activation_4[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 214, 214, 4)  196         ['activation_4[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 214, 214, 4)  196         ['activation_4[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_32[0][0]']
#  onv2D)
#
#  conv2d_34 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_33[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_31[0][0]',
#                                 )                                 'depthwise_conv2d_4[0][0]',
#                                                                   'conv2d_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_7[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 214, 214, 48  0           ['activation_4[0][0]',
#                                 )                                 'conv2d_35[0][0]']
#
#  activation_5 (Activation)      (None, 214, 214, 48  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 214, 214, 32  1568        ['activation_5[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_37[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_5[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 106, 106, 48  20784       ['activation_5[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_38[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_36[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_41[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_42[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_43[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_40[0][0]',
#                                 )                                 'conv2d_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_9[0][0]']
#                                 4)
#
#  add_5 (Add)                    (None, 106, 106, 14  0           ['concatenate_8[0][0]',
#                                 4)                                'conv2d_45[0][0]']
#
#  activation_6 (Activation)      (None, 106, 106, 14  0           ['add_5[0][0]']
#                                 4)
#
#  conv2d_47 (Conv2D)             (None, 106, 106, 16  2320        ['activation_6[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 106, 106, 24  3480        ['activation_6[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_49[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_46[0][0]',
#                                 )                                 'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_10[0][0]']
#                                 4)
#
#  add_6 (Add)                    (None, 106, 106, 14  0           ['activation_6[0][0]',
#                                 4)                                'conv2d_51[0][0]']
#
#  activation_7 (Activation)      (None, 106, 106, 14  0           ['add_6[0][0]']
#                                 4)
#
#  conv2d_53 (Conv2D)             (None, 106, 106, 16  2320        ['activation_7[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 106, 106, 24  3480        ['activation_7[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_55[0][0]']
#                                 )
#
#  concatenate_11 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_52[0][0]',
#                                 )                                 'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_11[0][0]']
#                                 4)
#
#  add_7 (Add)                    (None, 106, 106, 14  0           ['activation_7[0][0]',
#                                 4)                                'conv2d_57[0][0]']
#
#  activation_8 (Activation)      (None, 106, 106, 14  0           ['add_7[0][0]']
#                                 4)
#
#  conv2d_59 (Conv2D)             (None, 106, 106, 16  2320        ['activation_8[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_59[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_60[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 106, 106, 24  3480        ['activation_8[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_61[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_58[0][0]',
#                                 )                                 'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_12[0][0]']
#                                 4)
#
#  add_8 (Add)                    (None, 106, 106, 14  0           ['activation_8[0][0]',
#                                 4)                                'conv2d_63[0][0]']
#
#  activation_9 (Activation)      (None, 106, 106, 14  0           ['add_8[0][0]']
#                                 4)
#
#  conv2d_65 (Conv2D)             (None, 106, 106, 16  2320        ['activation_9[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_65[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_66[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 106, 106, 24  3480        ['activation_9[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_67[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_64[0][0]',
#                                 )                                 'conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_13[0][0]']
#                                 4)
#
#  add_9 (Add)                    (None, 106, 106, 14  0           ['activation_9[0][0]',
#                                 4)                                'conv2d_69[0][0]']
#
#  activation_10 (Activation)     (None, 106, 106, 14  0           ['add_9[0][0]']
#                                 4)
#
#  conv2d_71 (Conv2D)             (None, 106, 106, 16  2320        ['activation_10[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_71[0][0]']
#                                 )
#
#  conv2d_73 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_72[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 106, 106, 24  3480        ['activation_10[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_73[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_70[0][0]',
#                                 )                                 'conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_14[0][0]']
#                                 4)
#
#  add_10 (Add)                   (None, 106, 106, 14  0           ['activation_10[0][0]',
#                                 4)                                'conv2d_75[0][0]']
#
#  activation_11 (Activation)     (None, 106, 106, 14  0           ['add_10[0][0]']
#                                 4)
#
#  conv2d_77 (Conv2D)             (None, 106, 106, 16  2320        ['activation_11[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_77[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_78[0][0]']
#                                 )
#
#  conv2d_76 (Conv2D)             (None, 106, 106, 24  3480        ['activation_11[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_79[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_76[0][0]',
#                                 )                                 'conv2d_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_15[0][0]']
#                                 4)
#
#  add_11 (Add)                   (None, 106, 106, 14  0           ['activation_11[0][0]',
#                                 4)                                'conv2d_81[0][0]']
#
#  activation_12 (Activation)     (None, 106, 106, 14  0           ['add_11[0][0]']
#                                 4)
#
#  conv2d_83 (Conv2D)             (None, 106, 106, 16  2320        ['activation_12[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_83[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_84[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 106, 106, 24  3480        ['activation_12[0][0]']
#                                 )
#
#  conv2d_86 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_85[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_82[0][0]',
#                                 )                                 'conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_16[0][0]']
#                                 4)
#
#  add_12 (Add)                   (None, 106, 106, 14  0           ['activation_12[0][0]',
#                                 4)                                'conv2d_87[0][0]']
#
#  activation_13 (Activation)     (None, 106, 106, 14  0           ['add_12[0][0]']
#                                 4)
#
#  conv2d_89 (Conv2D)             (None, 106, 106, 16  2320        ['activation_13[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_89[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_90[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 106, 106, 24  3480        ['activation_13[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_91[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_88[0][0]',
#                                 )                                 'conv2d_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_17[0][0]']
#                                 4)
#
#  add_13 (Add)                   (None, 106, 106, 14  0           ['activation_13[0][0]',
#                                 4)                                'conv2d_93[0][0]']
#
#  activation_14 (Activation)     (None, 106, 106, 14  0           ['add_13[0][0]']
#                                 4)
#
#  conv2d_95 (Conv2D)             (None, 106, 106, 16  2320        ['activation_14[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_95[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_96[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 106, 106, 24  3480        ['activation_14[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_97[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_94[0][0]',
#                                 )                                 'conv2d_98[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_18[0][0]']
#                                 4)
#
#  add_14 (Add)                   (None, 106, 106, 14  0           ['activation_14[0][0]',
#                                 4)                                'conv2d_99[0][0]']
#
#  activation_15 (Activation)     (None, 106, 106, 14  0           ['add_14[0][0]']
#                                 4)
#
#  conv2d_104 (Conv2D)            (None, 106, 106, 32  4640        ['activation_15[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 106, 106, 32  4640        ['activation_15[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 106, 106, 32  4640        ['activation_15[0][0]']
#                                 )
#
#  conv2d_105 (Conv2D)            (None, 106, 106, 36  10404       ['conv2d_104[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_15[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_100[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_102[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 52, 52, 40)   13000       ['conv2d_105[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_101[0][0]',
#                                                                   'conv2d_103[0][0]',
#                                                                   'conv2d_106[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_108[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_109[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_107[0][0]',
#                                                                   'conv2d_110[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_20[0][0]']
#
#  add_15 (Add)                   (None, 52, 52, 256)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_111[0][0]']
#
#  activation_16 (Activation)     (None, 52, 52, 256)  0           ['add_15[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_16[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_113[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_16[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_114[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_112[0][0]',
#                                                                   'conv2d_115[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_21[0][0]']
#
#  add_16 (Add)                   (None, 52, 52, 256)  0           ['activation_16[0][0]',
#                                                                   'conv2d_116[0][0]']
#
#  activation_17 (Activation)     (None, 52, 52, 256)  0           ['add_16[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_17[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_118[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_17[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_119[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_117[0][0]',
#                                                                   'conv2d_120[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_22[0][0]']
#
#  add_17 (Add)                   (None, 52, 52, 256)  0           ['activation_17[0][0]',
#                                                                   'conv2d_121[0][0]']
#
#  activation_18 (Activation)     (None, 52, 52, 256)  0           ['add_17[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_18[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_123[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_18[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_124[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_122[0][0]',
#                                                                   'conv2d_125[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_23[0][0]']
#
#  add_18 (Add)                   (None, 52, 52, 256)  0           ['activation_18[0][0]',
#                                                                   'conv2d_126[0][0]']
#
#  activation_19 (Activation)     (None, 52, 52, 256)  0           ['add_18[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_19[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_128[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_19[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_129[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_127[0][0]',
#                                                                   'conv2d_130[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_24[0][0]']
#
#  add_19 (Add)                   (None, 52, 52, 256)  0           ['activation_19[0][0]',
#                                                                   'conv2d_131[0][0]']
#
#  activation_20 (Activation)     (None, 52, 52, 256)  0           ['add_19[0][0]']
#
#  average_pooling2d (AveragePool  (None, 49, 49, 256)  0          ['activation_20[0][0]']
#  ing2D)
#
#  dropout (Dropout)              (None, 49, 49, 256)  0           ['average_pooling2d[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 471,918
# Trainable params: 471,918
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version1-DIR40X"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)



lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = model.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)
# Out:
# Epoch 1/150
# 2024-03-05 21:16:51.584265: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-05 21:16:53.410151: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 18.2871 - accuracy: 0.6628 - precision: 0.6628 - recall: 0.6628 - auc: 0.6849 - f1_score: 0.6628
# Epoch 1: val_loss improved from inf to 0.43420, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5
# 71/71 [==============================] - 57s 661ms/step - loss: 18.2871 - accuracy: 0.6628 - precision: 0.6628 - recall: 0.6628 - auc: 0.6849 - f1_score: 0.6628 - val_loss: 0.4342 - val_accuracy: 0.7840 - val_precision: 0.7840 - val_recall: 0.7840 - val_auc: 0.8925 - val_f1_score: 0.7840 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5115 - accuracy: 0.7689 - precision: 0.7689 - recall: 0.7689 - auc: 0.8314 - f1_score: 0.7689
# Epoch 2: val_loss improved from 0.43420 to 0.34351, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5
# 71/71 [==============================] - 44s 616ms/step - loss: 0.5115 - accuracy: 0.7689 - precision: 0.7689 - recall: 0.7689 - auc: 0.8314 - f1_score: 0.7689 - val_loss: 0.3435 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9422 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 3/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4812 - accuracy: 0.7879 - precision: 0.7879 - recall: 0.7879 - auc: 0.8510 - f1_score: 0.7879
# Epoch 3: val_loss did not improve from 0.34351
# 71/71 [==============================] - 44s 618ms/step - loss: 0.4812 - accuracy: 0.7879 - precision: 0.7879 - recall: 0.7879 - auc: 0.8510 - f1_score: 0.7879 - val_loss: 0.3712 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9513 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 4/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4828 - accuracy: 0.7932 - precision: 0.7932 - recall: 0.7932 - auc: 0.8514 - f1_score: 0.7932
# Epoch 4: val_loss improved from 0.34351 to 0.30101, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5
# 71/71 [==============================] - 44s 620ms/step - loss: 0.4828 - accuracy: 0.7932 - precision: 0.7932 - recall: 0.7932 - auc: 0.8514 - f1_score: 0.7932 - val_loss: 0.3010 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9564 - val_f1_score: 0.8935 - lr: 0.0010
# Epoch 5/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4581 - accuracy: 0.8087 - precision: 0.8087 - recall: 0.8087 - auc: 0.8631 - f1_score: 0.8087
# Epoch 5: val_loss did not improve from 0.30101
# 71/71 [==============================] - 44s 616ms/step - loss: 0.4581 - accuracy: 0.8087 - precision: 0.8087 - recall: 0.8087 - auc: 0.8631 - f1_score: 0.8087 - val_loss: 0.3407 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9523 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 6/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4541 - accuracy: 0.8078 - precision: 0.8078 - recall: 0.8078 - auc: 0.8707 - f1_score: 0.8078
# Epoch 6: val_loss improved from 0.30101 to 0.27381, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5
# 71/71 [==============================] - 44s 620ms/step - loss: 0.4541 - accuracy: 0.8078 - precision: 0.8078 - recall: 0.8078 - auc: 0.8707 - f1_score: 0.8078 - val_loss: 0.2738 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9680 - val_f1_score: 0.9024 - lr: 0.0010
# Epoch 7/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4353 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.8807 - f1_score: 0.8197
# Epoch 7: val_loss did not improve from 0.27381
# 71/71 [==============================] - 44s 614ms/step - loss: 0.4353 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.8807 - f1_score: 0.8197 - val_loss: 0.4048 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9282 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 8/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4365 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.8782 - f1_score: 0.8197
# Epoch 8: val_loss did not improve from 0.27381
# 71/71 [==============================] - 44s 615ms/step - loss: 0.4365 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.8782 - f1_score: 0.8197 - val_loss: 0.2995 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9711 - val_f1_score: 0.9201 - lr: 0.0010
# Epoch 9/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4089 - accuracy: 0.8272 - precision: 0.8272 - recall: 0.8272 - auc: 0.8945 - f1_score: 0.8272
# Epoch 9: val_loss improved from 0.27381 to 0.23526, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5
# 71/71 [==============================] - 44s 619ms/step - loss: 0.4089 - accuracy: 0.8272 - precision: 0.8272 - recall: 0.8272 - auc: 0.8945 - f1_score: 0.8272 - val_loss: 0.2353 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9810 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 10/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4317 - accuracy: 0.8241 - precision: 0.8241 - recall: 0.8241 - auc: 0.8820 - f1_score: 0.8241
# Epoch 10: val_loss did not improve from 0.23526
# 71/71 [==============================] - 44s 614ms/step - loss: 0.4317 - accuracy: 0.8241 - precision: 0.8241 - recall: 0.8241 - auc: 0.8820 - f1_score: 0.8241 - val_loss: 0.2361 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9833 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 11/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4053 - accuracy: 0.8272 - precision: 0.8272 - recall: 0.8272 - auc: 0.8979 - f1_score: 0.8272
# Epoch 11: val_loss did not improve from 0.23526
# 71/71 [==============================] - 44s 614ms/step - loss: 0.4053 - accuracy: 0.8272 - precision: 0.8272 - recall: 0.8272 - auc: 0.8979 - f1_score: 0.8272 - val_loss: 0.3544 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9454 - val_f1_score: 0.9024 - lr: 0.0010
# Epoch 12/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3925 - accuracy: 0.8299 - precision: 0.8299 - recall: 0.8299 - auc: 0.9049 - f1_score: 0.8299
# Epoch 12: val_loss did not improve from 0.23526
# 71/71 [==============================] - 44s 614ms/step - loss: 0.3925 - accuracy: 0.8299 - precision: 0.8299 - recall: 0.8299 - auc: 0.9049 - f1_score: 0.8299 - val_loss: 0.2938 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9774 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 13/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3971 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.9039 - f1_score: 0.8294
# Epoch 13: val_loss did not improve from 0.23526
# 71/71 [==============================] - 44s 614ms/step - loss: 0.3971 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.9039 - f1_score: 0.8294 - val_loss: 0.2611 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9672 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 14/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3773 - accuracy: 0.8387 - precision: 0.8387 - recall: 0.8387 - auc: 0.9118 - f1_score: 0.8387
# Epoch 14: val_loss did not improve from 0.23526
# 71/71 [==============================] - 44s 614ms/step - loss: 0.3773 - accuracy: 0.8387 - precision: 0.8387 - recall: 0.8387 - auc: 0.9118 - f1_score: 0.8387 - val_loss: 0.5082 - val_accuracy: 0.7544 - val_precision: 0.7544 - val_recall: 0.7544 - val_auc: 0.8539 - val_f1_score: 0.7544 - lr: 0.0010
# Epoch 15/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4057 - accuracy: 0.8241 - precision: 0.8241 - recall: 0.8241 - auc: 0.8976 - f1_score: 0.8241
# Epoch 15: val_loss did not improve from 0.23526
# 71/71 [==============================] - 44s 615ms/step - loss: 0.4057 - accuracy: 0.8241 - precision: 0.8241 - recall: 0.8241 - auc: 0.8976 - f1_score: 0.8241 - val_loss: 0.2792 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9673 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 16/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3783 - accuracy: 0.8489 - precision: 0.8489 - recall: 0.8489 - auc: 0.9106 - f1_score: 0.8489
# Epoch 16: val_loss did not improve from 0.23526
# 71/71 [==============================] - 44s 614ms/step - loss: 0.3783 - accuracy: 0.8489 - precision: 0.8489 - recall: 0.8489 - auc: 0.9106 - f1_score: 0.8489 - val_loss: 0.2821 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9614 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 17/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3576 - accuracy: 0.8515 - precision: 0.8515 - recall: 0.8515 - auc: 0.9204 - f1_score: 0.8515
# Epoch 17: val_loss did not improve from 0.23526
# 71/71 [==============================] - 44s 614ms/step - loss: 0.3576 - accuracy: 0.8515 - precision: 0.8515 - recall: 0.8515 - auc: 0.9204 - f1_score: 0.8515 - val_loss: 0.2887 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9640 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 18/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3577 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9208 - f1_score: 0.8462
# Epoch 18: val_loss did not improve from 0.23526
# 71/71 [==============================] - 44s 614ms/step - loss: 0.3577 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9208 - f1_score: 0.8462 - val_loss: 0.2762 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9771 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 19/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.8555 - precision: 0.8555 - recall: 0.8555 - auc: 0.9209 - f1_score: 0.8555
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 19: val_loss did not improve from 0.23526
# 71/71 [==============================] - 44s 614ms/step - loss: 0.3586 - accuracy: 0.8555 - precision: 0.8555 - recall: 0.8555 - auc: 0.9209 - f1_score: 0.8555 - val_loss: 0.2798 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9552 - val_f1_score: 0.8846 - lr: 0.0010
# Epoch 20/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.8657 - precision: 0.8657 - recall: 0.8657 - auc: 0.9404 - f1_score: 0.8657
# Epoch 20: val_loss did not improve from 0.23526
# 71/71 [==============================] - 44s 614ms/step - loss: 0.3119 - accuracy: 0.8657 - precision: 0.8657 - recall: 0.8657 - auc: 0.9404 - f1_score: 0.8657 - val_loss: 0.2484 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9787 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 21/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2992 - accuracy: 0.8745 - precision: 0.8745 - recall: 0.8745 - auc: 0.9454 - f1_score: 0.8745
# Epoch 21: val_loss improved from 0.23526 to 0.21500, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2992 - accuracy: 0.8745 - precision: 0.8745 - recall: 0.8745 - auc: 0.9454 - f1_score: 0.8745 - val_loss: 0.2150 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9853 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 22/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2907 - accuracy: 0.8776 - precision: 0.8776 - recall: 0.8776 - auc: 0.9486 - f1_score: 0.8776
# Epoch 22: val_loss improved from 0.21500 to 0.19077, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2907 - accuracy: 0.8776 - precision: 0.8776 - recall: 0.8776 - auc: 0.9486 - f1_score: 0.8776 - val_loss: 0.1908 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9891 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 23/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9447 - f1_score: 0.8749
# Epoch 23: val_loss did not improve from 0.19077
# 71/71 [==============================] - 44s 615ms/step - loss: 0.3000 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9447 - f1_score: 0.8749 - val_loss: 0.2419 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9760 - val_f1_score: 0.9290 - lr: 1.0000e-04
# Epoch 24/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2916 - accuracy: 0.8723 - precision: 0.8723 - recall: 0.8723 - auc: 0.9481 - f1_score: 0.8723
# Epoch 24: val_loss did not improve from 0.19077
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2916 - accuracy: 0.8723 - precision: 0.8723 - recall: 0.8723 - auc: 0.9481 - f1_score: 0.8723 - val_loss: 0.2099 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9861 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 25/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2818 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9514 - f1_score: 0.8833
# Epoch 25: val_loss did not improve from 0.19077
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2818 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9514 - f1_score: 0.8833 - val_loss: 0.2186 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9788 - val_f1_score: 0.9231 - lr: 1.0000e-04
# Epoch 26/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2868 - accuracy: 0.8825 - precision: 0.8825 - recall: 0.8825 - auc: 0.9492 - f1_score: 0.8825
# Epoch 26: val_loss did not improve from 0.19077
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2868 - accuracy: 0.8825 - precision: 0.8825 - recall: 0.8825 - auc: 0.9492 - f1_score: 0.8825 - val_loss: 0.2260 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9767 - val_f1_score: 0.9083 - lr: 1.0000e-04
# Epoch 27/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9511 - f1_score: 0.8833
# Epoch 27: val_loss did not improve from 0.19077
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2819 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9511 - f1_score: 0.8833 - val_loss: 0.2022 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9842 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 28/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2837 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9505 - f1_score: 0.8842
# Epoch 28: val_loss did not improve from 0.19077
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2837 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9505 - f1_score: 0.8842 - val_loss: 0.2560 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9667 - val_f1_score: 0.9083 - lr: 1.0000e-04
# Epoch 29/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2751 - accuracy: 0.8909 - precision: 0.8909 - recall: 0.8909 - auc: 0.9539 - f1_score: 0.8909
# Epoch 29: val_loss did not improve from 0.19077
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2751 - accuracy: 0.8909 - precision: 0.8909 - recall: 0.8909 - auc: 0.9539 - f1_score: 0.8909 - val_loss: 0.1935 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9900 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 30/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.8847 - precision: 0.8847 - recall: 0.8847 - auc: 0.9525 - f1_score: 0.8847
# Epoch 30: val_loss did not improve from 0.19077
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2792 - accuracy: 0.8847 - precision: 0.8847 - recall: 0.8847 - auc: 0.9525 - f1_score: 0.8847 - val_loss: 0.2518 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9660 - val_f1_score: 0.9083 - lr: 1.0000e-04
# Epoch 31/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2660 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9570 - f1_score: 0.8860
# Epoch 31: val_loss did not improve from 0.19077
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2660 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9570 - f1_score: 0.8860 - val_loss: 0.2216 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9787 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 32/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2670 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9564 - f1_score: 0.8904
# Epoch 32: val_loss improved from 0.19077 to 0.17026, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2670 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9564 - f1_score: 0.8904 - val_loss: 0.1703 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9900 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 33/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2728 - accuracy: 0.8856 - precision: 0.8856 - recall: 0.8856 - auc: 0.9544 - f1_score: 0.8856
# Epoch 33: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2728 - accuracy: 0.8856 - precision: 0.8856 - recall: 0.8856 - auc: 0.9544 - f1_score: 0.8856 - val_loss: 0.2439 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9719 - val_f1_score: 0.9142 - lr: 1.0000e-04
# Epoch 34/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2618 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9576 - f1_score: 0.8962
# Epoch 34: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2618 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9576 - f1_score: 0.8962 - val_loss: 0.2245 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9787 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 35/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2736 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9536 - f1_score: 0.8873
# Epoch 35: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2736 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9536 - f1_score: 0.8873 - val_loss: 0.2086 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9800 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 36/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2838 - accuracy: 0.8829 - precision: 0.8829 - recall: 0.8829 - auc: 0.9506 - f1_score: 0.8829
# Epoch 36: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2838 - accuracy: 0.8829 - precision: 0.8829 - recall: 0.8829 - auc: 0.9506 - f1_score: 0.8829 - val_loss: 0.2112 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9813 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 37/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.8891 - precision: 0.8891 - recall: 0.8891 - auc: 0.9575 - f1_score: 0.8891
# Epoch 37: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2646 - accuracy: 0.8891 - precision: 0.8891 - recall: 0.8891 - auc: 0.9575 - f1_score: 0.8891 - val_loss: 0.2121 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9834 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 38/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2652 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9570 - f1_score: 0.8860
# Epoch 38: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2652 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9570 - f1_score: 0.8860 - val_loss: 0.2758 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9537 - val_f1_score: 0.8935 - lr: 1.0000e-04
# Epoch 39/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.8913 - precision: 0.8913 - recall: 0.8913 - auc: 0.9599 - f1_score: 0.8913
# Epoch 39: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 616ms/step - loss: 0.2562 - accuracy: 0.8913 - precision: 0.8913 - recall: 0.8913 - auc: 0.9599 - f1_score: 0.8913 - val_loss: 0.2342 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9721 - val_f1_score: 0.9112 - lr: 1.0000e-04
# Epoch 40/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2630 - accuracy: 0.8886 - precision: 0.8886 - recall: 0.8886 - auc: 0.9577 - f1_score: 0.8886
# Epoch 40: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2630 - accuracy: 0.8886 - precision: 0.8886 - recall: 0.8886 - auc: 0.9577 - f1_score: 0.8886 - val_loss: 0.1828 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9854 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 41/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2538 - accuracy: 0.8922 - precision: 0.8922 - recall: 0.8922 - auc: 0.9608 - f1_score: 0.8922
# Epoch 41: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2538 - accuracy: 0.8922 - precision: 0.8922 - recall: 0.8922 - auc: 0.9608 - f1_score: 0.8922 - val_loss: 0.1935 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9853 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 42/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2478 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9630 - f1_score: 0.9010
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 42: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2478 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9630 - f1_score: 0.9010 - val_loss: 0.2398 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9684 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 43/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2415 - accuracy: 0.8975 - precision: 0.8975 - recall: 0.8975 - auc: 0.9644 - f1_score: 0.8975
# Epoch 43: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2415 - accuracy: 0.8975 - precision: 0.8975 - recall: 0.8975 - auc: 0.9644 - f1_score: 0.8975 - val_loss: 0.1838 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9873 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 44/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2463 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9625 - f1_score: 0.9054
# Epoch 44: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2463 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9625 - f1_score: 0.9054 - val_loss: 0.1839 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9853 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 45/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2357 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - auc: 0.9663 - f1_score: 0.9041
# Epoch 45: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2357 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - auc: 0.9663 - f1_score: 0.9041 - val_loss: 0.1820 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9880 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 46/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2418 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9642 - f1_score: 0.9010
# Epoch 46: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2418 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9642 - f1_score: 0.9010 - val_loss: 0.1803 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9865 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 47/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2347 - accuracy: 0.9068 - precision: 0.9068 - recall: 0.9068 - auc: 0.9661 - f1_score: 0.9068
# Epoch 47: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2347 - accuracy: 0.9068 - precision: 0.9068 - recall: 0.9068 - auc: 0.9661 - f1_score: 0.9068 - val_loss: 0.1827 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9879 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 48/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2397 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9647 - f1_score: 0.9037
# Epoch 48: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2397 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9647 - f1_score: 0.9037 - val_loss: 0.1875 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9885 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 49/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9662 - f1_score: 0.9085
# Epoch 49: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2346 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9662 - f1_score: 0.9085 - val_loss: 0.1925 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9840 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 50/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2259 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9688 - f1_score: 0.9094
# Epoch 50: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2259 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9688 - f1_score: 0.9094 - val_loss: 0.1806 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9879 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 51/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2352 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9662 - f1_score: 0.9019
# Epoch 51: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2352 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9662 - f1_score: 0.9019 - val_loss: 0.1839 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9868 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 52/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9668 - f1_score: 0.9103
# Epoch 52: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 52: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2330 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9668 - f1_score: 0.9103 - val_loss: 0.1932 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9828 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 53/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2277 - accuracy: 0.9169 - precision: 0.9169 - recall: 0.9169 - auc: 0.9681 - f1_score: 0.9169
# Epoch 53: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 616ms/step - loss: 0.2277 - accuracy: 0.9169 - precision: 0.9169 - recall: 0.9169 - auc: 0.9681 - f1_score: 0.9169 - val_loss: 0.1832 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9824 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 54/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2339 - accuracy: 0.9099 - precision: 0.9099 - recall: 0.9099 - auc: 0.9661 - f1_score: 0.9099
# Epoch 54: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2339 - accuracy: 0.9099 - precision: 0.9099 - recall: 0.9099 - auc: 0.9661 - f1_score: 0.9099 - val_loss: 0.2087 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9799 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 55/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2362 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - auc: 0.9657 - f1_score: 0.9041
# Epoch 55: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2362 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - auc: 0.9657 - f1_score: 0.9041 - val_loss: 0.1810 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9875 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 56/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2306 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9676 - f1_score: 0.9085
# Epoch 56: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 613ms/step - loss: 0.2306 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9676 - f1_score: 0.9085 - val_loss: 0.1766 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9868 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 57/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2225 - accuracy: 0.9116 - precision: 0.9116 - recall: 0.9116 - auc: 0.9698 - f1_score: 0.9116
# Epoch 57: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2225 - accuracy: 0.9116 - precision: 0.9116 - recall: 0.9116 - auc: 0.9698 - f1_score: 0.9116 - val_loss: 0.2085 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9788 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 58/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2324 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9673 - f1_score: 0.9063
# Epoch 58: val_loss did not improve from 0.17026
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2324 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9673 - f1_score: 0.9063 - val_loss: 0.1903 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9831 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 59/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9691 - f1_score: 0.9090
# Epoch 59: val_loss improved from 0.17026 to 0.14970, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2248 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9691 - f1_score: 0.9090 - val_loss: 0.1497 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9934 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 60/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2330 - accuracy: 0.9116 - precision: 0.9116 - recall: 0.9116 - auc: 0.9664 - f1_score: 0.9116
# Epoch 60: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2330 - accuracy: 0.9116 - precision: 0.9116 - recall: 0.9116 - auc: 0.9664 - f1_score: 0.9116 - val_loss: 0.1840 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9861 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 61/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2295 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9675 - f1_score: 0.9081
# Epoch 61: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2295 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9675 - f1_score: 0.9081 - val_loss: 0.1729 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9878 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 62/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2273 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9686 - f1_score: 0.9063
# Epoch 62: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2273 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9686 - f1_score: 0.9063 - val_loss: 0.1542 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9929 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 63/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9667 - f1_score: 0.9023
# Epoch 63: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2337 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9667 - f1_score: 0.9023 - val_loss: 0.1585 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9931 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 64/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9681 - f1_score: 0.9090
# Epoch 64: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2291 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9681 - f1_score: 0.9090 - val_loss: 0.1780 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9872 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 65/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2260 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9690 - f1_score: 0.9054
# Epoch 65: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 616ms/step - loss: 0.2260 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9690 - f1_score: 0.9054 - val_loss: 0.1826 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9860 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 66/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2356 - accuracy: 0.9072 - precision: 0.9072 - recall: 0.9072 - auc: 0.9660 - f1_score: 0.9072
# Epoch 66: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 616ms/step - loss: 0.2356 - accuracy: 0.9072 - precision: 0.9072 - recall: 0.9072 - auc: 0.9660 - f1_score: 0.9072 - val_loss: 0.1949 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9828 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 67/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2357 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9656 - f1_score: 0.9094
# Epoch 67: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 616ms/step - loss: 0.2357 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9656 - f1_score: 0.9094 - val_loss: 0.1809 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9861 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 68/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2291 - accuracy: 0.9072 - precision: 0.9072 - recall: 0.9072 - auc: 0.9679 - f1_score: 0.9072
# Epoch 68: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2291 - accuracy: 0.9072 - precision: 0.9072 - recall: 0.9072 - auc: 0.9679 - f1_score: 0.9072 - val_loss: 0.2029 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9798 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 69/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2314 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9672 - f1_score: 0.9085
# Epoch 69: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2314 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9672 - f1_score: 0.9085 - val_loss: 0.1959 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9818 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 70/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2227 - accuracy: 0.9121 - precision: 0.9121 - recall: 0.9121 - auc: 0.9698 - f1_score: 0.9121
# Epoch 70: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2227 - accuracy: 0.9121 - precision: 0.9121 - recall: 0.9121 - auc: 0.9698 - f1_score: 0.9121 - val_loss: 0.1863 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9836 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 71/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2335 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9666 - f1_score: 0.9019
# Epoch 71: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2335 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9666 - f1_score: 0.9019 - val_loss: 0.1936 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9828 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 72/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2353 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - auc: 0.9661 - f1_score: 0.9041
# Epoch 72: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2353 - accuracy: 0.9041 - precision: 0.9041 - recall: 0.9041 - auc: 0.9661 - f1_score: 0.9041 - val_loss: 0.1907 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9836 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 73/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2287 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9678 - f1_score: 0.9076
# Epoch 73: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2287 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9678 - f1_score: 0.9076 - val_loss: 0.1968 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9821 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 74/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2254 - accuracy: 0.9116 - precision: 0.9116 - recall: 0.9116 - auc: 0.9685 - f1_score: 0.9116
# Epoch 74: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 616ms/step - loss: 0.2254 - accuracy: 0.9116 - precision: 0.9116 - recall: 0.9116 - auc: 0.9685 - f1_score: 0.9116 - val_loss: 0.1739 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9874 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 75/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9702 - f1_score: 0.9103
# Epoch 75: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 616ms/step - loss: 0.2217 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9702 - f1_score: 0.9103 - val_loss: 0.1897 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9835 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 76/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2243 - accuracy: 0.9072 - precision: 0.9072 - recall: 0.9072 - auc: 0.9690 - f1_score: 0.9072
# Epoch 76: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2243 - accuracy: 0.9072 - precision: 0.9072 - recall: 0.9072 - auc: 0.9690 - f1_score: 0.9072 - val_loss: 0.1856 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9828 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 77/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2266 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9688 - f1_score: 0.9085
# Epoch 77: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2266 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9688 - f1_score: 0.9085 - val_loss: 0.1929 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9840 - val_f1_score: 0.9260 - lr: 1.0000e-05
# Epoch 78/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2115 - accuracy: 0.9138 - precision: 0.9138 - recall: 0.9138 - auc: 0.9729 - f1_score: 0.9138
# Epoch 78: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2115 - accuracy: 0.9138 - precision: 0.9138 - recall: 0.9138 - auc: 0.9729 - f1_score: 0.9138 - val_loss: 0.1750 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9865 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 79/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2223 - accuracy: 0.9059 - precision: 0.9059 - recall: 0.9059 - auc: 0.9697 - f1_score: 0.9059
# Epoch 79: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2223 - accuracy: 0.9059 - precision: 0.9059 - recall: 0.9059 - auc: 0.9697 - f1_score: 0.9059 - val_loss: 0.2026 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9784 - val_f1_score: 0.9231 - lr: 1.0000e-05
# Epoch 80/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2218 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9701 - f1_score: 0.9085
# Epoch 80: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2218 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9701 - f1_score: 0.9085 - val_loss: 0.1925 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9806 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 81/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2243 - accuracy: 0.9099 - precision: 0.9099 - recall: 0.9099 - auc: 0.9692 - f1_score: 0.9099
# Epoch 81: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2243 - accuracy: 0.9099 - precision: 0.9099 - recall: 0.9099 - auc: 0.9692 - f1_score: 0.9099 - val_loss: 0.1796 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9876 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 82/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9032 - precision: 0.9032 - recall: 0.9032 - auc: 0.9696 - f1_score: 0.9032
# Epoch 82: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2238 - accuracy: 0.9032 - precision: 0.9032 - recall: 0.9032 - auc: 0.9696 - f1_score: 0.9032 - val_loss: 0.1746 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9827 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 83/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2236 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9696 - f1_score: 0.9090
# Epoch 83: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2236 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9696 - f1_score: 0.9090 - val_loss: 0.1899 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9832 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 84/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2211 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9703 - f1_score: 0.9076
# Epoch 84: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2211 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9703 - f1_score: 0.9076 - val_loss: 0.1736 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9866 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 85/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9700 - f1_score: 0.9085
# Epoch 85: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2219 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9700 - f1_score: 0.9085 - val_loss: 0.1825 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9838 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 86/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9681 - f1_score: 0.9085
# Epoch 86: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2276 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9681 - f1_score: 0.9085 - val_loss: 0.1909 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9822 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 87/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9705 - f1_score: 0.9125
# Epoch 87: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2187 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9705 - f1_score: 0.9125 - val_loss: 0.2042 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9779 - val_f1_score: 0.9142 - lr: 1.0000e-05
# Epoch 88/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9672 - f1_score: 0.9081
# Epoch 88: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2301 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9672 - f1_score: 0.9081 - val_loss: 0.1561 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9905 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 89/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2223 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9695 - f1_score: 0.9134
# Epoch 89: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2223 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9695 - f1_score: 0.9134 - val_loss: 0.1989 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9813 - val_f1_score: 0.9172 - lr: 1.0000e-05
# Epoch 90/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2238 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9690 - f1_score: 0.9134
# Epoch 90: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2238 - accuracy: 0.9134 - precision: 0.9134 - recall: 0.9134 - auc: 0.9690 - f1_score: 0.9134 - val_loss: 0.1646 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9875 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 91/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2230 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9696 - f1_score: 0.9103
# ...
# Epoch 121/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1968 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9763 - f1_score: 0.9213
# Epoch 121: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.1968 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9763 - f1_score: 0.9213 - val_loss: 0.1681 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9873 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 122/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2075 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9738 - f1_score: 0.9165
# Epoch 122: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2075 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9738 - f1_score: 0.9165 - val_loss: 0.1621 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9908 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 123/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9725 - f1_score: 0.9165
# Epoch 123: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2117 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9725 - f1_score: 0.9165 - val_loss: 0.2109 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9751 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 124/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9738 - f1_score: 0.9160
# Epoch 124: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2079 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9738 - f1_score: 0.9160 - val_loss: 0.1646 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9890 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 125/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2144 - accuracy: 0.9183 - precision: 0.9183 - recall: 0.9183 - auc: 0.9716 - f1_score: 0.9183
# Epoch 125: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2144 - accuracy: 0.9183 - precision: 0.9183 - recall: 0.9183 - auc: 0.9716 - f1_score: 0.9183 - val_loss: 0.1819 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9832 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 126/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2151 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9717 - f1_score: 0.9152
# Epoch 126: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2151 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9717 - f1_score: 0.9152 - val_loss: 0.1582 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9892 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 127/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2051 - accuracy: 0.9222 - precision: 0.9222 - recall: 0.9222 - auc: 0.9741 - f1_score: 0.9222
# Epoch 127: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2051 - accuracy: 0.9222 - precision: 0.9222 - recall: 0.9222 - auc: 0.9741 - f1_score: 0.9222 - val_loss: 0.1898 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9804 - val_f1_score: 0.9231 - lr: 1.0000e-05
# Epoch 128/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2020 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9749 - f1_score: 0.9174
# Epoch 128: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2020 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9749 - f1_score: 0.9174 - val_loss: 0.1751 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9846 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 129/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2111 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9731 - f1_score: 0.9112
# Epoch 129: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2111 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9731 - f1_score: 0.9112 - val_loss: 0.1824 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9829 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 130/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2063 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9742 - f1_score: 0.9178
# Epoch 130: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2063 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9742 - f1_score: 0.9178 - val_loss: 0.1989 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9786 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 131/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2110 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9725 - f1_score: 0.9160
# Epoch 131: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 616ms/step - loss: 0.2110 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9725 - f1_score: 0.9160 - val_loss: 0.1643 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9891 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 132/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2124 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9722 - f1_score: 0.9174
# Epoch 132: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2124 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9722 - f1_score: 0.9174 - val_loss: 0.1907 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9815 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 133/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2059 - accuracy: 0.9222 - precision: 0.9222 - recall: 0.9222 - auc: 0.9740 - f1_score: 0.9222
# Epoch 133: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2059 - accuracy: 0.9222 - precision: 0.9222 - recall: 0.9222 - auc: 0.9740 - f1_score: 0.9222 - val_loss: 0.1680 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9867 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 134/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2118 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9721 - f1_score: 0.9152
# Epoch 134: val_loss did not improve from 0.14970
# 71/71 [==============================] - 44s 617ms/step - loss: 0.2118 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9721 - f1_score: 0.9152 - val_loss: 0.1563 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9901 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 135/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9737 - f1_score: 0.9187
# Epoch 135: val_loss improved from 0.14970 to 0.14457, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2058 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9737 - f1_score: 0.9187 - val_loss: 0.1446 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9915 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 136/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1949 - accuracy: 0.9205 - precision: 0.9205 - recall: 0.9205 - auc: 0.9770 - f1_score: 0.9205
# Epoch 136: val_loss did not improve from 0.14457
# 71/71 [==============================] - 44s 615ms/step - loss: 0.1949 - accuracy: 0.9205 - precision: 0.9205 - recall: 0.9205 - auc: 0.9770 - f1_score: 0.9205 - val_loss: 0.1777 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9864 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 137/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9777 - f1_score: 0.9271
# Epoch 137: val_loss did not improve from 0.14457
# 71/71 [==============================] - 44s 614ms/step - loss: 0.1928 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9777 - f1_score: 0.9271 - val_loss: 0.1584 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9899 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 138/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9209 - precision: 0.9209 - recall: 0.9209 - auc: 0.9754 - f1_score: 0.9209
# Epoch 138: val_loss did not improve from 0.14457
# 71/71 [==============================] - 44s 615ms/step - loss: 0.1997 - accuracy: 0.9209 - precision: 0.9209 - recall: 0.9209 - auc: 0.9754 - f1_score: 0.9209 - val_loss: 0.1707 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9850 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 139/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2059 - accuracy: 0.9169 - precision: 0.9169 - recall: 0.9169 - auc: 0.9742 - f1_score: 0.9169
# Epoch 139: val_loss did not improve from 0.14457
# 71/71 [==============================] - 44s 615ms/step - loss: 0.2059 - accuracy: 0.9169 - precision: 0.9169 - recall: 0.9169 - auc: 0.9742 - f1_score: 0.9169 - val_loss: 0.1556 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9875 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 140/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2048 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9742 - f1_score: 0.9187
# Epoch 140: val_loss did not improve from 0.14457
# 71/71 [==============================] - 44s 614ms/step - loss: 0.2048 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9742 - f1_score: 0.9187 - val_loss: 0.1759 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9835 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 141/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9760 - f1_score: 0.9187
# Epoch 141: val_loss did not improve from 0.14457
# 71/71 [==============================] - 44s 617ms/step - loss: 0.1989 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9760 - f1_score: 0.9187 - val_loss: 0.1535 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9887 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 142/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1901 - accuracy: 0.9253 - precision: 0.9253 - recall: 0.9253 - auc: 0.9778 - f1_score: 0.9253
# Epoch 142: val_loss did not improve from 0.14457
# 71/71 [==============================] - 44s 614ms/step - loss: 0.1901 - accuracy: 0.9253 - precision: 0.9253 - recall: 0.9253 - auc: 0.9778 - f1_score: 0.9253 - val_loss: 0.1613 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9887 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 143/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9249 - precision: 0.9249 - recall: 0.9249 - auc: 0.9764 - f1_score: 0.9249
# Epoch 143: val_loss improved from 0.14457 to 0.14164, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version1-DIR.h5
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1953 - accuracy: 0.9249 - precision: 0.9249 - recall: 0.9249 - auc: 0.9764 - f1_score: 0.9249 - val_loss: 0.1416 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9901 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 144/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9767 - f1_score: 0.9231
# Epoch 144: val_loss did not improve from 0.14164
# 71/71 [==============================] - 44s 614ms/step - loss: 0.1935 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9767 - f1_score: 0.9231 - val_loss: 0.1731 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9859 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 145/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9759 - f1_score: 0.9213
# Epoch 145: val_loss did not improve from 0.14164
# 71/71 [==============================] - 44s 613ms/step - loss: 0.1984 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9759 - f1_score: 0.9213 - val_loss: 0.1510 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9895 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 146/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1940 - accuracy: 0.9222 - precision: 0.9222 - recall: 0.9222 - auc: 0.9769 - f1_score: 0.9222
# Epoch 146: val_loss did not improve from 0.14164
# 71/71 [==============================] - 44s 614ms/step - loss: 0.1940 - accuracy: 0.9222 - precision: 0.9222 - recall: 0.9222 - auc: 0.9769 - f1_score: 0.9222 - val_loss: 0.2025 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9783 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 147/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9753 - f1_score: 0.9178
# Epoch 147: val_loss did not improve from 0.14164
# 71/71 [==============================] - 44s 614ms/step - loss: 0.1993 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9753 - f1_score: 0.9178 - val_loss: 0.1848 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9837 - val_f1_score: 0.9201 - lr: 1.0000e-05
# Epoch 148/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1932 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9773 - f1_score: 0.9231
# Epoch 148: val_loss did not improve from 0.14164
# 71/71 [==============================] - 44s 614ms/step - loss: 0.1932 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9773 - f1_score: 0.9231 - val_loss: 0.1573 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9889 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 149/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1955 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9769 - f1_score: 0.9191
# Epoch 149: val_loss did not improve from 0.14164
# 71/71 [==============================] - 44s 614ms/step - loss: 0.1955 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9769 - f1_score: 0.9191 - val_loss: 0.1559 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9877 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 150/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1938 - accuracy: 0.9227 - precision: 0.9227 - recall: 0.9227 - auc: 0.9769 - f1_score: 0.9227
# Epoch 150: val_loss did not improve from 0.14164
# 71/71 [==============================] - 44s 614ms/step - loss: 0.1938 - accuracy: 0.9227 - precision: 0.9227 - recall: 0.9227 - auc: 0.9769 - f1_score: 0.9227 - val_loss: 0.1615 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9866 - val_f1_score: 0.9438 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 2s 102ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9214616853013362
# F1-Score for each class: [0.89473684 0.94818653]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9242424242424242
# specificity: 0.9444444444444444

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 1s 103ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 1s 137ms/step - loss: 0.2233 - accuracy: 0.9329 - precision: 0.9329 - recall: 0.9329 - auc: 0.9725 - f1_score: 0.9329
# Test loss: 0.2233055680990219
# Test accuracy: 0.9328858852386475
# Test precision: 0.9328858852386475
# Test recall: 0.9328858852386475
# Test AUC: 0.9725237488746643
# Test F1 Score: 0.9328858852386475

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 1s 102ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89        90
#            1       0.97      0.92      0.95       198
#
#     accuracy                           0.93       288
#    macro avg       0.91      0.93      0.92       288
# weighted avg       0.93      0.93      0.93       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 9>()
#       6 K.clear_session()
#       7 gc.collect()
# ----> 9 del model
#      12 from numba import cuda
#      14 cuda.select_device(0)
#
# NameError: name 'model' is not defined
