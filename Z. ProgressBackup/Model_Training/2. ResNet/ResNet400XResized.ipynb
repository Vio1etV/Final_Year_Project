# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/BCResize/400X/test'
train_dir = '/root/BreastCancer/BCResize/400X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/BCResize/400X/test/benign'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1782 images belonging to 2 classes.
# Found 266 images belonging to 2 classes.
# Found 272 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %% [markdown]
# <h1>Model Construction<h1>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, GlobalAveragePooling2D, Dense

def resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Input Convolution
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Residual Blocks
    for filters in [64, 128, 64, 128]:
        # Residual connection
        identity = x

        # Adjust the number of filters in identity to match x if necessary
        if identity.shape[-1] != filters:
            identity = Conv2D(filters, (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(identity)
            identity = BatchNormalization()(identity)

        # First Convolution
        x = Conv2D(filters, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)

        # Second Convolution
        x = Conv2D(filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)

        # Add Residual Connection
        x = Add()([x, identity])
        x = Activation('relu')(x)

        # Optional: Additional MaxPooling
        x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model



# Create the ResNet model
model = resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 64)   36928       ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 56, 56, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation (Activation)        (None, 56, 56, 64)   0           ['add[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  147584      ['batch_normalization_4[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 128)  8320        ['max_pooling2d_1[0][0]']
# 2023-12-25 10:53:15.110313: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-25 10:53:15.692096: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:61:00.0, compute capability: 8.6
#
#  batch_normalization_5 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 128)  0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  activation_1 (Activation)      (None, 28, 28, 128)  0           ['add_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 64)   73792       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 64)   36928       ['batch_normalization_7[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 64)   8256        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 64)   0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_2 (Activation)      (None, 14, 14, 64)   0           ['add_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 64)    0           ['activation_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 128)    73856       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 7, 7, 128)   512         ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 128)    147584      ['batch_normalization_10[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 128)    8320        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 7, 7, 128)   512         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 128)   512         ['conv2d_9[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  activation_3 (Activation)      (None, 7, 7, 128)    0           ['add_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 128)   0           ['activation_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['max_pooling2d_4[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            258         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 666,690
# Trainable params: 664,386
# Non-trainable params: 2,304
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "ResNet400XResized"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/2. ResNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-25 10:53:20.200064: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-25 10:53:22.424831: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 56/56 [==============================] - 26s 377ms/step - loss: 0.4584 - accuracy: 0.7941 - precision: 0.7941 - recall: 0.7941 - auc: 0.8772 - f1_score: 0.7941 - val_loss: 5.7733 - val_accuracy: 0.5113 - val_precision: 0.5113 - val_recall: 0.5113 - val_auc: 0.5113 - val_f1_score: 0.5113 - lr: 0.0010
# Epoch 2/100
# 56/56 [==============================] - 20s 362ms/step - loss: 0.3562 - accuracy: 0.8474 - precision: 0.8474 - recall: 0.8474 - auc: 0.9260 - f1_score: 0.8474 - val_loss: 1.7523 - val_accuracy: 0.5113 - val_precision: 0.5113 - val_recall: 0.5113 - val_auc: 0.6615 - val_f1_score: 0.5113 - lr: 0.0010
# Epoch 3/100
# 56/56 [==============================] - 20s 359ms/step - loss: 0.3157 - accuracy: 0.8704 - precision: 0.8704 - recall: 0.8704 - auc: 0.9395 - f1_score: 0.8704 - val_loss: 3.6207 - val_accuracy: 0.5113 - val_precision: 0.5113 - val_recall: 0.5113 - val_auc: 0.4963 - val_f1_score: 0.5113 - lr: 0.0010
# Epoch 4/100
# 56/56 [==============================] - 20s 360ms/step - loss: 0.2982 - accuracy: 0.8743 - precision: 0.8743 - recall: 0.8743 - auc: 0.9464 - f1_score: 0.8743 - val_loss: 1.8845 - val_accuracy: 0.5113 - val_precision: 0.5113 - val_recall: 0.5113 - val_auc: 0.5236 - val_f1_score: 0.5113 - lr: 0.0010
# Epoch 5/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.2883 - accuracy: 0.8782 - precision: 0.8782 - recall: 0.8782 - auc: 0.9497 - f1_score: 0.8782 - val_loss: 0.9006 - val_accuracy: 0.4549 - val_precision: 0.4549 - val_recall: 0.4549 - val_auc: 0.4259 - val_f1_score: 0.4549 - lr: 0.0010
# Epoch 6/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.2465 - accuracy: 0.8967 - precision: 0.8967 - recall: 0.8967 - auc: 0.9631 - f1_score: 0.8967 - val_loss: 1.0407 - val_accuracy: 0.4286 - val_precision: 0.4286 - val_recall: 0.4286 - val_auc: 0.4519 - val_f1_score: 0.4286 - lr: 0.0010
# Epoch 7/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.2607 - accuracy: 0.8889 - precision: 0.8889 - recall: 0.8889 - auc: 0.9584 - f1_score: 0.8889 - val_loss: 0.6954 - val_accuracy: 0.7632 - val_precision: 0.7632 - val_recall: 0.7632 - val_auc: 0.8273 - val_f1_score: 0.7632 - lr: 0.0010
# Epoch 8/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.2398 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9648 - f1_score: 0.8979 - val_loss: 0.6059 - val_accuracy: 0.6654 - val_precision: 0.6654 - val_recall: 0.6654 - val_auc: 0.7809 - val_f1_score: 0.6654 - lr: 0.0010
# Epoch 9/100
# 56/56 [==============================] - 20s 360ms/step - loss: 0.2030 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9747 - f1_score: 0.9231 - val_loss: 0.7257 - val_accuracy: 0.7293 - val_precision: 0.7293 - val_recall: 0.7293 - val_auc: 0.7659 - val_f1_score: 0.7293 - lr: 0.0010
# Epoch 10/100
# 56/56 [==============================] - 20s 362ms/step - loss: 0.1814 - accuracy: 0.9349 - precision: 0.9349 - recall: 0.9349 - auc: 0.9791 - f1_score: 0.9349 - val_loss: 2.5987 - val_accuracy: 0.5113 - val_precision: 0.5113 - val_recall: 0.5113 - val_auc: 0.4257 - val_f1_score: 0.5113 - lr: 0.0010
# Epoch 11/100
# 56/56 [==============================] - 20s 362ms/step - loss: 0.2066 - accuracy: 0.9158 - precision: 0.9158 - recall: 0.9158 - auc: 0.9737 - f1_score: 0.9158 - val_loss: 0.7102 - val_accuracy: 0.6654 - val_precision: 0.6654 - val_recall: 0.6654 - val_auc: 0.7652 - val_f1_score: 0.6654 - lr: 0.0010
# Epoch 12/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.1729 - accuracy: 0.9338 - precision: 0.9338 - recall: 0.9338 - auc: 0.9812 - f1_score: 0.9338 - val_loss: 6.6078 - val_accuracy: 0.4774 - val_precision: 0.4774 - val_recall: 0.4774 - val_auc: 0.4415 - val_f1_score: 0.4774 - lr: 0.0010
# Epoch 13/100
# 56/56 [==============================] - 20s 361ms/step - loss: 0.2001 - accuracy: 0.9242 - precision: 0.9242 - recall: 0.9242 - auc: 0.9758 - f1_score: 0.9242 - val_loss: 3.2047 - val_accuracy: 0.4549 - val_precision: 0.4549 - val_recall: 0.4549 - val_auc: 0.3751 - val_f1_score: 0.4549 - lr: 0.0010
# Epoch 14/100
# 56/56 [==============================] - 20s 362ms/step - loss: 0.1770 - accuracy: 0.9332 - precision: 0.9332 - recall: 0.9332 - auc: 0.9809 - f1_score: 0.9332 - val_loss: 2.3204 - val_accuracy: 0.5301 - val_precision: 0.5301 - val_recall: 0.5301 - val_auc: 0.4704 - val_f1_score: 0.5301 - lr: 0.0010
# Epoch 15/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.1922 - accuracy: 0.9198 - precision: 0.9198 - recall: 0.9198 - auc: 0.9769 - f1_score: 0.9198 - val_loss: 2.6421 - val_accuracy: 0.4850 - val_precision: 0.4850 - val_recall: 0.4850 - val_auc: 0.4905 - val_f1_score: 0.4850 - lr: 0.0010
# Epoch 16/100
# 56/56 [==============================] - 21s 366ms/step - loss: 0.1707 - accuracy: 0.9349 - precision: 0.9349 - recall: 0.9349 - auc: 0.9820 - f1_score: 0.9349 - val_loss: 0.7941 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_auc: 0.7533 - val_f1_score: 0.6992 - lr: 0.0010
# Epoch 17/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.1663 - accuracy: 0.9416 - precision: 0.9416 - recall: 0.9416 - auc: 0.9826 - f1_score: 0.9416 - val_loss: 0.6211 - val_accuracy: 0.7105 - val_precision: 0.7105 - val_recall: 0.7105 - val_auc: 0.8324 - val_f1_score: 0.7105 - lr: 0.0010
# Epoch 18/100
# 56/56 [==============================] - ETA: 0s - loss: 0.1605 - accuracy: 0.9400 - precision: 0.9400 - recall: 0.9400 - auc: 0.9836 - f1_score: 0.9400
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 56/56 [==============================] - 21s 367ms/step - loss: 0.1605 - accuracy: 0.9400 - precision: 0.9400 - recall: 0.9400 - auc: 0.9836 - f1_score: 0.9400 - val_loss: 2.9142 - val_accuracy: 0.4925 - val_precision: 0.4925 - val_recall: 0.4925 - val_auc: 0.5068 - val_f1_score: 0.4925 - lr: 0.0010
# Epoch 19/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.1165 - accuracy: 0.9545 - precision: 0.9545 - recall: 0.9545 - auc: 0.9914 - f1_score: 0.9545 - val_loss: 1.2295 - val_accuracy: 0.5075 - val_precision: 0.5075 - val_recall: 0.5075 - val_auc: 0.6039 - val_f1_score: 0.5075 - lr: 1.0000e-04
# Epoch 20/100
# 56/56 [==============================] - 21s 366ms/step - loss: 0.0967 - accuracy: 0.9658 - precision: 0.9658 - recall: 0.9658 - auc: 0.9947 - f1_score: 0.9658 - val_loss: 0.6041 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.8301 - val_f1_score: 0.7707 - lr: 1.0000e-04
# Epoch 21/100
# 56/56 [==============================] - 20s 361ms/step - loss: 0.0935 - accuracy: 0.9669 - precision: 0.9669 - recall: 0.9669 - auc: 0.9949 - f1_score: 0.9669 - val_loss: 0.7700 - val_accuracy: 0.7368 - val_precision: 0.7368 - val_recall: 0.7368 - val_auc: 0.7965 - val_f1_score: 0.7368 - lr: 1.0000e-04
# Epoch 22/100
# 56/56 [==============================] - 20s 360ms/step - loss: 0.0956 - accuracy: 0.9663 - precision: 0.9663 - recall: 0.9663 - auc: 0.9946 - f1_score: 0.9663 - val_loss: 0.8178 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.8171 - val_f1_score: 0.7744 - lr: 1.0000e-04
# Epoch 23/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0873 - accuracy: 0.9680 - precision: 0.9680 - recall: 0.9680 - auc: 0.9955 - f1_score: 0.9680 - val_loss: 1.1755 - val_accuracy: 0.5977 - val_precision: 0.5977 - val_recall: 0.5977 - val_auc: 0.6666 - val_f1_score: 0.5977 - lr: 1.0000e-04
# Epoch 24/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0883 - accuracy: 0.9703 - precision: 0.9703 - recall: 0.9703 - auc: 0.9949 - f1_score: 0.9703 - val_loss: 1.0919 - val_accuracy: 0.6429 - val_precision: 0.6429 - val_recall: 0.6429 - val_auc: 0.7130 - val_f1_score: 0.6429 - lr: 1.0000e-04
# Epoch 25/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0799 - accuracy: 0.9747 - precision: 0.9747 - recall: 0.9747 - auc: 0.9958 - f1_score: 0.9747 - val_loss: 1.0764 - val_accuracy: 0.7556 - val_precision: 0.7556 - val_recall: 0.7556 - val_auc: 0.7813 - val_f1_score: 0.7556 - lr: 1.0000e-04
# Epoch 26/100
# 56/56 [==============================] - 20s 366ms/step - loss: 0.0748 - accuracy: 0.9776 - precision: 0.9776 - recall: 0.9776 - auc: 0.9964 - f1_score: 0.9776 - val_loss: 0.8458 - val_accuracy: 0.8083 - val_precision: 0.8083 - val_recall: 0.8083 - val_auc: 0.8333 - val_f1_score: 0.8083 - lr: 1.0000e-04
# Epoch 27/100
# 56/56 [==============================] - 20s 360ms/step - loss: 0.0747 - accuracy: 0.9725 - precision: 0.9725 - recall: 0.9725 - auc: 0.9967 - f1_score: 0.9725 - val_loss: 0.6967 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8626 - val_f1_score: 0.8308 - lr: 1.0000e-04
# Epoch 28/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0804 - accuracy: 0.9708 - precision: 0.9708 - recall: 0.9708 - auc: 0.9961 - f1_score: 0.9708 - val_loss: 0.6355 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.8883 - val_f1_score: 0.8571 - lr: 1.0000e-04
# Epoch 29/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0691 - accuracy: 0.9792 - precision: 0.9792 - recall: 0.9792 - auc: 0.9971 - f1_score: 0.9792 - val_loss: 0.7154 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8743 - val_f1_score: 0.8308 - lr: 1.0000e-04
# Epoch 30/100
# 56/56 [==============================] - ETA: 0s - loss: 0.0787 - accuracy: 0.9714 - precision: 0.9714 - recall: 0.9714 - auc: 0.9958 - f1_score: 0.9714
# Epoch 30: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0787 - accuracy: 0.9714 - precision: 0.9714 - recall: 0.9714 - auc: 0.9958 - f1_score: 0.9714 - val_loss: 0.7813 - val_accuracy: 0.7932 - val_precision: 0.7932 - val_recall: 0.7932 - val_auc: 0.8312 - val_f1_score: 0.7932 - lr: 1.0000e-04
# Epoch 31/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0606 - accuracy: 0.9798 - precision: 0.9798 - recall: 0.9798 - auc: 0.9976 - f1_score: 0.9798 - val_loss: 0.6946 - val_accuracy: 0.8271 - val_precision: 0.8271 - val_recall: 0.8271 - val_auc: 0.8703 - val_f1_score: 0.8271 - lr: 1.0000e-05
# Epoch 32/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0584 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9982 - f1_score: 0.9804 - val_loss: 0.6537 - val_accuracy: 0.8346 - val_precision: 0.8346 - val_recall: 0.8346 - val_auc: 0.8836 - val_f1_score: 0.8346 - lr: 1.0000e-05
# Epoch 33/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.0577 - accuracy: 0.9809 - precision: 0.9809 - recall: 0.9809 - auc: 0.9984 - f1_score: 0.9809 - val_loss: 0.6417 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.8872 - val_f1_score: 0.8571 - lr: 1.0000e-05
# Epoch 34/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0671 - accuracy: 0.9809 - precision: 0.9809 - recall: 0.9809 - auc: 0.9969 - f1_score: 0.9809 - val_loss: 0.6586 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.8811 - val_f1_score: 0.8571 - lr: 1.0000e-05
# Epoch 35/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0655 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9976 - f1_score: 0.9764 - val_loss: 0.6656 - val_accuracy: 0.8346 - val_precision: 0.8346 - val_recall: 0.8346 - val_auc: 0.8791 - val_f1_score: 0.8346 - lr: 1.0000e-05
# Epoch 36/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0499 - accuracy: 0.9854 - precision: 0.9854 - recall: 0.9854 - auc: 0.9987 - f1_score: 0.9854 - val_loss: 0.6786 - val_accuracy: 0.8534 - val_precision: 0.8534 - val_recall: 0.8534 - val_auc: 0.8825 - val_f1_score: 0.8534 - lr: 1.0000e-05
# Epoch 37/100
# 56/56 [==============================] - 21s 366ms/step - loss: 0.0555 - accuracy: 0.9809 - precision: 0.9809 - recall: 0.9809 - auc: 0.9985 - f1_score: 0.9809 - val_loss: 0.7100 - val_accuracy: 0.8459 - val_precision: 0.8459 - val_recall: 0.8459 - val_auc: 0.8716 - val_f1_score: 0.8459 - lr: 1.0000e-05
# Epoch 38/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.0693 - accuracy: 0.9742 - precision: 0.9742 - recall: 0.9742 - auc: 0.9972 - f1_score: 0.9742 - val_loss: 0.7620 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8667 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 39/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0643 - accuracy: 0.9770 - precision: 0.9770 - recall: 0.9770 - auc: 0.9975 - f1_score: 0.9770 - val_loss: 0.8075 - val_accuracy: 0.8459 - val_precision: 0.8459 - val_recall: 0.8459 - val_auc: 0.8536 - val_f1_score: 0.8459 - lr: 1.0000e-05
# Epoch 40/100
# 56/56 [==============================] - ETA: 0s - loss: 0.0579 - accuracy: 0.9832 - precision: 0.9832 - recall: 0.9832 - auc: 0.9982 - f1_score: 0.9832
# Epoch 40: ReduceLROnPlateau reducing learning rate to 1e-05.
# 56/56 [==============================] - 20s 362ms/step - loss: 0.0579 - accuracy: 0.9832 - precision: 0.9832 - recall: 0.9832 - auc: 0.9982 - f1_score: 0.9832 - val_loss: 0.7617 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8702 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 41/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0731 - accuracy: 0.9742 - precision: 0.9742 - recall: 0.9742 - auc: 0.9964 - f1_score: 0.9742 - val_loss: 0.7922 - val_accuracy: 0.8271 - val_precision: 0.8271 - val_recall: 0.8271 - val_auc: 0.8630 - val_f1_score: 0.8271 - lr: 1.0000e-05
# Epoch 42/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0551 - accuracy: 0.9832 - precision: 0.9832 - recall: 0.9832 - auc: 0.9984 - f1_score: 0.9832 - val_loss: 0.8282 - val_accuracy: 0.8195 - val_precision: 0.8195 - val_recall: 0.8195 - val_auc: 0.8563 - val_f1_score: 0.8195 - lr: 1.0000e-05
# Epoch 43/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0636 - accuracy: 0.9759 - precision: 0.9759 - recall: 0.9759 - auc: 0.9978 - f1_score: 0.9759 - val_loss: 0.8781 - val_accuracy: 0.8233 - val_precision: 0.8233 - val_recall: 0.8233 - val_auc: 0.8455 - val_f1_score: 0.8233 - lr: 1.0000e-05
# Epoch 44/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0648 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9972 - f1_score: 0.9764 - val_loss: 0.7974 - val_accuracy: 0.8233 - val_precision: 0.8233 - val_recall: 0.8233 - val_auc: 0.8561 - val_f1_score: 0.8233 - lr: 1.0000e-05
# Epoch 45/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.0584 - accuracy: 0.9781 - precision: 0.9781 - recall: 0.9781 - auc: 0.9983 - f1_score: 0.9781 - val_loss: 0.7405 - val_accuracy: 0.8120 - val_precision: 0.8120 - val_recall: 0.8120 - val_auc: 0.8597 - val_f1_score: 0.8120 - lr: 1.0000e-05
# Epoch 46/100
# 56/56 [==============================] - 21s 370ms/step - loss: 0.0616 - accuracy: 0.9820 - precision: 0.9820 - recall: 0.9820 - auc: 0.9979 - f1_score: 0.9820 - val_loss: 0.8050 - val_accuracy: 0.8158 - val_precision: 0.8158 - val_recall: 0.8158 - val_auc: 0.8535 - val_f1_score: 0.8158 - lr: 1.0000e-05
# Epoch 47/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0644 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9974 - f1_score: 0.9764 - val_loss: 0.7785 - val_accuracy: 0.8271 - val_precision: 0.8271 - val_recall: 0.8271 - val_auc: 0.8601 - val_f1_score: 0.8271 - lr: 1.0000e-05
# Epoch 48/100
# 56/56 [==============================] - 20s 366ms/step - loss: 0.0512 - accuracy: 0.9854 - precision: 0.9854 - recall: 0.9854 - auc: 0.9985 - f1_score: 0.9854 - val_loss: 0.7349 - val_accuracy: 0.8459 - val_precision: 0.8459 - val_recall: 0.8459 - val_auc: 0.8718 - val_f1_score: 0.8459 - lr: 1.0000e-05
# Epoch 49/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0591 - accuracy: 0.9809 - precision: 0.9809 - recall: 0.9809 - auc: 0.9981 - f1_score: 0.9809 - val_loss: 0.7991 - val_accuracy: 0.8233 - val_precision: 0.8233 - val_recall: 0.8233 - val_auc: 0.8610 - val_f1_score: 0.8233 - lr: 1.0000e-05
# Epoch 50/100
# 56/56 [==============================] - 20s 362ms/step - loss: 0.0687 - accuracy: 0.9759 - precision: 0.9759 - recall: 0.9759 - auc: 0.9970 - f1_score: 0.9759 - val_loss: 0.7488 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.8717 - val_f1_score: 0.8421 - lr: 1.0000e-05
# Epoch 51/100
# 56/56 [==============================] - 20s 360ms/step - loss: 0.0577 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9982 - f1_score: 0.9804 - val_loss: 0.7674 - val_accuracy: 0.8271 - val_precision: 0.8271 - val_recall: 0.8271 - val_auc: 0.8638 - val_f1_score: 0.8271 - lr: 1.0000e-05
# Epoch 52/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0582 - accuracy: 0.9792 - precision: 0.9792 - recall: 0.9792 - auc: 0.9981 - f1_score: 0.9792 - val_loss: 0.8046 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8513 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 53/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.0669 - accuracy: 0.9781 - precision: 0.9781 - recall: 0.9781 - auc: 0.9974 - f1_score: 0.9781 - val_loss: 0.6836 - val_accuracy: 0.8346 - val_precision: 0.8346 - val_recall: 0.8346 - val_auc: 0.8788 - val_f1_score: 0.8346 - lr: 1.0000e-05
# Epoch 54/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0563 - accuracy: 0.9848 - precision: 0.9848 - recall: 0.9848 - auc: 0.9982 - f1_score: 0.9848 - val_loss: 0.8176 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8543 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 55/100
# 56/56 [==============================] - 21s 368ms/step - loss: 0.0503 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - auc: 0.9986 - f1_score: 0.9843 - val_loss: 0.7708 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.8676 - val_f1_score: 0.8421 - lr: 1.0000e-05
# Epoch 56/100
# 56/56 [==============================] - 20s 360ms/step - loss: 0.0643 - accuracy: 0.9770 - precision: 0.9770 - recall: 0.9770 - auc: 0.9974 - f1_score: 0.9770 - val_loss: 0.6872 - val_accuracy: 0.8534 - val_precision: 0.8534 - val_recall: 0.8534 - val_auc: 0.8831 - val_f1_score: 0.8534 - lr: 1.0000e-05
# Epoch 57/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0627 - accuracy: 0.9798 - precision: 0.9798 - recall: 0.9798 - auc: 0.9975 - f1_score: 0.9798 - val_loss: 0.7788 - val_accuracy: 0.8271 - val_precision: 0.8271 - val_recall: 0.8271 - val_auc: 0.8604 - val_f1_score: 0.8271 - lr: 1.0000e-05
# Epoch 58/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.0611 - accuracy: 0.9781 - precision: 0.9781 - recall: 0.9781 - auc: 0.9977 - f1_score: 0.9781 - val_loss: 0.7286 - val_accuracy: 0.8459 - val_precision: 0.8459 - val_recall: 0.8459 - val_auc: 0.8744 - val_f1_score: 0.8459 - lr: 1.0000e-05
# Epoch 59/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.0571 - accuracy: 0.9832 - precision: 0.9832 - recall: 0.9832 - auc: 0.9977 - f1_score: 0.9832 - val_loss: 0.7408 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.8734 - val_f1_score: 0.8609 - lr: 1.0000e-05
# Epoch 60/100
# 56/56 [==============================] - 20s 366ms/step - loss: 0.0531 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9987 - f1_score: 0.9804 - val_loss: 0.7904 - val_accuracy: 0.8271 - val_precision: 0.8271 - val_recall: 0.8271 - val_auc: 0.8729 - val_f1_score: 0.8271 - lr: 1.0000e-05
# Epoch 61/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.0682 - accuracy: 0.9781 - precision: 0.9781 - recall: 0.9781 - auc: 0.9967 - f1_score: 0.9781 - val_loss: 0.7905 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8667 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 62/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0561 - accuracy: 0.9837 - precision: 0.9837 - recall: 0.9837 - auc: 0.9982 - f1_score: 0.9837 - val_loss: 0.8118 - val_accuracy: 0.8271 - val_precision: 0.8271 - val_recall: 0.8271 - val_auc: 0.8535 - val_f1_score: 0.8271 - lr: 1.0000e-05
# Epoch 63/100
# 56/56 [==============================] - 20s 362ms/step - loss: 0.0619 - accuracy: 0.9787 - precision: 0.9787 - recall: 0.9787 - auc: 0.9978 - f1_score: 0.9787 - val_loss: 0.7382 - val_accuracy: 0.8346 - val_precision: 0.8346 - val_recall: 0.8346 - val_auc: 0.8749 - val_f1_score: 0.8346 - lr: 1.0000e-05
# Epoch 64/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0580 - accuracy: 0.9792 - precision: 0.9792 - recall: 0.9792 - auc: 0.9981 - f1_score: 0.9792 - val_loss: 0.7500 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8647 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 65/100
# 56/56 [==============================] - 20s 362ms/step - loss: 0.0581 - accuracy: 0.9809 - precision: 0.9809 - recall: 0.9809 - auc: 0.9982 - f1_score: 0.9809 - val_loss: 0.7670 - val_accuracy: 0.8496 - val_precision: 0.8496 - val_recall: 0.8496 - val_auc: 0.8692 - val_f1_score: 0.8496 - lr: 1.0000e-05
# Epoch 66/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0511 - accuracy: 0.9826 - precision: 0.9826 - recall: 0.9826 - auc: 0.9982 - f1_score: 0.9826 - val_loss: 0.7861 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.8894 - val_f1_score: 0.8421 - lr: 1.0000e-05
# Epoch 67/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0625 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9973 - f1_score: 0.9804 - val_loss: 0.7641 - val_accuracy: 0.8459 - val_precision: 0.8459 - val_recall: 0.8459 - val_auc: 0.8786 - val_f1_score: 0.8459 - lr: 1.0000e-05
# Epoch 68/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0574 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - auc: 0.9976 - f1_score: 0.9843 - val_loss: 0.8214 - val_accuracy: 0.8346 - val_precision: 0.8346 - val_recall: 0.8346 - val_auc: 0.8553 - val_f1_score: 0.8346 - lr: 1.0000e-05
# Epoch 69/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0553 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - auc: 0.9981 - f1_score: 0.9843 - val_loss: 0.7334 - val_accuracy: 0.8459 - val_precision: 0.8459 - val_recall: 0.8459 - val_auc: 0.8784 - val_f1_score: 0.8459 - lr: 1.0000e-05
# Epoch 70/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.0542 - accuracy: 0.9792 - precision: 0.9792 - recall: 0.9792 - auc: 0.9980 - f1_score: 0.9792 - val_loss: 0.7247 - val_accuracy: 0.8346 - val_precision: 0.8346 - val_recall: 0.8346 - val_auc: 0.8774 - val_f1_score: 0.8346 - lr: 1.0000e-05
# Epoch 71/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0487 - accuracy: 0.9826 - precision: 0.9826 - recall: 0.9826 - auc: 0.9987 - f1_score: 0.9826 - val_loss: 0.7816 - val_accuracy: 0.8346 - val_precision: 0.8346 - val_recall: 0.8346 - val_auc: 0.8655 - val_f1_score: 0.8346 - lr: 1.0000e-05
# Epoch 72/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0604 - accuracy: 0.9776 - precision: 0.9776 - recall: 0.9776 - auc: 0.9977 - f1_score: 0.9776 - val_loss: 0.7780 - val_accuracy: 0.8534 - val_precision: 0.8534 - val_recall: 0.8534 - val_auc: 0.8704 - val_f1_score: 0.8534 - lr: 1.0000e-05
# Epoch 73/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0570 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9978 - f1_score: 0.9804 - val_loss: 0.8588 - val_accuracy: 0.8233 - val_precision: 0.8233 - val_recall: 0.8233 - val_auc: 0.8515 - val_f1_score: 0.8233 - lr: 1.0000e-05
# Epoch 74/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0451 - accuracy: 0.9877 - precision: 0.9877 - recall: 0.9877 - auc: 0.9989 - f1_score: 0.9877 - val_loss: 0.8374 - val_accuracy: 0.8383 - val_precision: 0.8383 - val_recall: 0.8383 - val_auc: 0.8575 - val_f1_score: 0.8383 - lr: 1.0000e-05
# Epoch 75/100
# 56/56 [==============================] - 20s 366ms/step - loss: 0.0435 - accuracy: 0.9888 - precision: 0.9888 - recall: 0.9888 - auc: 0.9987 - f1_score: 0.9888 - val_loss: 0.7618 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.8805 - val_f1_score: 0.8421 - lr: 1.0000e-05
# Epoch 76/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.0551 - accuracy: 0.9776 - precision: 0.9776 - recall: 0.9776 - auc: 0.9984 - f1_score: 0.9776 - val_loss: 0.8557 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8540 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 77/100
# 56/56 [==============================] - 20s 366ms/step - loss: 0.0511 - accuracy: 0.9820 - precision: 0.9820 - recall: 0.9820 - auc: 0.9986 - f1_score: 0.9820 - val_loss: 0.7527 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8651 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 78/100
# 56/56 [==============================] - 21s 368ms/step - loss: 0.0563 - accuracy: 0.9792 - precision: 0.9792 - recall: 0.9792 - auc: 0.9983 - f1_score: 0.9792 - val_loss: 0.7993 - val_accuracy: 0.8459 - val_precision: 0.8459 - val_recall: 0.8459 - val_auc: 0.8757 - val_f1_score: 0.8459 - lr: 1.0000e-05
# Epoch 79/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0527 - accuracy: 0.9798 - precision: 0.9798 - recall: 0.9798 - auc: 0.9983 - f1_score: 0.9798 - val_loss: 0.7198 - val_accuracy: 0.8534 - val_precision: 0.8534 - val_recall: 0.8534 - val_auc: 0.8795 - val_f1_score: 0.8534 - lr: 1.0000e-05
# Epoch 80/100
# 56/56 [==============================] - 20s 366ms/step - loss: 0.0557 - accuracy: 0.9804 - precision: 0.9804 - recall: 0.9804 - auc: 0.9973 - f1_score: 0.9804 - val_loss: 0.7409 - val_accuracy: 0.8496 - val_precision: 0.8496 - val_recall: 0.8496 - val_auc: 0.8762 - val_f1_score: 0.8496 - lr: 1.0000e-05
# Epoch 81/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0415 - accuracy: 0.9877 - precision: 0.9877 - recall: 0.9877 - auc: 0.9992 - f1_score: 0.9877 - val_loss: 0.7747 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.8693 - val_f1_score: 0.8421 - lr: 1.0000e-05
# Epoch 82/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.0582 - accuracy: 0.9809 - precision: 0.9809 - recall: 0.9809 - auc: 0.9974 - f1_score: 0.9809 - val_loss: 0.7799 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.8728 - val_f1_score: 0.8421 - lr: 1.0000e-05
# Epoch 83/100
# 56/56 [==============================] - 20s 359ms/step - loss: 0.0510 - accuracy: 0.9809 - precision: 0.9809 - recall: 0.9809 - auc: 0.9987 - f1_score: 0.9809 - val_loss: 0.7642 - val_accuracy: 0.8496 - val_precision: 0.8496 - val_recall: 0.8496 - val_auc: 0.8817 - val_f1_score: 0.8496 - lr: 1.0000e-05
# Epoch 84/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.0627 - accuracy: 0.9787 - precision: 0.9787 - recall: 0.9787 - auc: 0.9977 - f1_score: 0.9787 - val_loss: 0.7536 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.8740 - val_f1_score: 0.8421 - lr: 1.0000e-05
# Epoch 85/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0504 - accuracy: 0.9837 - precision: 0.9837 - recall: 0.9837 - auc: 0.9986 - f1_score: 0.9837 - val_loss: 0.8254 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8773 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 86/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.0494 - accuracy: 0.9860 - precision: 0.9860 - recall: 0.9860 - auc: 0.9983 - f1_score: 0.9860 - val_loss: 0.7510 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.8837 - val_f1_score: 0.8421 - lr: 1.0000e-05
# Epoch 87/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0495 - accuracy: 0.9826 - precision: 0.9826 - recall: 0.9826 - auc: 0.9984 - f1_score: 0.9826 - val_loss: 0.8583 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8707 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 88/100
# 56/56 [==============================] - 21s 366ms/step - loss: 0.0484 - accuracy: 0.9871 - precision: 0.9871 - recall: 0.9871 - auc: 0.9978 - f1_score: 0.9871 - val_loss: 0.7481 - val_accuracy: 0.8647 - val_precision: 0.8647 - val_recall: 0.8647 - val_auc: 0.8840 - val_f1_score: 0.8647 - lr: 1.0000e-05
# Epoch 89/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0527 - accuracy: 0.9832 - precision: 0.9832 - recall: 0.9832 - auc: 0.9983 - f1_score: 0.9832 - val_loss: 0.7400 - val_accuracy: 0.8647 - val_precision: 0.8647 - val_recall: 0.8647 - val_auc: 0.8794 - val_f1_score: 0.8647 - lr: 1.0000e-05
# Epoch 90/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0492 - accuracy: 0.9837 - precision: 0.9837 - recall: 0.9837 - auc: 0.9985 - f1_score: 0.9837 - val_loss: 0.7690 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.8743 - val_f1_score: 0.8571 - lr: 1.0000e-05
# Epoch 91/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.0479 - accuracy: 0.9826 - precision: 0.9826 - recall: 0.9826 - auc: 0.9988 - f1_score: 0.9826 - val_loss: 0.7737 - val_accuracy: 0.8496 - val_precision: 0.8496 - val_recall: 0.8496 - val_auc: 0.8818 - val_f1_score: 0.8496 - lr: 1.0000e-05
# Epoch 92/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0541 - accuracy: 0.9837 - precision: 0.9837 - recall: 0.9837 - auc: 0.9978 - f1_score: 0.9837 - val_loss: 0.7948 - val_accuracy: 0.8571 - val_precision: 0.8571 - val_recall: 0.8571 - val_auc: 0.8795 - val_f1_score: 0.8571 - lr: 1.0000e-05
# Epoch 93/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0479 - accuracy: 0.9815 - precision: 0.9815 - recall: 0.9815 - auc: 0.9987 - f1_score: 0.9815 - val_loss: 0.8404 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8760 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 94/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.0490 - accuracy: 0.9854 - precision: 0.9854 - recall: 0.9854 - auc: 0.9981 - f1_score: 0.9854 - val_loss: 0.8381 - val_accuracy: 0.8383 - val_precision: 0.8383 - val_recall: 0.8383 - val_auc: 0.8605 - val_f1_score: 0.8383 - lr: 1.0000e-05
# Epoch 95/100
# 56/56 [==============================] - 20s 363ms/step - loss: 0.0433 - accuracy: 0.9865 - precision: 0.9865 - recall: 0.9865 - auc: 0.9989 - f1_score: 0.9865 - val_loss: 0.8140 - val_accuracy: 0.8346 - val_precision: 0.8346 - val_recall: 0.8346 - val_auc: 0.8643 - val_f1_score: 0.8346 - lr: 1.0000e-05
# Epoch 96/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.0459 - accuracy: 0.9843 - precision: 0.9843 - recall: 0.9843 - auc: 0.9983 - f1_score: 0.9843 - val_loss: 0.9159 - val_accuracy: 0.8195 - val_precision: 0.8195 - val_recall: 0.8195 - val_auc: 0.8631 - val_f1_score: 0.8195 - lr: 1.0000e-05
# Epoch 97/100
# 56/56 [==============================] - 20s 361ms/step - loss: 0.0407 - accuracy: 0.9888 - precision: 0.9888 - recall: 0.9888 - auc: 0.9991 - f1_score: 0.9888 - val_loss: 0.8325 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8760 - val_f1_score: 0.8308 - lr: 1.0000e-05
# Epoch 98/100
# 56/56 [==============================] - 21s 366ms/step - loss: 0.0411 - accuracy: 0.9882 - precision: 0.9882 - recall: 0.9882 - auc: 0.9987 - f1_score: 0.9882 - val_loss: 0.8117 - val_accuracy: 0.8496 - val_precision: 0.8496 - val_recall: 0.8496 - val_auc: 0.8745 - val_f1_score: 0.8496 - lr: 1.0000e-05
# Epoch 99/100
# 56/56 [==============================] - 20s 366ms/step - loss: 0.0483 - accuracy: 0.9832 - precision: 0.9832 - recall: 0.9832 - auc: 0.9986 - f1_score: 0.9832 - val_loss: 0.8491 - val_accuracy: 0.8383 - val_precision: 0.8383 - val_recall: 0.8383 - val_auc: 0.8686 - val_f1_score: 0.8383 - lr: 1.0000e-05
# Epoch 100/100
# 56/56 [==============================] - 21s 368ms/step - loss: 0.0459 - accuracy: 0.9837 - precision: 0.9837 - recall: 0.9837 - auc: 0.9989 - f1_score: 0.9837 - val_loss: 0.8232 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.8620 - val_f1_score: 0.8308 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 8/8 [==============================] - 0s 22ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.934777544840438
# F1-Score for each class: [0.91358025 0.95597484]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.926829268292683
# specificity: 0.9736842105263158

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 8/8 [==============================] - 0s 8ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 9/9 [==============================] - 1s 74ms/step - loss: 0.3470 - accuracy: 0.9449 - precision: 0.9449 - recall: 0.9449 - auc: 0.9593 - f1_score: 0.9449
# Test loss: 0.34696364402770996
# Test accuracy: 0.9448529481887817
# Test precision: 0.9448529481887817
# Test recall: 0.9448529481887817
# Test AUC: 0.9592613577842712
# Test F1 Score: 0.9448529481887817

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 8/8 [==============================] - 0s 9ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91        76
#            1       0.99      0.93      0.96       164
#
#     accuracy                           0.94       240
#    macro avg       0.92      0.95      0.93       240
# weighted avg       0.95      0.94      0.94       240

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
