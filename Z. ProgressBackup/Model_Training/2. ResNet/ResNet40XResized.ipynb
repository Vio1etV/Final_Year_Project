# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/BCResize/40X/test'
train_dir = '/root/BreastCancer/BCResize/40X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/BCResize/40X/test/benign'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2262 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 298 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %% [markdown]
# <h1>Model Construction<h1>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, GlobalAveragePooling2D, Dense

def resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Input Convolution
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Residual Blocks
    for filters in [64, 128, 64, 128]:
        # Residual connection
        identity = x

        # Adjust the number of filters in identity to match x if necessary
        if identity.shape[-1] != filters:
            identity = Conv2D(filters, (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(identity)
            identity = BatchNormalization()(identity)

        # First Convolution
        x = Conv2D(filters, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)

        # Second Convolution
        x = Conv2D(filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)

        # Add Residual Connection
        x = Add()([x, identity])
        x = Activation('relu')(x)

        # Optional: Additional MaxPooling
        x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Create the ResNet model
model = resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# 2023-12-24 16:48:29.990407: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 64)   36928       ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 56, 56, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation (Activation)        (None, 56, 56, 64)   0           ['add[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  147584      ['batch_normalization_4[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 128)  8320        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_3[0][0]']
# 2023-12-24 16:48:30.542784: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 128)  0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  activation_1 (Activation)      (None, 28, 28, 128)  0           ['add_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 64)   73792       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 64)   36928       ['batch_normalization_7[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 64)   8256        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 64)   0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_2 (Activation)      (None, 14, 14, 64)   0           ['add_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 64)    0           ['activation_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 128)    73856       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 7, 7, 128)   512         ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 128)    147584      ['batch_normalization_10[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 128)    8320        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 7, 7, 128)   512         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 128)   512         ['conv2d_9[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  activation_3 (Activation)      (None, 7, 7, 128)    0           ['add_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 128)   0           ['activation_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['max_pooling2d_4[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            258         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 666,690
# Trainable params: 664,386
# Non-trainable params: 2,304
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "ResNet40XResized"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/2. ResNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-24 16:48:34.947283: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-24 16:48:36.523953: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - 31s 375ms/step - loss: 0.4818 - accuracy: 0.7767 - precision: 0.7767 - recall: 0.7767 - auc: 0.8632 - f1_score: 0.7767 - val_loss: 0.8377 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5764 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 2/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3711 - accuracy: 0.8338 - precision: 0.8338 - recall: 0.8338 - auc: 0.9160 - f1_score: 0.8338 - val_loss: 1.3667 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.3927 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 3/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3441 - accuracy: 0.8431 - precision: 0.8431 - recall: 0.8431 - auc: 0.9276 - f1_score: 0.8431 - val_loss: 1.3601 - val_accuracy: 0.3491 - val_precision: 0.3491 - val_recall: 0.3491 - val_auc: 0.3581 - val_f1_score: 0.3491 - lr: 0.0010
# Epoch 4/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3321 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9327 - f1_score: 0.8462 - val_loss: 1.5191 - val_accuracy: 0.2929 - val_precision: 0.2929 - val_recall: 0.2929 - val_auc: 0.2722 - val_f1_score: 0.2929 - lr: 0.0010
# Epoch 5/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.3171 - accuracy: 0.8607 - precision: 0.8607 - recall: 0.8607 - auc: 0.9386 - f1_score: 0.8607 - val_loss: 1.5553 - val_accuracy: 0.4053 - val_precision: 0.4053 - val_recall: 0.4053 - val_auc: 0.3212 - val_f1_score: 0.4053 - lr: 0.0010
# Epoch 6/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.2863 - accuracy: 0.8696 - precision: 0.8696 - recall: 0.8696 - auc: 0.9496 - f1_score: 0.8696 - val_loss: 1.2549 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5016 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 7/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.2768 - accuracy: 0.8811 - precision: 0.8811 - recall: 0.8811 - auc: 0.9531 - f1_score: 0.8811 - val_loss: 1.5591 - val_accuracy: 0.5030 - val_precision: 0.5030 - val_recall: 0.5030 - val_auc: 0.5346 - val_f1_score: 0.5030 - lr: 0.0010
# Epoch 8/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.2246 - accuracy: 0.9058 - precision: 0.9058 - recall: 0.9058 - auc: 0.9693 - f1_score: 0.9058 - val_loss: 1.1582 - val_accuracy: 0.5799 - val_precision: 0.5799 - val_recall: 0.5799 - val_auc: 0.6786 - val_f1_score: 0.5799 - lr: 0.0010
# Epoch 9/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.2657 - accuracy: 0.8882 - precision: 0.8882 - recall: 0.8882 - auc: 0.9569 - f1_score: 0.8882 - val_loss: 3.4683 - val_accuracy: 0.5030 - val_precision: 0.5030 - val_recall: 0.5030 - val_auc: 0.5047 - val_f1_score: 0.5030 - lr: 0.0010
# Epoch 10/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.2070 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9737 - f1_score: 0.9094 - val_loss: 0.3402 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9347 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 11/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.2005 - accuracy: 0.9204 - precision: 0.9204 - recall: 0.9204 - auc: 0.9752 - f1_score: 0.9204 - val_loss: 1.7929 - val_accuracy: 0.4793 - val_precision: 0.4793 - val_recall: 0.4793 - val_auc: 0.5141 - val_f1_score: 0.4793 - lr: 0.0010
# Epoch 12/100
# 71/71 [==============================] - 25s 358ms/step - loss: 0.1889 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9782 - f1_score: 0.9200 - val_loss: 1.4045 - val_accuracy: 0.6568 - val_precision: 0.6568 - val_recall: 0.6568 - val_auc: 0.6934 - val_f1_score: 0.6568 - lr: 0.0010
# Epoch 13/100
# 71/71 [==============================] - 26s 371ms/step - loss: 0.1821 - accuracy: 0.9257 - precision: 0.9257 - recall: 0.9257 - auc: 0.9799 - f1_score: 0.9257 - val_loss: 0.4808 - val_accuracy: 0.7722 - val_precision: 0.7722 - val_recall: 0.7722 - val_auc: 0.8814 - val_f1_score: 0.7722 - lr: 0.0010
# Epoch 14/100
# 71/71 [==============================] - 27s 375ms/step - loss: 0.1853 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9786 - f1_score: 0.9297 - val_loss: 2.8110 - val_accuracy: 0.6213 - val_precision: 0.6213 - val_recall: 0.6213 - val_auc: 0.6370 - val_f1_score: 0.6213 - lr: 0.0010
# Epoch 15/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.1833 - accuracy: 0.9218 - precision: 0.9218 - recall: 0.9218 - auc: 0.9793 - f1_score: 0.9218 - val_loss: 2.0432 - val_accuracy: 0.5385 - val_precision: 0.5385 - val_recall: 0.5385 - val_auc: 0.6764 - val_f1_score: 0.5385 - lr: 0.0010
# Epoch 16/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.1507 - accuracy: 0.9377 - precision: 0.9377 - recall: 0.9377 - auc: 0.9859 - f1_score: 0.9377 - val_loss: 2.3702 - val_accuracy: 0.6213 - val_precision: 0.6213 - val_recall: 0.6213 - val_auc: 0.6733 - val_f1_score: 0.6213 - lr: 0.0010
# Epoch 17/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1370 - accuracy: 0.9425 - precision: 0.9425 - recall: 0.9425 - auc: 0.9883 - f1_score: 0.9425 - val_loss: 3.1742 - val_accuracy: 0.4911 - val_precision: 0.4911 - val_recall: 0.4911 - val_auc: 0.4509 - val_f1_score: 0.4911 - lr: 0.0010
# Epoch 18/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1375 - accuracy: 0.9469 - precision: 0.9469 - recall: 0.9469 - auc: 0.9884 - f1_score: 0.9469 - val_loss: 0.3580 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9374 - val_f1_score: 0.8639 - lr: 0.0010
# Epoch 19/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1239 - accuracy: 0.9509 - precision: 0.9509 - recall: 0.9509 - auc: 0.9902 - f1_score: 0.9509 - val_loss: 0.7012 - val_accuracy: 0.6923 - val_precision: 0.6923 - val_recall: 0.6923 - val_auc: 0.8175 - val_f1_score: 0.6923 - lr: 0.0010
# Epoch 20/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1330 - accuracy: 0.9465 - precision: 0.9465 - recall: 0.9465 - auc: 0.9888 - f1_score: 0.9465 - val_loss: 0.2914 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9556 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 21/100
# 71/71 [==============================] - 25s 358ms/step - loss: 0.1647 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9835 - f1_score: 0.9359 - val_loss: 1.1538 - val_accuracy: 0.6272 - val_precision: 0.6272 - val_recall: 0.6272 - val_auc: 0.6656 - val_f1_score: 0.6272 - lr: 0.0010
# Epoch 22/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1240 - accuracy: 0.9549 - precision: 0.9549 - recall: 0.9549 - auc: 0.9901 - f1_score: 0.9549 - val_loss: 1.4728 - val_accuracy: 0.5710 - val_precision: 0.5710 - val_recall: 0.5710 - val_auc: 0.6113 - val_f1_score: 0.5710 - lr: 0.0010
# Epoch 23/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1103 - accuracy: 0.9558 - precision: 0.9558 - recall: 0.9558 - auc: 0.9925 - f1_score: 0.9558 - val_loss: 0.9955 - val_accuracy: 0.7604 - val_precision: 0.7604 - val_recall: 0.7604 - val_auc: 0.8198 - val_f1_score: 0.7604 - lr: 0.0010
# Epoch 24/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1255 - accuracy: 0.9523 - precision: 0.9523 - recall: 0.9523 - auc: 0.9900 - f1_score: 0.9523 - val_loss: 0.9809 - val_accuracy: 0.5917 - val_precision: 0.5917 - val_recall: 0.5917 - val_auc: 0.6166 - val_f1_score: 0.5917 - lr: 0.0010
# Epoch 25/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1137 - accuracy: 0.9580 - precision: 0.9580 - recall: 0.9580 - auc: 0.9915 - f1_score: 0.9580 - val_loss: 1.8337 - val_accuracy: 0.6183 - val_precision: 0.6183 - val_recall: 0.6183 - val_auc: 0.7012 - val_f1_score: 0.6183 - lr: 0.0010
# Epoch 26/100
# 71/71 [==============================] - 27s 374ms/step - loss: 0.1182 - accuracy: 0.9558 - precision: 0.9558 - recall: 0.9558 - auc: 0.9907 - f1_score: 0.9558 - val_loss: 0.4486 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9245 - val_f1_score: 0.8402 - lr: 0.0010
# Epoch 27/100
# 71/71 [==============================] - 26s 369ms/step - loss: 0.1089 - accuracy: 0.9545 - precision: 0.9545 - recall: 0.9545 - auc: 0.9927 - f1_score: 0.9545 - val_loss: 1.7694 - val_accuracy: 0.5059 - val_precision: 0.5059 - val_recall: 0.5059 - val_auc: 0.6490 - val_f1_score: 0.5059 - lr: 0.0010
# Epoch 28/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1043 - accuracy: 0.9584 - precision: 0.9584 - recall: 0.9584 - auc: 0.9927 - f1_score: 0.9584 - val_loss: 0.3620 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9228 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 29/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.1244 - accuracy: 0.9549 - precision: 0.9549 - recall: 0.9549 - auc: 0.9898 - f1_score: 0.9549 - val_loss: 1.2262 - val_accuracy: 0.5355 - val_precision: 0.5355 - val_recall: 0.5355 - val_auc: 0.6133 - val_f1_score: 0.5355 - lr: 0.0010
# Epoch 30/100
# 71/71 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9611 - precision: 0.9611 - recall: 0.9611 - auc: 0.9941 - f1_score: 0.9611
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 71/71 [==============================] - 26s 364ms/step - loss: 0.0988 - accuracy: 0.9611 - precision: 0.9611 - recall: 0.9611 - auc: 0.9941 - f1_score: 0.9611 - val_loss: 0.3708 - val_accuracy: 0.8462 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9259 - val_f1_score: 0.8462 - lr: 0.0010
# Epoch 31/100
# 71/71 [==============================] - 26s 370ms/step - loss: 0.0797 - accuracy: 0.9721 - precision: 0.9721 - recall: 0.9721 - auc: 0.9959 - f1_score: 0.9721 - val_loss: 0.1899 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9790 - val_f1_score: 0.9083 - lr: 1.0000e-04
# Epoch 32/100
# 71/71 [==============================] - 26s 371ms/step - loss: 0.0509 - accuracy: 0.9832 - precision: 0.9832 - recall: 0.9832 - auc: 0.9986 - f1_score: 0.9832 - val_loss: 0.1041 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9942 - val_f1_score: 0.9675 - lr: 1.0000e-04
# Epoch 33/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0490 - accuracy: 0.9854 - precision: 0.9854 - recall: 0.9854 - auc: 0.9988 - f1_score: 0.9854 - val_loss: 0.1189 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9914 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 34/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.0548 - accuracy: 0.9805 - precision: 0.9805 - recall: 0.9805 - auc: 0.9982 - f1_score: 0.9805 - val_loss: 0.0273 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9999 - val_f1_score: 0.9911 - lr: 1.0000e-04
# Epoch 35/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.0470 - accuracy: 0.9832 - precision: 0.9832 - recall: 0.9832 - auc: 0.9988 - f1_score: 0.9832 - val_loss: 0.0707 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9967 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 36/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.0526 - accuracy: 0.9814 - precision: 0.9814 - recall: 0.9814 - auc: 0.9980 - f1_score: 0.9814 - val_loss: 0.0748 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9975 - val_f1_score: 0.9675 - lr: 1.0000e-04
# Epoch 37/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.0618 - accuracy: 0.9752 - precision: 0.9752 - recall: 0.9752 - auc: 0.9974 - f1_score: 0.9752 - val_loss: 0.0315 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9998 - val_f1_score: 0.9882 - lr: 1.0000e-04
# Epoch 38/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.0500 - accuracy: 0.9819 - precision: 0.9819 - recall: 0.9819 - auc: 0.9986 - f1_score: 0.9819 - val_loss: 0.0608 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9982 - val_f1_score: 0.9793 - lr: 1.0000e-04
# Epoch 39/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.0505 - accuracy: 0.9832 - precision: 0.9832 - recall: 0.9832 - auc: 0.9981 - f1_score: 0.9832 - val_loss: 0.0400 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9993 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 40/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.0399 - accuracy: 0.9876 - precision: 0.9876 - recall: 0.9876 - auc: 0.9992 - f1_score: 0.9876 - val_loss: 0.1903 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9788 - val_f1_score: 0.9290 - lr: 1.0000e-04
# Epoch 41/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.0472 - accuracy: 0.9832 - precision: 0.9832 - recall: 0.9832 - auc: 0.9987 - f1_score: 0.9832 - val_loss: 0.0437 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9962 - val_f1_score: 0.9882 - lr: 1.0000e-04
# Epoch 42/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0454 - accuracy: 0.9845 - precision: 0.9845 - recall: 0.9845 - auc: 0.9984 - f1_score: 0.9845 - val_loss: 0.0808 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9963 - val_f1_score: 0.9645 - lr: 1.0000e-04
# Epoch 43/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.0443 - accuracy: 0.9867 - precision: 0.9867 - recall: 0.9867 - auc: 0.9984 - f1_score: 0.9867 - val_loss: 0.0526 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9989 - val_f1_score: 0.9822 - lr: 1.0000e-04
# Epoch 44/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.0353 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9994 - f1_score: 0.9872 - val_loss: 0.0223 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 1.0000 - val_f1_score: 0.9970 - lr: 1.0000e-04
# Epoch 45/100
# 71/71 [==============================] - 26s 369ms/step - loss: 0.0450 - accuracy: 0.9850 - precision: 0.9850 - recall: 0.9850 - auc: 0.9979 - f1_score: 0.9850 - val_loss: 0.0726 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9974 - val_f1_score: 0.9645 - lr: 1.0000e-04
# Epoch 46/100
# 71/71 [==============================] - 26s 370ms/step - loss: 0.0395 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9991 - f1_score: 0.9872 - val_loss: 0.0236 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9997 - val_f1_score: 0.9882 - lr: 1.0000e-04
# Epoch 47/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0419 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9990 - f1_score: 0.9872 - val_loss: 0.0501 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9988 - val_f1_score: 0.9852 - lr: 1.0000e-04
# Epoch 48/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.0283 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9996 - f1_score: 0.9912 - val_loss: 0.0272 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9998 - val_f1_score: 0.9882 - lr: 1.0000e-04
# Epoch 49/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.0343 - accuracy: 0.9898 - precision: 0.9898 - recall: 0.9898 - auc: 0.9993 - f1_score: 0.9898 - val_loss: 0.0330 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9995 - val_f1_score: 0.9882 - lr: 1.0000e-04
# Epoch 50/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.0387 - accuracy: 0.9841 - precision: 0.9841 - recall: 0.9841 - auc: 0.9992 - f1_score: 0.9841 - val_loss: 0.0420 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9964 - val_f1_score: 0.9941 - lr: 1.0000e-04
# Epoch 51/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.0356 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9989 - f1_score: 0.9872 - val_loss: 0.1431 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9877 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 52/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0319 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9995 - f1_score: 0.9916 - val_loss: 0.0865 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9955 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 53/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.0300 - accuracy: 0.9889 - precision: 0.9889 - recall: 0.9889 - auc: 0.9996 - f1_score: 0.9889 - val_loss: 0.0275 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9995 - val_f1_score: 0.9911 - lr: 1.0000e-04
# Epoch 54/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.0340 - accuracy: 0.9898 - precision: 0.9898 - recall: 0.9898 - auc: 0.9993 - f1_score: 0.9898 - val_loss: 0.0158 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 1.0000 - val_f1_score: 0.9970 - lr: 1.0000e-04
# Epoch 55/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.0307 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9993 - f1_score: 0.9920 - val_loss: 0.1179 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9941 - val_f1_score: 0.9645 - lr: 1.0000e-04
# Epoch 56/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.0384 - accuracy: 0.9859 - precision: 0.9859 - recall: 0.9859 - auc: 0.9991 - f1_score: 0.9859 - val_loss: 0.1154 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9910 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 57/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.0366 - accuracy: 0.9876 - precision: 0.9876 - recall: 0.9876 - auc: 0.9992 - f1_score: 0.9876 - val_loss: 0.0541 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9981 - val_f1_score: 0.9822 - lr: 1.0000e-04
# Epoch 58/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0310 - accuracy: 0.9889 - precision: 0.9889 - recall: 0.9889 - auc: 0.9995 - f1_score: 0.9889 - val_loss: 0.0132 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 1.0000 - val_f1_score: 0.9970 - lr: 1.0000e-04
# Epoch 59/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.0405 - accuracy: 0.9867 - precision: 0.9867 - recall: 0.9867 - auc: 0.9986 - f1_score: 0.9867 - val_loss: 0.0449 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9990 - val_f1_score: 0.9822 - lr: 1.0000e-04
# Epoch 60/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.0311 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9991 - f1_score: 0.9894 - val_loss: 0.1319 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9900 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 61/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0341 - accuracy: 0.9898 - precision: 0.9898 - recall: 0.9898 - auc: 0.9989 - f1_score: 0.9898 - val_loss: 0.0172 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9999 - val_f1_score: 0.9941 - lr: 1.0000e-04
# Epoch 62/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.0318 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9994 - f1_score: 0.9894 - val_loss: 0.0255 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9997 - val_f1_score: 0.9941 - lr: 1.0000e-04
# Epoch 63/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.0207 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9998 - f1_score: 0.9934 - val_loss: 0.0164 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 1.0000 - val_f1_score: 0.9941 - lr: 1.0000e-04
# Epoch 64/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.0281 - accuracy: 0.9889 - precision: 0.9889 - recall: 0.9889 - auc: 0.9996 - f1_score: 0.9889 - val_loss: 0.1257 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9906 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 65/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0350 - accuracy: 0.9881 - precision: 0.9881 - recall: 0.9881 - auc: 0.9992 - f1_score: 0.9881 - val_loss: 0.0206 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 0.9999 - val_f1_score: 0.9970 - lr: 1.0000e-04
# Epoch 66/100
# 71/71 [==============================] - 27s 376ms/step - loss: 0.0336 - accuracy: 0.9885 - precision: 0.9885 - recall: 0.9885 - auc: 0.9993 - f1_score: 0.9885 - val_loss: 0.0211 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9998 - val_f1_score: 0.9911 - lr: 1.0000e-04
# Epoch 67/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.0321 - accuracy: 0.9881 - precision: 0.9881 - recall: 0.9881 - auc: 0.9994 - f1_score: 0.9881 - val_loss: 0.2278 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9767 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 68/100
# 71/71 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9998 - f1_score: 0.9920
# Epoch 68: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 71/71 [==============================] - 26s 368ms/step - loss: 0.0220 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9998 - f1_score: 0.9920 - val_loss: 0.0161 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 1.0000 - val_f1_score: 0.9970 - lr: 1.0000e-04
# Epoch 69/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.0224 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9998 - f1_score: 0.9920 - val_loss: 0.0121 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 70/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.0260 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9996 - f1_score: 0.9916 - val_loss: 0.0164 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9999 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 71/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.0241 - accuracy: 0.9894 - precision: 0.9894 - recall: 0.9894 - auc: 0.9997 - f1_score: 0.9894 - val_loss: 0.0055 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 72/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.0319 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9990 - f1_score: 0.9903 - val_loss: 0.0169 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 0.9998 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 73/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.0164 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9999 - f1_score: 0.9947 - val_loss: 0.0092 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 74/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0198 - accuracy: 0.9951 - precision: 0.9951 - recall: 0.9951 - auc: 0.9998 - f1_score: 0.9951 - val_loss: 0.0162 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9999 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 75/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.0209 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9998 - f1_score: 0.9929 - val_loss: 0.0080 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 76/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.0243 - accuracy: 0.9929 - precision: 0.9929 - recall: 0.9929 - auc: 0.9997 - f1_score: 0.9929 - val_loss: 0.0060 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 77/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.0266 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9996 - f1_score: 0.9920 - val_loss: 0.0107 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 1.0000 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 78/100
# 71/71 [==============================] - 26s 371ms/step - loss: 0.0222 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9997 - f1_score: 0.9943 - val_loss: 0.0059 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 79/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.0273 - accuracy: 0.9889 - precision: 0.9889 - recall: 0.9889 - auc: 0.9992 - f1_score: 0.9889 - val_loss: 0.0158 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 0.9999 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 80/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.0239 - accuracy: 0.9907 - precision: 0.9907 - recall: 0.9907 - auc: 0.9997 - f1_score: 0.9907 - val_loss: 0.0178 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 0.9996 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 81/100
# 71/71 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9998 - f1_score: 0.9934
# Epoch 81: ReduceLROnPlateau reducing learning rate to 1e-05.
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0192 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9998 - f1_score: 0.9934 - val_loss: 0.0099 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 1.0000 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 82/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.0227 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9997 - f1_score: 0.9912 - val_loss: 0.0118 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 1.0000 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 83/100
# 71/71 [==============================] - 26s 370ms/step - loss: 0.0242 - accuracy: 0.9925 - precision: 0.9925 - recall: 0.9925 - auc: 0.9992 - f1_score: 0.9925 - val_loss: 0.0053 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 84/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.0187 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9999 - f1_score: 0.9943 - val_loss: 0.0038 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 85/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0246 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9992 - f1_score: 0.9920 - val_loss: 0.0104 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 1.0000 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 86/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.0210 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9998 - f1_score: 0.9934 - val_loss: 0.0044 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 87/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.0290 - accuracy: 0.9889 - precision: 0.9889 - recall: 0.9889 - auc: 0.9995 - f1_score: 0.9889 - val_loss: 0.0044 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 88/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.0227 - accuracy: 0.9938 - precision: 0.9938 - recall: 0.9938 - auc: 0.9997 - f1_score: 0.9938 - val_loss: 0.0101 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 1.0000 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 89/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.0256 - accuracy: 0.9912 - precision: 0.9912 - recall: 0.9912 - auc: 0.9996 - f1_score: 0.9912 - val_loss: 0.0059 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 90/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.0183 - accuracy: 0.9951 - precision: 0.9951 - recall: 0.9951 - auc: 0.9998 - f1_score: 0.9951 - val_loss: 0.0051 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 91/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0277 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9987 - f1_score: 0.9934 - val_loss: 0.0128 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9999 - val_f1_score: 0.9941 - lr: 1.0000e-05
# Epoch 92/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.0240 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9997 - f1_score: 0.9916 - val_loss: 0.0110 - val_accuracy: 0.9970 - val_precision: 0.9970 - val_recall: 0.9970 - val_auc: 0.9999 - val_f1_score: 0.9970 - lr: 1.0000e-05
# Epoch 93/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.0216 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9998 - f1_score: 0.9934 - val_loss: 0.0089 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 94/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.0200 - accuracy: 0.9925 - precision: 0.9925 - recall: 0.9925 - auc: 0.9998 - f1_score: 0.9925 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 95/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.0231 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9997 - f1_score: 0.9916 - val_loss: 0.0052 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 96/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.0232 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9997 - f1_score: 0.9934 - val_loss: 0.0051 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 97/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.0164 - accuracy: 0.9943 - precision: 0.9943 - recall: 0.9943 - auc: 0.9999 - f1_score: 0.9943 - val_loss: 0.0096 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 98/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.0214 - accuracy: 0.9916 - precision: 0.9916 - recall: 0.9916 - auc: 0.9998 - f1_score: 0.9916 - val_loss: 0.0090 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 99/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.0226 - accuracy: 0.9925 - precision: 0.9925 - recall: 0.9925 - auc: 0.9998 - f1_score: 0.9925 - val_loss: 0.0069 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000 - val_f1_score: 1.0000 - lr: 1.0000e-05
# Epoch 100/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.0199 - accuracy: 0.9947 - precision: 0.9947 - recall: 0.9947 - auc: 0.9998 - f1_score: 0.9947 - val_loss: 0.0298 - val_accuracy: 0.9941 - val_precision: 0.9941 - val_recall: 0.9941 - val_auc: 0.9991 - val_f1_score: 0.9941 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 0s 8ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9718022239317434
# F1-Score for each class: [0.96132597 0.98227848]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9748743718592965
# specificity: 0.9775280898876404

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 8ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 1s 79ms/step - loss: 0.0677 - accuracy: 0.9765 - precision: 0.9765 - recall: 0.9765 - auc: 0.9948 - f1_score: 0.9765
# Test loss: 0.06770364195108414
# Test accuracy: 0.9765100479125977
# Test precision: 0.9765100479125977
# Test recall: 0.9765100479125977
# Test AUC: 0.9948200583457947
# Test F1 Score: 0.9765100479125977

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96        89
#            1       0.99      0.97      0.98       199
#
#     accuracy                           0.98       288
#    macro avg       0.97      0.98      0.97       288
# weighted avg       0.98      0.98      0.98       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del resnet


from numba import cuda

cuda.select_device(0)
cuda.close()
