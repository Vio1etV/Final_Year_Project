# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/BCResize/100X/test'
train_dir = '/root/BreastCancer/BCResize/100X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/BCResize/100X/test/benign'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2129 images belonging to 2 classes.
# Found 316 images belonging to 2 classes.
# Found 311 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %% [markdown]
# <h1>Model Construction<h1>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, GlobalAveragePooling2D, Dense

def resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Input Convolution
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Residual Blocks
    for filters in [64, 128, 64, 128]:
        # Residual connection
        identity = x

        # Adjust the number of filters in identity to match x if necessary
        if identity.shape[-1] != filters:
            identity = Conv2D(filters, (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(identity)
            identity = BatchNormalization()(identity)

        # First Convolution
        x = Conv2D(filters, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)

        # Second Convolution
        x = Conv2D(filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)

        # Add Residual Connection
        x = Add()([x, identity])
        x = Activation('relu')(x)

        # Optional: Additional MaxPooling
        x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model



# Create the ResNet model
model = resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 64)   36928       ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 56, 56, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation (Activation)        (None, 56, 56, 64)   0           ['add[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  147584      ['batch_normalization_4[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 128)  8320        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
# 2023-12-24 17:39:12.174553: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 17:39:12.706778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 128)  0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  activation_1 (Activation)      (None, 28, 28, 128)  0           ['add_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 64)   73792       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 64)   36928       ['batch_normalization_7[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 64)   8256        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 64)   0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_2 (Activation)      (None, 14, 14, 64)   0           ['add_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 64)    0           ['activation_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 128)    73856       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 7, 7, 128)   512         ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 128)    147584      ['batch_normalization_10[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 128)    8320        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 7, 7, 128)   512         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 128)   512         ['conv2d_9[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  activation_3 (Activation)      (None, 7, 7, 128)    0           ['add_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 128)   0           ['activation_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['max_pooling2d_4[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            258         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 666,690
# Trainable params: 664,386
# Non-trainable params: 2,304
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "ResNet100XResized"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/2. ResNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-24 17:39:17.108692: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-24 17:39:18.538945: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 67/67 [==============================] - 29s 377ms/step - loss: 0.5060 - accuracy: 0.7647 - precision: 0.7647 - recall: 0.7647 - auc: 0.8506 - f1_score: 0.7647 - val_loss: 0.7851 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5362 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 2/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.3881 - accuracy: 0.8253 - precision: 0.8253 - recall: 0.8253 - auc: 0.9091 - f1_score: 0.8253 - val_loss: 1.8541 - val_accuracy: 0.5380 - val_precision: 0.5380 - val_recall: 0.5380 - val_auc: 0.4150 - val_f1_score: 0.5380 - lr: 0.0010
# Epoch 3/100
# 67/67 [==============================] - 25s 370ms/step - loss: 0.3391 - accuracy: 0.8473 - precision: 0.8473 - recall: 0.8473 - auc: 0.9294 - f1_score: 0.8473 - val_loss: 0.8607 - val_accuracy: 0.1804 - val_precision: 0.1804 - val_recall: 0.1804 - val_auc: 0.1025 - val_f1_score: 0.1804 - lr: 0.0010
# Epoch 4/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.3305 - accuracy: 0.8539 - precision: 0.8539 - recall: 0.8539 - auc: 0.9329 - f1_score: 0.8539 - val_loss: 1.0868 - val_accuracy: 0.4842 - val_precision: 0.4842 - val_recall: 0.4842 - val_auc: 0.5424 - val_f1_score: 0.4842 - lr: 0.0010
# Epoch 5/100
# 67/67 [==============================] - 24s 359ms/step - loss: 0.3103 - accuracy: 0.8675 - precision: 0.8675 - recall: 0.8675 - auc: 0.9419 - f1_score: 0.8675 - val_loss: 0.7274 - val_accuracy: 0.5854 - val_precision: 0.5854 - val_recall: 0.5854 - val_auc: 0.6305 - val_f1_score: 0.5854 - lr: 0.0010
# Epoch 6/100
# 67/67 [==============================] - 25s 367ms/step - loss: 0.2591 - accuracy: 0.8882 - precision: 0.8882 - recall: 0.8882 - auc: 0.9590 - f1_score: 0.8882 - val_loss: 4.5070 - val_accuracy: 0.5127 - val_precision: 0.5127 - val_recall: 0.5127 - val_auc: 0.5637 - val_f1_score: 0.5127 - lr: 0.0010
# Epoch 7/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.2561 - accuracy: 0.8957 - precision: 0.8957 - recall: 0.8957 - auc: 0.9600 - f1_score: 0.8957 - val_loss: 0.8444 - val_accuracy: 0.6297 - val_precision: 0.6297 - val_recall: 0.6297 - val_auc: 0.6475 - val_f1_score: 0.6297 - lr: 0.0010
# Epoch 8/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.2286 - accuracy: 0.9079 - precision: 0.9079 - recall: 0.9079 - auc: 0.9680 - f1_score: 0.9079 - val_loss: 0.6804 - val_accuracy: 0.7247 - val_precision: 0.7247 - val_recall: 0.7247 - val_auc: 0.7999 - val_f1_score: 0.7247 - lr: 0.0010
# Epoch 9/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.2252 - accuracy: 0.9075 - precision: 0.9075 - recall: 0.9075 - auc: 0.9692 - f1_score: 0.9075 - val_loss: 1.7224 - val_accuracy: 0.4462 - val_precision: 0.4462 - val_recall: 0.4462 - val_auc: 0.3193 - val_f1_score: 0.4462 - lr: 0.0010
# Epoch 10/100
# 67/67 [==============================] - 25s 367ms/step - loss: 0.2036 - accuracy: 0.9192 - precision: 0.9192 - recall: 0.9192 - auc: 0.9748 - f1_score: 0.9192 - val_loss: 0.4571 - val_accuracy: 0.8354 - val_precision: 0.8354 - val_recall: 0.8354 - val_auc: 0.9050 - val_f1_score: 0.8354 - lr: 0.0010
# Epoch 11/100
# 67/67 [==============================] - 24s 360ms/step - loss: 0.1828 - accuracy: 0.9267 - precision: 0.9267 - recall: 0.9267 - auc: 0.9795 - f1_score: 0.9267 - val_loss: 1.4282 - val_accuracy: 0.4367 - val_precision: 0.4367 - val_recall: 0.4367 - val_auc: 0.4573 - val_f1_score: 0.4367 - lr: 0.0010
# Epoch 12/100
# 67/67 [==============================] - 24s 360ms/step - loss: 0.1729 - accuracy: 0.9324 - precision: 0.9324 - recall: 0.9324 - auc: 0.9816 - f1_score: 0.9324 - val_loss: 0.7731 - val_accuracy: 0.7785 - val_precision: 0.7785 - val_recall: 0.7785 - val_auc: 0.8315 - val_f1_score: 0.7785 - lr: 0.0010
# Epoch 13/100
# 67/67 [==============================] - 24s 360ms/step - loss: 0.1622 - accuracy: 0.9314 - precision: 0.9314 - recall: 0.9314 - auc: 0.9837 - f1_score: 0.9314 - val_loss: 2.0541 - val_accuracy: 0.5823 - val_precision: 0.5823 - val_recall: 0.5823 - val_auc: 0.5855 - val_f1_score: 0.5823 - lr: 0.0010
# Epoch 14/100
# 67/67 [==============================] - 25s 372ms/step - loss: 0.1660 - accuracy: 0.9347 - precision: 0.9347 - recall: 0.9347 - auc: 0.9832 - f1_score: 0.9347 - val_loss: 4.4922 - val_accuracy: 0.5728 - val_precision: 0.5728 - val_recall: 0.5728 - val_auc: 0.6205 - val_f1_score: 0.5728 - lr: 0.0010
# Epoch 15/100
# 67/67 [==============================] - 24s 361ms/step - loss: 0.1522 - accuracy: 0.9465 - precision: 0.9465 - recall: 0.9465 - auc: 0.9854 - f1_score: 0.9465 - val_loss: 0.8464 - val_accuracy: 0.7468 - val_precision: 0.7468 - val_recall: 0.7468 - val_auc: 0.8024 - val_f1_score: 0.7468 - lr: 0.0010
# Epoch 16/100
# 67/67 [==============================] - 24s 359ms/step - loss: 0.1315 - accuracy: 0.9507 - precision: 0.9507 - recall: 0.9507 - auc: 0.9892 - f1_score: 0.9507 - val_loss: 4.4792 - val_accuracy: 0.4937 - val_precision: 0.4937 - val_recall: 0.4937 - val_auc: 0.4738 - val_f1_score: 0.4937 - lr: 0.0010
# Epoch 17/100
# 67/67 [==============================] - 24s 365ms/step - loss: 0.1744 - accuracy: 0.9347 - precision: 0.9347 - recall: 0.9347 - auc: 0.9805 - f1_score: 0.9347 - val_loss: 4.2696 - val_accuracy: 0.1804 - val_precision: 0.1804 - val_recall: 0.1804 - val_auc: 0.1228 - val_f1_score: 0.1804 - lr: 0.0010
# Epoch 18/100
# 67/67 [==============================] - 24s 360ms/step - loss: 0.1232 - accuracy: 0.9512 - precision: 0.9512 - recall: 0.9512 - auc: 0.9908 - f1_score: 0.9512 - val_loss: 1.0231 - val_accuracy: 0.7025 - val_precision: 0.7025 - val_recall: 0.7025 - val_auc: 0.8008 - val_f1_score: 0.7025 - lr: 0.0010
# Epoch 19/100
# 67/67 [==============================] - 24s 361ms/step - loss: 0.1370 - accuracy: 0.9446 - precision: 0.9446 - recall: 0.9446 - auc: 0.9883 - f1_score: 0.9446 - val_loss: 1.8374 - val_accuracy: 0.5601 - val_precision: 0.5601 - val_recall: 0.5601 - val_auc: 0.5368 - val_f1_score: 0.5601 - lr: 0.0010
# Epoch 20/100
# 67/67 [==============================] - ETA: 0s - loss: 0.1270 - accuracy: 0.9516 - precision: 0.9516 - recall: 0.9516 - auc: 0.9900 - f1_score: 0.9516
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 67/67 [==============================] - 25s 367ms/step - loss: 0.1270 - accuracy: 0.9516 - precision: 0.9516 - recall: 0.9516 - auc: 0.9900 - f1_score: 0.9516 - val_loss: 1.8250 - val_accuracy: 0.5032 - val_precision: 0.5032 - val_recall: 0.5032 - val_auc: 0.4899 - val_f1_score: 0.5032 - lr: 0.0010
# Epoch 21/100
# 67/67 [==============================] - 25s 367ms/step - loss: 0.1039 - accuracy: 0.9596 - precision: 0.9596 - recall: 0.9596 - auc: 0.9932 - f1_score: 0.9596 - val_loss: 3.5196 - val_accuracy: 0.3006 - val_precision: 0.3006 - val_recall: 0.3006 - val_auc: 0.2980 - val_f1_score: 0.3006 - lr: 1.0000e-04
# Epoch 22/100
# 67/67 [==============================] - 25s 368ms/step - loss: 0.0779 - accuracy: 0.9728 - precision: 0.9728 - recall: 0.9728 - auc: 0.9968 - f1_score: 0.9728 - val_loss: 1.6183 - val_accuracy: 0.5886 - val_precision: 0.5886 - val_recall: 0.5886 - val_auc: 0.6092 - val_f1_score: 0.5886 - lr: 1.0000e-04
# Epoch 23/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0719 - accuracy: 0.9760 - precision: 0.9760 - recall: 0.9760 - auc: 0.9971 - f1_score: 0.9760 - val_loss: 0.9306 - val_accuracy: 0.7215 - val_precision: 0.7215 - val_recall: 0.7215 - val_auc: 0.7691 - val_f1_score: 0.7215 - lr: 1.0000e-04
# Epoch 24/100
# 67/67 [==============================] - 25s 367ms/step - loss: 0.0611 - accuracy: 0.9807 - precision: 0.9807 - recall: 0.9807 - auc: 0.9981 - f1_score: 0.9807 - val_loss: 0.6823 - val_accuracy: 0.8386 - val_precision: 0.8386 - val_recall: 0.8386 - val_auc: 0.8694 - val_f1_score: 0.8386 - lr: 1.0000e-04
# Epoch 25/100
# 67/67 [==============================] - 25s 367ms/step - loss: 0.0695 - accuracy: 0.9779 - precision: 0.9779 - recall: 0.9779 - auc: 0.9963 - f1_score: 0.9779 - val_loss: 0.3483 - val_accuracy: 0.9082 - val_precision: 0.9082 - val_recall: 0.9082 - val_auc: 0.9359 - val_f1_score: 0.9082 - lr: 1.0000e-04
# Epoch 26/100
# 67/67 [==============================] - 24s 363ms/step - loss: 0.0561 - accuracy: 0.9826 - precision: 0.9826 - recall: 0.9826 - auc: 0.9984 - f1_score: 0.9826 - val_loss: 0.5557 - val_accuracy: 0.8766 - val_precision: 0.8766 - val_recall: 0.8766 - val_auc: 0.9086 - val_f1_score: 0.8766 - lr: 1.0000e-04
# Epoch 27/100
# 67/67 [==============================] - 24s 365ms/step - loss: 0.0600 - accuracy: 0.9784 - precision: 0.9784 - recall: 0.9784 - auc: 0.9979 - f1_score: 0.9784 - val_loss: 0.4186 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9452 - val_f1_score: 0.8892 - lr: 1.0000e-04
# Epoch 28/100
# 67/67 [==============================] - 25s 368ms/step - loss: 0.0661 - accuracy: 0.9789 - precision: 0.9789 - recall: 0.9789 - auc: 0.9974 - f1_score: 0.9789 - val_loss: 0.3252 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_auc: 0.9539 - val_f1_score: 0.9241 - lr: 1.0000e-04
# Epoch 29/100
# 67/67 [==============================] - 25s 367ms/step - loss: 0.0693 - accuracy: 0.9732 - precision: 0.9732 - recall: 0.9732 - auc: 0.9972 - f1_score: 0.9732 - val_loss: 0.9104 - val_accuracy: 0.8481 - val_precision: 0.8481 - val_recall: 0.8481 - val_auc: 0.8506 - val_f1_score: 0.8481 - lr: 1.0000e-04
# Epoch 30/100
# 67/67 [==============================] - 24s 366ms/step - loss: 0.0645 - accuracy: 0.9756 - precision: 0.9756 - recall: 0.9756 - auc: 0.9975 - f1_score: 0.9756 - val_loss: 0.4542 - val_accuracy: 0.8797 - val_precision: 0.8797 - val_recall: 0.8797 - val_auc: 0.9358 - val_f1_score: 0.8797 - lr: 1.0000e-04
# Epoch 31/100
# 67/67 [==============================] - 25s 371ms/step - loss: 0.0547 - accuracy: 0.9817 - precision: 0.9817 - recall: 0.9817 - auc: 0.9986 - f1_score: 0.9817 - val_loss: 0.5499 - val_accuracy: 0.8513 - val_precision: 0.8513 - val_recall: 0.8513 - val_auc: 0.9085 - val_f1_score: 0.8513 - lr: 1.0000e-04
# Epoch 32/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.0575 - accuracy: 0.9784 - precision: 0.9784 - recall: 0.9784 - auc: 0.9982 - f1_score: 0.9784 - val_loss: 0.9336 - val_accuracy: 0.8259 - val_precision: 0.8259 - val_recall: 0.8259 - val_auc: 0.8677 - val_f1_score: 0.8259 - lr: 1.0000e-04
# Epoch 33/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0475 - accuracy: 0.9845 - precision: 0.9845 - recall: 0.9845 - auc: 0.9987 - f1_score: 0.9845 - val_loss: 0.9245 - val_accuracy: 0.8386 - val_precision: 0.8386 - val_recall: 0.8386 - val_auc: 0.8547 - val_f1_score: 0.8386 - lr: 1.0000e-04
# Epoch 34/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0546 - accuracy: 0.9793 - precision: 0.9793 - recall: 0.9793 - auc: 0.9983 - f1_score: 0.9793 - val_loss: 0.6554 - val_accuracy: 0.8259 - val_precision: 0.8259 - val_recall: 0.8259 - val_auc: 0.8586 - val_f1_score: 0.8259 - lr: 1.0000e-04
# Epoch 35/100
# 67/67 [==============================] - 24s 359ms/step - loss: 0.0622 - accuracy: 0.9756 - precision: 0.9756 - recall: 0.9756 - auc: 0.9975 - f1_score: 0.9756 - val_loss: 0.6706 - val_accuracy: 0.8228 - val_precision: 0.8228 - val_recall: 0.8228 - val_auc: 0.8716 - val_f1_score: 0.8228 - lr: 1.0000e-04
# Epoch 36/100
# 67/67 [==============================] - 24s 361ms/step - loss: 0.0574 - accuracy: 0.9812 - precision: 0.9812 - recall: 0.9812 - auc: 0.9978 - f1_score: 0.9812 - val_loss: 1.9817 - val_accuracy: 0.7405 - val_precision: 0.7405 - val_recall: 0.7405 - val_auc: 0.7698 - val_f1_score: 0.7405 - lr: 1.0000e-04
# Epoch 37/100
# 67/67 [==============================] - 24s 360ms/step - loss: 0.0458 - accuracy: 0.9831 - precision: 0.9831 - recall: 0.9831 - auc: 0.9988 - f1_score: 0.9831 - val_loss: 0.3103 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9616 - val_f1_score: 0.8987 - lr: 1.0000e-04
# Epoch 38/100
# 67/67 [==============================] - 24s 365ms/step - loss: 0.0485 - accuracy: 0.9854 - precision: 0.9854 - recall: 0.9854 - auc: 0.9981 - f1_score: 0.9854 - val_loss: 0.5978 - val_accuracy: 0.8766 - val_precision: 0.8766 - val_recall: 0.8766 - val_auc: 0.9161 - val_f1_score: 0.8766 - lr: 1.0000e-04
# Epoch 39/100
# 67/67 [==============================] - 24s 365ms/step - loss: 0.0468 - accuracy: 0.9817 - precision: 0.9817 - recall: 0.9817 - auc: 0.9988 - f1_score: 0.9817 - val_loss: 1.1975 - val_accuracy: 0.8165 - val_precision: 0.8165 - val_recall: 0.8165 - val_auc: 0.8395 - val_f1_score: 0.8165 - lr: 1.0000e-04
# Epoch 40/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.0432 - accuracy: 0.9873 - precision: 0.9873 - recall: 0.9873 - auc: 0.9982 - f1_score: 0.9873 - val_loss: 1.0309 - val_accuracy: 0.8418 - val_precision: 0.8418 - val_recall: 0.8418 - val_auc: 0.8550 - val_f1_score: 0.8418 - lr: 1.0000e-04
# Epoch 41/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0518 - accuracy: 0.9793 - precision: 0.9793 - recall: 0.9793 - auc: 0.9985 - f1_score: 0.9793 - val_loss: 0.2554 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_auc: 0.9695 - val_f1_score: 0.9114 - lr: 1.0000e-04
# Epoch 42/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.0341 - accuracy: 0.9883 - precision: 0.9883 - recall: 0.9883 - auc: 0.9995 - f1_score: 0.9883 - val_loss: 0.2746 - val_accuracy: 0.9082 - val_precision: 0.9082 - val_recall: 0.9082 - val_auc: 0.9684 - val_f1_score: 0.9082 - lr: 1.0000e-04
# Epoch 43/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0384 - accuracy: 0.9878 - precision: 0.9878 - recall: 0.9878 - auc: 0.9988 - f1_score: 0.9878 - val_loss: 0.9509 - val_accuracy: 0.8544 - val_precision: 0.8544 - val_recall: 0.8544 - val_auc: 0.8786 - val_f1_score: 0.8544 - lr: 1.0000e-04
# Epoch 44/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0479 - accuracy: 0.9840 - precision: 0.9840 - recall: 0.9840 - auc: 0.9985 - f1_score: 0.9840 - val_loss: 0.4896 - val_accuracy: 0.8829 - val_precision: 0.8829 - val_recall: 0.8829 - val_auc: 0.9344 - val_f1_score: 0.8829 - lr: 1.0000e-04
# Epoch 45/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0494 - accuracy: 0.9779 - precision: 0.9779 - recall: 0.9779 - auc: 0.9986 - f1_score: 0.9779 - val_loss: 0.1593 - val_accuracy: 0.9272 - val_precision: 0.9272 - val_recall: 0.9272 - val_auc: 0.9859 - val_f1_score: 0.9272 - lr: 1.0000e-04
# Epoch 46/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.0479 - accuracy: 0.9793 - precision: 0.9793 - recall: 0.9793 - auc: 0.9983 - f1_score: 0.9793 - val_loss: 3.7979 - val_accuracy: 0.6044 - val_precision: 0.6044 - val_recall: 0.6044 - val_auc: 0.6229 - val_f1_score: 0.6044 - lr: 1.0000e-04
# Epoch 47/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0339 - accuracy: 0.9873 - precision: 0.9873 - recall: 0.9873 - auc: 0.9995 - f1_score: 0.9873 - val_loss: 0.6360 - val_accuracy: 0.8259 - val_precision: 0.8259 - val_recall: 0.8259 - val_auc: 0.8913 - val_f1_score: 0.8259 - lr: 1.0000e-04
# Epoch 48/100
# 67/67 [==============================] - 24s 363ms/step - loss: 0.0328 - accuracy: 0.9901 - precision: 0.9901 - recall: 0.9901 - auc: 0.9995 - f1_score: 0.9901 - val_loss: 0.3974 - val_accuracy: 0.9051 - val_precision: 0.9051 - val_recall: 0.9051 - val_auc: 0.9503 - val_f1_score: 0.9051 - lr: 1.0000e-04
# Epoch 49/100
# 67/67 [==============================] - 24s 365ms/step - loss: 0.0414 - accuracy: 0.9845 - precision: 0.9845 - recall: 0.9845 - auc: 0.9989 - f1_score: 0.9845 - val_loss: 0.9144 - val_accuracy: 0.8386 - val_precision: 0.8386 - val_recall: 0.8386 - val_auc: 0.8672 - val_f1_score: 0.8386 - lr: 1.0000e-04
# Epoch 50/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.0401 - accuracy: 0.9859 - precision: 0.9859 - recall: 0.9859 - auc: 0.9986 - f1_score: 0.9859 - val_loss: 0.7751 - val_accuracy: 0.8703 - val_precision: 0.8703 - val_recall: 0.8703 - val_auc: 0.9063 - val_f1_score: 0.8703 - lr: 1.0000e-04
# Epoch 51/100
# 67/67 [==============================] - 25s 366ms/step - loss: 0.0445 - accuracy: 0.9854 - precision: 0.9854 - recall: 0.9854 - auc: 0.9984 - f1_score: 0.9854 - val_loss: 1.0431 - val_accuracy: 0.8259 - val_precision: 0.8259 - val_recall: 0.8259 - val_auc: 0.8690 - val_f1_score: 0.8259 - lr: 1.0000e-04
# Epoch 52/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0332 - accuracy: 0.9850 - precision: 0.9850 - recall: 0.9850 - auc: 0.9995 - f1_score: 0.9850 - val_loss: 0.4752 - val_accuracy: 0.8734 - val_precision: 0.8734 - val_recall: 0.8734 - val_auc: 0.9425 - val_f1_score: 0.8734 - lr: 1.0000e-04
# Epoch 53/100
# 67/67 [==============================] - 24s 368ms/step - loss: 0.0330 - accuracy: 0.9892 - precision: 0.9892 - recall: 0.9892 - auc: 0.9995 - f1_score: 0.9892 - val_loss: 0.1160 - val_accuracy: 0.9335 - val_precision: 0.9335 - val_recall: 0.9335 - val_auc: 0.9915 - val_f1_score: 0.9335 - lr: 1.0000e-04
# Epoch 54/100
# 67/67 [==============================] - 24s 363ms/step - loss: 0.0471 - accuracy: 0.9836 - precision: 0.9836 - recall: 0.9836 - auc: 0.9979 - f1_score: 0.9836 - val_loss: 0.5793 - val_accuracy: 0.8544 - val_precision: 0.8544 - val_recall: 0.8544 - val_auc: 0.9101 - val_f1_score: 0.8544 - lr: 1.0000e-04
# Epoch 55/100
# 67/67 [==============================] - 25s 368ms/step - loss: 0.0329 - accuracy: 0.9892 - precision: 0.9892 - recall: 0.9892 - auc: 0.9994 - f1_score: 0.9892 - val_loss: 0.2294 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_auc: 0.9742 - val_f1_score: 0.9114 - lr: 1.0000e-04
# Epoch 56/100
# 67/67 [==============================] - 24s 366ms/step - loss: 0.0354 - accuracy: 0.9864 - precision: 0.9864 - recall: 0.9864 - auc: 0.9993 - f1_score: 0.9864 - val_loss: 0.7452 - val_accuracy: 0.8703 - val_precision: 0.8703 - val_recall: 0.8703 - val_auc: 0.8975 - val_f1_score: 0.8703 - lr: 1.0000e-04
# Epoch 57/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0288 - accuracy: 0.9915 - precision: 0.9915 - recall: 0.9915 - auc: 0.9996 - f1_score: 0.9915 - val_loss: 1.1450 - val_accuracy: 0.8544 - val_precision: 0.8544 - val_recall: 0.8544 - val_auc: 0.8731 - val_f1_score: 0.8544 - lr: 1.0000e-04
# Epoch 58/100
# 67/67 [==============================] - 24s 363ms/step - loss: 0.0315 - accuracy: 0.9873 - precision: 0.9873 - recall: 0.9873 - auc: 0.9995 - f1_score: 0.9873 - val_loss: 0.4982 - val_accuracy: 0.8797 - val_precision: 0.8797 - val_recall: 0.8797 - val_auc: 0.9441 - val_f1_score: 0.8797 - lr: 1.0000e-04
# Epoch 59/100
# 67/67 [==============================] - 25s 367ms/step - loss: 0.0459 - accuracy: 0.9850 - precision: 0.9850 - recall: 0.9850 - auc: 0.9972 - f1_score: 0.9850 - val_loss: 2.4448 - val_accuracy: 0.7184 - val_precision: 0.7184 - val_recall: 0.7184 - val_auc: 0.7538 - val_f1_score: 0.7184 - lr: 1.0000e-04
# Epoch 60/100
# 67/67 [==============================] - 25s 366ms/step - loss: 0.0349 - accuracy: 0.9868 - precision: 0.9868 - recall: 0.9868 - auc: 0.9993 - f1_score: 0.9868 - val_loss: 0.2848 - val_accuracy: 0.9209 - val_precision: 0.9209 - val_recall: 0.9209 - val_auc: 0.9693 - val_f1_score: 0.9209 - lr: 1.0000e-04
# Epoch 61/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.0310 - accuracy: 0.9883 - precision: 0.9883 - recall: 0.9883 - auc: 0.9995 - f1_score: 0.9883 - val_loss: 0.7824 - val_accuracy: 0.8259 - val_precision: 0.8259 - val_recall: 0.8259 - val_auc: 0.8699 - val_f1_score: 0.8259 - lr: 1.0000e-04
# Epoch 62/100
# 67/67 [==============================] - 25s 370ms/step - loss: 0.0353 - accuracy: 0.9878 - precision: 0.9878 - recall: 0.9878 - auc: 0.9985 - f1_score: 0.9878 - val_loss: 0.1039 - val_accuracy: 0.9589 - val_precision: 0.9589 - val_recall: 0.9589 - val_auc: 0.9945 - val_f1_score: 0.9589 - lr: 1.0000e-04
# Epoch 63/100
# 67/67 [==============================] - 25s 369ms/step - loss: 0.0314 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - auc: 0.9990 - f1_score: 0.9906 - val_loss: 0.1760 - val_accuracy: 0.9462 - val_precision: 0.9462 - val_recall: 0.9462 - val_auc: 0.9863 - val_f1_score: 0.9462 - lr: 1.0000e-04
# Epoch 64/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0260 - accuracy: 0.9925 - precision: 0.9925 - recall: 0.9925 - auc: 0.9996 - f1_score: 0.9925 - val_loss: 0.3367 - val_accuracy: 0.8861 - val_precision: 0.8861 - val_recall: 0.8861 - val_auc: 0.9563 - val_f1_score: 0.8861 - lr: 1.0000e-04
# Epoch 65/100
# 67/67 [==============================] - 25s 368ms/step - loss: 0.0339 - accuracy: 0.9878 - precision: 0.9878 - recall: 0.9878 - auc: 0.9993 - f1_score: 0.9878 - val_loss: 1.8048 - val_accuracy: 0.7563 - val_precision: 0.7563 - val_recall: 0.7563 - val_auc: 0.8085 - val_f1_score: 0.7563 - lr: 1.0000e-04
# Epoch 66/100
# 67/67 [==============================] - 25s 366ms/step - loss: 0.0280 - accuracy: 0.9887 - precision: 0.9887 - recall: 0.9887 - auc: 0.9996 - f1_score: 0.9887 - val_loss: 0.2954 - val_accuracy: 0.9241 - val_precision: 0.9241 - val_recall: 0.9241 - val_auc: 0.9729 - val_f1_score: 0.9241 - lr: 1.0000e-04
# Epoch 67/100
# 67/67 [==============================] - 25s 369ms/step - loss: 0.0304 - accuracy: 0.9911 - precision: 0.9911 - recall: 0.9911 - auc: 0.9994 - f1_score: 0.9911 - val_loss: 0.7783 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.8972 - val_f1_score: 0.8892 - lr: 1.0000e-04
# Epoch 68/100
# 67/67 [==============================] - 25s 366ms/step - loss: 0.0269 - accuracy: 0.9911 - precision: 0.9911 - recall: 0.9911 - auc: 0.9996 - f1_score: 0.9911 - val_loss: 0.4119 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9430 - val_f1_score: 0.8892 - lr: 1.0000e-04
# Epoch 69/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0289 - accuracy: 0.9901 - precision: 0.9901 - recall: 0.9901 - auc: 0.9995 - f1_score: 0.9901 - val_loss: 1.3310 - val_accuracy: 0.8418 - val_precision: 0.8418 - val_recall: 0.8418 - val_auc: 0.8492 - val_f1_score: 0.8418 - lr: 1.0000e-04
# Epoch 70/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.0261 - accuracy: 0.9901 - precision: 0.9901 - recall: 0.9901 - auc: 0.9997 - f1_score: 0.9901 - val_loss: 1.6964 - val_accuracy: 0.7975 - val_precision: 0.7975 - val_recall: 0.7975 - val_auc: 0.8211 - val_f1_score: 0.7975 - lr: 1.0000e-04
# Epoch 71/100
# 67/67 [==============================] - 24s 365ms/step - loss: 0.0418 - accuracy: 0.9906 - precision: 0.9906 - recall: 0.9906 - auc: 0.9988 - f1_score: 0.9906 - val_loss: 0.9712 - val_accuracy: 0.7975 - val_precision: 0.7975 - val_recall: 0.7975 - val_auc: 0.8696 - val_f1_score: 0.7975 - lr: 1.0000e-04
# Epoch 72/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9989 - f1_score: 0.9934
# Epoch 72: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 67/67 [==============================] - 24s 360ms/step - loss: 0.0314 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9989 - f1_score: 0.9934 - val_loss: 0.6171 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9203 - val_f1_score: 0.8892 - lr: 1.0000e-04
# Epoch 73/100
# 67/67 [==============================] - 25s 369ms/step - loss: 0.0328 - accuracy: 0.9873 - precision: 0.9873 - recall: 0.9873 - auc: 0.9993 - f1_score: 0.9873 - val_loss: 0.6970 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9030 - val_f1_score: 0.8892 - lr: 1.0000e-05
# Epoch 74/100
# 67/67 [==============================] - 25s 366ms/step - loss: 0.0284 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9992 - f1_score: 0.9920 - val_loss: 0.7254 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9140 - val_f1_score: 0.8892 - lr: 1.0000e-05
# Epoch 75/100
# 67/67 [==============================] - 24s 363ms/step - loss: 0.0183 - accuracy: 0.9944 - precision: 0.9944 - recall: 0.9944 - auc: 0.9999 - f1_score: 0.9944 - val_loss: 0.8206 - val_accuracy: 0.8797 - val_precision: 0.8797 - val_recall: 0.8797 - val_auc: 0.9116 - val_f1_score: 0.8797 - lr: 1.0000e-05
# Epoch 76/100
# 67/67 [==============================] - 24s 360ms/step - loss: 0.0317 - accuracy: 0.9911 - precision: 0.9911 - recall: 0.9911 - auc: 0.9985 - f1_score: 0.9911 - val_loss: 0.5581 - val_accuracy: 0.8956 - val_precision: 0.8956 - val_recall: 0.8956 - val_auc: 0.9308 - val_f1_score: 0.8956 - lr: 1.0000e-05
# Epoch 77/100
# 67/67 [==============================] - 25s 366ms/step - loss: 0.0301 - accuracy: 0.9897 - precision: 0.9897 - recall: 0.9897 - auc: 0.9990 - f1_score: 0.9897 - val_loss: 0.5969 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9330 - val_f1_score: 0.8987 - lr: 1.0000e-05
# Epoch 78/100
# 67/67 [==============================] - 25s 367ms/step - loss: 0.0233 - accuracy: 0.9911 - precision: 0.9911 - recall: 0.9911 - auc: 0.9997 - f1_score: 0.9911 - val_loss: 0.5006 - val_accuracy: 0.9177 - val_precision: 0.9177 - val_recall: 0.9177 - val_auc: 0.9402 - val_f1_score: 0.9177 - lr: 1.0000e-05
# Epoch 79/100
# 67/67 [==============================] - 25s 374ms/step - loss: 0.0201 - accuracy: 0.9953 - precision: 0.9953 - recall: 0.9953 - auc: 0.9992 - f1_score: 0.9953 - val_loss: 0.4537 - val_accuracy: 0.9051 - val_precision: 0.9051 - val_recall: 0.9051 - val_auc: 0.9501 - val_f1_score: 0.9051 - lr: 1.0000e-05
# Epoch 80/100
# 67/67 [==============================] - 25s 370ms/step - loss: 0.0179 - accuracy: 0.9944 - precision: 0.9944 - recall: 0.9944 - auc: 0.9999 - f1_score: 0.9944 - val_loss: 0.5697 - val_accuracy: 0.8924 - val_precision: 0.8924 - val_recall: 0.8924 - val_auc: 0.9323 - val_f1_score: 0.8924 - lr: 1.0000e-05
# Epoch 81/100
# 67/67 [==============================] - 25s 371ms/step - loss: 0.0206 - accuracy: 0.9930 - precision: 0.9930 - recall: 0.9930 - auc: 0.9998 - f1_score: 0.9930 - val_loss: 0.5554 - val_accuracy: 0.9019 - val_precision: 0.9019 - val_recall: 0.9019 - val_auc: 0.9319 - val_f1_score: 0.9019 - lr: 1.0000e-05
# Epoch 82/100
# 67/67 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9997 - f1_score: 0.9920
# Epoch 82: ReduceLROnPlateau reducing learning rate to 1e-05.
# 67/67 [==============================] - 25s 367ms/step - loss: 0.0222 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9997 - f1_score: 0.9920 - val_loss: 0.6280 - val_accuracy: 0.8956 - val_precision: 0.8956 - val_recall: 0.8956 - val_auc: 0.9308 - val_f1_score: 0.8956 - lr: 1.0000e-05
# Epoch 83/100
# 67/67 [==============================] - 25s 367ms/step - loss: 0.0219 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9997 - f1_score: 0.9934 - val_loss: 0.4223 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_auc: 0.9551 - val_f1_score: 0.9114 - lr: 1.0000e-05
# Epoch 84/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.0182 - accuracy: 0.9944 - precision: 0.9944 - recall: 0.9944 - auc: 0.9998 - f1_score: 0.9944 - val_loss: 0.4227 - val_accuracy: 0.9082 - val_precision: 0.9082 - val_recall: 0.9082 - val_auc: 0.9501 - val_f1_score: 0.9082 - lr: 1.0000e-05
# Epoch 85/100
# 67/67 [==============================] - 24s 365ms/step - loss: 0.0237 - accuracy: 0.9934 - precision: 0.9934 - recall: 0.9934 - auc: 0.9997 - f1_score: 0.9934 - val_loss: 0.4517 - val_accuracy: 0.9051 - val_precision: 0.9051 - val_recall: 0.9051 - val_auc: 0.9512 - val_f1_score: 0.9051 - lr: 1.0000e-05
# Epoch 86/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.0185 - accuracy: 0.9953 - precision: 0.9953 - recall: 0.9953 - auc: 0.9997 - f1_score: 0.9953 - val_loss: 0.5117 - val_accuracy: 0.9019 - val_precision: 0.9019 - val_recall: 0.9019 - val_auc: 0.9413 - val_f1_score: 0.9019 - lr: 1.0000e-05
# Epoch 87/100
# 67/67 [==============================] - 24s 362ms/step - loss: 0.0157 - accuracy: 0.9962 - precision: 0.9962 - recall: 0.9962 - auc: 0.9999 - f1_score: 0.9962 - val_loss: 0.5871 - val_accuracy: 0.8956 - val_precision: 0.8956 - val_recall: 0.8956 - val_auc: 0.9329 - val_f1_score: 0.8956 - lr: 1.0000e-05
# Epoch 88/100
# 67/67 [==============================] - 24s 363ms/step - loss: 0.0312 - accuracy: 0.9930 - precision: 0.9930 - recall: 0.9930 - auc: 0.9977 - f1_score: 0.9930 - val_loss: 0.5165 - val_accuracy: 0.9019 - val_precision: 0.9019 - val_recall: 0.9019 - val_auc: 0.9392 - val_f1_score: 0.9019 - lr: 1.0000e-05
# Epoch 89/100
# 67/67 [==============================] - 24s 363ms/step - loss: 0.0174 - accuracy: 0.9958 - precision: 0.9958 - recall: 0.9958 - auc: 0.9999 - f1_score: 0.9958 - val_loss: 0.5804 - val_accuracy: 0.8924 - val_precision: 0.8924 - val_recall: 0.8924 - val_auc: 0.9314 - val_f1_score: 0.8924 - lr: 1.0000e-05
# Epoch 90/100
# 67/67 [==============================] - 24s 359ms/step - loss: 0.0112 - accuracy: 0.9967 - precision: 0.9967 - recall: 0.9967 - auc: 1.0000 - f1_score: 0.9967 - val_loss: 0.6118 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9290 - val_f1_score: 0.8892 - lr: 1.0000e-05
# Epoch 91/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0145 - accuracy: 0.9962 - precision: 0.9962 - recall: 0.9962 - auc: 0.9999 - f1_score: 0.9962 - val_loss: 0.6776 - val_accuracy: 0.8956 - val_precision: 0.8956 - val_recall: 0.8956 - val_auc: 0.9294 - val_f1_score: 0.8956 - lr: 1.0000e-05
# Epoch 92/100
# 67/67 [==============================] - 24s 358ms/step - loss: 0.0232 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9997 - f1_score: 0.9920 - val_loss: 0.5775 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9369 - val_f1_score: 0.8892 - lr: 1.0000e-05
# Epoch 93/100
# 67/67 [==============================] - 25s 366ms/step - loss: 0.0184 - accuracy: 0.9948 - precision: 0.9948 - recall: 0.9948 - auc: 0.9998 - f1_score: 0.9948 - val_loss: 0.5571 - val_accuracy: 0.9114 - val_precision: 0.9114 - val_recall: 0.9114 - val_auc: 0.9382 - val_f1_score: 0.9114 - lr: 1.0000e-05
# Epoch 94/100
# 67/67 [==============================] - 24s 363ms/step - loss: 0.0157 - accuracy: 0.9962 - precision: 0.9962 - recall: 0.9962 - auc: 0.9999 - f1_score: 0.9962 - val_loss: 0.5672 - val_accuracy: 0.8892 - val_precision: 0.8892 - val_recall: 0.8892 - val_auc: 0.9296 - val_f1_score: 0.8892 - lr: 1.0000e-05
# Epoch 95/100
# 67/67 [==============================] - 24s 361ms/step - loss: 0.0174 - accuracy: 0.9944 - precision: 0.9944 - recall: 0.9944 - auc: 0.9998 - f1_score: 0.9944 - val_loss: 0.4416 - val_accuracy: 0.9082 - val_precision: 0.9082 - val_recall: 0.9082 - val_auc: 0.9493 - val_f1_score: 0.9082 - lr: 1.0000e-05
# Epoch 96/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0232 - accuracy: 0.9925 - precision: 0.9925 - recall: 0.9925 - auc: 0.9997 - f1_score: 0.9925 - val_loss: 0.5161 - val_accuracy: 0.8861 - val_precision: 0.8861 - val_recall: 0.8861 - val_auc: 0.9427 - val_f1_score: 0.8861 - lr: 1.0000e-05
# Epoch 97/100
# 67/67 [==============================] - 24s 361ms/step - loss: 0.0125 - accuracy: 0.9967 - precision: 0.9967 - recall: 0.9967 - auc: 1.0000 - f1_score: 0.9967 - val_loss: 0.5433 - val_accuracy: 0.8987 - val_precision: 0.8987 - val_recall: 0.8987 - val_auc: 0.9366 - val_f1_score: 0.8987 - lr: 1.0000e-05
# Epoch 98/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0201 - accuracy: 0.9920 - precision: 0.9920 - recall: 0.9920 - auc: 0.9998 - f1_score: 0.9920 - val_loss: 0.7641 - val_accuracy: 0.8956 - val_precision: 0.8956 - val_recall: 0.8956 - val_auc: 0.9216 - val_f1_score: 0.8956 - lr: 1.0000e-05
# Epoch 99/100
# 67/67 [==============================] - 24s 361ms/step - loss: 0.0200 - accuracy: 0.9930 - precision: 0.9930 - recall: 0.9930 - auc: 0.9998 - f1_score: 0.9930 - val_loss: 0.7572 - val_accuracy: 0.8924 - val_precision: 0.8924 - val_recall: 0.8924 - val_auc: 0.9170 - val_f1_score: 0.8924 - lr: 1.0000e-05
# Epoch 100/100
# 67/67 [==============================] - 24s 364ms/step - loss: 0.0143 - accuracy: 0.9948 - precision: 0.9948 - recall: 0.9948 - auc: 0.9999 - f1_score: 0.9948 - val_loss: 0.6940 - val_accuracy: 0.8956 - val_precision: 0.8956 - val_recall: 0.8956 - val_auc: 0.9228 - val_f1_score: 0.8956 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 0s 22ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9422531046717919
# F1-Score for each class: [0.92134831 0.96315789]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9336734693877551
# specificity: 0.9879518072289156

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 8ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 1s 75ms/step - loss: 0.3184 - accuracy: 0.9550 - precision: 0.9550 - recall: 0.9550 - auc: 0.9650 - f1_score: 0.9550
# Test loss: 0.3184003531932831
# Test accuracy: 0.9549839496612549
# Test precision: 0.9549839496612549
# Test recall: 0.9549839496612549
# Test AUC: 0.9649919867515564
# Test F1 Score: 0.9549839496612549

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.99      0.92        83
#            1       0.99      0.93      0.96       196
#
#     accuracy                           0.95       279
#    macro avg       0.93      0.96      0.94       279
# weighted avg       0.96      0.95      0.95       279

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
