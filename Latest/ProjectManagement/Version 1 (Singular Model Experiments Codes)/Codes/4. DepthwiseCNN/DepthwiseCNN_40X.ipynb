# %%
import os
import tensorflow as tf
from keras.models import Model, Sequential
from keras.layers import Input, Conv2D, BatchNormalization, Activation, concatenate, DepthwiseConv2D, Multiply, Dropout, ReLU
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Layer, BatchNormalization, Add, Reshape, AveragePooling2D

from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from keras.optimizers import Adam
from keras.layers import ReLU  # Add this line to import ReLU

from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# Rest of your code...

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/BCResize/40X/test'
train_dir = '/root/BreastCancer/BCResize/40X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/BCResize/40X/test/benign'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2262 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 298 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# Define the depthwise separable CNN model
def depthwise_resnet(input_shape, num_classes):
    model = Sequential()

    # Depthwise separable convolution block 1
    model.add(DepthwiseConv2D(3, padding='same', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Conv2D(64, (1, 1)))
    model.add(BatchNormalization())
    model.add(ReLU())

    # Depthwise separable convolution block 2
    model.add(DepthwiseConv2D(3, strides=(2, 2), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Conv2D(128, (1, 1)))
    model.add(BatchNormalization())
    model.add(ReLU())

    # Depthwise separable convolution block 3
    model.add(DepthwiseConv2D(3, strides=(2, 2), padding='same'))
    model.add(BatchNormalization())
    model.add(ReLU())
    model.add(Conv2D(256, (1, 1)))
    model.add(BatchNormalization())
    model.add(ReLU())

    # Global average pooling and dense layers
    model.add(GlobalAveragePooling2D())
    model.add(Dense(num_classes, activation='softmax'))

    return model



# Create the depthwise separable CNN model
model = depthwise_resnet(input_shape, num_classes)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  depthwise_conv2d (Depthwise  (None, 224, 224, 3)      30
#  Conv2D)
#
#  batch_normalization (BatchN  (None, 224, 224, 3)      12
#  ormalization)
#
#  re_lu (ReLU)                (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 224, 224, 64)      256
#
#  batch_normalization_1 (Batc  (None, 224, 224, 64)     256
#  hNormalization)
#
#  re_lu_1 (ReLU)              (None, 224, 224, 64)      0
#
#  depthwise_conv2d_1 (Depthwi  (None, 112, 112, 64)     640
#  seConv2D)
#
#  batch_normalization_2 (Batc  (None, 112, 112, 64)     256
#  hNormalization)
#
#  re_lu_2 (ReLU)              (None, 112, 112, 64)      0
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 128)     8320
#
#  batch_normalization_3 (Batc  (None, 112, 112, 128)    512
#  hNormalization)
#
#  re_lu_3 (ReLU)              (None, 112, 112, 128)     0
#
#  depthwise_conv2d_2 (Depthwi  (None, 56, 56, 128)      1280
#  seConv2D)
#
#  batch_normalization_4 (Batc  (None, 56, 56, 128)      512
#  hNormalization)
#
#  re_lu_4 (ReLU)              (None, 56, 56, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 256)       33024
#
#  batch_normalization_5 (Batc  (None, 56, 56, 256)      1024
#  hNormalization)
#
#  re_lu_5 (ReLU)              (None, 56, 56, 256)       0
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 2)                 514
#
# =================================================================
# Total params: 46,636
# Trainable params: 45,350
# Non-trainable params: 1,286
# _________________________________________________________________
# 2023-12-25 12:58:09.863641: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-25 12:58:10.385651: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Depthwise40XResized"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/4. DepthwiseCNN/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-25 12:58:20.893067: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-25 12:58:22.304077: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - 30s 369ms/step - loss: 0.4955 - accuracy: 0.7630 - precision: 0.7630 - recall: 0.7630 - auc: 0.8409 - f1_score: 0.7630 - val_loss: 0.7034 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 2/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.4514 - accuracy: 0.7909 - precision: 0.7909 - recall: 0.7909 - auc: 0.8699 - f1_score: 0.7909 - val_loss: 0.7096 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6139 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 3/100
# 71/71 [==============================] - 26s 370ms/step - loss: 0.4132 - accuracy: 0.8081 - precision: 0.8081 - recall: 0.8081 - auc: 0.8939 - f1_score: 0.8081 - val_loss: 0.7680 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6356 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 4/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3955 - accuracy: 0.8148 - precision: 0.8148 - recall: 0.8148 - auc: 0.9029 - f1_score: 0.8148 - val_loss: 0.7061 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5988 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 5/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3751 - accuracy: 0.8391 - precision: 0.8391 - recall: 0.8391 - auc: 0.9128 - f1_score: 0.8391 - val_loss: 0.8306 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5970 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 6/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3752 - accuracy: 0.8285 - precision: 0.8285 - recall: 0.8285 - auc: 0.9135 - f1_score: 0.8285 - val_loss: 1.3764 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.4931 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 7/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3326 - accuracy: 0.8590 - precision: 0.8590 - recall: 0.8590 - auc: 0.9329 - f1_score: 0.8590 - val_loss: 0.9639 - val_accuracy: 0.5740 - val_precision: 0.5740 - val_recall: 0.5740 - val_auc: 0.6536 - val_f1_score: 0.5740 - lr: 0.0010
# Epoch 8/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3496 - accuracy: 0.8435 - precision: 0.8435 - recall: 0.8435 - auc: 0.9255 - f1_score: 0.8435 - val_loss: 0.6299 - val_accuracy: 0.6716 - val_precision: 0.6716 - val_recall: 0.6716 - val_auc: 0.7696 - val_f1_score: 0.6716 - lr: 0.0010
# Epoch 9/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.3393 - accuracy: 0.8528 - precision: 0.8528 - recall: 0.8528 - auc: 0.9303 - f1_score: 0.8528 - val_loss: 1.2199 - val_accuracy: 0.5414 - val_precision: 0.5414 - val_recall: 0.5414 - val_auc: 0.5684 - val_f1_score: 0.5414 - lr: 0.0010
# Epoch 10/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3231 - accuracy: 0.8559 - precision: 0.8559 - recall: 0.8559 - auc: 0.9360 - f1_score: 0.8559 - val_loss: 0.7168 - val_accuracy: 0.7367 - val_precision: 0.7367 - val_recall: 0.7367 - val_auc: 0.8007 - val_f1_score: 0.7367 - lr: 0.0010
# Epoch 11/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.3357 - accuracy: 0.8457 - precision: 0.8457 - recall: 0.8457 - auc: 0.9324 - f1_score: 0.8457 - val_loss: 0.9679 - val_accuracy: 0.6183 - val_precision: 0.6183 - val_recall: 0.6183 - val_auc: 0.6729 - val_f1_score: 0.6183 - lr: 0.0010
# Epoch 12/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3191 - accuracy: 0.8625 - precision: 0.8625 - recall: 0.8625 - auc: 0.9379 - f1_score: 0.8625 - val_loss: 0.7782 - val_accuracy: 0.6805 - val_precision: 0.6805 - val_recall: 0.6805 - val_auc: 0.7327 - val_f1_score: 0.6805 - lr: 0.0010
# Epoch 13/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3119 - accuracy: 0.8660 - precision: 0.8660 - recall: 0.8660 - auc: 0.9421 - f1_score: 0.8660 - val_loss: 1.2794 - val_accuracy: 0.5858 - val_precision: 0.5858 - val_recall: 0.5858 - val_auc: 0.6002 - val_f1_score: 0.5858 - lr: 0.0010
# Epoch 14/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.2843 - accuracy: 0.8758 - precision: 0.8758 - recall: 0.8758 - auc: 0.9514 - f1_score: 0.8758 - val_loss: 0.7010 - val_accuracy: 0.7130 - val_precision: 0.7130 - val_recall: 0.7130 - val_auc: 0.7848 - val_f1_score: 0.7130 - lr: 0.0010
# Epoch 15/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.2805 - accuracy: 0.8789 - precision: 0.8789 - recall: 0.8789 - auc: 0.9532 - f1_score: 0.8789 - val_loss: 1.3624 - val_accuracy: 0.4822 - val_precision: 0.4822 - val_recall: 0.4822 - val_auc: 0.5237 - val_f1_score: 0.4822 - lr: 0.0010
# Epoch 16/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.2758 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9541 - f1_score: 0.8833 - val_loss: 0.6815 - val_accuracy: 0.7160 - val_precision: 0.7160 - val_recall: 0.7160 - val_auc: 0.7990 - val_f1_score: 0.7160 - lr: 0.0010
# Epoch 17/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.2902 - accuracy: 0.8771 - precision: 0.8771 - recall: 0.8771 - auc: 0.9484 - f1_score: 0.8771 - val_loss: 0.7309 - val_accuracy: 0.7337 - val_precision: 0.7337 - val_recall: 0.7337 - val_auc: 0.7856 - val_f1_score: 0.7337 - lr: 0.0010
# Epoch 18/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.2740 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9551 - f1_score: 0.8820 - val_loss: 0.2860 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9599 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 19/100
# 71/71 [==============================] - 26s 358ms/step - loss: 0.2819 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9517 - f1_score: 0.8749 - val_loss: 0.3116 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9407 - val_f1_score: 0.8639 - lr: 0.0010
# Epoch 20/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.2638 - accuracy: 0.8815 - precision: 0.8815 - recall: 0.8815 - auc: 0.9578 - f1_score: 0.8815 - val_loss: 0.9956 - val_accuracy: 0.6479 - val_precision: 0.6479 - val_recall: 0.6479 - val_auc: 0.6972 - val_f1_score: 0.6479 - lr: 0.0010
# Epoch 21/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.2519 - accuracy: 0.8882 - precision: 0.8882 - recall: 0.8882 - auc: 0.9616 - f1_score: 0.8882 - val_loss: 0.2510 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9638 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 22/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.2468 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9633 - f1_score: 0.8979 - val_loss: 0.4183 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.8915 - val_f1_score: 0.8166 - lr: 0.0010
# Epoch 23/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.2544 - accuracy: 0.8855 - precision: 0.8855 - recall: 0.8855 - auc: 0.9604 - f1_score: 0.8855 - val_loss: 1.3046 - val_accuracy: 0.6243 - val_precision: 0.6243 - val_recall: 0.6243 - val_auc: 0.7341 - val_f1_score: 0.6243 - lr: 0.0010
# Epoch 24/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.2428 - accuracy: 0.8939 - precision: 0.8939 - recall: 0.8939 - auc: 0.9645 - f1_score: 0.8939 - val_loss: 0.3066 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9435 - val_f1_score: 0.8580 - lr: 0.0010
# Epoch 25/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.2427 - accuracy: 0.8974 - precision: 0.8974 - recall: 0.8974 - auc: 0.9646 - f1_score: 0.8974 - val_loss: 1.0811 - val_accuracy: 0.5888 - val_precision: 0.5888 - val_recall: 0.5888 - val_auc: 0.6477 - val_f1_score: 0.5888 - lr: 0.0010
# Epoch 26/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.2476 - accuracy: 0.8908 - precision: 0.8908 - recall: 0.8908 - auc: 0.9629 - f1_score: 0.8908 - val_loss: 0.2581 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9615 - val_f1_score: 0.9142 - lr: 0.0010
# Epoch 27/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.2275 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9689 - f1_score: 0.9054 - val_loss: 0.1971 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9818 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 28/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.2220 - accuracy: 0.9080 - precision: 0.9080 - recall: 0.9080 - auc: 0.9706 - f1_score: 0.9080 - val_loss: 1.1665 - val_accuracy: 0.7101 - val_precision: 0.7101 - val_recall: 0.7101 - val_auc: 0.7859 - val_f1_score: 0.7101 - lr: 0.0010
# Epoch 29/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.2185 - accuracy: 0.9080 - precision: 0.9080 - recall: 0.9080 - auc: 0.9710 - f1_score: 0.9080 - val_loss: 0.2953 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9463 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 30/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.2411 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9660 - f1_score: 0.9063 - val_loss: 0.3144 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9401 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 31/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.2190 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9709 - f1_score: 0.9023 - val_loss: 0.4284 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9033 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 32/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.2143 - accuracy: 0.9098 - precision: 0.9098 - recall: 0.9098 - auc: 0.9722 - f1_score: 0.9098 - val_loss: 0.2555 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9613 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 33/100
# 71/71 [==============================] - 26s 358ms/step - loss: 0.2239 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9697 - f1_score: 0.9125 - val_loss: 0.5303 - val_accuracy: 0.7751 - val_precision: 0.7751 - val_recall: 0.7751 - val_auc: 0.8843 - val_f1_score: 0.7751 - lr: 0.0010
# Epoch 34/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.2215 - accuracy: 0.9107 - precision: 0.9107 - recall: 0.9107 - auc: 0.9704 - f1_score: 0.9107 - val_loss: 0.2394 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9648 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 35/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.2030 - accuracy: 0.9235 - precision: 0.9235 - recall: 0.9235 - auc: 0.9752 - f1_score: 0.9235 - val_loss: 0.3516 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9288 - val_f1_score: 0.8402 - lr: 0.0010
# Epoch 36/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1875 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9794 - f1_score: 0.9231 - val_loss: 0.2206 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9751 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 37/100
# 71/71 [==============================] - ETA: 0s - loss: 0.1932 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9776 - f1_score: 0.9191
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1932 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9776 - f1_score: 0.9191 - val_loss: 0.2778 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9530 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 38/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1579 - accuracy: 0.9377 - precision: 0.9377 - recall: 0.9377 - auc: 0.9858 - f1_score: 0.9377 - val_loss: 0.1666 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9880 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 39/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.1539 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9869 - f1_score: 0.9368 - val_loss: 0.1291 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9953 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 40/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1520 - accuracy: 0.9439 - precision: 0.9439 - recall: 0.9439 - auc: 0.9878 - f1_score: 0.9439 - val_loss: 0.1347 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9927 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 41/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1485 - accuracy: 0.9456 - precision: 0.9456 - recall: 0.9456 - auc: 0.9886 - f1_score: 0.9456 - val_loss: 0.1293 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9925 - val_f1_score: 0.9645 - lr: 1.0000e-04
# Epoch 42/100
# 71/71 [==============================] - 26s 359ms/step - loss: 0.1707 - accuracy: 0.9332 - precision: 0.9332 - recall: 0.9332 - auc: 0.9832 - f1_score: 0.9332 - val_loss: 0.1183 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9950 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 43/100
# 71/71 [==============================] - 26s 357ms/step - loss: 0.1619 - accuracy: 0.9394 - precision: 0.9394 - recall: 0.9394 - auc: 0.9853 - f1_score: 0.9394 - val_loss: 0.1413 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9912 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 44/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1623 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9850 - f1_score: 0.9355 - val_loss: 0.1431 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9919 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 45/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1409 - accuracy: 0.9461 - precision: 0.9461 - recall: 0.9461 - auc: 0.9897 - f1_score: 0.9461 - val_loss: 0.1486 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9910 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 46/100
# 71/71 [==============================] - 26s 358ms/step - loss: 0.1560 - accuracy: 0.9377 - precision: 0.9377 - recall: 0.9377 - auc: 0.9863 - f1_score: 0.9377 - val_loss: 0.1528 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9900 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 47/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1492 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9880 - f1_score: 0.9421 - val_loss: 0.1164 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9962 - val_f1_score: 0.9734 - lr: 1.0000e-04
# Epoch 48/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1455 - accuracy: 0.9478 - precision: 0.9478 - recall: 0.9478 - auc: 0.9886 - f1_score: 0.9478 - val_loss: 0.1167 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9944 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 49/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1645 - accuracy: 0.9363 - precision: 0.9363 - recall: 0.9363 - auc: 0.9844 - f1_score: 0.9363 - val_loss: 0.1181 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9936 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 50/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1555 - accuracy: 0.9416 - precision: 0.9416 - recall: 0.9416 - auc: 0.9865 - f1_score: 0.9416 - val_loss: 0.1163 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9955 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 51/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1585 - accuracy: 0.9412 - precision: 0.9412 - recall: 0.9412 - auc: 0.9860 - f1_score: 0.9412 - val_loss: 0.1209 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9950 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 52/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1393 - accuracy: 0.9492 - precision: 0.9492 - recall: 0.9492 - auc: 0.9897 - f1_score: 0.9492 - val_loss: 0.1168 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9957 - val_f1_score: 0.9645 - lr: 1.0000e-04
# Epoch 53/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1485 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9876 - f1_score: 0.9474 - val_loss: 0.1292 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9920 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 54/100
# 71/71 [==============================] - 26s 359ms/step - loss: 0.1572 - accuracy: 0.9377 - precision: 0.9377 - recall: 0.9377 - auc: 0.9857 - f1_score: 0.9377 - val_loss: 0.1138 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9949 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 55/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1410 - accuracy: 0.9465 - precision: 0.9465 - recall: 0.9465 - auc: 0.9893 - f1_score: 0.9465 - val_loss: 0.1213 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9954 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 56/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1389 - accuracy: 0.9549 - precision: 0.9549 - recall: 0.9549 - auc: 0.9902 - f1_score: 0.9549 - val_loss: 0.1190 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9944 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 57/100
# 71/71 [==============================] - 26s 359ms/step - loss: 0.1434 - accuracy: 0.9478 - precision: 0.9478 - recall: 0.9478 - auc: 0.9886 - f1_score: 0.9478 - val_loss: 0.1226 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9938 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 58/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1468 - accuracy: 0.9461 - precision: 0.9461 - recall: 0.9461 - auc: 0.9883 - f1_score: 0.9461 - val_loss: 0.1000 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9968 - val_f1_score: 0.9734 - lr: 1.0000e-04
# Epoch 59/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1499 - accuracy: 0.9399 - precision: 0.9399 - recall: 0.9399 - auc: 0.9871 - f1_score: 0.9399 - val_loss: 0.1112 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9961 - val_f1_score: 0.9734 - lr: 1.0000e-04
# Epoch 60/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1316 - accuracy: 0.9518 - precision: 0.9518 - recall: 0.9518 - auc: 0.9908 - f1_score: 0.9518 - val_loss: 0.1080 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9945 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 61/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1363 - accuracy: 0.9492 - precision: 0.9492 - recall: 0.9492 - auc: 0.9899 - f1_score: 0.9492 - val_loss: 0.1352 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9920 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 62/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1314 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9909 - f1_score: 0.9505 - val_loss: 0.1299 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9931 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 63/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1390 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9898 - f1_score: 0.9487 - val_loss: 0.1016 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9968 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 64/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1461 - accuracy: 0.9430 - precision: 0.9430 - recall: 0.9430 - auc: 0.9874 - f1_score: 0.9430 - val_loss: 0.1256 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9940 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 65/100
# 71/71 [==============================] - 26s 359ms/step - loss: 0.1405 - accuracy: 0.9456 - precision: 0.9456 - recall: 0.9456 - auc: 0.9892 - f1_score: 0.9456 - val_loss: 0.0913 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9972 - val_f1_score: 0.9793 - lr: 1.0000e-04
# Epoch 66/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1411 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9889 - f1_score: 0.9487 - val_loss: 0.0989 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9971 - val_f1_score: 0.9734 - lr: 1.0000e-04
# Epoch 67/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1374 - accuracy: 0.9492 - precision: 0.9492 - recall: 0.9492 - auc: 0.9897 - f1_score: 0.9492 - val_loss: 0.1101 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9944 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 68/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.1469 - accuracy: 0.9434 - precision: 0.9434 - recall: 0.9434 - auc: 0.9879 - f1_score: 0.9434 - val_loss: 0.1168 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9928 - val_f1_score: 0.9763 - lr: 1.0000e-04
# Epoch 69/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1400 - accuracy: 0.9412 - precision: 0.9412 - recall: 0.9412 - auc: 0.9892 - f1_score: 0.9412 - val_loss: 0.1029 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9967 - val_f1_score: 0.9675 - lr: 1.0000e-04
# Epoch 70/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1369 - accuracy: 0.9483 - precision: 0.9483 - recall: 0.9483 - auc: 0.9900 - f1_score: 0.9483 - val_loss: 0.0898 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9972 - val_f1_score: 0.9763 - lr: 1.0000e-04
# Epoch 71/100
# 71/71 [==============================] - 26s 359ms/step - loss: 0.1374 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9893 - f1_score: 0.9474 - val_loss: 0.1082 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9963 - val_f1_score: 0.9645 - lr: 1.0000e-04
# Epoch 72/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1329 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9904 - f1_score: 0.9505 - val_loss: 0.1159 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9949 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 73/100
# 71/71 [==============================] - 26s 358ms/step - loss: 0.1307 - accuracy: 0.9496 - precision: 0.9496 - recall: 0.9496 - auc: 0.9907 - f1_score: 0.9496 - val_loss: 0.0906 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9978 - val_f1_score: 0.9763 - lr: 1.0000e-04
# Epoch 74/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1422 - accuracy: 0.9456 - precision: 0.9456 - recall: 0.9456 - auc: 0.9885 - f1_score: 0.9456 - val_loss: 0.1029 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9952 - val_f1_score: 0.9675 - lr: 1.0000e-04
# Epoch 75/100
# 71/71 [==============================] - 25s 357ms/step - loss: 0.1257 - accuracy: 0.9514 - precision: 0.9514 - recall: 0.9514 - auc: 0.9920 - f1_score: 0.9514 - val_loss: 0.0898 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9975 - val_f1_score: 0.9763 - lr: 1.0000e-04
# Epoch 76/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1281 - accuracy: 0.9518 - precision: 0.9518 - recall: 0.9518 - auc: 0.9913 - f1_score: 0.9518 - val_loss: 0.0960 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9971 - val_f1_score: 0.9734 - lr: 1.0000e-04
# Epoch 77/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1324 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9900 - f1_score: 0.9505 - val_loss: 0.0998 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9966 - val_f1_score: 0.9734 - lr: 1.0000e-04
# Epoch 78/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1377 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9893 - f1_score: 0.9474 - val_loss: 0.1213 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9923 - val_f1_score: 0.9645 - lr: 1.0000e-04
# Epoch 79/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1308 - accuracy: 0.9478 - precision: 0.9478 - recall: 0.9478 - auc: 0.9909 - f1_score: 0.9478 - val_loss: 0.1080 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9955 - val_f1_score: 0.9763 - lr: 1.0000e-04
# Epoch 80/100
# 71/71 [==============================] - ETA: 0s - loss: 0.1331 - accuracy: 0.9478 - precision: 0.9478 - recall: 0.9478 - auc: 0.9907 - f1_score: 0.9478
# Epoch 80: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 71/71 [==============================] - 25s 357ms/step - loss: 0.1331 - accuracy: 0.9478 - precision: 0.9478 - recall: 0.9478 - auc: 0.9907 - f1_score: 0.9478 - val_loss: 0.1110 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9953 - val_f1_score: 0.9675 - lr: 1.0000e-04
# Epoch 81/100
# 71/71 [==============================] - 26s 359ms/step - loss: 0.1363 - accuracy: 0.9430 - precision: 0.9430 - recall: 0.9430 - auc: 0.9897 - f1_score: 0.9430 - val_loss: 0.0959 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9972 - val_f1_score: 0.9822 - lr: 1.0000e-05
# Epoch 82/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1309 - accuracy: 0.9492 - precision: 0.9492 - recall: 0.9492 - auc: 0.9906 - f1_score: 0.9492 - val_loss: 0.0929 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9970 - val_f1_score: 0.9734 - lr: 1.0000e-05
# Epoch 83/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1336 - accuracy: 0.9456 - precision: 0.9456 - recall: 0.9456 - auc: 0.9905 - f1_score: 0.9456 - val_loss: 0.0980 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9971 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 84/100
# 71/71 [==============================] - 26s 358ms/step - loss: 0.1315 - accuracy: 0.9492 - precision: 0.9492 - recall: 0.9492 - auc: 0.9907 - f1_score: 0.9492 - val_loss: 0.0864 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9978 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 85/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1337 - accuracy: 0.9531 - precision: 0.9531 - recall: 0.9531 - auc: 0.9900 - f1_score: 0.9531 - val_loss: 0.0887 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9971 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 86/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1195 - accuracy: 0.9607 - precision: 0.9607 - recall: 0.9607 - auc: 0.9927 - f1_score: 0.9607 - val_loss: 0.0941 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9970 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 87/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1281 - accuracy: 0.9571 - precision: 0.9571 - recall: 0.9571 - auc: 0.9913 - f1_score: 0.9571 - val_loss: 0.0981 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9968 - val_f1_score: 0.9734 - lr: 1.0000e-05
# Epoch 88/100
# 71/71 [==============================] - 26s 359ms/step - loss: 0.1237 - accuracy: 0.9492 - precision: 0.9492 - recall: 0.9492 - auc: 0.9917 - f1_score: 0.9492 - val_loss: 0.0971 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9968 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 89/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1355 - accuracy: 0.9514 - precision: 0.9514 - recall: 0.9514 - auc: 0.9894 - f1_score: 0.9514 - val_loss: 0.0896 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9976 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 90/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1208 - accuracy: 0.9545 - precision: 0.9545 - recall: 0.9545 - auc: 0.9924 - f1_score: 0.9545 - val_loss: 0.0937 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9971 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 91/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.1223 - accuracy: 0.9598 - precision: 0.9598 - recall: 0.9598 - auc: 0.9923 - f1_score: 0.9598 - val_loss: 0.0948 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9973 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 92/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.1260 - accuracy: 0.9527 - precision: 0.9527 - recall: 0.9527 - auc: 0.9916 - f1_score: 0.9527 - val_loss: 0.0880 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9975 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 93/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1241 - accuracy: 0.9518 - precision: 0.9518 - recall: 0.9518 - auc: 0.9916 - f1_score: 0.9518 - val_loss: 0.0948 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9964 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 94/100
# 71/71 [==============================] - ETA: 0s - loss: 0.1277 - accuracy: 0.9514 - precision: 0.9514 - recall: 0.9514 - auc: 0.9911 - f1_score: 0.9514
# Epoch 94: ReduceLROnPlateau reducing learning rate to 1e-05.
# 71/71 [==============================] - 26s 359ms/step - loss: 0.1277 - accuracy: 0.9514 - precision: 0.9514 - recall: 0.9514 - auc: 0.9911 - f1_score: 0.9514 - val_loss: 0.0872 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9979 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 95/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1244 - accuracy: 0.9598 - precision: 0.9598 - recall: 0.9598 - auc: 0.9918 - f1_score: 0.9598 - val_loss: 0.0967 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9955 - val_f1_score: 0.9822 - lr: 1.0000e-05
# Epoch 96/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.1170 - accuracy: 0.9589 - precision: 0.9589 - recall: 0.9589 - auc: 0.9932 - f1_score: 0.9589 - val_loss: 0.1063 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9948 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 97/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1278 - accuracy: 0.9540 - precision: 0.9540 - recall: 0.9540 - auc: 0.9913 - f1_score: 0.9540 - val_loss: 0.0911 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9964 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 98/100
# 71/71 [==============================] - 26s 359ms/step - loss: 0.1310 - accuracy: 0.9496 - precision: 0.9496 - recall: 0.9496 - auc: 0.9907 - f1_score: 0.9496 - val_loss: 0.0852 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9983 - val_f1_score: 0.9822 - lr: 1.0000e-05
# Epoch 99/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1295 - accuracy: 0.9527 - precision: 0.9527 - recall: 0.9527 - auc: 0.9911 - f1_score: 0.9527 - val_loss: 0.0936 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9977 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 100/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1334 - accuracy: 0.9500 - precision: 0.9500 - recall: 0.9500 - auc: 0.9905 - f1_score: 0.9500 - val_loss: 0.0929 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9975 - val_f1_score: 0.9763 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 0s 13ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9447247203334065
# F1-Score for each class: [0.92553191 0.96391753]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9540816326530612
# specificity: 0.9456521739130435

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 12ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 1s 73ms/step - loss: 0.1199 - accuracy: 0.9530 - precision: 0.9530 - recall: 0.9530 - auc: 0.9918 - f1_score: 0.9530
# Test loss: 0.1198808029294014
# Test accuracy: 0.9530201554298401
# Test precision: 0.9530201554298401
# Test recall: 0.9530201554298401
# Test AUC: 0.9918472170829773
# Test F1 Score: 0.9530201554298401

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 12ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.95      0.93        92
#            1       0.97      0.95      0.96       196
#
#     accuracy                           0.95       288
#    macro avg       0.94      0.95      0.94       288
# weighted avg       0.95      0.95      0.95       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
