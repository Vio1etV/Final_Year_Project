# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/BCResize/200X/test'
train_dir = '/root/BreastCancer/BCResize/200X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/BCResize/200X/train/malignant'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1952 images belonging to 2 classes.
# Found 290 images belonging to 2 classes.
# Found 301 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %% [markdown]
# <h1>Model Construction<h1>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Concatenate, Flatten, Dense

def inception_block(x, filters):
    conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(x)

    conv3x3 = Conv2D(filters[1], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv3x3)

    conv5x5 = Conv2D(filters[3], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv5x5)

    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    maxpool = Conv2D(filters[5], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(maxpool)

    inception_block = Concatenate(axis=-1)([conv1x1, conv3x3, conv5x5, maxpool])
    return inception_block

def inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer = 'he_normal')(input_tensor)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception blocks
    x = inception_block(x, filters=[64, 128, 128, 32, 96, 32])
    x = inception_block(x, filters=[128, 128, 96, 64, 64, 64])

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=x)

    return model


# Create the InceptionNet model
model = inception_net(input_shape, num_classes)

# Display the model summary
model.summary()
# Out:
# 2023-12-24 15:01:07.517782: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 15:01:08.051769: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  8320        ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 128)  147584      ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 96)   76896       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 320)  0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 128)  41088       ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 64)   20544       ['concatenate[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 320)  0          ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 128)  41088       ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 56, 96)   110688      ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 64)   102464      ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 64)   20544       ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 352)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 352)  0          ['concatenate_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 352)         0           ['max_pooling2d_3[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            706         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 587,714
# Trainable params: 587,714
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "InceptionNetResized200X_CalledTwice"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/1. InceptionNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-24 15:01:11.957568: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-24 15:01:13.364448: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 61/61 [==============================] - 27s 377ms/step - loss: 0.6716 - accuracy: 0.6798 - precision: 0.6798 - recall: 0.6798 - auc: 0.7382 - f1_score: 0.6798 - val_loss: 0.4159 - val_accuracy: 0.8759 - val_precision: 0.8759 - val_recall: 0.8759 - val_auc: 0.9559 - val_f1_score: 0.8759 - lr: 0.0010
# Epoch 2/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.4737 - accuracy: 0.7976 - precision: 0.7976 - recall: 0.7976 - auc: 0.8569 - f1_score: 0.7976 - val_loss: 0.4576 - val_accuracy: 0.7828 - val_precision: 0.7828 - val_recall: 0.7828 - val_auc: 0.8870 - val_f1_score: 0.7828 - lr: 0.0010
# Epoch 3/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.4580 - accuracy: 0.8002 - precision: 0.8002 - recall: 0.8002 - auc: 0.8672 - f1_score: 0.8002 - val_loss: 0.4105 - val_accuracy: 0.8483 - val_precision: 0.8483 - val_recall: 0.8483 - val_auc: 0.9253 - val_f1_score: 0.8483 - lr: 0.0010
# Epoch 4/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.4372 - accuracy: 0.8120 - precision: 0.8120 - recall: 0.8120 - auc: 0.8799 - f1_score: 0.8120 - val_loss: 0.3721 - val_accuracy: 0.8586 - val_precision: 0.8586 - val_recall: 0.8586 - val_auc: 0.9427 - val_f1_score: 0.8586 - lr: 0.0010
# Epoch 5/100
# 61/61 [==============================] - 23s 371ms/step - loss: 0.4585 - accuracy: 0.8028 - precision: 0.8028 - recall: 0.8028 - auc: 0.8666 - f1_score: 0.8028 - val_loss: 0.3736 - val_accuracy: 0.8552 - val_precision: 0.8552 - val_recall: 0.8552 - val_auc: 0.9370 - val_f1_score: 0.8552 - lr: 0.0010
# Epoch 6/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.4143 - accuracy: 0.8181 - precision: 0.8181 - recall: 0.8181 - auc: 0.8942 - f1_score: 0.8181 - val_loss: 0.4777 - val_accuracy: 0.7862 - val_precision: 0.7862 - val_recall: 0.7862 - val_auc: 0.8482 - val_f1_score: 0.7862 - lr: 0.0010
# Epoch 7/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.4330 - accuracy: 0.8048 - precision: 0.8048 - recall: 0.8048 - auc: 0.8819 - f1_score: 0.8048 - val_loss: 0.3680 - val_accuracy: 0.8483 - val_precision: 0.8483 - val_recall: 0.8483 - val_auc: 0.9133 - val_f1_score: 0.8483 - lr: 0.0010
# Epoch 8/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.4448 - accuracy: 0.8069 - precision: 0.8069 - recall: 0.8069 - auc: 0.8764 - f1_score: 0.8069 - val_loss: 0.4719 - val_accuracy: 0.7690 - val_precision: 0.7690 - val_recall: 0.7690 - val_auc: 0.8640 - val_f1_score: 0.7690 - lr: 0.0010
# Epoch 9/100
# 61/61 [==============================] - 22s 364ms/step - loss: 0.4328 - accuracy: 0.8207 - precision: 0.8207 - recall: 0.8207 - auc: 0.8826 - f1_score: 0.8207 - val_loss: 0.3998 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9610 - val_f1_score: 0.8931 - lr: 0.0010
# Epoch 10/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.4499 - accuracy: 0.8064 - precision: 0.8064 - recall: 0.8064 - auc: 0.8715 - f1_score: 0.8064 - val_loss: 0.3727 - val_accuracy: 0.8586 - val_precision: 0.8586 - val_recall: 0.8586 - val_auc: 0.9134 - val_f1_score: 0.8586 - lr: 0.0010
# Epoch 11/100
# 61/61 [==============================] - 22s 364ms/step - loss: 0.4143 - accuracy: 0.8243 - precision: 0.8243 - recall: 0.8243 - auc: 0.8930 - f1_score: 0.8243 - val_loss: 0.3658 - val_accuracy: 0.8690 - val_precision: 0.8690 - val_recall: 0.8690 - val_auc: 0.9325 - val_f1_score: 0.8690 - lr: 0.0010
# Epoch 12/100
# 61/61 [==============================] - 23s 372ms/step - loss: 0.4098 - accuracy: 0.8248 - precision: 0.8248 - recall: 0.8248 - auc: 0.8960 - f1_score: 0.8248 - val_loss: 0.3089 - val_accuracy: 0.8828 - val_precision: 0.8828 - val_recall: 0.8828 - val_auc: 0.9608 - val_f1_score: 0.8828 - lr: 0.0010
# Epoch 13/100
# 61/61 [==============================] - 23s 374ms/step - loss: 0.4061 - accuracy: 0.8345 - precision: 0.8345 - recall: 0.8345 - auc: 0.8977 - f1_score: 0.8345 - val_loss: 0.4474 - val_accuracy: 0.7966 - val_precision: 0.7966 - val_recall: 0.7966 - val_auc: 0.8738 - val_f1_score: 0.7966 - lr: 0.0010
# Epoch 14/100
# 61/61 [==============================] - 23s 368ms/step - loss: 0.4038 - accuracy: 0.8243 - precision: 0.8243 - recall: 0.8243 - auc: 0.8986 - f1_score: 0.8243 - val_loss: 0.3323 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9587 - val_f1_score: 0.8931 - lr: 0.0010
# Epoch 15/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.4363 - accuracy: 0.8058 - precision: 0.8058 - recall: 0.8058 - auc: 0.8815 - f1_score: 0.8058 - val_loss: 0.3038 - val_accuracy: 0.9345 - val_precision: 0.9345 - val_recall: 0.9345 - val_auc: 0.9831 - val_f1_score: 0.9345 - lr: 0.0010
# Epoch 16/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.4209 - accuracy: 0.8017 - precision: 0.8017 - recall: 0.8017 - auc: 0.8882 - f1_score: 0.8017 - val_loss: 0.3065 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9660 - val_f1_score: 0.8931 - lr: 0.0010
# Epoch 17/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.3832 - accuracy: 0.8386 - precision: 0.8386 - recall: 0.8386 - auc: 0.9100 - f1_score: 0.8386 - val_loss: 0.2665 - val_accuracy: 0.8966 - val_precision: 0.8966 - val_recall: 0.8966 - val_auc: 0.9712 - val_f1_score: 0.8966 - lr: 0.0010
# Epoch 18/100
# 61/61 [==============================] - 22s 369ms/step - loss: 0.3752 - accuracy: 0.8417 - precision: 0.8417 - recall: 0.8417 - auc: 0.9141 - f1_score: 0.8417 - val_loss: 0.3274 - val_accuracy: 0.8655 - val_precision: 0.8655 - val_recall: 0.8655 - val_auc: 0.9417 - val_f1_score: 0.8655 - lr: 0.0010
# Epoch 19/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.3563 - accuracy: 0.8530 - precision: 0.8530 - recall: 0.8530 - auc: 0.9224 - f1_score: 0.8530 - val_loss: 0.3833 - val_accuracy: 0.8138 - val_precision: 0.8138 - val_recall: 0.8138 - val_auc: 0.9210 - val_f1_score: 0.8138 - lr: 0.0010
# Epoch 20/100
# 61/61 [==============================] - 22s 362ms/step - loss: 0.3472 - accuracy: 0.8586 - precision: 0.8586 - recall: 0.8586 - auc: 0.9270 - f1_score: 0.8586 - val_loss: 0.4262 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_auc: 0.8988 - val_f1_score: 0.8000 - lr: 0.0010
# Epoch 21/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.3814 - accuracy: 0.8391 - precision: 0.8391 - recall: 0.8391 - auc: 0.9109 - f1_score: 0.8391 - val_loss: 0.3101 - val_accuracy: 0.8724 - val_precision: 0.8724 - val_recall: 0.8724 - val_auc: 0.9541 - val_f1_score: 0.8724 - lr: 0.0010
# Epoch 22/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.3753 - accuracy: 0.8263 - precision: 0.8263 - recall: 0.8263 - auc: 0.9115 - f1_score: 0.8263 - val_loss: 0.3137 - val_accuracy: 0.8828 - val_precision: 0.8828 - val_recall: 0.8828 - val_auc: 0.9452 - val_f1_score: 0.8828 - lr: 0.0010
# Epoch 23/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.3439 - accuracy: 0.8571 - precision: 0.8571 - recall: 0.8571 - auc: 0.9276 - f1_score: 0.8571 - val_loss: 0.3945 - val_accuracy: 0.8310 - val_precision: 0.8310 - val_recall: 0.8310 - val_auc: 0.9298 - val_f1_score: 0.8310 - lr: 0.0010
# Epoch 24/100
# 61/61 [==============================] - 22s 363ms/step - loss: 0.3744 - accuracy: 0.8350 - precision: 0.8350 - recall: 0.8350 - auc: 0.9138 - f1_score: 0.8350 - val_loss: 0.5083 - val_accuracy: 0.8103 - val_precision: 0.8103 - val_recall: 0.8103 - val_auc: 0.8507 - val_f1_score: 0.8103 - lr: 0.0010
# Epoch 25/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.3489 - accuracy: 0.8545 - precision: 0.8545 - recall: 0.8545 - auc: 0.9265 - f1_score: 0.8545 - val_loss: 0.2793 - val_accuracy: 0.9103 - val_precision: 0.9103 - val_recall: 0.9103 - val_auc: 0.9697 - val_f1_score: 0.9103 - lr: 0.0010
# Epoch 26/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.3265 - accuracy: 0.8648 - precision: 0.8648 - recall: 0.8648 - auc: 0.9354 - f1_score: 0.8648 - val_loss: 0.2521 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9668 - val_f1_score: 0.8931 - lr: 0.0010
# Epoch 27/100
# 61/61 [==============================] - 22s 363ms/step - loss: 0.3459 - accuracy: 0.8596 - precision: 0.8596 - recall: 0.8596 - auc: 0.9270 - f1_score: 0.8596 - val_loss: 0.3669 - val_accuracy: 0.8448 - val_precision: 0.8448 - val_recall: 0.8448 - val_auc: 0.9156 - val_f1_score: 0.8448 - lr: 0.0010
# Epoch 28/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.3211 - accuracy: 0.8627 - precision: 0.8627 - recall: 0.8627 - auc: 0.9372 - f1_score: 0.8627 - val_loss: 0.3540 - val_accuracy: 0.8483 - val_precision: 0.8483 - val_recall: 0.8483 - val_auc: 0.9294 - val_f1_score: 0.8483 - lr: 0.0010
# Epoch 29/100
# 61/61 [==============================] - 23s 371ms/step - loss: 0.3122 - accuracy: 0.8673 - precision: 0.8673 - recall: 0.8673 - auc: 0.9404 - f1_score: 0.8673 - val_loss: 0.3637 - val_accuracy: 0.8552 - val_precision: 0.8552 - val_recall: 0.8552 - val_auc: 0.9378 - val_f1_score: 0.8552 - lr: 0.0010
# Epoch 30/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.3563 - accuracy: 0.8422 - precision: 0.8422 - recall: 0.8422 - auc: 0.9218 - f1_score: 0.8422 - val_loss: 0.5282 - val_accuracy: 0.7448 - val_precision: 0.7448 - val_recall: 0.7448 - val_auc: 0.8159 - val_f1_score: 0.7448 - lr: 0.0010
# Epoch 31/100
# 61/61 [==============================] - 22s 364ms/step - loss: 0.3503 - accuracy: 0.8443 - precision: 0.8443 - recall: 0.8443 - auc: 0.9248 - f1_score: 0.8443 - val_loss: 0.5761 - val_accuracy: 0.7448 - val_precision: 0.7448 - val_recall: 0.7448 - val_auc: 0.7957 - val_f1_score: 0.7448 - lr: 0.0010
# Epoch 32/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.3279 - accuracy: 0.8704 - precision: 0.8704 - recall: 0.8704 - auc: 0.9339 - f1_score: 0.8704 - val_loss: 0.2291 - val_accuracy: 0.9034 - val_precision: 0.9034 - val_recall: 0.9034 - val_auc: 0.9802 - val_f1_score: 0.9034 - lr: 0.0010
# Epoch 33/100
# 61/61 [==============================] - 23s 371ms/step - loss: 0.3096 - accuracy: 0.8740 - precision: 0.8740 - recall: 0.8740 - auc: 0.9413 - f1_score: 0.8740 - val_loss: 0.3729 - val_accuracy: 0.8586 - val_precision: 0.8586 - val_recall: 0.8586 - val_auc: 0.9197 - val_f1_score: 0.8586 - lr: 0.0010
# Epoch 34/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.2936 - accuracy: 0.8796 - precision: 0.8796 - recall: 0.8796 - auc: 0.9479 - f1_score: 0.8796 - val_loss: 0.3335 - val_accuracy: 0.8517 - val_precision: 0.8517 - val_recall: 0.8517 - val_auc: 0.9310 - val_f1_score: 0.8517 - lr: 0.0010
# Epoch 35/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.3050 - accuracy: 0.8653 - precision: 0.8653 - recall: 0.8653 - auc: 0.9430 - f1_score: 0.8653 - val_loss: 0.3592 - val_accuracy: 0.8379 - val_precision: 0.8379 - val_recall: 0.8379 - val_auc: 0.9275 - val_f1_score: 0.8379 - lr: 0.0010
# Epoch 36/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.2935 - accuracy: 0.8765 - precision: 0.8765 - recall: 0.8765 - auc: 0.9478 - f1_score: 0.8765 - val_loss: 0.3747 - val_accuracy: 0.8103 - val_precision: 0.8103 - val_recall: 0.8103 - val_auc: 0.9100 - val_f1_score: 0.8103 - lr: 0.0010
# Epoch 37/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.2986 - accuracy: 0.8796 - precision: 0.8796 - recall: 0.8796 - auc: 0.9456 - f1_score: 0.8796 - val_loss: 0.3770 - val_accuracy: 0.8655 - val_precision: 0.8655 - val_recall: 0.8655 - val_auc: 0.9381 - val_f1_score: 0.8655 - lr: 0.0010
# Epoch 38/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.3058 - accuracy: 0.8735 - precision: 0.8735 - recall: 0.8735 - auc: 0.9430 - f1_score: 0.8735 - val_loss: 0.3606 - val_accuracy: 0.8414 - val_precision: 0.8414 - val_recall: 0.8414 - val_auc: 0.9219 - val_f1_score: 0.8414 - lr: 0.0010
# Epoch 39/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.3039 - accuracy: 0.8781 - precision: 0.8781 - recall: 0.8781 - auc: 0.9430 - f1_score: 0.8781 - val_loss: 0.2718 - val_accuracy: 0.9000 - val_precision: 0.9000 - val_recall: 0.9000 - val_auc: 0.9626 - val_f1_score: 0.9000 - lr: 0.0010
# Epoch 40/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.2724 - accuracy: 0.8847 - precision: 0.8847 - recall: 0.8847 - auc: 0.9549 - f1_score: 0.8847 - val_loss: 0.2003 - val_accuracy: 0.9000 - val_precision: 0.9000 - val_recall: 0.9000 - val_auc: 0.9797 - val_f1_score: 0.9000 - lr: 0.0010
# Epoch 41/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.2865 - accuracy: 0.8699 - precision: 0.8699 - recall: 0.8699 - auc: 0.9502 - f1_score: 0.8699 - val_loss: 0.4054 - val_accuracy: 0.8276 - val_precision: 0.8276 - val_recall: 0.8276 - val_auc: 0.8986 - val_f1_score: 0.8276 - lr: 0.0010
# Epoch 42/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.2598 - accuracy: 0.8965 - precision: 0.8965 - recall: 0.8965 - auc: 0.9587 - f1_score: 0.8965 - val_loss: 0.5499 - val_accuracy: 0.8172 - val_precision: 0.8172 - val_recall: 0.8172 - val_auc: 0.8451 - val_f1_score: 0.8172 - lr: 0.0010
# Epoch 43/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.2991 - accuracy: 0.8760 - precision: 0.8760 - recall: 0.8760 - auc: 0.9450 - f1_score: 0.8760 - val_loss: 0.3245 - val_accuracy: 0.8517 - val_precision: 0.8517 - val_recall: 0.8517 - val_auc: 0.9413 - val_f1_score: 0.8517 - lr: 0.0010
# Epoch 44/100
# 61/61 [==============================] - 23s 377ms/step - loss: 0.2640 - accuracy: 0.8919 - precision: 0.8919 - recall: 0.8919 - auc: 0.9576 - f1_score: 0.8919 - val_loss: 0.3904 - val_accuracy: 0.8552 - val_precision: 0.8552 - val_recall: 0.8552 - val_auc: 0.9151 - val_f1_score: 0.8552 - lr: 0.0010
# Epoch 45/100
# 61/61 [==============================] - 22s 364ms/step - loss: 0.2530 - accuracy: 0.8960 - precision: 0.8960 - recall: 0.8960 - auc: 0.9609 - f1_score: 0.8960 - val_loss: 0.2653 - val_accuracy: 0.8759 - val_precision: 0.8759 - val_recall: 0.8759 - val_auc: 0.9647 - val_f1_score: 0.8759 - lr: 0.0010
# Epoch 46/100
# 61/61 [==============================] - 23s 372ms/step - loss: 0.2523 - accuracy: 0.8965 - precision: 0.8965 - recall: 0.8965 - auc: 0.9614 - f1_score: 0.8965 - val_loss: 0.2992 - val_accuracy: 0.8724 - val_precision: 0.8724 - val_recall: 0.8724 - val_auc: 0.9500 - val_f1_score: 0.8724 - lr: 0.0010
# Epoch 47/100
# 61/61 [==============================] - 23s 371ms/step - loss: 0.2429 - accuracy: 0.9011 - precision: 0.9011 - recall: 0.9011 - auc: 0.9643 - f1_score: 0.9011 - val_loss: 0.4026 - val_accuracy: 0.8276 - val_precision: 0.8276 - val_recall: 0.8276 - val_auc: 0.9056 - val_f1_score: 0.8276 - lr: 0.0010
# Epoch 48/100
# 61/61 [==============================] - 23s 371ms/step - loss: 0.2906 - accuracy: 0.8801 - precision: 0.8801 - recall: 0.8801 - auc: 0.9482 - f1_score: 0.8801 - val_loss: 0.4053 - val_accuracy: 0.8379 - val_precision: 0.8379 - val_recall: 0.8379 - val_auc: 0.9055 - val_f1_score: 0.8379 - lr: 0.0010
# Epoch 49/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.2310 - accuracy: 0.8991 - precision: 0.8991 - recall: 0.8991 - auc: 0.9680 - f1_score: 0.8991 - val_loss: 0.2959 - val_accuracy: 0.8621 - val_precision: 0.8621 - val_recall: 0.8621 - val_auc: 0.9448 - val_f1_score: 0.8621 - lr: 0.0010
# Epoch 50/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2393 - accuracy: 0.8929 - precision: 0.8929 - recall: 0.8929 - auc: 0.9652 - f1_score: 0.8929
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 61/61 [==============================] - 22s 367ms/step - loss: 0.2393 - accuracy: 0.8929 - precision: 0.8929 - recall: 0.8929 - auc: 0.9652 - f1_score: 0.8929 - val_loss: 0.2704 - val_accuracy: 0.8690 - val_precision: 0.8690 - val_recall: 0.8690 - val_auc: 0.9571 - val_f1_score: 0.8690 - lr: 0.0010
# Epoch 51/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.1897 - accuracy: 0.9237 - precision: 0.9237 - recall: 0.9237 - auc: 0.9794 - f1_score: 0.9237 - val_loss: 0.3025 - val_accuracy: 0.8552 - val_precision: 0.8552 - val_recall: 0.8552 - val_auc: 0.9429 - val_f1_score: 0.8552 - lr: 1.0000e-04
# Epoch 52/100
# 61/61 [==============================] - 23s 372ms/step - loss: 0.1767 - accuracy: 0.9283 - precision: 0.9283 - recall: 0.9283 - auc: 0.9821 - f1_score: 0.9283 - val_loss: 0.3386 - val_accuracy: 0.8414 - val_precision: 0.8414 - val_recall: 0.8414 - val_auc: 0.9297 - val_f1_score: 0.8414 - lr: 1.0000e-04
# Epoch 53/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.1729 - accuracy: 0.9314 - precision: 0.9314 - recall: 0.9314 - auc: 0.9829 - f1_score: 0.9314 - val_loss: 0.3891 - val_accuracy: 0.8241 - val_precision: 0.8241 - val_recall: 0.8241 - val_auc: 0.9099 - val_f1_score: 0.8241 - lr: 1.0000e-04
# Epoch 54/100
# 61/61 [==============================] - 23s 376ms/step - loss: 0.1701 - accuracy: 0.9283 - precision: 0.9283 - recall: 0.9283 - auc: 0.9830 - f1_score: 0.9283 - val_loss: 0.3277 - val_accuracy: 0.8655 - val_precision: 0.8655 - val_recall: 0.8655 - val_auc: 0.9340 - val_f1_score: 0.8655 - lr: 1.0000e-04
# Epoch 55/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.1739 - accuracy: 0.9288 - precision: 0.9288 - recall: 0.9288 - auc: 0.9821 - f1_score: 0.9288 - val_loss: 0.3593 - val_accuracy: 0.8517 - val_precision: 0.8517 - val_recall: 0.8517 - val_auc: 0.9237 - val_f1_score: 0.8517 - lr: 1.0000e-04
# Epoch 56/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.1588 - accuracy: 0.9329 - precision: 0.9329 - recall: 0.9329 - auc: 0.9854 - f1_score: 0.9329 - val_loss: 0.3909 - val_accuracy: 0.8448 - val_precision: 0.8448 - val_recall: 0.8448 - val_auc: 0.9150 - val_f1_score: 0.8448 - lr: 1.0000e-04
# Epoch 57/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.1578 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9853 - f1_score: 0.9355 - val_loss: 0.4438 - val_accuracy: 0.8103 - val_precision: 0.8103 - val_recall: 0.8103 - val_auc: 0.8974 - val_f1_score: 0.8103 - lr: 1.0000e-04
# Epoch 58/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.1572 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9854 - f1_score: 0.9319 - val_loss: 0.4528 - val_accuracy: 0.8138 - val_precision: 0.8138 - val_recall: 0.8138 - val_auc: 0.8923 - val_f1_score: 0.8138 - lr: 1.0000e-04
# Epoch 59/100
# 61/61 [==============================] - 23s 373ms/step - loss: 0.1523 - accuracy: 0.9370 - precision: 0.9370 - recall: 0.9370 - auc: 0.9864 - f1_score: 0.9370 - val_loss: 0.4638 - val_accuracy: 0.7862 - val_precision: 0.7862 - val_recall: 0.7862 - val_auc: 0.8859 - val_f1_score: 0.7862 - lr: 1.0000e-04
# Epoch 60/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9370 - precision: 0.9370 - recall: 0.9370 - auc: 0.9859 - f1_score: 0.9370
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 61/61 [==============================] - 22s 367ms/step - loss: 0.1545 - accuracy: 0.9370 - precision: 0.9370 - recall: 0.9370 - auc: 0.9859 - f1_score: 0.9370 - val_loss: 0.4263 - val_accuracy: 0.7966 - val_precision: 0.7966 - val_recall: 0.7966 - val_auc: 0.9018 - val_f1_score: 0.7966 - lr: 1.0000e-04
# Epoch 61/100
# 61/61 [==============================] - 23s 377ms/step - loss: 0.1449 - accuracy: 0.9380 - precision: 0.9380 - recall: 0.9380 - auc: 0.9879 - f1_score: 0.9380 - val_loss: 0.4132 - val_accuracy: 0.8138 - val_precision: 0.8138 - val_recall: 0.8138 - val_auc: 0.9055 - val_f1_score: 0.8138 - lr: 1.0000e-05
# Epoch 62/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.1467 - accuracy: 0.9344 - precision: 0.9344 - recall: 0.9344 - auc: 0.9873 - f1_score: 0.9344 - val_loss: 0.4186 - val_accuracy: 0.8207 - val_precision: 0.8207 - val_recall: 0.8207 - val_auc: 0.9046 - val_f1_score: 0.8207 - lr: 1.0000e-05
# Epoch 63/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.1421 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9884 - f1_score: 0.9390 - val_loss: 0.3991 - val_accuracy: 0.8276 - val_precision: 0.8276 - val_recall: 0.8276 - val_auc: 0.9120 - val_f1_score: 0.8276 - lr: 1.0000e-05
# Epoch 64/100
# 61/61 [==============================] - 23s 374ms/step - loss: 0.1440 - accuracy: 0.9385 - precision: 0.9385 - recall: 0.9385 - auc: 0.9880 - f1_score: 0.9385 - val_loss: 0.4030 - val_accuracy: 0.8000 - val_precision: 0.8000 - val_recall: 0.8000 - val_auc: 0.9110 - val_f1_score: 0.8000 - lr: 1.0000e-05
# Epoch 65/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.1426 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9882 - f1_score: 0.9390 - val_loss: 0.4115 - val_accuracy: 0.8138 - val_precision: 0.8138 - val_recall: 0.8138 - val_auc: 0.9082 - val_f1_score: 0.8138 - lr: 1.0000e-05
# Epoch 66/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.1425 - accuracy: 0.9360 - precision: 0.9360 - recall: 0.9360 - auc: 0.9883 - f1_score: 0.9360 - val_loss: 0.4167 - val_accuracy: 0.8310 - val_precision: 0.8310 - val_recall: 0.8310 - val_auc: 0.9072 - val_f1_score: 0.8310 - lr: 1.0000e-05
# Epoch 67/100
# 61/61 [==============================] - 23s 372ms/step - loss: 0.1429 - accuracy: 0.9416 - precision: 0.9416 - recall: 0.9416 - auc: 0.9882 - f1_score: 0.9416 - val_loss: 0.4165 - val_accuracy: 0.8345 - val_precision: 0.8345 - val_recall: 0.8345 - val_auc: 0.9076 - val_f1_score: 0.8345 - lr: 1.0000e-05
# Epoch 68/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.1435 - accuracy: 0.9406 - precision: 0.9406 - recall: 0.9406 - auc: 0.9880 - f1_score: 0.9406 - val_loss: 0.4122 - val_accuracy: 0.8310 - val_precision: 0.8310 - val_recall: 0.8310 - val_auc: 0.9089 - val_f1_score: 0.8310 - lr: 1.0000e-05
# Epoch 69/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.1425 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9881 - f1_score: 0.9390 - val_loss: 0.4176 - val_accuracy: 0.8172 - val_precision: 0.8172 - val_recall: 0.8172 - val_auc: 0.9068 - val_f1_score: 0.8172 - lr: 1.0000e-05
# Epoch 70/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1409 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9886 - f1_score: 0.9355
# Epoch 70: ReduceLROnPlateau reducing learning rate to 1e-05.
# 61/61 [==============================] - 22s 365ms/step - loss: 0.1409 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9886 - f1_score: 0.9355 - val_loss: 0.4146 - val_accuracy: 0.8345 - val_precision: 0.8345 - val_recall: 0.8345 - val_auc: 0.9087 - val_f1_score: 0.8345 - lr: 1.0000e-05
# Epoch 71/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.1447 - accuracy: 0.9385 - precision: 0.9385 - recall: 0.9385 - auc: 0.9877 - f1_score: 0.9385 - val_loss: 0.4099 - val_accuracy: 0.8207 - val_precision: 0.8207 - val_recall: 0.8207 - val_auc: 0.9098 - val_f1_score: 0.8207 - lr: 1.0000e-05
# Epoch 72/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.1409 - accuracy: 0.9431 - precision: 0.9431 - recall: 0.9431 - auc: 0.9885 - f1_score: 0.9431 - val_loss: 0.4354 - val_accuracy: 0.8103 - val_precision: 0.8103 - val_recall: 0.8103 - val_auc: 0.9043 - val_f1_score: 0.8103 - lr: 1.0000e-05
# Epoch 73/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.1433 - accuracy: 0.9344 - precision: 0.9344 - recall: 0.9344 - auc: 0.9880 - f1_score: 0.9344 - val_loss: 0.4156 - val_accuracy: 0.8207 - val_precision: 0.8207 - val_recall: 0.8207 - val_auc: 0.9090 - val_f1_score: 0.8207 - lr: 1.0000e-05
# Epoch 74/100
# 61/61 [==============================] - 22s 363ms/step - loss: 0.1410 - accuracy: 0.9401 - precision: 0.9401 - recall: 0.9401 - auc: 0.9884 - f1_score: 0.9401 - val_loss: 0.4194 - val_accuracy: 0.8241 - val_precision: 0.8241 - val_recall: 0.8241 - val_auc: 0.9067 - val_f1_score: 0.8241 - lr: 1.0000e-05
# Epoch 75/100
# 61/61 [==============================] - 23s 373ms/step - loss: 0.1358 - accuracy: 0.9447 - precision: 0.9447 - recall: 0.9447 - auc: 0.9895 - f1_score: 0.9447 - val_loss: 0.4447 - val_accuracy: 0.8276 - val_precision: 0.8276 - val_recall: 0.8276 - val_auc: 0.8979 - val_f1_score: 0.8276 - lr: 1.0000e-05
# Epoch 76/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.1467 - accuracy: 0.9349 - precision: 0.9349 - recall: 0.9349 - auc: 0.9873 - f1_score: 0.9349 - val_loss: 0.4210 - val_accuracy: 0.8483 - val_precision: 0.8483 - val_recall: 0.8483 - val_auc: 0.9074 - val_f1_score: 0.8483 - lr: 1.0000e-05
# Epoch 77/100
# 61/61 [==============================] - 22s 363ms/step - loss: 0.1418 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9883 - f1_score: 0.9390 - val_loss: 0.4312 - val_accuracy: 0.8207 - val_precision: 0.8207 - val_recall: 0.8207 - val_auc: 0.9023 - val_f1_score: 0.8207 - lr: 1.0000e-05
# Epoch 78/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.1403 - accuracy: 0.9360 - precision: 0.9360 - recall: 0.9360 - auc: 0.9886 - f1_score: 0.9360 - val_loss: 0.4618 - val_accuracy: 0.8172 - val_precision: 0.8172 - val_recall: 0.8172 - val_auc: 0.8957 - val_f1_score: 0.8172 - lr: 1.0000e-05
# Epoch 79/100
# 61/61 [==============================] - 22s 363ms/step - loss: 0.1412 - accuracy: 0.9385 - precision: 0.9385 - recall: 0.9385 - auc: 0.9884 - f1_score: 0.9385 - val_loss: 0.4448 - val_accuracy: 0.8345 - val_precision: 0.8345 - val_recall: 0.8345 - val_auc: 0.8998 - val_f1_score: 0.8345 - lr: 1.0000e-05
# Epoch 80/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.1430 - accuracy: 0.9395 - precision: 0.9395 - recall: 0.9395 - auc: 0.9881 - f1_score: 0.9395 - val_loss: 0.4176 - val_accuracy: 0.8207 - val_precision: 0.8207 - val_recall: 0.8207 - val_auc: 0.9080 - val_f1_score: 0.8207 - lr: 1.0000e-05
# Epoch 81/100
# 61/61 [==============================] - 22s 363ms/step - loss: 0.1409 - accuracy: 0.9411 - precision: 0.9411 - recall: 0.9411 - auc: 0.9885 - f1_score: 0.9411 - val_loss: 0.4245 - val_accuracy: 0.8172 - val_precision: 0.8172 - val_recall: 0.8172 - val_auc: 0.9063 - val_f1_score: 0.8172 - lr: 1.0000e-05
# Epoch 82/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.1411 - accuracy: 0.9380 - precision: 0.9380 - recall: 0.9380 - auc: 0.9883 - f1_score: 0.9380 - val_loss: 0.4472 - val_accuracy: 0.8138 - val_precision: 0.8138 - val_recall: 0.8138 - val_auc: 0.8980 - val_f1_score: 0.8138 - lr: 1.0000e-05
# Epoch 83/100
# 61/61 [==============================] - 22s 364ms/step - loss: 0.1367 - accuracy: 0.9406 - precision: 0.9406 - recall: 0.9406 - auc: 0.9893 - f1_score: 0.9406 - val_loss: 0.4280 - val_accuracy: 0.8276 - val_precision: 0.8276 - val_recall: 0.8276 - val_auc: 0.9053 - val_f1_score: 0.8276 - lr: 1.0000e-05
# Epoch 84/100
# 61/61 [==============================] - 22s 363ms/step - loss: 0.1407 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9884 - f1_score: 0.9390 - val_loss: 0.3877 - val_accuracy: 0.8414 - val_precision: 0.8414 - val_recall: 0.8414 - val_auc: 0.9184 - val_f1_score: 0.8414 - lr: 1.0000e-05
# Epoch 85/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.1382 - accuracy: 0.9447 - precision: 0.9447 - recall: 0.9447 - auc: 0.9889 - f1_score: 0.9447 - val_loss: 0.4046 - val_accuracy: 0.8207 - val_precision: 0.8207 - val_recall: 0.8207 - val_auc: 0.9127 - val_f1_score: 0.8207 - lr: 1.0000e-05
# Epoch 86/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.1383 - accuracy: 0.9401 - precision: 0.9401 - recall: 0.9401 - auc: 0.9886 - f1_score: 0.9401 - val_loss: 0.4343 - val_accuracy: 0.8207 - val_precision: 0.8207 - val_recall: 0.8207 - val_auc: 0.9010 - val_f1_score: 0.8207 - lr: 1.0000e-05
# Epoch 87/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.1355 - accuracy: 0.9431 - precision: 0.9431 - recall: 0.9431 - auc: 0.9895 - f1_score: 0.9431 - val_loss: 0.4267 - val_accuracy: 0.8172 - val_precision: 0.8172 - val_recall: 0.8172 - val_auc: 0.9065 - val_f1_score: 0.8172 - lr: 1.0000e-05
# Epoch 88/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.1369 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9892 - f1_score: 0.9421 - val_loss: 0.3951 - val_accuracy: 0.8207 - val_precision: 0.8207 - val_recall: 0.8207 - val_auc: 0.9138 - val_f1_score: 0.8207 - lr: 1.0000e-05
# Epoch 89/100
# 61/61 [==============================] - 23s 371ms/step - loss: 0.1412 - accuracy: 0.9395 - precision: 0.9395 - recall: 0.9395 - auc: 0.9883 - f1_score: 0.9395 - val_loss: 0.4280 - val_accuracy: 0.8310 - val_precision: 0.8310 - val_recall: 0.8310 - val_auc: 0.9078 - val_f1_score: 0.8310 - lr: 1.0000e-05
# Epoch 90/100
# 61/61 [==============================] - 22s 364ms/step - loss: 0.1388 - accuracy: 0.9380 - precision: 0.9380 - recall: 0.9380 - auc: 0.9887 - f1_score: 0.9380 - val_loss: 0.4218 - val_accuracy: 0.8207 - val_precision: 0.8207 - val_recall: 0.8207 - val_auc: 0.9071 - val_f1_score: 0.8207 - lr: 1.0000e-05
# Epoch 91/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.1386 - accuracy: 0.9411 - precision: 0.9411 - recall: 0.9411 - auc: 0.9887 - f1_score: 0.9411 - val_loss: 0.4119 - val_accuracy: 0.8207 - val_precision: 0.8207 - val_recall: 0.8207 - val_auc: 0.9101 - val_f1_score: 0.8207 - lr: 1.0000e-05
# Epoch 92/100
# 61/61 [==============================] - 23s 373ms/step - loss: 0.1410 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9884 - f1_score: 0.9390 - val_loss: 0.4079 - val_accuracy: 0.8276 - val_precision: 0.8276 - val_recall: 0.8276 - val_auc: 0.9114 - val_f1_score: 0.8276 - lr: 1.0000e-05
# Epoch 93/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.1396 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9885 - f1_score: 0.9390 - val_loss: 0.4456 - val_accuracy: 0.8138 - val_precision: 0.8138 - val_recall: 0.8138 - val_auc: 0.8981 - val_f1_score: 0.8138 - lr: 1.0000e-05
# Epoch 94/100
# 61/61 [==============================] - 22s 361ms/step - loss: 0.1416 - accuracy: 0.9385 - precision: 0.9385 - recall: 0.9385 - auc: 0.9881 - f1_score: 0.9385 - val_loss: 0.4458 - val_accuracy: 0.8241 - val_precision: 0.8241 - val_recall: 0.8241 - val_auc: 0.9006 - val_f1_score: 0.8241 - lr: 1.0000e-05
# Epoch 95/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.1349 - accuracy: 0.9426 - precision: 0.9426 - recall: 0.9426 - auc: 0.9897 - f1_score: 0.9426 - val_loss: 0.4435 - val_accuracy: 0.8241 - val_precision: 0.8241 - val_recall: 0.8241 - val_auc: 0.9022 - val_f1_score: 0.8241 - lr: 1.0000e-05
# Epoch 96/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.1383 - accuracy: 0.9442 - precision: 0.9442 - recall: 0.9442 - auc: 0.9888 - f1_score: 0.9442 - val_loss: 0.4363 - val_accuracy: 0.8103 - val_precision: 0.8103 - val_recall: 0.8103 - val_auc: 0.9025 - val_f1_score: 0.8103 - lr: 1.0000e-05
# Epoch 97/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.1373 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9890 - f1_score: 0.9390 - val_loss: 0.4535 - val_accuracy: 0.8345 - val_precision: 0.8345 - val_recall: 0.8345 - val_auc: 0.9002 - val_f1_score: 0.8345 - lr: 1.0000e-05
# Epoch 98/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.1387 - accuracy: 0.9411 - precision: 0.9411 - recall: 0.9411 - auc: 0.9887 - f1_score: 0.9411 - val_loss: 0.4441 - val_accuracy: 0.8276 - val_precision: 0.8276 - val_recall: 0.8276 - val_auc: 0.9016 - val_f1_score: 0.8276 - lr: 1.0000e-05
# Epoch 99/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.1323 - accuracy: 0.9426 - precision: 0.9426 - recall: 0.9426 - auc: 0.9899 - f1_score: 0.9426 - val_loss: 0.4628 - val_accuracy: 0.8172 - val_precision: 0.8172 - val_recall: 0.8172 - val_auc: 0.8966 - val_f1_score: 0.8172 - lr: 1.0000e-05
# Epoch 100/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.1361 - accuracy: 0.9406 - precision: 0.9406 - recall: 0.9406 - auc: 0.9894 - f1_score: 0.9406 - val_loss: 0.4191 - val_accuracy: 0.8241 - val_precision: 0.8241 - val_recall: 0.8241 - val_auc: 0.9073 - val_f1_score: 0.8241 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 0s 14ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9145031575538404
# F1-Score for each class: [0.88659794 0.94240838]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9090909090909091
# specificity: 0.9555555555555556

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 14ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 1s 83ms/step - loss: 0.2050 - accuracy: 0.9203 - precision: 0.9203 - recall: 0.9203 - auc: 0.9757 - f1_score: 0.9203
# Test loss: 0.20497164130210876
# Test accuracy: 0.920265793800354
# Test precision: 0.920265793800354
# Test recall: 0.920265793800354
# Test AUC: 0.9756680130958557
# Test F1 Score: 0.920265793800354

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89        90
#            1       0.98      0.91      0.94       198
#
#     accuracy                           0.92       288
#    macro avg       0.90      0.93      0.91       288
# weighted avg       0.93      0.92      0.92       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()

# %% [markdown]
# <h1>400X training</h1>

# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/BCResize/400X/test'
train_dir = '/root/BreastCancer/BCResize/400X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/BCResize/400X/train/malignant'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1782 images belonging to 2 classes.
# Found 266 images belonging to 2 classes.
# Found 272 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Concatenate, Flatten, Dense

def inception_block(x, filters):
    conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(x)

    conv3x3 = Conv2D(filters[1], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv3x3)

    conv5x5 = Conv2D(filters[3], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv5x5)

    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    maxpool = Conv2D(filters[5], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(maxpool)

    inception_block = Concatenate(axis=-1)([conv1x1, conv3x3, conv5x5, maxpool])
    return inception_block

def inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer = 'he_normal')(input_tensor)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception blocks
    x = inception_block(x, filters=[64, 128, 128, 32, 96, 32])
    x = inception_block(x, filters=[128, 128, 96, 64, 64, 64])

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=x)

    return model


# Create the InceptionNet model
model = inception_net(input_shape, num_classes)

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  8320        ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 128)  147584      ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 96)   76896       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 320)  0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 128)  41088       ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 64)   20544       ['concatenate[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 320)  0          ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 128)  41088       ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 56, 96)   110688      ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 64)   102464      ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 64)   20544       ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 352)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 352)  0          ['concatenate_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 352)         0           ['max_pooling2d_3[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            706         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 587,714
# Trainable params: 587,714
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2023-12-24 15:50:53.091154: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 15:50:53.658024: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "InceptionNetResized400X_CalledTwice"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/1. InceptionNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-24 15:51:11.752623: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-24 15:51:13.168256: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 56/56 [==============================] - 26s 393ms/step - loss: 0.6842 - accuracy: 0.6801 - precision: 0.6801 - recall: 0.6801 - auc: 0.7186 - f1_score: 0.6801 - val_loss: 0.4937 - val_accuracy: 0.7857 - val_precision: 0.7857 - val_recall: 0.7857 - val_auc: 0.8785 - val_f1_score: 0.7857 - lr: 0.0010
# Epoch 2/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.5323 - accuracy: 0.7486 - precision: 0.7486 - recall: 0.7486 - auc: 0.8131 - f1_score: 0.7486 - val_loss: 0.4227 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9145 - val_f1_score: 0.8421 - lr: 0.0010
# Epoch 3/100
# 56/56 [==============================] - 21s 373ms/step - loss: 0.4938 - accuracy: 0.7755 - precision: 0.7755 - recall: 0.7755 - auc: 0.8423 - f1_score: 0.7755 - val_loss: 0.5643 - val_accuracy: 0.6617 - val_precision: 0.6617 - val_recall: 0.6617 - val_auc: 0.7702 - val_f1_score: 0.6617 - lr: 0.0010
# Epoch 4/100
# 56/56 [==============================] - 21s 374ms/step - loss: 0.4707 - accuracy: 0.7890 - precision: 0.7890 - recall: 0.7890 - auc: 0.8589 - f1_score: 0.7890 - val_loss: 0.4079 - val_accuracy: 0.8195 - val_precision: 0.8195 - val_recall: 0.8195 - val_auc: 0.9088 - val_f1_score: 0.8195 - lr: 0.0010
# Epoch 5/100
# 56/56 [==============================] - 21s 373ms/step - loss: 0.4669 - accuracy: 0.7890 - precision: 0.7890 - recall: 0.7890 - auc: 0.8605 - f1_score: 0.7890 - val_loss: 0.5093 - val_accuracy: 0.7669 - val_precision: 0.7669 - val_recall: 0.7669 - val_auc: 0.8490 - val_f1_score: 0.7669 - lr: 0.0010
# Epoch 6/100
# 56/56 [==============================] - 21s 373ms/step - loss: 0.4535 - accuracy: 0.7969 - precision: 0.7969 - recall: 0.7969 - auc: 0.8700 - f1_score: 0.7969 - val_loss: 0.5309 - val_accuracy: 0.7594 - val_precision: 0.7594 - val_recall: 0.7594 - val_auc: 0.8303 - val_f1_score: 0.7594 - lr: 0.0010
# Epoch 7/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.4262 - accuracy: 0.8075 - precision: 0.8075 - recall: 0.8075 - auc: 0.8849 - f1_score: 0.8075 - val_loss: 0.3906 - val_accuracy: 0.8308 - val_precision: 0.8308 - val_recall: 0.8308 - val_auc: 0.9255 - val_f1_score: 0.8308 - lr: 0.0010
# Epoch 8/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.4271 - accuracy: 0.8176 - precision: 0.8176 - recall: 0.8176 - auc: 0.8853 - f1_score: 0.8176 - val_loss: 0.9647 - val_accuracy: 0.7519 - val_precision: 0.7519 - val_recall: 0.7519 - val_auc: 0.7277 - val_f1_score: 0.7519 - lr: 0.0010
# Epoch 9/100
# 56/56 [==============================] - 21s 376ms/step - loss: 0.4225 - accuracy: 0.8199 - precision: 0.8199 - recall: 0.8199 - auc: 0.8875 - f1_score: 0.8199 - val_loss: 0.3442 - val_accuracy: 0.9060 - val_precision: 0.9060 - val_recall: 0.9060 - val_auc: 0.9662 - val_f1_score: 0.9060 - lr: 0.0010
# Epoch 10/100
# 56/56 [==============================] - 21s 370ms/step - loss: 0.4370 - accuracy: 0.8103 - precision: 0.8103 - recall: 0.8103 - auc: 0.8792 - f1_score: 0.8103 - val_loss: 0.8173 - val_accuracy: 0.5639 - val_precision: 0.5639 - val_recall: 0.5639 - val_auc: 0.6824 - val_f1_score: 0.5639 - lr: 0.0010
# Epoch 11/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.4796 - accuracy: 0.7789 - precision: 0.7789 - recall: 0.7789 - auc: 0.8568 - f1_score: 0.7789 - val_loss: 0.5524 - val_accuracy: 0.7444 - val_precision: 0.7444 - val_recall: 0.7444 - val_auc: 0.8136 - val_f1_score: 0.7444 - lr: 0.0010
# Epoch 12/100
# 56/56 [==============================] - 21s 375ms/step - loss: 0.4284 - accuracy: 0.8131 - precision: 0.8131 - recall: 0.8131 - auc: 0.8850 - f1_score: 0.8131 - val_loss: 0.5374 - val_accuracy: 0.8045 - val_precision: 0.8045 - val_recall: 0.8045 - val_auc: 0.8522 - val_f1_score: 0.8045 - lr: 0.0010
# Epoch 13/100
# 56/56 [==============================] - 21s 370ms/step - loss: 0.4273 - accuracy: 0.8148 - precision: 0.8148 - recall: 0.8148 - auc: 0.8849 - f1_score: 0.8148 - val_loss: 0.4810 - val_accuracy: 0.8120 - val_precision: 0.8120 - val_recall: 0.8120 - val_auc: 0.8704 - val_f1_score: 0.8120 - lr: 0.0010
# Epoch 14/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.4246 - accuracy: 0.8165 - precision: 0.8165 - recall: 0.8165 - auc: 0.8868 - f1_score: 0.8165 - val_loss: 0.8094 - val_accuracy: 0.7556 - val_precision: 0.7556 - val_recall: 0.7556 - val_auc: 0.7437 - val_f1_score: 0.7556 - lr: 0.0010
# Epoch 15/100
# 56/56 [==============================] - 21s 370ms/step - loss: 0.4359 - accuracy: 0.8025 - precision: 0.8025 - recall: 0.8025 - auc: 0.8782 - f1_score: 0.8025 - val_loss: 0.8037 - val_accuracy: 0.8008 - val_precision: 0.8008 - val_recall: 0.8008 - val_auc: 0.7877 - val_f1_score: 0.8008 - lr: 0.0010
# Epoch 16/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.3955 - accuracy: 0.8333 - precision: 0.8333 - recall: 0.8333 - auc: 0.9028 - f1_score: 0.8333 - val_loss: 0.5338 - val_accuracy: 0.8195 - val_precision: 0.8195 - val_recall: 0.8195 - val_auc: 0.8514 - val_f1_score: 0.8195 - lr: 0.0010
# Epoch 17/100
# 56/56 [==============================] - 21s 377ms/step - loss: 0.4174 - accuracy: 0.8182 - precision: 0.8182 - recall: 0.8182 - auc: 0.8909 - f1_score: 0.8182 - val_loss: 0.7246 - val_accuracy: 0.7707 - val_precision: 0.7707 - val_recall: 0.7707 - val_auc: 0.7892 - val_f1_score: 0.7707 - lr: 0.0010
# Epoch 18/100
# 56/56 [==============================] - 21s 379ms/step - loss: 0.3875 - accuracy: 0.8418 - precision: 0.8418 - recall: 0.8418 - auc: 0.9051 - f1_score: 0.8418 - val_loss: 0.3931 - val_accuracy: 0.8421 - val_precision: 0.8421 - val_recall: 0.8421 - val_auc: 0.9184 - val_f1_score: 0.8421 - lr: 0.0010
# Epoch 19/100
# 56/56 [==============================] - ETA: 0s - loss: 0.3875 - accuracy: 0.8440 - precision: 0.8440 - recall: 0.8440 - auc: 0.9061 - f1_score: 0.8440
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 56/56 [==============================] - 21s 370ms/step - loss: 0.3875 - accuracy: 0.8440 - precision: 0.8440 - recall: 0.8440 - auc: 0.9061 - f1_score: 0.8440 - val_loss: 0.3653 - val_accuracy: 0.8835 - val_precision: 0.8835 - val_recall: 0.8835 - val_auc: 0.9334 - val_f1_score: 0.8835 - lr: 0.0010
# Epoch 20/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.3665 - accuracy: 0.8412 - precision: 0.8412 - recall: 0.8412 - auc: 0.9164 - f1_score: 0.8412 - val_loss: 0.5513 - val_accuracy: 0.8158 - val_precision: 0.8158 - val_recall: 0.8158 - val_auc: 0.8580 - val_f1_score: 0.8158 - lr: 1.0000e-04
# Epoch 21/100
# 56/56 [==============================] - 21s 368ms/step - loss: 0.3529 - accuracy: 0.8519 - precision: 0.8519 - recall: 0.8519 - auc: 0.9231 - f1_score: 0.8519 - val_loss: 0.7739 - val_accuracy: 0.7632 - val_precision: 0.7632 - val_recall: 0.7632 - val_auc: 0.7916 - val_f1_score: 0.7632 - lr: 1.0000e-04
# Epoch 22/100
# 56/56 [==============================] - 20s 361ms/step - loss: 0.3506 - accuracy: 0.8479 - precision: 0.8479 - recall: 0.8479 - auc: 0.9244 - f1_score: 0.8479 - val_loss: 0.8946 - val_accuracy: 0.7180 - val_precision: 0.7180 - val_recall: 0.7180 - val_auc: 0.7508 - val_f1_score: 0.7180 - lr: 1.0000e-04
# Epoch 23/100
# 56/56 [==============================] - 21s 379ms/step - loss: 0.3470 - accuracy: 0.8502 - precision: 0.8502 - recall: 0.8502 - auc: 0.9260 - f1_score: 0.8502 - val_loss: 0.7660 - val_accuracy: 0.7744 - val_precision: 0.7744 - val_recall: 0.7744 - val_auc: 0.7886 - val_f1_score: 0.7744 - lr: 1.0000e-04
# Epoch 24/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.3419 - accuracy: 0.8547 - precision: 0.8547 - recall: 0.8547 - auc: 0.9281 - f1_score: 0.8547 - val_loss: 1.1867 - val_accuracy: 0.7143 - val_precision: 0.7143 - val_recall: 0.7143 - val_auc: 0.7053 - val_f1_score: 0.7143 - lr: 1.0000e-04
# Epoch 25/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.3418 - accuracy: 0.8524 - precision: 0.8524 - recall: 0.8524 - auc: 0.9286 - f1_score: 0.8524 - val_loss: 1.0769 - val_accuracy: 0.7256 - val_precision: 0.7256 - val_recall: 0.7256 - val_auc: 0.7145 - val_f1_score: 0.7256 - lr: 1.0000e-04
# Epoch 26/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.3348 - accuracy: 0.8586 - precision: 0.8586 - recall: 0.8586 - auc: 0.9309 - f1_score: 0.8586 - val_loss: 0.8053 - val_accuracy: 0.7782 - val_precision: 0.7782 - val_recall: 0.7782 - val_auc: 0.7879 - val_f1_score: 0.7782 - lr: 1.0000e-04
# Epoch 27/100
# 56/56 [==============================] - 21s 373ms/step - loss: 0.3350 - accuracy: 0.8603 - precision: 0.8603 - recall: 0.8603 - auc: 0.9321 - f1_score: 0.8603 - val_loss: 1.1271 - val_accuracy: 0.7068 - val_precision: 0.7068 - val_recall: 0.7068 - val_auc: 0.7021 - val_f1_score: 0.7068 - lr: 1.0000e-04
# Epoch 28/100
# 56/56 [==============================] - 21s 376ms/step - loss: 0.3288 - accuracy: 0.8558 - precision: 0.8558 - recall: 0.8558 - auc: 0.9344 - f1_score: 0.8558 - val_loss: 1.1021 - val_accuracy: 0.7218 - val_precision: 0.7218 - val_recall: 0.7218 - val_auc: 0.7253 - val_f1_score: 0.7218 - lr: 1.0000e-04
# Epoch 29/100
# 56/56 [==============================] - ETA: 0s - loss: 0.3264 - accuracy: 0.8631 - precision: 0.8631 - recall: 0.8631 - auc: 0.9350 - f1_score: 0.8631
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 56/56 [==============================] - 21s 366ms/step - loss: 0.3264 - accuracy: 0.8631 - precision: 0.8631 - recall: 0.8631 - auc: 0.9350 - f1_score: 0.8631 - val_loss: 1.1560 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_auc: 0.6975 - val_f1_score: 0.6917 - lr: 1.0000e-04
# Epoch 30/100
# 56/56 [==============================] - 21s 373ms/step - loss: 0.3123 - accuracy: 0.8726 - precision: 0.8726 - recall: 0.8726 - auc: 0.9423 - f1_score: 0.8726 - val_loss: 1.0872 - val_accuracy: 0.6880 - val_precision: 0.6880 - val_recall: 0.6880 - val_auc: 0.7087 - val_f1_score: 0.6880 - lr: 1.0000e-05
# Epoch 31/100
# 56/56 [==============================] - 21s 368ms/step - loss: 0.3156 - accuracy: 0.8670 - precision: 0.8670 - recall: 0.8670 - auc: 0.9400 - f1_score: 0.8670 - val_loss: 1.1171 - val_accuracy: 0.7143 - val_precision: 0.7143 - val_recall: 0.7143 - val_auc: 0.7150 - val_f1_score: 0.7143 - lr: 1.0000e-05
# Epoch 32/100
# 56/56 [==============================] - 21s 381ms/step - loss: 0.3115 - accuracy: 0.8692 - precision: 0.8692 - recall: 0.8692 - auc: 0.9412 - f1_score: 0.8692 - val_loss: 1.1253 - val_accuracy: 0.7143 - val_precision: 0.7143 - val_recall: 0.7143 - val_auc: 0.7203 - val_f1_score: 0.7143 - lr: 1.0000e-05
# Epoch 33/100
# 56/56 [==============================] - 20s 365ms/step - loss: 0.3135 - accuracy: 0.8760 - precision: 0.8760 - recall: 0.8760 - auc: 0.9413 - f1_score: 0.8760 - val_loss: 1.1766 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_auc: 0.7027 - val_f1_score: 0.6917 - lr: 1.0000e-05
# Epoch 34/100
# 56/56 [==============================] - 21s 377ms/step - loss: 0.3136 - accuracy: 0.8704 - precision: 0.8704 - recall: 0.8704 - auc: 0.9406 - f1_score: 0.8704 - val_loss: 1.0486 - val_accuracy: 0.7030 - val_precision: 0.7030 - val_recall: 0.7030 - val_auc: 0.7181 - val_f1_score: 0.7030 - lr: 1.0000e-05
# Epoch 35/100
# 56/56 [==============================] - 21s 375ms/step - loss: 0.3122 - accuracy: 0.8687 - precision: 0.8687 - recall: 0.8687 - auc: 0.9414 - f1_score: 0.8687 - val_loss: 1.1948 - val_accuracy: 0.7143 - val_precision: 0.7143 - val_recall: 0.7143 - val_auc: 0.6988 - val_f1_score: 0.7143 - lr: 1.0000e-05
# Epoch 36/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.3102 - accuracy: 0.8726 - precision: 0.8726 - recall: 0.8726 - auc: 0.9421 - f1_score: 0.8726 - val_loss: 1.1637 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_auc: 0.7039 - val_f1_score: 0.6917 - lr: 1.0000e-05
# Epoch 37/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.3091 - accuracy: 0.8743 - precision: 0.8743 - recall: 0.8743 - auc: 0.9426 - f1_score: 0.8743 - val_loss: 1.1016 - val_accuracy: 0.7143 - val_precision: 0.7143 - val_recall: 0.7143 - val_auc: 0.7181 - val_f1_score: 0.7143 - lr: 1.0000e-05
# Epoch 38/100
# 56/56 [==============================] - 21s 375ms/step - loss: 0.3121 - accuracy: 0.8687 - precision: 0.8687 - recall: 0.8687 - auc: 0.9412 - f1_score: 0.8687 - val_loss: 1.1819 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_auc: 0.7033 - val_f1_score: 0.6992 - lr: 1.0000e-05
# Epoch 39/100
# 56/56 [==============================] - ETA: 0s - loss: 0.3108 - accuracy: 0.8715 - precision: 0.8715 - recall: 0.8715 - auc: 0.9420 - f1_score: 0.8715
# Epoch 39: ReduceLROnPlateau reducing learning rate to 1e-05.
# 56/56 [==============================] - 21s 368ms/step - loss: 0.3108 - accuracy: 0.8715 - precision: 0.8715 - recall: 0.8715 - auc: 0.9420 - f1_score: 0.8715 - val_loss: 1.0556 - val_accuracy: 0.7143 - val_precision: 0.7143 - val_recall: 0.7143 - val_auc: 0.7213 - val_f1_score: 0.7143 - lr: 1.0000e-05
# Epoch 40/100
# 56/56 [==============================] - 21s 375ms/step - loss: 0.3101 - accuracy: 0.8704 - precision: 0.8704 - recall: 0.8704 - auc: 0.9421 - f1_score: 0.8704 - val_loss: 1.1223 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_auc: 0.7138 - val_f1_score: 0.6917 - lr: 1.0000e-05
# Epoch 41/100
# 56/56 [==============================] - 21s 368ms/step - loss: 0.3059 - accuracy: 0.8698 - precision: 0.8698 - recall: 0.8698 - auc: 0.9440 - f1_score: 0.8698 - val_loss: 1.1253 - val_accuracy: 0.6880 - val_precision: 0.6880 - val_recall: 0.6880 - val_auc: 0.7037 - val_f1_score: 0.6880 - lr: 1.0000e-05
# Epoch 42/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.3054 - accuracy: 0.8715 - precision: 0.8715 - recall: 0.8715 - auc: 0.9443 - f1_score: 0.8715 - val_loss: 1.0927 - val_accuracy: 0.7068 - val_precision: 0.7068 - val_recall: 0.7068 - val_auc: 0.7135 - val_f1_score: 0.7068 - lr: 1.0000e-05
# Epoch 43/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.3095 - accuracy: 0.8709 - precision: 0.8709 - recall: 0.8709 - auc: 0.9425 - f1_score: 0.8709 - val_loss: 1.1380 - val_accuracy: 0.7030 - val_precision: 0.7030 - val_recall: 0.7030 - val_auc: 0.7199 - val_f1_score: 0.7030 - lr: 1.0000e-05
# Epoch 44/100
# 56/56 [==============================] - 21s 378ms/step - loss: 0.3069 - accuracy: 0.8805 - precision: 0.8805 - recall: 0.8805 - auc: 0.9436 - f1_score: 0.8805 - val_loss: 1.1268 - val_accuracy: 0.7180 - val_precision: 0.7180 - val_recall: 0.7180 - val_auc: 0.7212 - val_f1_score: 0.7180 - lr: 1.0000e-05
# Epoch 45/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.3031 - accuracy: 0.8782 - precision: 0.8782 - recall: 0.8782 - auc: 0.9453 - f1_score: 0.8782 - val_loss: 1.1265 - val_accuracy: 0.6805 - val_precision: 0.6805 - val_recall: 0.6805 - val_auc: 0.7019 - val_f1_score: 0.6805 - lr: 1.0000e-05
# Epoch 46/100
# 56/56 [==============================] - 21s 375ms/step - loss: 0.3059 - accuracy: 0.8765 - precision: 0.8765 - recall: 0.8765 - auc: 0.9439 - f1_score: 0.8765 - val_loss: 1.1578 - val_accuracy: 0.7068 - val_precision: 0.7068 - val_recall: 0.7068 - val_auc: 0.7094 - val_f1_score: 0.7068 - lr: 1.0000e-05
# Epoch 47/100
# 56/56 [==============================] - 21s 375ms/step - loss: 0.3048 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9448 - f1_score: 0.8793 - val_loss: 1.1572 - val_accuracy: 0.6955 - val_precision: 0.6955 - val_recall: 0.6955 - val_auc: 0.7039 - val_f1_score: 0.6955 - lr: 1.0000e-05
# Epoch 48/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.3046 - accuracy: 0.8771 - precision: 0.8771 - recall: 0.8771 - auc: 0.9452 - f1_score: 0.8771 - val_loss: 1.0825 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_auc: 0.7167 - val_f1_score: 0.6917 - lr: 1.0000e-05
# Epoch 49/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.3050 - accuracy: 0.8692 - precision: 0.8692 - recall: 0.8692 - auc: 0.9437 - f1_score: 0.8692 - val_loss: 1.1955 - val_accuracy: 0.6880 - val_precision: 0.6880 - val_recall: 0.6880 - val_auc: 0.6959 - val_f1_score: 0.6880 - lr: 1.0000e-05
# Epoch 50/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.3045 - accuracy: 0.8732 - precision: 0.8732 - recall: 0.8732 - auc: 0.9451 - f1_score: 0.8732 - val_loss: 1.0567 - val_accuracy: 0.7030 - val_precision: 0.7030 - val_recall: 0.7030 - val_auc: 0.7199 - val_f1_score: 0.7030 - lr: 1.0000e-05
# Epoch 51/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.3032 - accuracy: 0.8765 - precision: 0.8765 - recall: 0.8765 - auc: 0.9451 - f1_score: 0.8765 - val_loss: 1.0696 - val_accuracy: 0.7030 - val_precision: 0.7030 - val_recall: 0.7030 - val_auc: 0.7195 - val_f1_score: 0.7030 - lr: 1.0000e-05
# Epoch 52/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.3039 - accuracy: 0.8777 - precision: 0.8777 - recall: 0.8777 - auc: 0.9449 - f1_score: 0.8777 - val_loss: 1.1546 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_auc: 0.7103 - val_f1_score: 0.6917 - lr: 1.0000e-05
# Epoch 53/100
# 56/56 [==============================] - 21s 368ms/step - loss: 0.3025 - accuracy: 0.8844 - precision: 0.8844 - recall: 0.8844 - auc: 0.9454 - f1_score: 0.8844 - val_loss: 1.0935 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_auc: 0.7183 - val_f1_score: 0.6992 - lr: 1.0000e-05
# Epoch 54/100
# 56/56 [==============================] - 21s 374ms/step - loss: 0.3026 - accuracy: 0.8822 - precision: 0.8822 - recall: 0.8822 - auc: 0.9455 - f1_score: 0.8822 - val_loss: 1.0871 - val_accuracy: 0.7143 - val_precision: 0.7143 - val_recall: 0.7143 - val_auc: 0.7187 - val_f1_score: 0.7143 - lr: 1.0000e-05
# Epoch 55/100
# 56/56 [==============================] - 21s 370ms/step - loss: 0.3018 - accuracy: 0.8805 - precision: 0.8805 - recall: 0.8805 - auc: 0.9460 - f1_score: 0.8805 - val_loss: 1.0384 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_auc: 0.7309 - val_f1_score: 0.6917 - lr: 1.0000e-05
# Epoch 56/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.2999 - accuracy: 0.8782 - precision: 0.8782 - recall: 0.8782 - auc: 0.9463 - f1_score: 0.8782 - val_loss: 1.1473 - val_accuracy: 0.6880 - val_precision: 0.6880 - val_recall: 0.6880 - val_auc: 0.7062 - val_f1_score: 0.6880 - lr: 1.0000e-05
# Epoch 57/100
# 56/56 [==============================] - 21s 373ms/step - loss: 0.3006 - accuracy: 0.8777 - precision: 0.8777 - recall: 0.8777 - auc: 0.9465 - f1_score: 0.8777 - val_loss: 1.0793 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_auc: 0.7171 - val_f1_score: 0.6992 - lr: 1.0000e-05
# Epoch 58/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.2983 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9467 - f1_score: 0.8793 - val_loss: 1.1089 - val_accuracy: 0.7030 - val_precision: 0.7030 - val_recall: 0.7030 - val_auc: 0.7244 - val_f1_score: 0.7030 - lr: 1.0000e-05
# Epoch 59/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.2992 - accuracy: 0.8816 - precision: 0.8816 - recall: 0.8816 - auc: 0.9472 - f1_score: 0.8816 - val_loss: 1.2148 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_auc: 0.7013 - val_f1_score: 0.6992 - lr: 1.0000e-05
# Epoch 60/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.2971 - accuracy: 0.8788 - precision: 0.8788 - recall: 0.8788 - auc: 0.9473 - f1_score: 0.8788 - val_loss: 1.0938 - val_accuracy: 0.6805 - val_precision: 0.6805 - val_recall: 0.6805 - val_auc: 0.7113 - val_f1_score: 0.6805 - lr: 1.0000e-05
# Epoch 61/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.2986 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9472 - f1_score: 0.8793 - val_loss: 1.1509 - val_accuracy: 0.6729 - val_precision: 0.6729 - val_recall: 0.6729 - val_auc: 0.6923 - val_f1_score: 0.6729 - lr: 1.0000e-05
# Epoch 62/100
# 56/56 [==============================] - 21s 375ms/step - loss: 0.2969 - accuracy: 0.8799 - precision: 0.8799 - recall: 0.8799 - auc: 0.9478 - f1_score: 0.8799 - val_loss: 1.1209 - val_accuracy: 0.6955 - val_precision: 0.6955 - val_recall: 0.6955 - val_auc: 0.7108 - val_f1_score: 0.6955 - lr: 1.0000e-05
# Epoch 63/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.2960 - accuracy: 0.8788 - precision: 0.8788 - recall: 0.8788 - auc: 0.9483 - f1_score: 0.8788 - val_loss: 1.0732 - val_accuracy: 0.7143 - val_precision: 0.7143 - val_recall: 0.7143 - val_auc: 0.7248 - val_f1_score: 0.7143 - lr: 1.0000e-05
# Epoch 64/100
# 56/56 [==============================] - 21s 368ms/step - loss: 0.2954 - accuracy: 0.8816 - precision: 0.8816 - recall: 0.8816 - auc: 0.9484 - f1_score: 0.8816 - val_loss: 1.1022 - val_accuracy: 0.6842 - val_precision: 0.6842 - val_recall: 0.6842 - val_auc: 0.7108 - val_f1_score: 0.6842 - lr: 1.0000e-05
# Epoch 65/100
# 56/56 [==============================] - 20s 366ms/step - loss: 0.2948 - accuracy: 0.8850 - precision: 0.8850 - recall: 0.8850 - auc: 0.9488 - f1_score: 0.8850 - val_loss: 1.2011 - val_accuracy: 0.6729 - val_precision: 0.6729 - val_recall: 0.6729 - val_auc: 0.6930 - val_f1_score: 0.6729 - lr: 1.0000e-05
# Epoch 66/100
# 56/56 [==============================] - 21s 374ms/step - loss: 0.2949 - accuracy: 0.8838 - precision: 0.8838 - recall: 0.8838 - auc: 0.9481 - f1_score: 0.8838 - val_loss: 1.0738 - val_accuracy: 0.6955 - val_precision: 0.6955 - val_recall: 0.6955 - val_auc: 0.7162 - val_f1_score: 0.6955 - lr: 1.0000e-05
# Epoch 67/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.2959 - accuracy: 0.8850 - precision: 0.8850 - recall: 0.8850 - auc: 0.9486 - f1_score: 0.8850 - val_loss: 1.0719 - val_accuracy: 0.6880 - val_precision: 0.6880 - val_recall: 0.6880 - val_auc: 0.7240 - val_f1_score: 0.6880 - lr: 1.0000e-05
# Epoch 68/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.2931 - accuracy: 0.8855 - precision: 0.8855 - recall: 0.8855 - auc: 0.9493 - f1_score: 0.8855 - val_loss: 1.0757 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_auc: 0.7163 - val_f1_score: 0.6992 - lr: 1.0000e-05
# Epoch 69/100
# 56/56 [==============================] - 21s 376ms/step - loss: 0.2927 - accuracy: 0.8838 - precision: 0.8838 - recall: 0.8838 - auc: 0.9492 - f1_score: 0.8838 - val_loss: 1.1365 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_auc: 0.7099 - val_f1_score: 0.6917 - lr: 1.0000e-05
# Epoch 70/100
# 56/56 [==============================] - 21s 373ms/step - loss: 0.2931 - accuracy: 0.8878 - precision: 0.8878 - recall: 0.8878 - auc: 0.9491 - f1_score: 0.8878 - val_loss: 1.0963 - val_accuracy: 0.7068 - val_precision: 0.7068 - val_recall: 0.7068 - val_auc: 0.7159 - val_f1_score: 0.7068 - lr: 1.0000e-05
# Epoch 71/100
# 56/56 [==============================] - 20s 366ms/step - loss: 0.2917 - accuracy: 0.8855 - precision: 0.8855 - recall: 0.8855 - auc: 0.9500 - f1_score: 0.8855 - val_loss: 1.1299 - val_accuracy: 0.7180 - val_precision: 0.7180 - val_recall: 0.7180 - val_auc: 0.7092 - val_f1_score: 0.7180 - lr: 1.0000e-05
# Epoch 72/100
# 56/56 [==============================] - 21s 375ms/step - loss: 0.2979 - accuracy: 0.8883 - precision: 0.8883 - recall: 0.8883 - auc: 0.9476 - f1_score: 0.8883 - val_loss: 1.1014 - val_accuracy: 0.7030 - val_precision: 0.7030 - val_recall: 0.7030 - val_auc: 0.7161 - val_f1_score: 0.7030 - lr: 1.0000e-05
# Epoch 73/100
# 56/56 [==============================] - 21s 376ms/step - loss: 0.2900 - accuracy: 0.8906 - precision: 0.8906 - recall: 0.8906 - auc: 0.9506 - f1_score: 0.8906 - val_loss: 1.1195 - val_accuracy: 0.7105 - val_precision: 0.7105 - val_recall: 0.7105 - val_auc: 0.7185 - val_f1_score: 0.7105 - lr: 1.0000e-05
# Epoch 74/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.2919 - accuracy: 0.8822 - precision: 0.8822 - recall: 0.8822 - auc: 0.9499 - f1_score: 0.8822 - val_loss: 1.0819 - val_accuracy: 0.7068 - val_precision: 0.7068 - val_recall: 0.7068 - val_auc: 0.7177 - val_f1_score: 0.7068 - lr: 1.0000e-05
# Epoch 75/100
# 56/56 [==============================] - 21s 368ms/step - loss: 0.2898 - accuracy: 0.8850 - precision: 0.8850 - recall: 0.8850 - auc: 0.9503 - f1_score: 0.8850 - val_loss: 1.0952 - val_accuracy: 0.7143 - val_precision: 0.7143 - val_recall: 0.7143 - val_auc: 0.7153 - val_f1_score: 0.7143 - lr: 1.0000e-05
# Epoch 76/100
# 56/56 [==============================] - 21s 368ms/step - loss: 0.2856 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9524 - f1_score: 0.8962 - val_loss: 1.1157 - val_accuracy: 0.6880 - val_precision: 0.6880 - val_recall: 0.6880 - val_auc: 0.7008 - val_f1_score: 0.6880 - lr: 1.0000e-05
# Epoch 77/100
# 56/56 [==============================] - 20s 364ms/step - loss: 0.2871 - accuracy: 0.8934 - precision: 0.8934 - recall: 0.8934 - auc: 0.9517 - f1_score: 0.8934 - val_loss: 1.0390 - val_accuracy: 0.7180 - val_precision: 0.7180 - val_recall: 0.7180 - val_auc: 0.7247 - val_f1_score: 0.7180 - lr: 1.0000e-05
# Epoch 78/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.2898 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9506 - f1_score: 0.8900 - val_loss: 1.0827 - val_accuracy: 0.7143 - val_precision: 0.7143 - val_recall: 0.7143 - val_auc: 0.7215 - val_f1_score: 0.7143 - lr: 1.0000e-05
# Epoch 79/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.2890 - accuracy: 0.8906 - precision: 0.8906 - recall: 0.8906 - auc: 0.9512 - f1_score: 0.8906 - val_loss: 1.0835 - val_accuracy: 0.6842 - val_precision: 0.6842 - val_recall: 0.6842 - val_auc: 0.7069 - val_f1_score: 0.6842 - lr: 1.0000e-05
# Epoch 80/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.2881 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9506 - f1_score: 0.8833 - val_loss: 1.0837 - val_accuracy: 0.7218 - val_precision: 0.7218 - val_recall: 0.7218 - val_auc: 0.7193 - val_f1_score: 0.7218 - lr: 1.0000e-05
# Epoch 81/100
# 56/56 [==============================] - 21s 370ms/step - loss: 0.2882 - accuracy: 0.8883 - precision: 0.8883 - recall: 0.8883 - auc: 0.9518 - f1_score: 0.8883 - val_loss: 1.0803 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_auc: 0.7315 - val_f1_score: 0.6992 - lr: 1.0000e-05
# Epoch 82/100
# 56/56 [==============================] - 21s 373ms/step - loss: 0.2843 - accuracy: 0.8838 - precision: 0.8838 - recall: 0.8838 - auc: 0.9523 - f1_score: 0.8838 - val_loss: 1.0888 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_auc: 0.7141 - val_f1_score: 0.6992 - lr: 1.0000e-05
# Epoch 83/100
# 56/56 [==============================] - 21s 372ms/step - loss: 0.2857 - accuracy: 0.8923 - precision: 0.8923 - recall: 0.8923 - auc: 0.9525 - f1_score: 0.8923 - val_loss: 1.0976 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_auc: 0.7105 - val_f1_score: 0.6992 - lr: 1.0000e-05
# Epoch 84/100
# 56/56 [==============================] - 21s 371ms/step - loss: 0.2861 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9520 - f1_score: 0.8900 - val_loss: 1.1175 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_auc: 0.7055 - val_f1_score: 0.6917 - lr: 1.0000e-05
# Epoch 85/100
# 56/56 [==============================] - 21s 373ms/step - loss: 0.2863 - accuracy: 0.8911 - precision: 0.8911 - recall: 0.8911 - auc: 0.9520 - f1_score: 0.8911 - val_loss: 1.1310 - val_accuracy: 0.6805 - val_precision: 0.6805 - val_recall: 0.6805 - val_auc: 0.7048 - val_f1_score: 0.6805 - lr: 1.0000e-05
# Epoch 86/100
# 56/56 [==============================] - 21s 374ms/step - loss: 0.2846 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9517 - f1_score: 0.8900 - val_loss: 1.1851 - val_accuracy: 0.7030 - val_precision: 0.7030 - val_recall: 0.7030 - val_auc: 0.7111 - val_f1_score: 0.7030 - lr: 1.0000e-05
# Epoch 87/100
# 56/56 [==============================] - 21s 375ms/step - loss: 0.2880 - accuracy: 0.8928 - precision: 0.8928 - recall: 0.8928 - auc: 0.9514 - f1_score: 0.8928 - val_loss: 1.0700 - val_accuracy: 0.7068 - val_precision: 0.7068 - val_recall: 0.7068 - val_auc: 0.7184 - val_f1_score: 0.7068 - lr: 1.0000e-05
# Epoch 88/100
# 56/56 [==============================] - 21s 375ms/step - loss: 0.2865 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9516 - f1_score: 0.8895 - val_loss: 1.0996 - val_accuracy: 0.7068 - val_precision: 0.7068 - val_recall: 0.7068 - val_auc: 0.7176 - val_f1_score: 0.7068 - lr: 1.0000e-05
# Epoch 89/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.2832 - accuracy: 0.8923 - precision: 0.8923 - recall: 0.8923 - auc: 0.9532 - f1_score: 0.8923 - val_loss: 1.0498 - val_accuracy: 0.7030 - val_precision: 0.7030 - val_recall: 0.7030 - val_auc: 0.7174 - val_f1_score: 0.7030 - lr: 1.0000e-05
# Epoch 90/100
# 56/56 [==============================] - 21s 367ms/step - loss: 0.2837 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9523 - f1_score: 0.8895 - val_loss: 1.0889 - val_accuracy: 0.6992 - val_precision: 0.6992 - val_recall: 0.6992 - val_auc: 0.7105 - val_f1_score: 0.6992 - lr: 1.0000e-05
# Epoch 91/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.2804 - accuracy: 0.8951 - precision: 0.8951 - recall: 0.8951 - auc: 0.9539 - f1_score: 0.8951 - val_loss: 1.0876 - val_accuracy: 0.7180 - val_precision: 0.7180 - val_recall: 0.7180 - val_auc: 0.7270 - val_f1_score: 0.7180 - lr: 1.0000e-05
# Epoch 92/100
# 56/56 [==============================] - 21s 374ms/step - loss: 0.2817 - accuracy: 0.8878 - precision: 0.8878 - recall: 0.8878 - auc: 0.9533 - f1_score: 0.8878 - val_loss: 1.0826 - val_accuracy: 0.7105 - val_precision: 0.7105 - val_recall: 0.7105 - val_auc: 0.7228 - val_f1_score: 0.7105 - lr: 1.0000e-05
# Epoch 93/100
# 56/56 [==============================] - 21s 374ms/step - loss: 0.2818 - accuracy: 0.8917 - precision: 0.8917 - recall: 0.8917 - auc: 0.9536 - f1_score: 0.8917 - val_loss: 1.0637 - val_accuracy: 0.7180 - val_precision: 0.7180 - val_recall: 0.7180 - val_auc: 0.7250 - val_f1_score: 0.7180 - lr: 1.0000e-05
# Epoch 94/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.2801 - accuracy: 0.8956 - precision: 0.8956 - recall: 0.8956 - auc: 0.9545 - f1_score: 0.8956 - val_loss: 1.0889 - val_accuracy: 0.7030 - val_precision: 0.7030 - val_recall: 0.7030 - val_auc: 0.7151 - val_f1_score: 0.7030 - lr: 1.0000e-05
# Epoch 95/100
# 56/56 [==============================] - 21s 370ms/step - loss: 0.2868 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9511 - f1_score: 0.8895 - val_loss: 1.1421 - val_accuracy: 0.6805 - val_precision: 0.6805 - val_recall: 0.6805 - val_auc: 0.7078 - val_f1_score: 0.6805 - lr: 1.0000e-05
# Epoch 96/100
# 56/56 [==============================] - 21s 369ms/step - loss: 0.2819 - accuracy: 0.8945 - precision: 0.8945 - recall: 0.8945 - auc: 0.9534 - f1_score: 0.8945 - val_loss: 1.1404 - val_accuracy: 0.6917 - val_precision: 0.6917 - val_recall: 0.6917 - val_auc: 0.7037 - val_f1_score: 0.6917 - lr: 1.0000e-05
# Epoch 97/100
# 56/56 [==============================] - 21s 375ms/step - loss: 0.2848 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9527 - f1_score: 0.8900 - val_loss: 1.0817 - val_accuracy: 0.7105 - val_precision: 0.7105 - val_recall: 0.7105 - val_auc: 0.7164 - val_f1_score: 0.7105 - lr: 1.0000e-05
# Epoch 98/100
# 56/56 [==============================] - 21s 377ms/step - loss: 0.2786 - accuracy: 0.8872 - precision: 0.8872 - recall: 0.8872 - auc: 0.9544 - f1_score: 0.8872 - val_loss: 1.0796 - val_accuracy: 0.6955 - val_precision: 0.6955 - val_recall: 0.6955 - val_auc: 0.7072 - val_f1_score: 0.6955 - lr: 1.0000e-05
# Epoch 99/100
# 56/56 [==============================] - 21s 373ms/step - loss: 0.2816 - accuracy: 0.8984 - precision: 0.8984 - recall: 0.8984 - auc: 0.9538 - f1_score: 0.8984 - val_loss: 1.0764 - val_accuracy: 0.6955 - val_precision: 0.6955 - val_recall: 0.6955 - val_auc: 0.7095 - val_f1_score: 0.6955 - lr: 1.0000e-05
# Epoch 100/100
# 56/56 [==============================] - 21s 382ms/step - loss: 0.2782 - accuracy: 0.8973 - precision: 0.8973 - recall: 0.8973 - auc: 0.9550 - f1_score: 0.8973 - val_loss: 1.0301 - val_accuracy: 0.7030 - val_precision: 0.7030 - val_recall: 0.7030 - val_auc: 0.7147 - val_f1_score: 0.7030 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 8/8 [==============================] - 0s 14ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.8520029925865469
# F1-Score for each class: [0.8045977  0.89940828]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.8786127167630058
# specificity: 0.8433734939759037

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 8/8 [==============================] - 0s 14ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 9/9 [==============================] - 1s 87ms/step - loss: 0.5432 - accuracy: 0.8640 - precision: 0.8640 - recall: 0.8640 - auc: 0.9043 - f1_score: 0.8640
# Test loss: 0.5431619882583618
# Test accuracy: 0.8639705777168274
# Test precision: 0.8639705777168274
# Test recall: 0.8639705777168274
# Test AUC: 0.9043306708335876
# Test F1 Score: 0.8639705777168274

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 8/8 [==============================] - 0s 14ms/step
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.80        83
#            1       0.92      0.88      0.90       173
#
#     accuracy                           0.87       256
#    macro avg       0.85      0.86      0.85       256
# weighted avg       0.87      0.87      0.87       256

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
