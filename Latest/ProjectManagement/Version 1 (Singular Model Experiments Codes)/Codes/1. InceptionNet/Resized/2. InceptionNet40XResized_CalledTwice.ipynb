# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/BCResize/40X/test'
train_dir = '/root/BreastCancer/BCResize/40X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/BCResize/40X/train/malignant'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2262 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 298 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %% [markdown]
# <h1>Model Construction<h1>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Concatenate, Flatten, Dense

def inception_block(x, filters):
    conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(x)

    conv3x3 = Conv2D(filters[1], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv3x3)

    conv5x5 = Conv2D(filters[3], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv5x5)

    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    maxpool = Conv2D(filters[5], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(maxpool)

    inception_block = Concatenate(axis=-1)([conv1x1, conv3x3, conv5x5, maxpool])
    return inception_block

def inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer = 'he_normal')(input_tensor)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception blocks
    x = inception_block(x, filters=[64, 128, 128, 32, 96, 32])
    x = inception_block(x, filters=[128, 128, 96, 64, 64, 64])

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=x)

    return model


# Create the InceptionNet model
model = inception_net(input_shape, num_classes)

# Display the model summary
model.summary()
# Out:
# 2023-12-24 11:56:06.103620: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 11:56:06.644255: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  8320        ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 128)  147584      ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 96)   76896       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 320)  0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 128)  41088       ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 64)   20544       ['concatenate[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 320)  0          ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 128)  41088       ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 56, 96)   110688      ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 64)   102464      ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 64)   20544       ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 352)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 352)  0          ['concatenate_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 352)         0           ['max_pooling2d_3[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            706         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 587,714
# Trainable params: 587,714
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "InceptionNetResized40X_CalledTwice"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/1. InceptionNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-24 11:56:10.543344: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-24 11:56:12.000155: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - 30s 375ms/step - loss: 0.7741 - accuracy: 0.6309 - precision: 0.6309 - recall: 0.6309 - auc: 0.6639 - f1_score: 0.6309 - val_loss: 0.5836 - val_accuracy: 0.6538 - val_precision: 0.6538 - val_recall: 0.6538 - val_auc: 0.7546 - val_f1_score: 0.6538 - lr: 0.0010
# Epoch 2/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.5691 - accuracy: 0.7228 - precision: 0.7228 - recall: 0.7228 - auc: 0.7775 - f1_score: 0.7228 - val_loss: 0.4542 - val_accuracy: 0.7988 - val_precision: 0.7988 - val_recall: 0.7988 - val_auc: 0.9001 - val_f1_score: 0.7988 - lr: 0.0010
# Epoch 3/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.5481 - accuracy: 0.7334 - precision: 0.7334 - recall: 0.7334 - auc: 0.7969 - f1_score: 0.7334 - val_loss: 0.4053 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9247 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 4/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.5466 - accuracy: 0.7334 - precision: 0.7334 - recall: 0.7334 - auc: 0.7997 - f1_score: 0.7334 - val_loss: 0.4780 - val_accuracy: 0.7692 - val_precision: 0.7692 - val_recall: 0.7692 - val_auc: 0.8657 - val_f1_score: 0.7692 - lr: 0.0010
# Epoch 5/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.5273 - accuracy: 0.7586 - precision: 0.7586 - recall: 0.7586 - auc: 0.8162 - f1_score: 0.7586 - val_loss: 0.5110 - val_accuracy: 0.7308 - val_precision: 0.7308 - val_recall: 0.7308 - val_auc: 0.8397 - val_f1_score: 0.7308 - lr: 0.0010
# Epoch 6/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.5058 - accuracy: 0.7741 - precision: 0.7741 - recall: 0.7741 - auc: 0.8326 - f1_score: 0.7741 - val_loss: 0.4066 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9389 - val_f1_score: 0.8935 - lr: 0.0010
# Epoch 7/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.4959 - accuracy: 0.7834 - precision: 0.7834 - recall: 0.7834 - auc: 0.8424 - f1_score: 0.7834 - val_loss: 0.3772 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9443 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 8/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.5035 - accuracy: 0.7737 - precision: 0.7737 - recall: 0.7737 - auc: 0.8339 - f1_score: 0.7737 - val_loss: 0.8103 - val_accuracy: 0.5118 - val_precision: 0.5118 - val_recall: 0.5118 - val_auc: 0.6358 - val_f1_score: 0.5118 - lr: 0.0010
# Epoch 9/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.4966 - accuracy: 0.7759 - precision: 0.7759 - recall: 0.7759 - auc: 0.8398 - f1_score: 0.7759 - val_loss: 0.3714 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9441 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 10/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.4808 - accuracy: 0.7887 - precision: 0.7887 - recall: 0.7887 - auc: 0.8515 - f1_score: 0.7887 - val_loss: 0.4040 - val_accuracy: 0.8018 - val_precision: 0.8018 - val_recall: 0.8018 - val_auc: 0.9070 - val_f1_score: 0.8018 - lr: 0.0010
# Epoch 11/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.4769 - accuracy: 0.7856 - precision: 0.7856 - recall: 0.7856 - auc: 0.8536 - f1_score: 0.7856 - val_loss: 0.3713 - val_accuracy: 0.8314 - val_precision: 0.8314 - val_recall: 0.8314 - val_auc: 0.9357 - val_f1_score: 0.8314 - lr: 0.0010
# Epoch 12/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.4782 - accuracy: 0.7874 - precision: 0.7874 - recall: 0.7874 - auc: 0.8523 - f1_score: 0.7874 - val_loss: 0.3257 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9530 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 13/100
# 71/71 [==============================] - 25s 356ms/step - loss: 0.4810 - accuracy: 0.7913 - precision: 0.7913 - recall: 0.7913 - auc: 0.8501 - f1_score: 0.7913 - val_loss: 0.3333 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9558 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 14/100
# 71/71 [==============================] - 25s 359ms/step - loss: 0.4658 - accuracy: 0.7997 - precision: 0.7997 - recall: 0.7997 - auc: 0.8632 - f1_score: 0.7997 - val_loss: 0.3071 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9484 - val_f1_score: 0.8846 - lr: 0.0010
# Epoch 15/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.4803 - accuracy: 0.7772 - precision: 0.7772 - recall: 0.7772 - auc: 0.8510 - f1_score: 0.7772 - val_loss: 0.3702 - val_accuracy: 0.8284 - val_precision: 0.8284 - val_recall: 0.8284 - val_auc: 0.9259 - val_f1_score: 0.8284 - lr: 0.0010
# Epoch 16/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.4697 - accuracy: 0.7909 - precision: 0.7909 - recall: 0.7909 - auc: 0.8602 - f1_score: 0.7909 - val_loss: 0.3353 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9567 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 17/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.4541 - accuracy: 0.8006 - precision: 0.8006 - recall: 0.8006 - auc: 0.8698 - f1_score: 0.8006 - val_loss: 0.3437 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9499 - val_f1_score: 0.8905 - lr: 0.0010
# Epoch 18/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.4564 - accuracy: 0.7944 - precision: 0.7944 - recall: 0.7944 - auc: 0.8684 - f1_score: 0.7944 - val_loss: 0.2465 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9735 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 19/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.4343 - accuracy: 0.8068 - precision: 0.8068 - recall: 0.8068 - auc: 0.8811 - f1_score: 0.8068 - val_loss: 0.4151 - val_accuracy: 0.8669 - val_precision: 0.8669 - val_recall: 0.8669 - val_auc: 0.9290 - val_f1_score: 0.8669 - lr: 0.0010
# Epoch 20/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.4439 - accuracy: 0.8068 - precision: 0.8068 - recall: 0.8068 - auc: 0.8752 - f1_score: 0.8068 - val_loss: 0.4462 - val_accuracy: 0.8077 - val_precision: 0.8077 - val_recall: 0.8077 - val_auc: 0.9092 - val_f1_score: 0.8077 - lr: 0.0010
# Epoch 21/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.4189 - accuracy: 0.8187 - precision: 0.8187 - recall: 0.8187 - auc: 0.8908 - f1_score: 0.8187 - val_loss: 0.2316 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9753 - val_f1_score: 0.9142 - lr: 0.0010
# Epoch 22/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.4612 - accuracy: 0.8042 - precision: 0.8042 - recall: 0.8042 - auc: 0.8640 - f1_score: 0.8042 - val_loss: 0.3394 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9422 - val_f1_score: 0.8639 - lr: 0.0010
# Epoch 23/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.4208 - accuracy: 0.8205 - precision: 0.8205 - recall: 0.8205 - auc: 0.8875 - f1_score: 0.8205 - val_loss: 0.2798 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9700 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 24/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3829 - accuracy: 0.8360 - precision: 0.8360 - recall: 0.8360 - auc: 0.9095 - f1_score: 0.8360 - val_loss: 0.2665 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9746 - val_f1_score: 0.9024 - lr: 0.0010
# Epoch 25/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3578 - accuracy: 0.8506 - precision: 0.8506 - recall: 0.8506 - auc: 0.9214 - f1_score: 0.8506 - val_loss: 0.3229 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9581 - val_f1_score: 0.8757 - lr: 0.0010
# Epoch 26/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.3858 - accuracy: 0.8355 - precision: 0.8355 - recall: 0.8355 - auc: 0.9072 - f1_score: 0.8355 - val_loss: 0.3609 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9567 - val_f1_score: 0.9142 - lr: 0.0010
# Epoch 27/100
# 71/71 [==============================] - 26s 368ms/step - loss: 0.3660 - accuracy: 0.8453 - precision: 0.8453 - recall: 0.8453 - auc: 0.9166 - f1_score: 0.8453 - val_loss: 0.2610 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9727 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 28/100
# 71/71 [==============================] - 27s 374ms/step - loss: 0.3749 - accuracy: 0.8448 - precision: 0.8448 - recall: 0.8448 - auc: 0.9125 - f1_score: 0.8448 - val_loss: 0.3045 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9531 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 29/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3889 - accuracy: 0.8382 - precision: 0.8382 - recall: 0.8382 - auc: 0.9068 - f1_score: 0.8382 - val_loss: 0.2326 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9841 - val_f1_score: 0.9379 - lr: 0.0010
# Epoch 30/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.3491 - accuracy: 0.8466 - precision: 0.8466 - recall: 0.8466 - auc: 0.9255 - f1_score: 0.8466 - val_loss: 0.1671 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9894 - val_f1_score: 0.9556 - lr: 0.0010
# Epoch 31/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3501 - accuracy: 0.8576 - precision: 0.8576 - recall: 0.8576 - auc: 0.9241 - f1_score: 0.8576 - val_loss: 0.2560 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9780 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 32/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3442 - accuracy: 0.8621 - precision: 0.8621 - recall: 0.8621 - auc: 0.9265 - f1_score: 0.8621 - val_loss: 0.4840 - val_accuracy: 0.7278 - val_precision: 0.7278 - val_recall: 0.7278 - val_auc: 0.8530 - val_f1_score: 0.7278 - lr: 0.0010
# Epoch 33/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.3877 - accuracy: 0.8333 - precision: 0.8333 - recall: 0.8333 - auc: 0.9075 - f1_score: 0.8333 - val_loss: 0.2902 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9568 - val_f1_score: 0.8935 - lr: 0.0010
# Epoch 34/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3208 - accuracy: 0.8652 - precision: 0.8652 - recall: 0.8652 - auc: 0.9383 - f1_score: 0.8652 - val_loss: 0.2357 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9838 - val_f1_score: 0.9408 - lr: 0.0010
# Epoch 35/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.3169 - accuracy: 0.8691 - precision: 0.8691 - recall: 0.8691 - auc: 0.9380 - f1_score: 0.8691 - val_loss: 0.3348 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9598 - val_f1_score: 0.8905 - lr: 0.0010
# Epoch 36/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.3017 - accuracy: 0.8709 - precision: 0.8709 - recall: 0.8709 - auc: 0.9449 - f1_score: 0.8709 - val_loss: 0.2010 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9823 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 37/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3207 - accuracy: 0.8665 - precision: 0.8665 - recall: 0.8665 - auc: 0.9368 - f1_score: 0.8665 - val_loss: 0.2276 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9815 - val_f1_score: 0.9349 - lr: 0.0010
# Epoch 38/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.3072 - accuracy: 0.8718 - precision: 0.8718 - recall: 0.8718 - auc: 0.9423 - f1_score: 0.8718 - val_loss: 0.2546 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9661 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 39/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.3371 - accuracy: 0.8537 - precision: 0.8537 - recall: 0.8537 - auc: 0.9303 - f1_score: 0.8537 - val_loss: 0.3875 - val_accuracy: 0.8018 - val_precision: 0.8018 - val_recall: 0.8018 - val_auc: 0.9045 - val_f1_score: 0.8018 - lr: 0.0010
# Epoch 40/100
# 71/71 [==============================] - ETA: 0s - loss: 0.2998 - accuracy: 0.8775 - precision: 0.8775 - recall: 0.8775 - auc: 0.9446 - f1_score: 0.8775
# Epoch 40: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 71/71 [==============================] - 26s 368ms/step - loss: 0.2998 - accuracy: 0.8775 - precision: 0.8775 - recall: 0.8775 - auc: 0.9446 - f1_score: 0.8775 - val_loss: 0.5558 - val_accuracy: 0.6834 - val_precision: 0.6834 - val_recall: 0.6834 - val_auc: 0.7811 - val_f1_score: 0.6834 - lr: 0.0010
# Epoch 41/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.2892 - accuracy: 0.8767 - precision: 0.8767 - recall: 0.8767 - auc: 0.9508 - f1_score: 0.8767 - val_loss: 0.1949 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9895 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 42/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.2389 - accuracy: 0.8966 - precision: 0.8966 - recall: 0.8966 - auc: 0.9672 - f1_score: 0.8966 - val_loss: 0.1917 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9865 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 43/100
# 71/71 [==============================] - 26s 369ms/step - loss: 0.2258 - accuracy: 0.9036 - precision: 0.9036 - recall: 0.9036 - auc: 0.9709 - f1_score: 0.9036 - val_loss: 0.2087 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9864 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 44/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.2228 - accuracy: 0.9107 - precision: 0.9107 - recall: 0.9107 - auc: 0.9709 - f1_score: 0.9107 - val_loss: 0.2226 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9824 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 45/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.2222 - accuracy: 0.9036 - precision: 0.9036 - recall: 0.9036 - auc: 0.9714 - f1_score: 0.9036 - val_loss: 0.1733 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9903 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 46/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.2066 - accuracy: 0.9195 - precision: 0.9195 - recall: 0.9195 - auc: 0.9758 - f1_score: 0.9195 - val_loss: 0.2242 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9835 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 47/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.2082 - accuracy: 0.9151 - precision: 0.9151 - recall: 0.9151 - auc: 0.9750 - f1_score: 0.9151 - val_loss: 0.1758 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9875 - val_f1_score: 0.9349 - lr: 1.0000e-04
# Epoch 48/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.2070 - accuracy: 0.9151 - precision: 0.9151 - recall: 0.9151 - auc: 0.9746 - f1_score: 0.9151 - val_loss: 0.1773 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9883 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 49/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.1971 - accuracy: 0.9173 - precision: 0.9173 - recall: 0.9173 - auc: 0.9778 - f1_score: 0.9173 - val_loss: 0.2051 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9838 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 50/100
# 71/71 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9195 - precision: 0.9195 - recall: 0.9195 - auc: 0.9779 - f1_score: 0.9195
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1974 - accuracy: 0.9195 - precision: 0.9195 - recall: 0.9195 - auc: 0.9779 - f1_score: 0.9195 - val_loss: 0.2106 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9810 - val_f1_score: 0.9142 - lr: 1.0000e-04
# Epoch 51/100
# 71/71 [==============================] - 25s 358ms/step - loss: 0.1940 - accuracy: 0.9195 - precision: 0.9195 - recall: 0.9195 - auc: 0.9783 - f1_score: 0.9195 - val_loss: 0.1859 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9850 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 52/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1923 - accuracy: 0.9235 - precision: 0.9235 - recall: 0.9235 - auc: 0.9786 - f1_score: 0.9235 - val_loss: 0.1835 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9866 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 53/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.1908 - accuracy: 0.9173 - precision: 0.9173 - recall: 0.9173 - auc: 0.9793 - f1_score: 0.9173 - val_loss: 0.1738 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9897 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 54/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.1932 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9784 - f1_score: 0.9213 - val_loss: 0.1693 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9911 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 55/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1873 - accuracy: 0.9218 - precision: 0.9218 - recall: 0.9218 - auc: 0.9800 - f1_score: 0.9218 - val_loss: 0.1804 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9879 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 56/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1852 - accuracy: 0.9279 - precision: 0.9279 - recall: 0.9279 - auc: 0.9807 - f1_score: 0.9279 - val_loss: 0.1661 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9920 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 57/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.1927 - accuracy: 0.9182 - precision: 0.9182 - recall: 0.9182 - auc: 0.9782 - f1_score: 0.9182 - val_loss: 0.1796 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9883 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 58/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.1885 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9794 - f1_score: 0.9231 - val_loss: 0.1784 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9888 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 59/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1906 - accuracy: 0.9218 - precision: 0.9218 - recall: 0.9218 - auc: 0.9790 - f1_score: 0.9218 - val_loss: 0.1850 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9865 - val_f1_score: 0.9231 - lr: 1.0000e-05
# Epoch 60/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1856 - accuracy: 0.9235 - precision: 0.9235 - recall: 0.9235 - auc: 0.9803 - f1_score: 0.9235 - val_loss: 0.1894 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9836 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 61/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.1879 - accuracy: 0.9226 - precision: 0.9226 - recall: 0.9226 - auc: 0.9795 - f1_score: 0.9226 - val_loss: 0.1840 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9870 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 62/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1900 - accuracy: 0.9244 - precision: 0.9244 - recall: 0.9244 - auc: 0.9792 - f1_score: 0.9244 - val_loss: 0.1703 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9904 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 63/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1850 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9805 - f1_score: 0.9262 - val_loss: 0.1893 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9850 - val_f1_score: 0.9231 - lr: 1.0000e-05
# Epoch 64/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1841 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9806 - f1_score: 0.9271 - val_loss: 0.1812 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9878 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 65/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1837 - accuracy: 0.9288 - precision: 0.9288 - recall: 0.9288 - auc: 0.9810 - f1_score: 0.9288 - val_loss: 0.1763 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9889 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 66/100
# 71/71 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9248 - precision: 0.9248 - recall: 0.9248 - auc: 0.9807 - f1_score: 0.9248
# Epoch 66: ReduceLROnPlateau reducing learning rate to 1e-05.
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1837 - accuracy: 0.9248 - precision: 0.9248 - recall: 0.9248 - auc: 0.9807 - f1_score: 0.9248 - val_loss: 0.1738 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9886 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 67/100
# 71/71 [==============================] - 25s 359ms/step - loss: 0.1908 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9785 - f1_score: 0.9178 - val_loss: 0.1748 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9888 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 68/100
# 71/71 [==============================] - 26s 359ms/step - loss: 0.1815 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9815 - f1_score: 0.9262 - val_loss: 0.1846 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9859 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 69/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1820 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9810 - f1_score: 0.9302 - val_loss: 0.1727 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9896 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 70/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1824 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9811 - f1_score: 0.9302 - val_loss: 0.1733 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9894 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 71/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1789 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9818 - f1_score: 0.9302 - val_loss: 0.1675 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9900 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 72/100
# 71/71 [==============================] - 25s 359ms/step - loss: 0.1812 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9813 - f1_score: 0.9293 - val_loss: 0.1642 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9914 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 73/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.1822 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9807 - f1_score: 0.9262 - val_loss: 0.1743 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9885 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 74/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1790 - accuracy: 0.9248 - precision: 0.9248 - recall: 0.9248 - auc: 0.9819 - f1_score: 0.9248 - val_loss: 0.1673 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9894 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 75/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1830 - accuracy: 0.9235 - precision: 0.9235 - recall: 0.9235 - auc: 0.9806 - f1_score: 0.9235 - val_loss: 0.1759 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9885 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 76/100
# 71/71 [==============================] - 26s 359ms/step - loss: 0.1826 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9808 - f1_score: 0.9262 - val_loss: 0.1757 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9888 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 77/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.1809 - accuracy: 0.9226 - precision: 0.9226 - recall: 0.9226 - auc: 0.9812 - f1_score: 0.9226 - val_loss: 0.1670 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9904 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 78/100
# 71/71 [==============================] - 25s 358ms/step - loss: 0.1791 - accuracy: 0.9279 - precision: 0.9279 - recall: 0.9279 - auc: 0.9817 - f1_score: 0.9279 - val_loss: 0.1842 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9864 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 79/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1773 - accuracy: 0.9266 - precision: 0.9266 - recall: 0.9266 - auc: 0.9823 - f1_score: 0.9266 - val_loss: 0.1864 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9862 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 80/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1803 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9814 - f1_score: 0.9271 - val_loss: 0.1696 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9898 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 81/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1772 - accuracy: 0.9275 - precision: 0.9275 - recall: 0.9275 - auc: 0.9823 - f1_score: 0.9275 - val_loss: 0.1621 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9909 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 82/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.1823 - accuracy: 0.9235 - precision: 0.9235 - recall: 0.9235 - auc: 0.9810 - f1_score: 0.9235 - val_loss: 0.1629 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9907 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 83/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1800 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - auc: 0.9811 - f1_score: 0.9284 - val_loss: 0.1691 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9894 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 84/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1770 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9823 - f1_score: 0.9319 - val_loss: 0.1711 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9894 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 85/100
# 71/71 [==============================] - 26s 361ms/step - loss: 0.1753 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9828 - f1_score: 0.9293 - val_loss: 0.1721 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9894 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 86/100
# 71/71 [==============================] - 26s 367ms/step - loss: 0.1783 - accuracy: 0.9248 - precision: 0.9248 - recall: 0.9248 - auc: 0.9816 - f1_score: 0.9248 - val_loss: 0.1729 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9881 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 87/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.1794 - accuracy: 0.9310 - precision: 0.9310 - recall: 0.9310 - auc: 0.9814 - f1_score: 0.9310 - val_loss: 0.1702 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9883 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 88/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.1810 - accuracy: 0.9248 - precision: 0.9248 - recall: 0.9248 - auc: 0.9810 - f1_score: 0.9248 - val_loss: 0.1741 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9887 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 89/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1788 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9817 - f1_score: 0.9297 - val_loss: 0.1689 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9897 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 90/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1757 - accuracy: 0.9279 - precision: 0.9279 - recall: 0.9279 - auc: 0.9826 - f1_score: 0.9279 - val_loss: 0.1741 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9891 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 91/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1730 - accuracy: 0.9253 - precision: 0.9253 - recall: 0.9253 - auc: 0.9830 - f1_score: 0.9253 - val_loss: 0.1590 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9910 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 92/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1726 - accuracy: 0.9332 - precision: 0.9332 - recall: 0.9332 - auc: 0.9832 - f1_score: 0.9332 - val_loss: 0.1591 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9903 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 93/100
# 71/71 [==============================] - 26s 363ms/step - loss: 0.1773 - accuracy: 0.9275 - precision: 0.9275 - recall: 0.9275 - auc: 0.9819 - f1_score: 0.9275 - val_loss: 0.1778 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9860 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 94/100
# 71/71 [==============================] - 26s 366ms/step - loss: 0.1738 - accuracy: 0.9332 - precision: 0.9332 - recall: 0.9332 - auc: 0.9828 - f1_score: 0.9332 - val_loss: 0.1774 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9874 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 95/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1758 - accuracy: 0.9266 - precision: 0.9266 - recall: 0.9266 - auc: 0.9823 - f1_score: 0.9266 - val_loss: 0.1736 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9890 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 96/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1735 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9828 - f1_score: 0.9337 - val_loss: 0.1537 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9920 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 97/100
# 71/71 [==============================] - 26s 360ms/step - loss: 0.1769 - accuracy: 0.9248 - precision: 0.9248 - recall: 0.9248 - auc: 0.9817 - f1_score: 0.9248 - val_loss: 0.1672 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9902 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 98/100
# 71/71 [==============================] - 26s 365ms/step - loss: 0.1772 - accuracy: 0.9310 - precision: 0.9310 - recall: 0.9310 - auc: 0.9819 - f1_score: 0.9310 - val_loss: 0.1635 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9909 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 99/100
# 71/71 [==============================] - 26s 362ms/step - loss: 0.1746 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9826 - f1_score: 0.9293 - val_loss: 0.1540 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9924 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 100/100
# 71/71 [==============================] - 26s 364ms/step - loss: 0.1709 - accuracy: 0.9332 - precision: 0.9332 - recall: 0.9332 - auc: 0.9832 - f1_score: 0.9332 - val_loss: 0.1617 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9909 - val_f1_score: 0.9438 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 0s 14ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9210353147620092
# F1-Score for each class: [0.89361702 0.94845361]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9246231155778895
# specificity: 0.9438202247191011

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 14ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 1s 81ms/step - loss: 0.1835 - accuracy: 0.9295 - precision: 0.9295 - recall: 0.9295 - auc: 0.9803 - f1_score: 0.9295
# Test loss: 0.18346159160137177
# Test accuracy: 0.9295302033424377
# Test precision: 0.9295302033424377
# Test recall: 0.9295302033424377
# Test AUC: 0.9802767634391785
# Test F1 Score: 0.9295302629470825

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89        89
#            1       0.97      0.92      0.95       199
#
#     accuracy                           0.93       288
#    macro avg       0.91      0.93      0.92       288
# weighted avg       0.93      0.93      0.93       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
