# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/40X/test'
train_dir = '/root/BreastCancer/40X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/40X/train/malignant'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2262 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 298 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %% [markdown]
# <h1>Model Construction<h1>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Concatenate, Flatten, Dense

def inception_block(x, filters):
    conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(x)

    conv3x3 = Conv2D(filters[1], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv3x3)

    conv5x5 = Conv2D(filters[3], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv5x5)

    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    maxpool = Conv2D(filters[5], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(maxpool)

    inception_block = Concatenate(axis=-1)([conv1x1, conv3x3, conv5x5, maxpool])
    return inception_block

def inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer = 'he_normal')(input_tensor)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception blocks
    x = inception_block(x, filters=[64, 128, 128, 32, 96, 32])
    # x = inception_block(x, filters=[128, 128, 96, 64, 64, 64])

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=x)

    return model


# Create the InceptionNet model
model = inception_net(input_shape, num_classes)

# Display the model summary
model.summary()
# Out:
# 2023-12-23 17:11:39.779435: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-23 17:11:40.376137: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:a1:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  8320        ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 128)  147584      ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 32)   25632       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 256)  0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 56, 56, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 56, 56, 64)   16448       ['concatenate[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 256)  0          ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 56, 56, 96)   110688      ['conv2d_8[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 56, 56, 64)   102464      ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 56, 56, 64)   16448       ['max_pooling2d_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 352)  0           ['conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 352)  0          ['concatenate_1[0][0]']
#
#  global_average_pooling2d (Glob  (None, 352)         0           ['max_pooling2d_3[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            706         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 511,874
# Trainable params: 511,874
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "InceptionNet40X"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/InceptionNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-23 17:11:44.855671: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-23 17:11:46.308331: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - 52s 671ms/step - loss: 0.6816 - accuracy: 0.6662 - precision: 0.6662 - recall: 0.6662 - auc: 0.7106 - f1_score: 0.6662 - val_loss: 0.4435 - val_accuracy: 0.8521 - val_precision: 0.8521 - val_recall: 0.8521 - val_auc: 0.9128 - val_f1_score: 0.8521 - lr: 0.0010
# Epoch 2/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.5447 - accuracy: 0.7480 - precision: 0.7480 - recall: 0.7480 - auc: 0.8030 - f1_score: 0.7480 - val_loss: 0.4000 - val_accuracy: 0.8669 - val_precision: 0.8669 - val_recall: 0.8669 - val_auc: 0.9289 - val_f1_score: 0.8669 - lr: 0.0010
# Epoch 3/100
# 71/71 [==============================] - 47s 658ms/step - loss: 0.5132 - accuracy: 0.7732 - precision: 0.7732 - recall: 0.7732 - auc: 0.8253 - f1_score: 0.7732 - val_loss: 0.4085 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9234 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 4/100
# 71/71 [==============================] - 47s 662ms/step - loss: 0.5020 - accuracy: 0.7728 - precision: 0.7728 - recall: 0.7728 - auc: 0.8370 - f1_score: 0.7728 - val_loss: 0.4570 - val_accuracy: 0.7751 - val_precision: 0.7751 - val_recall: 0.7751 - val_auc: 0.8938 - val_f1_score: 0.7751 - lr: 0.0010
# Epoch 5/100
# 71/71 [==============================] - 47s 659ms/step - loss: 0.5030 - accuracy: 0.7714 - precision: 0.7714 - recall: 0.7714 - auc: 0.8357 - f1_score: 0.7714 - val_loss: 0.3699 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9299 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 6/100
# 71/71 [==============================] - 47s 664ms/step - loss: 0.5186 - accuracy: 0.7546 - precision: 0.7546 - recall: 0.7546 - auc: 0.8239 - f1_score: 0.7546 - val_loss: 0.3870 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9304 - val_f1_score: 0.8580 - lr: 0.0010
# Epoch 7/100
# 71/71 [==============================] - 47s 660ms/step - loss: 0.5055 - accuracy: 0.7630 - precision: 0.7630 - recall: 0.7630 - auc: 0.8337 - f1_score: 0.7630 - val_loss: 0.4020 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9271 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 8/100
# 71/71 [==============================] - 47s 658ms/step - loss: 0.4850 - accuracy: 0.7829 - precision: 0.7829 - recall: 0.7829 - auc: 0.8482 - f1_score: 0.7829 - val_loss: 0.3671 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9318 - val_f1_score: 0.8757 - lr: 0.0010
# Epoch 9/100
# 71/71 [==============================] - 47s 668ms/step - loss: 0.4853 - accuracy: 0.7882 - precision: 0.7882 - recall: 0.7882 - auc: 0.8489 - f1_score: 0.7882 - val_loss: 0.3683 - val_accuracy: 0.8136 - val_precision: 0.8136 - val_recall: 0.8136 - val_auc: 0.9212 - val_f1_score: 0.8136 - lr: 0.0010
# Epoch 10/100
# 71/71 [==============================] - 47s 666ms/step - loss: 0.4844 - accuracy: 0.7843 - precision: 0.7843 - recall: 0.7843 - auc: 0.8497 - f1_score: 0.7843 - val_loss: 0.4067 - val_accuracy: 0.8225 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.9263 - val_f1_score: 0.8225 - lr: 0.0010
# Epoch 11/100
# 71/71 [==============================] - 47s 667ms/step - loss: 0.4587 - accuracy: 0.7971 - precision: 0.7971 - recall: 0.7971 - auc: 0.8664 - f1_score: 0.7971 - val_loss: 0.4238 - val_accuracy: 0.8018 - val_precision: 0.8018 - val_recall: 0.8018 - val_auc: 0.9079 - val_f1_score: 0.8018 - lr: 0.0010
# Epoch 12/100
# 71/71 [==============================] - 47s 656ms/step - loss: 0.4832 - accuracy: 0.7772 - precision: 0.7772 - recall: 0.7772 - auc: 0.8518 - f1_score: 0.7772 - val_loss: 0.4196 - val_accuracy: 0.8669 - val_precision: 0.8669 - val_recall: 0.8669 - val_auc: 0.9270 - val_f1_score: 0.8669 - lr: 0.0010
# Epoch 13/100
# 71/71 [==============================] - 47s 664ms/step - loss: 0.4822 - accuracy: 0.7843 - precision: 0.7843 - recall: 0.7843 - auc: 0.8503 - f1_score: 0.7843 - val_loss: 0.4147 - val_accuracy: 0.8225 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.9196 - val_f1_score: 0.8225 - lr: 0.0010
# Epoch 14/100
# 71/71 [==============================] - 47s 665ms/step - loss: 0.5019 - accuracy: 0.7741 - precision: 0.7741 - recall: 0.7741 - auc: 0.8369 - f1_score: 0.7741 - val_loss: 0.3436 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9505 - val_f1_score: 0.8994 - lr: 0.0010
# Epoch 15/100
# 71/71 [==============================] - 47s 658ms/step - loss: 0.4745 - accuracy: 0.7860 - precision: 0.7860 - recall: 0.7860 - auc: 0.8581 - f1_score: 0.7860 - val_loss: 0.3689 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9443 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 16/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.4724 - accuracy: 0.7851 - precision: 0.7851 - recall: 0.7851 - auc: 0.8574 - f1_score: 0.7851 - val_loss: 0.4134 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9221 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 17/100
# 71/71 [==============================] - 48s 670ms/step - loss: 0.4842 - accuracy: 0.7882 - precision: 0.7882 - recall: 0.7882 - auc: 0.8494 - f1_score: 0.7882 - val_loss: 0.3453 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9461 - val_f1_score: 0.8787 - lr: 0.0010
# Epoch 18/100
# 71/71 [==============================] - 47s 660ms/step - loss: 0.4627 - accuracy: 0.7958 - precision: 0.7958 - recall: 0.7958 - auc: 0.8626 - f1_score: 0.7958 - val_loss: 0.4187 - val_accuracy: 0.8077 - val_precision: 0.8077 - val_recall: 0.8077 - val_auc: 0.9127 - val_f1_score: 0.8077 - lr: 0.0010
# Epoch 19/100
# 71/71 [==============================] - 47s 659ms/step - loss: 0.4644 - accuracy: 0.7900 - precision: 0.7900 - recall: 0.7900 - auc: 0.8631 - f1_score: 0.7900 - val_loss: 0.3438 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9470 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 20/100
# 71/71 [==============================] - 47s 662ms/step - loss: 0.4373 - accuracy: 0.8024 - precision: 0.8024 - recall: 0.8024 - auc: 0.8804 - f1_score: 0.8024 - val_loss: 0.3403 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9582 - val_f1_score: 0.8787 - lr: 0.0010
# Epoch 21/100
# 71/71 [==============================] - 47s 662ms/step - loss: 0.4436 - accuracy: 0.8033 - precision: 0.8033 - recall: 0.8033 - auc: 0.8772 - f1_score: 0.8033 - val_loss: 0.4721 - val_accuracy: 0.7722 - val_precision: 0.7722 - val_recall: 0.7722 - val_auc: 0.8833 - val_f1_score: 0.7722 - lr: 0.0010
# Epoch 22/100
# 71/71 [==============================] - 47s 667ms/step - loss: 0.4425 - accuracy: 0.8095 - precision: 0.8095 - recall: 0.8095 - auc: 0.8784 - f1_score: 0.8095 - val_loss: 0.4014 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9362 - val_f1_score: 0.8757 - lr: 0.0010
# Epoch 23/100
# 71/71 [==============================] - 48s 677ms/step - loss: 0.4661 - accuracy: 0.7909 - precision: 0.7909 - recall: 0.7909 - auc: 0.8611 - f1_score: 0.7909 - val_loss: 0.3553 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9598 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 24/100
# 71/71 [==============================] - 47s 667ms/step - loss: 0.4315 - accuracy: 0.8086 - precision: 0.8086 - recall: 0.8086 - auc: 0.8820 - f1_score: 0.8086 - val_loss: 0.4469 - val_accuracy: 0.8107 - val_precision: 0.8107 - val_recall: 0.8107 - val_auc: 0.9048 - val_f1_score: 0.8107 - lr: 0.0010
# Epoch 25/100
# 71/71 [==============================] - 47s 667ms/step - loss: 0.4392 - accuracy: 0.8068 - precision: 0.8068 - recall: 0.8068 - auc: 0.8800 - f1_score: 0.8068 - val_loss: 0.2890 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9524 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 26/100
# 71/71 [==============================] - 48s 672ms/step - loss: 0.4994 - accuracy: 0.7785 - precision: 0.7785 - recall: 0.7785 - auc: 0.8441 - f1_score: 0.7785 - val_loss: 0.3849 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9478 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 27/100
# 71/71 [==============================] - 47s 660ms/step - loss: 0.4394 - accuracy: 0.8050 - precision: 0.8050 - recall: 0.8050 - auc: 0.8784 - f1_score: 0.8050 - val_loss: 0.3018 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9675 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 28/100
# 71/71 [==============================] - 47s 666ms/step - loss: 0.4182 - accuracy: 0.8263 - precision: 0.8263 - recall: 0.8263 - auc: 0.8909 - f1_score: 0.8263 - val_loss: 0.2738 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9691 - val_f1_score: 0.9142 - lr: 0.0010
# Epoch 29/100
# 71/71 [==============================] - 48s 674ms/step - loss: 0.4844 - accuracy: 0.7737 - precision: 0.7737 - recall: 0.7737 - auc: 0.8465 - f1_score: 0.7737 - val_loss: 0.3008 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9748 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 30/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.4141 - accuracy: 0.8201 - precision: 0.8201 - recall: 0.8201 - auc: 0.8943 - f1_score: 0.8201 - val_loss: 0.4527 - val_accuracy: 0.7692 - val_precision: 0.7692 - val_recall: 0.7692 - val_auc: 0.8659 - val_f1_score: 0.7692 - lr: 0.0010
# Epoch 31/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.3877 - accuracy: 0.8307 - precision: 0.8307 - recall: 0.8307 - auc: 0.9074 - f1_score: 0.8307 - val_loss: 0.2703 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9593 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 32/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.3660 - accuracy: 0.8475 - precision: 0.8475 - recall: 0.8475 - auc: 0.9174 - f1_score: 0.8475 - val_loss: 0.2685 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9808 - val_f1_score: 0.9172 - lr: 0.0010
# Epoch 33/100
# 71/71 [==============================] - 47s 667ms/step - loss: 0.3582 - accuracy: 0.8510 - precision: 0.8510 - recall: 0.8510 - auc: 0.9206 - f1_score: 0.8510 - val_loss: 0.4828 - val_accuracy: 0.7781 - val_precision: 0.7781 - val_recall: 0.7781 - val_auc: 0.8526 - val_f1_score: 0.7781 - lr: 0.0010
# Epoch 34/100
# 71/71 [==============================] - 47s 661ms/step - loss: 0.4208 - accuracy: 0.8165 - precision: 0.8165 - recall: 0.8165 - auc: 0.8915 - f1_score: 0.8165 - val_loss: 0.2839 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9626 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 35/100
# 71/71 [==============================] - 47s 660ms/step - loss: 0.3533 - accuracy: 0.8435 - precision: 0.8435 - recall: 0.8435 - auc: 0.9239 - f1_score: 0.8435 - val_loss: 0.2257 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9887 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 36/100
# 71/71 [==============================] - 47s 665ms/step - loss: 0.3350 - accuracy: 0.8488 - precision: 0.8488 - recall: 0.8488 - auc: 0.9308 - f1_score: 0.8488 - val_loss: 0.2492 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9805 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 37/100
# 71/71 [==============================] - 48s 669ms/step - loss: 0.3509 - accuracy: 0.8554 - precision: 0.8554 - recall: 0.8554 - auc: 0.9238 - f1_score: 0.8554 - val_loss: 0.2472 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9666 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 38/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.3415 - accuracy: 0.8470 - precision: 0.8470 - recall: 0.8470 - auc: 0.9280 - f1_score: 0.8470 - val_loss: 0.3110 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9594 - val_f1_score: 0.8905 - lr: 0.0010
# Epoch 39/100
# 71/71 [==============================] - 47s 664ms/step - loss: 0.3306 - accuracy: 0.8643 - precision: 0.8643 - recall: 0.8643 - auc: 0.9328 - f1_score: 0.8643 - val_loss: 0.2200 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9824 - val_f1_score: 0.9408 - lr: 0.0010
# Epoch 40/100
# 71/71 [==============================] - 47s 665ms/step - loss: 0.3186 - accuracy: 0.8705 - precision: 0.8705 - recall: 0.8705 - auc: 0.9369 - f1_score: 0.8705 - val_loss: 0.3056 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9508 - val_f1_score: 0.8846 - lr: 0.0010
# Epoch 41/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.3697 - accuracy: 0.8519 - precision: 0.8519 - recall: 0.8519 - auc: 0.9161 - f1_score: 0.8519 - val_loss: 0.2908 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9611 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 42/100
# 71/71 [==============================] - 47s 668ms/step - loss: 0.3334 - accuracy: 0.8585 - precision: 0.8585 - recall: 0.8585 - auc: 0.9326 - f1_score: 0.8585 - val_loss: 0.2164 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9897 - val_f1_score: 0.9467 - lr: 0.0010
# Epoch 43/100
# 71/71 [==============================] - 47s 658ms/step - loss: 0.2975 - accuracy: 0.8753 - precision: 0.8753 - recall: 0.8753 - auc: 0.9460 - f1_score: 0.8753 - val_loss: 0.2408 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9826 - val_f1_score: 0.9172 - lr: 0.0010
# Epoch 44/100
# 71/71 [==============================] - 47s 665ms/step - loss: 0.2938 - accuracy: 0.8744 - precision: 0.8744 - recall: 0.8744 - auc: 0.9473 - f1_score: 0.8744 - val_loss: 0.2369 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9843 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 45/100
# 71/71 [==============================] - 47s 664ms/step - loss: 0.2911 - accuracy: 0.8784 - precision: 0.8784 - recall: 0.8784 - auc: 0.9480 - f1_score: 0.8784 - val_loss: 0.3729 - val_accuracy: 0.8284 - val_precision: 0.8284 - val_recall: 0.8284 - val_auc: 0.9158 - val_f1_score: 0.8284 - lr: 0.0010
# Epoch 46/100
# 71/71 [==============================] - 47s 664ms/step - loss: 0.3083 - accuracy: 0.8678 - precision: 0.8678 - recall: 0.8678 - auc: 0.9422 - f1_score: 0.8678 - val_loss: 0.3341 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9342 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 47/100
# 71/71 [==============================] - 47s 662ms/step - loss: 0.2834 - accuracy: 0.8762 - precision: 0.8762 - recall: 0.8762 - auc: 0.9512 - f1_score: 0.8762 - val_loss: 0.3461 - val_accuracy: 0.8521 - val_precision: 0.8521 - val_recall: 0.8521 - val_auc: 0.9364 - val_f1_score: 0.8521 - lr: 0.0010
# Epoch 48/100
# 71/71 [==============================] - 47s 665ms/step - loss: 0.2821 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9512 - f1_score: 0.8820 - val_loss: 0.2473 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9632 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 49/100
# 71/71 [==============================] - 47s 660ms/step - loss: 0.2949 - accuracy: 0.8784 - precision: 0.8784 - recall: 0.8784 - auc: 0.9475 - f1_score: 0.8784 - val_loss: 0.6286 - val_accuracy: 0.5917 - val_precision: 0.5917 - val_recall: 0.5917 - val_auc: 0.7042 - val_f1_score: 0.5917 - lr: 0.0010
# Epoch 50/100
# 71/71 [==============================] - 47s 661ms/step - loss: 0.3472 - accuracy: 0.8550 - precision: 0.8550 - recall: 0.8550 - auc: 0.9259 - f1_score: 0.8550 - val_loss: 0.2001 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9849 - val_f1_score: 0.9379 - lr: 0.0010
# Epoch 51/100
# 71/71 [==============================] - 47s 665ms/step - loss: 0.2831 - accuracy: 0.8758 - precision: 0.8758 - recall: 0.8758 - auc: 0.9512 - f1_score: 0.8758 - val_loss: 0.1625 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9921 - val_f1_score: 0.9497 - lr: 0.0010
# Epoch 52/100
# 71/71 [==============================] - 47s 662ms/step - loss: 0.2507 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9615 - f1_score: 0.9019 - val_loss: 0.2673 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9729 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 53/100
# 71/71 [==============================] - 47s 658ms/step - loss: 0.2441 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9639 - f1_score: 0.8992 - val_loss: 0.2485 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9700 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 54/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.2409 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9647 - f1_score: 0.8992 - val_loss: 0.2373 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9688 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 55/100
# 71/71 [==============================] - 47s 659ms/step - loss: 0.2447 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9634 - f1_score: 0.8992 - val_loss: 0.3955 - val_accuracy: 0.7929 - val_precision: 0.7929 - val_recall: 0.7929 - val_auc: 0.8979 - val_f1_score: 0.7929 - lr: 0.0010
# Epoch 56/100
# 71/71 [==============================] - 47s 665ms/step - loss: 0.2620 - accuracy: 0.8952 - precision: 0.8952 - recall: 0.8952 - auc: 0.9583 - f1_score: 0.8952 - val_loss: 0.3895 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.9042 - val_f1_score: 0.8166 - lr: 0.0010
# Epoch 57/100
# 71/71 [==============================] - 47s 666ms/step - loss: 0.2338 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9670 - f1_score: 0.9023 - val_loss: 0.2184 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9755 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 58/100
# 71/71 [==============================] - 47s 661ms/step - loss: 0.2445 - accuracy: 0.8974 - precision: 0.8974 - recall: 0.8974 - auc: 0.9635 - f1_score: 0.8974 - val_loss: 0.1931 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9857 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 59/100
# 71/71 [==============================] - 47s 659ms/step - loss: 0.2349 - accuracy: 0.9080 - precision: 0.9080 - recall: 0.9080 - auc: 0.9663 - f1_score: 0.9080 - val_loss: 0.1708 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9824 - val_f1_score: 0.9379 - lr: 0.0010
# Epoch 60/100
# 71/71 [==============================] - 47s 661ms/step - loss: 0.2078 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9740 - f1_score: 0.9160 - val_loss: 0.1392 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9949 - val_f1_score: 0.9675 - lr: 0.0010
# Epoch 61/100
# 71/71 [==============================] - 47s 660ms/step - loss: 0.2070 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9737 - f1_score: 0.9200 - val_loss: 0.1804 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9872 - val_f1_score: 0.9408 - lr: 0.0010
# Epoch 62/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.2973 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9474 - f1_score: 0.8798 - val_loss: 0.2797 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9750 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 63/100
# 71/71 [==============================] - 47s 666ms/step - loss: 0.2534 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9610 - f1_score: 0.8992 - val_loss: 0.2413 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9718 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 64/100
# 71/71 [==============================] - 47s 664ms/step - loss: 0.2397 - accuracy: 0.9036 - precision: 0.9036 - recall: 0.9036 - auc: 0.9649 - f1_score: 0.9036 - val_loss: 0.2671 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9573 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 65/100
# 71/71 [==============================] - 47s 660ms/step - loss: 0.2358 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9659 - f1_score: 0.9023 - val_loss: 0.1505 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9920 - val_f1_score: 0.9556 - lr: 0.0010
# Epoch 66/100
# 71/71 [==============================] - 47s 664ms/step - loss: 0.2101 - accuracy: 0.9129 - precision: 0.9129 - recall: 0.9129 - auc: 0.9729 - f1_score: 0.9129 - val_loss: 0.2939 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9471 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 67/100
# 71/71 [==============================] - 47s 660ms/step - loss: 0.1959 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9769 - f1_score: 0.9191 - val_loss: 0.2942 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9495 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 68/100
# 71/71 [==============================] - 47s 668ms/step - loss: 0.2509 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9617 - f1_score: 0.8992 - val_loss: 0.1755 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9898 - val_f1_score: 0.9408 - lr: 0.0010
# Epoch 69/100
# 71/71 [==============================] - 47s 668ms/step - loss: 0.1926 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9777 - f1_score: 0.9160 - val_loss: 0.2514 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9658 - val_f1_score: 0.8905 - lr: 0.0010
# Epoch 70/100
# 71/71 [==============================] - ETA: 0s - loss: 0.1911 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9779 - f1_score: 0.9200
# Epoch 70: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 71/71 [==============================] - 47s 668ms/step - loss: 0.1911 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9779 - f1_score: 0.9200 - val_loss: 0.1730 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9808 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 71/100
# 71/71 [==============================] - 47s 667ms/step - loss: 0.1449 - accuracy: 0.9447 - precision: 0.9447 - recall: 0.9447 - auc: 0.9876 - f1_score: 0.9447 - val_loss: 0.1254 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9931 - val_f1_score: 0.9675 - lr: 1.0000e-04
# Epoch 72/100
# 71/71 [==============================] - 47s 666ms/step - loss: 0.1288 - accuracy: 0.9478 - precision: 0.9478 - recall: 0.9478 - auc: 0.9909 - f1_score: 0.9478 - val_loss: 0.1325 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9928 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 73/100
# 71/71 [==============================] - 48s 676ms/step - loss: 0.1223 - accuracy: 0.9483 - precision: 0.9483 - recall: 0.9483 - auc: 0.9919 - f1_score: 0.9483 - val_loss: 0.1311 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9917 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 74/100
# 71/71 [==============================] - 47s 665ms/step - loss: 0.1222 - accuracy: 0.9562 - precision: 0.9562 - recall: 0.9562 - auc: 0.9920 - f1_score: 0.9562 - val_loss: 0.1362 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9918 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 75/100
# 71/71 [==============================] - 47s 669ms/step - loss: 0.1235 - accuracy: 0.9514 - precision: 0.9514 - recall: 0.9514 - auc: 0.9915 - f1_score: 0.9514 - val_loss: 0.1432 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9886 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 76/100
# 71/71 [==============================] - 48s 671ms/step - loss: 0.1273 - accuracy: 0.9500 - precision: 0.9500 - recall: 0.9500 - auc: 0.9904 - f1_score: 0.9500 - val_loss: 0.1206 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9936 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 77/100
# 71/71 [==============================] - 47s 669ms/step - loss: 0.1174 - accuracy: 0.9553 - precision: 0.9553 - recall: 0.9553 - auc: 0.9922 - f1_score: 0.9553 - val_loss: 0.1560 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9865 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 78/100
# 71/71 [==============================] - 47s 669ms/step - loss: 0.1118 - accuracy: 0.9571 - precision: 0.9571 - recall: 0.9571 - auc: 0.9932 - f1_score: 0.9571 - val_loss: 0.1420 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9892 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 79/100
# 71/71 [==============================] - 48s 672ms/step - loss: 0.1164 - accuracy: 0.9553 - precision: 0.9553 - recall: 0.9553 - auc: 0.9924 - f1_score: 0.9553 - val_loss: 0.1192 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9931 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 80/100
# 71/71 [==============================] - 47s 667ms/step - loss: 0.1267 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9906 - f1_score: 0.9505 - val_loss: 0.1288 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9914 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 81/100
# 71/71 [==============================] - 48s 671ms/step - loss: 0.1179 - accuracy: 0.9461 - precision: 0.9461 - recall: 0.9461 - auc: 0.9921 - f1_score: 0.9461 - val_loss: 0.1156 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9943 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 82/100
# 71/71 [==============================] - 47s 666ms/step - loss: 0.1157 - accuracy: 0.9545 - precision: 0.9545 - recall: 0.9545 - auc: 0.9924 - f1_score: 0.9545 - val_loss: 0.1334 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9895 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 83/100
# 71/71 [==============================] - 47s 659ms/step - loss: 0.1178 - accuracy: 0.9589 - precision: 0.9589 - recall: 0.9589 - auc: 0.9914 - f1_score: 0.9589 - val_loss: 0.1257 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9939 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 84/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.1125 - accuracy: 0.9615 - precision: 0.9615 - recall: 0.9615 - auc: 0.9928 - f1_score: 0.9615 - val_loss: 0.1234 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9923 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 85/100
# 71/71 [==============================] - 47s 666ms/step - loss: 0.1094 - accuracy: 0.9545 - precision: 0.9545 - recall: 0.9545 - auc: 0.9932 - f1_score: 0.9545 - val_loss: 0.1419 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9880 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 86/100
# 71/71 [==============================] - 47s 662ms/step - loss: 0.1152 - accuracy: 0.9584 - precision: 0.9584 - recall: 0.9584 - auc: 0.9915 - f1_score: 0.9584 - val_loss: 0.1268 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9917 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 87/100
# 71/71 [==============================] - 48s 671ms/step - loss: 0.1033 - accuracy: 0.9598 - precision: 0.9598 - recall: 0.9598 - auc: 0.9940 - f1_score: 0.9598 - val_loss: 0.1205 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9909 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 88/100
# 71/71 [==============================] - 48s 678ms/step - loss: 0.1055 - accuracy: 0.9607 - precision: 0.9607 - recall: 0.9607 - auc: 0.9936 - f1_score: 0.9607 - val_loss: 0.1198 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9931 - val_f1_score: 0.9675 - lr: 1.0000e-04
# Epoch 89/100
# 71/71 [==============================] - 48s 670ms/step - loss: 0.1076 - accuracy: 0.9607 - precision: 0.9607 - recall: 0.9607 - auc: 0.9933 - f1_score: 0.9607 - val_loss: 0.2047 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9752 - val_f1_score: 0.9112 - lr: 1.0000e-04
# Epoch 90/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.1143 - accuracy: 0.9531 - precision: 0.9531 - recall: 0.9531 - auc: 0.9925 - f1_score: 0.9531 - val_loss: 0.1218 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9944 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 91/100
# 71/71 [==============================] - 47s 668ms/step - loss: 0.1022 - accuracy: 0.9607 - precision: 0.9607 - recall: 0.9607 - auc: 0.9941 - f1_score: 0.9607 - val_loss: 0.1107 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9947 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 92/100
# 71/71 [==============================] - 47s 660ms/step - loss: 0.1113 - accuracy: 0.9580 - precision: 0.9580 - recall: 0.9580 - auc: 0.9928 - f1_score: 0.9580 - val_loss: 0.1087 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9933 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 93/100
# 71/71 [==============================] - 47s 661ms/step - loss: 0.1058 - accuracy: 0.9584 - precision: 0.9584 - recall: 0.9584 - auc: 0.9936 - f1_score: 0.9584 - val_loss: 0.1136 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9928 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 94/100
# 71/71 [==============================] - 47s 661ms/step - loss: 0.1057 - accuracy: 0.9602 - precision: 0.9602 - recall: 0.9602 - auc: 0.9935 - f1_score: 0.9602 - val_loss: 0.1348 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9908 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 95/100
# 71/71 [==============================] - 47s 662ms/step - loss: 0.1074 - accuracy: 0.9580 - precision: 0.9580 - recall: 0.9580 - auc: 0.9931 - f1_score: 0.9580 - val_loss: 0.0989 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9957 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 96/100
# 71/71 [==============================] - 47s 662ms/step - loss: 0.1060 - accuracy: 0.9584 - precision: 0.9584 - recall: 0.9584 - auc: 0.9934 - f1_score: 0.9584 - val_loss: 0.1209 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9913 - val_f1_score: 0.9645 - lr: 1.0000e-04
# Epoch 97/100
# 71/71 [==============================] - 47s 661ms/step - loss: 0.1049 - accuracy: 0.9593 - precision: 0.9593 - recall: 0.9593 - auc: 0.9934 - f1_score: 0.9593 - val_loss: 0.1150 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9912 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 98/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.1010 - accuracy: 0.9571 - precision: 0.9571 - recall: 0.9571 - auc: 0.9942 - f1_score: 0.9571 - val_loss: 0.1501 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9875 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 99/100
# 71/71 [==============================] - 47s 663ms/step - loss: 0.0983 - accuracy: 0.9589 - precision: 0.9589 - recall: 0.9589 - auc: 0.9944 - f1_score: 0.9589 - val_loss: 0.1405 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9880 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 100/100
# 71/71 [==============================] - 47s 667ms/step - loss: 0.1048 - accuracy: 0.9584 - precision: 0.9584 - recall: 0.9584 - auc: 0.9934 - f1_score: 0.9584 - val_loss: 0.1362 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9893 - val_f1_score: 0.9497 - lr: 1.0000e-04

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 0s 24ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9387056422410955
# F1-Score for each class: [0.91566265 0.96174863]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9723756906077348
# specificity: 0.8941176470588236

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 12ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 3s 309ms/step - loss: 0.1147 - accuracy: 0.9530 - precision: 0.9530 - recall: 0.9530 - auc: 0.9923 - f1_score: 0.9530
# Test loss: 0.11467228084802628
# Test accuracy: 0.9530201554298401
# Test precision: 0.9530201554298401
# Test recall: 0.9530201554298401
# Test AUC: 0.9922525882720947
# Test F1 Score: 0.9530201554298401

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 13ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92        85
#            1       0.95      0.97      0.96       181
#
#     accuracy                           0.95       266
#    macro avg       0.94      0.93      0.94       266
# weighted avg       0.95      0.95      0.95       266

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
