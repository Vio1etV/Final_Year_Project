# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/200X/test'
train_dir = '/root/BreastCancer/200X/train'


batch_size = 16
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/40X/train/malignant'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1491 images belonging to 2 classes.
# Found 221 images belonging to 2 classes.
# Found 301 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %% [markdown]
# <h1>Model Construction<h1>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Concatenate, Flatten, Dense

def inception_block(x, filters):
    conv1x1 = Conv2D(filters[0], (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(x)

    conv3x3 = Conv2D(filters[1], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv3x3 = Conv2D(filters[2], (3, 3), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv3x3)

    conv5x5 = Conv2D(filters[3], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(x)
    conv5x5 = Conv2D(filters[4], (5, 5), padding='same', activation='relu', kernel_initializer = 'he_normal')(conv5x5)

    maxpool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(x)
    maxpool = Conv2D(filters[5], (1, 1), padding='same', activation='relu', kernel_initializer = 'he_normal')(maxpool)

    inception_block = Concatenate(axis=-1)([conv1x1, conv3x3, conv5x5, maxpool])
    return inception_block

def inception_net(input_shape, num_classes):
    input_tensor = Input(shape=input_shape)

    # Initial convolutional layer
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer = 'he_normal')(input_tensor)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Inception blocks
    x = inception_block(x, filters=[64, 128, 128, 32, 96, 32])
    # x = inception_block(x, filters=[128, 128, 96, 64, 64, 64])

    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    x = GlobalAveragePooling2D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.models.Model(inputs=input_tensor, outputs=x)

    return model


# Create the InceptionNet model
model = inception_net(input_shape, num_classes)

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  8320        ['max_pooling2d[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 64)  0           ['max_pooling2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 128)  147584      ['conv2d_2[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 96)   76896       ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   2080        ['max_pooling2d_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 320)  0           ['conv2d_1[0][0]',
#                                                                   'conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 320)  0          ['concatenate[0][0]']
#
#  global_average_pooling2d (Glob  (None, 320)         0           ['max_pooling2d_2[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            642         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 251,234
# Trainable params: 251,234
# Non-trainable params: 0
# __________________________________________________________________________________________________
# 2023-12-23 21:55:49.490577: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-23 21:55:50.078039: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:a1:00.0, compute capability: 8.6

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'macro')
    ]
)

MODEL_NAME = "InceptionNet200X"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/1. InceptionNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-23 21:55:53.579395: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-23 21:55:54.907747: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 94/94 [==============================] - 35s 341ms/step - loss: 0.5130 - accuracy: 0.7659 - precision: 0.7659 - recall: 0.7659 - auc: 0.8319 - f1_score: 0.7049 - val_loss: 0.4274 - val_accuracy: 0.8643 - val_precision: 0.8643 - val_recall: 0.8643 - val_auc: 0.9461 - val_f1_score: 0.8407 - lr: 0.0010
# Epoch 2/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.4325 - accuracy: 0.8216 - precision: 0.8216 - recall: 0.8216 - auc: 0.8831 - f1_score: 0.7786 - val_loss: 0.4884 - val_accuracy: 0.7149 - val_precision: 0.7149 - val_recall: 0.7149 - val_auc: 0.8775 - val_f1_score: 0.4831 - lr: 0.0010
# Epoch 3/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.4272 - accuracy: 0.8243 - precision: 0.8243 - recall: 0.8243 - auc: 0.8836 - f1_score: 0.7806 - val_loss: 0.3327 - val_accuracy: 0.8597 - val_precision: 0.8597 - val_recall: 0.8597 - val_auc: 0.9359 - val_f1_score: 0.8089 - lr: 0.0010
# Epoch 4/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.4175 - accuracy: 0.8357 - precision: 0.8357 - recall: 0.8357 - auc: 0.8879 - f1_score: 0.7947 - val_loss: 0.3688 - val_accuracy: 0.8462 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9264 - val_f1_score: 0.7862 - lr: 0.0010
# Epoch 5/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.4233 - accuracy: 0.8330 - precision: 0.8330 - recall: 0.8330 - auc: 0.8857 - f1_score: 0.7904 - val_loss: 0.3671 - val_accuracy: 0.8597 - val_precision: 0.8597 - val_recall: 0.8597 - val_auc: 0.9282 - val_f1_score: 0.8089 - lr: 0.0010
# Epoch 6/100
# 94/94 [==============================] - 32s 339ms/step - loss: 0.4112 - accuracy: 0.8417 - precision: 0.8417 - recall: 0.8417 - auc: 0.8912 - f1_score: 0.8036 - val_loss: 0.3264 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9514 - val_f1_score: 0.8597 - lr: 0.0010
# Epoch 7/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.4839 - accuracy: 0.7921 - precision: 0.7921 - recall: 0.7921 - auc: 0.8534 - f1_score: 0.7327 - val_loss: 0.4881 - val_accuracy: 0.7149 - val_precision: 0.7149 - val_recall: 0.7149 - val_auc: 0.8706 - val_f1_score: 0.4831 - lr: 0.0010
# Epoch 8/100
# 94/94 [==============================] - 31s 329ms/step - loss: 0.4190 - accuracy: 0.8484 - precision: 0.8484 - recall: 0.8484 - auc: 0.8906 - f1_score: 0.8138 - val_loss: 0.5053 - val_accuracy: 0.7330 - val_precision: 0.7330 - val_recall: 0.7330 - val_auc: 0.8781 - val_f1_score: 0.5361 - lr: 0.0010
# Epoch 9/100
# 94/94 [==============================] - 31s 335ms/step - loss: 0.4231 - accuracy: 0.8310 - precision: 0.8310 - recall: 0.8310 - auc: 0.8853 - f1_score: 0.7874 - val_loss: 0.3073 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9456 - val_f1_score: 0.8497 - lr: 0.0010
# Epoch 10/100
# 94/94 [==============================] - 31s 335ms/step - loss: 0.4091 - accuracy: 0.8471 - precision: 0.8471 - recall: 0.8471 - auc: 0.8932 - f1_score: 0.8105 - val_loss: 0.3108 - val_accuracy: 0.9005 - val_precision: 0.9005 - val_recall: 0.9005 - val_auc: 0.9543 - val_f1_score: 0.8742 - lr: 0.0010
# Epoch 11/100
# 94/94 [==============================] - 31s 333ms/step - loss: 0.4063 - accuracy: 0.8471 - precision: 0.8471 - recall: 0.8471 - auc: 0.8930 - f1_score: 0.8102 - val_loss: 0.3021 - val_accuracy: 0.9095 - val_precision: 0.9095 - val_recall: 0.9095 - val_auc: 0.9581 - val_f1_score: 0.8879 - lr: 0.0010
# Epoch 12/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.4130 - accuracy: 0.8424 - precision: 0.8424 - recall: 0.8424 - auc: 0.8903 - f1_score: 0.8025 - val_loss: 0.3829 - val_accuracy: 0.8190 - val_precision: 0.8190 - val_recall: 0.8190 - val_auc: 0.9172 - val_f1_score: 0.7339 - lr: 0.0010
# Epoch 13/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3933 - accuracy: 0.8578 - precision: 0.8578 - recall: 0.8578 - auc: 0.8976 - f1_score: 0.8228 - val_loss: 0.3439 - val_accuracy: 0.8507 - val_precision: 0.8507 - val_recall: 0.8507 - val_auc: 0.9388 - val_f1_score: 0.7911 - lr: 0.0010
# Epoch 14/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3911 - accuracy: 0.8598 - precision: 0.8598 - recall: 0.8598 - auc: 0.8981 - f1_score: 0.8251 - val_loss: 0.3751 - val_accuracy: 0.8462 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9391 - val_f1_score: 0.7862 - lr: 0.0010
# Epoch 15/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3998 - accuracy: 0.8524 - precision: 0.8524 - recall: 0.8524 - auc: 0.8956 - f1_score: 0.8161 - val_loss: 0.3867 - val_accuracy: 0.8145 - val_precision: 0.8145 - val_recall: 0.8145 - val_auc: 0.9250 - val_f1_score: 0.7251 - lr: 0.0010
# Epoch 16/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3997 - accuracy: 0.8444 - precision: 0.8444 - recall: 0.8444 - auc: 0.8954 - f1_score: 0.8046 - val_loss: 0.3626 - val_accuracy: 0.9050 - val_precision: 0.9050 - val_recall: 0.9050 - val_auc: 0.9534 - val_f1_score: 0.8829 - lr: 0.0010
# Epoch 17/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3931 - accuracy: 0.8471 - precision: 0.8471 - recall: 0.8471 - auc: 0.9000 - f1_score: 0.8088 - val_loss: 0.3220 - val_accuracy: 0.8597 - val_precision: 0.8597 - val_recall: 0.8597 - val_auc: 0.9432 - val_f1_score: 0.8113 - lr: 0.0010
# Epoch 18/100
# 94/94 [==============================] - 31s 333ms/step - loss: 0.3795 - accuracy: 0.8598 - precision: 0.8598 - recall: 0.8598 - auc: 0.9041 - f1_score: 0.8264 - val_loss: 0.3548 - val_accuracy: 0.8416 - val_precision: 0.8416 - val_recall: 0.8416 - val_auc: 0.9262 - val_f1_score: 0.7785 - lr: 0.0010
# Epoch 19/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3957 - accuracy: 0.8437 - precision: 0.8437 - recall: 0.8437 - auc: 0.8982 - f1_score: 0.8062 - val_loss: 0.4370 - val_accuracy: 0.7783 - val_precision: 0.7783 - val_recall: 0.7783 - val_auc: 0.8938 - val_f1_score: 0.6494 - lr: 0.0010
# Epoch 20/100
# 94/94 [==============================] - 31s 333ms/step - loss: 0.4009 - accuracy: 0.8524 - precision: 0.8524 - recall: 0.8524 - auc: 0.8932 - f1_score: 0.8161 - val_loss: 0.3526 - val_accuracy: 0.8597 - val_precision: 0.8597 - val_recall: 0.8597 - val_auc: 0.9408 - val_f1_score: 0.8064 - lr: 0.0010
# Epoch 21/100
# 94/94 [==============================] - ETA: 0s - loss: 0.3952 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - auc: 0.8989 - f1_score: 0.8144
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3952 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - auc: 0.8989 - f1_score: 0.8144 - val_loss: 0.3437 - val_accuracy: 0.9005 - val_precision: 0.9005 - val_recall: 0.9005 - val_auc: 0.9632 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 22/100
# 94/94 [==============================] - 32s 335ms/step - loss: 0.3577 - accuracy: 0.8726 - precision: 0.8726 - recall: 0.8726 - auc: 0.9144 - f1_score: 0.8423 - val_loss: 0.3166 - val_accuracy: 0.9005 - val_precision: 0.9005 - val_recall: 0.9005 - val_auc: 0.9584 - val_f1_score: 0.8714 - lr: 1.0000e-04
# Epoch 23/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3540 - accuracy: 0.8773 - precision: 0.8773 - recall: 0.8773 - auc: 0.9157 - f1_score: 0.8487 - val_loss: 0.3460 - val_accuracy: 0.8462 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9375 - val_f1_score: 0.7833 - lr: 1.0000e-04
# Epoch 24/100
# 94/94 [==============================] - 31s 333ms/step - loss: 0.3499 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9173 - f1_score: 0.8542 - val_loss: 0.3427 - val_accuracy: 0.8507 - val_precision: 0.8507 - val_recall: 0.8507 - val_auc: 0.9375 - val_f1_score: 0.7911 - lr: 1.0000e-04
# Epoch 25/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3517 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9164 - f1_score: 0.8492 - val_loss: 0.3160 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9525 - val_f1_score: 0.8395 - lr: 1.0000e-04
# Epoch 26/100
# 94/94 [==============================] - 31s 333ms/step - loss: 0.3505 - accuracy: 0.8773 - precision: 0.8773 - recall: 0.8773 - auc: 0.9180 - f1_score: 0.8480 - val_loss: 0.3215 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9441 - val_f1_score: 0.8496 - lr: 1.0000e-04
# Epoch 27/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3494 - accuracy: 0.8753 - precision: 0.8753 - recall: 0.8753 - auc: 0.9194 - f1_score: 0.8454 - val_loss: 0.3143 - val_accuracy: 0.8959 - val_precision: 0.8959 - val_recall: 0.8959 - val_auc: 0.9505 - val_f1_score: 0.8648 - lr: 1.0000e-04
# Epoch 28/100
# 94/94 [==============================] - 31s 331ms/step - loss: 0.3495 - accuracy: 0.8732 - precision: 0.8732 - recall: 0.8732 - auc: 0.9208 - f1_score: 0.8428 - val_loss: 0.3041 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9576 - val_f1_score: 0.8582 - lr: 1.0000e-04
# Epoch 29/100
# 94/94 [==============================] - 31s 330ms/step - loss: 0.3502 - accuracy: 0.8786 - precision: 0.8786 - recall: 0.8786 - auc: 0.9194 - f1_score: 0.8499 - val_loss: 0.3191 - val_accuracy: 0.8733 - val_precision: 0.8733 - val_recall: 0.8733 - val_auc: 0.9452 - val_f1_score: 0.8306 - lr: 1.0000e-04
# Epoch 30/100
# 94/94 [==============================] - 31s 328ms/step - loss: 0.3489 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9187 - f1_score: 0.8483 - val_loss: 0.3258 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9517 - val_f1_score: 0.8376 - lr: 1.0000e-04
# Epoch 31/100
# 94/94 [==============================] - ETA: 0s - loss: 0.3430 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9227 - f1_score: 0.8471
# Epoch 31: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3430 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9227 - f1_score: 0.8471 - val_loss: 0.3296 - val_accuracy: 0.8643 - val_precision: 0.8643 - val_recall: 0.8643 - val_auc: 0.9390 - val_f1_score: 0.8138 - lr: 1.0000e-04
# Epoch 32/100
# 94/94 [==============================] - 31s 333ms/step - loss: 0.3411 - accuracy: 0.8773 - precision: 0.8773 - recall: 0.8773 - auc: 0.9232 - f1_score: 0.8471 - val_loss: 0.3303 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9375 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 33/100
# 94/94 [==============================] - 32s 335ms/step - loss: 0.3408 - accuracy: 0.8753 - precision: 0.8753 - recall: 0.8753 - auc: 0.9239 - f1_score: 0.8459 - val_loss: 0.3284 - val_accuracy: 0.8733 - val_precision: 0.8733 - val_recall: 0.8733 - val_auc: 0.9410 - val_f1_score: 0.8306 - lr: 1.0000e-05
# Epoch 34/100
# 94/94 [==============================] - 31s 335ms/step - loss: 0.3394 - accuracy: 0.8799 - precision: 0.8799 - recall: 0.8799 - auc: 0.9244 - f1_score: 0.8509 - val_loss: 0.3067 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9552 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 35/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3399 - accuracy: 0.8786 - precision: 0.8786 - recall: 0.8786 - auc: 0.9240 - f1_score: 0.8503 - val_loss: 0.3187 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9453 - val_f1_score: 0.8496 - lr: 1.0000e-05
# Epoch 36/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3417 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9234 - f1_score: 0.8469 - val_loss: 0.3219 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9440 - val_f1_score: 0.8376 - lr: 1.0000e-05
# Epoch 37/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3422 - accuracy: 0.8746 - precision: 0.8746 - recall: 0.8746 - auc: 0.9233 - f1_score: 0.8442 - val_loss: 0.3247 - val_accuracy: 0.8733 - val_precision: 0.8733 - val_recall: 0.8733 - val_auc: 0.9440 - val_f1_score: 0.8306 - lr: 1.0000e-05
# Epoch 38/100
# 94/94 [==============================] - 31s 330ms/step - loss: 0.3438 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9228 - f1_score: 0.8471 - val_loss: 0.3207 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9459 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 39/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3382 - accuracy: 0.8786 - precision: 0.8786 - recall: 0.8786 - auc: 0.9253 - f1_score: 0.8499 - val_loss: 0.3173 - val_accuracy: 0.8959 - val_precision: 0.8959 - val_recall: 0.8959 - val_auc: 0.9456 - val_f1_score: 0.8648 - lr: 1.0000e-05
# Epoch 40/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3392 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9249 - f1_score: 0.8477 - val_loss: 0.3164 - val_accuracy: 0.8733 - val_precision: 0.8733 - val_recall: 0.8733 - val_auc: 0.9500 - val_f1_score: 0.8306 - lr: 1.0000e-05
# Epoch 41/100
# 94/94 [==============================] - ETA: 0s - loss: 0.3386 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9247 - f1_score: 0.8490
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1e-05.
# 94/94 [==============================] - 31s 333ms/step - loss: 0.3386 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9247 - f1_score: 0.8490 - val_loss: 0.3153 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9495 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 42/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3412 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9240 - f1_score: 0.8508 - val_loss: 0.3256 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9438 - val_f1_score: 0.8427 - lr: 1.0000e-05
# Epoch 43/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3398 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9247 - f1_score: 0.8466 - val_loss: 0.3260 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9442 - val_f1_score: 0.8376 - lr: 1.0000e-05
# Epoch 44/100
# 94/94 [==============================] - 32s 339ms/step - loss: 0.3422 - accuracy: 0.8773 - precision: 0.8773 - recall: 0.8773 - auc: 0.9238 - f1_score: 0.8487 - val_loss: 0.3200 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9470 - val_f1_score: 0.8356 - lr: 1.0000e-05
# Epoch 45/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3409 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9241 - f1_score: 0.8511 - val_loss: 0.3122 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9508 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 46/100
# 94/94 [==============================] - 32s 336ms/step - loss: 0.3398 - accuracy: 0.8759 - precision: 0.8759 - recall: 0.8759 - auc: 0.9246 - f1_score: 0.8466 - val_loss: 0.3239 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9453 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 47/100
# 94/94 [==============================] - 31s 330ms/step - loss: 0.3407 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9247 - f1_score: 0.8480 - val_loss: 0.3242 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9403 - val_f1_score: 0.8582 - lr: 1.0000e-05
# Epoch 48/100
# 94/94 [==============================] - 31s 331ms/step - loss: 0.3413 - accuracy: 0.8746 - precision: 0.8746 - recall: 0.8746 - auc: 0.9244 - f1_score: 0.8440 - val_loss: 0.3308 - val_accuracy: 0.8733 - val_precision: 0.8733 - val_recall: 0.8733 - val_auc: 0.9385 - val_f1_score: 0.8306 - lr: 1.0000e-05
# Epoch 49/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3359 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9279 - f1_score: 0.8511 - val_loss: 0.3338 - val_accuracy: 0.8643 - val_precision: 0.8643 - val_recall: 0.8643 - val_auc: 0.9390 - val_f1_score: 0.8162 - lr: 1.0000e-05
# Epoch 50/100
# 94/94 [==============================] - 31s 331ms/step - loss: 0.3402 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9246 - f1_score: 0.8485 - val_loss: 0.3209 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9426 - val_f1_score: 0.8356 - lr: 1.0000e-05
# Epoch 51/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3361 - accuracy: 0.8813 - precision: 0.8813 - recall: 0.8813 - auc: 0.9262 - f1_score: 0.8526 - val_loss: 0.3228 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9460 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 52/100
# 94/94 [==============================] - 31s 330ms/step - loss: 0.3364 - accuracy: 0.8826 - precision: 0.8826 - recall: 0.8826 - auc: 0.9268 - f1_score: 0.8553 - val_loss: 0.3214 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9439 - val_f1_score: 0.8376 - lr: 1.0000e-05
# Epoch 53/100
# 94/94 [==============================] - 32s 335ms/step - loss: 0.3376 - accuracy: 0.8806 - precision: 0.8806 - recall: 0.8806 - auc: 0.9254 - f1_score: 0.8521 - val_loss: 0.3222 - val_accuracy: 0.8733 - val_precision: 0.8733 - val_recall: 0.8733 - val_auc: 0.9431 - val_f1_score: 0.8306 - lr: 1.0000e-05
# Epoch 54/100
# 94/94 [==============================] - 32s 340ms/step - loss: 0.3384 - accuracy: 0.8813 - precision: 0.8813 - recall: 0.8813 - auc: 0.9253 - f1_score: 0.8532 - val_loss: 0.3307 - val_accuracy: 0.8733 - val_precision: 0.8733 - val_recall: 0.8733 - val_auc: 0.9387 - val_f1_score: 0.8306 - lr: 1.0000e-05
# Epoch 55/100
# 94/94 [==============================] - 31s 331ms/step - loss: 0.3385 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9249 - f1_score: 0.8494 - val_loss: 0.3211 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9441 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 56/100
# 94/94 [==============================] - 32s 336ms/step - loss: 0.3369 - accuracy: 0.8813 - precision: 0.8813 - recall: 0.8813 - auc: 0.9262 - f1_score: 0.8524 - val_loss: 0.3209 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9458 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 57/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3389 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9257 - f1_score: 0.8480 - val_loss: 0.3336 - val_accuracy: 0.8507 - val_precision: 0.8507 - val_recall: 0.8507 - val_auc: 0.9343 - val_f1_score: 0.7939 - lr: 1.0000e-05
# Epoch 58/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3374 - accuracy: 0.8759 - precision: 0.8759 - recall: 0.8759 - auc: 0.9262 - f1_score: 0.8455 - val_loss: 0.3305 - val_accuracy: 0.8688 - val_precision: 0.8688 - val_recall: 0.8688 - val_auc: 0.9405 - val_f1_score: 0.8234 - lr: 1.0000e-05
# Epoch 59/100
# 94/94 [==============================] - 31s 331ms/step - loss: 0.3346 - accuracy: 0.8786 - precision: 0.8786 - recall: 0.8786 - auc: 0.9277 - f1_score: 0.8499 - val_loss: 0.3188 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9407 - val_f1_score: 0.8582 - lr: 1.0000e-05
# Epoch 60/100
# 94/94 [==============================] - 32s 336ms/step - loss: 0.3342 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9276 - f1_score: 0.8508 - val_loss: 0.3159 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9468 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 61/100
# 94/94 [==============================] - 32s 336ms/step - loss: 0.3382 - accuracy: 0.8799 - precision: 0.8799 - recall: 0.8799 - auc: 0.9255 - f1_score: 0.8518 - val_loss: 0.3250 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9364 - val_f1_score: 0.8582 - lr: 1.0000e-05
# Epoch 62/100
# 94/94 [==============================] - 32s 338ms/step - loss: 0.3360 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9272 - f1_score: 0.8469 - val_loss: 0.3293 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9380 - val_f1_score: 0.8496 - lr: 1.0000e-05
# Epoch 63/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3372 - accuracy: 0.8773 - precision: 0.8773 - recall: 0.8773 - auc: 0.9254 - f1_score: 0.8476 - val_loss: 0.3236 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9432 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 64/100
# 94/94 [==============================] - 32s 336ms/step - loss: 0.3357 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9268 - f1_score: 0.8490 - val_loss: 0.3152 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9496 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 65/100
# 94/94 [==============================] - 31s 330ms/step - loss: 0.3353 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9266 - f1_score: 0.8492 - val_loss: 0.3213 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9440 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 66/100
# 94/94 [==============================] - 32s 336ms/step - loss: 0.3368 - accuracy: 0.8826 - precision: 0.8826 - recall: 0.8826 - auc: 0.9260 - f1_score: 0.8549 - val_loss: 0.3230 - val_accuracy: 0.9050 - val_precision: 0.9050 - val_recall: 0.9050 - val_auc: 0.9441 - val_f1_score: 0.8766 - lr: 1.0000e-05
# Epoch 67/100
# 94/94 [==============================] - 31s 331ms/step - loss: 0.3339 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9278 - f1_score: 0.8508 - val_loss: 0.3198 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9426 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 68/100
# 94/94 [==============================] - 31s 333ms/step - loss: 0.3342 - accuracy: 0.8799 - precision: 0.8799 - recall: 0.8799 - auc: 0.9278 - f1_score: 0.8511 - val_loss: 0.3208 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9435 - val_f1_score: 0.8427 - lr: 1.0000e-05
# Epoch 69/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3381 - accuracy: 0.8773 - precision: 0.8773 - recall: 0.8773 - auc: 0.9266 - f1_score: 0.8474 - val_loss: 0.3191 - val_accuracy: 0.8959 - val_precision: 0.8959 - val_recall: 0.8959 - val_auc: 0.9443 - val_f1_score: 0.8648 - lr: 1.0000e-05
# Epoch 70/100
# 94/94 [==============================] - 32s 340ms/step - loss: 0.3340 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9279 - f1_score: 0.8506 - val_loss: 0.3205 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9463 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 71/100
# 94/94 [==============================] - 31s 333ms/step - loss: 0.3346 - accuracy: 0.8813 - precision: 0.8813 - recall: 0.8813 - auc: 0.9277 - f1_score: 0.8530 - val_loss: 0.3272 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9368 - val_f1_score: 0.8427 - lr: 1.0000e-05
# Epoch 72/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3366 - accuracy: 0.8746 - precision: 0.8746 - recall: 0.8746 - auc: 0.9272 - f1_score: 0.8431 - val_loss: 0.3262 - val_accuracy: 0.8733 - val_precision: 0.8733 - val_recall: 0.8733 - val_auc: 0.9430 - val_f1_score: 0.8306 - lr: 1.0000e-05
# Epoch 73/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3348 - accuracy: 0.8786 - precision: 0.8786 - recall: 0.8786 - auc: 0.9280 - f1_score: 0.8492 - val_loss: 0.3109 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9493 - val_f1_score: 0.8582 - lr: 1.0000e-05
# Epoch 74/100
# 94/94 [==============================] - 31s 333ms/step - loss: 0.3365 - accuracy: 0.8759 - precision: 0.8759 - recall: 0.8759 - auc: 0.9274 - f1_score: 0.8452 - val_loss: 0.3200 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9462 - val_f1_score: 0.8582 - lr: 1.0000e-05
# Epoch 75/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3350 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9281 - f1_score: 0.8466 - val_loss: 0.3136 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9473 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 76/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3339 - accuracy: 0.8799 - precision: 0.8799 - recall: 0.8799 - auc: 0.9281 - f1_score: 0.8511 - val_loss: 0.3216 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9457 - val_f1_score: 0.8376 - lr: 1.0000e-05
# Epoch 77/100
# 94/94 [==============================] - 31s 330ms/step - loss: 0.3339 - accuracy: 0.8799 - precision: 0.8799 - recall: 0.8799 - auc: 0.9284 - f1_score: 0.8511 - val_loss: 0.3253 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9414 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 78/100
# 94/94 [==============================] - 32s 338ms/step - loss: 0.3351 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9283 - f1_score: 0.8487 - val_loss: 0.3173 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9455 - val_f1_score: 0.8582 - lr: 1.0000e-05
# Epoch 79/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3343 - accuracy: 0.8813 - precision: 0.8813 - recall: 0.8813 - auc: 0.9279 - f1_score: 0.8536 - val_loss: 0.3281 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9381 - val_f1_score: 0.8376 - lr: 1.0000e-05
# Epoch 80/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3332 - accuracy: 0.8786 - precision: 0.8786 - recall: 0.8786 - auc: 0.9285 - f1_score: 0.8490 - val_loss: 0.3237 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9409 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 81/100
# 94/94 [==============================] - 32s 340ms/step - loss: 0.3363 - accuracy: 0.8806 - precision: 0.8806 - recall: 0.8806 - auc: 0.9274 - f1_score: 0.8521 - val_loss: 0.3227 - val_accuracy: 0.8688 - val_precision: 0.8688 - val_recall: 0.8688 - val_auc: 0.9443 - val_f1_score: 0.8234 - lr: 1.0000e-05
# Epoch 82/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3348 - accuracy: 0.8799 - precision: 0.8799 - recall: 0.8799 - auc: 0.9276 - f1_score: 0.8513 - val_loss: 0.3180 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9449 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 83/100
# 94/94 [==============================] - 32s 339ms/step - loss: 0.3327 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9287 - f1_score: 0.8496 - val_loss: 0.3210 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9416 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 84/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3331 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9292 - f1_score: 0.8483 - val_loss: 0.3242 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9384 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 85/100
# 94/94 [==============================] - 31s 333ms/step - loss: 0.3322 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9294 - f1_score: 0.8504 - val_loss: 0.3209 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9447 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 86/100
# 94/94 [==============================] - 32s 338ms/step - loss: 0.3323 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9295 - f1_score: 0.8471 - val_loss: 0.3181 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9477 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 87/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3313 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9297 - f1_score: 0.8511 - val_loss: 0.3277 - val_accuracy: 0.8959 - val_precision: 0.8959 - val_recall: 0.8959 - val_auc: 0.9375 - val_f1_score: 0.8633 - lr: 1.0000e-05
# Epoch 88/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3312 - accuracy: 0.8786 - precision: 0.8786 - recall: 0.8786 - auc: 0.9298 - f1_score: 0.8490 - val_loss: 0.3135 - val_accuracy: 0.9050 - val_precision: 0.9050 - val_recall: 0.9050 - val_auc: 0.9471 - val_f1_score: 0.8766 - lr: 1.0000e-05
# Epoch 89/100
# 94/94 [==============================] - 31s 330ms/step - loss: 0.3343 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9282 - f1_score: 0.8504 - val_loss: 0.3201 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9433 - val_f1_score: 0.8496 - lr: 1.0000e-05
# Epoch 90/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3314 - accuracy: 0.8793 - precision: 0.8793 - recall: 0.8793 - auc: 0.9300 - f1_score: 0.8508 - val_loss: 0.3216 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9403 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 91/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3317 - accuracy: 0.8779 - precision: 0.8779 - recall: 0.8779 - auc: 0.9297 - f1_score: 0.8500 - val_loss: 0.3267 - val_accuracy: 0.8778 - val_precision: 0.8778 - val_recall: 0.8778 - val_auc: 0.9388 - val_f1_score: 0.8376 - lr: 1.0000e-05
# Epoch 92/100
# 94/94 [==============================] - 32s 341ms/step - loss: 0.3304 - accuracy: 0.8826 - precision: 0.8826 - recall: 0.8826 - auc: 0.9307 - f1_score: 0.8545 - val_loss: 0.3132 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9482 - val_f1_score: 0.8445 - lr: 1.0000e-05
# Epoch 93/100
# 94/94 [==============================] - 32s 337ms/step - loss: 0.3320 - accuracy: 0.8813 - precision: 0.8813 - recall: 0.8813 - auc: 0.9297 - f1_score: 0.8530 - val_loss: 0.3184 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9491 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 94/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3307 - accuracy: 0.8766 - precision: 0.8766 - recall: 0.8766 - auc: 0.9307 - f1_score: 0.8471 - val_loss: 0.3260 - val_accuracy: 0.8959 - val_precision: 0.8959 - val_recall: 0.8959 - val_auc: 0.9385 - val_f1_score: 0.8633 - lr: 1.0000e-05
# Epoch 95/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3313 - accuracy: 0.8806 - precision: 0.8806 - recall: 0.8806 - auc: 0.9291 - f1_score: 0.8516 - val_loss: 0.3194 - val_accuracy: 0.9005 - val_precision: 0.9005 - val_recall: 0.9005 - val_auc: 0.9416 - val_f1_score: 0.8714 - lr: 1.0000e-05
# Epoch 96/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3304 - accuracy: 0.8826 - precision: 0.8826 - recall: 0.8826 - auc: 0.9301 - f1_score: 0.8540 - val_loss: 0.3102 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9515 - val_f1_score: 0.8582 - lr: 1.0000e-05
# Epoch 97/100
# 94/94 [==============================] - 32s 336ms/step - loss: 0.3287 - accuracy: 0.8840 - precision: 0.8840 - recall: 0.8840 - auc: 0.9309 - f1_score: 0.8570 - val_loss: 0.3263 - val_accuracy: 0.8824 - val_precision: 0.8824 - val_recall: 0.8824 - val_auc: 0.9388 - val_f1_score: 0.8427 - lr: 1.0000e-05
# Epoch 98/100
# 94/94 [==============================] - 31s 334ms/step - loss: 0.3322 - accuracy: 0.8759 - precision: 0.8759 - recall: 0.8759 - auc: 0.9302 - f1_score: 0.8457 - val_loss: 0.3181 - val_accuracy: 0.8914 - val_precision: 0.8914 - val_recall: 0.8914 - val_auc: 0.9453 - val_f1_score: 0.8582 - lr: 1.0000e-05
# Epoch 99/100
# 94/94 [==============================] - 31s 333ms/step - loss: 0.3305 - accuracy: 0.8773 - precision: 0.8773 - recall: 0.8773 - auc: 0.9305 - f1_score: 0.8478 - val_loss: 0.3200 - val_accuracy: 0.8869 - val_precision: 0.8869 - val_recall: 0.8869 - val_auc: 0.9439 - val_f1_score: 0.8514 - lr: 1.0000e-05
# Epoch 100/100
# 94/94 [==============================] - 31s 332ms/step - loss: 0.3298 - accuracy: 0.8799 - precision: 0.8799 - recall: 0.8799 - auc: 0.9311 - f1_score: 0.8507 - val_loss: 0.3123 - val_accuracy: 0.9005 - val_precision: 0.9005 - val_recall: 0.9005 - val_auc: 0.9474 - val_f1_score: 0.8714 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 0s 9ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.8164903784885944
# F1-Score for each class: [0.74576271 0.88721805]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.8894472361809045
# specificity: 0.7415730337078652

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 8ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 19/19 [==============================] - 3s 166ms/step - loss: 0.3928 - accuracy: 0.8439 - precision: 0.8439 - recall: 0.8439 - auc: 0.8993 - f1_score: 0.8166
# Test loss: 0.3927591145038605
# Test accuracy: 0.8438538312911987
# Test precision: 0.8438538312911987
# Test recall: 0.8438538312911987
# Test AUC: 0.899311363697052
# Test F1 Score: 0.8166180849075317

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 9ms/step
#               precision    recall  f1-score   support
#
#            0       0.75      0.74      0.75        89
#            1       0.89      0.89      0.89       199
#
#     accuracy                           0.84       288
#    macro avg       0.82      0.82      0.82       288
# weighted avg       0.84      0.84      0.84       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
