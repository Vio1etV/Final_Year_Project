# %%
import os
import tensorflow as tf
from keras.models import Model
from keras.layers import Input, Conv2D, BatchNormalization,Activation, concatenate, DepthwiseConv2D, Multiply,Dropout
from keras.layers import GlobalAveragePooling2D, Dense, MaxPooling2D,Flatten, Layer,BatchNormalization, Add,Reshape,AveragePooling2D

from keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.optimizers import Adam


from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/BCResize/200X/test'
train_dir = '/root/BreastCancer/BCResize/200X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/BCResize/200X/test/benign'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 1952 images belonging to 2 classes.
# Found 290 images belonging to 2 classes.
# Found 301 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %% [markdown]
# <h1>Model Construction<h1>

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Add, GlobalAveragePooling2D, Dense

def resnet(input_shape, num_classes):
    inputs = Input(shape=input_shape)

    # Input Convolution
    x = Conv2D(64, (7, 7), strides=(2, 2), padding='same', activation='relu', kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Residual Blocks
    for filters in [64, 128, 64, 128]:
        # Residual connection
        identity = x

        # Adjust the number of filters in identity to match x if necessary
        if identity.shape[-1] != filters:
            identity = Conv2D(filters, (1, 1), padding='same', activation='relu', kernel_initializer='he_normal')(identity)
            identity = BatchNormalization()(identity)

        # First Convolution
        x = Conv2D(filters, (3, 3), padding='same', activation='relu', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)

        # Second Convolution
        x = Conv2D(filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
        x = BatchNormalization()(x)

        # Add Residual Connection
        x = Add()([x, identity])
        x = Activation('relu')(x)

        # Optional: Additional MaxPooling
        x = MaxPooling2D((2, 2), strides=(2, 2), padding='same')(x)

    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model


# Create the ResNet model
model = resnet(input_shape, num_classes)

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 64)   36928       ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 56, 56, 64)   0           ['batch_normalization_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation (Activation)        (None, 56, 56, 64)   0           ['add[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 64)  0           ['activation[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 28, 28, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 28, 28, 128)  147584      ['batch_normalization_4[0][0]']
# 2023-12-24 18:23:44.403077: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 18:23:44.927433: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
#  conv2d_3 (Conv2D)              (None, 28, 28, 128)  8320        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 28, 28, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 28, 28, 128)  0           ['batch_normalization_5[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  activation_1 (Activation)      (None, 28, 28, 128)  0           ['add_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 128)  0          ['activation_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 14, 14, 64)   73792       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 14, 14, 64)   36928       ['batch_normalization_7[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 14, 14, 64)   8256        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 14, 14, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 14, 14, 64)   0           ['batch_normalization_8[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  activation_2 (Activation)      (None, 14, 14, 64)   0           ['add_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 64)    0           ['activation_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 7, 7, 128)    73856       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 7, 7, 128)   512         ['conv2d_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 7, 7, 128)    147584      ['batch_normalization_10[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 7, 7, 128)    8320        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 7, 7, 128)   512         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_9 (BatchNo  (None, 7, 7, 128)   512         ['conv2d_9[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 7, 7, 128)    0           ['batch_normalization_11[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  activation_3 (Activation)      (None, 7, 7, 128)    0           ['add_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 128)   0           ['activation_3[0][0]']
#
#  global_average_pooling2d (Glob  (None, 128)         0           ['max_pooling2d_4[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            258         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 666,690
# Trainable params: 664,386
# Non-trainable params: 2,304
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "ResNet200XResized"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/2. ResNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-24 18:23:49.406191: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-24 18:23:51.028681: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 61/61 [==============================] - 28s 378ms/step - loss: 0.4053 - accuracy: 0.8176 - precision: 0.8176 - recall: 0.8176 - auc: 0.9032 - f1_score: 0.8176 - val_loss: 1.7982 - val_accuracy: 0.4724 - val_precision: 0.4724 - val_recall: 0.4724 - val_auc: 0.3959 - val_f1_score: 0.4724 - lr: 0.0010
# Epoch 2/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.3129 - accuracy: 0.8668 - precision: 0.8668 - recall: 0.8668 - auc: 0.9405 - f1_score: 0.8668 - val_loss: 1.3260 - val_accuracy: 0.4586 - val_precision: 0.4586 - val_recall: 0.4586 - val_auc: 0.2947 - val_f1_score: 0.4586 - lr: 0.0010
# Epoch 3/100
# 61/61 [==============================] - 23s 372ms/step - loss: 0.2468 - accuracy: 0.8878 - precision: 0.8878 - recall: 0.8878 - auc: 0.9627 - f1_score: 0.8878 - val_loss: 2.5213 - val_accuracy: 0.5276 - val_precision: 0.5276 - val_recall: 0.5276 - val_auc: 0.5978 - val_f1_score: 0.5276 - lr: 0.0010
# Epoch 4/100
# 61/61 [==============================] - 23s 372ms/step - loss: 0.2568 - accuracy: 0.8934 - precision: 0.8934 - recall: 0.8934 - auc: 0.9595 - f1_score: 0.8934 - val_loss: 1.6200 - val_accuracy: 0.3207 - val_precision: 0.3207 - val_recall: 0.3207 - val_auc: 0.3031 - val_f1_score: 0.3207 - lr: 0.0010
# Epoch 5/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.2381 - accuracy: 0.8914 - precision: 0.8914 - recall: 0.8914 - auc: 0.9652 - f1_score: 0.8914 - val_loss: 0.7441 - val_accuracy: 0.6103 - val_precision: 0.6103 - val_recall: 0.6103 - val_auc: 0.7526 - val_f1_score: 0.6103 - lr: 0.0010
# Epoch 6/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.2247 - accuracy: 0.8986 - precision: 0.8986 - recall: 0.8986 - auc: 0.9689 - f1_score: 0.8986 - val_loss: 1.7265 - val_accuracy: 0.6172 - val_precision: 0.6172 - val_recall: 0.6172 - val_auc: 0.6877 - val_f1_score: 0.6172 - lr: 0.0010
# Epoch 7/100
# 61/61 [==============================] - 23s 372ms/step - loss: 0.1936 - accuracy: 0.9180 - precision: 0.9180 - recall: 0.9180 - auc: 0.9772 - f1_score: 0.9180 - val_loss: 3.8152 - val_accuracy: 0.4138 - val_precision: 0.4138 - val_recall: 0.4138 - val_auc: 0.3502 - val_f1_score: 0.4138 - lr: 0.0010
# Epoch 8/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.1606 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9843 - f1_score: 0.9293 - val_loss: 3.7293 - val_accuracy: 0.5310 - val_precision: 0.5310 - val_recall: 0.5310 - val_auc: 0.4749 - val_f1_score: 0.5310 - lr: 0.0010
# Epoch 9/100
# 61/61 [==============================] - 23s 371ms/step - loss: 0.1710 - accuracy: 0.9303 - precision: 0.9303 - recall: 0.9303 - auc: 0.9819 - f1_score: 0.9303 - val_loss: 0.7237 - val_accuracy: 0.6414 - val_precision: 0.6414 - val_recall: 0.6414 - val_auc: 0.6699 - val_f1_score: 0.6414 - lr: 0.0010
# Epoch 10/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.1604 - accuracy: 0.9344 - precision: 0.9344 - recall: 0.9344 - auc: 0.9841 - f1_score: 0.9344 - val_loss: 1.6772 - val_accuracy: 0.4103 - val_precision: 0.4103 - val_recall: 0.4103 - val_auc: 0.4110 - val_f1_score: 0.4103 - lr: 0.0010
# Epoch 11/100
# 61/61 [==============================] - 23s 374ms/step - loss: 0.1551 - accuracy: 0.9395 - precision: 0.9395 - recall: 0.9395 - auc: 0.9849 - f1_score: 0.9395 - val_loss: 0.5888 - val_accuracy: 0.7379 - val_precision: 0.7379 - val_recall: 0.7379 - val_auc: 0.8576 - val_f1_score: 0.7379 - lr: 0.0010
# Epoch 12/100
# 61/61 [==============================] - 23s 373ms/step - loss: 0.1734 - accuracy: 0.9237 - precision: 0.9237 - recall: 0.9237 - auc: 0.9816 - f1_score: 0.9237 - val_loss: 0.7425 - val_accuracy: 0.8207 - val_precision: 0.8207 - val_recall: 0.8207 - val_auc: 0.8443 - val_f1_score: 0.8207 - lr: 0.0010
# Epoch 13/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.1532 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9859 - f1_score: 0.9355 - val_loss: 1.3604 - val_accuracy: 0.5138 - val_precision: 0.5138 - val_recall: 0.5138 - val_auc: 0.5215 - val_f1_score: 0.5138 - lr: 0.0010
# Epoch 14/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.1520 - accuracy: 0.9365 - precision: 0.9365 - recall: 0.9365 - auc: 0.9861 - f1_score: 0.9365 - val_loss: 1.3468 - val_accuracy: 0.5966 - val_precision: 0.5966 - val_recall: 0.5966 - val_auc: 0.6968 - val_f1_score: 0.5966 - lr: 0.0010
# Epoch 15/100
# 61/61 [==============================] - 22s 369ms/step - loss: 0.1695 - accuracy: 0.9298 - precision: 0.9298 - recall: 0.9298 - auc: 0.9821 - f1_score: 0.9298 - val_loss: 2.8958 - val_accuracy: 0.4724 - val_precision: 0.4724 - val_recall: 0.4724 - val_auc: 0.4424 - val_f1_score: 0.4724 - lr: 0.0010
# Epoch 16/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.1397 - accuracy: 0.9472 - precision: 0.9472 - recall: 0.9472 - auc: 0.9880 - f1_score: 0.9472 - val_loss: 0.6495 - val_accuracy: 0.6517 - val_precision: 0.6517 - val_recall: 0.6517 - val_auc: 0.6916 - val_f1_score: 0.6517 - lr: 0.0010
# Epoch 17/100
# 61/61 [==============================] - 23s 371ms/step - loss: 0.1576 - accuracy: 0.9401 - precision: 0.9401 - recall: 0.9401 - auc: 0.9843 - f1_score: 0.9401 - val_loss: 1.0553 - val_accuracy: 0.4552 - val_precision: 0.4552 - val_recall: 0.4552 - val_auc: 0.4798 - val_f1_score: 0.4552 - lr: 0.0010
# Epoch 18/100
# 61/61 [==============================] - 23s 371ms/step - loss: 0.1276 - accuracy: 0.9498 - precision: 0.9498 - recall: 0.9498 - auc: 0.9903 - f1_score: 0.9498 - val_loss: 1.9814 - val_accuracy: 0.5241 - val_precision: 0.5241 - val_recall: 0.5241 - val_auc: 0.6238 - val_f1_score: 0.5241 - lr: 0.0010
# Epoch 19/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.1387 - accuracy: 0.9395 - precision: 0.9395 - recall: 0.9395 - auc: 0.9880 - f1_score: 0.9395 - val_loss: 1.2536 - val_accuracy: 0.5862 - val_precision: 0.5862 - val_recall: 0.5862 - val_auc: 0.7081 - val_f1_score: 0.5862 - lr: 0.0010
# Epoch 20/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.1247 - accuracy: 0.9503 - precision: 0.9503 - recall: 0.9503 - auc: 0.9907 - f1_score: 0.9503 - val_loss: 2.6766 - val_accuracy: 0.5276 - val_precision: 0.5276 - val_recall: 0.5276 - val_auc: 0.5684 - val_f1_score: 0.5276 - lr: 0.0010
# Epoch 21/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1194 - accuracy: 0.9534 - precision: 0.9534 - recall: 0.9534 - auc: 0.9910 - f1_score: 0.9534
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 61/61 [==============================] - 23s 374ms/step - loss: 0.1194 - accuracy: 0.9534 - precision: 0.9534 - recall: 0.9534 - auc: 0.9910 - f1_score: 0.9534 - val_loss: 2.5142 - val_accuracy: 0.5241 - val_precision: 0.5241 - val_recall: 0.5241 - val_auc: 0.6388 - val_f1_score: 0.5241 - lr: 0.0010
# Epoch 22/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0972 - accuracy: 0.9662 - precision: 0.9662 - recall: 0.9662 - auc: 0.9946 - f1_score: 0.9662 - val_loss: 0.9532 - val_accuracy: 0.8034 - val_precision: 0.8034 - val_recall: 0.8034 - val_auc: 0.8289 - val_f1_score: 0.8034 - lr: 1.0000e-04
# Epoch 23/100
# 61/61 [==============================] - 23s 372ms/step - loss: 0.0747 - accuracy: 0.9713 - precision: 0.9713 - recall: 0.9713 - auc: 0.9970 - f1_score: 0.9713 - val_loss: 1.0284 - val_accuracy: 0.6828 - val_precision: 0.6828 - val_recall: 0.6828 - val_auc: 0.7813 - val_f1_score: 0.6828 - lr: 1.0000e-04
# Epoch 24/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.0656 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9979 - f1_score: 0.9764 - val_loss: 0.8555 - val_accuracy: 0.7931 - val_precision: 0.7931 - val_recall: 0.7931 - val_auc: 0.8440 - val_f1_score: 0.7931 - lr: 1.0000e-04
# Epoch 25/100
# 61/61 [==============================] - 23s 371ms/step - loss: 0.0675 - accuracy: 0.9749 - precision: 0.9749 - recall: 0.9749 - auc: 0.9975 - f1_score: 0.9749 - val_loss: 0.9967 - val_accuracy: 0.7172 - val_precision: 0.7172 - val_recall: 0.7172 - val_auc: 0.7897 - val_f1_score: 0.7172 - lr: 1.0000e-04
# Epoch 26/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.0761 - accuracy: 0.9713 - precision: 0.9713 - recall: 0.9713 - auc: 0.9963 - f1_score: 0.9713 - val_loss: 0.9268 - val_accuracy: 0.6897 - val_precision: 0.6897 - val_recall: 0.6897 - val_auc: 0.8015 - val_f1_score: 0.6897 - lr: 1.0000e-04
# Epoch 27/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0650 - accuracy: 0.9734 - precision: 0.9734 - recall: 0.9734 - auc: 0.9977 - f1_score: 0.9734 - val_loss: 0.5232 - val_accuracy: 0.8690 - val_precision: 0.8690 - val_recall: 0.8690 - val_auc: 0.9228 - val_f1_score: 0.8690 - lr: 1.0000e-04
# Epoch 28/100
# 61/61 [==============================] - 23s 372ms/step - loss: 0.0656 - accuracy: 0.9744 - precision: 0.9744 - recall: 0.9744 - auc: 0.9972 - f1_score: 0.9744 - val_loss: 0.6643 - val_accuracy: 0.7793 - val_precision: 0.7793 - val_recall: 0.7793 - val_auc: 0.8736 - val_f1_score: 0.7793 - lr: 1.0000e-04
# Epoch 29/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.0509 - accuracy: 0.9826 - precision: 0.9826 - recall: 0.9826 - auc: 0.9986 - f1_score: 0.9826 - val_loss: 0.4681 - val_accuracy: 0.8828 - val_precision: 0.8828 - val_recall: 0.8828 - val_auc: 0.9268 - val_f1_score: 0.8828 - lr: 1.0000e-04
# Epoch 30/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.0533 - accuracy: 0.9805 - precision: 0.9805 - recall: 0.9805 - auc: 0.9985 - f1_score: 0.9805 - val_loss: 0.2911 - val_accuracy: 0.8862 - val_precision: 0.8862 - val_recall: 0.8862 - val_auc: 0.9600 - val_f1_score: 0.8862 - lr: 1.0000e-04
# Epoch 31/100
# 61/61 [==============================] - 23s 373ms/step - loss: 0.0586 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9981 - f1_score: 0.9764 - val_loss: 0.9286 - val_accuracy: 0.6793 - val_precision: 0.6793 - val_recall: 0.6793 - val_auc: 0.8206 - val_f1_score: 0.6793 - lr: 1.0000e-04
# Epoch 32/100
# 61/61 [==============================] - 23s 373ms/step - loss: 0.0656 - accuracy: 0.9764 - precision: 0.9764 - recall: 0.9764 - auc: 0.9971 - f1_score: 0.9764 - val_loss: 0.9111 - val_accuracy: 0.8483 - val_precision: 0.8483 - val_recall: 0.8483 - val_auc: 0.8711 - val_f1_score: 0.8483 - lr: 1.0000e-04
# Epoch 33/100
# 61/61 [==============================] - 22s 369ms/step - loss: 0.0590 - accuracy: 0.9790 - precision: 0.9790 - recall: 0.9790 - auc: 0.9977 - f1_score: 0.9790 - val_loss: 0.8261 - val_accuracy: 0.7276 - val_precision: 0.7276 - val_recall: 0.7276 - val_auc: 0.8323 - val_f1_score: 0.7276 - lr: 1.0000e-04
# Epoch 34/100
# 61/61 [==============================] - 23s 372ms/step - loss: 0.0490 - accuracy: 0.9810 - precision: 0.9810 - recall: 0.9810 - auc: 0.9987 - f1_score: 0.9810 - val_loss: 0.5533 - val_accuracy: 0.8690 - val_precision: 0.8690 - val_recall: 0.8690 - val_auc: 0.9063 - val_f1_score: 0.8690 - lr: 1.0000e-04
# Epoch 35/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.0551 - accuracy: 0.9795 - precision: 0.9795 - recall: 0.9795 - auc: 0.9982 - f1_score: 0.9795 - val_loss: 0.2437 - val_accuracy: 0.9207 - val_precision: 0.9207 - val_recall: 0.9207 - val_auc: 0.9698 - val_f1_score: 0.9207 - lr: 1.0000e-04
# Epoch 36/100
# 61/61 [==============================] - 23s 373ms/step - loss: 0.0559 - accuracy: 0.9795 - precision: 0.9795 - recall: 0.9795 - auc: 0.9978 - f1_score: 0.9795 - val_loss: 0.4125 - val_accuracy: 0.8966 - val_precision: 0.8966 - val_recall: 0.8966 - val_auc: 0.9429 - val_f1_score: 0.8966 - lr: 1.0000e-04
# Epoch 37/100
# 61/61 [==============================] - 23s 373ms/step - loss: 0.0550 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9982 - f1_score: 0.9775 - val_loss: 0.3487 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9510 - val_f1_score: 0.8897 - lr: 1.0000e-04
# Epoch 38/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0565 - accuracy: 0.9821 - precision: 0.9821 - recall: 0.9821 - auc: 0.9980 - f1_score: 0.9821 - val_loss: 0.5093 - val_accuracy: 0.8759 - val_precision: 0.8759 - val_recall: 0.8759 - val_auc: 0.9245 - val_f1_score: 0.8759 - lr: 1.0000e-04
# Epoch 39/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.0501 - accuracy: 0.9810 - precision: 0.9810 - recall: 0.9810 - auc: 0.9986 - f1_score: 0.9810 - val_loss: 0.3368 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9514 - val_f1_score: 0.8931 - lr: 1.0000e-04
# Epoch 40/100
# 61/61 [==============================] - 22s 369ms/step - loss: 0.0501 - accuracy: 0.9826 - precision: 0.9826 - recall: 0.9826 - auc: 0.9985 - f1_score: 0.9826 - val_loss: 0.7738 - val_accuracy: 0.8379 - val_precision: 0.8379 - val_recall: 0.8379 - val_auc: 0.8679 - val_f1_score: 0.8379 - lr: 1.0000e-04
# Epoch 41/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0438 - accuracy: 0.9816 - precision: 0.9816 - recall: 0.9816 - auc: 0.9990 - f1_score: 0.9816 - val_loss: 0.7183 - val_accuracy: 0.7828 - val_precision: 0.7828 - val_recall: 0.7828 - val_auc: 0.8555 - val_f1_score: 0.7828 - lr: 1.0000e-04
# Epoch 42/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0406 - accuracy: 0.9841 - precision: 0.9841 - recall: 0.9841 - auc: 0.9991 - f1_score: 0.9841 - val_loss: 0.4693 - val_accuracy: 0.8655 - val_precision: 0.8655 - val_recall: 0.8655 - val_auc: 0.9240 - val_f1_score: 0.8655 - lr: 1.0000e-04
# Epoch 43/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.0446 - accuracy: 0.9795 - precision: 0.9795 - recall: 0.9795 - auc: 0.9990 - f1_score: 0.9795 - val_loss: 0.5593 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9139 - val_f1_score: 0.8897 - lr: 1.0000e-04
# Epoch 44/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0516 - accuracy: 0.9805 - precision: 0.9805 - recall: 0.9805 - auc: 0.9985 - f1_score: 0.9805 - val_loss: 0.3400 - val_accuracy: 0.9000 - val_precision: 0.9000 - val_recall: 0.9000 - val_auc: 0.9582 - val_f1_score: 0.9000 - lr: 1.0000e-04
# Epoch 45/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9846 - precision: 0.9846 - recall: 0.9846 - auc: 0.9983 - f1_score: 0.9846
# Epoch 45: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 61/61 [==============================] - 22s 365ms/step - loss: 0.0465 - accuracy: 0.9846 - precision: 0.9846 - recall: 0.9846 - auc: 0.9983 - f1_score: 0.9846 - val_loss: 0.6182 - val_accuracy: 0.7966 - val_precision: 0.7966 - val_recall: 0.7966 - val_auc: 0.8897 - val_f1_score: 0.7966 - lr: 1.0000e-04
# Epoch 46/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.0376 - accuracy: 0.9851 - precision: 0.9851 - recall: 0.9851 - auc: 0.9991 - f1_score: 0.9851 - val_loss: 0.4913 - val_accuracy: 0.8966 - val_precision: 0.8966 - val_recall: 0.8966 - val_auc: 0.9227 - val_f1_score: 0.8966 - lr: 1.0000e-05
# Epoch 47/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0457 - accuracy: 0.9857 - precision: 0.9857 - recall: 0.9857 - auc: 0.9979 - f1_score: 0.9857 - val_loss: 0.5517 - val_accuracy: 0.8828 - val_precision: 0.8828 - val_recall: 0.8828 - val_auc: 0.9214 - val_f1_score: 0.8828 - lr: 1.0000e-05
# Epoch 48/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.0362 - accuracy: 0.9887 - precision: 0.9887 - recall: 0.9887 - auc: 0.9993 - f1_score: 0.9887 - val_loss: 0.5755 - val_accuracy: 0.8862 - val_precision: 0.8862 - val_recall: 0.8862 - val_auc: 0.9263 - val_f1_score: 0.8862 - lr: 1.0000e-05
# Epoch 49/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.0359 - accuracy: 0.9898 - precision: 0.9898 - recall: 0.9898 - auc: 0.9993 - f1_score: 0.9898 - val_loss: 0.5933 - val_accuracy: 0.8793 - val_precision: 0.8793 - val_recall: 0.8793 - val_auc: 0.9129 - val_f1_score: 0.8793 - lr: 1.0000e-05
# Epoch 50/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.0409 - accuracy: 0.9826 - precision: 0.9826 - recall: 0.9826 - auc: 0.9991 - f1_score: 0.9826 - val_loss: 0.6014 - val_accuracy: 0.8793 - val_precision: 0.8793 - val_recall: 0.8793 - val_auc: 0.9165 - val_f1_score: 0.8793 - lr: 1.0000e-05
# Epoch 51/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.0357 - accuracy: 0.9898 - precision: 0.9898 - recall: 0.9898 - auc: 0.9995 - f1_score: 0.9898 - val_loss: 0.5412 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9242 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 52/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0417 - accuracy: 0.9821 - precision: 0.9821 - recall: 0.9821 - auc: 0.9990 - f1_score: 0.9821 - val_loss: 0.5426 - val_accuracy: 0.8759 - val_precision: 0.8759 - val_recall: 0.8759 - val_auc: 0.9298 - val_f1_score: 0.8759 - lr: 1.0000e-05
# Epoch 53/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.0446 - accuracy: 0.9846 - precision: 0.9846 - recall: 0.9846 - auc: 0.9988 - f1_score: 0.9846 - val_loss: 0.5656 - val_accuracy: 0.8828 - val_precision: 0.8828 - val_recall: 0.8828 - val_auc: 0.9173 - val_f1_score: 0.8828 - lr: 1.0000e-05
# Epoch 54/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.0393 - accuracy: 0.9857 - precision: 0.9857 - recall: 0.9857 - auc: 0.9991 - f1_score: 0.9857 - val_loss: 0.5189 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9317 - val_f1_score: 0.8931 - lr: 1.0000e-05
# Epoch 55/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0499 - accuracy: 0.9846 - precision: 0.9846 - recall: 0.9846 - auc: 0.9983 - f1_score: 0.9846
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1e-05.
# 61/61 [==============================] - 22s 366ms/step - loss: 0.0499 - accuracy: 0.9846 - precision: 0.9846 - recall: 0.9846 - auc: 0.9983 - f1_score: 0.9846 - val_loss: 0.5792 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9119 - val_f1_score: 0.8931 - lr: 1.0000e-05
# Epoch 56/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.0328 - accuracy: 0.9882 - precision: 0.9882 - recall: 0.9882 - auc: 0.9995 - f1_score: 0.9882 - val_loss: 0.5807 - val_accuracy: 0.8828 - val_precision: 0.8828 - val_recall: 0.8828 - val_auc: 0.9182 - val_f1_score: 0.8828 - lr: 1.0000e-05
# Epoch 57/100
# 61/61 [==============================] - 22s 369ms/step - loss: 0.0385 - accuracy: 0.9857 - precision: 0.9857 - recall: 0.9857 - auc: 0.9992 - f1_score: 0.9857 - val_loss: 0.5581 - val_accuracy: 0.9000 - val_precision: 0.9000 - val_recall: 0.9000 - val_auc: 0.9258 - val_f1_score: 0.9000 - lr: 1.0000e-05
# Epoch 58/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.0325 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9995 - f1_score: 0.9872 - val_loss: 0.5808 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9215 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 59/100
# 61/61 [==============================] - 22s 369ms/step - loss: 0.0316 - accuracy: 0.9867 - precision: 0.9867 - recall: 0.9867 - auc: 0.9996 - f1_score: 0.9867 - val_loss: 0.5362 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9343 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 60/100
# 61/61 [==============================] - 22s 364ms/step - loss: 0.0387 - accuracy: 0.9857 - precision: 0.9857 - recall: 0.9857 - auc: 0.9993 - f1_score: 0.9857 - val_loss: 0.5399 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9288 - val_f1_score: 0.8931 - lr: 1.0000e-05
# Epoch 61/100
# 61/61 [==============================] - 23s 371ms/step - loss: 0.0389 - accuracy: 0.9887 - precision: 0.9887 - recall: 0.9887 - auc: 0.9992 - f1_score: 0.9887 - val_loss: 0.5418 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9321 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 62/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0380 - accuracy: 0.9887 - precision: 0.9887 - recall: 0.9887 - auc: 0.9991 - f1_score: 0.9887 - val_loss: 0.6002 - val_accuracy: 0.8828 - val_precision: 0.8828 - val_recall: 0.8828 - val_auc: 0.9115 - val_f1_score: 0.8828 - lr: 1.0000e-05
# Epoch 63/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.0392 - accuracy: 0.9836 - precision: 0.9836 - recall: 0.9836 - auc: 0.9992 - f1_score: 0.9836 - val_loss: 0.5866 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9229 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 64/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.0340 - accuracy: 0.9862 - precision: 0.9862 - recall: 0.9862 - auc: 0.9995 - f1_score: 0.9862 - val_loss: 0.5751 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9155 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 65/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.0318 - accuracy: 0.9862 - precision: 0.9862 - recall: 0.9862 - auc: 0.9995 - f1_score: 0.9862 - val_loss: 0.6103 - val_accuracy: 0.8828 - val_precision: 0.8828 - val_recall: 0.8828 - val_auc: 0.9248 - val_f1_score: 0.8828 - lr: 1.0000e-05
# Epoch 66/100
# 61/61 [==============================] - 22s 364ms/step - loss: 0.0304 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9996 - f1_score: 0.9903 - val_loss: 0.5590 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9223 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 67/100
# 61/61 [==============================] - 23s 369ms/step - loss: 0.0382 - accuracy: 0.9887 - precision: 0.9887 - recall: 0.9887 - auc: 0.9992 - f1_score: 0.9887 - val_loss: 0.6143 - val_accuracy: 0.8759 - val_precision: 0.8759 - val_recall: 0.8759 - val_auc: 0.9183 - val_f1_score: 0.8759 - lr: 1.0000e-05
# Epoch 68/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.0512 - accuracy: 0.9785 - precision: 0.9785 - recall: 0.9785 - auc: 0.9984 - f1_score: 0.9785 - val_loss: 0.6039 - val_accuracy: 0.8793 - val_precision: 0.8793 - val_recall: 0.8793 - val_auc: 0.9128 - val_f1_score: 0.8793 - lr: 1.0000e-05
# Epoch 69/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.0384 - accuracy: 0.9887 - precision: 0.9887 - recall: 0.9887 - auc: 0.9987 - f1_score: 0.9887 - val_loss: 0.5703 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9226 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 70/100
# 61/61 [==============================] - 22s 369ms/step - loss: 0.0390 - accuracy: 0.9857 - precision: 0.9857 - recall: 0.9857 - auc: 0.9992 - f1_score: 0.9857 - val_loss: 0.5771 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9075 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 71/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.0364 - accuracy: 0.9867 - precision: 0.9867 - recall: 0.9867 - auc: 0.9993 - f1_score: 0.9867 - val_loss: 0.5915 - val_accuracy: 0.8862 - val_precision: 0.8862 - val_recall: 0.8862 - val_auc: 0.9124 - val_f1_score: 0.8862 - lr: 1.0000e-05
# Epoch 72/100
# 61/61 [==============================] - 22s 363ms/step - loss: 0.0303 - accuracy: 0.9892 - precision: 0.9892 - recall: 0.9892 - auc: 0.9996 - f1_score: 0.9892 - val_loss: 0.6040 - val_accuracy: 0.8793 - val_precision: 0.8793 - val_recall: 0.8793 - val_auc: 0.9134 - val_f1_score: 0.8793 - lr: 1.0000e-05
# Epoch 73/100
# 61/61 [==============================] - 23s 372ms/step - loss: 0.0460 - accuracy: 0.9841 - precision: 0.9841 - recall: 0.9841 - auc: 0.9986 - f1_score: 0.9841 - val_loss: 0.5405 - val_accuracy: 0.8828 - val_precision: 0.8828 - val_recall: 0.8828 - val_auc: 0.9260 - val_f1_score: 0.8828 - lr: 1.0000e-05
# Epoch 74/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.0352 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9993 - f1_score: 0.9872 - val_loss: 0.4870 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9301 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 75/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.0386 - accuracy: 0.9831 - precision: 0.9831 - recall: 0.9831 - auc: 0.9993 - f1_score: 0.9831 - val_loss: 0.5617 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9219 - val_f1_score: 0.8931 - lr: 1.0000e-05
# Epoch 76/100
# 61/61 [==============================] - 22s 363ms/step - loss: 0.0428 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9988 - f1_score: 0.9872 - val_loss: 0.5432 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9301 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 77/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.0295 - accuracy: 0.9908 - precision: 0.9908 - recall: 0.9908 - auc: 0.9996 - f1_score: 0.9908 - val_loss: 0.5122 - val_accuracy: 0.8966 - val_precision: 0.8966 - val_recall: 0.8966 - val_auc: 0.9255 - val_f1_score: 0.8966 - lr: 1.0000e-05
# Epoch 78/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.0372 - accuracy: 0.9836 - precision: 0.9836 - recall: 0.9836 - auc: 0.9993 - f1_score: 0.9836 - val_loss: 0.5978 - val_accuracy: 0.8966 - val_precision: 0.8966 - val_recall: 0.8966 - val_auc: 0.9216 - val_f1_score: 0.8966 - lr: 1.0000e-05
# Epoch 79/100
# 61/61 [==============================] - 22s 363ms/step - loss: 0.0307 - accuracy: 0.9877 - precision: 0.9877 - recall: 0.9877 - auc: 0.9996 - f1_score: 0.9877 - val_loss: 0.5718 - val_accuracy: 0.8759 - val_precision: 0.8759 - val_recall: 0.8759 - val_auc: 0.9290 - val_f1_score: 0.8759 - lr: 1.0000e-05
# Epoch 80/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.0328 - accuracy: 0.9898 - precision: 0.9898 - recall: 0.9898 - auc: 0.9993 - f1_score: 0.9898 - val_loss: 0.5126 - val_accuracy: 0.8862 - val_precision: 0.8862 - val_recall: 0.8862 - val_auc: 0.9302 - val_f1_score: 0.8862 - lr: 1.0000e-05
# Epoch 81/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.0355 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9992 - f1_score: 0.9903 - val_loss: 0.5237 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9347 - val_f1_score: 0.8931 - lr: 1.0000e-05
# Epoch 82/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.0371 - accuracy: 0.9882 - precision: 0.9882 - recall: 0.9882 - auc: 0.9993 - f1_score: 0.9882 - val_loss: 0.5295 - val_accuracy: 0.8862 - val_precision: 0.8862 - val_recall: 0.8862 - val_auc: 0.9393 - val_f1_score: 0.8862 - lr: 1.0000e-05
# Epoch 83/100
# 61/61 [==============================] - 22s 364ms/step - loss: 0.0261 - accuracy: 0.9928 - precision: 0.9928 - recall: 0.9928 - auc: 0.9997 - f1_score: 0.9928 - val_loss: 0.6170 - val_accuracy: 0.8828 - val_precision: 0.8828 - val_recall: 0.8828 - val_auc: 0.9184 - val_f1_score: 0.8828 - lr: 1.0000e-05
# Epoch 84/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0395 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9990 - f1_score: 0.9872 - val_loss: 0.5731 - val_accuracy: 0.9000 - val_precision: 0.9000 - val_recall: 0.9000 - val_auc: 0.9202 - val_f1_score: 0.9000 - lr: 1.0000e-05
# Epoch 85/100
# 61/61 [==============================] - 22s 362ms/step - loss: 0.0370 - accuracy: 0.9862 - precision: 0.9862 - recall: 0.9862 - auc: 0.9992 - f1_score: 0.9862 - val_loss: 0.4968 - val_accuracy: 0.8828 - val_precision: 0.8828 - val_recall: 0.8828 - val_auc: 0.9267 - val_f1_score: 0.8828 - lr: 1.0000e-05
# Epoch 86/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.0410 - accuracy: 0.9857 - precision: 0.9857 - recall: 0.9857 - auc: 0.9990 - f1_score: 0.9857 - val_loss: 0.4852 - val_accuracy: 0.8966 - val_precision: 0.8966 - val_recall: 0.8966 - val_auc: 0.9382 - val_f1_score: 0.8966 - lr: 1.0000e-05
# Epoch 87/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0269 - accuracy: 0.9892 - precision: 0.9892 - recall: 0.9892 - auc: 0.9998 - f1_score: 0.9892 - val_loss: 0.5533 - val_accuracy: 0.8966 - val_precision: 0.8966 - val_recall: 0.8966 - val_auc: 0.9151 - val_f1_score: 0.8966 - lr: 1.0000e-05
# Epoch 88/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0321 - accuracy: 0.9908 - precision: 0.9908 - recall: 0.9908 - auc: 0.9994 - f1_score: 0.9908 - val_loss: 0.5424 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9303 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 89/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.0315 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9990 - f1_score: 0.9903 - val_loss: 0.5617 - val_accuracy: 0.8793 - val_precision: 0.8793 - val_recall: 0.8793 - val_auc: 0.9232 - val_f1_score: 0.8793 - lr: 1.0000e-05
# Epoch 90/100
# 61/61 [==============================] - 22s 367ms/step - loss: 0.0286 - accuracy: 0.9918 - precision: 0.9918 - recall: 0.9918 - auc: 0.9996 - f1_score: 0.9918 - val_loss: 0.5456 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9260 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 91/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.0305 - accuracy: 0.9903 - precision: 0.9903 - recall: 0.9903 - auc: 0.9996 - f1_score: 0.9903 - val_loss: 0.5467 - val_accuracy: 0.8793 - val_precision: 0.8793 - val_recall: 0.8793 - val_auc: 0.9240 - val_f1_score: 0.8793 - lr: 1.0000e-05
# Epoch 92/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.0355 - accuracy: 0.9872 - precision: 0.9872 - recall: 0.9872 - auc: 0.9992 - f1_score: 0.9872 - val_loss: 0.5554 - val_accuracy: 0.8862 - val_precision: 0.8862 - val_recall: 0.8862 - val_auc: 0.9361 - val_f1_score: 0.8862 - lr: 1.0000e-05
# Epoch 93/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.0380 - accuracy: 0.9836 - precision: 0.9836 - recall: 0.9836 - auc: 0.9992 - f1_score: 0.9836 - val_loss: 0.5588 - val_accuracy: 0.8759 - val_precision: 0.8759 - val_recall: 0.8759 - val_auc: 0.9211 - val_f1_score: 0.8759 - lr: 1.0000e-05
# Epoch 94/100
# 61/61 [==============================] - 22s 365ms/step - loss: 0.0377 - accuracy: 0.9867 - precision: 0.9867 - recall: 0.9867 - auc: 0.9992 - f1_score: 0.9867 - val_loss: 0.5556 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9274 - val_f1_score: 0.8931 - lr: 1.0000e-05
# Epoch 95/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0311 - accuracy: 0.9892 - precision: 0.9892 - recall: 0.9892 - auc: 0.9995 - f1_score: 0.9892 - val_loss: 0.5722 - val_accuracy: 0.8862 - val_precision: 0.8862 - val_recall: 0.8862 - val_auc: 0.9273 - val_f1_score: 0.8862 - lr: 1.0000e-05
# Epoch 96/100
# 61/61 [==============================] - 22s 366ms/step - loss: 0.0301 - accuracy: 0.9908 - precision: 0.9908 - recall: 0.9908 - auc: 0.9995 - f1_score: 0.9908 - val_loss: 0.4953 - val_accuracy: 0.8862 - val_precision: 0.8862 - val_recall: 0.8862 - val_auc: 0.9366 - val_f1_score: 0.8862 - lr: 1.0000e-05
# Epoch 97/100
# 61/61 [==============================] - 22s 363ms/step - loss: 0.0339 - accuracy: 0.9882 - precision: 0.9882 - recall: 0.9882 - auc: 0.9994 - f1_score: 0.9882 - val_loss: 0.4635 - val_accuracy: 0.8966 - val_precision: 0.8966 - val_recall: 0.8966 - val_auc: 0.9340 - val_f1_score: 0.8966 - lr: 1.0000e-05
# Epoch 98/100
# 61/61 [==============================] - 22s 368ms/step - loss: 0.0264 - accuracy: 0.9923 - precision: 0.9923 - recall: 0.9923 - auc: 0.9997 - f1_score: 0.9923 - val_loss: 0.4926 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9361 - val_f1_score: 0.8931 - lr: 1.0000e-05
# Epoch 99/100
# 61/61 [==============================] - 22s 364ms/step - loss: 0.0365 - accuracy: 0.9882 - precision: 0.9882 - recall: 0.9882 - auc: 0.9991 - f1_score: 0.9882 - val_loss: 0.4442 - val_accuracy: 0.8897 - val_precision: 0.8897 - val_recall: 0.8897 - val_auc: 0.9376 - val_f1_score: 0.8897 - lr: 1.0000e-05
# Epoch 100/100
# 61/61 [==============================] - 23s 370ms/step - loss: 0.0293 - accuracy: 0.9918 - precision: 0.9918 - recall: 0.9918 - auc: 0.9996 - f1_score: 0.9918 - val_loss: 0.5330 - val_accuracy: 0.8931 - val_precision: 0.8931 - val_recall: 0.8931 - val_auc: 0.9286 - val_f1_score: 0.8931 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 0s 9ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9602977667493796
# F1-Score for each class: [0.94623656 0.97435897]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.95
# specificity: 1.0

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs = model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 10ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 1s 84ms/step - loss: 0.1328 - accuracy: 0.9668 - precision: 0.9668 - recall: 0.9668 - auc: 0.9879 - f1_score: 0.9668
# Test loss: 0.1327613741159439
# Test accuracy: 0.9667773842811584
# Test precision: 0.9667773842811584
# Test recall: 0.9667773842811584
# Test AUC: 0.9878920912742615
# Test F1 Score: 0.9667773842811584

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95        88
#            1       1.00      0.95      0.97       200
#
#     accuracy                           0.97       288
#    macro avg       0.95      0.97      0.96       288
# weighted avg       0.97      0.97      0.97       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
