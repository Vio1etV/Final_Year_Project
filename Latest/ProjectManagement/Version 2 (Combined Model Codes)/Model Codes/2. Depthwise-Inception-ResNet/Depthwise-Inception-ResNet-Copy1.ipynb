# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/BreastCancer/BCResize/40X/test'
train_dir = '/root/BreastCancer/BCResize/40X/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_diabetic = '/root/BreastCancer/BCResize/40X/test/benign'

#Show the import original image
train_img_files = os.listdir(train_diabetic)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_diabetic, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2262 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 298 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    b = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    
    c = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    #Added
    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 5
num_B_blocks = 10
num_C_blocks = 5

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.5)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax')(x)

model = Model(inputs=inputs, outputs=predictions)
model.summary()
# Out:
# 2023-12-25 15:02:36.515487: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-25 15:02:37.047952: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22307 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:61:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 4)  112         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 220, 220, 4)  148         ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 220, 220, 8)  296         ['conv2d_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 218, 218, 12  876         ['conv2d_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 218, 218, 8)  456         ['conv2d_6[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 218, 218, 8)  456         ['conv2d_7[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 216, 216, 12  876         ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 216, 216, 12  876         ['conv2d_8[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_5[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_10[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation (Activation)        (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 214, 214, 4)  196         ['activation[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 214, 214, 4)  196         ['activation[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 214, 214, 4)  196         ['activation[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 4)  40         ['conv2d_12[0][0]']
#  v2D)
#
#  conv2d_14 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_13[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_11[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['activation[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  activation_1 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 4)  196         ['activation_1[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 4)  196         ['activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 4)  196         ['activation_1[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_17[0][0]']
#  onv2D)
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_18[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_16[0][0]',
#                                 )                                 'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 214, 214, 48  0           ['activation_1[0][0]',
#                                 )                                 'conv2d_20[0][0]']
#
#  activation_2 (Activation)      (None, 214, 214, 48  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 4)  196         ['activation_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 214, 214, 4)  196         ['activation_2[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 4)  196         ['activation_2[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_22[0][0]']
#  onv2D)
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_23[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_21[0][0]',
#                                 )                                 'depthwise_conv2d_2[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_5[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 214, 214, 48  0           ['activation_2[0][0]',
#                                 )                                 'conv2d_25[0][0]']
#
#  activation_3 (Activation)      (None, 214, 214, 48  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 214, 214, 4)  196         ['activation_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 214, 214, 4)  196         ['activation_3[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 214, 214, 4)  196         ['activation_3[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_27[0][0]']
#  onv2D)
#
#  conv2d_29 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_28[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_26[0][0]',
#                                 )                                 'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_6[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 214, 214, 48  0           ['activation_3[0][0]',
#                                 )                                 'conv2d_30[0][0]']
#
#  activation_4 (Activation)      (None, 214, 214, 48  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 214, 214, 4)  196         ['activation_4[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 214, 214, 4)  196         ['activation_4[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 214, 214, 4)  196         ['activation_4[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_32[0][0]']
#  onv2D)
#
#  conv2d_34 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_33[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_31[0][0]',
#                                 )                                 'depthwise_conv2d_4[0][0]',
#                                                                   'conv2d_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_7[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 214, 214, 48  0           ['activation_4[0][0]',
#                                 )                                 'conv2d_35[0][0]']
#
#  activation_5 (Activation)      (None, 214, 214, 48  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 214, 214, 32  1568        ['activation_5[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_37[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_5[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 106, 106, 48  20784       ['activation_5[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_38[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_36[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_41[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_42[0][0]']
#                                 )
#
#  conv2d_40 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_43[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_40[0][0]',
#                                 )                                 'conv2d_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_9[0][0]']
#                                 4)
#
#  add_5 (Add)                    (None, 106, 106, 14  0           ['concatenate_8[0][0]',
#                                 4)                                'conv2d_45[0][0]']
#
#  activation_6 (Activation)      (None, 106, 106, 14  0           ['add_5[0][0]']
#                                 4)
#
#  conv2d_47 (Conv2D)             (None, 106, 106, 16  2320        ['activation_6[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 106, 106, 24  3480        ['activation_6[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_49[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_46[0][0]',
#                                 )                                 'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_10[0][0]']
#                                 4)
#
#  add_6 (Add)                    (None, 106, 106, 14  0           ['activation_6[0][0]',
#                                 4)                                'conv2d_51[0][0]']
#
#  activation_7 (Activation)      (None, 106, 106, 14  0           ['add_6[0][0]']
#                                 4)
#
#  conv2d_53 (Conv2D)             (None, 106, 106, 16  2320        ['activation_7[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 106, 106, 24  3480        ['activation_7[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_55[0][0]']
#                                 )
#
#  concatenate_11 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_52[0][0]',
#                                 )                                 'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_11[0][0]']
#                                 4)
#
#  add_7 (Add)                    (None, 106, 106, 14  0           ['activation_7[0][0]',
#                                 4)                                'conv2d_57[0][0]']
#
#  activation_8 (Activation)      (None, 106, 106, 14  0           ['add_7[0][0]']
#                                 4)
#
#  conv2d_59 (Conv2D)             (None, 106, 106, 16  2320        ['activation_8[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_59[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_60[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 106, 106, 24  3480        ['activation_8[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_61[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_58[0][0]',
#                                 )                                 'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_12[0][0]']
#                                 4)
#
#  add_8 (Add)                    (None, 106, 106, 14  0           ['activation_8[0][0]',
#                                 4)                                'conv2d_63[0][0]']
#
#  activation_9 (Activation)      (None, 106, 106, 14  0           ['add_8[0][0]']
#                                 4)
#
#  conv2d_65 (Conv2D)             (None, 106, 106, 16  2320        ['activation_9[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_65[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_66[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 106, 106, 24  3480        ['activation_9[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_67[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_64[0][0]',
#                                 )                                 'conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_13[0][0]']
#                                 4)
#
#  add_9 (Add)                    (None, 106, 106, 14  0           ['activation_9[0][0]',
#                                 4)                                'conv2d_69[0][0]']
#
#  activation_10 (Activation)     (None, 106, 106, 14  0           ['add_9[0][0]']
#                                 4)
#
#  conv2d_71 (Conv2D)             (None, 106, 106, 16  2320        ['activation_10[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_71[0][0]']
#                                 )
#
#  conv2d_73 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_72[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 106, 106, 24  3480        ['activation_10[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_73[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_70[0][0]',
#                                 )                                 'conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_14[0][0]']
#                                 4)
#
#  add_10 (Add)                   (None, 106, 106, 14  0           ['activation_10[0][0]',
#                                 4)                                'conv2d_75[0][0]']
#
#  activation_11 (Activation)     (None, 106, 106, 14  0           ['add_10[0][0]']
#                                 4)
#
#  conv2d_77 (Conv2D)             (None, 106, 106, 16  2320        ['activation_11[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_77[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_78[0][0]']
#                                 )
#
#  conv2d_76 (Conv2D)             (None, 106, 106, 24  3480        ['activation_11[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_79[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_76[0][0]',
#                                 )                                 'conv2d_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_15[0][0]']
#                                 4)
#
#  add_11 (Add)                   (None, 106, 106, 14  0           ['activation_11[0][0]',
#                                 4)                                'conv2d_81[0][0]']
#
#  activation_12 (Activation)     (None, 106, 106, 14  0           ['add_11[0][0]']
#                                 4)
#
#  conv2d_83 (Conv2D)             (None, 106, 106, 16  2320        ['activation_12[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_83[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_84[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 106, 106, 24  3480        ['activation_12[0][0]']
#                                 )
#
#  conv2d_86 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_85[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_82[0][0]',
#                                 )                                 'conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_16[0][0]']
#                                 4)
#
#  add_12 (Add)                   (None, 106, 106, 14  0           ['activation_12[0][0]',
#                                 4)                                'conv2d_87[0][0]']
#
#  activation_13 (Activation)     (None, 106, 106, 14  0           ['add_12[0][0]']
#                                 4)
#
#  conv2d_89 (Conv2D)             (None, 106, 106, 16  2320        ['activation_13[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_89[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_90[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 106, 106, 24  3480        ['activation_13[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_91[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_88[0][0]',
#                                 )                                 'conv2d_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_17[0][0]']
#                                 4)
#
#  add_13 (Add)                   (None, 106, 106, 14  0           ['activation_13[0][0]',
#                                 4)                                'conv2d_93[0][0]']
#
#  activation_14 (Activation)     (None, 106, 106, 14  0           ['add_13[0][0]']
#                                 4)
#
#  conv2d_95 (Conv2D)             (None, 106, 106, 16  2320        ['activation_14[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_95[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_96[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 106, 106, 24  3480        ['activation_14[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_97[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_94[0][0]',
#                                 )                                 'conv2d_98[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_18[0][0]']
#                                 4)
#
#  add_14 (Add)                   (None, 106, 106, 14  0           ['activation_14[0][0]',
#                                 4)                                'conv2d_99[0][0]']
#
#  activation_15 (Activation)     (None, 106, 106, 14  0           ['add_14[0][0]']
#                                 4)
#
#  conv2d_104 (Conv2D)            (None, 106, 106, 32  4640        ['activation_15[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 106, 106, 32  4640        ['activation_15[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 106, 106, 32  4640        ['activation_15[0][0]']
#                                 )
#
#  conv2d_105 (Conv2D)            (None, 106, 106, 36  10404       ['conv2d_104[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_15[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_100[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_102[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 52, 52, 40)   13000       ['conv2d_105[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_101[0][0]',
#                                                                   'conv2d_103[0][0]',
#                                                                   'conv2d_106[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_108[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_109[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_107[0][0]',
#                                                                   'conv2d_110[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_20[0][0]']
#
#  add_15 (Add)                   (None, 52, 52, 256)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_111[0][0]']
#
#  activation_16 (Activation)     (None, 52, 52, 256)  0           ['add_15[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_16[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_113[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_16[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_114[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_112[0][0]',
#                                                                   'conv2d_115[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_21[0][0]']
#
#  add_16 (Add)                   (None, 52, 52, 256)  0           ['activation_16[0][0]',
#                                                                   'conv2d_116[0][0]']
#
#  activation_17 (Activation)     (None, 52, 52, 256)  0           ['add_16[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_17[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_118[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_17[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_119[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_117[0][0]',
#                                                                   'conv2d_120[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_22[0][0]']
#
#  add_17 (Add)                   (None, 52, 52, 256)  0           ['activation_17[0][0]',
#                                                                   'conv2d_121[0][0]']
#
#  activation_18 (Activation)     (None, 52, 52, 256)  0           ['add_17[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_18[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_123[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_18[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_124[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_122[0][0]',
#                                                                   'conv2d_125[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_23[0][0]']
#
#  add_18 (Add)                   (None, 52, 52, 256)  0           ['activation_18[0][0]',
#                                                                   'conv2d_126[0][0]']
#
#  activation_19 (Activation)     (None, 52, 52, 256)  0           ['add_18[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_19[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_128[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_19[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_129[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_127[0][0]',
#                                                                   'conv2d_130[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_24[0][0]']
#
#  add_19 (Add)                   (None, 52, 52, 256)  0           ['activation_19[0][0]',
#                                                                   'conv2d_131[0][0]']
#
#  activation_20 (Activation)     (None, 52, 52, 256)  0           ['add_19[0][0]']
#
#  average_pooling2d (AveragePool  (None, 49, 49, 256)  0          ['activation_20[0][0]']
#  ing2D)
#
#  dropout (Dropout)              (None, 49, 49, 256)  0           ['average_pooling2d[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 471,918
# Trainable params: 471,918
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


model.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "DIR_40XResized"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/BreastCancer/CSVHistory/5. DepthwiseInceptionResNet/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)

lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# %%
history = model.fit(
    train_generator,
    epochs=100,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction]  # 添加 ModelCheckpoint 到回调列表
)
# Out:
# Epoch 1/100
# 2023-12-25 15:02:46.799184: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2023-12-25 15:02:48.832933: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - 71s 854ms/step - loss: 5.1013 - accuracy: 0.5040 - precision: 0.5040 - recall: 0.5040 - auc: 0.5020 - f1_score: 0.5040 - val_loss: 0.6906 - val_accuracy: 0.5207 - val_precision: 0.5207 - val_recall: 0.5207 - val_auc: 0.5632 - val_f1_score: 0.5207 - lr: 0.0010
# Epoch 2/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.7173 - accuracy: 0.5084 - precision: 0.5084 - recall: 0.5084 - auc: 0.5137 - f1_score: 0.5084 - val_loss: 0.6976 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6137 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 3/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.6982 - accuracy: 0.5309 - precision: 0.5309 - recall: 0.5309 - auc: 0.5388 - f1_score: 0.5309 - val_loss: 0.7032 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.3608 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 4/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.6908 - accuracy: 0.5433 - precision: 0.5433 - recall: 0.5433 - auc: 0.5634 - f1_score: 0.5433 - val_loss: 0.6752 - val_accuracy: 0.4970 - val_precision: 0.4970 - val_recall: 0.4970 - val_auc: 0.6433 - val_f1_score: 0.4970 - lr: 0.0010
# Epoch 5/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.6724 - accuracy: 0.5937 - precision: 0.5937 - recall: 0.5937 - auc: 0.6355 - f1_score: 0.5937 - val_loss: 0.7616 - val_accuracy: 0.5030 - val_precision: 0.5030 - val_recall: 0.5030 - val_auc: 0.5430 - val_f1_score: 0.5030 - lr: 0.0010
# Epoch 6/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.6388 - accuracy: 0.6340 - precision: 0.6340 - recall: 0.6340 - auc: 0.6897 - f1_score: 0.6340 - val_loss: 0.6401 - val_accuracy: 0.6124 - val_precision: 0.6124 - val_recall: 0.6124 - val_auc: 0.6809 - val_f1_score: 0.6124 - lr: 0.0010
# Epoch 7/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.5576 - accuracy: 0.7241 - precision: 0.7241 - recall: 0.7241 - auc: 0.7897 - f1_score: 0.7241 - val_loss: 0.6096 - val_accuracy: 0.6154 - val_precision: 0.6154 - val_recall: 0.6154 - val_auc: 0.7094 - val_f1_score: 0.6154 - lr: 0.0010
# Epoch 8/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.5597 - accuracy: 0.7268 - precision: 0.7268 - recall: 0.7268 - auc: 0.7889 - f1_score: 0.7268 - val_loss: 0.5895 - val_accuracy: 0.6657 - val_precision: 0.6657 - val_recall: 0.6657 - val_auc: 0.7560 - val_f1_score: 0.6657 - lr: 0.0010
# Epoch 9/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.5276 - accuracy: 0.7405 - precision: 0.7405 - recall: 0.7405 - auc: 0.8157 - f1_score: 0.7405 - val_loss: 0.5792 - val_accuracy: 0.6953 - val_precision: 0.6953 - val_recall: 0.6953 - val_auc: 0.7797 - val_f1_score: 0.6953 - lr: 0.0010
# Epoch 10/100
# 71/71 [==============================] - 45s 626ms/step - loss: 0.5259 - accuracy: 0.7498 - precision: 0.7498 - recall: 0.7498 - auc: 0.8172 - f1_score: 0.7498 - val_loss: 0.6176 - val_accuracy: 0.6657 - val_precision: 0.6657 - val_recall: 0.6657 - val_auc: 0.7199 - val_f1_score: 0.6657 - lr: 0.0010
# Epoch 11/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.5293 - accuracy: 0.7507 - precision: 0.7507 - recall: 0.7507 - auc: 0.8164 - f1_score: 0.7507 - val_loss: 0.5561 - val_accuracy: 0.7426 - val_precision: 0.7426 - val_recall: 0.7426 - val_auc: 0.8079 - val_f1_score: 0.7426 - lr: 0.0010
# Epoch 12/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.5164 - accuracy: 0.7529 - precision: 0.7529 - recall: 0.7529 - auc: 0.8241 - f1_score: 0.7529 - val_loss: 0.5759 - val_accuracy: 0.7219 - val_precision: 0.7219 - val_recall: 0.7219 - val_auc: 0.7857 - val_f1_score: 0.7219 - lr: 0.0010
# Epoch 13/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.5457 - accuracy: 0.7392 - precision: 0.7392 - recall: 0.7392 - auc: 0.8009 - f1_score: 0.7392 - val_loss: 0.5167 - val_accuracy: 0.7308 - val_precision: 0.7308 - val_recall: 0.7308 - val_auc: 0.8247 - val_f1_score: 0.7308 - lr: 0.0010
# Epoch 14/100
# 71/71 [==============================] - 45s 626ms/step - loss: 0.5024 - accuracy: 0.7657 - precision: 0.7657 - recall: 0.7657 - auc: 0.8358 - f1_score: 0.7657 - val_loss: 0.6037 - val_accuracy: 0.6834 - val_precision: 0.6834 - val_recall: 0.6834 - val_auc: 0.7436 - val_f1_score: 0.6834 - lr: 0.0010
# Epoch 15/100
# 71/71 [==============================] - 45s 626ms/step - loss: 0.4929 - accuracy: 0.7710 - precision: 0.7710 - recall: 0.7710 - auc: 0.8420 - f1_score: 0.7710 - val_loss: 0.5310 - val_accuracy: 0.7337 - val_precision: 0.7337 - val_recall: 0.7337 - val_auc: 0.8122 - val_f1_score: 0.7337 - lr: 0.0010
# Epoch 16/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.5283 - accuracy: 0.7436 - precision: 0.7436 - recall: 0.7436 - auc: 0.8127 - f1_score: 0.7436 - val_loss: 0.5144 - val_accuracy: 0.7544 - val_precision: 0.7544 - val_recall: 0.7544 - val_auc: 0.8231 - val_f1_score: 0.7544 - lr: 0.0010
# Epoch 17/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.4898 - accuracy: 0.7666 - precision: 0.7666 - recall: 0.7666 - auc: 0.8453 - f1_score: 0.7666 - val_loss: 0.5233 - val_accuracy: 0.7426 - val_precision: 0.7426 - val_recall: 0.7426 - val_auc: 0.8136 - val_f1_score: 0.7426 - lr: 0.0010
# Epoch 18/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.4816 - accuracy: 0.7745 - precision: 0.7745 - recall: 0.7745 - auc: 0.8497 - f1_score: 0.7745 - val_loss: 0.5046 - val_accuracy: 0.7574 - val_precision: 0.7574 - val_recall: 0.7574 - val_auc: 0.8381 - val_f1_score: 0.7574 - lr: 0.0010
# Epoch 19/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.4684 - accuracy: 0.7829 - precision: 0.7829 - recall: 0.7829 - auc: 0.8599 - f1_score: 0.7829 - val_loss: 0.4809 - val_accuracy: 0.7544 - val_precision: 0.7544 - val_recall: 0.7544 - val_auc: 0.8501 - val_f1_score: 0.7544 - lr: 0.0010
# Epoch 20/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.4723 - accuracy: 0.7851 - precision: 0.7851 - recall: 0.7851 - auc: 0.8557 - f1_score: 0.7851 - val_loss: 0.5415 - val_accuracy: 0.7308 - val_precision: 0.7308 - val_recall: 0.7308 - val_auc: 0.8011 - val_f1_score: 0.7308 - lr: 0.0010
# Epoch 21/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.4852 - accuracy: 0.7701 - precision: 0.7701 - recall: 0.7701 - auc: 0.8484 - f1_score: 0.7701 - val_loss: 0.4749 - val_accuracy: 0.7485 - val_precision: 0.7485 - val_recall: 0.7485 - val_auc: 0.8518 - val_f1_score: 0.7485 - lr: 0.0010
# Epoch 22/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.4779 - accuracy: 0.7772 - precision: 0.7772 - recall: 0.7772 - auc: 0.8540 - f1_score: 0.7772 - val_loss: 0.6981 - val_accuracy: 0.6864 - val_precision: 0.6864 - val_recall: 0.6864 - val_auc: 0.7389 - val_f1_score: 0.6864 - lr: 0.0010
# Epoch 23/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.4833 - accuracy: 0.7829 - precision: 0.7829 - recall: 0.7829 - auc: 0.8494 - f1_score: 0.7829 - val_loss: 0.6347 - val_accuracy: 0.6893 - val_precision: 0.6893 - val_recall: 0.6893 - val_auc: 0.7510 - val_f1_score: 0.6893 - lr: 0.0010
# Epoch 24/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.4898 - accuracy: 0.7630 - precision: 0.7630 - recall: 0.7630 - auc: 0.8446 - f1_score: 0.7630 - val_loss: 0.5180 - val_accuracy: 0.7456 - val_precision: 0.7456 - val_recall: 0.7456 - val_auc: 0.8207 - val_f1_score: 0.7456 - lr: 0.0010
# Epoch 25/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.4867 - accuracy: 0.7723 - precision: 0.7723 - recall: 0.7723 - auc: 0.8463 - f1_score: 0.7723 - val_loss: 0.4625 - val_accuracy: 0.7929 - val_precision: 0.7929 - val_recall: 0.7929 - val_auc: 0.8764 - val_f1_score: 0.7929 - lr: 0.0010
# Epoch 26/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.4732 - accuracy: 0.7812 - precision: 0.7812 - recall: 0.7812 - auc: 0.8567 - f1_score: 0.7812 - val_loss: 0.4754 - val_accuracy: 0.7959 - val_precision: 0.7959 - val_recall: 0.7959 - val_auc: 0.8753 - val_f1_score: 0.7959 - lr: 0.0010
# Epoch 27/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.4794 - accuracy: 0.7737 - precision: 0.7737 - recall: 0.7737 - auc: 0.8528 - f1_score: 0.7737 - val_loss: 0.4516 - val_accuracy: 0.7929 - val_precision: 0.7929 - val_recall: 0.7929 - val_auc: 0.8723 - val_f1_score: 0.7929 - lr: 0.0010
# Epoch 28/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.4557 - accuracy: 0.7869 - precision: 0.7869 - recall: 0.7869 - auc: 0.8691 - f1_score: 0.7869 - val_loss: 0.4399 - val_accuracy: 0.7870 - val_precision: 0.7870 - val_recall: 0.7870 - val_auc: 0.8796 - val_f1_score: 0.7870 - lr: 0.0010
# Epoch 29/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.4648 - accuracy: 0.7927 - precision: 0.7927 - recall: 0.7927 - auc: 0.8618 - f1_score: 0.7927 - val_loss: 0.4795 - val_accuracy: 0.7544 - val_precision: 0.7544 - val_recall: 0.7544 - val_auc: 0.8506 - val_f1_score: 0.7544 - lr: 0.0010
# Epoch 30/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.4348 - accuracy: 0.8059 - precision: 0.8059 - recall: 0.8059 - auc: 0.8814 - f1_score: 0.8059 - val_loss: 0.4086 - val_accuracy: 0.8018 - val_precision: 0.8018 - val_recall: 0.8018 - val_auc: 0.9015 - val_f1_score: 0.8018 - lr: 0.0010
# Epoch 31/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.4398 - accuracy: 0.8002 - precision: 0.8002 - recall: 0.8002 - auc: 0.8780 - f1_score: 0.8002 - val_loss: 0.4538 - val_accuracy: 0.8254 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.8761 - val_f1_score: 0.8254 - lr: 0.0010
# Epoch 32/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.4573 - accuracy: 0.7935 - precision: 0.7935 - recall: 0.7935 - auc: 0.8670 - f1_score: 0.7935 - val_loss: 0.4042 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9229 - val_f1_score: 0.8639 - lr: 0.0010
# Epoch 33/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.4254 - accuracy: 0.8117 - precision: 0.8117 - recall: 0.8117 - auc: 0.8868 - f1_score: 0.8117 - val_loss: 0.3835 - val_accuracy: 0.8077 - val_precision: 0.8077 - val_recall: 0.8077 - val_auc: 0.9111 - val_f1_score: 0.8077 - lr: 0.0010
# Epoch 34/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.4115 - accuracy: 0.8201 - precision: 0.8201 - recall: 0.8201 - auc: 0.8936 - f1_score: 0.8201 - val_loss: 0.3536 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9257 - val_f1_score: 0.8402 - lr: 0.0010
# Epoch 35/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3811 - accuracy: 0.8413 - precision: 0.8413 - recall: 0.8413 - auc: 0.9095 - f1_score: 0.8413 - val_loss: 0.3112 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9430 - val_f1_score: 0.8846 - lr: 0.0010
# Epoch 36/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3792 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9107 - f1_score: 0.8369 - val_loss: 0.5347 - val_accuracy: 0.7337 - val_precision: 0.7337 - val_recall: 0.7337 - val_auc: 0.8161 - val_f1_score: 0.7337 - lr: 0.0010
# Epoch 37/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3973 - accuracy: 0.8258 - precision: 0.8258 - recall: 0.8258 - auc: 0.9027 - f1_score: 0.8258 - val_loss: 0.3409 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9483 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 38/100
# 71/71 [==============================] - 44s 626ms/step - loss: 0.3678 - accuracy: 0.8435 - precision: 0.8435 - recall: 0.8435 - auc: 0.9166 - f1_score: 0.8435 - val_loss: 0.4055 - val_accuracy: 0.8107 - val_precision: 0.8107 - val_recall: 0.8107 - val_auc: 0.9080 - val_f1_score: 0.8107 - lr: 0.0010
# Epoch 39/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3946 - accuracy: 0.8302 - precision: 0.8302 - recall: 0.8302 - auc: 0.9032 - f1_score: 0.8302 - val_loss: 0.3213 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9536 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 40/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.4040 - accuracy: 0.8289 - precision: 0.8289 - recall: 0.8289 - auc: 0.8977 - f1_score: 0.8289 - val_loss: 0.3285 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9435 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 41/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3812 - accuracy: 0.8435 - precision: 0.8435 - recall: 0.8435 - auc: 0.9095 - f1_score: 0.8435 - val_loss: 0.3798 - val_accuracy: 0.8018 - val_precision: 0.8018 - val_recall: 0.8018 - val_auc: 0.9087 - val_f1_score: 0.8018 - lr: 0.0010
# Epoch 42/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.3780 - accuracy: 0.8382 - precision: 0.8382 - recall: 0.8382 - auc: 0.9108 - f1_score: 0.8382 - val_loss: 0.3369 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9347 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 43/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.4051 - accuracy: 0.8320 - precision: 0.8320 - recall: 0.8320 - auc: 0.8964 - f1_score: 0.8320 - val_loss: 0.3020 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9591 - val_f1_score: 0.8935 - lr: 0.0010
# Epoch 44/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.3460 - accuracy: 0.8607 - precision: 0.8607 - recall: 0.8607 - auc: 0.9253 - f1_score: 0.8607 - val_loss: 0.2831 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9567 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 45/100
# 71/71 [==============================] - 45s 626ms/step - loss: 0.3862 - accuracy: 0.8382 - precision: 0.8382 - recall: 0.8382 - auc: 0.9077 - f1_score: 0.8382 - val_loss: 0.3935 - val_accuracy: 0.8195 - val_precision: 0.8195 - val_recall: 0.8195 - val_auc: 0.9015 - val_f1_score: 0.8195 - lr: 0.0010
# Epoch 46/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.3386 - accuracy: 0.8572 - precision: 0.8572 - recall: 0.8572 - auc: 0.9288 - f1_score: 0.8572 - val_loss: 0.2485 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9723 - val_f1_score: 0.9201 - lr: 0.0010
# Epoch 47/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.3420 - accuracy: 0.8576 - precision: 0.8576 - recall: 0.8576 - auc: 0.9278 - f1_score: 0.8576 - val_loss: 0.3122 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9571 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 48/100
# 71/71 [==============================] - 45s 628ms/step - loss: 0.3222 - accuracy: 0.8837 - precision: 0.8837 - recall: 0.8837 - auc: 0.9345 - f1_score: 0.8837 - val_loss: 0.2957 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9482 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 49/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3491 - accuracy: 0.8594 - precision: 0.8594 - recall: 0.8594 - auc: 0.9249 - f1_score: 0.8594 - val_loss: 0.2291 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9779 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 50/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3278 - accuracy: 0.8625 - precision: 0.8625 - recall: 0.8625 - auc: 0.9342 - f1_score: 0.8625 - val_loss: 0.3088 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9443 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 51/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3275 - accuracy: 0.8603 - precision: 0.8603 - recall: 0.8603 - auc: 0.9334 - f1_score: 0.8603 - val_loss: 0.2700 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9673 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 52/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.3096 - accuracy: 0.8740 - precision: 0.8740 - recall: 0.8740 - auc: 0.9410 - f1_score: 0.8740 - val_loss: 0.2924 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9482 - val_f1_score: 0.8757 - lr: 0.0010
# Epoch 53/100
# 71/71 [==============================] - 45s 627ms/step - loss: 0.3199 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9377 - f1_score: 0.8749 - val_loss: 0.2527 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9674 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 54/100
# 71/71 [==============================] - 45s 626ms/step - loss: 0.3241 - accuracy: 0.8678 - precision: 0.8678 - recall: 0.8678 - auc: 0.9355 - f1_score: 0.8678 - val_loss: 0.2073 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9853 - val_f1_score: 0.9467 - lr: 0.0010
# Epoch 55/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3671 - accuracy: 0.8523 - precision: 0.8523 - recall: 0.8523 - auc: 0.9147 - f1_score: 0.8523 - val_loss: 0.2145 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9773 - val_f1_score: 0.9172 - lr: 0.0010
# Epoch 56/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.3280 - accuracy: 0.8674 - precision: 0.8674 - recall: 0.8674 - auc: 0.9329 - f1_score: 0.8674 - val_loss: 0.2883 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9527 - val_f1_score: 0.8757 - lr: 0.0010
# Epoch 57/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.3469 - accuracy: 0.8532 - precision: 0.8532 - recall: 0.8532 - auc: 0.9268 - f1_score: 0.8532 - val_loss: 0.2234 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9760 - val_f1_score: 0.9201 - lr: 0.0010
# Epoch 58/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3286 - accuracy: 0.8652 - precision: 0.8652 - recall: 0.8652 - auc: 0.9340 - f1_score: 0.8652 - val_loss: 0.5887 - val_accuracy: 0.7604 - val_precision: 0.7604 - val_recall: 0.7604 - val_auc: 0.8551 - val_f1_score: 0.7604 - lr: 0.0010
# Epoch 59/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3079 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9401 - f1_score: 0.8798 - val_loss: 0.2740 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9558 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 60/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3014 - accuracy: 0.8771 - precision: 0.8771 - recall: 0.8771 - auc: 0.9442 - f1_score: 0.8771 - val_loss: 0.2478 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9660 - val_f1_score: 0.9024 - lr: 0.0010
# Epoch 61/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.2969 - accuracy: 0.8828 - precision: 0.8828 - recall: 0.8828 - auc: 0.9457 - f1_score: 0.8828 - val_loss: 0.2328 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9687 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 62/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.3330 - accuracy: 0.8599 - precision: 0.8599 - recall: 0.8599 - auc: 0.9317 - f1_score: 0.8599 - val_loss: 0.3283 - val_accuracy: 0.8698 - val_precision: 0.8698 - val_recall: 0.8698 - val_auc: 0.9319 - val_f1_score: 0.8698 - lr: 0.0010
# Epoch 63/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.2833 - accuracy: 0.8890 - precision: 0.8890 - recall: 0.8890 - auc: 0.9498 - f1_score: 0.8890 - val_loss: 0.2051 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9801 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 64/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.2946 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9473 - f1_score: 0.8820 - val_loss: 0.2456 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9661 - val_f1_score: 0.8935 - lr: 0.0010
# Epoch 65/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.2877 - accuracy: 0.8811 - precision: 0.8811 - recall: 0.8811 - auc: 0.9495 - f1_score: 0.8811 - val_loss: 0.2211 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9737 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 66/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.3095 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9410 - f1_score: 0.8749 - val_loss: 0.2279 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9672 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 67/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.3229 - accuracy: 0.8700 - precision: 0.8700 - recall: 0.8700 - auc: 0.9361 - f1_score: 0.8700 - val_loss: 0.3713 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9214 - val_f1_score: 0.8402 - lr: 0.0010
# Epoch 68/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.3174 - accuracy: 0.8722 - precision: 0.8722 - recall: 0.8722 - auc: 0.9381 - f1_score: 0.8722 - val_loss: 0.4274 - val_accuracy: 0.8018 - val_precision: 0.8018 - val_recall: 0.8018 - val_auc: 0.8894 - val_f1_score: 0.8018 - lr: 0.0010
# Epoch 69/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.2857 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9486 - f1_score: 0.8873 - val_loss: 0.2117 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9740 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 70/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.2850 - accuracy: 0.8780 - precision: 0.8780 - recall: 0.8780 - auc: 0.9503 - f1_score: 0.8780 - val_loss: 0.2395 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9674 - val_f1_score: 0.9024 - lr: 0.0010
# Epoch 71/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.3087 - accuracy: 0.8683 - precision: 0.8683 - recall: 0.8683 - auc: 0.9418 - f1_score: 0.8683 - val_loss: 0.2811 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9524 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 72/100
# 71/71 [==============================] - 45s 626ms/step - loss: 0.2826 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9500 - f1_score: 0.8842 - val_loss: 0.2131 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9828 - val_f1_score: 0.9349 - lr: 0.0010
# Epoch 73/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.2800 - accuracy: 0.8815 - precision: 0.8815 - recall: 0.8815 - auc: 0.9529 - f1_score: 0.8815 - val_loss: 0.1545 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9893 - val_f1_score: 0.9467 - lr: 0.0010
# Epoch 74/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.2743 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9546 - f1_score: 0.8873 - val_loss: 0.2182 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9766 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 75/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.2958 - accuracy: 0.8771 - precision: 0.8771 - recall: 0.8771 - auc: 0.9465 - f1_score: 0.8771 - val_loss: 0.1922 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9826 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 76/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.2703 - accuracy: 0.8855 - precision: 0.8855 - recall: 0.8855 - auc: 0.9563 - f1_score: 0.8855 - val_loss: 0.2720 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9555 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 77/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.2639 - accuracy: 0.8970 - precision: 0.8970 - recall: 0.8970 - auc: 0.9576 - f1_score: 0.8970 - val_loss: 0.2116 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9760 - val_f1_score: 0.9201 - lr: 0.0010
# Epoch 78/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.2593 - accuracy: 0.8930 - precision: 0.8930 - recall: 0.8930 - auc: 0.9596 - f1_score: 0.8930 - val_loss: 0.3269 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9373 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 79/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.2595 - accuracy: 0.8912 - precision: 0.8912 - recall: 0.8912 - auc: 0.9591 - f1_score: 0.8912 - val_loss: 0.2111 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9828 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 80/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.2644 - accuracy: 0.8917 - precision: 0.8917 - recall: 0.8917 - auc: 0.9576 - f1_score: 0.8917 - val_loss: 0.1229 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9929 - val_f1_score: 0.9675 - lr: 0.0010
# Epoch 81/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.2621 - accuracy: 0.9014 - precision: 0.9014 - recall: 0.9014 - auc: 0.9567 - f1_score: 0.9014 - val_loss: 0.1604 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9903 - val_f1_score: 0.9556 - lr: 0.0010
# Epoch 82/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.2671 - accuracy: 0.8974 - precision: 0.8974 - recall: 0.8974 - auc: 0.9556 - f1_score: 0.8974 - val_loss: 0.1593 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9883 - val_f1_score: 0.9497 - lr: 0.0010
# Epoch 83/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.2467 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9628 - f1_score: 0.9010 - val_loss: 0.1624 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9904 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 84/100
# 71/71 [==============================] - 44s 625ms/step - loss: 0.2502 - accuracy: 0.9014 - precision: 0.9014 - recall: 0.9014 - auc: 0.9616 - f1_score: 0.9014 - val_loss: 0.2426 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9654 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 85/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.2689 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9561 - f1_score: 0.8904 - val_loss: 0.1294 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9928 - val_f1_score: 0.9675 - lr: 0.0010
# Epoch 86/100
# 71/71 [==============================] - 45s 623ms/step - loss: 0.2437 - accuracy: 0.8961 - precision: 0.8961 - recall: 0.8961 - auc: 0.9642 - f1_score: 0.8961 - val_loss: 0.1816 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9857 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 87/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.2739 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9542 - f1_score: 0.8873 - val_loss: 0.2245 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9722 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 88/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.2314 - accuracy: 0.9080 - precision: 0.9080 - recall: 0.9080 - auc: 0.9664 - f1_score: 0.9080 - val_loss: 0.1909 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9849 - val_f1_score: 0.9379 - lr: 0.0010
# Epoch 89/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.2982 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9509 - f1_score: 0.8873 - val_loss: 0.3301 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9346 - val_f1_score: 0.8757 - lr: 0.0010
# Epoch 90/100
# 71/71 [==============================] - ETA: 0s - loss: 0.2906 - accuracy: 0.8837 - precision: 0.8837 - recall: 0.8837 - auc: 0.9478 - f1_score: 0.8837
# Epoch 90: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 71/71 [==============================] - 45s 624ms/step - loss: 0.2906 - accuracy: 0.8837 - precision: 0.8837 - recall: 0.8837 - auc: 0.9478 - f1_score: 0.8837 - val_loss: 0.2432 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9665 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 91/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.2380 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9662 - f1_score: 0.9023 - val_loss: 0.1527 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9889 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 92/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.2056 - accuracy: 0.9111 - precision: 0.9111 - recall: 0.9111 - auc: 0.9754 - f1_score: 0.9111 - val_loss: 0.1555 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9901 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 93/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.2122 - accuracy: 0.9138 - precision: 0.9138 - recall: 0.9138 - auc: 0.9733 - f1_score: 0.9138 - val_loss: 0.1429 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9918 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 94/100
# 71/71 [==============================] - 45s 626ms/step - loss: 0.1940 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9774 - f1_score: 0.9178 - val_loss: 0.1377 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9922 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 95/100
# 71/71 [==============================] - 45s 625ms/step - loss: 0.1867 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9799 - f1_score: 0.9231 - val_loss: 0.1477 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9888 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 96/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.1924 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9780 - f1_score: 0.9178 - val_loss: 0.1647 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9859 - val_f1_score: 0.9290 - lr: 1.0000e-04
# Epoch 97/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.1764 - accuracy: 0.9253 - precision: 0.9253 - recall: 0.9253 - auc: 0.9815 - f1_score: 0.9253 - val_loss: 0.2010 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9762 - val_f1_score: 0.9112 - lr: 1.0000e-04
# Epoch 98/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.1738 - accuracy: 0.9266 - precision: 0.9266 - recall: 0.9266 - auc: 0.9823 - f1_score: 0.9266 - val_loss: 0.1457 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9889 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 99/100
# 71/71 [==============================] - 45s 624ms/step - loss: 0.1858 - accuracy: 0.9222 - precision: 0.9222 - recall: 0.9222 - auc: 0.9791 - f1_score: 0.9222 - val_loss: 0.1929 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9782 - val_f1_score: 0.9231 - lr: 1.0000e-04
# Epoch 100/100
# 71/71 [==============================] - ETA: 0s - loss: 0.1699 - accuracy: 0.9310 - precision: 0.9310 - recall: 0.9310 - auc: 0.9828 - f1_score: 0.9310
# Epoch 100: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 71/71 [==============================] - 45s 625ms/step - loss: 0.1699 - accuracy: 0.9310 - precision: 0.9310 - recall: 0.9310 - auc: 0.9828 - f1_score: 0.9310 - val_loss: 0.1496 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9880 - val_f1_score: 0.9438 - lr: 1.0000e-04

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = model.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 2s 112ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9263636363636364
# F1-Score for each class: [0.89772727 0.955     ]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9597989949748744
# specificity: 0.8876404494382022

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  model.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 1s 111ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = model.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 2s 140ms/step - loss: 0.1890 - accuracy: 0.9362 - precision: 0.9362 - recall: 0.9362 - auc: 0.9763 - f1_score: 0.9362
# Test loss: 0.18896643817424774
# Test accuracy: 0.936241626739502
# Test precision: 0.936241626739502
# Test recall: 0.936241626739502
# Test AUC: 0.9763243198394775
# Test F1 Score: 0.936241626739502

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = model.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 1s 111ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90        89
#            1       0.95      0.96      0.96       199
#
#     accuracy                           0.94       288
#    macro avg       0.93      0.92      0.93       288
# weighted avg       0.94      0.94      0.94       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

del model


from numba import cuda

cuda.select_device(0)
cuda.close()
