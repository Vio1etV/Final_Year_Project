# %% [markdown]
# 再version 6的基础上，batchsize = 32， stem第一层变为4，用leaky relu，将inception a的函数里面的分支第一层神经元改为8
#
# 在Version 7的及基础上，加入L1正则化

# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.regularizers import l2

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 304 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

l2_reg = 0.001

def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='leaky_relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)
    
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    # a = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    c = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = attention_block_2(x)

    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    # c = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    shortcut = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(shortcut)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    shortcut = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(shortcut)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    shortcut = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(shortcut)
    
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 1
num_B_blocks = 2
num_C_blocks = 1

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.3)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax')(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# 2024-03-13 12:11:29.716562: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-13 12:11:30.311704: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22134 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:31:00.0, compute capability: 8.9
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 4)  112         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 222, 222, 96  3552        ['conv2d[0][0]']
#                                 )
#
#  activation (Activation)        (None, 222, 222, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 222, 222, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 222, 222, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 222, 222, 4)  0           ['conv2d[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 220, 220, 4)  148         ['multiply[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 220, 220, 96  3552        ['conv2d_3[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 220, 220, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 220, 220, 1)  97          ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 220, 220, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 220, 220, 4)  0           ['conv2d_3[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 220, 220, 8)  296         ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 220, 220, 96  7008        ['conv2d_6[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 220, 220, 96  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 220, 220, 1)  97          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 220, 220, 1)  0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 220, 220, 8)  0           ['conv2d_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['multiply_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 218, 218, 12  876         ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_13[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_16[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_6 (Activation)      (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 16  160        ['conv2d_18[0][0]']
#  v2D)                           )
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_17[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 48  2352        ['activation_6[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['conv2d_22[0][0]',
#                                 )                                 'conv2d_21[0][0]']
#
#  activation_7 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 32  1568        ['activation_7[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_24[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_7[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 106, 106, 48  20784       ['activation_7[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_25[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_23[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_4[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_28[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_29[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_4[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_30[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_27[0][0]',
#                                 )                                 'conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 106, 106, 14  20880       ['concatenate_4[0][0]']
#                                 4)
#
#  conv2d_32 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_5[0][0]']
#                                 4)
#
#  add_1 (Add)                    (None, 106, 106, 14  0           ['conv2d_33[0][0]',
#                                 4)                                'conv2d_32[0][0]']
#
#  activation_8 (Activation)      (None, 106, 106, 14  0           ['add_1[0][0]']
#                                 4)
#
#  conv2d_35 (Conv2D)             (None, 106, 106, 16  2320        ['activation_8[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_36[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 106, 106, 24  3480        ['activation_8[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_37[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_34[0][0]',
#                                 )                                 'conv2d_38[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 106, 106, 14  20880       ['activation_8[0][0]']
#                                 4)
#
#  conv2d_39 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_6[0][0]']
#                                 4)
#
#  add_2 (Add)                    (None, 106, 106, 14  0           ['conv2d_40[0][0]',
#                                 4)                                'conv2d_39[0][0]']
#
#  activation_9 (Activation)      (None, 106, 106, 14  0           ['add_2[0][0]']
#                                 4)
#
#  conv2d_45 (Conv2D)             (None, 106, 106, 32  4640        ['activation_9[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 106, 106, 32  4640        ['activation_9[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 106, 106, 32  4640        ['activation_9[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 106, 106, 36  10404       ['conv2d_45[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_9[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 52, 52, 36)   10404       ['conv2d_41[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 52, 52, 36)   10404       ['conv2d_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 52, 52, 40)   13000       ['conv2d_46[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_44[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 52, 52, 24)   6168        ['concatenate_7[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 52, 52, 28)   2044        ['conv2d_49[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 52, 52, 24)   6168        ['concatenate_7[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 52, 52, 32)   2720        ['conv2d_50[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 52, 52, 56)   0           ['conv2d_48[0][0]',
#                                                                   'conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 52, 52, 256)  65792       ['concatenate_7[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 52, 52, 256)  14592       ['concatenate_8[0][0]']
#
#  add_3 (Add)                    (None, 52, 52, 256)  0           ['conv2d_53[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  activation_10 (Activation)     (None, 52, 52, 256)  0           ['add_3[0][0]']
#
#  dropout (Dropout)              (None, 52, 52, 256)  0           ['activation_10[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 313,597
# Trainable params: 313,597
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# import numpy as np
# from sklearn.metrics import f1_score
# from tensorflow.keras.callbacks import Callback

# class F1ScoreCallback(Callback):
#     def __init__(self, train_generator, validation_generator, num_classes):
#         super(F1ScoreCallback, self).__init__()
#         self.train_generator = train_generator
#         self.validation_generator = validation_generator
#         self.num_classes = num_classes
#         self.train_f1_scores = []
#         self.val_f1_scores = []

#     def on_epoch_end(self, epoch, logs=None):
#         # 计算训练集F1分数
#         train_predict, train_true = self._get_predictions_and_true_labels(self.train_generator)
#         train_f1 = f1_score(train_true, train_predict, average='micro')
#         self.train_f1_scores.append(train_f1)
        
#         # 计算验证集F1分数
#         val_predict, val_true = self._get_predictions_and_true_labels(self.validation_generator)
#         val_f1 = f1_score(val_true, val_predict, average='micro')
#         self.val_f1_scores.append(val_f1)
        
#         print(f'Epoch {epoch+1}: Training F1 Score: {train_f1}, Validation F1 Score: {val_f1}')

#     def _get_predictions_and_true_labels(self, generator):
#         predictions = []
#         true_labels = []
#         for i in range(len(generator)):
#             x_batch, y_batch_true = next(generator)
#             y_batch_pred = self.model.predict(x_batch, verbose=0)
#             y_batch_pred = np.argmax(y_batch_pred, axis=1)
#             y_true = np.argmax(y_batch_true, axis=1)
#             predictions.extend(y_batch_pred)
#             true_labels.extend(y_true)
#         return predictions, true_labels


# # 继续使用之前的方式将回调添加到你的模型训练中

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(),
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version8_run5-DIR"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)


lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', 
                                 factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# f1_score_callback = F1ScoreCallback(train_generator = train_generator, 
#                                     validation_generator=validation_generator, 
#                                     num_classes=num_classes)


from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = DIR.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)


# history = DIR.fit(
#     train_generator,
#     epochs=150,
#     validation_data=validation_generator,
#     callbacks=[csv_logger, lr_reduction, model_checkpoint_callback, f1_score_callback]
# )
# Out:
# Epoch 1/150
# 2024-03-13 12:11:37.848494: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-13 12:11:38.859884: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-03-13 12:11:38.859906: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2024-03-13 12:11:38.860009: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-03-13 12:11:40.263520: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 0.6385 - accuracy: 0.6589 - precision: 0.6589 - recall: 0.6589 - auc: 0.7339 - f1_score: 0.6589
# Epoch 1: val_loss improved from inf to 0.61462, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 46s 523ms/step - loss: 0.6385 - accuracy: 0.6589 - precision: 0.6589 - recall: 0.6589 - auc: 0.7339 - f1_score: 0.6589 - val_loss: 0.6146 - val_accuracy: 0.6893 - val_precision: 0.6893 - val_recall: 0.6893 - val_auc: 0.7999 - val_f1_score: 0.6893 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5747 - accuracy: 0.7494 - precision: 0.7494 - recall: 0.7494 - auc: 0.8018 - f1_score: 0.7494
# Epoch 2: val_loss improved from 0.61462 to 0.53707, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 32s 449ms/step - loss: 0.5747 - accuracy: 0.7494 - precision: 0.7494 - recall: 0.7494 - auc: 0.8018 - f1_score: 0.7494 - val_loss: 0.5371 - val_accuracy: 0.7663 - val_precision: 0.7663 - val_recall: 0.7663 - val_auc: 0.8342 - val_f1_score: 0.7663 - lr: 0.0010
# Epoch 3/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5383 - accuracy: 0.7578 - precision: 0.7578 - recall: 0.7578 - auc: 0.8296 - f1_score: 0.7578
# Epoch 3: val_loss improved from 0.53707 to 0.41883, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 34s 470ms/step - loss: 0.5383 - accuracy: 0.7578 - precision: 0.7578 - recall: 0.7578 - auc: 0.8296 - f1_score: 0.7578 - val_loss: 0.4188 - val_accuracy: 0.8521 - val_precision: 0.8521 - val_recall: 0.8521 - val_auc: 0.9116 - val_f1_score: 0.8521 - lr: 0.0010
# Epoch 4/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5153 - accuracy: 0.7729 - precision: 0.7729 - recall: 0.7729 - auc: 0.8503 - f1_score: 0.7729
# Epoch 4: val_loss did not improve from 0.41883
# 71/71 [==============================] - 34s 478ms/step - loss: 0.5153 - accuracy: 0.7729 - precision: 0.7729 - recall: 0.7729 - auc: 0.8503 - f1_score: 0.7729 - val_loss: 0.5027 - val_accuracy: 0.7722 - val_precision: 0.7722 - val_recall: 0.7722 - val_auc: 0.8788 - val_f1_score: 0.7722 - lr: 0.0010
# Epoch 5/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4845 - accuracy: 0.7954 - precision: 0.7954 - recall: 0.7954 - auc: 0.8661 - f1_score: 0.7954
# Epoch 5: val_loss did not improve from 0.41883
# 71/71 [==============================] - 33s 463ms/step - loss: 0.4845 - accuracy: 0.7954 - precision: 0.7954 - recall: 0.7954 - auc: 0.8661 - f1_score: 0.7954 - val_loss: 0.4634 - val_accuracy: 0.8047 - val_precision: 0.8047 - val_recall: 0.8047 - val_auc: 0.9021 - val_f1_score: 0.8047 - lr: 0.0010
# Epoch 6/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4833 - accuracy: 0.7963 - precision: 0.7963 - recall: 0.7963 - auc: 0.8676 - f1_score: 0.7963
# Epoch 6: val_loss did not improve from 0.41883
# 71/71 [==============================] - 34s 482ms/step - loss: 0.4833 - accuracy: 0.7963 - precision: 0.7963 - recall: 0.7963 - auc: 0.8676 - f1_score: 0.7963 - val_loss: 0.4201 - val_accuracy: 0.8018 - val_precision: 0.8018 - val_recall: 0.8018 - val_auc: 0.9252 - val_f1_score: 0.8018 - lr: 0.0010
# Epoch 7/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4492 - accuracy: 0.8171 - precision: 0.8171 - recall: 0.8171 - auc: 0.8869 - f1_score: 0.8171
# Epoch 7: val_loss improved from 0.41883 to 0.33037, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 33s 461ms/step - loss: 0.4492 - accuracy: 0.8171 - precision: 0.8171 - recall: 0.8171 - auc: 0.8869 - f1_score: 0.8171 - val_loss: 0.3304 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9647 - val_f1_score: 0.9024 - lr: 0.0010
# Epoch 8/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4821 - accuracy: 0.8011 - precision: 0.8011 - recall: 0.8011 - auc: 0.8664 - f1_score: 0.8011
# Epoch 8: val_loss did not improve from 0.33037
# 71/71 [==============================] - 35s 491ms/step - loss: 0.4821 - accuracy: 0.8011 - precision: 0.8011 - recall: 0.8011 - auc: 0.8664 - f1_score: 0.8011 - val_loss: 0.3978 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9741 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 9/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4418 - accuracy: 0.8179 - precision: 0.8179 - recall: 0.8179 - auc: 0.8912 - f1_score: 0.8179
# Epoch 9: val_loss did not improve from 0.33037
# 71/71 [==============================] - 33s 456ms/step - loss: 0.4418 - accuracy: 0.8179 - precision: 0.8179 - recall: 0.8179 - auc: 0.8912 - f1_score: 0.8179 - val_loss: 0.3893 - val_accuracy: 0.8432 - val_precision: 0.8432 - val_recall: 0.8432 - val_auc: 0.9346 - val_f1_score: 0.8432 - lr: 0.0010
# Epoch 10/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4203 - accuracy: 0.8308 - precision: 0.8308 - recall: 0.8308 - auc: 0.9025 - f1_score: 0.8308
# Epoch 10: val_loss did not improve from 0.33037
# 71/71 [==============================] - 36s 500ms/step - loss: 0.4203 - accuracy: 0.8308 - precision: 0.8308 - recall: 0.8308 - auc: 0.9025 - f1_score: 0.8308 - val_loss: 0.4188 - val_accuracy: 0.8047 - val_precision: 0.8047 - val_recall: 0.8047 - val_auc: 0.9182 - val_f1_score: 0.8047 - lr: 0.0010
# Epoch 11/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4020 - accuracy: 0.8392 - precision: 0.8392 - recall: 0.8392 - auc: 0.9110 - f1_score: 0.8392
# Epoch 11: val_loss improved from 0.33037 to 0.30256, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 36s 504ms/step - loss: 0.4020 - accuracy: 0.8392 - precision: 0.8392 - recall: 0.8392 - auc: 0.9110 - f1_score: 0.8392 - val_loss: 0.3026 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9596 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 12/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3963 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9145 - f1_score: 0.8462
# Epoch 12: val_loss improved from 0.30256 to 0.22795, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 34s 480ms/step - loss: 0.3963 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9145 - f1_score: 0.8462 - val_loss: 0.2279 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9829 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 13/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3826 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9198 - f1_score: 0.8546
# Epoch 13: val_loss did not improve from 0.22795
# 71/71 [==============================] - 35s 488ms/step - loss: 0.3826 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9198 - f1_score: 0.8546 - val_loss: 0.8436 - val_accuracy: 0.6509 - val_precision: 0.6509 - val_recall: 0.6509 - val_auc: 0.7431 - val_f1_score: 0.6509 - lr: 0.0010
# Epoch 14/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4211 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9018 - f1_score: 0.8369
# Epoch 14: val_loss did not improve from 0.22795
# 71/71 [==============================] - 34s 475ms/step - loss: 0.4211 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9018 - f1_score: 0.8369 - val_loss: 0.4964 - val_accuracy: 0.7574 - val_precision: 0.7574 - val_recall: 0.7574 - val_auc: 0.8580 - val_f1_score: 0.7574 - lr: 0.0010
# Epoch 15/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3899 - accuracy: 0.8533 - precision: 0.8533 - recall: 0.8533 - auc: 0.9172 - f1_score: 0.8533
# Epoch 15: val_loss did not improve from 0.22795
# 71/71 [==============================] - 34s 475ms/step - loss: 0.3899 - accuracy: 0.8533 - precision: 0.8533 - recall: 0.8533 - auc: 0.9172 - f1_score: 0.8533 - val_loss: 0.2418 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9764 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 16/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3813 - accuracy: 0.8533 - precision: 0.8533 - recall: 0.8533 - auc: 0.9222 - f1_score: 0.8533
# Epoch 16: val_loss did not improve from 0.22795
# 71/71 [==============================] - 33s 467ms/step - loss: 0.3813 - accuracy: 0.8533 - precision: 0.8533 - recall: 0.8533 - auc: 0.9222 - f1_score: 0.8533 - val_loss: 0.2322 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9792 - val_f1_score: 0.9349 - lr: 0.0010
# Epoch 17/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3943 - accuracy: 0.8484 - precision: 0.8484 - recall: 0.8484 - auc: 0.9158 - f1_score: 0.8484
# Epoch 17: val_loss did not improve from 0.22795
# 71/71 [==============================] - 37s 514ms/step - loss: 0.3943 - accuracy: 0.8484 - precision: 0.8484 - recall: 0.8484 - auc: 0.9158 - f1_score: 0.8484 - val_loss: 0.2639 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9839 - val_f1_score: 0.9556 - lr: 0.0010
# Epoch 18/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3680 - accuracy: 0.8599 - precision: 0.8599 - recall: 0.8599 - auc: 0.9285 - f1_score: 0.8599
# Epoch 18: val_loss did not improve from 0.22795
# 71/71 [==============================] - 36s 497ms/step - loss: 0.3680 - accuracy: 0.8599 - precision: 0.8599 - recall: 0.8599 - auc: 0.9285 - f1_score: 0.8599 - val_loss: 0.2607 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9838 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 19/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3507 - accuracy: 0.8665 - precision: 0.8665 - recall: 0.8665 - auc: 0.9347 - f1_score: 0.8665
# Epoch 19: val_loss did not improve from 0.22795
# 71/71 [==============================] - 34s 476ms/step - loss: 0.3507 - accuracy: 0.8665 - precision: 0.8665 - recall: 0.8665 - auc: 0.9347 - f1_score: 0.8665 - val_loss: 0.3096 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9577 - val_f1_score: 0.9024 - lr: 0.0010
# Epoch 20/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3498 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9331 - f1_score: 0.8749
# Epoch 20: val_loss did not improve from 0.22795
# 71/71 [==============================] - 33s 456ms/step - loss: 0.3498 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9331 - f1_score: 0.8749 - val_loss: 0.2637 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9733 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 21/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3489 - accuracy: 0.8657 - precision: 0.8657 - recall: 0.8657 - auc: 0.9350 - f1_score: 0.8657
# Epoch 21: val_loss did not improve from 0.22795
# 71/71 [==============================] - 34s 472ms/step - loss: 0.3489 - accuracy: 0.8657 - precision: 0.8657 - recall: 0.8657 - auc: 0.9350 - f1_score: 0.8657 - val_loss: 0.3170 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9561 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 22/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3422 - accuracy: 0.8736 - precision: 0.8736 - recall: 0.8736 - auc: 0.9380 - f1_score: 0.8736
# Epoch 22: val_loss improved from 0.22795 to 0.21989, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 33s 461ms/step - loss: 0.3422 - accuracy: 0.8736 - precision: 0.8736 - recall: 0.8736 - auc: 0.9380 - f1_score: 0.8736 - val_loss: 0.2199 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9827 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 23/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3318 - accuracy: 0.8767 - precision: 0.8767 - recall: 0.8767 - auc: 0.9421 - f1_score: 0.8767
# Epoch 23: val_loss did not improve from 0.21989
# 71/71 [==============================] - 35s 487ms/step - loss: 0.3318 - accuracy: 0.8767 - precision: 0.8767 - recall: 0.8767 - auc: 0.9421 - f1_score: 0.8767 - val_loss: 0.2592 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9822 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 24/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3754 - accuracy: 0.8502 - precision: 0.8502 - recall: 0.8502 - auc: 0.9238 - f1_score: 0.8502
# Epoch 24: val_loss did not improve from 0.21989
# 71/71 [==============================] - 33s 466ms/step - loss: 0.3754 - accuracy: 0.8502 - precision: 0.8502 - recall: 0.8502 - auc: 0.9238 - f1_score: 0.8502 - val_loss: 0.3006 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9666 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 25/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3323 - accuracy: 0.8701 - precision: 0.8701 - recall: 0.8701 - auc: 0.9420 - f1_score: 0.8701
# Epoch 25: val_loss did not improve from 0.21989
# 71/71 [==============================] - 34s 469ms/step - loss: 0.3323 - accuracy: 0.8701 - precision: 0.8701 - recall: 0.8701 - auc: 0.9420 - f1_score: 0.8701 - val_loss: 0.2641 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9652 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 26/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3059 - accuracy: 0.8838 - precision: 0.8838 - recall: 0.8838 - auc: 0.9518 - f1_score: 0.8838
# Epoch 26: val_loss did not improve from 0.21989
# 71/71 [==============================] - 33s 467ms/step - loss: 0.3059 - accuracy: 0.8838 - precision: 0.8838 - recall: 0.8838 - auc: 0.9518 - f1_score: 0.8838 - val_loss: 0.2859 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9636 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 27/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3125 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9495 - f1_score: 0.8820
# Epoch 27: val_loss did not improve from 0.21989
# 71/71 [==============================] - 34s 469ms/step - loss: 0.3125 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9495 - f1_score: 0.8820 - val_loss: 0.2574 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9716 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 28/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3222 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9458 - f1_score: 0.8842
# Epoch 28: val_loss did not improve from 0.21989
# 71/71 [==============================] - 34s 472ms/step - loss: 0.3222 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9458 - f1_score: 0.8842 - val_loss: 0.3548 - val_accuracy: 0.8521 - val_precision: 0.8521 - val_recall: 0.8521 - val_auc: 0.9355 - val_f1_score: 0.8521 - lr: 0.0010
# Epoch 29/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2916 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9562 - f1_score: 0.8851
# Epoch 29: val_loss did not improve from 0.21989
# 71/71 [==============================] - 37s 518ms/step - loss: 0.2916 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9562 - f1_score: 0.8851 - val_loss: 0.2333 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9746 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 30/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3194 - accuracy: 0.8763 - precision: 0.8763 - recall: 0.8763 - auc: 0.9470 - f1_score: 0.8763
# Epoch 30: val_loss improved from 0.21989 to 0.20940, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 37s 519ms/step - loss: 0.3194 - accuracy: 0.8763 - precision: 0.8763 - recall: 0.8763 - auc: 0.9470 - f1_score: 0.8763 - val_loss: 0.2094 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9863 - val_f1_score: 0.9408 - lr: 0.0010
# Epoch 31/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2992 - accuracy: 0.8917 - precision: 0.8917 - recall: 0.8917 - auc: 0.9541 - f1_score: 0.8917
# Epoch 31: val_loss did not improve from 0.20940
# 71/71 [==============================] - 36s 502ms/step - loss: 0.2992 - accuracy: 0.8917 - precision: 0.8917 - recall: 0.8917 - auc: 0.9541 - f1_score: 0.8917 - val_loss: 0.3704 - val_accuracy: 0.8373 - val_precision: 0.8373 - val_recall: 0.8373 - val_auc: 0.9258 - val_f1_score: 0.8373 - lr: 0.0010
# Epoch 32/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3349 - accuracy: 0.8732 - precision: 0.8732 - recall: 0.8732 - auc: 0.9418 - f1_score: 0.8732
# Epoch 32: val_loss did not improve from 0.20940
# 71/71 [==============================] - 36s 505ms/step - loss: 0.3349 - accuracy: 0.8732 - precision: 0.8732 - recall: 0.8732 - auc: 0.9418 - f1_score: 0.8732 - val_loss: 0.2256 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9805 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 33/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3093 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9500 - f1_score: 0.8833
# Epoch 33: val_loss did not improve from 0.20940
# 71/71 [==============================] - 35s 494ms/step - loss: 0.3093 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9500 - f1_score: 0.8833 - val_loss: 0.2110 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9898 - val_f1_score: 0.9527 - lr: 0.0010
# Epoch 34/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2865 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9574 - f1_score: 0.8979
# Epoch 34: val_loss improved from 0.20940 to 0.20488, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 34s 474ms/step - loss: 0.2865 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9574 - f1_score: 0.8979 - val_loss: 0.2049 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9855 - val_f1_score: 0.9408 - lr: 0.0010
# Epoch 35/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2764 - accuracy: 0.9001 - precision: 0.9001 - recall: 0.9001 - auc: 0.9611 - f1_score: 0.9001
# Epoch 35: val_loss did not improve from 0.20488
# 71/71 [==============================] - 36s 497ms/step - loss: 0.2764 - accuracy: 0.9001 - precision: 0.9001 - recall: 0.9001 - auc: 0.9611 - f1_score: 0.9001 - val_loss: 0.3495 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9346 - val_f1_score: 0.8580 - lr: 0.0010
# Epoch 36/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9561 - f1_score: 0.8873
# Epoch 36: val_loss improved from 0.20488 to 0.18989, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 37s 522ms/step - loss: 0.2937 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9561 - f1_score: 0.8873 - val_loss: 0.1899 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9898 - val_f1_score: 0.9556 - lr: 0.0010
# Epoch 37/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2901 - accuracy: 0.8886 - precision: 0.8886 - recall: 0.8886 - auc: 0.9566 - f1_score: 0.8886
# Epoch 37: val_loss did not improve from 0.18989
# 71/71 [==============================] - 34s 479ms/step - loss: 0.2901 - accuracy: 0.8886 - precision: 0.8886 - recall: 0.8886 - auc: 0.9566 - f1_score: 0.8886 - val_loss: 0.2877 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9580 - val_f1_score: 0.8994 - lr: 0.0010
# Epoch 38/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2961 - accuracy: 0.8909 - precision: 0.8909 - recall: 0.8909 - auc: 0.9547 - f1_score: 0.8909
# Epoch 38: val_loss did not improve from 0.18989
# 71/71 [==============================] - 33s 462ms/step - loss: 0.2961 - accuracy: 0.8909 - precision: 0.8909 - recall: 0.8909 - auc: 0.9547 - f1_score: 0.8909 - val_loss: 0.2089 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9796 - val_f1_score: 0.9349 - lr: 0.0010
# Epoch 39/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3336 - accuracy: 0.8714 - precision: 0.8714 - recall: 0.8714 - auc: 0.9420 - f1_score: 0.8714
# Epoch 39: val_loss did not improve from 0.18989
# 71/71 [==============================] - 35s 486ms/step - loss: 0.3336 - accuracy: 0.8714 - precision: 0.8714 - recall: 0.8714 - auc: 0.9420 - f1_score: 0.8714 - val_loss: 0.2319 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9807 - val_f1_score: 0.9201 - lr: 0.0010
# Epoch 40/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2595 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9659 - f1_score: 0.9076
# Epoch 40: val_loss did not improve from 0.18989
# 71/71 [==============================] - 34s 470ms/step - loss: 0.2595 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9659 - f1_score: 0.9076 - val_loss: 0.1911 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9878 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 41/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2895 - accuracy: 0.8886 - precision: 0.8886 - recall: 0.8886 - auc: 0.9566 - f1_score: 0.8886
# Epoch 41: val_loss did not improve from 0.18989
# 71/71 [==============================] - 35s 486ms/step - loss: 0.2895 - accuracy: 0.8886 - precision: 0.8886 - recall: 0.8886 - auc: 0.9566 - f1_score: 0.8886 - val_loss: 0.2170 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9777 - val_f1_score: 0.9349 - lr: 0.0010
# Epoch 42/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9494 - f1_score: 0.8873
# Epoch 42: val_loss did not improve from 0.18989
# 71/71 [==============================] - 36s 497ms/step - loss: 0.3121 - accuracy: 0.8873 - precision: 0.8873 - recall: 0.8873 - auc: 0.9494 - f1_score: 0.8873 - val_loss: 0.2446 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9708 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 43/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2894 - accuracy: 0.8891 - precision: 0.8891 - recall: 0.8891 - auc: 0.9572 - f1_score: 0.8891
# Epoch 43: val_loss improved from 0.18989 to 0.18785, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 36s 506ms/step - loss: 0.2894 - accuracy: 0.8891 - precision: 0.8891 - recall: 0.8891 - auc: 0.9572 - f1_score: 0.8891 - val_loss: 0.1878 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9897 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 44/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2849 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9584 - f1_score: 0.8926
# Epoch 44: val_loss improved from 0.18785 to 0.18355, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 36s 510ms/step - loss: 0.2849 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9584 - f1_score: 0.8926 - val_loss: 0.1836 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9874 - val_f1_score: 0.9527 - lr: 0.0010
# Epoch 45/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2560 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9668 - f1_score: 0.9094
# Epoch 45: val_loss improved from 0.18355 to 0.16576, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 35s 492ms/step - loss: 0.2560 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9668 - f1_score: 0.9094 - val_loss: 0.1658 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9909 - val_f1_score: 0.9586 - lr: 0.0010
# Epoch 46/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9681 - f1_score: 0.9178
# Epoch 46: val_loss improved from 0.16576 to 0.15206, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 37s 513ms/step - loss: 0.2503 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9681 - f1_score: 0.9178 - val_loss: 0.1521 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9927 - val_f1_score: 0.9586 - lr: 0.0010
# Epoch 47/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2459 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9704 - f1_score: 0.9085
# Epoch 47: val_loss did not improve from 0.15206
# 71/71 [==============================] - 34s 474ms/step - loss: 0.2459 - accuracy: 0.9085 - precision: 0.9085 - recall: 0.9085 - auc: 0.9704 - f1_score: 0.9085 - val_loss: 0.2331 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9785 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 48/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2417 - accuracy: 0.9156 - precision: 0.9156 - recall: 0.9156 - auc: 0.9708 - f1_score: 0.9156
# Epoch 48: val_loss did not improve from 0.15206
# 71/71 [==============================] - 34s 470ms/step - loss: 0.2417 - accuracy: 0.9156 - precision: 0.9156 - recall: 0.9156 - auc: 0.9708 - f1_score: 0.9156 - val_loss: 0.1831 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9872 - val_f1_score: 0.9467 - lr: 0.0010
# Epoch 49/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9722 - f1_score: 0.9112
# Epoch 49: val_loss did not improve from 0.15206
# 71/71 [==============================] - 35s 487ms/step - loss: 0.2395 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9722 - f1_score: 0.9112 - val_loss: 0.1916 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9859 - val_f1_score: 0.9527 - lr: 0.0010
# Epoch 50/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9218 - precision: 0.9218 - recall: 0.9218 - auc: 0.9754 - f1_score: 0.9218
# Epoch 50: val_loss did not improve from 0.15206
# 71/71 [==============================] - 35s 491ms/step - loss: 0.2240 - accuracy: 0.9218 - precision: 0.9218 - recall: 0.9218 - auc: 0.9754 - f1_score: 0.9218 - val_loss: 0.2181 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9785 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 51/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2512 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9684 - f1_score: 0.9112
# Epoch 51: val_loss did not improve from 0.15206
# 71/71 [==============================] - 36s 499ms/step - loss: 0.2512 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9684 - f1_score: 0.9112 - val_loss: 0.2320 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9782 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 52/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2324 - accuracy: 0.9156 - precision: 0.9156 - recall: 0.9156 - auc: 0.9733 - f1_score: 0.9156
# Epoch 52: val_loss did not improve from 0.15206
# 71/71 [==============================] - 33s 465ms/step - loss: 0.2324 - accuracy: 0.9156 - precision: 0.9156 - recall: 0.9156 - auc: 0.9733 - f1_score: 0.9156 - val_loss: 0.1560 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9906 - val_f1_score: 0.9615 - lr: 0.0010
# Epoch 53/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2399 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9721 - f1_score: 0.9165
# Epoch 53: val_loss did not improve from 0.15206
# 71/71 [==============================] - 35s 490ms/step - loss: 0.2399 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9721 - f1_score: 0.9165 - val_loss: 0.4110 - val_accuracy: 0.8254 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.9100 - val_f1_score: 0.8254 - lr: 0.0010
# Epoch 54/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2763 - accuracy: 0.9006 - precision: 0.9006 - recall: 0.9006 - auc: 0.9610 - f1_score: 0.9006
# Epoch 54: val_loss did not improve from 0.15206
# 71/71 [==============================] - 35s 493ms/step - loss: 0.2763 - accuracy: 0.9006 - precision: 0.9006 - recall: 0.9006 - auc: 0.9610 - f1_score: 0.9006 - val_loss: 0.2412 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9779 - val_f1_score: 0.9172 - lr: 0.0010
# Epoch 55/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9747 - f1_score: 0.9160
# Epoch 55: val_loss did not improve from 0.15206
# 71/71 [==============================] - 38s 529ms/step - loss: 0.2286 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9747 - f1_score: 0.9160 - val_loss: 0.3069 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9514 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 56/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2526 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9685 - f1_score: 0.9054
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 56: val_loss did not improve from 0.15206
# 71/71 [==============================] - 35s 495ms/step - loss: 0.2526 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9685 - f1_score: 0.9054 - val_loss: 0.1949 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9952 - val_f1_score: 0.9704 - lr: 0.0010
# Epoch 57/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2188 - accuracy: 0.9227 - precision: 0.9227 - recall: 0.9227 - auc: 0.9786 - f1_score: 0.9227
# Epoch 57: val_loss did not improve from 0.15206
# 71/71 [==============================] - 35s 492ms/step - loss: 0.2188 - accuracy: 0.9227 - precision: 0.9227 - recall: 0.9227 - auc: 0.9786 - f1_score: 0.9227 - val_loss: 0.1659 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9910 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 58/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1899 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - auc: 0.9839 - f1_score: 0.9284
# Epoch 58: val_loss did not improve from 0.15206
# 71/71 [==============================] - 38s 529ms/step - loss: 0.1899 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - auc: 0.9839 - f1_score: 0.9284 - val_loss: 0.1751 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9896 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 59/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1781 - accuracy: 0.9443 - precision: 0.9443 - recall: 0.9443 - auc: 0.9856 - f1_score: 0.9443
# Epoch 59: val_loss did not improve from 0.15206
# 71/71 [==============================] - 35s 483ms/step - loss: 0.1781 - accuracy: 0.9443 - precision: 0.9443 - recall: 0.9443 - auc: 0.9856 - f1_score: 0.9443 - val_loss: 0.2031 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9818 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 60/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1775 - accuracy: 0.9381 - precision: 0.9381 - recall: 0.9381 - auc: 0.9860 - f1_score: 0.9381
# Epoch 60: val_loss did not improve from 0.15206
# 71/71 [==============================] - 34s 479ms/step - loss: 0.1775 - accuracy: 0.9381 - precision: 0.9381 - recall: 0.9381 - auc: 0.9860 - f1_score: 0.9381 - val_loss: 0.1678 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9904 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 61/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1693 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9874 - f1_score: 0.9421
# Epoch 61: val_loss did not improve from 0.15206
# 71/71 [==============================] - 34s 474ms/step - loss: 0.1693 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9874 - f1_score: 0.9421 - val_loss: 0.1719 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9884 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 62/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9461 - precision: 0.9461 - recall: 0.9461 - auc: 0.9890 - f1_score: 0.9461
# Epoch 62: val_loss did not improve from 0.15206
# 71/71 [==============================] - 35s 493ms/step - loss: 0.1608 - accuracy: 0.9461 - precision: 0.9461 - recall: 0.9461 - auc: 0.9890 - f1_score: 0.9461 - val_loss: 0.1614 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9904 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 63/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1537 - accuracy: 0.9523 - precision: 0.9523 - recall: 0.9523 - auc: 0.9898 - f1_score: 0.9523
# Epoch 63: val_loss improved from 0.15206 to 0.13034, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 36s 504ms/step - loss: 0.1537 - accuracy: 0.9523 - precision: 0.9523 - recall: 0.9523 - auc: 0.9898 - f1_score: 0.9523 - val_loss: 0.1303 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9948 - val_f1_score: 0.9645 - lr: 1.0000e-04
# Epoch 64/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9465 - precision: 0.9465 - recall: 0.9465 - auc: 0.9900 - f1_score: 0.9465
# Epoch 64: val_loss did not improve from 0.13034
# 71/71 [==============================] - 37s 521ms/step - loss: 0.1550 - accuracy: 0.9465 - precision: 0.9465 - recall: 0.9465 - auc: 0.9900 - f1_score: 0.9465 - val_loss: 0.1452 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9927 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 65/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 0.9532 - precision: 0.9532 - recall: 0.9532 - auc: 0.9906 - f1_score: 0.9532
# Epoch 65: val_loss did not improve from 0.13034
# 71/71 [==============================] - 35s 495ms/step - loss: 0.1488 - accuracy: 0.9532 - precision: 0.9532 - recall: 0.9532 - auc: 0.9906 - f1_score: 0.9532 - val_loss: 0.1570 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9901 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 66/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.9465 - precision: 0.9465 - recall: 0.9465 - auc: 0.9881 - f1_score: 0.9465
# Epoch 66: val_loss did not improve from 0.13034
# 71/71 [==============================] - 34s 482ms/step - loss: 0.1645 - accuracy: 0.9465 - precision: 0.9465 - recall: 0.9465 - auc: 0.9881 - f1_score: 0.9465 - val_loss: 0.1729 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9872 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 67/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1544 - accuracy: 0.9536 - precision: 0.9536 - recall: 0.9536 - auc: 0.9892 - f1_score: 0.9536
# Epoch 67: val_loss did not improve from 0.13034
# 71/71 [==============================] - 37s 513ms/step - loss: 0.1544 - accuracy: 0.9536 - precision: 0.9536 - recall: 0.9536 - auc: 0.9892 - f1_score: 0.9536 - val_loss: 0.1758 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9868 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 68/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1513 - accuracy: 0.9483 - precision: 0.9483 - recall: 0.9483 - auc: 0.9904 - f1_score: 0.9483
# Epoch 68: val_loss did not improve from 0.13034
# 71/71 [==============================] - 36s 506ms/step - loss: 0.1513 - accuracy: 0.9483 - precision: 0.9483 - recall: 0.9483 - auc: 0.9904 - f1_score: 0.9483 - val_loss: 0.1627 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9896 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 69/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9913 - f1_score: 0.9487
# Epoch 69: val_loss did not improve from 0.13034
# 71/71 [==============================] - 35s 488ms/step - loss: 0.1462 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9913 - f1_score: 0.9487 - val_loss: 0.1753 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9871 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 70/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1441 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9914 - f1_score: 0.9505
# Epoch 70: val_loss improved from 0.13034 to 0.12622, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 36s 510ms/step - loss: 0.1441 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9914 - f1_score: 0.9505 - val_loss: 0.1262 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9962 - val_f1_score: 0.9675 - lr: 1.0000e-04
# Epoch 71/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9496 - precision: 0.9496 - recall: 0.9496 - auc: 0.9910 - f1_score: 0.9496
# Epoch 71: val_loss did not improve from 0.12622
# 71/71 [==============================] - 34s 471ms/step - loss: 0.1468 - accuracy: 0.9496 - precision: 0.9496 - recall: 0.9496 - auc: 0.9910 - f1_score: 0.9496 - val_loss: 0.1502 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9911 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 72/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1524 - accuracy: 0.9479 - precision: 0.9479 - recall: 0.9479 - auc: 0.9900 - f1_score: 0.9479
# Epoch 72: val_loss did not improve from 0.12622
# 71/71 [==============================] - 35s 485ms/step - loss: 0.1524 - accuracy: 0.9479 - precision: 0.9479 - recall: 0.9479 - auc: 0.9900 - f1_score: 0.9479 - val_loss: 0.1321 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9939 - val_f1_score: 0.9645 - lr: 1.0000e-04
# Epoch 73/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9496 - precision: 0.9496 - recall: 0.9496 - auc: 0.9901 - f1_score: 0.9496
# Epoch 73: val_loss did not improve from 0.12622
# 71/71 [==============================] - 35s 489ms/step - loss: 0.1525 - accuracy: 0.9496 - precision: 0.9496 - recall: 0.9496 - auc: 0.9901 - f1_score: 0.9496 - val_loss: 0.1485 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9913 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 74/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1485 - accuracy: 0.9514 - precision: 0.9514 - recall: 0.9514 - auc: 0.9908 - f1_score: 0.9514
# Epoch 74: val_loss did not improve from 0.12622
# 71/71 [==============================] - 34s 482ms/step - loss: 0.1485 - accuracy: 0.9514 - precision: 0.9514 - recall: 0.9514 - auc: 0.9908 - f1_score: 0.9514 - val_loss: 0.1327 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9940 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 75/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1387 - accuracy: 0.9558 - precision: 0.9558 - recall: 0.9558 - auc: 0.9920 - f1_score: 0.9558
# Epoch 75: val_loss did not improve from 0.12622
# 71/71 [==============================] - 35s 483ms/step - loss: 0.1387 - accuracy: 0.9558 - precision: 0.9558 - recall: 0.9558 - auc: 0.9920 - f1_score: 0.9558 - val_loss: 0.1659 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9887 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 76/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9917 - f1_score: 0.9505
# Epoch 76: val_loss did not improve from 0.12622
# 71/71 [==============================] - 36s 497ms/step - loss: 0.1414 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9917 - f1_score: 0.9505 - val_loss: 0.1295 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9936 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 77/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9916 - f1_score: 0.9505
# Epoch 77: val_loss did not improve from 0.12622
# 71/71 [==============================] - 33s 466ms/step - loss: 0.1444 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9916 - f1_score: 0.9505 - val_loss: 0.1432 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9925 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 78/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9527 - precision: 0.9527 - recall: 0.9527 - auc: 0.9909 - f1_score: 0.9527
# Epoch 78: val_loss improved from 0.12622 to 0.12581, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 35s 490ms/step - loss: 0.1450 - accuracy: 0.9527 - precision: 0.9527 - recall: 0.9527 - auc: 0.9909 - f1_score: 0.9527 - val_loss: 0.1258 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9951 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 79/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9540 - precision: 0.9540 - recall: 0.9540 - auc: 0.9918 - f1_score: 0.9540
# Epoch 79: val_loss did not improve from 0.12581
# 71/71 [==============================] - 34s 474ms/step - loss: 0.1406 - accuracy: 0.9540 - precision: 0.9540 - recall: 0.9540 - auc: 0.9918 - f1_score: 0.9540 - val_loss: 0.1350 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9939 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 80/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1386 - accuracy: 0.9554 - precision: 0.9554 - recall: 0.9554 - auc: 0.9921 - f1_score: 0.9554
# Epoch 80: val_loss improved from 0.12581 to 0.10715, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 35s 492ms/step - loss: 0.1386 - accuracy: 0.9554 - precision: 0.9554 - recall: 0.9554 - auc: 0.9921 - f1_score: 0.9554 - val_loss: 0.1071 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9968 - val_f1_score: 0.9734 - lr: 1.0000e-04
# Epoch 81/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1376 - accuracy: 0.9571 - precision: 0.9571 - recall: 0.9571 - auc: 0.9925 - f1_score: 0.9571
# Epoch 81: val_loss did not improve from 0.10715
# 71/71 [==============================] - 34s 471ms/step - loss: 0.1376 - accuracy: 0.9571 - precision: 0.9571 - recall: 0.9571 - auc: 0.9925 - f1_score: 0.9571 - val_loss: 0.1465 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9933 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 82/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1417 - accuracy: 0.9492 - precision: 0.9492 - recall: 0.9492 - auc: 0.9917 - f1_score: 0.9492
# Epoch 82: val_loss did not improve from 0.10715
# 71/71 [==============================] - 33s 463ms/step - loss: 0.1417 - accuracy: 0.9492 - precision: 0.9492 - recall: 0.9492 - auc: 0.9917 - f1_score: 0.9492 - val_loss: 0.1333 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9932 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 83/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1291 - accuracy: 0.9593 - precision: 0.9593 - recall: 0.9593 - auc: 0.9935 - f1_score: 0.9593
# Epoch 83: val_loss did not improve from 0.10715
# 71/71 [==============================] - 36s 508ms/step - loss: 0.1291 - accuracy: 0.9593 - precision: 0.9593 - recall: 0.9593 - auc: 0.9935 - f1_score: 0.9593 - val_loss: 0.1721 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9867 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 84/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.9523 - precision: 0.9523 - recall: 0.9523 - auc: 0.9915 - f1_score: 0.9523
# Epoch 84: val_loss did not improve from 0.10715
# 71/71 [==============================] - 34s 472ms/step - loss: 0.1414 - accuracy: 0.9523 - precision: 0.9523 - recall: 0.9523 - auc: 0.9915 - f1_score: 0.9523 - val_loss: 0.1242 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9942 - val_f1_score: 0.9734 - lr: 1.0000e-04
# Epoch 85/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1363 - accuracy: 0.9549 - precision: 0.9549 - recall: 0.9549 - auc: 0.9925 - f1_score: 0.9549
# Epoch 85: val_loss did not improve from 0.10715
# 71/71 [==============================] - 35s 492ms/step - loss: 0.1363 - accuracy: 0.9549 - precision: 0.9549 - recall: 0.9549 - auc: 0.9925 - f1_score: 0.9549 - val_loss: 0.1375 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9928 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 86/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1321 - accuracy: 0.9576 - precision: 0.9576 - recall: 0.9576 - auc: 0.9930 - f1_score: 0.9576
# Epoch 86: val_loss improved from 0.10715 to 0.10510, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run5-DIR.h5
# 71/71 [==============================] - 34s 482ms/step - loss: 0.1321 - accuracy: 0.9576 - precision: 0.9576 - recall: 0.9576 - auc: 0.9930 - f1_score: 0.9576 - val_loss: 0.1051 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9976 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 87/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1319 - accuracy: 0.9580 - precision: 0.9580 - recall: 0.9580 - auc: 0.9930 - f1_score: 0.9580
# Epoch 87: val_loss did not improve from 0.10510
# 71/71 [==============================] - 35s 496ms/step - loss: 0.1319 - accuracy: 0.9580 - precision: 0.9580 - recall: 0.9580 - auc: 0.9930 - f1_score: 0.9580 - val_loss: 0.1394 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9914 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 88/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1488 - accuracy: 0.9496 - precision: 0.9496 - recall: 0.9496 - auc: 0.9906 - f1_score: 0.9496
# Epoch 88: val_loss did not improve from 0.10510
# 71/71 [==============================] - 34s 473ms/step - loss: 0.1488 - accuracy: 0.9496 - precision: 0.9496 - recall: 0.9496 - auc: 0.9906 - f1_score: 0.9496 - val_loss: 0.1963 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9817 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 89/150
# ...
# 71/71 [==============================] - 32s 445ms/step - loss: 0.1013 - accuracy: 0.9735 - precision: 0.9735 - recall: 0.9735 - auc: 0.9964 - f1_score: 0.9735 - val_loss: 0.1110 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9956 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 121/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700 - auc: 0.9967 - f1_score: 0.9700
# Epoch 121: val_loss did not improve from 0.08521
# 71/71 [==============================] - 32s 452ms/step - loss: 0.0997 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700 - auc: 0.9967 - f1_score: 0.9700 - val_loss: 0.0984 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9970 - val_f1_score: 0.9734 - lr: 1.0000e-05
# Epoch 122/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1070 - accuracy: 0.9624 - precision: 0.9624 - recall: 0.9624 - auc: 0.9960 - f1_score: 0.9624
# Epoch 122: val_loss did not improve from 0.08521
# 71/71 [==============================] - 34s 479ms/step - loss: 0.1070 - accuracy: 0.9624 - precision: 0.9624 - recall: 0.9624 - auc: 0.9960 - f1_score: 0.9624 - val_loss: 0.0899 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9978 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 123/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9757 - precision: 0.9757 - recall: 0.9757 - auc: 0.9975 - f1_score: 0.9757
# Epoch 123: val_loss did not improve from 0.08521
# 71/71 [==============================] - 31s 430ms/step - loss: 0.0916 - accuracy: 0.9757 - precision: 0.9757 - recall: 0.9757 - auc: 0.9975 - f1_score: 0.9757 - val_loss: 0.1163 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9948 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 124/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1091 - accuracy: 0.9669 - precision: 0.9669 - recall: 0.9669 - auc: 0.9956 - f1_score: 0.9669
# Epoch 124: val_loss did not improve from 0.08521
# 71/71 [==============================] - 33s 460ms/step - loss: 0.1091 - accuracy: 0.9669 - precision: 0.9669 - recall: 0.9669 - auc: 0.9956 - f1_score: 0.9669 - val_loss: 0.0908 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9979 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 125/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9966 - f1_score: 0.9730
# Epoch 125: val_loss did not improve from 0.08521
# 71/71 [==============================] - 32s 453ms/step - loss: 0.0975 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9966 - f1_score: 0.9730 - val_loss: 0.0907 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9981 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 126/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0916 - accuracy: 0.9779 - precision: 0.9779 - recall: 0.9779 - auc: 0.9973 - f1_score: 0.9779
# Epoch 126: val_loss did not improve from 0.08521
# 71/71 [==============================] - 34s 470ms/step - loss: 0.0916 - accuracy: 0.9779 - precision: 0.9779 - recall: 0.9779 - auc: 0.9973 - f1_score: 0.9779 - val_loss: 0.1170 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9949 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 127/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9691 - precision: 0.9691 - recall: 0.9691 - auc: 0.9967 - f1_score: 0.9691
# Epoch 127: val_loss did not improve from 0.08521
# 71/71 [==============================] - 34s 475ms/step - loss: 0.0994 - accuracy: 0.9691 - precision: 0.9691 - recall: 0.9691 - auc: 0.9967 - f1_score: 0.9691 - val_loss: 0.1156 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9922 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 128/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9744 - precision: 0.9744 - recall: 0.9744 - auc: 0.9969 - f1_score: 0.9744
# Epoch 128: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 128: val_loss did not improve from 0.08521
# 71/71 [==============================] - 33s 459ms/step - loss: 0.0969 - accuracy: 0.9744 - precision: 0.9744 - recall: 0.9744 - auc: 0.9969 - f1_score: 0.9744 - val_loss: 0.1044 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9962 - val_f1_score: 0.9734 - lr: 1.0000e-05
# Epoch 129/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0936 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9971 - f1_score: 0.9730
# Epoch 129: val_loss did not improve from 0.08521
# 71/71 [==============================] - 32s 453ms/step - loss: 0.0936 - accuracy: 0.9730 - precision: 0.9730 - recall: 0.9730 - auc: 0.9971 - f1_score: 0.9730 - val_loss: 0.0952 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9971 - val_f1_score: 0.9734 - lr: 1.0000e-05
# Epoch 130/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0997 - accuracy: 0.9717 - precision: 0.9717 - recall: 0.9717 - auc: 0.9965 - f1_score: 0.9717
# Epoch 130: val_loss did not improve from 0.08521
# 71/71 [==============================] - 32s 442ms/step - loss: 0.0997 - accuracy: 0.9717 - precision: 0.9717 - recall: 0.9717 - auc: 0.9965 - f1_score: 0.9717 - val_loss: 0.0986 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9972 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 131/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9966 - f1_score: 0.9753
# Epoch 131: val_loss did not improve from 0.08521
# 71/71 [==============================] - 34s 470ms/step - loss: 0.0958 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9966 - f1_score: 0.9753 - val_loss: 0.0880 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9979 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 132/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9682 - precision: 0.9682 - recall: 0.9682 - auc: 0.9964 - f1_score: 0.9682
# Epoch 132: val_loss did not improve from 0.08521
# 71/71 [==============================] - 34s 468ms/step - loss: 0.0988 - accuracy: 0.9682 - precision: 0.9682 - recall: 0.9682 - auc: 0.9964 - f1_score: 0.9682 - val_loss: 0.0968 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9974 - val_f1_score: 0.9734 - lr: 1.0000e-05
# Epoch 133/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0972 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9969 - f1_score: 0.9704
# Epoch 133: val_loss did not improve from 0.08521
# 71/71 [==============================] - 33s 462ms/step - loss: 0.0972 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9969 - f1_score: 0.9704 - val_loss: 0.0981 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9973 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 134/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9748 - precision: 0.9748 - recall: 0.9748 - auc: 0.9970 - f1_score: 0.9748
# Epoch 134: val_loss did not improve from 0.08521
# 71/71 [==============================] - 34s 473ms/step - loss: 0.0958 - accuracy: 0.9748 - precision: 0.9748 - recall: 0.9748 - auc: 0.9970 - f1_score: 0.9748 - val_loss: 0.1167 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9950 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 135/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9726 - precision: 0.9726 - recall: 0.9726 - auc: 0.9960 - f1_score: 0.9726
# Epoch 135: val_loss did not improve from 0.08521
# 71/71 [==============================] - 33s 465ms/step - loss: 0.1031 - accuracy: 0.9726 - precision: 0.9726 - recall: 0.9726 - auc: 0.9960 - f1_score: 0.9726 - val_loss: 0.0913 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9983 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 136/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9981 - f1_score: 0.9775
# Epoch 136: val_loss did not improve from 0.08521
# 71/71 [==============================] - 32s 452ms/step - loss: 0.0846 - accuracy: 0.9775 - precision: 0.9775 - recall: 0.9775 - auc: 0.9981 - f1_score: 0.9775 - val_loss: 0.1086 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9963 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 137/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9726 - precision: 0.9726 - recall: 0.9726 - auc: 0.9970 - f1_score: 0.9726
# Epoch 137: val_loss did not improve from 0.08521
# 71/71 [==============================] - 33s 460ms/step - loss: 0.0962 - accuracy: 0.9726 - precision: 0.9726 - recall: 0.9726 - auc: 0.9970 - f1_score: 0.9726 - val_loss: 0.1041 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9964 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 138/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9975 - f1_score: 0.9704
# Epoch 138: val_loss did not improve from 0.08521
# 71/71 [==============================] - 34s 483ms/step - loss: 0.0914 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9975 - f1_score: 0.9704 - val_loss: 0.1089 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9957 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 139/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9748 - precision: 0.9748 - recall: 0.9748 - auc: 0.9974 - f1_score: 0.9748
# Epoch 139: val_loss did not improve from 0.08521
# 71/71 [==============================] - 35s 491ms/step - loss: 0.0903 - accuracy: 0.9748 - precision: 0.9748 - recall: 0.9748 - auc: 0.9974 - f1_score: 0.9748 - val_loss: 0.0925 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9978 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 140/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9686 - precision: 0.9686 - recall: 0.9686 - auc: 0.9968 - f1_score: 0.9686
# Epoch 140: val_loss did not improve from 0.08521
# 71/71 [==============================] - 34s 469ms/step - loss: 0.0981 - accuracy: 0.9686 - precision: 0.9686 - recall: 0.9686 - auc: 0.9968 - f1_score: 0.9686 - val_loss: 0.1067 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9961 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 141/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0964 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700 - auc: 0.9966 - f1_score: 0.9700
# Epoch 141: val_loss did not improve from 0.08521
# 71/71 [==============================] - 34s 480ms/step - loss: 0.0964 - accuracy: 0.9700 - precision: 0.9700 - recall: 0.9700 - auc: 0.9966 - f1_score: 0.9700 - val_loss: 0.1091 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9955 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 142/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9964 - f1_score: 0.9704
# Epoch 142: val_loss did not improve from 0.08521
# 71/71 [==============================] - 35s 485ms/step - loss: 0.0994 - accuracy: 0.9704 - precision: 0.9704 - recall: 0.9704 - auc: 0.9964 - f1_score: 0.9704 - val_loss: 0.1024 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9968 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 143/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0953 - accuracy: 0.9726 - precision: 0.9726 - recall: 0.9726 - auc: 0.9970 - f1_score: 0.9726
# Epoch 143: val_loss did not improve from 0.08521
# 71/71 [==============================] - 35s 496ms/step - loss: 0.0953 - accuracy: 0.9726 - precision: 0.9726 - recall: 0.9726 - auc: 0.9970 - f1_score: 0.9726 - val_loss: 0.0860 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9979 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 144/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 0.9735 - precision: 0.9735 - recall: 0.9735 - auc: 0.9972 - f1_score: 0.9735
# Epoch 144: val_loss did not improve from 0.08521
# 71/71 [==============================] - 35s 483ms/step - loss: 0.0943 - accuracy: 0.9735 - precision: 0.9735 - recall: 0.9735 - auc: 0.9972 - f1_score: 0.9735 - val_loss: 0.1262 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9939 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 145/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.9722 - precision: 0.9722 - recall: 0.9722 - auc: 0.9963 - f1_score: 0.9722
# Epoch 145: val_loss did not improve from 0.08521
# 71/71 [==============================] - 33s 459ms/step - loss: 0.0990 - accuracy: 0.9722 - precision: 0.9722 - recall: 0.9722 - auc: 0.9963 - f1_score: 0.9722 - val_loss: 0.1107 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9956 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 146/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1011 - accuracy: 0.9695 - precision: 0.9695 - recall: 0.9695 - auc: 0.9965 - f1_score: 0.9695
# Epoch 146: val_loss did not improve from 0.08521
# 71/71 [==============================] - 33s 469ms/step - loss: 0.1011 - accuracy: 0.9695 - precision: 0.9695 - recall: 0.9695 - auc: 0.9965 - f1_score: 0.9695 - val_loss: 0.0927 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9978 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 147/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9748 - precision: 0.9748 - recall: 0.9748 - auc: 0.9972 - f1_score: 0.9748
# Epoch 147: val_loss did not improve from 0.08521
# 71/71 [==============================] - 33s 459ms/step - loss: 0.0926 - accuracy: 0.9748 - precision: 0.9748 - recall: 0.9748 - auc: 0.9972 - f1_score: 0.9748 - val_loss: 0.1041 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9965 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 148/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9766 - precision: 0.9766 - recall: 0.9766 - auc: 0.9971 - f1_score: 0.9766
# Epoch 148: val_loss did not improve from 0.08521
# 71/71 [==============================] - 33s 469ms/step - loss: 0.0937 - accuracy: 0.9766 - precision: 0.9766 - recall: 0.9766 - auc: 0.9971 - f1_score: 0.9766 - val_loss: 0.0957 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9976 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 149/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0962 - accuracy: 0.9726 - precision: 0.9726 - recall: 0.9726 - auc: 0.9969 - f1_score: 0.9726
# Epoch 149: val_loss did not improve from 0.08521
# 71/71 [==============================] - 33s 456ms/step - loss: 0.0962 - accuracy: 0.9726 - precision: 0.9726 - recall: 0.9726 - auc: 0.9969 - f1_score: 0.9726 - val_loss: 0.0988 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9967 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 150/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0929 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9972 - f1_score: 0.9753
# Epoch 150: val_loss did not improve from 0.08521
# 71/71 [==============================] - 34s 475ms/step - loss: 0.0929 - accuracy: 0.9753 - precision: 0.9753 - recall: 0.9753 - auc: 0.9972 - f1_score: 0.9753 - val_loss: 0.1017 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9968 - val_f1_score: 0.9645 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

# plt.subplot(2, 3, 5)
# plt.plot(range(1, len(f1_score_callback.train_f1_scores) + 1), f1_score_callback.train_f1_scores, label='Training F1 Score')
# plt.plot(range(1, len(f1_score_callback.val_f1_scores) + 1), f1_score_callback.val_f1_scores, label='Validation F1 Score')
# plt.title('Model F1-Score')
# plt.xlabel('Epoch')
# plt.ylabel('F1-Score')
# plt.legend(['F1 Score'], loc='lower right')


plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = DIR.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["benign", "malignant"], yticklabels=["benign", "malignant"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 1s 56ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9214616853013362
# F1-Score for each class: [0.89473684 0.94818653]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9242424242424242
# specificity: 0.9444444444444444

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  DIR.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 1s 56ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = DIR.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)

# test_loss, test_acc, test_precision, test_recall, test_auc = DIR.evaluate(test_generator)
# print('Test loss:', test_loss)
# print('Test accuracy:', test_acc)
# print('Test precision:', test_precision)
# print('Test recall:', test_recall)
# print('Test AUC:', test_auc)


# from sklearn.metrics import f1_score
# import numpy as np

# # 预测测试集
# y_pred = DIR.predict(test_generator)
# y_pred = np.argmax(y_pred, axis=1)

# # 真实标签
# y_true = test_generator.classes

# # 计算F1分数
# test_f1_score = f1_score(y_true, y_pred, average='micro')  # 或者根据你的需要选择其他average参数
# print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 2s 165ms/step - loss: 0.1784 - accuracy: 0.9309 - precision: 0.9309 - recall: 0.9309 - auc: 0.9868 - f1_score: 0.9309
# Test loss: 0.17836153507232666
# Test accuracy: 0.9309210777282715
# Test precision: 0.9309210777282715
# Test recall: 0.9309210777282715
# Test AUC: 0.9868096113204956
# Test F1 Score: 0.9309210777282715

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = DIR.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 56ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.94      0.89        90
#            1       0.97      0.92      0.95       198
#
#     accuracy                           0.93       288
#    macro avg       0.91      0.93      0.92       288
# weighted avg       0.93      0.93      0.93       288

# %% [markdown]
# #delete the model to prevent memory costs
#
# from keras import backend as K
# import gc
#
# K.clear_session()
# gc.collect()
#
# # del DIR
#
#
# from numba import cuda
#
# cuda.select_device(0)
# cuda.close()
