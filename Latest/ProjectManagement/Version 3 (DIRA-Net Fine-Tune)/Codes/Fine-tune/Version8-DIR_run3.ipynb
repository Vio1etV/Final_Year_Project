# %% [markdown]
# 再version 6的基础上，batchsize = 32， stem第一层变为4，用leaky relu，将inception a的函数里面的分支第一层神经元改为8
#
# 在Version 7的及基础上，加入L1正则化

# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.regularizers import l2

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.
# Out:
# 2024-03-12 15:12:38.125054: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 304 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

l2_reg = 0.001



def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='leaky_relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)
    
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    # a = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    c = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = attention_block_2(x)

    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    # c = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    shortcut = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(shortcut)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    shortcut = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(shortcut)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    shortcut = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(shortcut)
    
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 1
num_B_blocks = 1
num_C_blocks = 1

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.3)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax')(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# 2024-03-12 15:12:43.150464: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-12 15:12:43.883351: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22134 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:b1:00.0, compute capability: 8.9
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 4)  112         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 222, 222, 96  3552        ['conv2d[0][0]']
#                                 )
#
#  activation (Activation)        (None, 222, 222, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 222, 222, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 222, 222, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 222, 222, 4)  0           ['conv2d[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 220, 220, 4)  148         ['multiply[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 220, 220, 96  3552        ['conv2d_3[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 220, 220, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 220, 220, 1)  97          ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 220, 220, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 220, 220, 4)  0           ['conv2d_3[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 220, 220, 8)  296         ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 220, 220, 96  7008        ['conv2d_6[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 220, 220, 96  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 220, 220, 1)  97          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 220, 220, 1)  0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 220, 220, 8)  0           ['conv2d_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['multiply_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 218, 218, 12  876         ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_13[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_16[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_6 (Activation)      (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 16  160        ['conv2d_18[0][0]']
#  v2D)                           )
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_17[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 48  2352        ['activation_6[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['conv2d_22[0][0]',
#                                 )                                 'conv2d_21[0][0]']
#
#  activation_7 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 32  1568        ['activation_7[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_24[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_7[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 106, 106, 48  20784       ['activation_7[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_25[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_23[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_4[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_28[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_29[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_4[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_30[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_27[0][0]',
#                                 )                                 'conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 106, 106, 14  20880       ['concatenate_4[0][0]']
#                                 4)
#
#  conv2d_32 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_5[0][0]']
#                                 4)
#
#  add_1 (Add)                    (None, 106, 106, 14  0           ['conv2d_33[0][0]',
#                                 4)                                'conv2d_32[0][0]']
#
#  activation_8 (Activation)      (None, 106, 106, 14  0           ['add_1[0][0]']
#                                 4)
#
#  conv2d_38 (Conv2D)             (None, 106, 106, 32  4640        ['activation_8[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 106, 106, 32  4640        ['activation_8[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 106, 106, 32  4640        ['activation_8[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 106, 106, 36  10404       ['conv2d_38[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_8[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 52, 52, 36)   10404       ['conv2d_34[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 52, 52, 36)   10404       ['conv2d_36[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 52, 52, 40)   13000       ['conv2d_39[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_35[0][0]',
#                                                                   'conv2d_37[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 52, 52, 24)   6168        ['concatenate_6[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 52, 52, 28)   2044        ['conv2d_42[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 52, 52, 24)   6168        ['concatenate_6[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 52, 52, 32)   2720        ['conv2d_43[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 52, 52, 56)   0           ['conv2d_41[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 52, 52, 256)  65792       ['concatenate_6[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 52, 52, 256)  14592       ['concatenate_7[0][0]']
#
#  add_2 (Add)                    (None, 52, 52, 256)  0           ['conv2d_46[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  activation_9 (Activation)      (None, 52, 52, 256)  0           ['add_2[0][0]']
#
#  dropout (Dropout)              (None, 52, 52, 256)  0           ['activation_9[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 273,617
# Trainable params: 273,617
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# import numpy as np
# from sklearn.metrics import f1_score
# from tensorflow.keras.callbacks import Callback

# class F1ScoreCallback(Callback):
#     def __init__(self, train_generator, validation_generator, num_classes):
#         super(F1ScoreCallback, self).__init__()
#         self.train_generator = train_generator
#         self.validation_generator = validation_generator
#         self.num_classes = num_classes
#         self.train_f1_scores = []
#         self.val_f1_scores = []

#     def on_epoch_end(self, epoch, logs=None):
#         # 计算训练集F1分数
#         train_predict, train_true = self._get_predictions_and_true_labels(self.train_generator)
#         train_f1 = f1_score(train_true, train_predict, average='micro')
#         self.train_f1_scores.append(train_f1)
        
#         # 计算验证集F1分数
#         val_predict, val_true = self._get_predictions_and_true_labels(self.validation_generator)
#         val_f1 = f1_score(val_true, val_predict, average='micro')
#         self.val_f1_scores.append(val_f1)
        
#         print(f'Epoch {epoch+1}: Training F1 Score: {train_f1}, Validation F1 Score: {val_f1}')

#     def _get_predictions_and_true_labels(self, generator):
#         predictions = []
#         true_labels = []
#         for i in range(len(generator)):
#             x_batch, y_batch_true = next(generator)
#             y_batch_pred = self.model.predict(x_batch, verbose=0)
#             y_batch_pred = np.argmax(y_batch_pred, axis=1)
#             y_true = np.argmax(y_batch_true, axis=1)
#             predictions.extend(y_batch_pred)
#             true_labels.extend(y_true)
#         return predictions, true_labels


# # 继续使用之前的方式将回调添加到你的模型训练中

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(),
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version8_run3-DIR"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)


lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', 
                                 factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# f1_score_callback = F1ScoreCallback(train_generator = train_generator, 
#                                     validation_generator=validation_generator, 
#                                     num_classes=num_classes)


from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = DIR.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)


# history = DIR.fit(
#     train_generator,
#     epochs=150,
#     validation_data=validation_generator,
#     callbacks=[csv_logger, lr_reduction, model_checkpoint_callback, f1_score_callback]
# )
# Out:
# Epoch 1/150
# 2024-03-12 15:12:51.022770: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-12 15:12:52.087572: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-03-12 15:12:52.087595: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2024-03-12 15:12:52.087666: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-03-12 15:12:53.524327: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 0.7150 - accuracy: 0.5484 - precision: 0.5484 - recall: 0.5484 - auc: 0.5702 - f1_score: 0.5484
# Epoch 1: val_loss improved from inf to 0.63958, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 46s 533ms/step - loss: 0.7150 - accuracy: 0.5484 - precision: 0.5484 - recall: 0.5484 - auc: 0.5702 - f1_score: 0.5484 - val_loss: 0.6396 - val_accuracy: 0.6746 - val_precision: 0.6746 - val_recall: 0.6746 - val_auc: 0.7394 - val_f1_score: 0.6746 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6941 - accuracy: 0.6001 - precision: 0.6001 - recall: 0.6001 - auc: 0.6372 - f1_score: 0.6001
# Epoch 2: val_loss did not improve from 0.63958
# 71/71 [==============================] - 35s 491ms/step - loss: 0.6941 - accuracy: 0.6001 - precision: 0.6001 - recall: 0.6001 - auc: 0.6372 - f1_score: 0.6001 - val_loss: 0.6544 - val_accuracy: 0.6243 - val_precision: 0.6243 - val_recall: 0.6243 - val_auc: 0.6954 - val_f1_score: 0.6243 - lr: 0.0010
# Epoch 3/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5864 - accuracy: 0.7163 - precision: 0.7163 - recall: 0.7163 - auc: 0.7854 - f1_score: 0.7163
# Epoch 3: val_loss improved from 0.63958 to 0.63878, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 31s 437ms/step - loss: 0.5864 - accuracy: 0.7163 - precision: 0.7163 - recall: 0.7163 - auc: 0.7854 - f1_score: 0.7163 - val_loss: 0.6388 - val_accuracy: 0.6420 - val_precision: 0.6420 - val_recall: 0.6420 - val_auc: 0.7501 - val_f1_score: 0.6420 - lr: 0.0010
# Epoch 4/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5648 - accuracy: 0.7437 - precision: 0.7437 - recall: 0.7437 - auc: 0.8040 - f1_score: 0.7437
# Epoch 4: val_loss improved from 0.63878 to 0.51015, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 34s 476ms/step - loss: 0.5648 - accuracy: 0.7437 - precision: 0.7437 - recall: 0.7437 - auc: 0.8040 - f1_score: 0.7437 - val_loss: 0.5102 - val_accuracy: 0.7722 - val_precision: 0.7722 - val_recall: 0.7722 - val_auc: 0.8581 - val_f1_score: 0.7722 - lr: 0.0010
# Epoch 5/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5478 - accuracy: 0.7384 - precision: 0.7384 - recall: 0.7384 - auc: 0.8165 - f1_score: 0.7384
# Epoch 5: val_loss did not improve from 0.51015
# 71/71 [==============================] - 34s 475ms/step - loss: 0.5478 - accuracy: 0.7384 - precision: 0.7384 - recall: 0.7384 - auc: 0.8165 - f1_score: 0.7384 - val_loss: 0.5172 - val_accuracy: 0.7485 - val_precision: 0.7485 - val_recall: 0.7485 - val_auc: 0.8492 - val_f1_score: 0.7485 - lr: 0.0010
# Epoch 6/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5318 - accuracy: 0.7614 - precision: 0.7614 - recall: 0.7614 - auc: 0.8290 - f1_score: 0.7614
# Epoch 6: val_loss improved from 0.51015 to 0.44379, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 37s 525ms/step - loss: 0.5318 - accuracy: 0.7614 - precision: 0.7614 - recall: 0.7614 - auc: 0.8290 - f1_score: 0.7614 - val_loss: 0.4438 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.8987 - val_f1_score: 0.8166 - lr: 0.0010
# Epoch 7/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5548 - accuracy: 0.7357 - precision: 0.7357 - recall: 0.7357 - auc: 0.8100 - f1_score: 0.7357
# Epoch 7: val_loss did not improve from 0.44379
# 71/71 [==============================] - 37s 525ms/step - loss: 0.5548 - accuracy: 0.7357 - precision: 0.7357 - recall: 0.7357 - auc: 0.8100 - f1_score: 0.7357 - val_loss: 0.5284 - val_accuracy: 0.7219 - val_precision: 0.7219 - val_recall: 0.7219 - val_auc: 0.8247 - val_f1_score: 0.7219 - lr: 0.0010
# Epoch 8/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5304 - accuracy: 0.7609 - precision: 0.7609 - recall: 0.7609 - auc: 0.8303 - f1_score: 0.7609
# Epoch 8: val_loss did not improve from 0.44379
# 71/71 [==============================] - 39s 547ms/step - loss: 0.5304 - accuracy: 0.7609 - precision: 0.7609 - recall: 0.7609 - auc: 0.8303 - f1_score: 0.7609 - val_loss: 0.5541 - val_accuracy: 0.7515 - val_precision: 0.7515 - val_recall: 0.7515 - val_auc: 0.8611 - val_f1_score: 0.7515 - lr: 0.0010
# Epoch 9/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5135 - accuracy: 0.7680 - precision: 0.7680 - recall: 0.7680 - auc: 0.8419 - f1_score: 0.7680
# Epoch 9: val_loss improved from 0.44379 to 0.41435, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 37s 525ms/step - loss: 0.5135 - accuracy: 0.7680 - precision: 0.7680 - recall: 0.7680 - auc: 0.8419 - f1_score: 0.7680 - val_loss: 0.4143 - val_accuracy: 0.8373 - val_precision: 0.8373 - val_recall: 0.8373 - val_auc: 0.9270 - val_f1_score: 0.8373 - lr: 0.0010
# Epoch 10/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4813 - accuracy: 0.7839 - precision: 0.7839 - recall: 0.7839 - auc: 0.8678 - f1_score: 0.7839
# Epoch 10: val_loss did not improve from 0.41435
# 71/71 [==============================] - 36s 504ms/step - loss: 0.4813 - accuracy: 0.7839 - precision: 0.7839 - recall: 0.7839 - auc: 0.8678 - f1_score: 0.7839 - val_loss: 0.4449 - val_accuracy: 0.8284 - val_precision: 0.8284 - val_recall: 0.8284 - val_auc: 0.9065 - val_f1_score: 0.8284 - lr: 0.0010
# Epoch 11/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5043 - accuracy: 0.7773 - precision: 0.7773 - recall: 0.7773 - auc: 0.8549 - f1_score: 0.7773
# Epoch 11: val_loss did not improve from 0.41435
# 71/71 [==============================] - 38s 535ms/step - loss: 0.5043 - accuracy: 0.7773 - precision: 0.7773 - recall: 0.7773 - auc: 0.8549 - f1_score: 0.7773 - val_loss: 0.4254 - val_accuracy: 0.7811 - val_precision: 0.7811 - val_recall: 0.7811 - val_auc: 0.9011 - val_f1_score: 0.7811 - lr: 0.0010
# Epoch 12/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4802 - accuracy: 0.7715 - precision: 0.7715 - recall: 0.7715 - auc: 0.8657 - f1_score: 0.7715
# Epoch 12: val_loss did not improve from 0.41435
# 71/71 [==============================] - 38s 529ms/step - loss: 0.4802 - accuracy: 0.7715 - precision: 0.7715 - recall: 0.7715 - auc: 0.8657 - f1_score: 0.7715 - val_loss: 0.5910 - val_accuracy: 0.6331 - val_precision: 0.6331 - val_recall: 0.6331 - val_auc: 0.7618 - val_f1_score: 0.6331 - lr: 0.0010
# Epoch 13/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4729 - accuracy: 0.7830 - precision: 0.7830 - recall: 0.7830 - auc: 0.8718 - f1_score: 0.7830
# Epoch 13: val_loss did not improve from 0.41435
# 71/71 [==============================] - 39s 553ms/step - loss: 0.4729 - accuracy: 0.7830 - precision: 0.7830 - recall: 0.7830 - auc: 0.8718 - f1_score: 0.7830 - val_loss: 0.4144 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9566 - val_f1_score: 0.8787 - lr: 0.0010
# Epoch 14/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4627 - accuracy: 0.7879 - precision: 0.7879 - recall: 0.7879 - auc: 0.8771 - f1_score: 0.7879
# Epoch 14: val_loss improved from 0.41435 to 0.36797, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 40s 557ms/step - loss: 0.4627 - accuracy: 0.7879 - precision: 0.7879 - recall: 0.7879 - auc: 0.8771 - f1_score: 0.7879 - val_loss: 0.3680 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9380 - val_f1_score: 0.8402 - lr: 0.0010
# Epoch 15/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4246 - accuracy: 0.8065 - precision: 0.8065 - recall: 0.8065 - auc: 0.8968 - f1_score: 0.8065
# Epoch 15: val_loss did not improve from 0.36797
# 71/71 [==============================] - 36s 507ms/step - loss: 0.4246 - accuracy: 0.8065 - precision: 0.8065 - recall: 0.8065 - auc: 0.8968 - f1_score: 0.8065 - val_loss: 0.4299 - val_accuracy: 0.8136 - val_precision: 0.8136 - val_recall: 0.8136 - val_auc: 0.8950 - val_f1_score: 0.8136 - lr: 0.0010
# Epoch 16/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4472 - accuracy: 0.7932 - precision: 0.7932 - recall: 0.7932 - auc: 0.8843 - f1_score: 0.7932
# Epoch 16: val_loss did not improve from 0.36797
# 71/71 [==============================] - 36s 508ms/step - loss: 0.4472 - accuracy: 0.7932 - precision: 0.7932 - recall: 0.7932 - auc: 0.8843 - f1_score: 0.7932 - val_loss: 0.5694 - val_accuracy: 0.7219 - val_precision: 0.7219 - val_recall: 0.7219 - val_auc: 0.8110 - val_f1_score: 0.7219 - lr: 0.0010
# Epoch 17/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4014 - accuracy: 0.8268 - precision: 0.8268 - recall: 0.8268 - auc: 0.9101 - f1_score: 0.8268
# Epoch 17: val_loss improved from 0.36797 to 0.33527, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 37s 525ms/step - loss: 0.4014 - accuracy: 0.8268 - precision: 0.8268 - recall: 0.8268 - auc: 0.9101 - f1_score: 0.8268 - val_loss: 0.3353 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9401 - val_f1_score: 0.8580 - lr: 0.0010
# Epoch 18/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4458 - accuracy: 0.8007 - precision: 0.8007 - recall: 0.8007 - auc: 0.8898 - f1_score: 0.8007
# Epoch 18: val_loss did not improve from 0.33527
# 71/71 [==============================] - 36s 506ms/step - loss: 0.4458 - accuracy: 0.8007 - precision: 0.8007 - recall: 0.8007 - auc: 0.8898 - f1_score: 0.8007 - val_loss: 0.4095 - val_accuracy: 0.8669 - val_precision: 0.8669 - val_recall: 0.8669 - val_auc: 0.9364 - val_f1_score: 0.8669 - lr: 0.0010
# Epoch 19/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4120 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.9034 - f1_score: 0.8197
# Epoch 19: val_loss did not improve from 0.33527
# 71/71 [==============================] - 38s 529ms/step - loss: 0.4120 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.9034 - f1_score: 0.8197 - val_loss: 0.3443 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9526 - val_f1_score: 0.8787 - lr: 0.0010
# Epoch 20/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3949 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - auc: 0.9137 - f1_score: 0.8325
# Epoch 20: val_loss improved from 0.33527 to 0.30958, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 33s 456ms/step - loss: 0.3949 - accuracy: 0.8325 - precision: 0.8325 - recall: 0.8325 - auc: 0.9137 - f1_score: 0.8325 - val_loss: 0.3096 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9585 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 21/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3545 - accuracy: 0.8515 - precision: 0.8515 - recall: 0.8515 - auc: 0.9314 - f1_score: 0.8515
# Epoch 21: val_loss did not improve from 0.30958
# 71/71 [==============================] - 36s 500ms/step - loss: 0.3545 - accuracy: 0.8515 - precision: 0.8515 - recall: 0.8515 - auc: 0.9314 - f1_score: 0.8515 - val_loss: 0.3276 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9493 - val_f1_score: 0.9024 - lr: 0.0010
# Epoch 22/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3661 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.9246 - f1_score: 0.8374
# Epoch 22: val_loss did not improve from 0.30958
# 71/71 [==============================] - 35s 483ms/step - loss: 0.3661 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.9246 - f1_score: 0.8374 - val_loss: 0.3189 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9719 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 23/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3512 - accuracy: 0.8559 - precision: 0.8559 - recall: 0.8559 - auc: 0.9335 - f1_score: 0.8559
# Epoch 23: val_loss improved from 0.30958 to 0.27994, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 38s 535ms/step - loss: 0.3512 - accuracy: 0.8559 - precision: 0.8559 - recall: 0.8559 - auc: 0.9335 - f1_score: 0.8559 - val_loss: 0.2799 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9768 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 24/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3403 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9370 - f1_score: 0.8546
# Epoch 24: val_loss did not improve from 0.27994
# 71/71 [==============================] - 37s 515ms/step - loss: 0.3403 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9370 - f1_score: 0.8546 - val_loss: 0.5449 - val_accuracy: 0.7160 - val_precision: 0.7160 - val_recall: 0.7160 - val_auc: 0.8161 - val_f1_score: 0.7160 - lr: 0.0010
# Epoch 25/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3659 - accuracy: 0.8471 - precision: 0.8471 - recall: 0.8471 - auc: 0.9265 - f1_score: 0.8471
# Epoch 25: val_loss improved from 0.27994 to 0.26257, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 39s 542ms/step - loss: 0.3659 - accuracy: 0.8471 - precision: 0.8471 - recall: 0.8471 - auc: 0.9265 - f1_score: 0.8471 - val_loss: 0.2626 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9721 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 26/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3612 - accuracy: 0.8414 - precision: 0.8414 - recall: 0.8414 - auc: 0.9283 - f1_score: 0.8414
# Epoch 26: val_loss did not improve from 0.26257
# 71/71 [==============================] - 35s 495ms/step - loss: 0.3612 - accuracy: 0.8414 - precision: 0.8414 - recall: 0.8414 - auc: 0.9283 - f1_score: 0.8414 - val_loss: 0.3319 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9526 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 27/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3173 - accuracy: 0.8794 - precision: 0.8794 - recall: 0.8794 - auc: 0.9463 - f1_score: 0.8794
# Epoch 27: val_loss improved from 0.26257 to 0.23527, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 36s 506ms/step - loss: 0.3173 - accuracy: 0.8794 - precision: 0.8794 - recall: 0.8794 - auc: 0.9463 - f1_score: 0.8794 - val_loss: 0.2353 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9793 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 28/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3294 - accuracy: 0.8679 - precision: 0.8679 - recall: 0.8679 - auc: 0.9411 - f1_score: 0.8679
# Epoch 28: val_loss did not improve from 0.23527
# 71/71 [==============================] - 38s 525ms/step - loss: 0.3294 - accuracy: 0.8679 - precision: 0.8679 - recall: 0.8679 - auc: 0.9411 - f1_score: 0.8679 - val_loss: 0.2715 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9717 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 29/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3179 - accuracy: 0.8741 - precision: 0.8741 - recall: 0.8741 - auc: 0.9455 - f1_score: 0.8741
# Epoch 29: val_loss did not improve from 0.23527
# 71/71 [==============================] - 37s 512ms/step - loss: 0.3179 - accuracy: 0.8741 - precision: 0.8741 - recall: 0.8741 - auc: 0.9455 - f1_score: 0.8741 - val_loss: 0.4025 - val_accuracy: 0.8432 - val_precision: 0.8432 - val_recall: 0.8432 - val_auc: 0.9230 - val_f1_score: 0.8432 - lr: 0.0010
# Epoch 30/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3107 - accuracy: 0.8719 - precision: 0.8719 - recall: 0.8719 - auc: 0.9484 - f1_score: 0.8719
# Epoch 30: val_loss did not improve from 0.23527
# 71/71 [==============================] - 38s 526ms/step - loss: 0.3107 - accuracy: 0.8719 - precision: 0.8719 - recall: 0.8719 - auc: 0.9484 - f1_score: 0.8719 - val_loss: 0.2398 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9804 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 31/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3165 - accuracy: 0.8683 - precision: 0.8683 - recall: 0.8683 - auc: 0.9465 - f1_score: 0.8683
# Epoch 31: val_loss did not improve from 0.23527
# 71/71 [==============================] - 39s 551ms/step - loss: 0.3165 - accuracy: 0.8683 - precision: 0.8683 - recall: 0.8683 - auc: 0.9465 - f1_score: 0.8683 - val_loss: 0.4441 - val_accuracy: 0.7574 - val_precision: 0.7574 - val_recall: 0.7574 - val_auc: 0.8838 - val_f1_score: 0.7574 - lr: 0.0010
# Epoch 32/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8670 - precision: 0.8670 - recall: 0.8670 - auc: 0.9464 - f1_score: 0.8670
# Epoch 32: val_loss did not improve from 0.23527
# 71/71 [==============================] - 37s 515ms/step - loss: 0.3137 - accuracy: 0.8670 - precision: 0.8670 - recall: 0.8670 - auc: 0.9464 - f1_score: 0.8670 - val_loss: 0.3491 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9413 - val_f1_score: 0.8580 - lr: 0.0010
# Epoch 33/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3030 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9522 - f1_score: 0.8860
# Epoch 33: val_loss did not improve from 0.23527
# 71/71 [==============================] - 37s 519ms/step - loss: 0.3030 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9522 - f1_score: 0.8860 - val_loss: 0.3031 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9613 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 34/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2988 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9526 - f1_score: 0.8798
# Epoch 34: val_loss did not improve from 0.23527
# 71/71 [==============================] - 37s 512ms/step - loss: 0.2988 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9526 - f1_score: 0.8798 - val_loss: 0.2392 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9749 - val_f1_score: 0.9172 - lr: 0.0010
# Epoch 35/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.8917 - precision: 0.8917 - recall: 0.8917 - auc: 0.9536 - f1_score: 0.8917
# Epoch 35: val_loss did not improve from 0.23527
# 71/71 [==============================] - 37s 524ms/step - loss: 0.2947 - accuracy: 0.8917 - precision: 0.8917 - recall: 0.8917 - auc: 0.9536 - f1_score: 0.8917 - val_loss: 0.2850 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9658 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 36/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9570 - f1_score: 0.8860
# Epoch 36: val_loss did not improve from 0.23527
# 71/71 [==============================] - 40s 565ms/step - loss: 0.2844 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9570 - f1_score: 0.8860 - val_loss: 0.2465 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9758 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 37/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3006 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9528 - f1_score: 0.8851
# Epoch 37: val_loss improved from 0.23527 to 0.23473, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 38s 525ms/step - loss: 0.3006 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9528 - f1_score: 0.8851 - val_loss: 0.2347 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9734 - val_f1_score: 0.9172 - lr: 0.0010
# Epoch 38/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3518 - accuracy: 0.8626 - precision: 0.8626 - recall: 0.8626 - auc: 0.9329 - f1_score: 0.8626
# Epoch 38: val_loss did not improve from 0.23473
# 71/71 [==============================] - 37s 515ms/step - loss: 0.3518 - accuracy: 0.8626 - precision: 0.8626 - recall: 0.8626 - auc: 0.9329 - f1_score: 0.8626 - val_loss: 0.2839 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9714 - val_f1_score: 0.9083 - lr: 0.0010
# Epoch 39/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2932 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9550 - f1_score: 0.8895
# Epoch 39: val_loss did not improve from 0.23473
# 71/71 [==============================] - 39s 543ms/step - loss: 0.2932 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9550 - f1_score: 0.8895 - val_loss: 0.2589 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9692 - val_f1_score: 0.8935 - lr: 0.0010
# Epoch 40/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2831 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9575 - f1_score: 0.8900
# Epoch 40: val_loss did not improve from 0.23473
# 71/71 [==============================] - 36s 510ms/step - loss: 0.2831 - accuracy: 0.8900 - precision: 0.8900 - recall: 0.8900 - auc: 0.9575 - f1_score: 0.8900 - val_loss: 0.3388 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9381 - val_f1_score: 0.8580 - lr: 0.0010
# Epoch 41/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2731 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9604 - f1_score: 0.8931
# Epoch 41: val_loss did not improve from 0.23473
# 71/71 [==============================] - 37s 520ms/step - loss: 0.2731 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9604 - f1_score: 0.8931 - val_loss: 0.2670 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9685 - val_f1_score: 0.9024 - lr: 0.0010
# Epoch 42/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2858 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9566 - f1_score: 0.8842
# Epoch 42: val_loss did not improve from 0.23473
# 71/71 [==============================] - 34s 471ms/step - loss: 0.2858 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9566 - f1_score: 0.8842 - val_loss: 0.3101 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9595 - val_f1_score: 0.8846 - lr: 0.0010
# Epoch 43/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3056 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9502 - f1_score: 0.8798
# Epoch 43: val_loss did not improve from 0.23473
# 71/71 [==============================] - 38s 534ms/step - loss: 0.3056 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9502 - f1_score: 0.8798 - val_loss: 0.5243 - val_accuracy: 0.7130 - val_precision: 0.7130 - val_recall: 0.7130 - val_auc: 0.8233 - val_f1_score: 0.7130 - lr: 0.0010
# Epoch 44/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2831 - accuracy: 0.8869 - precision: 0.8869 - recall: 0.8869 - auc: 0.9574 - f1_score: 0.8869
# Epoch 44: val_loss did not improve from 0.23473
# 71/71 [==============================] - 37s 520ms/step - loss: 0.2831 - accuracy: 0.8869 - precision: 0.8869 - recall: 0.8869 - auc: 0.9574 - f1_score: 0.8869 - val_loss: 0.2448 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9763 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 45/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2625 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9639 - f1_score: 0.8931
# Epoch 45: val_loss did not improve from 0.23473
# 71/71 [==============================] - 38s 531ms/step - loss: 0.2625 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9639 - f1_score: 0.8931 - val_loss: 0.3412 - val_accuracy: 0.8462 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9375 - val_f1_score: 0.8462 - lr: 0.0010
# Epoch 46/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2720 - accuracy: 0.8864 - precision: 0.8864 - recall: 0.8864 - auc: 0.9608 - f1_score: 0.8864
# Epoch 46: val_loss improved from 0.23473 to 0.19442, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 37s 520ms/step - loss: 0.2720 - accuracy: 0.8864 - precision: 0.8864 - recall: 0.8864 - auc: 0.9608 - f1_score: 0.8864 - val_loss: 0.1944 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9864 - val_f1_score: 0.9379 - lr: 0.0010
# Epoch 47/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2581 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9653 - f1_score: 0.8962
# Epoch 47: val_loss did not improve from 0.19442
# 71/71 [==============================] - 36s 501ms/step - loss: 0.2581 - accuracy: 0.8962 - precision: 0.8962 - recall: 0.8962 - auc: 0.9653 - f1_score: 0.8962 - val_loss: 0.2293 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9813 - val_f1_score: 0.9142 - lr: 0.0010
# Epoch 48/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2743 - accuracy: 0.8957 - precision: 0.8957 - recall: 0.8957 - auc: 0.9598 - f1_score: 0.8957
# Epoch 48: val_loss did not improve from 0.19442
# 71/71 [==============================] - 39s 542ms/step - loss: 0.2743 - accuracy: 0.8957 - precision: 0.8957 - recall: 0.8957 - auc: 0.9598 - f1_score: 0.8957 - val_loss: 0.2284 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9809 - val_f1_score: 0.9349 - lr: 0.0010
# Epoch 49/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2604 - accuracy: 0.8966 - precision: 0.8966 - recall: 0.8966 - auc: 0.9647 - f1_score: 0.8966
# Epoch 49: val_loss did not improve from 0.19442
# 71/71 [==============================] - 37s 517ms/step - loss: 0.2604 - accuracy: 0.8966 - precision: 0.8966 - recall: 0.8966 - auc: 0.9647 - f1_score: 0.8966 - val_loss: 0.2568 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9656 - val_f1_score: 0.8905 - lr: 0.0010
# Epoch 50/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2737 - accuracy: 0.8856 - precision: 0.8856 - recall: 0.8856 - auc: 0.9604 - f1_score: 0.8856
# Epoch 50: val_loss did not improve from 0.19442
# 71/71 [==============================] - 39s 539ms/step - loss: 0.2737 - accuracy: 0.8856 - precision: 0.8856 - recall: 0.8856 - auc: 0.9604 - f1_score: 0.8856 - val_loss: 0.2552 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9676 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 51/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2681 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9626 - f1_score: 0.8931
# Epoch 51: val_loss did not improve from 0.19442
# 71/71 [==============================] - 40s 556ms/step - loss: 0.2681 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9626 - f1_score: 0.8931 - val_loss: 0.3241 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9410 - val_f1_score: 0.8402 - lr: 0.0010
# Epoch 52/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2691 - accuracy: 0.8966 - precision: 0.8966 - recall: 0.8966 - auc: 0.9622 - f1_score: 0.8966
# Epoch 52: val_loss did not improve from 0.19442
# 71/71 [==============================] - 40s 554ms/step - loss: 0.2691 - accuracy: 0.8966 - precision: 0.8966 - recall: 0.8966 - auc: 0.9622 - f1_score: 0.8966 - val_loss: 0.3087 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9500 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 53/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2644 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9637 - f1_score: 0.9023
# Epoch 53: val_loss did not improve from 0.19442
# 71/71 [==============================] - 38s 530ms/step - loss: 0.2644 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9637 - f1_score: 0.9023 - val_loss: 0.2393 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9744 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 54/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2449 - accuracy: 0.9028 - precision: 0.9028 - recall: 0.9028 - auc: 0.9693 - f1_score: 0.9028
# Epoch 54: val_loss did not improve from 0.19442
# 71/71 [==============================] - 37s 528ms/step - loss: 0.2449 - accuracy: 0.9028 - precision: 0.9028 - recall: 0.9028 - auc: 0.9693 - f1_score: 0.9028 - val_loss: 0.1984 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9845 - val_f1_score: 0.9349 - lr: 0.0010
# Epoch 55/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9709 - f1_score: 0.9050
# Epoch 55: val_loss did not improve from 0.19442
# 71/71 [==============================] - 38s 525ms/step - loss: 0.2392 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9709 - f1_score: 0.9050 - val_loss: 0.2875 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9563 - val_f1_score: 0.8757 - lr: 0.0010
# Epoch 56/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2387 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9702 - f1_score: 0.9076
# Epoch 56: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 56: val_loss did not improve from 0.19442
# 71/71 [==============================] - 37s 511ms/step - loss: 0.2387 - accuracy: 0.9076 - precision: 0.9076 - recall: 0.9076 - auc: 0.9702 - f1_score: 0.9076 - val_loss: 0.3599 - val_accuracy: 0.8521 - val_precision: 0.8521 - val_recall: 0.8521 - val_auc: 0.9262 - val_f1_score: 0.8521 - lr: 0.0010
# Epoch 57/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2226 - accuracy: 0.9143 - precision: 0.9143 - recall: 0.9143 - auc: 0.9747 - f1_score: 0.9143
# Epoch 57: val_loss improved from 0.19442 to 0.19031, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 37s 519ms/step - loss: 0.2226 - accuracy: 0.9143 - precision: 0.9143 - recall: 0.9143 - auc: 0.9747 - f1_score: 0.9143 - val_loss: 0.1903 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9864 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 58/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2050 - accuracy: 0.9236 - precision: 0.9236 - recall: 0.9236 - auc: 0.9791 - f1_score: 0.9236
# Epoch 58: val_loss did not improve from 0.19031
# 71/71 [==============================] - 36s 504ms/step - loss: 0.2050 - accuracy: 0.9236 - precision: 0.9236 - recall: 0.9236 - auc: 0.9791 - f1_score: 0.9236 - val_loss: 0.2032 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9833 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 59/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2002 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9800 - f1_score: 0.9200
# Epoch 59: val_loss did not improve from 0.19031
# 71/71 [==============================] - 37s 519ms/step - loss: 0.2002 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9800 - f1_score: 0.9200 - val_loss: 0.1917 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9846 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 60/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9196 - precision: 0.9196 - recall: 0.9196 - auc: 0.9781 - f1_score: 0.9196
# Epoch 60: val_loss did not improve from 0.19031
# 71/71 [==============================] - 39s 547ms/step - loss: 0.2080 - accuracy: 0.9196 - precision: 0.9196 - recall: 0.9196 - auc: 0.9781 - f1_score: 0.9196 - val_loss: 0.1988 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9836 - val_f1_score: 0.9349 - lr: 1.0000e-04
# Epoch 61/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2068 - accuracy: 0.9240 - precision: 0.9240 - recall: 0.9240 - auc: 0.9782 - f1_score: 0.9240
# Epoch 61: val_loss improved from 0.19031 to 0.18524, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 38s 534ms/step - loss: 0.2068 - accuracy: 0.9240 - precision: 0.9240 - recall: 0.9240 - auc: 0.9782 - f1_score: 0.9240 - val_loss: 0.1852 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9876 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 62/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2038 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9791 - f1_score: 0.9200
# Epoch 62: val_loss improved from 0.18524 to 0.18517, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 40s 561ms/step - loss: 0.2038 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9791 - f1_score: 0.9200 - val_loss: 0.1852 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9857 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 63/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2061 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9786 - f1_score: 0.9213
# Epoch 63: val_loss did not improve from 0.18517
# 71/71 [==============================] - 37s 517ms/step - loss: 0.2061 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9786 - f1_score: 0.9213 - val_loss: 0.1916 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9849 - val_f1_score: 0.9231 - lr: 1.0000e-04
# Epoch 64/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9275 - precision: 0.9275 - recall: 0.9275 - auc: 0.9815 - f1_score: 0.9275
# Epoch 64: val_loss did not improve from 0.18517
# 71/71 [==============================] - 36s 505ms/step - loss: 0.1921 - accuracy: 0.9275 - precision: 0.9275 - recall: 0.9275 - auc: 0.9815 - f1_score: 0.9275 - val_loss: 0.1878 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9854 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 65/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9236 - precision: 0.9236 - recall: 0.9236 - auc: 0.9800 - f1_score: 0.9236
# Epoch 65: val_loss improved from 0.18517 to 0.16507, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 36s 501ms/step - loss: 0.2005 - accuracy: 0.9236 - precision: 0.9236 - recall: 0.9236 - auc: 0.9800 - f1_score: 0.9236 - val_loss: 0.1651 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9903 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 66/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1960 - accuracy: 0.9227 - precision: 0.9227 - recall: 0.9227 - auc: 0.9808 - f1_score: 0.9227
# Epoch 66: val_loss did not improve from 0.16507
# 71/71 [==============================] - 36s 498ms/step - loss: 0.1960 - accuracy: 0.9227 - precision: 0.9227 - recall: 0.9227 - auc: 0.9808 - f1_score: 0.9227 - val_loss: 0.1744 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9887 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 67/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1957 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9805 - f1_score: 0.9311
# Epoch 67: val_loss did not improve from 0.16507
# 71/71 [==============================] - 33s 466ms/step - loss: 0.1957 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9805 - f1_score: 0.9311 - val_loss: 0.1766 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9896 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 68/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9802 - f1_score: 0.9191
# Epoch 68: val_loss did not improve from 0.16507
# 71/71 [==============================] - 35s 496ms/step - loss: 0.1987 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9802 - f1_score: 0.9191 - val_loss: 0.1955 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9847 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 69/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9821 - f1_score: 0.9289
# Epoch 69: val_loss did not improve from 0.16507
# 71/71 [==============================] - 35s 491ms/step - loss: 0.1892 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9821 - f1_score: 0.9289 - val_loss: 0.1900 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9857 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 70/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9819 - f1_score: 0.9319
# Epoch 70: val_loss did not improve from 0.16507
# 71/71 [==============================] - 34s 473ms/step - loss: 0.1889 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9819 - f1_score: 0.9319 - val_loss: 0.2214 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9753 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 71/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1933 - accuracy: 0.9266 - precision: 0.9266 - recall: 0.9266 - auc: 0.9814 - f1_score: 0.9266
# Epoch 71: val_loss did not improve from 0.16507
# 71/71 [==============================] - 35s 485ms/step - loss: 0.1933 - accuracy: 0.9266 - precision: 0.9266 - recall: 0.9266 - auc: 0.9814 - f1_score: 0.9266 - val_loss: 0.1993 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9813 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 72/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1908 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9820 - f1_score: 0.9289
# Epoch 72: val_loss did not improve from 0.16507
# 71/71 [==============================] - 33s 467ms/step - loss: 0.1908 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9820 - f1_score: 0.9289 - val_loss: 0.1824 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9861 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 73/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1909 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - auc: 0.9822 - f1_score: 0.9284
# Epoch 73: val_loss did not improve from 0.16507
# 71/71 [==============================] - 34s 474ms/step - loss: 0.1909 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - auc: 0.9822 - f1_score: 0.9284 - val_loss: 0.1833 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9849 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 74/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1920 - accuracy: 0.9315 - precision: 0.9315 - recall: 0.9315 - auc: 0.9814 - f1_score: 0.9315
# Epoch 74: val_loss did not improve from 0.16507
# 71/71 [==============================] - 33s 456ms/step - loss: 0.1920 - accuracy: 0.9315 - precision: 0.9315 - recall: 0.9315 - auc: 0.9814 - f1_score: 0.9315 - val_loss: 0.1847 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9864 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 75/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1929 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9813 - f1_score: 0.9271
# Epoch 75: val_loss improved from 0.16507 to 0.16301, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 36s 505ms/step - loss: 0.1929 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9813 - f1_score: 0.9271 - val_loss: 0.1630 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9910 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 76/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9827 - f1_score: 0.9271
# Epoch 76: val_loss did not improve from 0.16301
# 71/71 [==============================] - 35s 492ms/step - loss: 0.1876 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9827 - f1_score: 0.9271 - val_loss: 0.1773 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9861 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 77/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1952 - accuracy: 0.9249 - precision: 0.9249 - recall: 0.9249 - auc: 0.9809 - f1_score: 0.9249
# Epoch 77: val_loss did not improve from 0.16301
# 71/71 [==============================] - 37s 516ms/step - loss: 0.1952 - accuracy: 0.9249 - precision: 0.9249 - recall: 0.9249 - auc: 0.9809 - f1_score: 0.9249 - val_loss: 0.1861 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9857 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 78/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1874 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9825 - f1_score: 0.9271
# Epoch 78: val_loss did not improve from 0.16301
# 71/71 [==============================] - 36s 499ms/step - loss: 0.1874 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9825 - f1_score: 0.9271 - val_loss: 0.1907 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9852 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 79/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9812 - f1_score: 0.9262
# Epoch 79: val_loss did not improve from 0.16301
# 71/71 [==============================] - 37s 518ms/step - loss: 0.1936 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9812 - f1_score: 0.9262 - val_loss: 0.1788 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9866 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 80/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1961 - accuracy: 0.9249 - precision: 0.9249 - recall: 0.9249 - auc: 0.9807 - f1_score: 0.9249
# Epoch 80: val_loss did not improve from 0.16301
# 71/71 [==============================] - 36s 510ms/step - loss: 0.1961 - accuracy: 0.9249 - precision: 0.9249 - recall: 0.9249 - auc: 0.9807 - f1_score: 0.9249 - val_loss: 0.1947 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9831 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 81/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1980 - accuracy: 0.9222 - precision: 0.9222 - recall: 0.9222 - auc: 0.9802 - f1_score: 0.9222
# Epoch 81: val_loss did not improve from 0.16301
# 71/71 [==============================] - 36s 505ms/step - loss: 0.1980 - accuracy: 0.9222 - precision: 0.9222 - recall: 0.9222 - auc: 0.9802 - f1_score: 0.9222 - val_loss: 0.1990 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9824 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 82/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9800 - f1_score: 0.9297
# Epoch 82: val_loss did not improve from 0.16301
# 71/71 [==============================] - 36s 504ms/step - loss: 0.1996 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9800 - f1_score: 0.9297 - val_loss: 0.1636 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9908 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 83/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1897 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9823 - f1_score: 0.9302
# Epoch 83: val_loss did not improve from 0.16301
# 71/71 [==============================] - 34s 468ms/step - loss: 0.1897 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9823 - f1_score: 0.9302 - val_loss: 0.1711 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9891 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 84/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1815 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9838 - f1_score: 0.9346
# Epoch 84: val_loss improved from 0.16301 to 0.16263, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 34s 482ms/step - loss: 0.1815 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9838 - f1_score: 0.9346 - val_loss: 0.1626 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9909 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 85/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9819 - f1_score: 0.9293
# Epoch 85: val_loss did not improve from 0.16263
# 71/71 [==============================] - 33s 461ms/step - loss: 0.1935 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9819 - f1_score: 0.9293 - val_loss: 0.1887 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9846 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 86/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1788 - accuracy: 0.9315 - precision: 0.9315 - recall: 0.9315 - auc: 0.9845 - f1_score: 0.9315
# Epoch 86: val_loss did not improve from 0.16263
# 71/71 [==============================] - 35s 483ms/step - loss: 0.1788 - accuracy: 0.9315 - precision: 0.9315 - recall: 0.9315 - auc: 0.9845 - f1_score: 0.9315 - val_loss: 0.1874 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9852 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 87/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9824 - f1_score: 0.9302
# Epoch 87: val_loss improved from 0.16263 to 0.13490, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run3-DIR.h5
# 71/71 [==============================] - 34s 471ms/step - loss: 0.1907 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9824 - f1_score: 0.9302 - val_loss: 0.1349 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9946 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 88/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1851 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9830 - f1_score: 0.9319
# Epoch 88: val_loss did not improve from 0.13490
# ...
# 71/71 [==============================] - 35s 493ms/step - loss: 0.1785 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9844 - f1_score: 0.9319 - val_loss: 0.1703 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9893 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 100/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9386 - precision: 0.9386 - recall: 0.9386 - auc: 0.9851 - f1_score: 0.9386
# Epoch 100: val_loss did not improve from 0.13490
# 71/71 [==============================] - 35s 489ms/step - loss: 0.1748 - accuracy: 0.9386 - precision: 0.9386 - recall: 0.9386 - auc: 0.9851 - f1_score: 0.9386 - val_loss: 0.1658 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9895 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 101/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1812 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9844 - f1_score: 0.9355
# Epoch 101: val_loss did not improve from 0.13490
# 71/71 [==============================] - 36s 500ms/step - loss: 0.1812 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9844 - f1_score: 0.9355 - val_loss: 0.1672 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9896 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 102/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1696 - accuracy: 0.9395 - precision: 0.9395 - recall: 0.9395 - auc: 0.9864 - f1_score: 0.9395
# Epoch 102: val_loss did not improve from 0.13490
# 71/71 [==============================] - 39s 543ms/step - loss: 0.1696 - accuracy: 0.9395 - precision: 0.9395 - recall: 0.9395 - auc: 0.9864 - f1_score: 0.9395 - val_loss: 0.1758 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9881 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 103/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1715 - accuracy: 0.9377 - precision: 0.9377 - recall: 0.9377 - auc: 0.9859 - f1_score: 0.9377
# Epoch 103: val_loss did not improve from 0.13490
# 71/71 [==============================] - 38s 531ms/step - loss: 0.1715 - accuracy: 0.9377 - precision: 0.9377 - recall: 0.9377 - auc: 0.9859 - f1_score: 0.9377 - val_loss: 0.1749 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9875 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 104/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1845 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9834 - f1_score: 0.9297
# Epoch 104: val_loss did not improve from 0.13490
# 71/71 [==============================] - 37s 517ms/step - loss: 0.1845 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9834 - f1_score: 0.9297 - val_loss: 0.1766 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9871 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 105/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9386 - precision: 0.9386 - recall: 0.9386 - auc: 0.9854 - f1_score: 0.9386
# Epoch 105: val_loss did not improve from 0.13490
# 71/71 [==============================] - 37s 519ms/step - loss: 0.1731 - accuracy: 0.9386 - precision: 0.9386 - recall: 0.9386 - auc: 0.9854 - f1_score: 0.9386 - val_loss: 0.1743 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9888 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 106/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1729 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9855 - f1_score: 0.9390
# Epoch 106: val_loss did not improve from 0.13490
# 71/71 [==============================] - 37s 522ms/step - loss: 0.1729 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9855 - f1_score: 0.9390 - val_loss: 0.1666 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9902 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 107/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9373 - precision: 0.9373 - recall: 0.9373 - auc: 0.9870 - f1_score: 0.9373
# Epoch 107: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 107: val_loss did not improve from 0.13490
# 71/71 [==============================] - 37s 522ms/step - loss: 0.1655 - accuracy: 0.9373 - precision: 0.9373 - recall: 0.9373 - auc: 0.9870 - f1_score: 0.9373 - val_loss: 0.1662 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9889 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 108/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9851 - f1_score: 0.9355
# Epoch 108: val_loss did not improve from 0.13490
# 71/71 [==============================] - 35s 486ms/step - loss: 0.1749 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9851 - f1_score: 0.9355 - val_loss: 0.1885 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9842 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 109/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1773 - accuracy: 0.9324 - precision: 0.9324 - recall: 0.9324 - auc: 0.9848 - f1_score: 0.9324
# Epoch 109: val_loss did not improve from 0.13490
# 71/71 [==============================] - 37s 523ms/step - loss: 0.1773 - accuracy: 0.9324 - precision: 0.9324 - recall: 0.9324 - auc: 0.9848 - f1_score: 0.9324 - val_loss: 0.1631 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9893 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 110/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9845 - f1_score: 0.9355
# Epoch 110: val_loss did not improve from 0.13490
# 71/71 [==============================] - 38s 528ms/step - loss: 0.1777 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9845 - f1_score: 0.9355 - val_loss: 0.1687 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9899 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 111/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1790 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9840 - f1_score: 0.9337
# Epoch 111: val_loss did not improve from 0.13490
# 71/71 [==============================] - 36s 499ms/step - loss: 0.1790 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9840 - f1_score: 0.9337 - val_loss: 0.1871 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9843 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 112/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9858 - f1_score: 0.9355
# Epoch 112: val_loss did not improve from 0.13490
# 71/71 [==============================] - 38s 527ms/step - loss: 0.1717 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9858 - f1_score: 0.9355 - val_loss: 0.1757 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9877 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 113/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1793 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9842 - f1_score: 0.9359
# Epoch 113: val_loss did not improve from 0.13490
# 71/71 [==============================] - 36s 509ms/step - loss: 0.1793 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9842 - f1_score: 0.9359 - val_loss: 0.1677 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9888 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 114/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1754 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9851 - f1_score: 0.9355
# Epoch 114: val_loss did not improve from 0.13490
# 71/71 [==============================] - 35s 483ms/step - loss: 0.1754 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9851 - f1_score: 0.9355 - val_loss: 0.1827 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9858 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 115/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1680 - accuracy: 0.9439 - precision: 0.9439 - recall: 0.9439 - auc: 0.9863 - f1_score: 0.9439
# Epoch 115: val_loss did not improve from 0.13490
# 71/71 [==============================] - 38s 536ms/step - loss: 0.1680 - accuracy: 0.9439 - precision: 0.9439 - recall: 0.9439 - auc: 0.9863 - f1_score: 0.9439 - val_loss: 0.1580 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9913 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 116/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1754 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9851 - f1_score: 0.9346
# Epoch 116: val_loss did not improve from 0.13490
# 71/71 [==============================] - 36s 507ms/step - loss: 0.1754 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9851 - f1_score: 0.9346 - val_loss: 0.1961 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9824 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 117/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9862 - f1_score: 0.9368
# Epoch 117: val_loss did not improve from 0.13490
# 71/71 [==============================] - 35s 488ms/step - loss: 0.1700 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9862 - f1_score: 0.9368 - val_loss: 0.1614 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9901 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 118/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9852 - f1_score: 0.9368
# Epoch 118: val_loss did not improve from 0.13490
# 71/71 [==============================] - 34s 470ms/step - loss: 0.1742 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9852 - f1_score: 0.9368 - val_loss: 0.1719 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9892 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 119/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1791 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9841 - f1_score: 0.9355
# Epoch 119: val_loss did not improve from 0.13490
# 71/71 [==============================] - 37s 518ms/step - loss: 0.1791 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9841 - f1_score: 0.9355 - val_loss: 0.1751 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9872 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 120/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1713 - accuracy: 0.9373 - precision: 0.9373 - recall: 0.9373 - auc: 0.9857 - f1_score: 0.9373
# Epoch 120: val_loss did not improve from 0.13490
# 71/71 [==============================] - 35s 485ms/step - loss: 0.1713 - accuracy: 0.9373 - precision: 0.9373 - recall: 0.9373 - auc: 0.9857 - f1_score: 0.9373 - val_loss: 0.1874 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9857 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 121/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1665 - accuracy: 0.9386 - precision: 0.9386 - recall: 0.9386 - auc: 0.9867 - f1_score: 0.9386
# Epoch 123: val_loss did not improve from 0.13490
# 71/71 [==============================] - 35s 497ms/step - loss: 0.1665 - accuracy: 0.9386 - precision: 0.9386 - recall: 0.9386 - auc: 0.9867 - f1_score: 0.9386 - val_loss: 0.1645 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9909 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 124/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1729 - accuracy: 0.9426 - precision: 0.9426 - recall: 0.9426 - auc: 0.9854 - f1_score: 0.9426
# Epoch 124: val_loss did not improve from 0.13490
# 71/71 [==============================] - 34s 473ms/step - loss: 0.1729 - accuracy: 0.9426 - precision: 0.9426 - recall: 0.9426 - auc: 0.9854 - f1_score: 0.9426 - val_loss: 0.1724 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9878 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 125/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1783 - accuracy: 0.9386 - precision: 0.9386 - recall: 0.9386 - auc: 0.9843 - f1_score: 0.9386
# Epoch 125: val_loss did not improve from 0.13490
# 71/71 [==============================] - 34s 481ms/step - loss: 0.1783 - accuracy: 0.9386 - precision: 0.9386 - recall: 0.9386 - auc: 0.9843 - f1_score: 0.9386 - val_loss: 0.1578 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9912 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 126/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9412 - precision: 0.9412 - recall: 0.9412 - auc: 0.9860 - f1_score: 0.9412
# Epoch 126: val_loss did not improve from 0.13490
# 71/71 [==============================] - 37s 519ms/step - loss: 0.1701 - accuracy: 0.9412 - precision: 0.9412 - recall: 0.9412 - auc: 0.9860 - f1_score: 0.9412 - val_loss: 0.1668 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9906 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 127/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 0.9386 - precision: 0.9386 - recall: 0.9386 - auc: 0.9865 - f1_score: 0.9386
# Epoch 127: val_loss did not improve from 0.13490
# 71/71 [==============================] - 36s 509ms/step - loss: 0.1683 - accuracy: 0.9386 - precision: 0.9386 - recall: 0.9386 - auc: 0.9865 - f1_score: 0.9386 - val_loss: 0.1526 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9936 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 128/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9862 - f1_score: 0.9368
# Epoch 128: val_loss did not improve from 0.13490
# 71/71 [==============================] - 38s 528ms/step - loss: 0.1701 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9862 - f1_score: 0.9368 - val_loss: 0.1727 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9880 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 129/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1711 - accuracy: 0.9364 - precision: 0.9364 - recall: 0.9364 - auc: 0.9857 - f1_score: 0.9364
# Epoch 148: val_loss did not improve from 0.13490
# 71/71 [==============================] - 35s 486ms/step - loss: 0.1711 - accuracy: 0.9364 - precision: 0.9364 - recall: 0.9364 - auc: 0.9857 - f1_score: 0.9364 - val_loss: 0.1653 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9899 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 149/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1692 - accuracy: 0.9381 - precision: 0.9381 - recall: 0.9381 - auc: 0.9862 - f1_score: 0.9381
# Epoch 149: val_loss did not improve from 0.13490
# 71/71 [==============================] - 37s 511ms/step - loss: 0.1692 - accuracy: 0.9381 - precision: 0.9381 - recall: 0.9381 - auc: 0.9862 - f1_score: 0.9381 - val_loss: 0.1836 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9852 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 150/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1641 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9872 - f1_score: 0.9390
# Epoch 150: val_loss did not improve from 0.13490
# 71/71 [==============================] - 34s 475ms/step - loss: 0.1641 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9872 - f1_score: 0.9390 - val_loss: 0.1796 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9855 - val_f1_score: 0.9379 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

# plt.subplot(2, 3, 5)
# plt.plot(range(1, len(f1_score_callback.train_f1_scores) + 1), f1_score_callback.train_f1_scores, label='Training F1 Score')
# plt.plot(range(1, len(f1_score_callback.val_f1_scores) + 1), f1_score_callback.val_f1_scores, label='Validation F1 Score')
# plt.title('Model F1-Score')
# plt.xlabel('Epoch')
# plt.ylabel('F1-Score')
# plt.legend(['F1 Score'], loc='lower right')


plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = DIR.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 1s 50ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9067869355360736
# F1-Score for each class: [0.87150838 0.94206549]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9396984924623115
# specificity: 0.8764044943820225

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  DIR.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 0s 50ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = DIR.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)

# test_loss, test_acc, test_precision, test_recall, test_auc = DIR.evaluate(test_generator)
# print('Test loss:', test_loss)
# print('Test accuracy:', test_acc)
# print('Test precision:', test_precision)
# print('Test recall:', test_recall)
# print('Test AUC:', test_auc)


# from sklearn.metrics import f1_score
# import numpy as np

# # 预测测试集
# y_pred = DIR.predict(test_generator)
# y_pred = np.argmax(y_pred, axis=1)

# # 真实标签
# y_true = test_generator.classes

# # 计算F1分数
# test_f1_score = f1_score(y_true, y_pred, average='micro')  # 或者根据你的需要选择其他average参数
# print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 2s 158ms/step - loss: 0.2170 - accuracy: 0.9211 - precision: 0.9211 - recall: 0.9211 - auc: 0.9763 - f1_score: 0.9211
# Test loss: 0.21702006459236145
# Test accuracy: 0.9210526347160339
# Test precision: 0.9210526347160339
# Test recall: 0.9210526347160339
# Test AUC: 0.9763460159301758
# Test F1 Score: 0.9210526347160339

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = DIR.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 0s 51ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.87        89
#            1       0.94      0.94      0.94       199
#
#     accuracy                           0.92       288
#    macro avg       0.91      0.91      0.91       288
# weighted avg       0.92      0.92      0.92       288

# %% [markdown]
# #delete the model to prevent memory costs
#
# from keras import backend as K
# import gc
#
# K.clear_session()
# gc.collect()
#
# # del DIR
#
#
# from numba import cuda
#
# cuda.select_device(0)
# cuda.close()
