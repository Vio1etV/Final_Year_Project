# %% [markdown]
# 再version 6的基础上，batchsize = 32， stem第一层变为4，用leaky relu，将inception a的函数里面的分支第一层神经元改为8
#
# 在Version 7的及基础上，加入L1正则化

# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.regularizers import l2

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.
# Out:
# 2024-03-11 13:17:08.253288: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 304 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

l2_reg = 0.001



def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='leaky_relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = attention_block_2(x)
    
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    x = attention_block_2(x)
    

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)
    
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    # a = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    c = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = attention_block_2(x)

    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    # c = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 5
num_B_blocks = 10
num_C_blocks = 5

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.3)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax', kernel_regularizer = l2(l2_reg))(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# 2024-03-11 13:17:13.232370: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-11 13:17:13.863175: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22134 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:b1:00.0, compute capability: 8.9
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 4)  112         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 222, 222, 96  3552        ['conv2d[0][0]']
#                                 )
#
#  activation (Activation)        (None, 222, 222, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 222, 222, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 222, 222, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 222, 222, 4)  0           ['conv2d[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 220, 220, 4)  148         ['multiply[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 220, 220, 96  3552        ['conv2d_3[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 220, 220, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 220, 220, 1)  97          ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 220, 220, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 220, 220, 4)  0           ['conv2d_3[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 220, 220, 8)  296         ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 220, 220, 96  7008        ['conv2d_6[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 220, 220, 96  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 220, 220, 1)  97          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 220, 220, 1)  0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 220, 220, 8)  0           ['conv2d_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['multiply_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 218, 218, 12  876         ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_13[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_16[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_6 (Activation)      (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 16  160        ['conv2d_18[0][0]']
#  v2D)                           )
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_17[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['activation_6[0][0]',
#                                 )                                 'conv2d_21[0][0]']
#
#  activation_7 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 16  784         ['activation_7[0][0]']
#                                 )
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_23[0][0]']
#  onv2D)                         )
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_24[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_22[0][0]',
#                                 )                                 'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 214, 214, 48  0           ['activation_7[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  activation_8 (Activation)      (None, 214, 214, 48  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 214, 214, 16  784         ['activation_8[0][0]']
#                                 )
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_28[0][0]']
#  onv2D)                         )
#
#  conv2d_30 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_29[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_27[0][0]',
#                                 )                                 'depthwise_conv2d_2[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_5[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 214, 214, 48  0           ['activation_8[0][0]',
#                                 )                                 'conv2d_31[0][0]']
#
#  activation_9 (Activation)      (None, 214, 214, 48  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  conv2d_32 (Conv2D)             (None, 214, 214, 16  784         ['activation_9[0][0]']
#                                 )
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_33[0][0]']
#  onv2D)                         )
#
#  conv2d_35 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_34[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_32[0][0]',
#                                 )                                 'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_6[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 214, 214, 48  0           ['activation_9[0][0]',
#                                 )                                 'conv2d_36[0][0]']
#
#  activation_10 (Activation)     (None, 214, 214, 48  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 214, 214, 16  784         ['activation_10[0][0]']
#                                 )
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 214, 214, 16  160        ['conv2d_38[0][0]']
#  onv2D)                         )
#
#  conv2d_40 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_39[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_37[0][0]',
#                                 )                                 'depthwise_conv2d_4[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_7[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 214, 214, 48  0           ['activation_10[0][0]',
#                                 )                                 'conv2d_41[0][0]']
#
#  activation_11 (Activation)     (None, 214, 214, 48  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 214, 214, 32  1568        ['activation_11[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_43[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_11[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 106, 106, 48  20784       ['activation_11[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_44[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_42[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_49[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_46[0][0]',
#                                 )                                 'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_9[0][0]']
#                                 4)
#
#  add_5 (Add)                    (None, 106, 106, 14  0           ['concatenate_8[0][0]',
#                                 4)                                'conv2d_51[0][0]']
#
#  activation_12 (Activation)     (None, 106, 106, 14  0           ['add_5[0][0]']
#                                 4)
#
#  conv2d_53 (Conv2D)             (None, 106, 106, 16  2320        ['activation_12[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 106, 106, 24  3480        ['activation_12[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_55[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_52[0][0]',
#                                 )                                 'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_10[0][0]']
#                                 4)
#
#  add_6 (Add)                    (None, 106, 106, 14  0           ['activation_12[0][0]',
#                                 4)                                'conv2d_57[0][0]']
#
#  activation_13 (Activation)     (None, 106, 106, 14  0           ['add_6[0][0]']
#                                 4)
#
#  conv2d_59 (Conv2D)             (None, 106, 106, 16  2320        ['activation_13[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_59[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_60[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 106, 106, 24  3480        ['activation_13[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_61[0][0]']
#                                 )
#
#  concatenate_11 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_58[0][0]',
#                                 )                                 'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_11[0][0]']
#                                 4)
#
#  add_7 (Add)                    (None, 106, 106, 14  0           ['activation_13[0][0]',
#                                 4)                                'conv2d_63[0][0]']
#
#  activation_14 (Activation)     (None, 106, 106, 14  0           ['add_7[0][0]']
#                                 4)
#
#  conv2d_65 (Conv2D)             (None, 106, 106, 16  2320        ['activation_14[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_65[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_66[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 106, 106, 24  3480        ['activation_14[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_67[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_64[0][0]',
#                                 )                                 'conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_12[0][0]']
#                                 4)
#
#  add_8 (Add)                    (None, 106, 106, 14  0           ['activation_14[0][0]',
#                                 4)                                'conv2d_69[0][0]']
#
#  activation_15 (Activation)     (None, 106, 106, 14  0           ['add_8[0][0]']
#                                 4)
#
#  conv2d_71 (Conv2D)             (None, 106, 106, 16  2320        ['activation_15[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_71[0][0]']
#                                 )
#
#  conv2d_73 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_72[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 106, 106, 24  3480        ['activation_15[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_73[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_70[0][0]',
#                                 )                                 'conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_13[0][0]']
#                                 4)
#
#  add_9 (Add)                    (None, 106, 106, 14  0           ['activation_15[0][0]',
#                                 4)                                'conv2d_75[0][0]']
#
#  activation_16 (Activation)     (None, 106, 106, 14  0           ['add_9[0][0]']
#                                 4)
#
#  conv2d_77 (Conv2D)             (None, 106, 106, 16  2320        ['activation_16[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_77[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_78[0][0]']
#                                 )
#
#  conv2d_76 (Conv2D)             (None, 106, 106, 24  3480        ['activation_16[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_79[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_76[0][0]',
#                                 )                                 'conv2d_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_14[0][0]']
#                                 4)
#
#  add_10 (Add)                   (None, 106, 106, 14  0           ['activation_16[0][0]',
#                                 4)                                'conv2d_81[0][0]']
#
#  activation_17 (Activation)     (None, 106, 106, 14  0           ['add_10[0][0]']
#                                 4)
#
#  conv2d_83 (Conv2D)             (None, 106, 106, 16  2320        ['activation_17[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_83[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_84[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 106, 106, 24  3480        ['activation_17[0][0]']
#                                 )
#
#  conv2d_86 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_85[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_82[0][0]',
#                                 )                                 'conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_15[0][0]']
#                                 4)
#
#  add_11 (Add)                   (None, 106, 106, 14  0           ['activation_17[0][0]',
#                                 4)                                'conv2d_87[0][0]']
#
#  activation_18 (Activation)     (None, 106, 106, 14  0           ['add_11[0][0]']
#                                 4)
#
#  conv2d_89 (Conv2D)             (None, 106, 106, 16  2320        ['activation_18[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_89[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_90[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 106, 106, 24  3480        ['activation_18[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_91[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_88[0][0]',
#                                 )                                 'conv2d_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_16[0][0]']
#                                 4)
#
#  add_12 (Add)                   (None, 106, 106, 14  0           ['activation_18[0][0]',
#                                 4)                                'conv2d_93[0][0]']
#
#  activation_19 (Activation)     (None, 106, 106, 14  0           ['add_12[0][0]']
#                                 4)
#
#  conv2d_95 (Conv2D)             (None, 106, 106, 16  2320        ['activation_19[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_95[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_96[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 106, 106, 24  3480        ['activation_19[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_97[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_94[0][0]',
#                                 )                                 'conv2d_98[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_17[0][0]']
#                                 4)
#
#  add_13 (Add)                   (None, 106, 106, 14  0           ['activation_19[0][0]',
#                                 4)                                'conv2d_99[0][0]']
#
#  activation_20 (Activation)     (None, 106, 106, 14  0           ['add_13[0][0]']
#                                 4)
#
#  conv2d_101 (Conv2D)            (None, 106, 106, 16  2320        ['activation_20[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 106, 106, 20  2260        ['conv2d_101[0][0]']
#                                 )
#
#  conv2d_103 (Conv2D)            (None, 106, 106, 24  3384        ['conv2d_102[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 106, 106, 24  3480        ['activation_20[0][0]']
#                                 )
#
#  conv2d_104 (Conv2D)            (None, 106, 106, 24  600         ['conv2d_103[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_100[0][0]',
#                                 )                                 'conv2d_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 106, 106, 14  7056        ['concatenate_18[0][0]']
#                                 4)
#
#  add_14 (Add)                   (None, 106, 106, 14  0           ['activation_20[0][0]',
#                                 4)                                'conv2d_105[0][0]']
#
#  activation_21 (Activation)     (None, 106, 106, 14  0           ['add_14[0][0]']
#                                 4)
#
#  conv2d_110 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_106 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_108 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_111 (Conv2D)            (None, 106, 106, 36  10404       ['conv2d_110[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_21[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_106[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_108[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 52, 52, 40)   13000       ['conv2d_111[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_107[0][0]',
#                                                                   'conv2d_109[0][0]',
#                                                                   'conv2d_112[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_114[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_115[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_113[0][0]',
#                                                                   'conv2d_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_20[0][0]']
#
#  add_15 (Add)                   (None, 52, 52, 256)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_117[0][0]']
#
#  activation_22 (Activation)     (None, 52, 52, 256)  0           ['add_15[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_119[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_120[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_118[0][0]',
#                                                                   'conv2d_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_21[0][0]']
#
#  add_16 (Add)                   (None, 52, 52, 256)  0           ['activation_22[0][0]',
#                                                                   'conv2d_122[0][0]']
#
#  activation_23 (Activation)     (None, 52, 52, 256)  0           ['add_16[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_124[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_125[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_123[0][0]',
#                                                                   'conv2d_126[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_22[0][0]']
#
#  add_17 (Add)                   (None, 52, 52, 256)  0           ['activation_23[0][0]',
#                                                                   'conv2d_127[0][0]']
#
#  activation_24 (Activation)     (None, 52, 52, 256)  0           ['add_17[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_129[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_130[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_128[0][0]',
#                                                                   'conv2d_131[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_23[0][0]']
#
#  add_18 (Add)                   (None, 52, 52, 256)  0           ['activation_24[0][0]',
#                                                                   'conv2d_132[0][0]']
#
#  activation_25 (Activation)     (None, 52, 52, 256)  0           ['add_18[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_134[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_135[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_133[0][0]',
#                                                                   'conv2d_136[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_24[0][0]']
#
#  add_19 (Add)                   (None, 52, 52, 256)  0           ['activation_25[0][0]',
#                                                                   'conv2d_137[0][0]']
#
#  activation_26 (Activation)     (None, 52, 52, 256)  0           ['add_19[0][0]']
#
#  dropout (Dropout)              (None, 52, 52, 256)  0           ['activation_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 505,821
# Trainable params: 505,821
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# import numpy as np
# from sklearn.metrics import f1_score
# from tensorflow.keras.callbacks import Callback

# class F1ScoreCallback(Callback):
#     def __init__(self, train_generator, validation_generator, num_classes):
#         super(F1ScoreCallback, self).__init__()
#         self.train_generator = train_generator
#         self.validation_generator = validation_generator
#         self.num_classes = num_classes
#         self.train_f1_scores = []
#         self.val_f1_scores = []

#     def on_epoch_end(self, epoch, logs=None):
#         # 计算训练集F1分数
#         train_predict, train_true = self._get_predictions_and_true_labels(self.train_generator)
#         train_f1 = f1_score(train_true, train_predict, average='micro')
#         self.train_f1_scores.append(train_f1)
        
#         # 计算验证集F1分数
#         val_predict, val_true = self._get_predictions_and_true_labels(self.validation_generator)
#         val_f1 = f1_score(val_true, val_predict, average='micro')
#         self.val_f1_scores.append(val_f1)
        
#         print(f'Epoch {epoch+1}: Training F1 Score: {train_f1}, Validation F1 Score: {val_f1}')

#     def _get_predictions_and_true_labels(self, generator):
#         predictions = []
#         true_labels = []
#         for i in range(len(generator)):
#             x_batch, y_batch_true = next(generator)
#             y_batch_pred = self.model.predict(x_batch, verbose=0)
#             y_batch_pred = np.argmax(y_batch_pred, axis=1)
#             y_true = np.argmax(y_batch_true, axis=1)
#             predictions.extend(y_batch_pred)
#             true_labels.extend(y_true)
#         return predictions, true_labels


# # 继续使用之前的方式将回调添加到你的模型训练中

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(),
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version10-DIR"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)


lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', 
                                 factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# f1_score_callback = F1ScoreCallback(train_generator = train_generator, 
#                                     validation_generator=validation_generator, 
#                                     num_classes=num_classes)


from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = DIR.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)


# history = DIR.fit(
#     train_generator,
#     epochs=150,
#     validation_data=validation_generator,
#     callbacks=[csv_logger, lr_reduction, model_checkpoint_callback, f1_score_callback]
# )
# Out:
# Epoch 1/150
# 2024-03-11 13:17:26.342032: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-11 13:17:27.330523: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-03-11 13:17:27.330545: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2024-03-11 13:17:27.330608: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-03-11 13:17:28.711500: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 32.7201 - accuracy: 0.5029 - precision: 0.5029 - recall: 0.5029 - auc: 0.4998 - f1_score: 0.5029
# Epoch 1: val_loss improved from inf to 0.72359, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 69s 795ms/step - loss: 32.7201 - accuracy: 0.5029 - precision: 0.5029 - recall: 0.5029 - auc: 0.4998 - f1_score: 0.5029 - val_loss: 0.7236 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.4498 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6927 - accuracy: 0.5608 - precision: 0.5608 - recall: 0.5608 - auc: 0.5831 - f1_score: 0.5608
# Epoch 2: val_loss improved from 0.72359 to 0.72152, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 731ms/step - loss: 0.6927 - accuracy: 0.5608 - precision: 0.5608 - recall: 0.5608 - auc: 0.5831 - f1_score: 0.5608 - val_loss: 0.7215 - val_accuracy: 0.4793 - val_precision: 0.4793 - val_recall: 0.4793 - val_auc: 0.5205 - val_f1_score: 0.4793 - lr: 0.0010
# Epoch 3/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6576 - accuracy: 0.6173 - precision: 0.6173 - recall: 0.6173 - auc: 0.6651 - f1_score: 0.6173
# Epoch 3: val_loss improved from 0.72152 to 0.55516, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 51s 719ms/step - loss: 0.6576 - accuracy: 0.6173 - precision: 0.6173 - recall: 0.6173 - auc: 0.6651 - f1_score: 0.6173 - val_loss: 0.5552 - val_accuracy: 0.7663 - val_precision: 0.7663 - val_recall: 0.7663 - val_auc: 0.8406 - val_f1_score: 0.7663 - lr: 0.0010
# Epoch 4/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6048 - accuracy: 0.6805 - precision: 0.6805 - recall: 0.6805 - auc: 0.7482 - f1_score: 0.6805
# Epoch 4: val_loss did not improve from 0.55516
# 71/71 [==============================] - 51s 712ms/step - loss: 0.6048 - accuracy: 0.6805 - precision: 0.6805 - recall: 0.6805 - auc: 0.7482 - f1_score: 0.6805 - val_loss: 0.7396 - val_accuracy: 0.5858 - val_precision: 0.5858 - val_recall: 0.5858 - val_auc: 0.7120 - val_f1_score: 0.5858 - lr: 0.0010
# Epoch 5/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5603 - accuracy: 0.7309 - precision: 0.7309 - recall: 0.7309 - auc: 0.7946 - f1_score: 0.7309
# Epoch 5: val_loss improved from 0.55516 to 0.48175, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 53s 739ms/step - loss: 0.5603 - accuracy: 0.7309 - precision: 0.7309 - recall: 0.7309 - auc: 0.7946 - f1_score: 0.7309 - val_loss: 0.4817 - val_accuracy: 0.7811 - val_precision: 0.7811 - val_recall: 0.7811 - val_auc: 0.8583 - val_f1_score: 0.7811 - lr: 0.0010
# Epoch 6/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5282 - accuracy: 0.7596 - precision: 0.7596 - recall: 0.7596 - auc: 0.8250 - f1_score: 0.7596
# Epoch 6: val_loss did not improve from 0.48175
# 71/71 [==============================] - 51s 716ms/step - loss: 0.5282 - accuracy: 0.7596 - precision: 0.7596 - recall: 0.7596 - auc: 0.8250 - f1_score: 0.7596 - val_loss: 0.5066 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.8992 - val_f1_score: 0.8166 - lr: 0.0010
# Epoch 7/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5274 - accuracy: 0.7534 - precision: 0.7534 - recall: 0.7534 - auc: 0.8260 - f1_score: 0.7534
# Epoch 7: val_loss improved from 0.48175 to 0.44001, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 51s 709ms/step - loss: 0.5274 - accuracy: 0.7534 - precision: 0.7534 - recall: 0.7534 - auc: 0.8260 - f1_score: 0.7534 - val_loss: 0.4400 - val_accuracy: 0.8284 - val_precision: 0.8284 - val_recall: 0.8284 - val_auc: 0.9031 - val_f1_score: 0.8284 - lr: 0.0010
# Epoch 8/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5067 - accuracy: 0.7605 - precision: 0.7605 - recall: 0.7605 - auc: 0.8424 - f1_score: 0.7605
# Epoch 8: val_loss did not improve from 0.44001
# 71/71 [==============================] - 51s 714ms/step - loss: 0.5067 - accuracy: 0.7605 - precision: 0.7605 - recall: 0.7605 - auc: 0.8424 - f1_score: 0.7605 - val_loss: 0.4496 - val_accuracy: 0.7959 - val_precision: 0.7959 - val_recall: 0.7959 - val_auc: 0.8988 - val_f1_score: 0.7959 - lr: 0.0010
# Epoch 9/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5495 - accuracy: 0.7296 - precision: 0.7296 - recall: 0.7296 - auc: 0.8079 - f1_score: 0.7296
# Epoch 9: val_loss did not improve from 0.44001
# 71/71 [==============================] - 51s 715ms/step - loss: 0.5495 - accuracy: 0.7296 - precision: 0.7296 - recall: 0.7296 - auc: 0.8079 - f1_score: 0.7296 - val_loss: 0.4784 - val_accuracy: 0.8284 - val_precision: 0.8284 - val_recall: 0.8284 - val_auc: 0.9037 - val_f1_score: 0.8284 - lr: 0.0010
# Epoch 10/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5128 - accuracy: 0.7645 - precision: 0.7645 - recall: 0.7645 - auc: 0.8398 - f1_score: 0.7645
# Epoch 10: val_loss did not improve from 0.44001
# 71/71 [==============================] - 52s 730ms/step - loss: 0.5128 - accuracy: 0.7645 - precision: 0.7645 - recall: 0.7645 - auc: 0.8398 - f1_score: 0.7645 - val_loss: 0.6997 - val_accuracy: 0.5473 - val_precision: 0.5473 - val_recall: 0.5473 - val_auc: 0.7122 - val_f1_score: 0.5473 - lr: 0.0010
# Epoch 11/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4975 - accuracy: 0.7658 - precision: 0.7658 - recall: 0.7658 - auc: 0.8488 - f1_score: 0.7658
# Epoch 11: val_loss improved from 0.44001 to 0.42153, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 53s 740ms/step - loss: 0.4975 - accuracy: 0.7658 - precision: 0.7658 - recall: 0.7658 - auc: 0.8488 - f1_score: 0.7658 - val_loss: 0.4215 - val_accuracy: 0.8195 - val_precision: 0.8195 - val_recall: 0.8195 - val_auc: 0.9072 - val_f1_score: 0.8195 - lr: 0.0010
# Epoch 12/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.7707 - precision: 0.7707 - recall: 0.7707 - auc: 0.8472 - f1_score: 0.7707
# Epoch 12: val_loss did not improve from 0.42153
# 71/71 [==============================] - 52s 727ms/step - loss: 0.5000 - accuracy: 0.7707 - precision: 0.7707 - recall: 0.7707 - auc: 0.8472 - f1_score: 0.7707 - val_loss: 0.4254 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.9086 - val_f1_score: 0.8166 - lr: 0.0010
# Epoch 13/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4833 - accuracy: 0.7808 - precision: 0.7808 - recall: 0.7808 - auc: 0.8592 - f1_score: 0.7808
# Epoch 13: val_loss did not improve from 0.42153
# 71/71 [==============================] - 51s 706ms/step - loss: 0.4833 - accuracy: 0.7808 - precision: 0.7808 - recall: 0.7808 - auc: 0.8592 - f1_score: 0.7808 - val_loss: 0.4276 - val_accuracy: 0.8432 - val_precision: 0.8432 - val_recall: 0.8432 - val_auc: 0.9233 - val_f1_score: 0.8432 - lr: 0.0010
# Epoch 14/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4854 - accuracy: 0.7830 - precision: 0.7830 - recall: 0.7830 - auc: 0.8566 - f1_score: 0.7830
# Epoch 14: val_loss did not improve from 0.42153
# 71/71 [==============================] - 50s 701ms/step - loss: 0.4854 - accuracy: 0.7830 - precision: 0.7830 - recall: 0.7830 - auc: 0.8566 - f1_score: 0.7830 - val_loss: 0.4377 - val_accuracy: 0.8077 - val_precision: 0.8077 - val_recall: 0.8077 - val_auc: 0.9073 - val_f1_score: 0.8077 - lr: 0.0010
# Epoch 15/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5145 - accuracy: 0.7561 - precision: 0.7561 - recall: 0.7561 - auc: 0.8352 - f1_score: 0.7561
# Epoch 15: val_loss did not improve from 0.42153
# 71/71 [==============================] - 52s 724ms/step - loss: 0.5145 - accuracy: 0.7561 - precision: 0.7561 - recall: 0.7561 - auc: 0.8352 - f1_score: 0.7561 - val_loss: 0.4979 - val_accuracy: 0.8018 - val_precision: 0.8018 - val_recall: 0.8018 - val_auc: 0.8646 - val_f1_score: 0.8018 - lr: 0.0010
# Epoch 16/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5062 - accuracy: 0.7715 - precision: 0.7715 - recall: 0.7715 - auc: 0.8414 - f1_score: 0.7715
# Epoch 16: val_loss did not improve from 0.42153
# 71/71 [==============================] - 52s 727ms/step - loss: 0.5062 - accuracy: 0.7715 - precision: 0.7715 - recall: 0.7715 - auc: 0.8414 - f1_score: 0.7715 - val_loss: 0.5498 - val_accuracy: 0.6982 - val_precision: 0.6982 - val_recall: 0.6982 - val_auc: 0.8144 - val_f1_score: 0.6982 - lr: 0.0010
# Epoch 17/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5012 - accuracy: 0.7676 - precision: 0.7676 - recall: 0.7676 - auc: 0.8481 - f1_score: 0.7676
# Epoch 17: val_loss did not improve from 0.42153
# 71/71 [==============================] - 51s 708ms/step - loss: 0.5012 - accuracy: 0.7676 - precision: 0.7676 - recall: 0.7676 - auc: 0.8481 - f1_score: 0.7676 - val_loss: 0.4562 - val_accuracy: 0.7811 - val_precision: 0.7811 - val_recall: 0.7811 - val_auc: 0.8980 - val_f1_score: 0.7811 - lr: 0.0010
# Epoch 18/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5208 - accuracy: 0.7503 - precision: 0.7503 - recall: 0.7503 - auc: 0.8295 - f1_score: 0.7503
# Epoch 18: val_loss improved from 0.42153 to 0.41124, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 725ms/step - loss: 0.5208 - accuracy: 0.7503 - precision: 0.7503 - recall: 0.7503 - auc: 0.8295 - f1_score: 0.7503 - val_loss: 0.4112 - val_accuracy: 0.8314 - val_precision: 0.8314 - val_recall: 0.8314 - val_auc: 0.9157 - val_f1_score: 0.8314 - lr: 0.0010
# Epoch 19/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4903 - accuracy: 0.7729 - precision: 0.7729 - recall: 0.7729 - auc: 0.8550 - f1_score: 0.7729
# Epoch 19: val_loss did not improve from 0.41124
# 71/71 [==============================] - 52s 729ms/step - loss: 0.4903 - accuracy: 0.7729 - precision: 0.7729 - recall: 0.7729 - auc: 0.8550 - f1_score: 0.7729 - val_loss: 0.4634 - val_accuracy: 0.7899 - val_precision: 0.7899 - val_recall: 0.7899 - val_auc: 0.8709 - val_f1_score: 0.7899 - lr: 0.0010
# Epoch 20/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5299 - accuracy: 0.7402 - precision: 0.7402 - recall: 0.7402 - auc: 0.8259 - f1_score: 0.7402
# Epoch 20: val_loss did not improve from 0.41124
# 71/71 [==============================] - 51s 712ms/step - loss: 0.5299 - accuracy: 0.7402 - precision: 0.7402 - recall: 0.7402 - auc: 0.8259 - f1_score: 0.7402 - val_loss: 0.5458 - val_accuracy: 0.7101 - val_precision: 0.7101 - val_recall: 0.7101 - val_auc: 0.7976 - val_f1_score: 0.7101 - lr: 0.0010
# Epoch 21/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5003 - accuracy: 0.7715 - precision: 0.7715 - recall: 0.7715 - auc: 0.8481 - f1_score: 0.7715
# Epoch 21: val_loss did not improve from 0.41124
# 71/71 [==============================] - 51s 710ms/step - loss: 0.5003 - accuracy: 0.7715 - precision: 0.7715 - recall: 0.7715 - auc: 0.8481 - f1_score: 0.7715 - val_loss: 0.4441 - val_accuracy: 0.7840 - val_precision: 0.7840 - val_recall: 0.7840 - val_auc: 0.9040 - val_f1_score: 0.7840 - lr: 0.0010
# Epoch 22/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5009 - accuracy: 0.7587 - precision: 0.7587 - recall: 0.7587 - auc: 0.8469 - f1_score: 0.7587
# Epoch 22: val_loss did not improve from 0.41124
# 71/71 [==============================] - 51s 717ms/step - loss: 0.5009 - accuracy: 0.7587 - precision: 0.7587 - recall: 0.7587 - auc: 0.8469 - f1_score: 0.7587 - val_loss: 0.4886 - val_accuracy: 0.7663 - val_precision: 0.7663 - val_recall: 0.7663 - val_auc: 0.8636 - val_f1_score: 0.7663 - lr: 0.0010
# Epoch 23/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4873 - accuracy: 0.7684 - precision: 0.7684 - recall: 0.7684 - auc: 0.8557 - f1_score: 0.7684
# Epoch 23: val_loss did not improve from 0.41124
# 71/71 [==============================] - 51s 710ms/step - loss: 0.4873 - accuracy: 0.7684 - precision: 0.7684 - recall: 0.7684 - auc: 0.8557 - f1_score: 0.7684 - val_loss: 0.4164 - val_accuracy: 0.8225 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.9155 - val_f1_score: 0.8225 - lr: 0.0010
# Epoch 24/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4776 - accuracy: 0.7888 - precision: 0.7888 - recall: 0.7888 - auc: 0.8632 - f1_score: 0.7888
# Epoch 24: val_loss did not improve from 0.41124
# 71/71 [==============================] - 51s 717ms/step - loss: 0.4776 - accuracy: 0.7888 - precision: 0.7888 - recall: 0.7888 - auc: 0.8632 - f1_score: 0.7888 - val_loss: 0.4191 - val_accuracy: 0.8343 - val_precision: 0.8343 - val_recall: 0.8343 - val_auc: 0.9014 - val_f1_score: 0.8343 - lr: 0.0010
# Epoch 25/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4673 - accuracy: 0.7852 - precision: 0.7852 - recall: 0.7852 - auc: 0.8686 - f1_score: 0.7852
# Epoch 25: val_loss improved from 0.41124 to 0.40836, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 729ms/step - loss: 0.4673 - accuracy: 0.7852 - precision: 0.7852 - recall: 0.7852 - auc: 0.8686 - f1_score: 0.7852 - val_loss: 0.4084 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9335 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 26/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4600 - accuracy: 0.7932 - precision: 0.7932 - recall: 0.7932 - auc: 0.8738 - f1_score: 0.7932
# Epoch 26: val_loss did not improve from 0.40836
# 71/71 [==============================] - 52s 720ms/step - loss: 0.4600 - accuracy: 0.7932 - precision: 0.7932 - recall: 0.7932 - auc: 0.8738 - f1_score: 0.7932 - val_loss: 0.4131 - val_accuracy: 0.8254 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.9312 - val_f1_score: 0.8254 - lr: 0.0010
# Epoch 27/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4567 - accuracy: 0.7923 - precision: 0.7923 - recall: 0.7923 - auc: 0.8765 - f1_score: 0.7923
# Epoch 27: val_loss did not improve from 0.40836
# 71/71 [==============================] - 52s 722ms/step - loss: 0.4567 - accuracy: 0.7923 - precision: 0.7923 - recall: 0.7923 - auc: 0.8765 - f1_score: 0.7923 - val_loss: 0.4135 - val_accuracy: 0.8254 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.9128 - val_f1_score: 0.8254 - lr: 0.0010
# Epoch 28/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4618 - accuracy: 0.7958 - precision: 0.7958 - recall: 0.7958 - auc: 0.8733 - f1_score: 0.7958
# Epoch 28: val_loss improved from 0.40836 to 0.39696, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 732ms/step - loss: 0.4618 - accuracy: 0.7958 - precision: 0.7958 - recall: 0.7958 - auc: 0.8733 - f1_score: 0.7958 - val_loss: 0.3970 - val_accuracy: 0.8373 - val_precision: 0.8373 - val_recall: 0.8373 - val_auc: 0.9128 - val_f1_score: 0.8373 - lr: 0.0010
# Epoch 29/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4557 - accuracy: 0.7950 - precision: 0.7950 - recall: 0.7950 - auc: 0.8771 - f1_score: 0.7950
# Epoch 29: val_loss improved from 0.39696 to 0.37351, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 720ms/step - loss: 0.4557 - accuracy: 0.7950 - precision: 0.7950 - recall: 0.7950 - auc: 0.8771 - f1_score: 0.7950 - val_loss: 0.3735 - val_accuracy: 0.8491 - val_precision: 0.8491 - val_recall: 0.8491 - val_auc: 0.9334 - val_f1_score: 0.8491 - lr: 0.0010
# Epoch 30/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4435 - accuracy: 0.8016 - precision: 0.8016 - recall: 0.8016 - auc: 0.8839 - f1_score: 0.8016
# Epoch 30: val_loss did not improve from 0.37351
# 71/71 [==============================] - 52s 724ms/step - loss: 0.4435 - accuracy: 0.8016 - precision: 0.8016 - recall: 0.8016 - auc: 0.8839 - f1_score: 0.8016 - val_loss: 0.3859 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9227 - val_f1_score: 0.8402 - lr: 0.0010
# Epoch 31/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4231 - accuracy: 0.8162 - precision: 0.8162 - recall: 0.8162 - auc: 0.8940 - f1_score: 0.8162
# Epoch 31: val_loss improved from 0.37351 to 0.34570, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 719ms/step - loss: 0.4231 - accuracy: 0.8162 - precision: 0.8162 - recall: 0.8162 - auc: 0.8940 - f1_score: 0.8162 - val_loss: 0.3457 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9356 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 32/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4528 - accuracy: 0.8051 - precision: 0.8051 - recall: 0.8051 - auc: 0.8776 - f1_score: 0.8051
# Epoch 32: val_loss did not improve from 0.34570
# 71/71 [==============================] - 51s 715ms/step - loss: 0.4528 - accuracy: 0.8051 - precision: 0.8051 - recall: 0.8051 - auc: 0.8776 - f1_score: 0.8051 - val_loss: 0.4239 - val_accuracy: 0.8195 - val_precision: 0.8195 - val_recall: 0.8195 - val_auc: 0.9047 - val_f1_score: 0.8195 - lr: 0.0010
# Epoch 33/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4379 - accuracy: 0.8073 - precision: 0.8073 - recall: 0.8073 - auc: 0.8871 - f1_score: 0.8073
# Epoch 33: val_loss did not improve from 0.34570
# 71/71 [==============================] - 50s 694ms/step - loss: 0.4379 - accuracy: 0.8073 - precision: 0.8073 - recall: 0.8073 - auc: 0.8871 - f1_score: 0.8073 - val_loss: 0.3552 - val_accuracy: 0.8432 - val_precision: 0.8432 - val_recall: 0.8432 - val_auc: 0.9386 - val_f1_score: 0.8432 - lr: 0.0010
# Epoch 34/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4113 - accuracy: 0.8299 - precision: 0.8299 - recall: 0.8299 - auc: 0.9002 - f1_score: 0.8299
# Epoch 34: val_loss improved from 0.34570 to 0.34462, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 727ms/step - loss: 0.4113 - accuracy: 0.8299 - precision: 0.8299 - recall: 0.8299 - auc: 0.9002 - f1_score: 0.8299 - val_loss: 0.3446 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9426 - val_f1_score: 0.8580 - lr: 0.0010
# Epoch 35/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4405 - accuracy: 0.8078 - precision: 0.8078 - recall: 0.8078 - auc: 0.8853 - f1_score: 0.8078
# Epoch 35: val_loss did not improve from 0.34462
# 71/71 [==============================] - 51s 721ms/step - loss: 0.4405 - accuracy: 0.8078 - precision: 0.8078 - recall: 0.8078 - auc: 0.8853 - f1_score: 0.8078 - val_loss: 0.4272 - val_accuracy: 0.7899 - val_precision: 0.7899 - val_recall: 0.7899 - val_auc: 0.9068 - val_f1_score: 0.7899 - lr: 0.0010
# Epoch 36/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4213 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.8961 - f1_score: 0.8197
# Epoch 36: val_loss did not improve from 0.34462
# 71/71 [==============================] - 52s 719ms/step - loss: 0.4213 - accuracy: 0.8197 - precision: 0.8197 - recall: 0.8197 - auc: 0.8961 - f1_score: 0.8197 - val_loss: 0.3772 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9182 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 37/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4298 - accuracy: 0.8100 - precision: 0.8100 - recall: 0.8100 - auc: 0.8901 - f1_score: 0.8100
# Epoch 37: val_loss did not improve from 0.34462
# 71/71 [==============================] - 52s 731ms/step - loss: 0.4298 - accuracy: 0.8100 - precision: 0.8100 - recall: 0.8100 - auc: 0.8901 - f1_score: 0.8100 - val_loss: 0.4073 - val_accuracy: 0.8077 - val_precision: 0.8077 - val_recall: 0.8077 - val_auc: 0.9085 - val_f1_score: 0.8077 - lr: 0.0010
# Epoch 38/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4035 - accuracy: 0.8281 - precision: 0.8281 - recall: 0.8281 - auc: 0.9038 - f1_score: 0.8281
# Epoch 38: val_loss did not improve from 0.34462
# 71/71 [==============================] - 53s 739ms/step - loss: 0.4035 - accuracy: 0.8281 - precision: 0.8281 - recall: 0.8281 - auc: 0.9038 - f1_score: 0.8281 - val_loss: 0.4995 - val_accuracy: 0.7604 - val_precision: 0.7604 - val_recall: 0.7604 - val_auc: 0.8471 - val_f1_score: 0.7604 - lr: 0.0010
# Epoch 39/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4005 - accuracy: 0.8308 - precision: 0.8308 - recall: 0.8308 - auc: 0.9059 - f1_score: 0.8308
# Epoch 39: val_loss improved from 0.34462 to 0.28463, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 731ms/step - loss: 0.4005 - accuracy: 0.8308 - precision: 0.8308 - recall: 0.8308 - auc: 0.9059 - f1_score: 0.8308 - val_loss: 0.2846 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9648 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 40/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4095 - accuracy: 0.8268 - precision: 0.8268 - recall: 0.8268 - auc: 0.9012 - f1_score: 0.8268
# Epoch 40: val_loss did not improve from 0.28463
# 71/71 [==============================] - 51s 718ms/step - loss: 0.4095 - accuracy: 0.8268 - precision: 0.8268 - recall: 0.8268 - auc: 0.9012 - f1_score: 0.8268 - val_loss: 0.4756 - val_accuracy: 0.7633 - val_precision: 0.7633 - val_recall: 0.7633 - val_auc: 0.8635 - val_f1_score: 0.7633 - lr: 0.0010
# Epoch 41/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4100 - accuracy: 0.8210 - precision: 0.8210 - recall: 0.8210 - auc: 0.9004 - f1_score: 0.8210
# Epoch 41: val_loss did not improve from 0.28463
# 71/71 [==============================] - 51s 714ms/step - loss: 0.4100 - accuracy: 0.8210 - precision: 0.8210 - recall: 0.8210 - auc: 0.9004 - f1_score: 0.8210 - val_loss: 0.3980 - val_accuracy: 0.8254 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.9151 - val_f1_score: 0.8254 - lr: 0.0010
# Epoch 42/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4073 - accuracy: 0.8338 - precision: 0.8338 - recall: 0.8338 - auc: 0.9022 - f1_score: 0.8338
# Epoch 42: val_loss did not improve from 0.28463
# 71/71 [==============================] - 51s 713ms/step - loss: 0.4073 - accuracy: 0.8338 - precision: 0.8338 - recall: 0.8338 - auc: 0.9022 - f1_score: 0.8338 - val_loss: 0.3386 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9480 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 43/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3791 - accuracy: 0.8475 - precision: 0.8475 - recall: 0.8475 - auc: 0.9154 - f1_score: 0.8475
# Epoch 43: val_loss did not improve from 0.28463
# 71/71 [==============================] - 52s 723ms/step - loss: 0.3791 - accuracy: 0.8475 - precision: 0.8475 - recall: 0.8475 - auc: 0.9154 - f1_score: 0.8475 - val_loss: 0.4467 - val_accuracy: 0.8018 - val_precision: 0.8018 - val_recall: 0.8018 - val_auc: 0.8819 - val_f1_score: 0.8018 - lr: 0.0010
# Epoch 44/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3793 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9157 - f1_score: 0.8462
# Epoch 44: val_loss did not improve from 0.28463
# 71/71 [==============================] - 51s 716ms/step - loss: 0.3793 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9157 - f1_score: 0.8462 - val_loss: 0.2917 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9645 - val_f1_score: 0.8935 - lr: 0.0010
# Epoch 45/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4196 - accuracy: 0.8246 - precision: 0.8246 - recall: 0.8246 - auc: 0.8965 - f1_score: 0.8246
# Epoch 45: val_loss improved from 0.28463 to 0.26158, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 731ms/step - loss: 0.4196 - accuracy: 0.8246 - precision: 0.8246 - recall: 0.8246 - auc: 0.8965 - f1_score: 0.8246 - val_loss: 0.2616 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9754 - val_f1_score: 0.9172 - lr: 0.0010
# Epoch 46/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8506 - precision: 0.8506 - recall: 0.8506 - auc: 0.9181 - f1_score: 0.8506
# Epoch 46: val_loss did not improve from 0.26158
# 71/71 [==============================] - 51s 717ms/step - loss: 0.3759 - accuracy: 0.8506 - precision: 0.8506 - recall: 0.8506 - auc: 0.9181 - f1_score: 0.8506 - val_loss: 0.3106 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9527 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 47/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3663 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - auc: 0.9223 - f1_score: 0.8511
# Epoch 47: val_loss did not improve from 0.26158
# 71/71 [==============================] - 52s 729ms/step - loss: 0.3663 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - auc: 0.9223 - f1_score: 0.8511 - val_loss: 0.3336 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9422 - val_f1_score: 0.8580 - lr: 0.0010
# Epoch 48/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3686 - accuracy: 0.8484 - precision: 0.8484 - recall: 0.8484 - auc: 0.9231 - f1_score: 0.8484
# Epoch 48: val_loss did not improve from 0.26158
# 71/71 [==============================] - 51s 724ms/step - loss: 0.3686 - accuracy: 0.8484 - precision: 0.8484 - recall: 0.8484 - auc: 0.9231 - f1_score: 0.8484 - val_loss: 0.3209 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9537 - val_f1_score: 0.8935 - lr: 0.0010
# Epoch 49/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3375 - accuracy: 0.8635 - precision: 0.8635 - recall: 0.8635 - auc: 0.9347 - f1_score: 0.8635
# Epoch 49: val_loss improved from 0.26158 to 0.25481, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 735ms/step - loss: 0.3375 - accuracy: 0.8635 - precision: 0.8635 - recall: 0.8635 - auc: 0.9347 - f1_score: 0.8635 - val_loss: 0.2548 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9714 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 50/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3968 - accuracy: 0.8431 - precision: 0.8431 - recall: 0.8431 - auc: 0.9097 - f1_score: 0.8431
# Epoch 50: val_loss did not improve from 0.25481
# 71/71 [==============================] - 53s 736ms/step - loss: 0.3968 - accuracy: 0.8431 - precision: 0.8431 - recall: 0.8431 - auc: 0.9097 - f1_score: 0.8431 - val_loss: 0.3659 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9396 - val_f1_score: 0.8580 - lr: 0.0010
# Epoch 51/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.8475 - precision: 0.8475 - recall: 0.8475 - auc: 0.9198 - f1_score: 0.8475
# Epoch 51: val_loss did not improve from 0.25481
# 71/71 [==============================] - 53s 741ms/step - loss: 0.3711 - accuracy: 0.8475 - precision: 0.8475 - recall: 0.8475 - auc: 0.9198 - f1_score: 0.8475 - val_loss: 0.3062 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9500 - val_f1_score: 0.8787 - lr: 0.0010
# Epoch 52/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4151 - accuracy: 0.8281 - precision: 0.8281 - recall: 0.8281 - auc: 0.8997 - f1_score: 0.8281
# Epoch 52: val_loss did not improve from 0.25481
# 71/71 [==============================] - 52s 728ms/step - loss: 0.4151 - accuracy: 0.8281 - precision: 0.8281 - recall: 0.8281 - auc: 0.8997 - f1_score: 0.8281 - val_loss: 0.4466 - val_accuracy: 0.8018 - val_precision: 0.8018 - val_recall: 0.8018 - val_auc: 0.8882 - val_f1_score: 0.8018 - lr: 0.0010
# Epoch 53/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3530 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9270 - f1_score: 0.8546
# Epoch 53: val_loss did not improve from 0.25481
# 71/71 [==============================] - 51s 715ms/step - loss: 0.3530 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9270 - f1_score: 0.8546 - val_loss: 0.3364 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9450 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 54/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3518 - accuracy: 0.8529 - precision: 0.8529 - recall: 0.8529 - auc: 0.9281 - f1_score: 0.8529
# Epoch 54: val_loss improved from 0.25481 to 0.21911, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 53s 737ms/step - loss: 0.3518 - accuracy: 0.8529 - precision: 0.8529 - recall: 0.8529 - auc: 0.9281 - f1_score: 0.8529 - val_loss: 0.2191 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9807 - val_f1_score: 0.9349 - lr: 0.0010
# Epoch 55/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3193 - accuracy: 0.8719 - precision: 0.8719 - recall: 0.8719 - auc: 0.9418 - f1_score: 0.8719
# Epoch 55: val_loss did not improve from 0.21911
# 71/71 [==============================] - 52s 726ms/step - loss: 0.3193 - accuracy: 0.8719 - precision: 0.8719 - recall: 0.8719 - auc: 0.9418 - f1_score: 0.8719 - val_loss: 0.2797 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9577 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 56/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.8338 - precision: 0.8338 - recall: 0.8338 - auc: 0.8989 - f1_score: 0.8338
# Epoch 56: val_loss did not improve from 0.21911
# 71/71 [==============================] - 50s 703ms/step - loss: 0.4146 - accuracy: 0.8338 - precision: 0.8338 - recall: 0.8338 - auc: 0.8989 - f1_score: 0.8338 - val_loss: 0.3189 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9499 - val_f1_score: 0.8639 - lr: 0.0010
# Epoch 57/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3529 - accuracy: 0.8573 - precision: 0.8573 - recall: 0.8573 - auc: 0.9278 - f1_score: 0.8573
# Epoch 57: val_loss improved from 0.21911 to 0.21906, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 53s 734ms/step - loss: 0.3529 - accuracy: 0.8573 - precision: 0.8573 - recall: 0.8573 - auc: 0.9278 - f1_score: 0.8573 - val_loss: 0.2191 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9834 - val_f1_score: 0.9379 - lr: 0.0010
# Epoch 58/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3578 - accuracy: 0.8639 - precision: 0.8639 - recall: 0.8639 - auc: 0.9258 - f1_score: 0.8639
# Epoch 58: val_loss did not improve from 0.21906
# 71/71 [==============================] - 52s 727ms/step - loss: 0.3578 - accuracy: 0.8639 - precision: 0.8639 - recall: 0.8639 - auc: 0.9258 - f1_score: 0.8639 - val_loss: 0.2929 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9647 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 59/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3358 - accuracy: 0.8696 - precision: 0.8696 - recall: 0.8696 - auc: 0.9340 - f1_score: 0.8696
# Epoch 59: val_loss did not improve from 0.21906
# 71/71 [==============================] - 52s 726ms/step - loss: 0.3358 - accuracy: 0.8696 - precision: 0.8696 - recall: 0.8696 - auc: 0.9340 - f1_score: 0.8696 - val_loss: 0.3066 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9537 - val_f1_score: 0.8935 - lr: 0.0010
# Epoch 60/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3443 - accuracy: 0.8582 - precision: 0.8582 - recall: 0.8582 - auc: 0.9321 - f1_score: 0.8582
# Epoch 60: val_loss did not improve from 0.21906
# 71/71 [==============================] - 52s 724ms/step - loss: 0.3443 - accuracy: 0.8582 - precision: 0.8582 - recall: 0.8582 - auc: 0.9321 - f1_score: 0.8582 - val_loss: 0.3309 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9402 - val_f1_score: 0.8787 - lr: 0.0010
# Epoch 61/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3782 - accuracy: 0.8440 - precision: 0.8440 - recall: 0.8440 - auc: 0.9173 - f1_score: 0.8440
# Epoch 61: val_loss did not improve from 0.21906
# 71/71 [==============================] - 52s 724ms/step - loss: 0.3782 - accuracy: 0.8440 - precision: 0.8440 - recall: 0.8440 - auc: 0.9173 - f1_score: 0.8440 - val_loss: 0.3001 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9534 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 62/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3746 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9188 - f1_score: 0.8546
# Epoch 62: val_loss did not improve from 0.21906
# 71/71 [==============================] - 52s 733ms/step - loss: 0.3746 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9188 - f1_score: 0.8546 - val_loss: 0.3728 - val_accuracy: 0.8432 - val_precision: 0.8432 - val_recall: 0.8432 - val_auc: 0.9211 - val_f1_score: 0.8432 - lr: 0.0010
# Epoch 63/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3411 - accuracy: 0.8626 - precision: 0.8626 - recall: 0.8626 - auc: 0.9329 - f1_score: 0.8626
# Epoch 63: val_loss did not improve from 0.21906
# 71/71 [==============================] - 52s 724ms/step - loss: 0.3411 - accuracy: 0.8626 - precision: 0.8626 - recall: 0.8626 - auc: 0.9329 - f1_score: 0.8626 - val_loss: 0.2217 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9796 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 64/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3204 - accuracy: 0.8754 - precision: 0.8754 - recall: 0.8754 - auc: 0.9408 - f1_score: 0.8754
# Epoch 64: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 64: val_loss did not improve from 0.21906
# 71/71 [==============================] - 53s 744ms/step - loss: 0.3204 - accuracy: 0.8754 - precision: 0.8754 - recall: 0.8754 - auc: 0.9408 - f1_score: 0.8754 - val_loss: 0.2751 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9634 - val_f1_score: 0.8994 - lr: 0.0010
# Epoch 65/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2662 - accuracy: 0.9006 - precision: 0.9006 - recall: 0.9006 - auc: 0.9618 - f1_score: 0.9006
# Epoch 65: val_loss improved from 0.21906 to 0.20934, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 726ms/step - loss: 0.2662 - accuracy: 0.9006 - precision: 0.9006 - recall: 0.9006 - auc: 0.9618 - f1_score: 0.9006 - val_loss: 0.2093 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9824 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 66/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2551 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9646 - f1_score: 0.9050
# Epoch 66: val_loss improved from 0.20934 to 0.19472, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 53s 734ms/step - loss: 0.2551 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9646 - f1_score: 0.9050 - val_loss: 0.1947 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9860 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 67/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.8997 - precision: 0.8997 - recall: 0.8997 - auc: 0.9655 - f1_score: 0.8997
# Epoch 67: val_loss did not improve from 0.19472
# 71/71 [==============================] - 51s 710ms/step - loss: 0.2524 - accuracy: 0.8997 - precision: 0.8997 - recall: 0.8997 - auc: 0.9655 - f1_score: 0.8997 - val_loss: 0.2173 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9795 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 68/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2487 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9661 - f1_score: 0.9063
# Epoch 68: val_loss did not improve from 0.19472
# 71/71 [==============================] - 51s 711ms/step - loss: 0.2487 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9661 - f1_score: 0.9063 - val_loss: 0.2588 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9667 - val_f1_score: 0.9142 - lr: 1.0000e-04
# Epoch 69/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2501 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9652 - f1_score: 0.9037
# Epoch 69: val_loss improved from 0.19472 to 0.19425, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 731ms/step - loss: 0.2501 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9652 - f1_score: 0.9037 - val_loss: 0.1943 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9867 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 70/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2383 - accuracy: 0.9107 - precision: 0.9107 - recall: 0.9107 - auc: 0.9696 - f1_score: 0.9107
# Epoch 70: val_loss improved from 0.19425 to 0.18509, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 51s 716ms/step - loss: 0.2383 - accuracy: 0.9107 - precision: 0.9107 - recall: 0.9107 - auc: 0.9696 - f1_score: 0.9107 - val_loss: 0.1851 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9832 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 71/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2363 - accuracy: 0.9138 - precision: 0.9138 - recall: 0.9138 - auc: 0.9691 - f1_score: 0.9138
# Epoch 71: val_loss improved from 0.18509 to 0.16946, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 53s 742ms/step - loss: 0.2363 - accuracy: 0.9138 - precision: 0.9138 - recall: 0.9138 - auc: 0.9691 - f1_score: 0.9138 - val_loss: 0.1695 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9884 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 72/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2408 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9677 - f1_score: 0.9112
# Epoch 72: val_loss did not improve from 0.16946
# 71/71 [==============================] - 52s 724ms/step - loss: 0.2408 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9677 - f1_score: 0.9112 - val_loss: 0.1986 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9848 - val_f1_score: 0.9349 - lr: 1.0000e-04
# Epoch 73/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2452 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9670 - f1_score: 0.9081
# Epoch 73: val_loss improved from 0.16946 to 0.16799, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 727ms/step - loss: 0.2452 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9670 - f1_score: 0.9081 - val_loss: 0.1680 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9897 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 74/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2409 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9677 - f1_score: 0.9094
# Epoch 74: val_loss did not improve from 0.16799
# 71/71 [==============================] - 50s 703ms/step - loss: 0.2409 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9677 - f1_score: 0.9094 - val_loss: 0.1893 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9838 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 75/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9683 - f1_score: 0.9037
# Epoch 75: val_loss improved from 0.16799 to 0.16372, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 725ms/step - loss: 0.2392 - accuracy: 0.9037 - precision: 0.9037 - recall: 0.9037 - auc: 0.9683 - f1_score: 0.9037 - val_loss: 0.1637 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9898 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 76/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2312 - accuracy: 0.9183 - precision: 0.9183 - recall: 0.9183 - auc: 0.9707 - f1_score: 0.9183
# Epoch 76: val_loss did not improve from 0.16372
# 71/71 [==============================] - 51s 709ms/step - loss: 0.2312 - accuracy: 0.9183 - precision: 0.9183 - recall: 0.9183 - auc: 0.9707 - f1_score: 0.9183 - val_loss: 0.1676 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9862 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 77/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2405 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9675 - f1_score: 0.9152
# Epoch 77: val_loss did not improve from 0.16372
# 71/71 [==============================] - 51s 710ms/step - loss: 0.2405 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9675 - f1_score: 0.9152 - val_loss: 0.2002 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9803 - val_f1_score: 0.9290 - lr: 1.0000e-04
# Epoch 78/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2183 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9741 - f1_score: 0.9165
# Epoch 78: val_loss did not improve from 0.16372
# 71/71 [==============================] - 51s 718ms/step - loss: 0.2183 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9741 - f1_score: 0.9165 - val_loss: 0.1789 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9849 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 79/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9686 - f1_score: 0.9081
# Epoch 79: val_loss did not improve from 0.16372
# 71/71 [==============================] - 52s 727ms/step - loss: 0.2385 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9686 - f1_score: 0.9081 - val_loss: 0.1948 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9812 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 80/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2331 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9698 - f1_score: 0.9152
# Epoch 80: val_loss did not improve from 0.16372
# 71/71 [==============================] - 51s 712ms/step - loss: 0.2331 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9698 - f1_score: 0.9152 - val_loss: 0.1936 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9819 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 81/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2204 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9734 - f1_score: 0.9174
# Epoch 81: val_loss did not improve from 0.16372
# 71/71 [==============================] - 52s 723ms/step - loss: 0.2204 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9734 - f1_score: 0.9174 - val_loss: 0.1870 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9854 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 82/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2292 - accuracy: 0.9116 - precision: 0.9116 - recall: 0.9116 - auc: 0.9714 - f1_score: 0.9116
# Epoch 82: val_loss did not improve from 0.16372
# 71/71 [==============================] - 52s 720ms/step - loss: 0.2292 - accuracy: 0.9116 - precision: 0.9116 - recall: 0.9116 - auc: 0.9714 - f1_score: 0.9116 - val_loss: 0.1772 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9843 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 83/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2315 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9703 - f1_score: 0.9090
# Epoch 83: val_loss did not improve from 0.16372
# 71/71 [==============================] - 52s 728ms/step - loss: 0.2315 - accuracy: 0.9090 - precision: 0.9090 - recall: 0.9090 - auc: 0.9703 - f1_score: 0.9090 - val_loss: 0.2047 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9807 - val_f1_score: 0.9290 - lr: 1.0000e-04
# Epoch 84/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2271 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9717 - f1_score: 0.9103
# Epoch 84: val_loss did not improve from 0.16372
# 71/71 [==============================] - 52s 725ms/step - loss: 0.2271 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9717 - f1_score: 0.9103 - val_loss: 0.2199 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9785 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 85/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2250 - accuracy: 0.9099 - precision: 0.9099 - recall: 0.9099 - auc: 0.9726 - f1_score: 0.9099
# Epoch 85: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 85: val_loss did not improve from 0.16372
# 71/71 [==============================] - 52s 722ms/step - loss: 0.2250 - accuracy: 0.9099 - precision: 0.9099 - recall: 0.9099 - auc: 0.9726 - f1_score: 0.9099 - val_loss: 0.2018 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9814 - val_f1_score: 0.9349 - lr: 1.0000e-04
# Epoch 86/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2105 - accuracy: 0.9196 - precision: 0.9196 - recall: 0.9196 - auc: 0.9764 - f1_score: 0.9196
# Epoch 86: val_loss did not improve from 0.16372
# 71/71 [==============================] - 51s 710ms/step - loss: 0.2105 - accuracy: 0.9196 - precision: 0.9196 - recall: 0.9196 - auc: 0.9764 - f1_score: 0.9196 - val_loss: 0.1771 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9846 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 87/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2027 - accuracy: 0.9244 - precision: 0.9244 - recall: 0.9244 - auc: 0.9783 - f1_score: 0.9244
# Epoch 87: val_loss did not improve from 0.16372
# 71/71 [==============================] - 52s 721ms/step - loss: 0.2027 - accuracy: 0.9244 - precision: 0.9244 - recall: 0.9244 - auc: 0.9783 - f1_score: 0.9244 - val_loss: 0.1911 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9824 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 88/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9766 - f1_score: 0.9231
# ...
# Epoch 121/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9801 - f1_score: 0.9262
# Epoch 121: val_loss did not improve from 0.13881
# 71/71 [==============================] - 51s 709ms/step - loss: 0.1921 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9801 - f1_score: 0.9262 - val_loss: 0.1514 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9889 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 122/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9788 - f1_score: 0.9258
# Epoch 122: val_loss did not improve from 0.13881
# 71/71 [==============================] - 52s 724ms/step - loss: 0.1974 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9788 - f1_score: 0.9258 - val_loss: 0.1602 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9879 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 123/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1953 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - auc: 0.9793 - f1_score: 0.9284
# Epoch 123: val_loss did not improve from 0.13881
# 71/71 [==============================] - 51s 717ms/step - loss: 0.1953 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - auc: 0.9793 - f1_score: 0.9284 - val_loss: 0.1518 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9894 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 124/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9777 - f1_score: 0.9280
# Epoch 124: val_loss did not improve from 0.13881
# 71/71 [==============================] - 52s 731ms/step - loss: 0.2005 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9777 - f1_score: 0.9280 - val_loss: 0.1586 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9875 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 125/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1863 - accuracy: 0.9373 - precision: 0.9373 - recall: 0.9373 - auc: 0.9809 - f1_score: 0.9373
# Epoch 125: val_loss improved from 0.13881 to 0.13449, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version10-DIR.h5
# 71/71 [==============================] - 52s 732ms/step - loss: 0.1863 - accuracy: 0.9373 - precision: 0.9373 - recall: 0.9373 - auc: 0.9809 - f1_score: 0.9373 - val_loss: 0.1345 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9936 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 126/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9266 - precision: 0.9266 - recall: 0.9266 - auc: 0.9805 - f1_score: 0.9266
# Epoch 126: val_loss did not improve from 0.13449
# 71/71 [==============================] - 50s 696ms/step - loss: 0.1915 - accuracy: 0.9266 - precision: 0.9266 - recall: 0.9266 - auc: 0.9805 - f1_score: 0.9266 - val_loss: 0.1560 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9892 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 127/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2038 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9769 - f1_score: 0.9231
# Epoch 127: val_loss did not improve from 0.13449
# 71/71 [==============================] - 51s 718ms/step - loss: 0.2038 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9769 - f1_score: 0.9231 - val_loss: 0.1682 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9861 - val_f1_score: 0.9379 - lr: 1.0000e-05
# Epoch 128/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1909 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9804 - f1_score: 0.9271
# Epoch 128: val_loss did not improve from 0.13449
# 71/71 [==============================] - 51s 718ms/step - loss: 0.1909 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9804 - f1_score: 0.9271 - val_loss: 0.1520 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9897 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 129/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1920 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9805 - f1_score: 0.9280
# Epoch 129: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 721ms/step - loss: 0.1920 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9805 - f1_score: 0.9280 - val_loss: 0.1703 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9836 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 130/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1931 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9796 - f1_score: 0.9280
# Epoch 130: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 721ms/step - loss: 0.1931 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9796 - f1_score: 0.9280 - val_loss: 0.1798 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9830 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 131/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9786 - f1_score: 0.9258
# Epoch 131: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 720ms/step - loss: 0.1974 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9786 - f1_score: 0.9258 - val_loss: 0.1723 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9857 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 132/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1937 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9795 - f1_score: 0.9311
# Epoch 132: val_loss did not improve from 0.13449
# 71/71 [==============================] - 50s 704ms/step - loss: 0.1937 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9795 - f1_score: 0.9311 - val_loss: 0.1583 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9849 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 133/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1944 - accuracy: 0.9306 - precision: 0.9306 - recall: 0.9306 - auc: 0.9791 - f1_score: 0.9306
# Epoch 133: val_loss did not improve from 0.13449
# 71/71 [==============================] - 51s 713ms/step - loss: 0.1944 - accuracy: 0.9306 - precision: 0.9306 - recall: 0.9306 - auc: 0.9791 - f1_score: 0.9306 - val_loss: 0.1442 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9901 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 134/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9832 - f1_score: 0.9359
# Epoch 134: val_loss did not improve from 0.13449
# 71/71 [==============================] - 53s 741ms/step - loss: 0.1789 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9832 - f1_score: 0.9359 - val_loss: 0.1636 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9866 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 135/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1918 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9800 - f1_score: 0.9271
# Epoch 135: val_loss did not improve from 0.13449
# 71/71 [==============================] - 51s 712ms/step - loss: 0.1918 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9800 - f1_score: 0.9271 - val_loss: 0.1807 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9820 - val_f1_score: 0.9290 - lr: 1.0000e-05
# Epoch 136/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1892 - accuracy: 0.9306 - precision: 0.9306 - recall: 0.9306 - auc: 0.9806 - f1_score: 0.9306
# Epoch 136: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 729ms/step - loss: 0.1892 - accuracy: 0.9306 - precision: 0.9306 - recall: 0.9306 - auc: 0.9806 - f1_score: 0.9306 - val_loss: 0.1671 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9869 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 137/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9799 - f1_score: 0.9289
# Epoch 137: val_loss did not improve from 0.13449
# 71/71 [==============================] - 51s 709ms/step - loss: 0.1921 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9799 - f1_score: 0.9289 - val_loss: 0.1816 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9827 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 138/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9240 - precision: 0.9240 - recall: 0.9240 - auc: 0.9803 - f1_score: 0.9240
# Epoch 138: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 724ms/step - loss: 0.1921 - accuracy: 0.9240 - precision: 0.9240 - recall: 0.9240 - auc: 0.9803 - f1_score: 0.9240 - val_loss: 0.1814 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9820 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 139/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 0.9240 - precision: 0.9240 - recall: 0.9240 - auc: 0.9814 - f1_score: 0.9240
# Epoch 139: val_loss did not improve from 0.13449
# 71/71 [==============================] - 51s 714ms/step - loss: 0.1871 - accuracy: 0.9240 - precision: 0.9240 - recall: 0.9240 - auc: 0.9814 - f1_score: 0.9240 - val_loss: 0.1443 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9896 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 140/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9795 - f1_score: 0.9280
# Epoch 140: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 720ms/step - loss: 0.1943 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9795 - f1_score: 0.9280 - val_loss: 0.1806 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9825 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 141/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1844 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9812 - f1_score: 0.9355
# Epoch 141: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 725ms/step - loss: 0.1844 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9812 - f1_score: 0.9355 - val_loss: 0.1669 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9872 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 142/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1915 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - auc: 0.9800 - f1_score: 0.9284
# Epoch 142: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 721ms/step - loss: 0.1915 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - auc: 0.9800 - f1_score: 0.9284 - val_loss: 0.1427 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9909 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 143/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9803 - f1_score: 0.9289
# Epoch 143: val_loss did not improve from 0.13449
# 71/71 [==============================] - 51s 718ms/step - loss: 0.1907 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9803 - f1_score: 0.9289 - val_loss: 0.1560 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9881 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 144/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9785 - f1_score: 0.9271
# Epoch 144: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 726ms/step - loss: 0.1972 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9785 - f1_score: 0.9271 - val_loss: 0.1402 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9925 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 145/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1867 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9816 - f1_score: 0.9271
# Epoch 145: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 726ms/step - loss: 0.1867 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9816 - f1_score: 0.9271 - val_loss: 0.1538 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9875 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 146/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1919 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9796 - f1_score: 0.9297
# Epoch 146: val_loss did not improve from 0.13449
# 71/71 [==============================] - 51s 716ms/step - loss: 0.1919 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9796 - f1_score: 0.9297 - val_loss: 0.1422 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9906 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 147/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1948 - accuracy: 0.9275 - precision: 0.9275 - recall: 0.9275 - auc: 0.9792 - f1_score: 0.9275
# Epoch 147: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 727ms/step - loss: 0.1948 - accuracy: 0.9275 - precision: 0.9275 - recall: 0.9275 - auc: 0.9792 - f1_score: 0.9275 - val_loss: 0.1566 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9874 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 148/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9218 - precision: 0.9218 - recall: 0.9218 - auc: 0.9799 - f1_score: 0.9218
# Epoch 148: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 724ms/step - loss: 0.1945 - accuracy: 0.9218 - precision: 0.9218 - recall: 0.9218 - auc: 0.9799 - f1_score: 0.9218 - val_loss: 0.1545 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9881 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 149/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1867 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9810 - f1_score: 0.9311
# Epoch 149: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 724ms/step - loss: 0.1867 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9810 - f1_score: 0.9311 - val_loss: 0.1563 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9864 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 150/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2001 - accuracy: 0.9244 - precision: 0.9244 - recall: 0.9244 - auc: 0.9783 - f1_score: 0.9244
# Epoch 150: val_loss did not improve from 0.13449
# 71/71 [==============================] - 52s 729ms/step - loss: 0.2001 - accuracy: 0.9244 - precision: 0.9244 - recall: 0.9244 - auc: 0.9783 - f1_score: 0.9244 - val_loss: 0.1655 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9872 - val_f1_score: 0.9467 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

# plt.subplot(2, 3, 5)
# plt.plot(range(1, len(f1_score_callback.train_f1_scores) + 1), f1_score_callback.train_f1_scores, label='Training F1 Score')
# plt.plot(range(1, len(f1_score_callback.val_f1_scores) + 1), f1_score_callback.val_f1_scores, label='Validation F1 Score')
# plt.title('Model F1-Score')
# plt.xlabel('Epoch')
# plt.ylabel('F1-Score')
# plt.legend(['F1 Score'], loc='lower right')


plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = DIR.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 2s 116ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9136078538314698
# F1-Score for each class: [0.88421053 0.94300518]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9285714285714286
# specificity: 0.9130434782608696

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  DIR.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 1s 117ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = DIR.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)

# test_loss, test_acc, test_precision, test_recall, test_auc = DIR.evaluate(test_generator)
# print('Test loss:', test_loss)
# print('Test accuracy:', test_acc)
# print('Test precision:', test_precision)
# print('Test recall:', test_recall)
# print('Test AUC:', test_auc)


# from sklearn.metrics import f1_score
# import numpy as np

# # 预测测试集
# y_pred = DIR.predict(test_generator)
# y_pred = np.argmax(y_pred, axis=1)

# # 真实标签
# y_true = test_generator.classes

# # 计算F1分数
# test_f1_score = f1_score(y_true, y_pred, average='micro')  # 或者根据你的需要选择其他average参数
# print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 2s 158ms/step - loss: 0.2035 - accuracy: 0.9276 - precision: 0.9276 - recall: 0.9276 - auc: 0.9776 - f1_score: 0.9276
# Test loss: 0.2035083770751953
# Test accuracy: 0.9276315569877625
# Test precision: 0.9276315569877625
# Test recall: 0.9276315569877625
# Test AUC: 0.9776391386985779
# Test F1 Score: 0.9276314973831177

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = DIR.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 1s 119ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.91      0.88        92
#            1       0.96      0.93      0.94       196
#
#     accuracy                           0.92       288
#    macro avg       0.91      0.92      0.91       288
# weighted avg       0.93      0.92      0.92       288

# %% [markdown]
# #delete the model to prevent memory costs
#
# from keras import backend as K
# import gc
#
# K.clear_session()
# gc.collect()
#
# # del DIR
#
#
# from numba import cuda
#
# cuda.select_device(0)
# cuda.close()
