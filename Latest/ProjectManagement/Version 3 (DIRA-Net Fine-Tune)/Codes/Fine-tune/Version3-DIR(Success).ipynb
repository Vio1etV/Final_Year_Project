# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.
# Out:
# 2024-03-06 01:13:48.466348: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 298 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 2

def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = attention_block_2(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = attention_block_2(x)
    
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    x = attention_block_2(x)
    

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)
    
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    # a = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    c = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = attention_block_2(x)

    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    # c = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 5
num_B_blocks = 8
num_C_blocks = 5

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.5)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax')(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# 2024-03-06 01:13:51.950934: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-06 01:13:52.476380: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22309 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:04:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 4)  112         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 222, 222, 96  3552        ['conv2d[0][0]']
#                                 )
#
#  activation (Activation)        (None, 222, 222, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 222, 222, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 222, 222, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 222, 222, 4)  0           ['conv2d[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 220, 220, 4)  148         ['multiply[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 220, 220, 96  3552        ['conv2d_3[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 220, 220, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 220, 220, 1)  97          ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 220, 220, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 220, 220, 4)  0           ['conv2d_3[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 220, 220, 8)  296         ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 220, 220, 96  7008        ['conv2d_6[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 220, 220, 96  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 220, 220, 1)  97          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 220, 220, 1)  0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 220, 220, 8)  0           ['conv2d_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['multiply_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 218, 218, 12  876         ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_13[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_16[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_6 (Activation)      (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 4)  196         ['activation_6[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 4)  196         ['activation_6[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 4)  196         ['activation_6[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 4)  40         ['conv2d_18[0][0]']
#  v2D)
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_17[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['activation_6[0][0]',
#                                 )                                 'conv2d_21[0][0]']
#
#  activation_7 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 214, 214, 4)  196         ['activation_7[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 4)  196         ['activation_7[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 4)  196         ['activation_7[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_23[0][0]']
#  onv2D)
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_24[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_22[0][0]',
#                                 )                                 'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 214, 214, 48  0           ['activation_7[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  activation_8 (Activation)      (None, 214, 214, 48  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 214, 214, 4)  196         ['activation_8[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 214, 214, 4)  196         ['activation_8[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 214, 214, 4)  196         ['activation_8[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_28[0][0]']
#  onv2D)
#
#  conv2d_30 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_29[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_27[0][0]',
#                                 )                                 'depthwise_conv2d_2[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_5[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 214, 214, 48  0           ['activation_8[0][0]',
#                                 )                                 'conv2d_31[0][0]']
#
#  activation_9 (Activation)      (None, 214, 214, 48  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 214, 214, 4)  196         ['activation_9[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 214, 214, 4)  196         ['activation_9[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 214, 214, 4)  196         ['activation_9[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_33[0][0]']
#  onv2D)
#
#  conv2d_35 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_34[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_32[0][0]',
#                                 )                                 'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_6[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 214, 214, 48  0           ['activation_9[0][0]',
#                                 )                                 'conv2d_36[0][0]']
#
#  activation_10 (Activation)     (None, 214, 214, 48  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 214, 214, 4)  196         ['activation_10[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 214, 214, 4)  196         ['activation_10[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 214, 214, 4)  196         ['activation_10[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_38[0][0]']
#  onv2D)
#
#  conv2d_40 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_39[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_37[0][0]',
#                                 )                                 'depthwise_conv2d_4[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_7[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 214, 214, 48  0           ['activation_10[0][0]',
#                                 )                                 'conv2d_41[0][0]']
#
#  activation_11 (Activation)     (None, 214, 214, 48  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 214, 214, 32  1568        ['activation_11[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_43[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_11[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 106, 106, 48  20784       ['activation_11[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_44[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_42[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_49[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_46[0][0]',
#                                 )                                 'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_9[0][0]']
#                                 4)
#
#  add_5 (Add)                    (None, 106, 106, 14  0           ['concatenate_8[0][0]',
#                                 4)                                'conv2d_51[0][0]']
#
#  activation_12 (Activation)     (None, 106, 106, 14  0           ['add_5[0][0]']
#                                 4)
#
#  conv2d_53 (Conv2D)             (None, 106, 106, 16  2320        ['activation_12[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 106, 106, 24  3480        ['activation_12[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_55[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_52[0][0]',
#                                 )                                 'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_10[0][0]']
#                                 4)
#
#  add_6 (Add)                    (None, 106, 106, 14  0           ['activation_12[0][0]',
#                                 4)                                'conv2d_57[0][0]']
#
#  activation_13 (Activation)     (None, 106, 106, 14  0           ['add_6[0][0]']
#                                 4)
#
#  conv2d_59 (Conv2D)             (None, 106, 106, 16  2320        ['activation_13[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_59[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_60[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 106, 106, 24  3480        ['activation_13[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_61[0][0]']
#                                 )
#
#  concatenate_11 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_58[0][0]',
#                                 )                                 'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_11[0][0]']
#                                 4)
#
#  add_7 (Add)                    (None, 106, 106, 14  0           ['activation_13[0][0]',
#                                 4)                                'conv2d_63[0][0]']
#
#  activation_14 (Activation)     (None, 106, 106, 14  0           ['add_7[0][0]']
#                                 4)
#
#  conv2d_65 (Conv2D)             (None, 106, 106, 16  2320        ['activation_14[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_65[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_66[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 106, 106, 24  3480        ['activation_14[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_67[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_64[0][0]',
#                                 )                                 'conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_12[0][0]']
#                                 4)
#
#  add_8 (Add)                    (None, 106, 106, 14  0           ['activation_14[0][0]',
#                                 4)                                'conv2d_69[0][0]']
#
#  activation_15 (Activation)     (None, 106, 106, 14  0           ['add_8[0][0]']
#                                 4)
#
#  conv2d_71 (Conv2D)             (None, 106, 106, 16  2320        ['activation_15[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_71[0][0]']
#                                 )
#
#  conv2d_73 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_72[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 106, 106, 24  3480        ['activation_15[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_73[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_70[0][0]',
#                                 )                                 'conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_13[0][0]']
#                                 4)
#
#  add_9 (Add)                    (None, 106, 106, 14  0           ['activation_15[0][0]',
#                                 4)                                'conv2d_75[0][0]']
#
#  activation_16 (Activation)     (None, 106, 106, 14  0           ['add_9[0][0]']
#                                 4)
#
#  conv2d_77 (Conv2D)             (None, 106, 106, 16  2320        ['activation_16[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_77[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_78[0][0]']
#                                 )
#
#  conv2d_76 (Conv2D)             (None, 106, 106, 24  3480        ['activation_16[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_79[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_76[0][0]',
#                                 )                                 'conv2d_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_14[0][0]']
#                                 4)
#
#  add_10 (Add)                   (None, 106, 106, 14  0           ['activation_16[0][0]',
#                                 4)                                'conv2d_81[0][0]']
#
#  activation_17 (Activation)     (None, 106, 106, 14  0           ['add_10[0][0]']
#                                 4)
#
#  conv2d_83 (Conv2D)             (None, 106, 106, 16  2320        ['activation_17[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_83[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_84[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 106, 106, 24  3480        ['activation_17[0][0]']
#                                 )
#
#  conv2d_86 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_85[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_82[0][0]',
#                                 )                                 'conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_15[0][0]']
#                                 4)
#
#  add_11 (Add)                   (None, 106, 106, 14  0           ['activation_17[0][0]',
#                                 4)                                'conv2d_87[0][0]']
#
#  activation_18 (Activation)     (None, 106, 106, 14  0           ['add_11[0][0]']
#                                 4)
#
#  conv2d_89 (Conv2D)             (None, 106, 106, 16  2320        ['activation_18[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_89[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_90[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 106, 106, 24  3480        ['activation_18[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_91[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_88[0][0]',
#                                 )                                 'conv2d_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_16[0][0]']
#                                 4)
#
#  add_12 (Add)                   (None, 106, 106, 14  0           ['activation_18[0][0]',
#                                 4)                                'conv2d_93[0][0]']
#
#  activation_19 (Activation)     (None, 106, 106, 14  0           ['add_12[0][0]']
#                                 4)
#
#  conv2d_98 (Conv2D)             (None, 106, 106, 32  4640        ['activation_19[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 106, 106, 32  4640        ['activation_19[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 106, 106, 32  4640        ['activation_19[0][0]']
#                                 )
#
#  conv2d_99 (Conv2D)             (None, 106, 106, 36  10404       ['conv2d_98[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_19[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 52, 52, 36)   10404       ['conv2d_94[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 52, 52, 36)   10404       ['conv2d_96[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 52, 52, 40)   13000       ['conv2d_99[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_95[0][0]',
#                                                                   'conv2d_97[0][0]',
#                                                                   'conv2d_100[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_17[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_102[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_17[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_103[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_101[0][0]',
#                                                                   'conv2d_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_18[0][0]']
#
#  add_13 (Add)                   (None, 52, 52, 256)  0           ['concatenate_17[0][0]',
#                                                                   'conv2d_105[0][0]']
#
#  activation_20 (Activation)     (None, 52, 52, 256)  0           ['add_13[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_20[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_107[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_20[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_108[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_106[0][0]',
#                                                                   'conv2d_109[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_19[0][0]']
#
#  add_14 (Add)                   (None, 52, 52, 256)  0           ['activation_20[0][0]',
#                                                                   'conv2d_110[0][0]']
#
#  activation_21 (Activation)     (None, 52, 52, 256)  0           ['add_14[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_21[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_112[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_21[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_113[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_111[0][0]',
#                                                                   'conv2d_114[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_20[0][0]']
#
#  add_15 (Add)                   (None, 52, 52, 256)  0           ['activation_21[0][0]',
#                                                                   'conv2d_115[0][0]']
#
#  activation_22 (Activation)     (None, 52, 52, 256)  0           ['add_15[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_117[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_118[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_116[0][0]',
#                                                                   'conv2d_119[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_21[0][0]']
#
#  add_16 (Add)                   (None, 52, 52, 256)  0           ['activation_22[0][0]',
#                                                                   'conv2d_120[0][0]']
#
#  activation_23 (Activation)     (None, 52, 52, 256)  0           ['add_16[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_122[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_123[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_121[0][0]',
#                                                                   'conv2d_124[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_22[0][0]']
#
#  add_17 (Add)                   (None, 52, 52, 256)  0           ['activation_23[0][0]',
#                                                                   'conv2d_125[0][0]']
#
#  activation_24 (Activation)     (None, 52, 52, 256)  0           ['add_17[0][0]']
#
#  dropout (Dropout)              (None, 52, 52, 256)  0           ['activation_24[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 448,121
# Trainable params: 448,121
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version3-DIR"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)



lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = DIR.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)
# Out:
# Epoch 1/150
# 2024-03-06 01:14:01.591423: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-06 01:14:03.749219: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 0.9418 - accuracy: 0.5475 - precision: 0.5475 - recall: 0.5475 - auc: 0.5685 - f1_score: 0.5475
# Epoch 1: val_loss improved from inf to 0.49074, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 59s 684ms/step - loss: 0.9418 - accuracy: 0.5475 - precision: 0.5475 - recall: 0.5475 - auc: 0.5685 - f1_score: 0.5475 - val_loss: 0.4907 - val_accuracy: 0.7929 - val_precision: 0.7929 - val_recall: 0.7929 - val_auc: 0.9035 - val_f1_score: 0.7929 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5989 - accuracy: 0.7022 - precision: 0.7022 - recall: 0.7022 - auc: 0.7482 - f1_score: 0.7022
# Epoch 2: val_loss improved from 0.49074 to 0.44432, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 624ms/step - loss: 0.5989 - accuracy: 0.7022 - precision: 0.7022 - recall: 0.7022 - auc: 0.7482 - f1_score: 0.7022 - val_loss: 0.4443 - val_accuracy: 0.8254 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.9095 - val_f1_score: 0.8254 - lr: 0.0010
# Epoch 3/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5351 - accuracy: 0.7499 - precision: 0.7499 - recall: 0.7499 - auc: 0.8091 - f1_score: 0.7499
# Epoch 3: val_loss improved from 0.44432 to 0.41542, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 626ms/step - loss: 0.5351 - accuracy: 0.7499 - precision: 0.7499 - recall: 0.7499 - auc: 0.8091 - f1_score: 0.7499 - val_loss: 0.4154 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9081 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 4/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5102 - accuracy: 0.7764 - precision: 0.7764 - recall: 0.7764 - auc: 0.8269 - f1_score: 0.7764
# Epoch 4: val_loss did not improve from 0.41542
# 71/71 [==============================] - 44s 620ms/step - loss: 0.5102 - accuracy: 0.7764 - precision: 0.7764 - recall: 0.7764 - auc: 0.8269 - f1_score: 0.7764 - val_loss: 0.4505 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9057 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 5/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5026 - accuracy: 0.7826 - precision: 0.7826 - recall: 0.7826 - auc: 0.8348 - f1_score: 0.7826
# Epoch 5: val_loss improved from 0.41542 to 0.38967, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 627ms/step - loss: 0.5026 - accuracy: 0.7826 - precision: 0.7826 - recall: 0.7826 - auc: 0.8348 - f1_score: 0.7826 - val_loss: 0.3897 - val_accuracy: 0.8254 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.9229 - val_f1_score: 0.8254 - lr: 0.0010
# Epoch 6/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4771 - accuracy: 0.7919 - precision: 0.7919 - recall: 0.7919 - auc: 0.8490 - f1_score: 0.7919
# Epoch 6: val_loss did not improve from 0.38967
# 71/71 [==============================] - 44s 621ms/step - loss: 0.4771 - accuracy: 0.7919 - precision: 0.7919 - recall: 0.7919 - auc: 0.8490 - f1_score: 0.7919 - val_loss: 0.3984 - val_accuracy: 0.8402 - val_precision: 0.8402 - val_recall: 0.8402 - val_auc: 0.9371 - val_f1_score: 0.8402 - lr: 0.0010
# Epoch 7/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4733 - accuracy: 0.7901 - precision: 0.7901 - recall: 0.7901 - auc: 0.8570 - f1_score: 0.7901
# Epoch 7: val_loss improved from 0.38967 to 0.28234, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 628ms/step - loss: 0.4733 - accuracy: 0.7901 - precision: 0.7901 - recall: 0.7901 - auc: 0.8570 - f1_score: 0.7901 - val_loss: 0.2823 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9611 - val_f1_score: 0.9172 - lr: 0.0010
# Epoch 8/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4760 - accuracy: 0.7923 - precision: 0.7923 - recall: 0.7923 - auc: 0.8554 - f1_score: 0.7923
# Epoch 8: val_loss did not improve from 0.28234
# 71/71 [==============================] - 44s 622ms/step - loss: 0.4760 - accuracy: 0.7923 - precision: 0.7923 - recall: 0.7923 - auc: 0.8554 - f1_score: 0.7923 - val_loss: 0.3205 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9685 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 9/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4631 - accuracy: 0.8051 - precision: 0.8051 - recall: 0.8051 - auc: 0.8586 - f1_score: 0.8051
# Epoch 9: val_loss did not improve from 0.28234
# 71/71 [==============================] - 44s 621ms/step - loss: 0.4631 - accuracy: 0.8051 - precision: 0.8051 - recall: 0.8051 - auc: 0.8586 - f1_score: 0.8051 - val_loss: 0.3864 - val_accuracy: 0.8314 - val_precision: 0.8314 - val_recall: 0.8314 - val_auc: 0.9321 - val_f1_score: 0.8314 - lr: 0.0010
# Epoch 10/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5275 - accuracy: 0.7552 - precision: 0.7552 - recall: 0.7552 - auc: 0.8126 - f1_score: 0.7552
# Epoch 10: val_loss did not improve from 0.28234
# 71/71 [==============================] - 44s 622ms/step - loss: 0.5275 - accuracy: 0.7552 - precision: 0.7552 - recall: 0.7552 - auc: 0.8126 - f1_score: 0.7552 - val_loss: 0.4324 - val_accuracy: 0.8225 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.9314 - val_f1_score: 0.8225 - lr: 0.0010
# Epoch 11/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4683 - accuracy: 0.7928 - precision: 0.7928 - recall: 0.7928 - auc: 0.8592 - f1_score: 0.7928
# Epoch 11: val_loss improved from 0.28234 to 0.26629, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 628ms/step - loss: 0.4683 - accuracy: 0.7928 - precision: 0.7928 - recall: 0.7928 - auc: 0.8592 - f1_score: 0.7928 - val_loss: 0.2663 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9665 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 12/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4584 - accuracy: 0.8007 - precision: 0.8007 - recall: 0.8007 - auc: 0.8673 - f1_score: 0.8007
# Epoch 12: val_loss did not improve from 0.26629
# 71/71 [==============================] - 44s 622ms/step - loss: 0.4584 - accuracy: 0.8007 - precision: 0.8007 - recall: 0.8007 - auc: 0.8673 - f1_score: 0.8007 - val_loss: 0.3775 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9502 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 13/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5070 - accuracy: 0.7707 - precision: 0.7707 - recall: 0.7707 - auc: 0.8328 - f1_score: 0.7707
# Epoch 13: val_loss did not improve from 0.26629
# 71/71 [==============================] - 44s 622ms/step - loss: 0.5070 - accuracy: 0.7707 - precision: 0.7707 - recall: 0.7707 - auc: 0.8328 - f1_score: 0.7707 - val_loss: 0.4551 - val_accuracy: 0.7781 - val_precision: 0.7781 - val_recall: 0.7781 - val_auc: 0.8963 - val_f1_score: 0.7781 - lr: 0.0010
# Epoch 14/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4583 - accuracy: 0.8042 - precision: 0.8042 - recall: 0.8042 - auc: 0.8662 - f1_score: 0.8042
# Epoch 14: val_loss did not improve from 0.26629
# 71/71 [==============================] - 44s 621ms/step - loss: 0.4583 - accuracy: 0.8042 - precision: 0.8042 - recall: 0.8042 - auc: 0.8662 - f1_score: 0.8042 - val_loss: 0.2971 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9692 - val_f1_score: 0.9142 - lr: 0.0010
# Epoch 15/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4538 - accuracy: 0.7967 - precision: 0.7967 - recall: 0.7967 - auc: 0.8702 - f1_score: 0.7967
# Epoch 15: val_loss did not improve from 0.26629
# 71/71 [==============================] - 44s 621ms/step - loss: 0.4538 - accuracy: 0.7967 - precision: 0.7967 - recall: 0.7967 - auc: 0.8702 - f1_score: 0.7967 - val_loss: 0.3087 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9575 - val_f1_score: 0.8935 - lr: 0.0010
# Epoch 16/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4252 - accuracy: 0.8171 - precision: 0.8171 - recall: 0.8171 - auc: 0.8862 - f1_score: 0.8171
# Epoch 16: val_loss did not improve from 0.26629
# 71/71 [==============================] - 44s 620ms/step - loss: 0.4252 - accuracy: 0.8171 - precision: 0.8171 - recall: 0.8171 - auc: 0.8862 - f1_score: 0.8171 - val_loss: 0.2747 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9750 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 17/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4351 - accuracy: 0.8109 - precision: 0.8109 - recall: 0.8109 - auc: 0.8825 - f1_score: 0.8109
# Epoch 17: val_loss improved from 0.26629 to 0.26375, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 625ms/step - loss: 0.4351 - accuracy: 0.8109 - precision: 0.8109 - recall: 0.8109 - auc: 0.8825 - f1_score: 0.8109 - val_loss: 0.2638 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9723 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 18/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4260 - accuracy: 0.8131 - precision: 0.8131 - recall: 0.8131 - auc: 0.8875 - f1_score: 0.8131
# Epoch 18: val_loss did not improve from 0.26375
# 71/71 [==============================] - 44s 620ms/step - loss: 0.4260 - accuracy: 0.8131 - precision: 0.8131 - recall: 0.8131 - auc: 0.8875 - f1_score: 0.8131 - val_loss: 0.2837 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9682 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 19/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4243 - accuracy: 0.8100 - precision: 0.8100 - recall: 0.8100 - auc: 0.8874 - f1_score: 0.8100
# Epoch 19: val_loss did not improve from 0.26375
# 71/71 [==============================] - 44s 620ms/step - loss: 0.4243 - accuracy: 0.8100 - precision: 0.8100 - recall: 0.8100 - auc: 0.8874 - f1_score: 0.8100 - val_loss: 0.2779 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9662 - val_f1_score: 0.9142 - lr: 0.0010
# Epoch 20/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4218 - accuracy: 0.8215 - precision: 0.8215 - recall: 0.8215 - auc: 0.8883 - f1_score: 0.8215
# Epoch 20: val_loss improved from 0.26375 to 0.25823, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 626ms/step - loss: 0.4218 - accuracy: 0.8215 - precision: 0.8215 - recall: 0.8215 - auc: 0.8883 - f1_score: 0.8215 - val_loss: 0.2582 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9858 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 21/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4263 - accuracy: 0.8175 - precision: 0.8175 - recall: 0.8175 - auc: 0.8854 - f1_score: 0.8175
# Epoch 21: val_loss did not improve from 0.25823
# 71/71 [==============================] - 44s 620ms/step - loss: 0.4263 - accuracy: 0.8175 - precision: 0.8175 - recall: 0.8175 - auc: 0.8854 - f1_score: 0.8175 - val_loss: 0.3845 - val_accuracy: 0.8195 - val_precision: 0.8195 - val_recall: 0.8195 - val_auc: 0.9186 - val_f1_score: 0.8195 - lr: 0.0010
# Epoch 22/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4255 - accuracy: 0.8157 - precision: 0.8157 - recall: 0.8157 - auc: 0.8867 - f1_score: 0.8157
# Epoch 22: val_loss did not improve from 0.25823
# 71/71 [==============================] - 44s 620ms/step - loss: 0.4255 - accuracy: 0.8157 - precision: 0.8157 - recall: 0.8157 - auc: 0.8867 - f1_score: 0.8157 - val_loss: 0.2977 - val_accuracy: 0.8817 - val_precision: 0.8817 - val_recall: 0.8817 - val_auc: 0.9541 - val_f1_score: 0.8817 - lr: 0.0010
# Epoch 23/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4489 - accuracy: 0.7914 - precision: 0.7914 - recall: 0.7914 - auc: 0.8730 - f1_score: 0.7914
# Epoch 23: val_loss did not improve from 0.25823
# 71/71 [==============================] - 44s 620ms/step - loss: 0.4489 - accuracy: 0.7914 - precision: 0.7914 - recall: 0.7914 - auc: 0.8730 - f1_score: 0.7914 - val_loss: 0.3000 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9573 - val_f1_score: 0.9172 - lr: 0.0010
# Epoch 24/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4256 - accuracy: 0.8118 - precision: 0.8118 - recall: 0.8118 - auc: 0.8864 - f1_score: 0.8118
# Epoch 24: val_loss did not improve from 0.25823
# 71/71 [==============================] - 44s 620ms/step - loss: 0.4256 - accuracy: 0.8118 - precision: 0.8118 - recall: 0.8118 - auc: 0.8864 - f1_score: 0.8118 - val_loss: 0.3245 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9453 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 25/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4122 - accuracy: 0.8241 - precision: 0.8241 - recall: 0.8241 - auc: 0.8946 - f1_score: 0.8241
# Epoch 25: val_loss did not improve from 0.25823
# 71/71 [==============================] - 44s 620ms/step - loss: 0.4122 - accuracy: 0.8241 - precision: 0.8241 - recall: 0.8241 - auc: 0.8946 - f1_score: 0.8241 - val_loss: 0.2789 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9605 - val_f1_score: 0.8994 - lr: 0.0010
# Epoch 26/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4315 - accuracy: 0.8087 - precision: 0.8087 - recall: 0.8087 - auc: 0.8842 - f1_score: 0.8087
# Epoch 26: val_loss did not improve from 0.25823
# 71/71 [==============================] - 44s 620ms/step - loss: 0.4315 - accuracy: 0.8087 - precision: 0.8087 - recall: 0.8087 - auc: 0.8842 - f1_score: 0.8087 - val_loss: 0.3076 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9687 - val_f1_score: 0.9172 - lr: 0.0010
# Epoch 27/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3786 - accuracy: 0.8378 - precision: 0.8378 - recall: 0.8378 - auc: 0.9134 - f1_score: 0.8378
# Epoch 27: val_loss did not improve from 0.25823
# 71/71 [==============================] - 44s 620ms/step - loss: 0.3786 - accuracy: 0.8378 - precision: 0.8378 - recall: 0.8378 - auc: 0.9134 - f1_score: 0.8378 - val_loss: 0.3389 - val_accuracy: 0.8669 - val_precision: 0.8669 - val_recall: 0.8669 - val_auc: 0.9278 - val_f1_score: 0.8669 - lr: 0.0010
# Epoch 28/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4085 - accuracy: 0.8272 - precision: 0.8272 - recall: 0.8272 - auc: 0.8946 - f1_score: 0.8272
# Epoch 28: val_loss did not improve from 0.25823
# 71/71 [==============================] - 44s 621ms/step - loss: 0.4085 - accuracy: 0.8272 - precision: 0.8272 - recall: 0.8272 - auc: 0.8946 - f1_score: 0.8272 - val_loss: 0.3350 - val_accuracy: 0.8462 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9288 - val_f1_score: 0.8462 - lr: 0.0010
# Epoch 29/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4218 - accuracy: 0.8237 - precision: 0.8237 - recall: 0.8237 - auc: 0.8891 - f1_score: 0.8237
# Epoch 29: val_loss did not improve from 0.25823
# 71/71 [==============================] - 44s 622ms/step - loss: 0.4218 - accuracy: 0.8237 - precision: 0.8237 - recall: 0.8237 - auc: 0.8891 - f1_score: 0.8237 - val_loss: 0.3538 - val_accuracy: 0.8521 - val_precision: 0.8521 - val_recall: 0.8521 - val_auc: 0.9317 - val_f1_score: 0.8521 - lr: 0.0010
# Epoch 30/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3722 - accuracy: 0.8458 - precision: 0.8458 - recall: 0.8458 - auc: 0.9147 - f1_score: 0.8458
# Epoch 30: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 30: val_loss did not improve from 0.25823
# 71/71 [==============================] - 44s 621ms/step - loss: 0.3722 - accuracy: 0.8458 - precision: 0.8458 - recall: 0.8458 - auc: 0.9147 - f1_score: 0.8458 - val_loss: 0.4867 - val_accuracy: 0.7840 - val_precision: 0.7840 - val_recall: 0.7840 - val_auc: 0.8511 - val_f1_score: 0.7840 - lr: 0.0010
# Epoch 31/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3412 - accuracy: 0.8635 - precision: 0.8635 - recall: 0.8635 - auc: 0.9282 - f1_score: 0.8635
# Epoch 31: val_loss did not improve from 0.25823
# 71/71 [==============================] - 44s 622ms/step - loss: 0.3412 - accuracy: 0.8635 - precision: 0.8635 - recall: 0.8635 - auc: 0.9282 - f1_score: 0.8635 - val_loss: 0.2765 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9597 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 32/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3034 - accuracy: 0.8811 - precision: 0.8811 - recall: 0.8811 - auc: 0.9430 - f1_score: 0.8811
# Epoch 32: val_loss improved from 0.25823 to 0.24136, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 627ms/step - loss: 0.3034 - accuracy: 0.8811 - precision: 0.8811 - recall: 0.8811 - auc: 0.9430 - f1_score: 0.8811 - val_loss: 0.2414 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9727 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 33/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2974 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9447 - f1_score: 0.8820
# Epoch 33: val_loss did not improve from 0.24136
# 71/71 [==============================] - 44s 622ms/step - loss: 0.2974 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9447 - f1_score: 0.8820 - val_loss: 0.2792 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9589 - val_f1_score: 0.8964 - lr: 1.0000e-04
# Epoch 34/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2922 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9464 - f1_score: 0.8851
# Epoch 34: val_loss did not improve from 0.24136
# 71/71 [==============================] - 44s 622ms/step - loss: 0.2922 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9464 - f1_score: 0.8851 - val_loss: 0.2423 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9690 - val_f1_score: 0.9112 - lr: 1.0000e-04
# Epoch 35/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9479 - f1_score: 0.8820
# Epoch 35: val_loss did not improve from 0.24136
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2896 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9479 - f1_score: 0.8820 - val_loss: 0.2421 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9672 - val_f1_score: 0.9112 - lr: 1.0000e-04
# Epoch 36/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2859 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9485 - f1_score: 0.8904
# Epoch 36: val_loss improved from 0.24136 to 0.22893, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 627ms/step - loss: 0.2859 - accuracy: 0.8904 - precision: 0.8904 - recall: 0.8904 - auc: 0.9485 - f1_score: 0.8904 - val_loss: 0.2289 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9744 - val_f1_score: 0.9142 - lr: 1.0000e-04
# Epoch 37/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2883 - accuracy: 0.8882 - precision: 0.8882 - recall: 0.8882 - auc: 0.9482 - f1_score: 0.8882
# Epoch 37: val_loss did not improve from 0.22893
# 71/71 [==============================] - 44s 622ms/step - loss: 0.2883 - accuracy: 0.8882 - precision: 0.8882 - recall: 0.8882 - auc: 0.9482 - f1_score: 0.8882 - val_loss: 0.2838 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9485 - val_f1_score: 0.8994 - lr: 1.0000e-04
# Epoch 38/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2863 - accuracy: 0.8944 - precision: 0.8944 - recall: 0.8944 - auc: 0.9490 - f1_score: 0.8944
# Epoch 38: val_loss did not improve from 0.22893
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2863 - accuracy: 0.8944 - precision: 0.8944 - recall: 0.8944 - auc: 0.9490 - f1_score: 0.8944 - val_loss: 0.2507 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9642 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 39/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2829 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9503 - f1_score: 0.8851
# Epoch 39: val_loss did not improve from 0.22893
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2829 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9503 - f1_score: 0.8851 - val_loss: 0.2430 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9673 - val_f1_score: 0.9083 - lr: 1.0000e-04
# Epoch 40/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2679 - accuracy: 0.8909 - precision: 0.8909 - recall: 0.8909 - auc: 0.9563 - f1_score: 0.8909
# Epoch 40: val_loss improved from 0.22893 to 0.21867, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 625ms/step - loss: 0.2679 - accuracy: 0.8909 - precision: 0.8909 - recall: 0.8909 - auc: 0.9563 - f1_score: 0.8909 - val_loss: 0.2187 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9759 - val_f1_score: 0.9142 - lr: 1.0000e-04
# Epoch 41/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2731 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9538 - f1_score: 0.8926
# Epoch 41: val_loss improved from 0.21867 to 0.19856, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 626ms/step - loss: 0.2731 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9538 - f1_score: 0.8926 - val_loss: 0.1986 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9813 - val_f1_score: 0.9231 - lr: 1.0000e-04
# Epoch 42/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2705 - accuracy: 0.8948 - precision: 0.8948 - recall: 0.8948 - auc: 0.9542 - f1_score: 0.8948
# Epoch 42: val_loss improved from 0.19856 to 0.19820, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 625ms/step - loss: 0.2705 - accuracy: 0.8948 - precision: 0.8948 - recall: 0.8948 - auc: 0.9542 - f1_score: 0.8948 - val_loss: 0.1982 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9777 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 43/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2684 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9551 - f1_score: 0.8979
# Epoch 43: val_loss did not improve from 0.19820
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2684 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9551 - f1_score: 0.8979 - val_loss: 0.2127 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9771 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 44/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2645 - accuracy: 0.8970 - precision: 0.8970 - recall: 0.8970 - auc: 0.9564 - f1_score: 0.8970
# Epoch 44: val_loss did not improve from 0.19820
# 71/71 [==============================] - 44s 619ms/step - loss: 0.2645 - accuracy: 0.8970 - precision: 0.8970 - recall: 0.8970 - auc: 0.9564 - f1_score: 0.8970 - val_loss: 0.2039 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9799 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 45/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9597 - f1_score: 0.9023
# Epoch 45: val_loss did not improve from 0.19820
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2543 - accuracy: 0.9023 - precision: 0.9023 - recall: 0.9023 - auc: 0.9597 - f1_score: 0.9023 - val_loss: 0.2046 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9769 - val_f1_score: 0.9290 - lr: 1.0000e-04
# Epoch 46/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2646 - accuracy: 0.8948 - precision: 0.8948 - recall: 0.8948 - auc: 0.9573 - f1_score: 0.8948
# Epoch 46: val_loss did not improve from 0.19820
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2646 - accuracy: 0.8948 - precision: 0.8948 - recall: 0.8948 - auc: 0.9573 - f1_score: 0.8948 - val_loss: 0.2495 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9669 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 47/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2612 - accuracy: 0.8970 - precision: 0.8970 - recall: 0.8970 - auc: 0.9579 - f1_score: 0.8970
# Epoch 47: val_loss did not improve from 0.19820
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2612 - accuracy: 0.8970 - precision: 0.8970 - recall: 0.8970 - auc: 0.9579 - f1_score: 0.8970 - val_loss: 0.2000 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9829 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 48/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2540 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9596 - f1_score: 0.9054
# Epoch 48: val_loss improved from 0.19820 to 0.19467, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 626ms/step - loss: 0.2540 - accuracy: 0.9054 - precision: 0.9054 - recall: 0.9054 - auc: 0.9596 - f1_score: 0.9054 - val_loss: 0.1947 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9806 - val_f1_score: 0.9349 - lr: 1.0000e-04
# Epoch 49/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2515 - accuracy: 0.8984 - precision: 0.8984 - recall: 0.8984 - auc: 0.9606 - f1_score: 0.8984
# Epoch 49: val_loss improved from 0.19467 to 0.17610, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 625ms/step - loss: 0.2515 - accuracy: 0.8984 - precision: 0.8984 - recall: 0.8984 - auc: 0.9606 - f1_score: 0.8984 - val_loss: 0.1761 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9845 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 50/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2634 - accuracy: 0.8997 - precision: 0.8997 - recall: 0.8997 - auc: 0.9568 - f1_score: 0.8997
# Epoch 50: val_loss did not improve from 0.17610
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2634 - accuracy: 0.8997 - precision: 0.8997 - recall: 0.8997 - auc: 0.9568 - f1_score: 0.8997 - val_loss: 0.2130 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9785 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 51/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2524 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9606 - f1_score: 0.9050
# Epoch 51: val_loss did not improve from 0.17610
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2524 - accuracy: 0.9050 - precision: 0.9050 - recall: 0.9050 - auc: 0.9606 - f1_score: 0.9050 - val_loss: 0.2107 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9767 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 52/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9597 - f1_score: 0.9019
# Epoch 52: val_loss did not improve from 0.17610
# 71/71 [==============================] - 44s 622ms/step - loss: 0.2544 - accuracy: 0.9019 - precision: 0.9019 - recall: 0.9019 - auc: 0.9597 - f1_score: 0.9019 - val_loss: 0.1907 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9843 - val_f1_score: 0.9231 - lr: 1.0000e-04
# Epoch 53/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2404 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9648 - f1_score: 0.9010
# Epoch 53: val_loss did not improve from 0.17610
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2404 - accuracy: 0.9010 - precision: 0.9010 - recall: 0.9010 - auc: 0.9648 - f1_score: 0.9010 - val_loss: 0.1851 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9811 - val_f1_score: 0.9290 - lr: 1.0000e-04
# Epoch 54/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9643 - f1_score: 0.9112
# Epoch 54: val_loss improved from 0.17610 to 0.15920, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 627ms/step - loss: 0.2395 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9643 - f1_score: 0.9112 - val_loss: 0.1592 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9909 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 55/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9059 - precision: 0.9059 - recall: 0.9059 - auc: 0.9635 - f1_score: 0.9059
# Epoch 55: val_loss did not improve from 0.15920
# 71/71 [==============================] - 44s 622ms/step - loss: 0.2429 - accuracy: 0.9059 - precision: 0.9059 - recall: 0.9059 - auc: 0.9635 - f1_score: 0.9059 - val_loss: 0.2283 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9686 - val_f1_score: 0.9142 - lr: 1.0000e-04
# Epoch 56/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.9006 - precision: 0.9006 - recall: 0.9006 - auc: 0.9644 - f1_score: 0.9006
# Epoch 56: val_loss did not improve from 0.15920
# 71/71 [==============================] - 44s 622ms/step - loss: 0.2424 - accuracy: 0.9006 - precision: 0.9006 - recall: 0.9006 - auc: 0.9644 - f1_score: 0.9006 - val_loss: 0.1966 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9802 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 57/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2395 - accuracy: 0.9116 - precision: 0.9116 - recall: 0.9116 - auc: 0.9642 - f1_score: 0.9116
# Epoch 57: val_loss improved from 0.15920 to 0.13707, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 628ms/step - loss: 0.2395 - accuracy: 0.9116 - precision: 0.9116 - recall: 0.9116 - auc: 0.9642 - f1_score: 0.9116 - val_loss: 0.1371 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9927 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 58/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2523 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9614 - f1_score: 0.8931
# Epoch 58: val_loss did not improve from 0.13707
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2523 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9614 - f1_score: 0.8931 - val_loss: 0.2003 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9828 - val_f1_score: 0.9231 - lr: 1.0000e-04
# Epoch 59/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2226 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9693 - f1_score: 0.9174
# Epoch 59: val_loss did not improve from 0.13707
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2226 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9693 - f1_score: 0.9174 - val_loss: 0.1874 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9808 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 60/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.9107 - precision: 0.9107 - recall: 0.9107 - auc: 0.9670 - f1_score: 0.9107
# Epoch 60: val_loss did not improve from 0.13707
# 71/71 [==============================] - 44s 622ms/step - loss: 0.2307 - accuracy: 0.9107 - precision: 0.9107 - recall: 0.9107 - auc: 0.9670 - f1_score: 0.9107 - val_loss: 0.2003 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9776 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 61/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2273 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9680 - f1_score: 0.9103
# Epoch 61: val_loss did not improve from 0.13707
# 71/71 [==============================] - 44s 622ms/step - loss: 0.2273 - accuracy: 0.9103 - precision: 0.9103 - recall: 0.9103 - auc: 0.9680 - f1_score: 0.9103 - val_loss: 0.2245 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9723 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 62/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.9032 - precision: 0.9032 - recall: 0.9032 - auc: 0.9663 - f1_score: 0.9032
# Epoch 62: val_loss did not improve from 0.13707
# 71/71 [==============================] - 44s 622ms/step - loss: 0.2329 - accuracy: 0.9032 - precision: 0.9032 - recall: 0.9032 - auc: 0.9663 - f1_score: 0.9032 - val_loss: 0.1455 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9909 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 63/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9691 - f1_score: 0.9152
# Epoch 63: val_loss did not improve from 0.13707
# 71/71 [==============================] - 44s 622ms/step - loss: 0.2224 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9691 - f1_score: 0.9152 - val_loss: 0.1842 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9818 - val_f1_score: 0.9290 - lr: 1.0000e-04
# Epoch 64/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2194 - accuracy: 0.9147 - precision: 0.9147 - recall: 0.9147 - auc: 0.9704 - f1_score: 0.9147
# Epoch 64: val_loss did not improve from 0.13707
# 71/71 [==============================] - 44s 622ms/step - loss: 0.2194 - accuracy: 0.9147 - precision: 0.9147 - recall: 0.9147 - auc: 0.9704 - f1_score: 0.9147 - val_loss: 0.2053 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9770 - val_f1_score: 0.9112 - lr: 1.0000e-04
# Epoch 65/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2261 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9685 - f1_score: 0.9094
# Epoch 65: val_loss did not improve from 0.13707
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2261 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9685 - f1_score: 0.9094 - val_loss: 0.1653 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9883 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 66/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9707 - f1_score: 0.9165
# Epoch 66: val_loss did not improve from 0.13707
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2165 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9707 - f1_score: 0.9165 - val_loss: 0.1413 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9944 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 67/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9156 - precision: 0.9156 - recall: 0.9156 - auc: 0.9702 - f1_score: 0.9156
# Epoch 67: val_loss improved from 0.13707 to 0.13176, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 625ms/step - loss: 0.2187 - accuracy: 0.9156 - precision: 0.9156 - recall: 0.9156 - auc: 0.9702 - f1_score: 0.9156 - val_loss: 0.1318 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9936 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 68/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2165 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9709 - f1_score: 0.9152
# Epoch 68: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2165 - accuracy: 0.9152 - precision: 0.9152 - recall: 0.9152 - auc: 0.9709 - f1_score: 0.9152 - val_loss: 0.1993 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9827 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 69/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2092 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9732 - f1_score: 0.9165
# Epoch 69: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2092 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9732 - f1_score: 0.9165 - val_loss: 0.2007 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9771 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 70/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2129 - accuracy: 0.9205 - precision: 0.9205 - recall: 0.9205 - auc: 0.9711 - f1_score: 0.9205
# Epoch 70: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2129 - accuracy: 0.9205 - precision: 0.9205 - recall: 0.9205 - auc: 0.9711 - f1_score: 0.9205 - val_loss: 0.1480 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9887 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 71/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2112 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9720 - f1_score: 0.9200
# Epoch 71: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 619ms/step - loss: 0.2112 - accuracy: 0.9200 - precision: 0.9200 - recall: 0.9200 - auc: 0.9720 - f1_score: 0.9200 - val_loss: 0.1909 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9768 - val_f1_score: 0.9231 - lr: 1.0000e-04
# Epoch 72/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2027 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9743 - f1_score: 0.9213
# Epoch 72: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2027 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9743 - f1_score: 0.9213 - val_loss: 0.1817 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9849 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 73/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2018 - accuracy: 0.9275 - precision: 0.9275 - recall: 0.9275 - auc: 0.9743 - f1_score: 0.9275
# Epoch 73: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2018 - accuracy: 0.9275 - precision: 0.9275 - recall: 0.9275 - auc: 0.9743 - f1_score: 0.9275 - val_loss: 0.1737 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9843 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 74/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2059 - accuracy: 0.9253 - precision: 0.9253 - recall: 0.9253 - auc: 0.9737 - f1_score: 0.9253
# Epoch 74: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2059 - accuracy: 0.9253 - precision: 0.9253 - recall: 0.9253 - auc: 0.9737 - f1_score: 0.9253 - val_loss: 0.1324 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9915 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 75/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2058 - accuracy: 0.9196 - precision: 0.9196 - recall: 0.9196 - auc: 0.9737 - f1_score: 0.9196
# Epoch 75: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2058 - accuracy: 0.9196 - precision: 0.9196 - recall: 0.9196 - auc: 0.9737 - f1_score: 0.9196 - val_loss: 0.1948 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9767 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 76/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2243 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9686 - f1_score: 0.9125
# Epoch 76: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 620ms/step - loss: 0.2243 - accuracy: 0.9125 - precision: 0.9125 - recall: 0.9125 - auc: 0.9686 - f1_score: 0.9125 - val_loss: 0.1712 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9858 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 77/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2125 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9720 - f1_score: 0.9191
# Epoch 77: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 77: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 621ms/step - loss: 0.2125 - accuracy: 0.9191 - precision: 0.9191 - recall: 0.9191 - auc: 0.9720 - f1_score: 0.9191 - val_loss: 0.1500 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9893 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 78/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 0.9236 - precision: 0.9236 - recall: 0.9236 - auc: 0.9789 - f1_score: 0.9236
# Epoch 78: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1871 - accuracy: 0.9236 - precision: 0.9236 - recall: 0.9236 - auc: 0.9789 - f1_score: 0.9236 - val_loss: 0.1347 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9930 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 79/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1738 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9819 - f1_score: 0.9333
# Epoch 79: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 622ms/step - loss: 0.1738 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9819 - f1_score: 0.9333 - val_loss: 0.1526 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9885 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 80/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1754 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9814 - f1_score: 0.9293
# Epoch 80: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 622ms/step - loss: 0.1754 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9814 - f1_score: 0.9293 - val_loss: 0.1451 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9904 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 81/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1820 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9803 - f1_score: 0.9271
# Epoch 81: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1820 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9803 - f1_score: 0.9271 - val_loss: 0.1404 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9895 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 82/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1759 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9806 - f1_score: 0.9355
# Epoch 82: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 622ms/step - loss: 0.1759 - accuracy: 0.9355 - precision: 0.9355 - recall: 0.9355 - auc: 0.9806 - f1_score: 0.9355 - val_loss: 0.1387 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9912 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 83/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1732 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9820 - f1_score: 0.9302
# Epoch 83: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1732 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9820 - f1_score: 0.9302 - val_loss: 0.1376 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9914 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 84/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1754 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9811 - f1_score: 0.9293
# Epoch 84: val_loss did not improve from 0.13176
# 71/71 [==============================] - 44s 622ms/step - loss: 0.1754 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9811 - f1_score: 0.9293 - val_loss: 0.1390 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9909 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 85/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1853 - accuracy: 0.9266 - precision: 0.9266 - recall: 0.9266 - auc: 0.9790 - f1_score: 0.9266
# Epoch 85: val_loss improved from 0.13176 to 0.11552, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Versioin3-DIR.h5
# 71/71 [==============================] - 45s 627ms/step - loss: 0.1853 - accuracy: 0.9266 - precision: 0.9266 - recall: 0.9266 - auc: 0.9790 - f1_score: 0.9266 - val_loss: 0.1155 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9949 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 86/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9824 - f1_score: 0.9350
# Epoch 86: val_loss did not improve from 0.11552
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1710 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9824 - f1_score: 0.9350 - val_loss: 0.1328 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9928 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 87/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1733 - accuracy: 0.9315 - precision: 0.9315 - recall: 0.9315 - auc: 0.9819 - f1_score: 0.9315
# Epoch 87: val_loss did not improve from 0.11552
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1733 - accuracy: 0.9315 - precision: 0.9315 - recall: 0.9315 - auc: 0.9819 - f1_score: 0.9315 - val_loss: 0.1330 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9922 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 88/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9828 - f1_score: 0.9328
# Epoch 88: val_loss did not improve from 0.11552
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1689 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9828 - f1_score: 0.9328 - val_loss: 0.1335 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9928 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 89/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.9390 - precision: 0.9390 - recall: 0.9390 - auc: 0.9828 - f1_score: 0.9390
# Epoch 89: val_loss did not improve from 0.11552
# ...
# Epoch 120: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1620 - accuracy: 0.9377 - precision: 0.9377 - recall: 0.9377 - auc: 0.9840 - f1_score: 0.9377 - val_loss: 0.1186 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9946 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 121/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9822 - f1_score: 0.9350
# Epoch 121: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1701 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9822 - f1_score: 0.9350 - val_loss: 0.1420 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9898 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 122/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9844 - f1_score: 0.9328
# Epoch 122: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1611 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9844 - f1_score: 0.9328 - val_loss: 0.1583 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9868 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 123/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1709 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9822 - f1_score: 0.9289
# Epoch 123: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1709 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9822 - f1_score: 0.9289 - val_loss: 0.1262 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9929 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 124/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1613 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9844 - f1_score: 0.9337
# Epoch 124: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1613 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9844 - f1_score: 0.9337 - val_loss: 0.1291 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9925 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 125/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1673 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9827 - f1_score: 0.9258
# Epoch 125: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1673 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9827 - f1_score: 0.9258 - val_loss: 0.1280 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9903 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 126/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9833 - f1_score: 0.9368
# Epoch 126: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1658 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9833 - f1_score: 0.9368 - val_loss: 0.1164 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9947 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 127/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1742 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9819 - f1_score: 0.9262
# Epoch 127: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1742 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9819 - f1_score: 0.9262 - val_loss: 0.1461 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9891 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 128/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9842 - f1_score: 0.9359
# Epoch 128: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 622ms/step - loss: 0.1615 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9842 - f1_score: 0.9359 - val_loss: 0.1279 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9917 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 129/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1679 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9825 - f1_score: 0.9293
# Epoch 129: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 622ms/step - loss: 0.1679 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9825 - f1_score: 0.9293 - val_loss: 0.1222 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9927 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 130/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1549 - accuracy: 0.9408 - precision: 0.9408 - recall: 0.9408 - auc: 0.9854 - f1_score: 0.9408
# Epoch 130: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 622ms/step - loss: 0.1549 - accuracy: 0.9408 - precision: 0.9408 - recall: 0.9408 - auc: 0.9854 - f1_score: 0.9408 - val_loss: 0.1582 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9850 - val_f1_score: 0.9349 - lr: 1.0000e-05
# Epoch 131/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9834 - f1_score: 0.9319
# Epoch 131: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1650 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9834 - f1_score: 0.9319 - val_loss: 0.1195 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9934 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 132/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1649 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9835 - f1_score: 0.9346
# Epoch 132: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 622ms/step - loss: 0.1649 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9835 - f1_score: 0.9346 - val_loss: 0.1380 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9903 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 133/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1589 - accuracy: 0.9434 - precision: 0.9434 - recall: 0.9434 - auc: 0.9846 - f1_score: 0.9434
# Epoch 133: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 622ms/step - loss: 0.1589 - accuracy: 0.9434 - precision: 0.9434 - recall: 0.9434 - auc: 0.9846 - f1_score: 0.9434 - val_loss: 0.1639 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9839 - val_f1_score: 0.9320 - lr: 1.0000e-05
# Epoch 134/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9820 - f1_score: 0.9328
# Epoch 134: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1720 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9820 - f1_score: 0.9328 - val_loss: 0.1338 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9908 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 135/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1659 - accuracy: 0.9364 - precision: 0.9364 - recall: 0.9364 - auc: 0.9832 - f1_score: 0.9364
# Epoch 135: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1659 - accuracy: 0.9364 - precision: 0.9364 - recall: 0.9364 - auc: 0.9832 - f1_score: 0.9364 - val_loss: 0.1415 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9887 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 136/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9821 - f1_score: 0.9359
# Epoch 136: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1701 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9821 - f1_score: 0.9359 - val_loss: 0.1441 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9887 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 137/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9408 - precision: 0.9408 - recall: 0.9408 - auc: 0.9840 - f1_score: 0.9408
# Epoch 137: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 622ms/step - loss: 0.1603 - accuracy: 0.9408 - precision: 0.9408 - recall: 0.9408 - auc: 0.9840 - f1_score: 0.9408 - val_loss: 0.1265 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9926 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 138/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.9342 - precision: 0.9342 - recall: 0.9342 - auc: 0.9830 - f1_score: 0.9342
# Epoch 138: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 621ms/step - loss: 0.1645 - accuracy: 0.9342 - precision: 0.9342 - recall: 0.9342 - auc: 0.9830 - f1_score: 0.9342 - val_loss: 0.1459 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9879 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 139/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9830 - f1_score: 0.9346
# Epoch 139: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1658 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9830 - f1_score: 0.9346 - val_loss: 0.1425 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9886 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 140/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9403 - precision: 0.9403 - recall: 0.9403 - auc: 0.9851 - f1_score: 0.9403
# Epoch 140: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1550 - accuracy: 0.9403 - precision: 0.9403 - recall: 0.9403 - auc: 0.9851 - f1_score: 0.9403 - val_loss: 0.1287 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9908 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 141/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1631 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9840 - f1_score: 0.9302
# Epoch 141: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1631 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9840 - f1_score: 0.9302 - val_loss: 0.1341 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9911 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 142/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1660 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9830 - f1_score: 0.9311
# Epoch 142: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1660 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9830 - f1_score: 0.9311 - val_loss: 0.1242 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9936 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 143/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1477 - accuracy: 0.9403 - precision: 0.9403 - recall: 0.9403 - auc: 0.9869 - f1_score: 0.9403
# Epoch 143: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1477 - accuracy: 0.9403 - precision: 0.9403 - recall: 0.9403 - auc: 0.9869 - f1_score: 0.9403 - val_loss: 0.1453 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9876 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 144/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1581 - accuracy: 0.9364 - precision: 0.9364 - recall: 0.9364 - auc: 0.9850 - f1_score: 0.9364
# Epoch 144: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1581 - accuracy: 0.9364 - precision: 0.9364 - recall: 0.9364 - auc: 0.9850 - f1_score: 0.9364 - val_loss: 0.1365 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9907 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 145/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1669 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9826 - f1_score: 0.9328
# Epoch 145: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1669 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9826 - f1_score: 0.9328 - val_loss: 0.1342 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9912 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 146/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9846 - f1_score: 0.9333
# Epoch 146: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1596 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9846 - f1_score: 0.9333 - val_loss: 0.1255 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9910 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 147/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1628 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9838 - f1_score: 0.9333
# Epoch 147: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1628 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9838 - f1_score: 0.9333 - val_loss: 0.1393 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9892 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 148/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1563 - accuracy: 0.9399 - precision: 0.9399 - recall: 0.9399 - auc: 0.9848 - f1_score: 0.9399
# Epoch 148: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1563 - accuracy: 0.9399 - precision: 0.9399 - recall: 0.9399 - auc: 0.9848 - f1_score: 0.9399 - val_loss: 0.1164 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9943 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 149/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1594 - accuracy: 0.9373 - precision: 0.9373 - recall: 0.9373 - auc: 0.9841 - f1_score: 0.9373
# Epoch 149: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 620ms/step - loss: 0.1594 - accuracy: 0.9373 - precision: 0.9373 - recall: 0.9373 - auc: 0.9841 - f1_score: 0.9373 - val_loss: 0.1254 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9914 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 150/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1557 - accuracy: 0.9412 - precision: 0.9412 - recall: 0.9412 - auc: 0.9850 - f1_score: 0.9412
# Epoch 150: val_loss did not improve from 0.10864
# 71/71 [==============================] - 44s 622ms/step - loss: 0.1557 - accuracy: 0.9412 - precision: 0.9412 - recall: 0.9412 - auc: 0.9850 - f1_score: 0.9412 - val_loss: 0.1262 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9920 - val_f1_score: 0.9497 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = DIR.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 2s 154ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9398578811369509
# F1-Score for each class: [0.91860465 0.96111111]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9558011049723757
# specificity: 0.9294117647058824

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  DIR.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 1s 99ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = DIR.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 1s 96ms/step - loss: 0.1844 - accuracy: 0.9430 - precision: 0.9430 - recall: 0.9430 - auc: 0.9836 - f1_score: 0.9430
# Test loss: 0.18443411588668823
# Test accuracy: 0.9429529905319214
# Test precision: 0.9429529905319214
# Test recall: 0.9429529905319214
# Test AUC: 0.9836381077766418
# Test F1 Score: 0.9429529905319214

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = DIR.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 1s 98ms/step
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92        85
#            1       0.97      0.96      0.96       181
#
#     accuracy                           0.95       266
#    macro avg       0.94      0.94      0.94       266
# weighted avg       0.95      0.95      0.95       266

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

# del DIR


from numba import cuda

cuda.select_device(0)
cuda.close()
