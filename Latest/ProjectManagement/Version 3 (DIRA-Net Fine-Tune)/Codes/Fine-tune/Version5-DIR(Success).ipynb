# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.
# Out:
# 2024-03-06 14:38:23.185433: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 300 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = attention_block_2(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = attention_block_2(x)
    
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    x = attention_block_2(x)
    

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)
    
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    # a = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    c = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = attention_block_2(x)

    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    # c = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 5
num_B_blocks = 10
num_C_blocks = 5

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.3)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax')(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# 2024-03-06 14:38:26.722477: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-06 14:38:27.361639: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22309 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:04:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 4)  112         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 222, 222, 96  3552        ['conv2d[0][0]']
#                                 )
#
#  activation (Activation)        (None, 222, 222, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 222, 222, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 222, 222, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 222, 222, 4)  0           ['conv2d[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 220, 220, 4)  148         ['multiply[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 220, 220, 96  3552        ['conv2d_3[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 220, 220, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 220, 220, 1)  97          ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 220, 220, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 220, 220, 4)  0           ['conv2d_3[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 220, 220, 8)  296         ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 220, 220, 96  7008        ['conv2d_6[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 220, 220, 96  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 220, 220, 1)  97          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 220, 220, 1)  0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 220, 220, 8)  0           ['conv2d_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['multiply_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 218, 218, 12  876         ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_13[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_16[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_6 (Activation)      (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 4)  196         ['activation_6[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 4)  196         ['activation_6[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 4)  196         ['activation_6[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 4)  40         ['conv2d_18[0][0]']
#  v2D)
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_17[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['activation_6[0][0]',
#                                 )                                 'conv2d_21[0][0]']
#
#  activation_7 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 214, 214, 4)  196         ['activation_7[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 4)  196         ['activation_7[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 4)  196         ['activation_7[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_23[0][0]']
#  onv2D)
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_24[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_22[0][0]',
#                                 )                                 'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 214, 214, 48  0           ['activation_7[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  activation_8 (Activation)      (None, 214, 214, 48  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 214, 214, 4)  196         ['activation_8[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 214, 214, 4)  196         ['activation_8[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 214, 214, 4)  196         ['activation_8[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_28[0][0]']
#  onv2D)
#
#  conv2d_30 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_29[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_27[0][0]',
#                                 )                                 'depthwise_conv2d_2[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_5[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 214, 214, 48  0           ['activation_8[0][0]',
#                                 )                                 'conv2d_31[0][0]']
#
#  activation_9 (Activation)      (None, 214, 214, 48  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 214, 214, 4)  196         ['activation_9[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 214, 214, 4)  196         ['activation_9[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 214, 214, 4)  196         ['activation_9[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_33[0][0]']
#  onv2D)
#
#  conv2d_35 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_34[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_32[0][0]',
#                                 )                                 'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_6[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 214, 214, 48  0           ['activation_9[0][0]',
#                                 )                                 'conv2d_36[0][0]']
#
#  activation_10 (Activation)     (None, 214, 214, 48  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 214, 214, 4)  196         ['activation_10[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 214, 214, 4)  196         ['activation_10[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 214, 214, 4)  196         ['activation_10[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_38[0][0]']
#  onv2D)
#
#  conv2d_40 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_39[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_37[0][0]',
#                                 )                                 'depthwise_conv2d_4[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_7[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 214, 214, 48  0           ['activation_10[0][0]',
#                                 )                                 'conv2d_41[0][0]']
#
#  activation_11 (Activation)     (None, 214, 214, 48  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 214, 214, 32  1568        ['activation_11[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_43[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_11[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 106, 106, 48  20784       ['activation_11[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_44[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_42[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_49[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_46[0][0]',
#                                 )                                 'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_9[0][0]']
#                                 4)
#
#  add_5 (Add)                    (None, 106, 106, 14  0           ['concatenate_8[0][0]',
#                                 4)                                'conv2d_51[0][0]']
#
#  activation_12 (Activation)     (None, 106, 106, 14  0           ['add_5[0][0]']
#                                 4)
#
#  conv2d_53 (Conv2D)             (None, 106, 106, 16  2320        ['activation_12[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 106, 106, 24  3480        ['activation_12[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_55[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_52[0][0]',
#                                 )                                 'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_10[0][0]']
#                                 4)
#
#  add_6 (Add)                    (None, 106, 106, 14  0           ['activation_12[0][0]',
#                                 4)                                'conv2d_57[0][0]']
#
#  activation_13 (Activation)     (None, 106, 106, 14  0           ['add_6[0][0]']
#                                 4)
#
#  conv2d_59 (Conv2D)             (None, 106, 106, 16  2320        ['activation_13[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_59[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_60[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 106, 106, 24  3480        ['activation_13[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_61[0][0]']
#                                 )
#
#  concatenate_11 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_58[0][0]',
#                                 )                                 'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_11[0][0]']
#                                 4)
#
#  add_7 (Add)                    (None, 106, 106, 14  0           ['activation_13[0][0]',
#                                 4)                                'conv2d_63[0][0]']
#
#  activation_14 (Activation)     (None, 106, 106, 14  0           ['add_7[0][0]']
#                                 4)
#
#  conv2d_65 (Conv2D)             (None, 106, 106, 16  2320        ['activation_14[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_65[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_66[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 106, 106, 24  3480        ['activation_14[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_67[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_64[0][0]',
#                                 )                                 'conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_12[0][0]']
#                                 4)
#
#  add_8 (Add)                    (None, 106, 106, 14  0           ['activation_14[0][0]',
#                                 4)                                'conv2d_69[0][0]']
#
#  activation_15 (Activation)     (None, 106, 106, 14  0           ['add_8[0][0]']
#                                 4)
#
#  conv2d_71 (Conv2D)             (None, 106, 106, 16  2320        ['activation_15[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_71[0][0]']
#                                 )
#
#  conv2d_73 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_72[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 106, 106, 24  3480        ['activation_15[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_73[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_70[0][0]',
#                                 )                                 'conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_13[0][0]']
#                                 4)
#
#  add_9 (Add)                    (None, 106, 106, 14  0           ['activation_15[0][0]',
#                                 4)                                'conv2d_75[0][0]']
#
#  activation_16 (Activation)     (None, 106, 106, 14  0           ['add_9[0][0]']
#                                 4)
#
#  conv2d_77 (Conv2D)             (None, 106, 106, 16  2320        ['activation_16[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_77[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_78[0][0]']
#                                 )
#
#  conv2d_76 (Conv2D)             (None, 106, 106, 24  3480        ['activation_16[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_79[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_76[0][0]',
#                                 )                                 'conv2d_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_14[0][0]']
#                                 4)
#
#  add_10 (Add)                   (None, 106, 106, 14  0           ['activation_16[0][0]',
#                                 4)                                'conv2d_81[0][0]']
#
#  activation_17 (Activation)     (None, 106, 106, 14  0           ['add_10[0][0]']
#                                 4)
#
#  conv2d_83 (Conv2D)             (None, 106, 106, 16  2320        ['activation_17[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_83[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_84[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 106, 106, 24  3480        ['activation_17[0][0]']
#                                 )
#
#  conv2d_86 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_85[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_82[0][0]',
#                                 )                                 'conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_15[0][0]']
#                                 4)
#
#  add_11 (Add)                   (None, 106, 106, 14  0           ['activation_17[0][0]',
#                                 4)                                'conv2d_87[0][0]']
#
#  activation_18 (Activation)     (None, 106, 106, 14  0           ['add_11[0][0]']
#                                 4)
#
#  conv2d_89 (Conv2D)             (None, 106, 106, 16  2320        ['activation_18[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_89[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_90[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 106, 106, 24  3480        ['activation_18[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_91[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_88[0][0]',
#                                 )                                 'conv2d_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_16[0][0]']
#                                 4)
#
#  add_12 (Add)                   (None, 106, 106, 14  0           ['activation_18[0][0]',
#                                 4)                                'conv2d_93[0][0]']
#
#  activation_19 (Activation)     (None, 106, 106, 14  0           ['add_12[0][0]']
#                                 4)
#
#  conv2d_95 (Conv2D)             (None, 106, 106, 16  2320        ['activation_19[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_95[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_96[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 106, 106, 24  3480        ['activation_19[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_97[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_94[0][0]',
#                                 )                                 'conv2d_98[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_17[0][0]']
#                                 4)
#
#  add_13 (Add)                   (None, 106, 106, 14  0           ['activation_19[0][0]',
#                                 4)                                'conv2d_99[0][0]']
#
#  activation_20 (Activation)     (None, 106, 106, 14  0           ['add_13[0][0]']
#                                 4)
#
#  conv2d_101 (Conv2D)            (None, 106, 106, 16  2320        ['activation_20[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 106, 106, 20  2260        ['conv2d_101[0][0]']
#                                 )
#
#  conv2d_103 (Conv2D)            (None, 106, 106, 24  3384        ['conv2d_102[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 106, 106, 24  3480        ['activation_20[0][0]']
#                                 )
#
#  conv2d_104 (Conv2D)            (None, 106, 106, 24  600         ['conv2d_103[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_100[0][0]',
#                                 )                                 'conv2d_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 106, 106, 14  7056        ['concatenate_18[0][0]']
#                                 4)
#
#  add_14 (Add)                   (None, 106, 106, 14  0           ['activation_20[0][0]',
#                                 4)                                'conv2d_105[0][0]']
#
#  activation_21 (Activation)     (None, 106, 106, 14  0           ['add_14[0][0]']
#                                 4)
#
#  conv2d_110 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_106 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_108 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_111 (Conv2D)            (None, 106, 106, 36  10404       ['conv2d_110[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_21[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_106[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_108[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 52, 52, 40)   13000       ['conv2d_111[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_107[0][0]',
#                                                                   'conv2d_109[0][0]',
#                                                                   'conv2d_112[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_114[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_115[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_113[0][0]',
#                                                                   'conv2d_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_20[0][0]']
#
#  add_15 (Add)                   (None, 52, 52, 256)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_117[0][0]']
#
#  activation_22 (Activation)     (None, 52, 52, 256)  0           ['add_15[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_119[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_120[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_118[0][0]',
#                                                                   'conv2d_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_21[0][0]']
#
#  add_16 (Add)                   (None, 52, 52, 256)  0           ['activation_22[0][0]',
#                                                                   'conv2d_122[0][0]']
#
#  activation_23 (Activation)     (None, 52, 52, 256)  0           ['add_16[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_124[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_125[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_123[0][0]',
#                                                                   'conv2d_126[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_22[0][0]']
#
#  add_17 (Add)                   (None, 52, 52, 256)  0           ['activation_23[0][0]',
#                                                                   'conv2d_127[0][0]']
#
#  activation_24 (Activation)     (None, 52, 52, 256)  0           ['add_17[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_129[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_130[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_128[0][0]',
#                                                                   'conv2d_131[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_23[0][0]']
#
#  add_18 (Add)                   (None, 52, 52, 256)  0           ['activation_24[0][0]',
#                                                                   'conv2d_132[0][0]']
#
#  activation_25 (Activation)     (None, 52, 52, 256)  0           ['add_18[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_134[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_135[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_133[0][0]',
#                                                                   'conv2d_136[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_24[0][0]']
#
#  add_19 (Add)                   (None, 52, 52, 256)  0           ['activation_25[0][0]',
#                                                                   'conv2d_137[0][0]']
#
#  activation_26 (Activation)     (None, 52, 52, 256)  0           ['add_19[0][0]']
#
#  dropout (Dropout)              (None, 52, 52, 256)  0           ['activation_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 486,321
# Trainable params: 486,321
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version5-DIR"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)



lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = DIR.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)
# Out:
# Epoch 1/150
# 2024-03-06 14:38:37.020377: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-06 14:38:39.182565: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 2.5830 - accuracy: 0.4852 - precision: 0.4852 - recall: 0.4852 - auc: 0.4783 - f1_score: 0.4852
# Epoch 1: val_loss improved from inf to 0.69289, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 61s 713ms/step - loss: 2.5830 - accuracy: 0.4852 - precision: 0.4852 - recall: 0.4852 - auc: 0.4783 - f1_score: 0.4852 - val_loss: 0.6929 - val_accuracy: 0.5266 - val_precision: 0.5266 - val_recall: 0.5266 - val_auc: 0.4913 - val_f1_score: 0.5266 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6684 - accuracy: 0.5687 - precision: 0.5687 - recall: 0.5687 - auc: 0.6135 - f1_score: 0.5687
# Epoch 2: val_loss did not improve from 0.69289
# 71/71 [==============================] - 47s 653ms/step - loss: 0.6684 - accuracy: 0.5687 - precision: 0.5687 - recall: 0.5687 - auc: 0.6135 - f1_score: 0.5687 - val_loss: 0.7447 - val_accuracy: 0.5148 - val_precision: 0.5148 - val_recall: 0.5148 - val_auc: 0.4967 - val_f1_score: 0.5148 - lr: 0.0010
# Epoch 3/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5462 - accuracy: 0.7415 - precision: 0.7415 - recall: 0.7415 - auc: 0.8019 - f1_score: 0.7415
# Epoch 3: val_loss improved from 0.69289 to 0.49031, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 654ms/step - loss: 0.5462 - accuracy: 0.7415 - precision: 0.7415 - recall: 0.7415 - auc: 0.8019 - f1_score: 0.7415 - val_loss: 0.4903 - val_accuracy: 0.7899 - val_precision: 0.7899 - val_recall: 0.7899 - val_auc: 0.8900 - val_f1_score: 0.7899 - lr: 0.0010
# Epoch 4/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5217 - accuracy: 0.7609 - precision: 0.7609 - recall: 0.7609 - auc: 0.8211 - f1_score: 0.7609
# Epoch 4: val_loss did not improve from 0.49031
# 71/71 [==============================] - 47s 652ms/step - loss: 0.5217 - accuracy: 0.7609 - precision: 0.7609 - recall: 0.7609 - auc: 0.8211 - f1_score: 0.7609 - val_loss: 0.4952 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.9110 - val_f1_score: 0.8166 - lr: 0.0010
# Epoch 5/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5032 - accuracy: 0.7693 - precision: 0.7693 - recall: 0.7693 - auc: 0.8349 - f1_score: 0.7693
# Epoch 5: val_loss improved from 0.49031 to 0.39801, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 655ms/step - loss: 0.5032 - accuracy: 0.7693 - precision: 0.7693 - recall: 0.7693 - auc: 0.8349 - f1_score: 0.7693 - val_loss: 0.3980 - val_accuracy: 0.8462 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9063 - val_f1_score: 0.8462 - lr: 0.0010
# Epoch 6/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4968 - accuracy: 0.7698 - precision: 0.7698 - recall: 0.7698 - auc: 0.8410 - f1_score: 0.7698
# Epoch 6: val_loss improved from 0.39801 to 0.37750, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 658ms/step - loss: 0.4968 - accuracy: 0.7698 - precision: 0.7698 - recall: 0.7698 - auc: 0.8410 - f1_score: 0.7698 - val_loss: 0.3775 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9195 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 7/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5040 - accuracy: 0.7724 - precision: 0.7724 - recall: 0.7724 - auc: 0.8354 - f1_score: 0.7724
# Epoch 7: val_loss did not improve from 0.37750
# 71/71 [==============================] - 46s 649ms/step - loss: 0.5040 - accuracy: 0.7724 - precision: 0.7724 - recall: 0.7724 - auc: 0.8354 - f1_score: 0.7724 - val_loss: 0.3829 - val_accuracy: 0.8136 - val_precision: 0.8136 - val_recall: 0.8136 - val_auc: 0.9246 - val_f1_score: 0.8136 - lr: 0.0010
# Epoch 8/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4688 - accuracy: 0.7888 - precision: 0.7888 - recall: 0.7888 - auc: 0.8611 - f1_score: 0.7888
# Epoch 8: val_loss did not improve from 0.37750
# 71/71 [==============================] - 47s 652ms/step - loss: 0.4688 - accuracy: 0.7888 - precision: 0.7888 - recall: 0.7888 - auc: 0.8611 - f1_score: 0.7888 - val_loss: 0.4076 - val_accuracy: 0.8136 - val_precision: 0.8136 - val_recall: 0.8136 - val_auc: 0.9105 - val_f1_score: 0.8136 - lr: 0.0010
# Epoch 9/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4518 - accuracy: 0.8007 - precision: 0.8007 - recall: 0.8007 - auc: 0.8691 - f1_score: 0.8007
# Epoch 9: val_loss did not improve from 0.37750
# 71/71 [==============================] - 46s 649ms/step - loss: 0.4518 - accuracy: 0.8007 - precision: 0.8007 - recall: 0.8007 - auc: 0.8691 - f1_score: 0.8007 - val_loss: 0.4150 - val_accuracy: 0.8314 - val_precision: 0.8314 - val_recall: 0.8314 - val_auc: 0.9221 - val_f1_score: 0.8314 - lr: 0.0010
# Epoch 10/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4835 - accuracy: 0.7777 - precision: 0.7777 - recall: 0.7777 - auc: 0.8527 - f1_score: 0.7777
# Epoch 10: val_loss did not improve from 0.37750
# 71/71 [==============================] - 47s 652ms/step - loss: 0.4835 - accuracy: 0.7777 - precision: 0.7777 - recall: 0.7777 - auc: 0.8527 - f1_score: 0.7777 - val_loss: 0.3905 - val_accuracy: 0.8343 - val_precision: 0.8343 - val_recall: 0.8343 - val_auc: 0.9320 - val_f1_score: 0.8343 - lr: 0.0010
# Epoch 11/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5032 - accuracy: 0.7662 - precision: 0.7662 - recall: 0.7662 - auc: 0.8342 - f1_score: 0.7662
# Epoch 11: val_loss did not improve from 0.37750
# 71/71 [==============================] - 46s 649ms/step - loss: 0.5032 - accuracy: 0.7662 - precision: 0.7662 - recall: 0.7662 - auc: 0.8342 - f1_score: 0.7662 - val_loss: 0.4847 - val_accuracy: 0.7929 - val_precision: 0.7929 - val_recall: 0.7929 - val_auc: 0.9055 - val_f1_score: 0.7929 - lr: 0.0010
# Epoch 12/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4707 - accuracy: 0.7844 - precision: 0.7844 - recall: 0.7844 - auc: 0.8570 - f1_score: 0.7844
# Epoch 12: val_loss did not improve from 0.37750
# 71/71 [==============================] - 47s 652ms/step - loss: 0.4707 - accuracy: 0.7844 - precision: 0.7844 - recall: 0.7844 - auc: 0.8570 - f1_score: 0.7844 - val_loss: 0.4069 - val_accuracy: 0.8047 - val_precision: 0.8047 - val_recall: 0.8047 - val_auc: 0.9106 - val_f1_score: 0.8047 - lr: 0.0010
# Epoch 13/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4847 - accuracy: 0.7857 - precision: 0.7857 - recall: 0.7857 - auc: 0.8482 - f1_score: 0.7857
# Epoch 13: val_loss improved from 0.37750 to 0.35556, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 655ms/step - loss: 0.4847 - accuracy: 0.7857 - precision: 0.7857 - recall: 0.7857 - auc: 0.8482 - f1_score: 0.7857 - val_loss: 0.3556 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9344 - val_f1_score: 0.8728 - lr: 0.0010
# Epoch 14/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4457 - accuracy: 0.8065 - precision: 0.8065 - recall: 0.8065 - auc: 0.8730 - f1_score: 0.8065
# Epoch 14: val_loss did not improve from 0.35556
# 71/71 [==============================] - 47s 652ms/step - loss: 0.4457 - accuracy: 0.8065 - precision: 0.8065 - recall: 0.8065 - auc: 0.8730 - f1_score: 0.8065 - val_loss: 0.3945 - val_accuracy: 0.8195 - val_precision: 0.8195 - val_recall: 0.8195 - val_auc: 0.9295 - val_f1_score: 0.8195 - lr: 0.0010
# Epoch 15/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4573 - accuracy: 0.7998 - precision: 0.7998 - recall: 0.7998 - auc: 0.8680 - f1_score: 0.7998
# Epoch 15: val_loss did not improve from 0.35556
# 71/71 [==============================] - 46s 650ms/step - loss: 0.4573 - accuracy: 0.7998 - precision: 0.7998 - recall: 0.7998 - auc: 0.8680 - f1_score: 0.7998 - val_loss: 0.5247 - val_accuracy: 0.7219 - val_precision: 0.7219 - val_recall: 0.7219 - val_auc: 0.8346 - val_f1_score: 0.7219 - lr: 0.0010
# Epoch 16/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4508 - accuracy: 0.8025 - precision: 0.8025 - recall: 0.8025 - auc: 0.8701 - f1_score: 0.8025
# Epoch 16: val_loss did not improve from 0.35556
# 71/71 [==============================] - 47s 653ms/step - loss: 0.4508 - accuracy: 0.8025 - precision: 0.8025 - recall: 0.8025 - auc: 0.8701 - f1_score: 0.8025 - val_loss: 0.3885 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9334 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 17/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4346 - accuracy: 0.8157 - precision: 0.8157 - recall: 0.8157 - auc: 0.8811 - f1_score: 0.8157
# Epoch 17: val_loss improved from 0.35556 to 0.30933, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 654ms/step - loss: 0.4346 - accuracy: 0.8157 - precision: 0.8157 - recall: 0.8157 - auc: 0.8811 - f1_score: 0.8157 - val_loss: 0.3093 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9573 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 18/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4462 - accuracy: 0.8060 - precision: 0.8060 - recall: 0.8060 - auc: 0.8754 - f1_score: 0.8060
# Epoch 18: val_loss did not improve from 0.30933
# 71/71 [==============================] - 47s 653ms/step - loss: 0.4462 - accuracy: 0.8060 - precision: 0.8060 - recall: 0.8060 - auc: 0.8754 - f1_score: 0.8060 - val_loss: 0.3271 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9570 - val_f1_score: 0.8994 - lr: 0.0010
# Epoch 19/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4208 - accuracy: 0.8162 - precision: 0.8162 - recall: 0.8162 - auc: 0.8894 - f1_score: 0.8162
# Epoch 19: val_loss did not improve from 0.30933
# 71/71 [==============================] - 46s 649ms/step - loss: 0.4208 - accuracy: 0.8162 - precision: 0.8162 - recall: 0.8162 - auc: 0.8894 - f1_score: 0.8162 - val_loss: 0.3148 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9527 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 20/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4508 - accuracy: 0.8003 - precision: 0.8003 - recall: 0.8003 - auc: 0.8709 - f1_score: 0.8003
# Epoch 20: val_loss did not improve from 0.30933
# 71/71 [==============================] - 47s 652ms/step - loss: 0.4508 - accuracy: 0.8003 - precision: 0.8003 - recall: 0.8003 - auc: 0.8709 - f1_score: 0.8003 - val_loss: 0.4291 - val_accuracy: 0.7929 - val_precision: 0.7929 - val_recall: 0.7929 - val_auc: 0.8989 - val_f1_score: 0.7929 - lr: 0.0010
# Epoch 21/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4117 - accuracy: 0.8241 - precision: 0.8241 - recall: 0.8241 - auc: 0.8930 - f1_score: 0.8241
# Epoch 21: val_loss did not improve from 0.30933
# 71/71 [==============================] - 46s 649ms/step - loss: 0.4117 - accuracy: 0.8241 - precision: 0.8241 - recall: 0.8241 - auc: 0.8930 - f1_score: 0.8241 - val_loss: 0.3654 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9414 - val_f1_score: 0.8580 - lr: 0.0010
# Epoch 22/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4257 - accuracy: 0.8184 - precision: 0.8184 - recall: 0.8184 - auc: 0.8859 - f1_score: 0.8184
# Epoch 22: val_loss did not improve from 0.30933
# 71/71 [==============================] - 47s 653ms/step - loss: 0.4257 - accuracy: 0.8184 - precision: 0.8184 - recall: 0.8184 - auc: 0.8859 - f1_score: 0.8184 - val_loss: 0.3218 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9687 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 23/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4668 - accuracy: 0.7835 - precision: 0.7835 - recall: 0.7835 - auc: 0.8612 - f1_score: 0.7835
# Epoch 23: val_loss did not improve from 0.30933
# 71/71 [==============================] - 46s 650ms/step - loss: 0.4668 - accuracy: 0.7835 - precision: 0.7835 - recall: 0.7835 - auc: 0.8612 - f1_score: 0.7835 - val_loss: 0.3418 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9451 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 24/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4172 - accuracy: 0.8188 - precision: 0.8188 - recall: 0.8188 - auc: 0.8910 - f1_score: 0.8188
# Epoch 24: val_loss improved from 0.30933 to 0.29372, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 660ms/step - loss: 0.4172 - accuracy: 0.8188 - precision: 0.8188 - recall: 0.8188 - auc: 0.8910 - f1_score: 0.8188 - val_loss: 0.2937 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9581 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 25/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4469 - accuracy: 0.8065 - precision: 0.8065 - recall: 0.8065 - auc: 0.8735 - f1_score: 0.8065
# Epoch 25: val_loss did not improve from 0.29372
# 71/71 [==============================] - 46s 649ms/step - loss: 0.4469 - accuracy: 0.8065 - precision: 0.8065 - recall: 0.8065 - auc: 0.8735 - f1_score: 0.8065 - val_loss: 0.3105 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9657 - val_f1_score: 0.9112 - lr: 0.0010
# Epoch 26/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4083 - accuracy: 0.8219 - precision: 0.8219 - recall: 0.8219 - auc: 0.8946 - f1_score: 0.8219
# Epoch 26: val_loss did not improve from 0.29372
# 71/71 [==============================] - 47s 653ms/step - loss: 0.4083 - accuracy: 0.8219 - precision: 0.8219 - recall: 0.8219 - auc: 0.8946 - f1_score: 0.8219 - val_loss: 0.3035 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9546 - val_f1_score: 0.8905 - lr: 0.0010
# Epoch 27/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4024 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.8985 - f1_score: 0.8294
# Epoch 27: val_loss improved from 0.29372 to 0.24984, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 655ms/step - loss: 0.4024 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.8985 - f1_score: 0.8294 - val_loss: 0.2498 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9641 - val_f1_score: 0.9053 - lr: 0.0010
# Epoch 28/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3898 - accuracy: 0.8343 - precision: 0.8343 - recall: 0.8343 - auc: 0.9060 - f1_score: 0.8343
# Epoch 28: val_loss did not improve from 0.24984
# 71/71 [==============================] - 47s 652ms/step - loss: 0.3898 - accuracy: 0.8343 - precision: 0.8343 - recall: 0.8343 - auc: 0.9060 - f1_score: 0.8343 - val_loss: 0.2610 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9747 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 29/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4010 - accuracy: 0.8308 - precision: 0.8308 - recall: 0.8308 - auc: 0.9004 - f1_score: 0.8308
# Epoch 29: val_loss improved from 0.24984 to 0.23246, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 655ms/step - loss: 0.4010 - accuracy: 0.8308 - precision: 0.8308 - recall: 0.8308 - auc: 0.9004 - f1_score: 0.8308 - val_loss: 0.2325 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9743 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 30/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3933 - accuracy: 0.8312 - precision: 0.8312 - recall: 0.8312 - auc: 0.9031 - f1_score: 0.8312
# Epoch 30: val_loss did not improve from 0.23246
# 71/71 [==============================] - 46s 649ms/step - loss: 0.3933 - accuracy: 0.8312 - precision: 0.8312 - recall: 0.8312 - auc: 0.9031 - f1_score: 0.8312 - val_loss: 0.2363 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9703 - val_f1_score: 0.9201 - lr: 0.0010
# Epoch 31/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3588 - accuracy: 0.8537 - precision: 0.8537 - recall: 0.8537 - auc: 0.9209 - f1_score: 0.8537
# Epoch 31: val_loss did not improve from 0.23246
# 71/71 [==============================] - 46s 649ms/step - loss: 0.3588 - accuracy: 0.8537 - precision: 0.8537 - recall: 0.8537 - auc: 0.9209 - f1_score: 0.8537 - val_loss: 0.2524 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9746 - val_f1_score: 0.9142 - lr: 0.0010
# Epoch 32/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4036 - accuracy: 0.8321 - precision: 0.8321 - recall: 0.8321 - auc: 0.8982 - f1_score: 0.8321
# Epoch 32: val_loss did not improve from 0.23246
# 71/71 [==============================] - 47s 652ms/step - loss: 0.4036 - accuracy: 0.8321 - precision: 0.8321 - recall: 0.8321 - auc: 0.8982 - f1_score: 0.8321 - val_loss: 0.3333 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9599 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 33/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3931 - accuracy: 0.8285 - precision: 0.8285 - recall: 0.8285 - auc: 0.9030 - f1_score: 0.8285
# Epoch 33: val_loss improved from 0.23246 to 0.23081, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 655ms/step - loss: 0.3931 - accuracy: 0.8285 - precision: 0.8285 - recall: 0.8285 - auc: 0.9030 - f1_score: 0.8285 - val_loss: 0.2308 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9801 - val_f1_score: 0.9349 - lr: 0.0010
# Epoch 34/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3649 - accuracy: 0.8471 - precision: 0.8471 - recall: 0.8471 - auc: 0.9171 - f1_score: 0.8471
# Epoch 34: val_loss did not improve from 0.23081
# 71/71 [==============================] - 47s 653ms/step - loss: 0.3649 - accuracy: 0.8471 - precision: 0.8471 - recall: 0.8471 - auc: 0.9171 - f1_score: 0.8471 - val_loss: 0.4687 - val_accuracy: 0.7515 - val_precision: 0.7515 - val_recall: 0.7515 - val_auc: 0.8627 - val_f1_score: 0.7515 - lr: 0.0010
# Epoch 35/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3513 - accuracy: 0.8529 - precision: 0.8529 - recall: 0.8529 - auc: 0.9242 - f1_score: 0.8529
# Epoch 35: val_loss improved from 0.23081 to 0.19413, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 655ms/step - loss: 0.3513 - accuracy: 0.8529 - precision: 0.8529 - recall: 0.8529 - auc: 0.9242 - f1_score: 0.8529 - val_loss: 0.1941 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9839 - val_f1_score: 0.9379 - lr: 0.0010
# Epoch 36/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3691 - accuracy: 0.8493 - precision: 0.8493 - recall: 0.8493 - auc: 0.9153 - f1_score: 0.8493
# Epoch 36: val_loss did not improve from 0.19413
# 71/71 [==============================] - 47s 653ms/step - loss: 0.3691 - accuracy: 0.8493 - precision: 0.8493 - recall: 0.8493 - auc: 0.9153 - f1_score: 0.8493 - val_loss: 0.2262 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9737 - val_f1_score: 0.9320 - lr: 0.0010
# Epoch 37/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3484 - accuracy: 0.8542 - precision: 0.8542 - recall: 0.8542 - auc: 0.9259 - f1_score: 0.8542
# Epoch 37: val_loss did not improve from 0.19413
# 71/71 [==============================] - 46s 649ms/step - loss: 0.3484 - accuracy: 0.8542 - precision: 0.8542 - recall: 0.8542 - auc: 0.9259 - f1_score: 0.8542 - val_loss: 0.2288 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9730 - val_f1_score: 0.9231 - lr: 0.0010
# Epoch 38/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3310 - accuracy: 0.8670 - precision: 0.8670 - recall: 0.8670 - auc: 0.9321 - f1_score: 0.8670
# Epoch 38: val_loss did not improve from 0.19413
# 71/71 [==============================] - 47s 653ms/step - loss: 0.3310 - accuracy: 0.8670 - precision: 0.8670 - recall: 0.8670 - auc: 0.9321 - f1_score: 0.8670 - val_loss: 0.3921 - val_accuracy: 0.8047 - val_precision: 0.8047 - val_recall: 0.8047 - val_auc: 0.9073 - val_f1_score: 0.8047 - lr: 0.0010
# Epoch 39/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3431 - accuracy: 0.8573 - precision: 0.8573 - recall: 0.8573 - auc: 0.9283 - f1_score: 0.8573
# Epoch 39: val_loss did not improve from 0.19413
# 71/71 [==============================] - 46s 649ms/step - loss: 0.3431 - accuracy: 0.8573 - precision: 0.8573 - recall: 0.8573 - auc: 0.9283 - f1_score: 0.8573 - val_loss: 0.3334 - val_accuracy: 0.8669 - val_precision: 0.8669 - val_recall: 0.8669 - val_auc: 0.9319 - val_f1_score: 0.8669 - lr: 0.0010
# Epoch 40/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3368 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9304 - f1_score: 0.8546
# Epoch 40: val_loss did not improve from 0.19413
# 71/71 [==============================] - 47s 652ms/step - loss: 0.3368 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9304 - f1_score: 0.8546 - val_loss: 0.2156 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9837 - val_f1_score: 0.9527 - lr: 0.0010
# Epoch 41/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3601 - accuracy: 0.8533 - precision: 0.8533 - recall: 0.8533 - auc: 0.9199 - f1_score: 0.8533
# Epoch 41: val_loss did not improve from 0.19413
# 71/71 [==============================] - 47s 652ms/step - loss: 0.3601 - accuracy: 0.8533 - precision: 0.8533 - recall: 0.8533 - auc: 0.9199 - f1_score: 0.8533 - val_loss: 0.2256 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9792 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 42/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3444 - accuracy: 0.8595 - precision: 0.8595 - recall: 0.8595 - auc: 0.9263 - f1_score: 0.8595
# Epoch 42: val_loss improved from 0.19413 to 0.17125, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 657ms/step - loss: 0.3444 - accuracy: 0.8595 - precision: 0.8595 - recall: 0.8595 - auc: 0.9263 - f1_score: 0.8595 - val_loss: 0.1712 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9927 - val_f1_score: 0.9615 - lr: 0.0010
# Epoch 43/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3241 - accuracy: 0.8643 - precision: 0.8643 - recall: 0.8643 - auc: 0.9357 - f1_score: 0.8643
# Epoch 43: val_loss did not improve from 0.17125
# 71/71 [==============================] - 46s 649ms/step - loss: 0.3241 - accuracy: 0.8643 - precision: 0.8643 - recall: 0.8643 - auc: 0.9357 - f1_score: 0.8643 - val_loss: 0.2315 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9827 - val_f1_score: 0.9379 - lr: 0.0010
# Epoch 44/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3292 - accuracy: 0.8621 - precision: 0.8621 - recall: 0.8621 - auc: 0.9334 - f1_score: 0.8621
# Epoch 44: val_loss did not improve from 0.17125
# 71/71 [==============================] - 46s 649ms/step - loss: 0.3292 - accuracy: 0.8621 - precision: 0.8621 - recall: 0.8621 - auc: 0.9334 - f1_score: 0.8621 - val_loss: 0.2449 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9825 - val_f1_score: 0.9438 - lr: 0.0010
# Epoch 45/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3104 - accuracy: 0.8736 - precision: 0.8736 - recall: 0.8736 - auc: 0.9419 - f1_score: 0.8736
# Epoch 45: val_loss did not improve from 0.17125
# 71/71 [==============================] - 46s 649ms/step - loss: 0.3104 - accuracy: 0.8736 - precision: 0.8736 - recall: 0.8736 - auc: 0.9419 - f1_score: 0.8736 - val_loss: 0.4317 - val_accuracy: 0.8047 - val_precision: 0.8047 - val_recall: 0.8047 - val_auc: 0.8896 - val_f1_score: 0.8047 - lr: 0.0010
# Epoch 46/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.8471 - precision: 0.8471 - recall: 0.8471 - auc: 0.9268 - f1_score: 0.8471
# Epoch 46: val_loss did not improve from 0.17125
# 71/71 [==============================] - 47s 653ms/step - loss: 0.3473 - accuracy: 0.8471 - precision: 0.8471 - recall: 0.8471 - auc: 0.9268 - f1_score: 0.8471 - val_loss: 0.2146 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9778 - val_f1_score: 0.9379 - lr: 0.0010
# Epoch 47/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3214 - accuracy: 0.8657 - precision: 0.8657 - recall: 0.8657 - auc: 0.9369 - f1_score: 0.8657
# Epoch 47: val_loss did not improve from 0.17125
# 71/71 [==============================] - 46s 648ms/step - loss: 0.3214 - accuracy: 0.8657 - precision: 0.8657 - recall: 0.8657 - auc: 0.9369 - f1_score: 0.8657 - val_loss: 0.2300 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9739 - val_f1_score: 0.9290 - lr: 0.0010
# Epoch 48/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3086 - accuracy: 0.8763 - precision: 0.8763 - recall: 0.8763 - auc: 0.9420 - f1_score: 0.8763
# Epoch 48: val_loss did not improve from 0.17125
# 71/71 [==============================] - 47s 652ms/step - loss: 0.3086 - accuracy: 0.8763 - precision: 0.8763 - recall: 0.8763 - auc: 0.9420 - f1_score: 0.8763 - val_loss: 0.4642 - val_accuracy: 0.7870 - val_precision: 0.7870 - val_recall: 0.7870 - val_auc: 0.8625 - val_f1_score: 0.7870 - lr: 0.0010
# Epoch 49/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3255 - accuracy: 0.8568 - precision: 0.8568 - recall: 0.8568 - auc: 0.9355 - f1_score: 0.8568
# Epoch 49: val_loss improved from 0.17125 to 0.14314, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 654ms/step - loss: 0.3255 - accuracy: 0.8568 - precision: 0.8568 - recall: 0.8568 - auc: 0.9355 - f1_score: 0.8568 - val_loss: 0.1431 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9905 - val_f1_score: 0.9497 - lr: 0.0010
# Epoch 50/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3310 - accuracy: 0.8639 - precision: 0.8639 - recall: 0.8639 - auc: 0.9329 - f1_score: 0.8639
# Epoch 50: val_loss did not improve from 0.14314
# 71/71 [==============================] - 47s 652ms/step - loss: 0.3310 - accuracy: 0.8639 - precision: 0.8639 - recall: 0.8639 - auc: 0.9329 - f1_score: 0.8639 - val_loss: 0.2462 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9671 - val_f1_score: 0.9201 - lr: 0.0010
# Epoch 51/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3279 - accuracy: 0.8621 - precision: 0.8621 - recall: 0.8621 - auc: 0.9340 - f1_score: 0.8621
# Epoch 51: val_loss did not improve from 0.14314
# 71/71 [==============================] - 46s 649ms/step - loss: 0.3279 - accuracy: 0.8621 - precision: 0.8621 - recall: 0.8621 - auc: 0.9340 - f1_score: 0.8621 - val_loss: 0.2738 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9647 - val_f1_score: 0.9024 - lr: 0.0010
# Epoch 52/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3161 - accuracy: 0.8701 - precision: 0.8701 - recall: 0.8701 - auc: 0.9387 - f1_score: 0.8701
# Epoch 52: val_loss did not improve from 0.14314
# 71/71 [==============================] - 46s 652ms/step - loss: 0.3161 - accuracy: 0.8701 - precision: 0.8701 - recall: 0.8701 - auc: 0.9387 - f1_score: 0.8701 - val_loss: 0.1836 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9869 - val_f1_score: 0.9497 - lr: 0.0010
# Epoch 53/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3187 - accuracy: 0.8674 - precision: 0.8674 - recall: 0.8674 - auc: 0.9377 - f1_score: 0.8674
# Epoch 53: val_loss did not improve from 0.14314
# 71/71 [==============================] - 46s 649ms/step - loss: 0.3187 - accuracy: 0.8674 - precision: 0.8674 - recall: 0.8674 - auc: 0.9377 - f1_score: 0.8674 - val_loss: 0.2583 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9627 - val_f1_score: 0.8935 - lr: 0.0010
# Epoch 54/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2992 - accuracy: 0.8776 - precision: 0.8776 - recall: 0.8776 - auc: 0.9459 - f1_score: 0.8776
# Epoch 54: val_loss did not improve from 0.14314
# 71/71 [==============================] - 47s 651ms/step - loss: 0.2992 - accuracy: 0.8776 - precision: 0.8776 - recall: 0.8776 - auc: 0.9459 - f1_score: 0.8776 - val_loss: 0.1634 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9867 - val_f1_score: 0.9527 - lr: 0.0010
# Epoch 55/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.8944 - precision: 0.8944 - recall: 0.8944 - auc: 0.9542 - f1_score: 0.8944
# Epoch 55: val_loss did not improve from 0.14314
# 71/71 [==============================] - 46s 650ms/step - loss: 0.2733 - accuracy: 0.8944 - precision: 0.8944 - recall: 0.8944 - auc: 0.9542 - f1_score: 0.8944 - val_loss: 0.3876 - val_accuracy: 0.8373 - val_precision: 0.8373 - val_recall: 0.8373 - val_auc: 0.9094 - val_f1_score: 0.8373 - lr: 0.0010
# Epoch 56/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2829 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9513 - f1_score: 0.8842
# Epoch 56: val_loss did not improve from 0.14314
# 71/71 [==============================] - 46s 649ms/step - loss: 0.2829 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9513 - f1_score: 0.8842 - val_loss: 0.2363 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9738 - val_f1_score: 0.9172 - lr: 0.0010
# Epoch 57/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2849 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9504 - f1_score: 0.8842
# Epoch 57: val_loss did not improve from 0.14314
# 71/71 [==============================] - 46s 650ms/step - loss: 0.2849 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9504 - f1_score: 0.8842 - val_loss: 0.3378 - val_accuracy: 0.8462 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9308 - val_f1_score: 0.8462 - lr: 0.0010
# Epoch 58/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2609 - accuracy: 0.8975 - precision: 0.8975 - recall: 0.8975 - auc: 0.9577 - f1_score: 0.8975
# Epoch 58: val_loss did not improve from 0.14314
# 71/71 [==============================] - 47s 653ms/step - loss: 0.2609 - accuracy: 0.8975 - precision: 0.8975 - recall: 0.8975 - auc: 0.9577 - f1_score: 0.8975 - val_loss: 0.2155 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9715 - val_f1_score: 0.9260 - lr: 0.0010
# Epoch 59/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2685 - accuracy: 0.8869 - precision: 0.8869 - recall: 0.8869 - auc: 0.9560 - f1_score: 0.8869
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 59: val_loss did not improve from 0.14314
# 71/71 [==============================] - 46s 649ms/step - loss: 0.2685 - accuracy: 0.8869 - precision: 0.8869 - recall: 0.8869 - auc: 0.9560 - f1_score: 0.8869 - val_loss: 0.1453 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9927 - val_f1_score: 0.9556 - lr: 0.0010
# Epoch 60/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2307 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9680 - f1_score: 0.9094
# Epoch 60: val_loss did not improve from 0.14314
# 71/71 [==============================] - 47s 653ms/step - loss: 0.2307 - accuracy: 0.9094 - precision: 0.9094 - recall: 0.9094 - auc: 0.9680 - f1_score: 0.9094 - val_loss: 0.1520 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9915 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 61/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2050 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9753 - f1_score: 0.9160
# Epoch 61: val_loss improved from 0.14314 to 0.13453, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 655ms/step - loss: 0.2050 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9753 - f1_score: 0.9160 - val_loss: 0.1345 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9916 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 62/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2068 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9747 - f1_score: 0.9112
# Epoch 62: val_loss improved from 0.13453 to 0.12602, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 658ms/step - loss: 0.2068 - accuracy: 0.9112 - precision: 0.9112 - recall: 0.9112 - auc: 0.9747 - f1_score: 0.9112 - val_loss: 0.1260 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9932 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 63/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9764 - f1_score: 0.9160
# Epoch 63: val_loss did not improve from 0.12602
# 71/71 [==============================] - 46s 650ms/step - loss: 0.1991 - accuracy: 0.9160 - precision: 0.9160 - recall: 0.9160 - auc: 0.9764 - f1_score: 0.9160 - val_loss: 0.1287 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9911 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 64/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9764 - f1_score: 0.9187
# Epoch 64: val_loss did not improve from 0.12602
# 71/71 [==============================] - 47s 652ms/step - loss: 0.1988 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9764 - f1_score: 0.9187 - val_loss: 0.1396 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9900 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 65/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1800 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9803 - f1_score: 0.9311
# Epoch 65: val_loss improved from 0.12602 to 0.10752, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 657ms/step - loss: 0.1800 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9803 - f1_score: 0.9311 - val_loss: 0.1075 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9951 - val_f1_score: 0.9645 - lr: 1.0000e-04
# Epoch 66/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1854 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9793 - f1_score: 0.9213
# Epoch 66: val_loss did not improve from 0.10752
# 71/71 [==============================] - 47s 652ms/step - loss: 0.1854 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9793 - f1_score: 0.9213 - val_loss: 0.1755 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9820 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 67/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1818 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9800 - f1_score: 0.9280
# Epoch 67: val_loss did not improve from 0.10752
# 71/71 [==============================] - 46s 649ms/step - loss: 0.1818 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9800 - f1_score: 0.9280 - val_loss: 0.1160 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9925 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 68/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1715 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9823 - f1_score: 0.9302
# Epoch 68: val_loss did not improve from 0.10752
# 71/71 [==============================] - 47s 653ms/step - loss: 0.1715 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9823 - f1_score: 0.9302 - val_loss: 0.1249 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9896 - val_f1_score: 0.9793 - lr: 1.0000e-04
# Epoch 69/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1797 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9799 - f1_score: 0.9297
# Epoch 69: val_loss did not improve from 0.10752
# 71/71 [==============================] - 46s 648ms/step - loss: 0.1797 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9799 - f1_score: 0.9297 - val_loss: 0.1174 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9933 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 70/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1677 - accuracy: 0.9373 - precision: 0.9373 - recall: 0.9373 - auc: 0.9829 - f1_score: 0.9373
# Epoch 70: val_loss improved from 0.10752 to 0.09765, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 658ms/step - loss: 0.1677 - accuracy: 0.9373 - precision: 0.9373 - recall: 0.9373 - auc: 0.9829 - f1_score: 0.9373 - val_loss: 0.0977 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9955 - val_f1_score: 0.9734 - lr: 1.0000e-04
# Epoch 71/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1767 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9810 - f1_score: 0.9302
# Epoch 71: val_loss did not improve from 0.09765
# 71/71 [==============================] - 46s 649ms/step - loss: 0.1767 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9810 - f1_score: 0.9302 - val_loss: 0.1157 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9936 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 72/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1701 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9821 - f1_score: 0.9350
# Epoch 72: val_loss did not improve from 0.09765
# 71/71 [==============================] - 47s 653ms/step - loss: 0.1701 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9821 - f1_score: 0.9350 - val_loss: 0.1087 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9927 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 73/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9836 - f1_score: 0.9333
# Epoch 73: val_loss did not improve from 0.09765
# 71/71 [==============================] - 46s 649ms/step - loss: 0.1639 - accuracy: 0.9333 - precision: 0.9333 - recall: 0.9333 - auc: 0.9836 - f1_score: 0.9333 - val_loss: 0.1079 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9923 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 74/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9342 - precision: 0.9342 - recall: 0.9342 - auc: 0.9848 - f1_score: 0.9342
# Epoch 74: val_loss did not improve from 0.09765
# 71/71 [==============================] - 47s 653ms/step - loss: 0.1593 - accuracy: 0.9342 - precision: 0.9342 - recall: 0.9342 - auc: 0.9848 - f1_score: 0.9342 - val_loss: 0.1074 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9928 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 75/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1635 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9838 - f1_score: 0.9302
# Epoch 75: val_loss did not improve from 0.09765
# 71/71 [==============================] - 46s 650ms/step - loss: 0.1635 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9838 - f1_score: 0.9302 - val_loss: 0.1221 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9919 - val_f1_score: 0.9556 - lr: 1.0000e-04
# Epoch 76/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9828 - f1_score: 0.9337
# Epoch 76: val_loss did not improve from 0.09765
# 71/71 [==============================] - 47s 653ms/step - loss: 0.1683 - accuracy: 0.9337 - precision: 0.9337 - recall: 0.9337 - auc: 0.9828 - f1_score: 0.9337 - val_loss: 0.1147 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9925 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 77/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1607 - accuracy: 0.9377 - precision: 0.9377 - recall: 0.9377 - auc: 0.9836 - f1_score: 0.9377
# Epoch 77: val_loss improved from 0.09765 to 0.09558, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 657ms/step - loss: 0.1607 - accuracy: 0.9377 - precision: 0.9377 - recall: 0.9377 - auc: 0.9836 - f1_score: 0.9377 - val_loss: 0.0956 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9962 - val_f1_score: 0.9763 - lr: 1.0000e-04
# Epoch 78/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1603 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9845 - f1_score: 0.9368
# Epoch 78: val_loss improved from 0.09558 to 0.08382, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 659ms/step - loss: 0.1603 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9845 - f1_score: 0.9368 - val_loss: 0.0838 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9977 - val_f1_score: 0.9763 - lr: 1.0000e-04
# Epoch 79/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1570 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9847 - f1_score: 0.9368
# Epoch 79: val_loss did not improve from 0.08382
# 71/71 [==============================] - 46s 650ms/step - loss: 0.1570 - accuracy: 0.9368 - precision: 0.9368 - recall: 0.9368 - auc: 0.9847 - f1_score: 0.9368 - val_loss: 0.0973 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9953 - val_f1_score: 0.9763 - lr: 1.0000e-04
# Epoch 80/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1517 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9861 - f1_score: 0.9421
# Epoch 80: val_loss did not improve from 0.08382
# 71/71 [==============================] - 46s 651ms/step - loss: 0.1517 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9861 - f1_score: 0.9421 - val_loss: 0.1025 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9949 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 81/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1619 - accuracy: 0.9381 - precision: 0.9381 - recall: 0.9381 - auc: 0.9833 - f1_score: 0.9381
# Epoch 81: val_loss did not improve from 0.08382
# 71/71 [==============================] - 46s 650ms/step - loss: 0.1619 - accuracy: 0.9381 - precision: 0.9381 - recall: 0.9381 - auc: 0.9833 - f1_score: 0.9381 - val_loss: 0.1213 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9922 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 82/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9434 - precision: 0.9434 - recall: 0.9434 - auc: 0.9862 - f1_score: 0.9434
# Epoch 82: val_loss improved from 0.08382 to 0.08122, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 659ms/step - loss: 0.1490 - accuracy: 0.9434 - precision: 0.9434 - recall: 0.9434 - auc: 0.9862 - f1_score: 0.9434 - val_loss: 0.0812 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9970 - val_f1_score: 0.9763 - lr: 1.0000e-04
# Epoch 83/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1464 - accuracy: 0.9430 - precision: 0.9430 - recall: 0.9430 - auc: 0.9869 - f1_score: 0.9430
# Epoch 83: val_loss did not improve from 0.08122
# 71/71 [==============================] - 47s 651ms/step - loss: 0.1464 - accuracy: 0.9430 - precision: 0.9430 - recall: 0.9430 - auc: 0.9869 - f1_score: 0.9430 - val_loss: 0.1086 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9944 - val_f1_score: 0.9615 - lr: 1.0000e-04
# Epoch 84/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.9483 - precision: 0.9483 - recall: 0.9483 - auc: 0.9880 - f1_score: 0.9483
# Epoch 84: val_loss did not improve from 0.08122
# 71/71 [==============================] - 46s 650ms/step - loss: 0.1383 - accuracy: 0.9483 - precision: 0.9483 - recall: 0.9483 - auc: 0.9880 - f1_score: 0.9483 - val_loss: 0.0909 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9956 - val_f1_score: 0.9704 - lr: 1.0000e-04
# Epoch 85/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1455 - accuracy: 0.9452 - precision: 0.9452 - recall: 0.9452 - auc: 0.9865 - f1_score: 0.9452
# Epoch 85: val_loss did not improve from 0.08122
# 71/71 [==============================] - 46s 651ms/step - loss: 0.1455 - accuracy: 0.9452 - precision: 0.9452 - recall: 0.9452 - auc: 0.9865 - f1_score: 0.9452 - val_loss: 0.1526 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9865 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 86/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9456 - precision: 0.9456 - recall: 0.9456 - auc: 0.9875 - f1_score: 0.9456
# Epoch 86: val_loss did not improve from 0.08122
# 71/71 [==============================] - 47s 651ms/step - loss: 0.1397 - accuracy: 0.9456 - precision: 0.9456 - recall: 0.9456 - auc: 0.9875 - f1_score: 0.9456 - val_loss: 0.1059 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9936 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 87/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1501 - accuracy: 0.9434 - precision: 0.9434 - recall: 0.9434 - auc: 0.9858 - f1_score: 0.9434
# Epoch 87: val_loss did not improve from 0.08122
# 71/71 [==============================] - 47s 650ms/step - loss: 0.1501 - accuracy: 0.9434 - precision: 0.9434 - recall: 0.9434 - auc: 0.9858 - f1_score: 0.9434 - val_loss: 0.1100 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9942 - val_f1_score: 0.9497 - lr: 1.0000e-04
# Epoch 88/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1303 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9896 - f1_score: 0.9474
# Epoch 88: val_loss did not improve from 0.08122
# 71/71 [==============================] - 47s 653ms/step - loss: 0.1303 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9896 - f1_score: 0.9474 - val_loss: 0.1431 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9877 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 89/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9889 - f1_score: 0.9505
# Epoch 89: val_loss did not improve from 0.08122
# 71/71 [==============================] - 47s 650ms/step - loss: 0.1320 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9889 - f1_score: 0.9505 - val_loss: 0.0858 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9956 - val_f1_score: 0.9763 - lr: 1.0000e-04
# Epoch 90/150
# ...
# Epoch 121/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1072 - accuracy: 0.9563 - precision: 0.9563 - recall: 0.9563 - auc: 0.9931 - f1_score: 0.9563
# Epoch 121: val_loss did not improve from 0.05374
# 71/71 [==============================] - 46s 650ms/step - loss: 0.1072 - accuracy: 0.9563 - precision: 0.9563 - recall: 0.9563 - auc: 0.9931 - f1_score: 0.9563 - val_loss: 0.0684 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9980 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 122/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9947 - f1_score: 0.9642
# Epoch 122: val_loss did not improve from 0.05374
# 71/71 [==============================] - 47s 653ms/step - loss: 0.0919 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9947 - f1_score: 0.9642 - val_loss: 0.0786 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9964 - val_f1_score: 0.9734 - lr: 1.0000e-05
# Epoch 123/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9585 - precision: 0.9585 - recall: 0.9585 - auc: 0.9948 - f1_score: 0.9585
# Epoch 123: val_loss did not improve from 0.05374
# 71/71 [==============================] - 47s 651ms/step - loss: 0.0932 - accuracy: 0.9585 - precision: 0.9585 - recall: 0.9585 - auc: 0.9948 - f1_score: 0.9585 - val_loss: 0.0763 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9968 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 124/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0852 - accuracy: 0.9669 - precision: 0.9669 - recall: 0.9669 - auc: 0.9954 - f1_score: 0.9669
# Epoch 124: val_loss did not improve from 0.05374
# 71/71 [==============================] - 47s 652ms/step - loss: 0.0852 - accuracy: 0.9669 - precision: 0.9669 - recall: 0.9669 - auc: 0.9954 - f1_score: 0.9669 - val_loss: 0.0602 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9985 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 125/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9956 - f1_score: 0.9642
# Epoch 125: val_loss did not improve from 0.05374
# 71/71 [==============================] - 46s 650ms/step - loss: 0.0865 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9956 - f1_score: 0.9642 - val_loss: 0.0900 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9951 - val_f1_score: 0.9734 - lr: 1.0000e-05
# Epoch 126/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9602 - precision: 0.9602 - recall: 0.9602 - auc: 0.9938 - f1_score: 0.9602
# Epoch 126: val_loss did not improve from 0.05374
# 71/71 [==============================] - 46s 649ms/step - loss: 0.0991 - accuracy: 0.9602 - precision: 0.9602 - recall: 0.9602 - auc: 0.9938 - f1_score: 0.9602 - val_loss: 0.0707 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9974 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 127/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0936 - accuracy: 0.9611 - precision: 0.9611 - recall: 0.9611 - auc: 0.9946 - f1_score: 0.9611
# Epoch 127: val_loss did not improve from 0.05374
# 71/71 [==============================] - 46s 649ms/step - loss: 0.0936 - accuracy: 0.9611 - precision: 0.9611 - recall: 0.9611 - auc: 0.9946 - f1_score: 0.9611 - val_loss: 0.0830 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9962 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 128/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9633 - precision: 0.9633 - recall: 0.9633 - auc: 0.9952 - f1_score: 0.9633
# Epoch 128: val_loss did not improve from 0.05374
# 71/71 [==============================] - 47s 652ms/step - loss: 0.0885 - accuracy: 0.9633 - precision: 0.9633 - recall: 0.9633 - auc: 0.9952 - f1_score: 0.9633 - val_loss: 0.0619 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9972 - val_f1_score: 0.9852 - lr: 1.0000e-05
# Epoch 129/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0853 - accuracy: 0.9682 - precision: 0.9682 - recall: 0.9682 - auc: 0.9956 - f1_score: 0.9682
# Epoch 129: val_loss did not improve from 0.05374
# 71/71 [==============================] - 46s 649ms/step - loss: 0.0853 - accuracy: 0.9682 - precision: 0.9682 - recall: 0.9682 - auc: 0.9956 - f1_score: 0.9682 - val_loss: 0.0726 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9972 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 130/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 0.9646 - precision: 0.9646 - recall: 0.9646 - auc: 0.9944 - f1_score: 0.9646
# Epoch 130: val_loss did not improve from 0.05374
# 71/71 [==============================] - 47s 653ms/step - loss: 0.0943 - accuracy: 0.9646 - precision: 0.9646 - recall: 0.9646 - auc: 0.9944 - f1_score: 0.9646 - val_loss: 0.0832 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9959 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 131/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0857 - accuracy: 0.9682 - precision: 0.9682 - recall: 0.9682 - auc: 0.9952 - f1_score: 0.9682
# Epoch 131: val_loss improved from 0.05374 to 0.04758, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 657ms/step - loss: 0.0857 - accuracy: 0.9682 - precision: 0.9682 - recall: 0.9682 - auc: 0.9952 - f1_score: 0.9682 - val_loss: 0.0476 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9993 - val_f1_score: 0.9911 - lr: 1.0000e-05
# Epoch 132/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0899 - accuracy: 0.9616 - precision: 0.9616 - recall: 0.9616 - auc: 0.9950 - f1_score: 0.9616
# Epoch 132: val_loss did not improve from 0.04758
# 71/71 [==============================] - 47s 653ms/step - loss: 0.0899 - accuracy: 0.9616 - precision: 0.9616 - recall: 0.9616 - auc: 0.9950 - f1_score: 0.9616 - val_loss: 0.0728 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9969 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 133/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0904 - accuracy: 0.9620 - precision: 0.9620 - recall: 0.9620 - auc: 0.9949 - f1_score: 0.9620
# Epoch 133: val_loss did not improve from 0.04758
# 71/71 [==============================] - 46s 651ms/step - loss: 0.0904 - accuracy: 0.9620 - precision: 0.9620 - recall: 0.9620 - auc: 0.9949 - f1_score: 0.9620 - val_loss: 0.0869 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9956 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 134/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9942 - f1_score: 0.9642
# Epoch 134: val_loss did not improve from 0.04758
# 71/71 [==============================] - 47s 655ms/step - loss: 0.0945 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9942 - f1_score: 0.9642 - val_loss: 0.0565 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9987 - val_f1_score: 0.9822 - lr: 1.0000e-05
# Epoch 135/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1031 - accuracy: 0.9593 - precision: 0.9593 - recall: 0.9593 - auc: 0.9932 - f1_score: 0.9593
# Epoch 135: val_loss did not improve from 0.04758
# 71/71 [==============================] - 46s 650ms/step - loss: 0.1031 - accuracy: 0.9593 - precision: 0.9593 - recall: 0.9593 - auc: 0.9932 - f1_score: 0.9593 - val_loss: 0.0610 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9984 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 136/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0952 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - auc: 0.9945 - f1_score: 0.9629
# Epoch 136: val_loss did not improve from 0.04758
# 71/71 [==============================] - 46s 651ms/step - loss: 0.0952 - accuracy: 0.9629 - precision: 0.9629 - recall: 0.9629 - auc: 0.9945 - f1_score: 0.9629 - val_loss: 0.0692 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9976 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 137/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1002 - accuracy: 0.9589 - precision: 0.9589 - recall: 0.9589 - auc: 0.9941 - f1_score: 0.9589
# Epoch 137: val_loss did not improve from 0.04758
# 71/71 [==============================] - 47s 651ms/step - loss: 0.1002 - accuracy: 0.9589 - precision: 0.9589 - recall: 0.9589 - auc: 0.9941 - f1_score: 0.9589 - val_loss: 0.0613 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9983 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 138/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0863 - accuracy: 0.9669 - precision: 0.9669 - recall: 0.9669 - auc: 0.9956 - f1_score: 0.9669
# Epoch 138: val_loss did not improve from 0.04758
# 71/71 [==============================] - 47s 654ms/step - loss: 0.0863 - accuracy: 0.9669 - precision: 0.9669 - recall: 0.9669 - auc: 0.9956 - f1_score: 0.9669 - val_loss: 0.0636 - val_accuracy: 0.9911 - val_precision: 0.9911 - val_recall: 0.9911 - val_auc: 0.9975 - val_f1_score: 0.9911 - lr: 1.0000e-05
# Epoch 139/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0825 - accuracy: 0.9660 - precision: 0.9660 - recall: 0.9660 - auc: 0.9957 - f1_score: 0.9660
# Epoch 139: val_loss did not improve from 0.04758
# 71/71 [==============================] - 46s 650ms/step - loss: 0.0825 - accuracy: 0.9660 - precision: 0.9660 - recall: 0.9660 - auc: 0.9957 - f1_score: 0.9660 - val_loss: 0.0808 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9929 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 140/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9624 - precision: 0.9624 - recall: 0.9624 - auc: 0.9946 - f1_score: 0.9624
# Epoch 140: val_loss did not improve from 0.04758
# 71/71 [==============================] - 47s 654ms/step - loss: 0.0921 - accuracy: 0.9624 - precision: 0.9624 - recall: 0.9624 - auc: 0.9946 - f1_score: 0.9624 - val_loss: 0.0751 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9967 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 141/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0812 - accuracy: 0.9686 - precision: 0.9686 - recall: 0.9686 - auc: 0.9958 - f1_score: 0.9686
# Epoch 141: val_loss did not improve from 0.04758
# 71/71 [==============================] - 47s 651ms/step - loss: 0.0812 - accuracy: 0.9686 - precision: 0.9686 - recall: 0.9686 - auc: 0.9958 - f1_score: 0.9686 - val_loss: 0.0711 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9969 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 142/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9571 - precision: 0.9571 - recall: 0.9571 - auc: 0.9933 - f1_score: 0.9571
# Epoch 142: val_loss did not improve from 0.04758
# 71/71 [==============================] - 47s 653ms/step - loss: 0.0988 - accuracy: 0.9571 - precision: 0.9571 - recall: 0.9571 - auc: 0.9933 - f1_score: 0.9571 - val_loss: 0.1012 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9932 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 143/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9953 - f1_score: 0.9642
# Epoch 143: val_loss did not improve from 0.04758
# 71/71 [==============================] - 46s 652ms/step - loss: 0.0884 - accuracy: 0.9642 - precision: 0.9642 - recall: 0.9642 - auc: 0.9953 - f1_score: 0.9642 - val_loss: 0.0661 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9976 - val_f1_score: 0.9734 - lr: 1.0000e-05
# Epoch 144/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0921 - accuracy: 0.9669 - precision: 0.9669 - recall: 0.9669 - auc: 0.9941 - f1_score: 0.9669
# Epoch 144: val_loss did not improve from 0.04758
# 71/71 [==============================] - 47s 654ms/step - loss: 0.0921 - accuracy: 0.9669 - precision: 0.9669 - recall: 0.9669 - auc: 0.9941 - f1_score: 0.9669 - val_loss: 0.0813 - val_accuracy: 0.9793 - val_precision: 0.9793 - val_recall: 0.9793 - val_auc: 0.9968 - val_f1_score: 0.9793 - lr: 1.0000e-05
# Epoch 145/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.9686 - precision: 0.9686 - recall: 0.9686 - auc: 0.9961 - f1_score: 0.9686
# Epoch 145: val_loss did not improve from 0.04758
# 71/71 [==============================] - 47s 651ms/step - loss: 0.0819 - accuracy: 0.9686 - precision: 0.9686 - recall: 0.9686 - auc: 0.9961 - f1_score: 0.9686 - val_loss: 0.0672 - val_accuracy: 0.9822 - val_precision: 0.9822 - val_recall: 0.9822 - val_auc: 0.9970 - val_f1_score: 0.9822 - lr: 1.0000e-05
# Epoch 146/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0856 - accuracy: 0.9664 - precision: 0.9664 - recall: 0.9664 - auc: 0.9956 - f1_score: 0.9664
# Epoch 146: val_loss did not improve from 0.04758
# 71/71 [==============================] - 47s 655ms/step - loss: 0.0856 - accuracy: 0.9664 - precision: 0.9664 - recall: 0.9664 - auc: 0.9956 - f1_score: 0.9664 - val_loss: 0.0711 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9972 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 147/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0914 - accuracy: 0.9633 - precision: 0.9633 - recall: 0.9633 - auc: 0.9946 - f1_score: 0.9633
# Epoch 147: val_loss improved from 0.04758 to 0.04547, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version5-DIR.h5
# 71/71 [==============================] - 47s 656ms/step - loss: 0.0914 - accuracy: 0.9633 - precision: 0.9633 - recall: 0.9633 - auc: 0.9946 - f1_score: 0.9633 - val_loss: 0.0455 - val_accuracy: 0.9882 - val_precision: 0.9882 - val_recall: 0.9882 - val_auc: 0.9994 - val_f1_score: 0.9882 - lr: 1.0000e-05
# Epoch 148/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9646 - precision: 0.9646 - recall: 0.9646 - auc: 0.9950 - f1_score: 0.9646
# Epoch 148: val_loss did not improve from 0.04547
# 71/71 [==============================] - 46s 649ms/step - loss: 0.0884 - accuracy: 0.9646 - precision: 0.9646 - recall: 0.9646 - auc: 0.9950 - f1_score: 0.9646 - val_loss: 0.1049 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9930 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 149/150
# 71/71 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9624 - precision: 0.9624 - recall: 0.9624 - auc: 0.9936 - f1_score: 0.9624
# Epoch 149: val_loss did not improve from 0.04547
# 71/71 [==============================] - 46s 649ms/step - loss: 0.0946 - accuracy: 0.9624 - precision: 0.9624 - recall: 0.9624 - auc: 0.9936 - f1_score: 0.9624 - val_loss: 0.0829 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9960 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 150/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1005 - accuracy: 0.9567 - precision: 0.9567 - recall: 0.9567 - auc: 0.9940 - f1_score: 0.9567
# Epoch 150: val_loss did not improve from 0.04547
# 71/71 [==============================] - 47s 655ms/step - loss: 0.1005 - accuracy: 0.9567 - precision: 0.9567 - recall: 0.9567 - auc: 0.9940 - f1_score: 0.9567 - val_loss: 0.0570 - val_accuracy: 0.9852 - val_precision: 0.9852 - val_recall: 0.9852 - val_auc: 0.9984 - val_f1_score: 0.9852 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = DIR.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 2s 108ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.929304743339831
# F1-Score for each class: [0.9005848  0.95802469]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9651741293532339
# specificity: 0.8850574712643678

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  DIR.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 1s 108ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = DIR.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 2s 160ms/step - loss: 0.1744 - accuracy: 0.9400 - precision: 0.9400 - recall: 0.9400 - auc: 0.9821 - f1_score: 0.9400
# Test loss: 0.17441804707050323
# Test accuracy: 0.9399999976158142
# Test precision: 0.9399999976158142
# Test recall: 0.9399999976158142
# Test AUC: 0.982127845287323
# Test F1 Score: 0.9399999976158142

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = DIR.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 1s 107ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90        87
#            1       0.95      0.97      0.96       201
#
#     accuracy                           0.94       288
#    macro avg       0.93      0.93      0.93       288
# weighted avg       0.94      0.94      0.94       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

# del DIR


from numba import cuda

cuda.select_device(0)
cuda.close()
