# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.
# Out:
# 2024-03-06 13:51:03.882589: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 300 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

# def attention_block_2(x):
#     # 使用卷积层创建一个更复杂的注意力机制
#     attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
#     attention_network = Activation('relu')(attention_network)
#     attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
#     attention_output = Activation('sigmoid')(attention_network)
#     scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

#     return scaled_feature

def attention_block_2(x):
    # 直接使用单个卷积层生成注意力图
    attention_network = Conv2D(1, (1, 1), padding='same')(x)  # 使用1x1卷积生成注意力图
    attention_output = Activation('sigmoid')(attention_network)  # 使用sigmoid激活函数获取注意力权重
    
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征
    
    return scaled_feature


def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(128 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    x = attention_block_2(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    x = attention_block_2(x)
    
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    x = attention_block_2(x)
    

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    a = attention_block_2(x)
    
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    # a = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(96// nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(128// nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    c = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = attention_block_2(x)

    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    # c = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b, c])
    
    x = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    shortcut = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    b = Conv2D(32 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    x = Concatenate(axis=-1)([a, b])
    
    x = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    ##加入shortcut的projection mapping 保证通道数一致
    shortcut = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])
    
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    ##加入shortcut 的projection 映射
    shortcut = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 5
num_B_blocks = 8
num_C_blocks = 5

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.3)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax')(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# 2024-03-06 13:51:07.370842: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-06 13:51:07.894485: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22309 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:04:00.0, compute capability: 8.6
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 224, 224, 16  448         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 224, 224, 1)  17          ['conv2d[0][0]']
#
#  activation (Activation)        (None, 224, 224, 1)  0           ['conv2d_1[0][0]']
#
#  multiply (Multiply)            (None, 224, 224, 16  0           ['conv2d[0][0]',
#                                 )                                 'activation[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 224, 224, 4)  580         ['multiply[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 224, 224, 1)  5           ['conv2d_2[0][0]']
#
#  activation_1 (Activation)      (None, 224, 224, 1)  0           ['conv2d_3[0][0]']
#
#  multiply_1 (Multiply)          (None, 224, 224, 4)  0           ['conv2d_2[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 224, 224, 4)  148         ['multiply_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 224, 224, 1)  5           ['conv2d_4[0][0]']
#
#  activation_2 (Activation)      (None, 224, 224, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_2 (Multiply)          (None, 224, 224, 4)  0           ['conv2d_4[0][0]',
#                                                                   'activation_2[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 222, 222, 4)  0           ['multiply_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 222, 222, 12  444         ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 222, 222, 16  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_6[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 222, 222, 1)  17          ['concatenate[0][0]']
#
#  activation_4 (Activation)      (None, 222, 222, 1)  0           ['conv2d_11[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 222, 222, 1)  17          ['concatenate[0][0]']
#
#  multiply_4 (Multiply)          (None, 222, 222, 16  0           ['concatenate[0][0]',
#                                 )                                 'activation_4[0][0]']
#
#  activation_3 (Activation)      (None, 222, 222, 1)  0           ['conv2d_8[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 222, 222, 8)  904         ['multiply_4[0][0]']
#
#  multiply_3 (Multiply)          (None, 222, 222, 16  0           ['concatenate[0][0]',
#                                 )                                 'activation_3[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 222, 222, 8)  456         ['conv2d_12[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 220, 220, 12  1740        ['multiply_3[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 220, 220, 12  876         ['conv2d_13[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 220, 220, 24  0           ['conv2d_9[0][0]',
#                                 )                                 'conv2d_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 218, 218, 16  3472        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 218, 218, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 218, 218, 40  0           ['conv2d_15[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_5 (Activation)      (None, 218, 218, 40  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 218, 218, 4)  164         ['activation_5[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 218, 218, 4)  164         ['activation_5[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 218, 218, 16  656         ['activation_5[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 218, 218, 4)  40         ['conv2d_17[0][0]']
#  v2D)
#
#  conv2d_19 (Conv2D)             (None, 218, 218, 8)  296         ['conv2d_18[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 218, 218, 28  0           ['conv2d_16[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 218, 218, 4)  116         ['concatenate_3[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 218, 218, 4)  20          ['conv2d_20[0][0]']
#
#  add (Add)                      (None, 218, 218, 4)  0           ['conv2d_21[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  activation_6 (Activation)      (None, 218, 218, 4)  0           ['add[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 218, 218, 4)  20          ['activation_6[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 218, 218, 4)  20          ['activation_6[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 218, 218, 16  80          ['activation_6[0][0]']
#                                 )
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 218, 218, 4)  40         ['conv2d_23[0][0]']
#  onv2D)
#
#  conv2d_25 (Conv2D)             (None, 218, 218, 8)  296         ['conv2d_24[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 218, 218, 28  0           ['conv2d_22[0][0]',
#                                 )                                 'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 218, 218, 4)  116         ['concatenate_4[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 218, 218, 4)  20          ['conv2d_26[0][0]']
#
#  add_1 (Add)                    (None, 218, 218, 4)  0           ['conv2d_27[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  activation_7 (Activation)      (None, 218, 218, 4)  0           ['add_1[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 218, 218, 4)  20          ['activation_7[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 218, 218, 4)  20          ['activation_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 218, 218, 16  80          ['activation_7[0][0]']
#                                 )
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 218, 218, 4)  40         ['conv2d_29[0][0]']
#  onv2D)
#
#  conv2d_31 (Conv2D)             (None, 218, 218, 8)  296         ['conv2d_30[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 218, 218, 28  0           ['conv2d_28[0][0]',
#                                 )                                 'depthwise_conv2d_2[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 218, 218, 4)  116         ['concatenate_5[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 218, 218, 4)  20          ['conv2d_32[0][0]']
#
#  add_2 (Add)                    (None, 218, 218, 4)  0           ['conv2d_33[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  activation_8 (Activation)      (None, 218, 218, 4)  0           ['add_2[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 218, 218, 4)  20          ['activation_8[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 218, 218, 4)  20          ['activation_8[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 218, 218, 16  80          ['activation_8[0][0]']
#                                 )
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 218, 218, 4)  40         ['conv2d_35[0][0]']
#  onv2D)
#
#  conv2d_37 (Conv2D)             (None, 218, 218, 8)  296         ['conv2d_36[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 218, 218, 28  0           ['conv2d_34[0][0]',
#                                 )                                 'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 218, 218, 4)  116         ['concatenate_6[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 218, 218, 4)  20          ['conv2d_38[0][0]']
#
#  add_3 (Add)                    (None, 218, 218, 4)  0           ['conv2d_39[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  activation_9 (Activation)      (None, 218, 218, 4)  0           ['add_3[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 218, 218, 4)  20          ['activation_9[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 218, 218, 4)  20          ['activation_9[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 218, 218, 16  80          ['activation_9[0][0]']
#                                 )
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 218, 218, 4)  40         ['conv2d_41[0][0]']
#  onv2D)
#
#  conv2d_43 (Conv2D)             (None, 218, 218, 8)  296         ['conv2d_42[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 218, 218, 28  0           ['conv2d_40[0][0]',
#                                 )                                 'depthwise_conv2d_4[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 218, 218, 4)  116         ['concatenate_7[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 218, 218, 4)  20          ['conv2d_44[0][0]']
#
#  add_4 (Add)                    (None, 218, 218, 4)  0           ['conv2d_45[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  activation_10 (Activation)     (None, 218, 218, 4)  0           ['add_4[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 218, 218, 32  160         ['activation_10[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 218, 218, 32  9248        ['conv2d_47[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 108, 108, 4)  0          ['activation_10[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 108, 108, 48  1776        ['activation_10[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 108, 108, 48  13872       ['conv2d_48[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 108, 108, 10  0           ['max_pooling2d_2[0][0]',
#                                 0)                                'conv2d_46[0][0]',
#                                                                   'conv2d_49[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 108, 108, 8)  808         ['concatenate_8[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 108, 108, 8)  456         ['conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 108, 108, 4)  228         ['conv2d_52[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 108, 108, 16  1616        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 108, 108, 8)  40          ['conv2d_53[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 108, 108, 24  0           ['conv2d_50[0][0]',
#                                 )                                 'conv2d_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 108, 108, 16  400         ['concatenate_9[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 108, 108, 16  272         ['conv2d_55[0][0]']
#                                 )
#
#  add_5 (Add)                    (None, 108, 108, 16  0           ['conv2d_56[0][0]',
#                                 )                                 'conv2d_55[0][0]']
#
#  activation_11 (Activation)     (None, 108, 108, 16  0           ['add_5[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 108, 108, 8)  136         ['activation_11[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 108, 108, 8)  456         ['conv2d_58[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 108, 108, 4)  228         ['conv2d_59[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 108, 108, 16  272         ['activation_11[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 108, 108, 8)  40          ['conv2d_60[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 108, 108, 24  0           ['conv2d_57[0][0]',
#                                 )                                 'conv2d_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 108, 108, 16  400         ['concatenate_10[0][0]']
#                                 )
#
#  conv2d_63 (Conv2D)             (None, 108, 108, 16  272         ['conv2d_62[0][0]']
#                                 )
#
#  add_6 (Add)                    (None, 108, 108, 16  0           ['conv2d_63[0][0]',
#                                 )                                 'conv2d_62[0][0]']
#
#  activation_12 (Activation)     (None, 108, 108, 16  0           ['add_6[0][0]']
#                                 )
#
#  conv2d_65 (Conv2D)             (None, 108, 108, 8)  136         ['activation_12[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 108, 108, 8)  456         ['conv2d_65[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 108, 108, 4)  228         ['conv2d_66[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 108, 108, 16  272         ['activation_12[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 108, 108, 8)  40          ['conv2d_67[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 108, 108, 24  0           ['conv2d_64[0][0]',
#                                 )                                 'conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 108, 108, 16  400         ['concatenate_11[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 108, 108, 16  272         ['conv2d_69[0][0]']
#                                 )
#
#  add_7 (Add)                    (None, 108, 108, 16  0           ['conv2d_70[0][0]',
#                                 )                                 'conv2d_69[0][0]']
#
#  activation_13 (Activation)     (None, 108, 108, 16  0           ['add_7[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 108, 108, 8)  136         ['activation_13[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 108, 108, 8)  456         ['conv2d_72[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 108, 108, 4)  228         ['conv2d_73[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 108, 108, 16  272         ['activation_13[0][0]']
#                                 )
#
#  conv2d_75 (Conv2D)             (None, 108, 108, 8)  40          ['conv2d_74[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 108, 108, 24  0           ['conv2d_71[0][0]',
#                                 )                                 'conv2d_75[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 108, 108, 16  400         ['concatenate_12[0][0]']
#                                 )
#
#  conv2d_77 (Conv2D)             (None, 108, 108, 16  272         ['conv2d_76[0][0]']
#                                 )
#
#  add_8 (Add)                    (None, 108, 108, 16  0           ['conv2d_77[0][0]',
#                                 )                                 'conv2d_76[0][0]']
#
#  activation_14 (Activation)     (None, 108, 108, 16  0           ['add_8[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 108, 108, 8)  136         ['activation_14[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 108, 108, 8)  456         ['conv2d_79[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 108, 108, 4)  228         ['conv2d_80[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 108, 108, 16  272         ['activation_14[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 108, 108, 8)  40          ['conv2d_81[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 108, 108, 24  0           ['conv2d_78[0][0]',
#                                 )                                 'conv2d_82[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 108, 108, 16  400         ['concatenate_13[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 108, 108, 16  272         ['conv2d_83[0][0]']
#                                 )
#
#  add_9 (Add)                    (None, 108, 108, 16  0           ['conv2d_84[0][0]',
#                                 )                                 'conv2d_83[0][0]']
#
#  activation_15 (Activation)     (None, 108, 108, 16  0           ['add_9[0][0]']
#                                 )
#
#  conv2d_86 (Conv2D)             (None, 108, 108, 8)  136         ['activation_15[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 108, 108, 8)  456         ['conv2d_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 108, 108, 4)  228         ['conv2d_87[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 108, 108, 16  272         ['activation_15[0][0]']
#                                 )
#
#  conv2d_89 (Conv2D)             (None, 108, 108, 8)  40          ['conv2d_88[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 108, 108, 24  0           ['conv2d_85[0][0]',
#                                 )                                 'conv2d_89[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 108, 108, 16  400         ['concatenate_14[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 108, 108, 16  272         ['conv2d_90[0][0]']
#                                 )
#
#  add_10 (Add)                   (None, 108, 108, 16  0           ['conv2d_91[0][0]',
#                                 )                                 'conv2d_90[0][0]']
#
#  activation_16 (Activation)     (None, 108, 108, 16  0           ['add_10[0][0]']
#                                 )
#
#  conv2d_93 (Conv2D)             (None, 108, 108, 8)  136         ['activation_16[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 108, 108, 8)  456         ['conv2d_93[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 108, 108, 4)  228         ['conv2d_94[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 108, 108, 16  272         ['activation_16[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 108, 108, 8)  40          ['conv2d_95[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 108, 108, 24  0           ['conv2d_92[0][0]',
#                                 )                                 'conv2d_96[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 108, 108, 16  400         ['concatenate_15[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 108, 108, 16  272         ['conv2d_97[0][0]']
#                                 )
#
#  add_11 (Add)                   (None, 108, 108, 16  0           ['conv2d_98[0][0]',
#                                 )                                 'conv2d_97[0][0]']
#
#  activation_17 (Activation)     (None, 108, 108, 16  0           ['add_11[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 108, 108, 8)  136         ['activation_17[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 108, 108, 8)  456         ['conv2d_100[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 108, 108, 4)  228         ['conv2d_101[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 108, 108, 16  272         ['activation_17[0][0]']
#                                 )
#
#  conv2d_103 (Conv2D)            (None, 108, 108, 8)  40          ['conv2d_102[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 108, 108, 24  0           ['conv2d_99[0][0]',
#                                 )                                 'conv2d_103[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 108, 108, 16  400         ['concatenate_16[0][0]']
#                                 )
#
#  conv2d_105 (Conv2D)            (None, 108, 108, 16  272         ['conv2d_104[0][0]']
#                                 )
#
#  add_12 (Add)                   (None, 108, 108, 16  0           ['conv2d_105[0][0]',
#                                 )                                 'conv2d_104[0][0]']
#
#  activation_18 (Activation)     (None, 108, 108, 16  0           ['add_12[0][0]']
#                                 )
#
#  conv2d_110 (Conv2D)            (None, 108, 108, 32  544         ['activation_18[0][0]']
#                                 )
#
#  conv2d_106 (Conv2D)            (None, 108, 108, 32  544         ['activation_18[0][0]']
#                                 )
#
#  conv2d_108 (Conv2D)            (None, 108, 108, 32  544         ['activation_18[0][0]']
#                                 )
#
#  conv2d_111 (Conv2D)            (None, 108, 108, 36  10404       ['conv2d_110[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 53, 53, 16)  0           ['activation_18[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 53, 53, 36)   10404       ['conv2d_106[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 53, 53, 36)   10404       ['conv2d_108[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 53, 53, 40)   13000       ['conv2d_111[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 53, 53, 128)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_107[0][0]',
#                                                                   'conv2d_109[0][0]',
#                                                                   'conv2d_112[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 53, 53, 16)   2064        ['concatenate_17[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 53, 53, 4)    68          ['conv2d_114[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 53, 53, 16)   2064        ['concatenate_17[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 53, 53, 4)    20          ['conv2d_115[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 53, 53, 20)   0           ['conv2d_113[0][0]',
#                                                                   'conv2d_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 53, 53, 256)  5376        ['concatenate_18[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 53, 53, 256)  65792       ['conv2d_117[0][0]']
#
#  add_13 (Add)                   (None, 53, 53, 256)  0           ['conv2d_118[0][0]',
#                                                                   'conv2d_117[0][0]']
#
#  activation_19 (Activation)     (None, 53, 53, 256)  0           ['add_13[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 53, 53, 16)   4112        ['activation_19[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 53, 53, 4)    68          ['conv2d_120[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 53, 53, 16)   4112        ['activation_19[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 53, 53, 4)    20          ['conv2d_121[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 53, 53, 20)   0           ['conv2d_119[0][0]',
#                                                                   'conv2d_122[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 53, 53, 256)  5376        ['concatenate_19[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 53, 53, 256)  65792       ['conv2d_123[0][0]']
#
#  add_14 (Add)                   (None, 53, 53, 256)  0           ['conv2d_124[0][0]',
#                                                                   'conv2d_123[0][0]']
#
#  activation_20 (Activation)     (None, 53, 53, 256)  0           ['add_14[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 53, 53, 16)   4112        ['activation_20[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 53, 53, 4)    68          ['conv2d_126[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 53, 53, 16)   4112        ['activation_20[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 53, 53, 4)    20          ['conv2d_127[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 53, 53, 20)   0           ['conv2d_125[0][0]',
#                                                                   'conv2d_128[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 53, 53, 256)  5376        ['concatenate_20[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 53, 53, 256)  65792       ['conv2d_129[0][0]']
#
#  add_15 (Add)                   (None, 53, 53, 256)  0           ['conv2d_130[0][0]',
#                                                                   'conv2d_129[0][0]']
#
#  activation_21 (Activation)     (None, 53, 53, 256)  0           ['add_15[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 53, 53, 16)   4112        ['activation_21[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 53, 53, 4)    68          ['conv2d_132[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 53, 53, 16)   4112        ['activation_21[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 53, 53, 4)    20          ['conv2d_133[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 53, 53, 20)   0           ['conv2d_131[0][0]',
#                                                                   'conv2d_134[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 53, 53, 256)  5376        ['concatenate_21[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 53, 53, 256)  65792       ['conv2d_135[0][0]']
#
#  add_16 (Add)                   (None, 53, 53, 256)  0           ['conv2d_136[0][0]',
#                                                                   'conv2d_135[0][0]']
#
#  activation_22 (Activation)     (None, 53, 53, 256)  0           ['add_16[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 53, 53, 16)   4112        ['activation_22[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 53, 53, 4)    68          ['conv2d_138[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 53, 53, 16)   4112        ['activation_22[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 53, 53, 4)    20          ['conv2d_139[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 53, 53, 20)   0           ['conv2d_137[0][0]',
#                                                                   'conv2d_140[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 53, 53, 256)  5376        ['concatenate_22[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 53, 53, 256)  65792       ['conv2d_141[0][0]']
#
#  add_17 (Add)                   (None, 53, 53, 256)  0           ['conv2d_142[0][0]',
#                                                                   'conv2d_141[0][0]']
#
#  activation_23 (Activation)     (None, 53, 53, 256)  0           ['add_17[0][0]']
#
#  dropout (Dropout)              (None, 53, 53, 256)  0           ['activation_23[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 494,119
# Trainable params: 494,119
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(), 
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version4-DIR"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)



lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Version4-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = DIR.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)
# Out:
# Epoch 1/150
# 2024-03-06 13:51:17.727529: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-06 13:51:19.490687: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 0.8432 - accuracy: 0.4958 - precision: 0.4958 - recall: 0.4958 - auc: 0.4972 - f1_score: 0.4958
# Epoch 1: val_loss improved from inf to 0.69320, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version4-DIR.h5
# 71/71 [==============================] - 49s 544ms/step - loss: 0.8432 - accuracy: 0.4958 - precision: 0.4958 - recall: 0.4958 - auc: 0.4972 - f1_score: 0.4958 - val_loss: 0.6932 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.5000 - val_f1_score: 0.5000 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.6940 - accuracy: 0.4949 - precision: 0.4949 - recall: 0.4949 - auc: 0.4883 - f1_score: 0.4949

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = DIR.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  DIR.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = DIR.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = DIR.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

# del DIR


from numba import cuda

cuda.select_device(0)
cuda.close()
