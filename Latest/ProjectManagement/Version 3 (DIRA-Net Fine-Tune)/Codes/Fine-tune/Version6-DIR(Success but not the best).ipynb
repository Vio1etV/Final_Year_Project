# %% [markdown]
# 这里再version 5的基础上，增加刚进入网络时的神经元数量，从而解决欠拟合问题，模型调用为 5 10 5
# stem第一层改为 16

# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.
# Out:
# 2024-03-09 17:42:01.126649: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 16
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 301 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = attention_block_2(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = attention_block_2(x)
    
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    x = attention_block_2(x)
    

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)
    
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    # a = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    c = Conv2D(32 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = attention_block_2(x)

    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    # c = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='linear',
               kernel_initializer='he_normal', padding='same')(x)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 5
num_B_blocks = 10
num_C_blocks = 5

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.3)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax')(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# 2024-03-09 17:42:05.470778: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-09 17:42:06.078406: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22134 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:b1:00.0, compute capability: 8.9
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 8)  224         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 222, 222, 96  7008        ['conv2d[0][0]']
#                                 )
#
#  activation (Activation)        (None, 222, 222, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 222, 222, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 222, 222, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 222, 222, 8)  0           ['conv2d[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 220, 220, 4)  292         ['multiply[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 220, 220, 96  3552        ['conv2d_3[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 220, 220, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 220, 220, 1)  97          ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 220, 220, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 220, 220, 4)  0           ['conv2d_3[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 220, 220, 8)  296         ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 220, 220, 96  7008        ['conv2d_6[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 220, 220, 96  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 220, 220, 1)  97          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 220, 220, 1)  0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 220, 220, 8)  0           ['conv2d_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['multiply_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 218, 218, 12  876         ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_13[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_16[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_6 (Activation)      (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 4)  196         ['activation_6[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 4)  196         ['activation_6[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 4)  196         ['activation_6[0][0]']
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 4)  40         ['conv2d_18[0][0]']
#  v2D)
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_17[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['activation_6[0][0]',
#                                 )                                 'conv2d_21[0][0]']
#
#  activation_7 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 214, 214, 4)  196         ['activation_7[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 4)  196         ['activation_7[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 4)  196         ['activation_7[0][0]']
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_23[0][0]']
#  onv2D)
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_24[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_22[0][0]',
#                                 )                                 'depthwise_conv2d_1[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_4[0][0]']
#                                 )
#
#  add_1 (Add)                    (None, 214, 214, 48  0           ['activation_7[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  activation_8 (Activation)      (None, 214, 214, 48  0           ['add_1[0][0]']
#                                 )
#
#  conv2d_28 (Conv2D)             (None, 214, 214, 4)  196         ['activation_8[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 214, 214, 4)  196         ['activation_8[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 214, 214, 4)  196         ['activation_8[0][0]']
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_28[0][0]']
#  onv2D)
#
#  conv2d_30 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_29[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_27[0][0]',
#                                 )                                 'depthwise_conv2d_2[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_5[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 214, 214, 48  0           ['activation_8[0][0]',
#                                 )                                 'conv2d_31[0][0]']
#
#  activation_9 (Activation)      (None, 214, 214, 48  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 214, 214, 4)  196         ['activation_9[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 214, 214, 4)  196         ['activation_9[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 214, 214, 4)  196         ['activation_9[0][0]']
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_33[0][0]']
#  onv2D)
#
#  conv2d_35 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_34[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_32[0][0]',
#                                 )                                 'depthwise_conv2d_3[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_6[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 214, 214, 48  0           ['activation_9[0][0]',
#                                 )                                 'conv2d_36[0][0]']
#
#  activation_10 (Activation)     (None, 214, 214, 48  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 214, 214, 4)  196         ['activation_10[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 214, 214, 4)  196         ['activation_10[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 214, 214, 4)  196         ['activation_10[0][0]']
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 214, 214, 4)  40         ['conv2d_38[0][0]']
#  onv2D)
#
#  conv2d_40 (Conv2D)             (None, 214, 214, 8)  296         ['conv2d_39[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 214, 214, 16  0           ['conv2d_37[0][0]',
#                                 )                                 'depthwise_conv2d_4[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 214, 214, 48  816         ['concatenate_7[0][0]']
#                                 )
#
#  add_4 (Add)                    (None, 214, 214, 48  0           ['activation_10[0][0]',
#                                 )                                 'conv2d_41[0][0]']
#
#  activation_11 (Activation)     (None, 214, 214, 48  0           ['add_4[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 214, 214, 32  1568        ['activation_11[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_43[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_11[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 106, 106, 48  20784       ['activation_11[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_44[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_42[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_47[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_48[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_8[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_49[0][0]']
#                                 )
#
#  concatenate_9 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_46[0][0]',
#                                 )                                 'conv2d_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_9[0][0]']
#                                 4)
#
#  add_5 (Add)                    (None, 106, 106, 14  0           ['concatenate_8[0][0]',
#                                 4)                                'conv2d_51[0][0]']
#
#  activation_12 (Activation)     (None, 106, 106, 14  0           ['add_5[0][0]']
#                                 4)
#
#  conv2d_53 (Conv2D)             (None, 106, 106, 16  2320        ['activation_12[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_54[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 106, 106, 24  3480        ['activation_12[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_55[0][0]']
#                                 )
#
#  concatenate_10 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_52[0][0]',
#                                 )                                 'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_10[0][0]']
#                                 4)
#
#  add_6 (Add)                    (None, 106, 106, 14  0           ['activation_12[0][0]',
#                                 4)                                'conv2d_57[0][0]']
#
#  activation_13 (Activation)     (None, 106, 106, 14  0           ['add_6[0][0]']
#                                 4)
#
#  conv2d_59 (Conv2D)             (None, 106, 106, 16  2320        ['activation_13[0][0]']
#                                 )
#
#  conv2d_60 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_59[0][0]']
#                                 )
#
#  conv2d_61 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_60[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 106, 106, 24  3480        ['activation_13[0][0]']
#                                 )
#
#  conv2d_62 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_61[0][0]']
#                                 )
#
#  concatenate_11 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_58[0][0]',
#                                 )                                 'conv2d_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_11[0][0]']
#                                 4)
#
#  add_7 (Add)                    (None, 106, 106, 14  0           ['activation_13[0][0]',
#                                 4)                                'conv2d_63[0][0]']
#
#  activation_14 (Activation)     (None, 106, 106, 14  0           ['add_7[0][0]']
#                                 4)
#
#  conv2d_65 (Conv2D)             (None, 106, 106, 16  2320        ['activation_14[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_65[0][0]']
#                                 )
#
#  conv2d_67 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_66[0][0]']
#                                 )
#
#  conv2d_64 (Conv2D)             (None, 106, 106, 24  3480        ['activation_14[0][0]']
#                                 )
#
#  conv2d_68 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_67[0][0]']
#                                 )
#
#  concatenate_12 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_64[0][0]',
#                                 )                                 'conv2d_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_12[0][0]']
#                                 4)
#
#  add_8 (Add)                    (None, 106, 106, 14  0           ['activation_14[0][0]',
#                                 4)                                'conv2d_69[0][0]']
#
#  activation_15 (Activation)     (None, 106, 106, 14  0           ['add_8[0][0]']
#                                 4)
#
#  conv2d_71 (Conv2D)             (None, 106, 106, 16  2320        ['activation_15[0][0]']
#                                 )
#
#  conv2d_72 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_71[0][0]']
#                                 )
#
#  conv2d_73 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_72[0][0]']
#                                 )
#
#  conv2d_70 (Conv2D)             (None, 106, 106, 24  3480        ['activation_15[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_73[0][0]']
#                                 )
#
#  concatenate_13 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_70[0][0]',
#                                 )                                 'conv2d_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_13[0][0]']
#                                 4)
#
#  add_9 (Add)                    (None, 106, 106, 14  0           ['activation_15[0][0]',
#                                 4)                                'conv2d_75[0][0]']
#
#  activation_16 (Activation)     (None, 106, 106, 14  0           ['add_9[0][0]']
#                                 4)
#
#  conv2d_77 (Conv2D)             (None, 106, 106, 16  2320        ['activation_16[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_77[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_78[0][0]']
#                                 )
#
#  conv2d_76 (Conv2D)             (None, 106, 106, 24  3480        ['activation_16[0][0]']
#                                 )
#
#  conv2d_80 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_79[0][0]']
#                                 )
#
#  concatenate_14 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_76[0][0]',
#                                 )                                 'conv2d_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_14[0][0]']
#                                 4)
#
#  add_10 (Add)                   (None, 106, 106, 14  0           ['activation_16[0][0]',
#                                 4)                                'conv2d_81[0][0]']
#
#  activation_17 (Activation)     (None, 106, 106, 14  0           ['add_10[0][0]']
#                                 4)
#
#  conv2d_83 (Conv2D)             (None, 106, 106, 16  2320        ['activation_17[0][0]']
#                                 )
#
#  conv2d_84 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_83[0][0]']
#                                 )
#
#  conv2d_85 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_84[0][0]']
#                                 )
#
#  conv2d_82 (Conv2D)             (None, 106, 106, 24  3480        ['activation_17[0][0]']
#                                 )
#
#  conv2d_86 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_85[0][0]']
#                                 )
#
#  concatenate_15 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_82[0][0]',
#                                 )                                 'conv2d_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_15[0][0]']
#                                 4)
#
#  add_11 (Add)                   (None, 106, 106, 14  0           ['activation_17[0][0]',
#                                 4)                                'conv2d_87[0][0]']
#
#  activation_18 (Activation)     (None, 106, 106, 14  0           ['add_11[0][0]']
#                                 4)
#
#  conv2d_89 (Conv2D)             (None, 106, 106, 16  2320        ['activation_18[0][0]']
#                                 )
#
#  conv2d_90 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_89[0][0]']
#                                 )
#
#  conv2d_91 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_90[0][0]']
#                                 )
#
#  conv2d_88 (Conv2D)             (None, 106, 106, 24  3480        ['activation_18[0][0]']
#                                 )
#
#  conv2d_92 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_91[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_88[0][0]',
#                                 )                                 'conv2d_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_16[0][0]']
#                                 4)
#
#  add_12 (Add)                   (None, 106, 106, 14  0           ['activation_18[0][0]',
#                                 4)                                'conv2d_93[0][0]']
#
#  activation_19 (Activation)     (None, 106, 106, 14  0           ['add_12[0][0]']
#                                 4)
#
#  conv2d_95 (Conv2D)             (None, 106, 106, 16  2320        ['activation_19[0][0]']
#                                 )
#
#  conv2d_96 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_95[0][0]']
#                                 )
#
#  conv2d_97 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_96[0][0]']
#                                 )
#
#  conv2d_94 (Conv2D)             (None, 106, 106, 24  3480        ['activation_19[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_97[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_94[0][0]',
#                                 )                                 'conv2d_98[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_17[0][0]']
#                                 4)
#
#  add_13 (Add)                   (None, 106, 106, 14  0           ['activation_19[0][0]',
#                                 4)                                'conv2d_99[0][0]']
#
#  activation_20 (Activation)     (None, 106, 106, 14  0           ['add_13[0][0]']
#                                 4)
#
#  conv2d_101 (Conv2D)            (None, 106, 106, 16  2320        ['activation_20[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 106, 106, 20  2260        ['conv2d_101[0][0]']
#                                 )
#
#  conv2d_103 (Conv2D)            (None, 106, 106, 24  3384        ['conv2d_102[0][0]']
#                                 )
#
#  conv2d_100 (Conv2D)            (None, 106, 106, 24  3480        ['activation_20[0][0]']
#                                 )
#
#  conv2d_104 (Conv2D)            (None, 106, 106, 24  600         ['conv2d_103[0][0]']
#                                 )
#
#  concatenate_18 (Concatenate)   (None, 106, 106, 48  0           ['conv2d_100[0][0]',
#                                 )                                 'conv2d_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 106, 106, 14  7056        ['concatenate_18[0][0]']
#                                 4)
#
#  add_14 (Add)                   (None, 106, 106, 14  0           ['activation_20[0][0]',
#                                 4)                                'conv2d_105[0][0]']
#
#  activation_21 (Activation)     (None, 106, 106, 14  0           ['add_14[0][0]']
#                                 4)
#
#  conv2d_110 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_106 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_108 (Conv2D)            (None, 106, 106, 32  4640        ['activation_21[0][0]']
#                                 )
#
#  conv2d_111 (Conv2D)            (None, 106, 106, 36  10404       ['conv2d_110[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_21[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_106[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 52, 52, 36)   10404       ['conv2d_108[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 52, 52, 40)   13000       ['conv2d_111[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_107[0][0]',
#                                                                   'conv2d_109[0][0]',
#                                                                   'conv2d_112[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_114[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 52, 52, 24)   6168        ['concatenate_19[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_115[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_113[0][0]',
#                                                                   'conv2d_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_20[0][0]']
#
#  add_15 (Add)                   (None, 52, 52, 256)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_117[0][0]']
#
#  activation_22 (Activation)     (None, 52, 52, 256)  0           ['add_15[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_119[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_22[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_120[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_118[0][0]',
#                                                                   'conv2d_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_21[0][0]']
#
#  add_16 (Add)                   (None, 52, 52, 256)  0           ['activation_22[0][0]',
#                                                                   'conv2d_122[0][0]']
#
#  activation_23 (Activation)     (None, 52, 52, 256)  0           ['add_16[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_124[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_23[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_125[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_123[0][0]',
#                                                                   'conv2d_126[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_22[0][0]']
#
#  add_17 (Add)                   (None, 52, 52, 256)  0           ['activation_23[0][0]',
#                                                                   'conv2d_127[0][0]']
#
#  activation_24 (Activation)     (None, 52, 52, 256)  0           ['add_17[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_129[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_24[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_130[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_128[0][0]',
#                                                                   'conv2d_131[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_23[0][0]']
#
#  add_18 (Add)                   (None, 52, 52, 256)  0           ['activation_24[0][0]',
#                                                                   'conv2d_132[0][0]']
#
#  activation_25 (Activation)     (None, 52, 52, 256)  0           ['add_18[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 52, 52, 28)   2044        ['conv2d_134[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 52, 52, 24)   6168        ['activation_25[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 52, 52, 32)   2720        ['conv2d_135[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_133[0][0]',
#                                                                   'conv2d_136[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 52, 52, 256)  14592       ['concatenate_24[0][0]']
#
#  add_19 (Add)                   (None, 52, 52, 256)  0           ['activation_25[0][0]',
#                                                                   'conv2d_137[0][0]']
#
#  activation_26 (Activation)     (None, 52, 52, 256)  0           ['add_19[0][0]']
#
#  dropout (Dropout)              (None, 52, 52, 256)  0           ['activation_26[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 490,033
# Trainable params: 490,033
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import numpy as np
from sklearn.metrics import f1_score
from tensorflow.keras.callbacks import Callback

class F1ScoreCallback(Callback):
    def __init__(self, validation_generator, num_classes):
        super(F1ScoreCallback, self).__init__()
        self.validation_generator = validation_generator
        self.num_classes = num_classes
        self.f1_scores = []

    def on_epoch_end(self, epoch, logs=None):
        val_predict = []
        val_true = []
        # 遍历验证集
        for i in range(len(self.validation_generator)):
            x_val, y_val_true_batch = next(self.validation_generator)
            y_val_pred = self.model.predict(x_val, verbose = 0)
            y_val_pred = np.argmax(y_val_pred, axis=1)
            y_val_true = np.argmax(y_val_true_batch, axis=1)  # 此行修正了之前的错误
            val_predict.extend(y_val_pred)
            val_true.extend(y_val_true)

        # 计算F1分数
        f1 = f1_score(val_true, val_predict, average='micro')  # 或者使用'macro'取决于你的需求
        self.f1_scores.append(f1)
        print(f'Epoch {epoch+1}: F1 Score: {f1}')

# 继续使用之前的方式将回调添加到你的模型训练中

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC()
    ]
)

MODEL_NAME = "Version6-DIR"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)


lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', 
                                 factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

f1_score_callback = F1ScoreCallback(validation_generator=validation_generator, 
                                    num_classes=num_classes)


from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
# history = DIR.fit(
#     train_generator,
#     epochs=150,  # 根据需要调整epochs数
#     validation_data=validation_generator,
#     callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
# )


history = DIR.fit(
    train_generator,
    epochs=150,
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback, f1_score_callback]
)
# Out:
# Epoch 1/150
# 2024-03-09 17:42:17.069899: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-09 17:42:17.922950: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-03-09 17:42:17.922984: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2024-03-09 17:42:17.923103: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-03-09 17:42:19.129472: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
#   6/142 [>.............................] - ETA: 34s - loss: 371.4960 - accuracy: 0.4479 - precision: 0.4479 - recall: 0.4479 - auc: 0.4572WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1019s vs `on_train_batch_end` time: 0.1247s). Check your callbacks.
# 142/142 [==============================] - ETA: 0s - loss: 16.4905 - accuracy: 0.4697 - precision: 0.4697 - recall: 0.4697 - auc: 0.4644
# Epoch 1: val_loss improved from inf to 0.68852, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 1: F1 Score: 0.5
# 142/142 [==============================] - 63s 370ms/step - loss: 16.4905 - accuracy: 0.4697 - precision: 0.4697 - recall: 0.4697 - auc: 0.4644 - val_loss: 0.6885 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 0.5000 - val_auc: 0.6950 - lr: 0.0010
# Epoch 2/150
# 142/142 [==============================] - ETA: 0s - loss: 0.6592 - accuracy: 0.6231 - precision: 0.6231 - recall: 0.6231 - auc: 0.6568
# Epoch 2: val_loss improved from 0.68852 to 0.50419, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 2: F1 Score: 0.819526627218935
# 142/142 [==============================] - 46s 326ms/step - loss: 0.6592 - accuracy: 0.6231 - precision: 0.6231 - recall: 0.6231 - auc: 0.6568 - val_loss: 0.5042 - val_accuracy: 0.8432 - val_precision: 0.8432 - val_recall: 0.8432 - val_auc: 0.8960 - lr: 0.0010
# Epoch 3/150
# 142/142 [==============================] - ETA: 0s - loss: 0.5881 - accuracy: 0.7008 - precision: 0.7008 - recall: 0.7008 - auc: 0.7588
# Epoch 3: val_loss improved from 0.50419 to 0.47327, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 3: F1 Score: 0.8165680473372781
# 142/142 [==============================] - 47s 332ms/step - loss: 0.5881 - accuracy: 0.7008 - precision: 0.7008 - recall: 0.7008 - auc: 0.7588 - val_loss: 0.4733 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.9029 - lr: 0.0010
# Epoch 4/150
# 142/142 [==============================] - ETA: 0s - loss: 0.5686 - accuracy: 0.7212 - precision: 0.7212 - recall: 0.7212 - auc: 0.7767
# Epoch 4: val_loss improved from 0.47327 to 0.40269, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 4: F1 Score: 0.8579881656804734
# 142/142 [==============================] - 49s 341ms/step - loss: 0.5686 - accuracy: 0.7212 - precision: 0.7212 - recall: 0.7212 - auc: 0.7767 - val_loss: 0.4027 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9110 - lr: 0.0010
# Epoch 5/150
# 142/142 [==============================] - ETA: 0s - loss: 0.5340 - accuracy: 0.7490 - precision: 0.7490 - recall: 0.7490 - auc: 0.8090
# Epoch 5: val_loss did not improve from 0.40269
# Epoch 5: F1 Score: 0.7307692307692306
# 142/142 [==============================] - 47s 327ms/step - loss: 0.5340 - accuracy: 0.7490 - precision: 0.7490 - recall: 0.7490 - auc: 0.8090 - val_loss: 0.4947 - val_accuracy: 0.7456 - val_precision: 0.7456 - val_recall: 0.7456 - val_auc: 0.8647 - lr: 0.0010
# Epoch 6/150
# 142/142 [==============================] - ETA: 0s - loss: 0.5293 - accuracy: 0.7486 - precision: 0.7486 - recall: 0.7486 - auc: 0.8142
# Epoch 6: val_loss did not improve from 0.40269
# Epoch 6: F1 Score: 0.7071005917159763
# 142/142 [==============================] - 47s 328ms/step - loss: 0.5293 - accuracy: 0.7486 - precision: 0.7486 - recall: 0.7486 - auc: 0.8142 - val_loss: 0.5587 - val_accuracy: 0.7130 - val_precision: 0.7130 - val_recall: 0.7130 - val_auc: 0.7821 - lr: 0.0010
# Epoch 7/150
# 142/142 [==============================] - ETA: 0s - loss: 0.5060 - accuracy: 0.7548 - precision: 0.7548 - recall: 0.7548 - auc: 0.8330
# Epoch 7: val_loss improved from 0.40269 to 0.37455, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 7: F1 Score: 0.831360946745562
# 142/142 [==============================] - 48s 338ms/step - loss: 0.5060 - accuracy: 0.7548 - precision: 0.7548 - recall: 0.7548 - auc: 0.8330 - val_loss: 0.3746 - val_accuracy: 0.8254 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.9225 - lr: 0.0010
# Epoch 8/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4904 - accuracy: 0.7671 - precision: 0.7671 - recall: 0.7671 - auc: 0.8452
# Epoch 8: val_loss did not improve from 0.37455
# Epoch 8: F1 Score: 0.8224852071005917
# 142/142 [==============================] - 47s 326ms/step - loss: 0.4904 - accuracy: 0.7671 - precision: 0.7671 - recall: 0.7671 - auc: 0.8452 - val_loss: 0.4268 - val_accuracy: 0.8314 - val_precision: 0.8314 - val_recall: 0.8314 - val_auc: 0.9063 - lr: 0.0010
# Epoch 9/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4692 - accuracy: 0.7901 - precision: 0.7901 - recall: 0.7901 - auc: 0.8584
# Epoch 9: val_loss did not improve from 0.37455
# Epoch 9: F1 Score: 0.7426035502958581
# 142/142 [==============================] - 48s 336ms/step - loss: 0.4692 - accuracy: 0.7901 - precision: 0.7901 - recall: 0.7901 - auc: 0.8584 - val_loss: 0.5331 - val_accuracy: 0.7278 - val_precision: 0.7278 - val_recall: 0.7278 - val_auc: 0.8446 - lr: 0.0010
# Epoch 10/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4604 - accuracy: 0.7919 - precision: 0.7919 - recall: 0.7919 - auc: 0.8648
# Epoch 10: val_loss did not improve from 0.37455
# Epoch 10: F1 Score: 0.8136094674556213
# 142/142 [==============================] - 46s 324ms/step - loss: 0.4604 - accuracy: 0.7919 - precision: 0.7919 - recall: 0.7919 - auc: 0.8648 - val_loss: 0.4179 - val_accuracy: 0.8225 - val_precision: 0.8225 - val_recall: 0.8225 - val_auc: 0.8903 - lr: 0.0010
# Epoch 11/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4616 - accuracy: 0.7954 - precision: 0.7954 - recall: 0.7954 - auc: 0.8635
# Epoch 11: val_loss improved from 0.37455 to 0.33214, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 11: F1 Score: 0.8727810650887574
# 142/142 [==============================] - 48s 339ms/step - loss: 0.4616 - accuracy: 0.7954 - precision: 0.7954 - recall: 0.7954 - auc: 0.8635 - val_loss: 0.3321 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9476 - lr: 0.0010
# Epoch 12/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4405 - accuracy: 0.7972 - precision: 0.7972 - recall: 0.7972 - auc: 0.8780
# Epoch 12: val_loss did not improve from 0.33214
# Epoch 12: F1 Score: 0.8520710059171598
# 142/142 [==============================] - 48s 337ms/step - loss: 0.4405 - accuracy: 0.7972 - precision: 0.7972 - recall: 0.7972 - auc: 0.8780 - val_loss: 0.3499 - val_accuracy: 0.8343 - val_precision: 0.8343 - val_recall: 0.8343 - val_auc: 0.9308 - lr: 0.0010
# Epoch 13/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4309 - accuracy: 0.8073 - precision: 0.8073 - recall: 0.8073 - auc: 0.8833
# Epoch 13: val_loss did not improve from 0.33214
# Epoch 13: F1 Score: 0.7514792899408284
# 142/142 [==============================] - 47s 331ms/step - loss: 0.4309 - accuracy: 0.8073 - precision: 0.8073 - recall: 0.8073 - auc: 0.8833 - val_loss: 0.5139 - val_accuracy: 0.7367 - val_precision: 0.7367 - val_recall: 0.7367 - val_auc: 0.8454 - lr: 0.0010
# Epoch 14/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4515 - accuracy: 0.7954 - precision: 0.7954 - recall: 0.7954 - auc: 0.8704
# Epoch 14: val_loss did not improve from 0.33214
# Epoch 14: F1 Score: 0.8461538461538461
# 142/142 [==============================] - 48s 335ms/step - loss: 0.4515 - accuracy: 0.7954 - precision: 0.7954 - recall: 0.7954 - auc: 0.8704 - val_loss: 0.3631 - val_accuracy: 0.8373 - val_precision: 0.8373 - val_recall: 0.8373 - val_auc: 0.9232 - lr: 0.0010
# Epoch 15/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4494 - accuracy: 0.8029 - precision: 0.8029 - recall: 0.8029 - auc: 0.8723
# Epoch 15: val_loss did not improve from 0.33214
# Epoch 15: F1 Score: 0.8550295857988166
# 142/142 [==============================] - 46s 324ms/step - loss: 0.4494 - accuracy: 0.8029 - precision: 0.8029 - recall: 0.8029 - auc: 0.8723 - val_loss: 0.3531 - val_accuracy: 0.8462 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9397 - lr: 0.0010
# Epoch 16/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4283 - accuracy: 0.8104 - precision: 0.8104 - recall: 0.8104 - auc: 0.8842
# Epoch 16: val_loss did not improve from 0.33214
# Epoch 16: F1 Score: 0.8698224852071006
# 142/142 [==============================] - 48s 335ms/step - loss: 0.4283 - accuracy: 0.8104 - precision: 0.8104 - recall: 0.8104 - auc: 0.8842 - val_loss: 0.3749 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9304 - lr: 0.0010
# Epoch 17/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4032 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.8981
# Epoch 17: val_loss did not improve from 0.33214
# Epoch 17: F1 Score: 0.849112426035503
# 142/142 [==============================] - 47s 330ms/step - loss: 0.4032 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.8981 - val_loss: 0.3375 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9435 - lr: 0.0010
# Epoch 18/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4226 - accuracy: 0.8148 - precision: 0.8148 - recall: 0.8148 - auc: 0.8872
# Epoch 18: val_loss did not improve from 0.33214
# Epoch 18: F1 Score: 0.8520710059171598
# 142/142 [==============================] - 47s 331ms/step - loss: 0.4226 - accuracy: 0.8148 - precision: 0.8148 - recall: 0.8148 - auc: 0.8872 - val_loss: 0.3602 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9293 - lr: 0.0010
# Epoch 19/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4106 - accuracy: 0.8246 - precision: 0.8246 - recall: 0.8246 - auc: 0.8934
# Epoch 19: val_loss improved from 0.33214 to 0.30550, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 19: F1 Score: 0.8816568047337278
# 142/142 [==============================] - 48s 334ms/step - loss: 0.4106 - accuracy: 0.8246 - precision: 0.8246 - recall: 0.8246 - auc: 0.8934 - val_loss: 0.3055 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9511 - lr: 0.0010
# Epoch 20/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4119 - accuracy: 0.8268 - precision: 0.8268 - recall: 0.8268 - auc: 0.8927
# Epoch 20: val_loss did not improve from 0.30550
# Epoch 20: F1 Score: 0.7692307692307693
# 142/142 [==============================] - 48s 339ms/step - loss: 0.4119 - accuracy: 0.8268 - precision: 0.8268 - recall: 0.8268 - auc: 0.8927 - val_loss: 0.4530 - val_accuracy: 0.7722 - val_precision: 0.7722 - val_recall: 0.7722 - val_auc: 0.8772 - lr: 0.0010
# Epoch 21/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4095 - accuracy: 0.8241 - precision: 0.8241 - recall: 0.8241 - auc: 0.8954
# Epoch 21: val_loss did not improve from 0.30550
# Epoch 21: F1 Score: 0.8372781065088757
# 142/142 [==============================] - 47s 330ms/step - loss: 0.4095 - accuracy: 0.8241 - precision: 0.8241 - recall: 0.8241 - auc: 0.8954 - val_loss: 0.3465 - val_accuracy: 0.8521 - val_precision: 0.8521 - val_recall: 0.8521 - val_auc: 0.9367 - lr: 0.0010
# Epoch 22/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4165 - accuracy: 0.8246 - precision: 0.8246 - recall: 0.8246 - auc: 0.8898
# Epoch 22: val_loss improved from 0.30550 to 0.30210, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 22: F1 Score: 0.9053254437869822
# 142/142 [==============================] - 49s 345ms/step - loss: 0.4165 - accuracy: 0.8246 - precision: 0.8246 - recall: 0.8246 - auc: 0.8898 - val_loss: 0.3021 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9569 - lr: 0.0010
# Epoch 23/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4036 - accuracy: 0.8277 - precision: 0.8277 - recall: 0.8277 - auc: 0.8979
# Epoch 23: val_loss improved from 0.30210 to 0.22173, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 23: F1 Score: 0.9260355029585798
# 142/142 [==============================] - 49s 343ms/step - loss: 0.4036 - accuracy: 0.8277 - precision: 0.8277 - recall: 0.8277 - auc: 0.8979 - val_loss: 0.2217 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9760 - lr: 0.0010
# Epoch 24/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4058 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.8960
# Epoch 24: val_loss did not improve from 0.22173
# Epoch 24: F1 Score: 0.8076923076923077
# 142/142 [==============================] - 48s 335ms/step - loss: 0.4058 - accuracy: 0.8294 - precision: 0.8294 - recall: 0.8294 - auc: 0.8960 - val_loss: 0.3904 - val_accuracy: 0.8195 - val_precision: 0.8195 - val_recall: 0.8195 - val_auc: 0.9100 - lr: 0.0010
# Epoch 25/150
# 142/142 [==============================] - ETA: 0s - loss: 0.4105 - accuracy: 0.8259 - precision: 0.8259 - recall: 0.8259 - auc: 0.8936
# Epoch 25: val_loss did not improve from 0.22173
# Epoch 25: F1 Score: 0.8284023668639053
# 142/142 [==============================] - 47s 331ms/step - loss: 0.4105 - accuracy: 0.8259 - precision: 0.8259 - recall: 0.8259 - auc: 0.8936 - val_loss: 0.3686 - val_accuracy: 0.8462 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9197 - lr: 0.0010
# Epoch 26/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3852 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9075
# Epoch 26: val_loss did not improve from 0.22173
# Epoch 26: F1 Score: 0.9142011834319527
# 142/142 [==============================] - 47s 329ms/step - loss: 0.3852 - accuracy: 0.8369 - precision: 0.8369 - recall: 0.8369 - auc: 0.9075 - val_loss: 0.2606 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9756 - lr: 0.0010
# Epoch 27/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3910 - accuracy: 0.8387 - precision: 0.8387 - recall: 0.8387 - auc: 0.9038
# Epoch 27: val_loss did not improve from 0.22173
# Epoch 27: F1 Score: 0.8757396449704142
# 142/142 [==============================] - 47s 327ms/step - loss: 0.3910 - accuracy: 0.8387 - precision: 0.8387 - recall: 0.8387 - auc: 0.9038 - val_loss: 0.3228 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9573 - lr: 0.0010
# Epoch 28/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3741 - accuracy: 0.8440 - precision: 0.8440 - recall: 0.8440 - auc: 0.9133
# Epoch 28: val_loss did not improve from 0.22173
# Epoch 28: F1 Score: 0.6597633136094675
# 142/142 [==============================] - 48s 339ms/step - loss: 0.3741 - accuracy: 0.8440 - precision: 0.8440 - recall: 0.8440 - auc: 0.9133 - val_loss: 0.6934 - val_accuracy: 0.6420 - val_precision: 0.6420 - val_recall: 0.6420 - val_auc: 0.7436 - lr: 0.0010
# Epoch 29/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3993 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.8995
# Epoch 29: val_loss did not improve from 0.22173
# Epoch 29: F1 Score: 0.8846153846153846
# 142/142 [==============================] - 48s 335ms/step - loss: 0.3993 - accuracy: 0.8374 - precision: 0.8374 - recall: 0.8374 - auc: 0.8995 - val_loss: 0.2847 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9570 - lr: 0.0010
# Epoch 30/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3895 - accuracy: 0.8405 - precision: 0.8405 - recall: 0.8405 - auc: 0.9045
# Epoch 30: val_loss did not improve from 0.22173
# Epoch 30: F1 Score: 0.8224852071005917
# 142/142 [==============================] - 48s 335ms/step - loss: 0.3895 - accuracy: 0.8405 - precision: 0.8405 - recall: 0.8405 - auc: 0.9045 - val_loss: 0.3998 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.9045 - lr: 0.0010
# Epoch 31/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3892 - accuracy: 0.8400 - precision: 0.8400 - recall: 0.8400 - auc: 0.9054
# Epoch 31: val_loss did not improve from 0.22173
# Epoch 31: F1 Score: 0.8520710059171598
# 142/142 [==============================] - 48s 337ms/step - loss: 0.3892 - accuracy: 0.8400 - precision: 0.8400 - recall: 0.8400 - auc: 0.9054 - val_loss: 0.3302 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9367 - lr: 0.0010
# Epoch 32/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3856 - accuracy: 0.8392 - precision: 0.8392 - recall: 0.8392 - auc: 0.9072
# Epoch 32: val_loss did not improve from 0.22173
# Epoch 32: F1 Score: 0.8372781065088757
# 142/142 [==============================] - 47s 330ms/step - loss: 0.3856 - accuracy: 0.8392 - precision: 0.8392 - recall: 0.8392 - auc: 0.9072 - val_loss: 0.4294 - val_accuracy: 0.8343 - val_precision: 0.8343 - val_recall: 0.8343 - val_auc: 0.9085 - lr: 0.0010
# Epoch 33/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3856 - accuracy: 0.8338 - precision: 0.8338 - recall: 0.8338 - auc: 0.9077
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 33: val_loss did not improve from 0.22173
# Epoch 33: F1 Score: 0.896449704142012
# 142/142 [==============================] - 48s 336ms/step - loss: 0.3856 - accuracy: 0.8338 - precision: 0.8338 - recall: 0.8338 - auc: 0.9077 - val_loss: 0.2630 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9694 - lr: 0.0010
# Epoch 34/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3297 - accuracy: 0.8652 - precision: 0.8652 - recall: 0.8652 - auc: 0.9334
# Epoch 34: val_loss did not improve from 0.22173
# Epoch 34: F1 Score: 0.9053254437869822
# 142/142 [==============================] - 47s 330ms/step - loss: 0.3297 - accuracy: 0.8652 - precision: 0.8652 - recall: 0.8652 - auc: 0.9334 - val_loss: 0.2430 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9744 - lr: 1.0000e-04
# Epoch 35/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3207 - accuracy: 0.8665 - precision: 0.8665 - recall: 0.8665 - auc: 0.9361
# Epoch 35: val_loss did not improve from 0.22173
# Epoch 35: F1 Score: 0.9053254437869822
# 142/142 [==============================] - 47s 331ms/step - loss: 0.3207 - accuracy: 0.8665 - precision: 0.8665 - recall: 0.8665 - auc: 0.9361 - val_loss: 0.2399 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9722 - lr: 1.0000e-04
# Epoch 36/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3168 - accuracy: 0.8736 - precision: 0.8736 - recall: 0.8736 - auc: 0.9380
# Epoch 36: val_loss did not improve from 0.22173
# Epoch 36: F1 Score: 0.9142011834319527
# 142/142 [==============================] - 48s 334ms/step - loss: 0.3168 - accuracy: 0.8736 - precision: 0.8736 - recall: 0.8736 - auc: 0.9380 - val_loss: 0.2373 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9721 - lr: 1.0000e-04
# Epoch 37/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3058 - accuracy: 0.8807 - precision: 0.8807 - recall: 0.8807 - auc: 0.9409
# Epoch 37: val_loss improved from 0.22173 to 0.21008, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 37: F1 Score: 0.9230769230769231
# 142/142 [==============================] - 48s 339ms/step - loss: 0.3058 - accuracy: 0.8807 - precision: 0.8807 - recall: 0.8807 - auc: 0.9409 - val_loss: 0.2101 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9795 - lr: 1.0000e-04
# Epoch 38/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3108 - accuracy: 0.8741 - precision: 0.8741 - recall: 0.8741 - auc: 0.9408
# Epoch 38: val_loss did not improve from 0.21008
# Epoch 38: F1 Score: 0.849112426035503
# 142/142 [==============================] - 47s 333ms/step - loss: 0.3108 - accuracy: 0.8741 - precision: 0.8741 - recall: 0.8741 - auc: 0.9408 - val_loss: 0.3344 - val_accuracy: 0.8580 - val_precision: 0.8580 - val_recall: 0.8580 - val_auc: 0.9353 - lr: 1.0000e-04
# Epoch 39/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3048 - accuracy: 0.8763 - precision: 0.8763 - recall: 0.8763 - auc: 0.9421
# Epoch 39: val_loss did not improve from 0.21008
# Epoch 39: F1 Score: 0.9112426035502958
# 142/142 [==============================] - 48s 339ms/step - loss: 0.3048 - accuracy: 0.8763 - precision: 0.8763 - recall: 0.8763 - auc: 0.9421 - val_loss: 0.2142 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9768 - lr: 1.0000e-04
# Epoch 40/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9442
# Epoch 40: val_loss did not improve from 0.21008
# Epoch 40: F1 Score: 0.9319526627218935
# 142/142 [==============================] - 48s 335ms/step - loss: 0.2985 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9442 - val_loss: 0.2112 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9752 - lr: 1.0000e-04
# Epoch 41/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2986 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9434
# Epoch 41: val_loss improved from 0.21008 to 0.19390, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 41: F1 Score: 0.9142011834319527
# 142/142 [==============================] - 48s 339ms/step - loss: 0.2986 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9434 - val_loss: 0.1939 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9820 - lr: 1.0000e-04
# Epoch 42/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2989 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9450
# Epoch 42: val_loss did not improve from 0.19390
# Epoch 42: F1 Score: 0.9023668639053254
# 142/142 [==============================] - 47s 329ms/step - loss: 0.2989 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9450 - val_loss: 0.2369 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9663 - lr: 1.0000e-04
# Epoch 43/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2994 - accuracy: 0.8807 - precision: 0.8807 - recall: 0.8807 - auc: 0.9445
# Epoch 43: val_loss did not improve from 0.19390
# Epoch 43: F1 Score: 0.9260355029585798
# 142/142 [==============================] - 47s 329ms/step - loss: 0.2994 - accuracy: 0.8807 - precision: 0.8807 - recall: 0.8807 - auc: 0.9445 - val_loss: 0.2028 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9783 - lr: 1.0000e-04
# Epoch 44/150
# 142/142 [==============================] - ETA: 0s - loss: 0.3103 - accuracy: 0.8785 - precision: 0.8785 - recall: 0.8785 - auc: 0.9399
# Epoch 44: val_loss did not improve from 0.19390
# Epoch 44: F1 Score: 0.9319526627218935
# 142/142 [==============================] - 46s 323ms/step - loss: 0.3103 - accuracy: 0.8785 - precision: 0.8785 - recall: 0.8785 - auc: 0.9399 - val_loss: 0.2272 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9713 - lr: 1.0000e-04
# Epoch 45/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9451
# Epoch 45: val_loss did not improve from 0.19390
# Epoch 45: F1 Score: 0.8994082840236687
# 142/142 [==============================] - 47s 329ms/step - loss: 0.2960 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9451 - val_loss: 0.2112 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9804 - lr: 1.0000e-04
# Epoch 46/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2932 - accuracy: 0.8847 - precision: 0.8847 - recall: 0.8847 - auc: 0.9463
# Epoch 46: val_loss did not improve from 0.19390
# Epoch 46: F1 Score: 0.9171597633136095
# 142/142 [==============================] - 48s 336ms/step - loss: 0.2932 - accuracy: 0.8847 - precision: 0.8847 - recall: 0.8847 - auc: 0.9463 - val_loss: 0.2282 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9729 - lr: 1.0000e-04
# Epoch 47/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2957 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9468
# Epoch 47: val_loss did not improve from 0.19390
# Epoch 47: F1 Score: 0.9289940828402367
# 142/142 [==============================] - 48s 334ms/step - loss: 0.2957 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9468 - val_loss: 0.2002 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9802 - lr: 1.0000e-04
# Epoch 48/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2920 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9472
# Epoch 48: val_loss did not improve from 0.19390
# Epoch 48: F1 Score: 0.9289940828402367
# 142/142 [==============================] - 47s 333ms/step - loss: 0.2920 - accuracy: 0.8851 - precision: 0.8851 - recall: 0.8851 - auc: 0.9472 - val_loss: 0.2092 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9786 - lr: 1.0000e-04
# Epoch 49/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.8825 - precision: 0.8825 - recall: 0.8825 - auc: 0.9460
# Epoch 49: val_loss did not improve from 0.19390
# Epoch 49: F1 Score: 0.9408284023668639
# 142/142 [==============================] - 48s 339ms/step - loss: 0.2946 - accuracy: 0.8825 - precision: 0.8825 - recall: 0.8825 - auc: 0.9460 - val_loss: 0.2228 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9776 - lr: 1.0000e-04
# Epoch 50/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9438
# Epoch 50: val_loss did not improve from 0.19390
# Epoch 50: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 47s 331ms/step - loss: 0.2985 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9438 - val_loss: 0.1976 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9851 - lr: 1.0000e-04
# Epoch 51/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2829 - accuracy: 0.8891 - precision: 0.8891 - recall: 0.8891 - auc: 0.9508
# Epoch 51: val_loss improved from 0.19390 to 0.18235, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 51: F1 Score: 0.9349112426035503
# 142/142 [==============================] - 49s 344ms/step - loss: 0.2829 - accuracy: 0.8891 - precision: 0.8891 - recall: 0.8891 - auc: 0.9508 - val_loss: 0.1824 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9791 - lr: 1.0000e-04
# Epoch 52/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2868 - accuracy: 0.8869 - precision: 0.8869 - recall: 0.8869 - auc: 0.9494
# Epoch 52: val_loss did not improve from 0.18235
# Epoch 52: F1 Score: 0.908284023668639
# 142/142 [==============================] - 47s 329ms/step - loss: 0.2868 - accuracy: 0.8869 - precision: 0.8869 - recall: 0.8869 - auc: 0.9494 - val_loss: 0.2307 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9722 - lr: 1.0000e-04
# Epoch 53/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9485
# Epoch 53: val_loss did not improve from 0.18235
# Epoch 53: F1 Score: 0.9230769230769231
# 142/142 [==============================] - 47s 327ms/step - loss: 0.2889 - accuracy: 0.8842 - precision: 0.8842 - recall: 0.8842 - auc: 0.9485 - val_loss: 0.1970 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9808 - lr: 1.0000e-04
# Epoch 54/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.8878 - precision: 0.8878 - recall: 0.8878 - auc: 0.9496
# Epoch 54: val_loss did not improve from 0.18235
# Epoch 54: F1 Score: 0.9260355029585798
# 142/142 [==============================] - 47s 330ms/step - loss: 0.2844 - accuracy: 0.8878 - precision: 0.8878 - recall: 0.8878 - auc: 0.9496 - val_loss: 0.1970 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9808 - lr: 1.0000e-04
# Epoch 55/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2761 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9519
# Epoch 55: val_loss improved from 0.18235 to 0.17722, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 55: F1 Score: 0.9319526627218935
# 142/142 [==============================] - 48s 333ms/step - loss: 0.2761 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9519 - val_loss: 0.1772 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9856 - lr: 1.0000e-04
# Epoch 56/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2798 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9524
# Epoch 56: val_loss did not improve from 0.17722
# Epoch 56: F1 Score: 0.9142011834319527
# 142/142 [==============================] - 48s 335ms/step - loss: 0.2798 - accuracy: 0.8895 - precision: 0.8895 - recall: 0.8895 - auc: 0.9524 - val_loss: 0.2283 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9702 - lr: 1.0000e-04
# Epoch 57/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2807 - accuracy: 0.8816 - precision: 0.8816 - recall: 0.8816 - auc: 0.9523
# Epoch 57: val_loss did not improve from 0.17722
# Epoch 57: F1 Score: 0.9260355029585798
# 142/142 [==============================] - 48s 333ms/step - loss: 0.2807 - accuracy: 0.8816 - precision: 0.8816 - recall: 0.8816 - auc: 0.9523 - val_loss: 0.2019 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9777 - lr: 1.0000e-04
# Epoch 58/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2719 - accuracy: 0.8935 - precision: 0.8935 - recall: 0.8935 - auc: 0.9540
# Epoch 58: val_loss did not improve from 0.17722
# Epoch 58: F1 Score: 0.9142011834319527
# 142/142 [==============================] - 47s 329ms/step - loss: 0.2719 - accuracy: 0.8935 - precision: 0.8935 - recall: 0.8935 - auc: 0.9540 - val_loss: 0.2070 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9772 - lr: 1.0000e-04
# Epoch 59/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2706 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9555
# Epoch 59: val_loss did not improve from 0.17722
# Epoch 59: F1 Score: 0.9053254437869822
# 142/142 [==============================] - 48s 338ms/step - loss: 0.2706 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9555 - val_loss: 0.1940 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9790 - lr: 1.0000e-04
# Epoch 60/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2682 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9552
# Epoch 60: val_loss did not improve from 0.17722
# Epoch 60: F1 Score: 0.9289940828402367
# 142/142 [==============================] - 48s 338ms/step - loss: 0.2682 - accuracy: 0.8992 - precision: 0.8992 - recall: 0.8992 - auc: 0.9552 - val_loss: 0.2226 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9733 - lr: 1.0000e-04
# Epoch 61/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2699 - accuracy: 0.8922 - precision: 0.8922 - recall: 0.8922 - auc: 0.9544
# Epoch 61: val_loss did not improve from 0.17722
# Epoch 61: F1 Score: 0.9112426035502958
# 142/142 [==============================] - 47s 331ms/step - loss: 0.2699 - accuracy: 0.8922 - precision: 0.8922 - recall: 0.8922 - auc: 0.9544 - val_loss: 0.2011 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9773 - lr: 1.0000e-04
# Epoch 62/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2745 - accuracy: 0.8913 - precision: 0.8913 - recall: 0.8913 - auc: 0.9520
# Epoch 62: val_loss did not improve from 0.17722
# Epoch 62: F1 Score: 0.8905325443786983
# 142/142 [==============================] - 47s 329ms/step - loss: 0.2745 - accuracy: 0.8913 - precision: 0.8913 - recall: 0.8913 - auc: 0.9520 - val_loss: 0.2933 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9455 - lr: 1.0000e-04
# Epoch 63/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.8953 - precision: 0.8953 - recall: 0.8953 - auc: 0.9535
# Epoch 63: val_loss did not improve from 0.17722
# Epoch 63: F1 Score: 0.9201183431952662
# 142/142 [==============================] - 48s 338ms/step - loss: 0.2729 - accuracy: 0.8953 - precision: 0.8953 - recall: 0.8953 - auc: 0.9535 - val_loss: 0.2100 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9755 - lr: 1.0000e-04
# Epoch 64/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2706 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9547
# Epoch 64: val_loss did not improve from 0.17722
# Epoch 64: F1 Score: 0.9260355029585798
# 142/142 [==============================] - 48s 340ms/step - loss: 0.2706 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9547 - val_loss: 0.2076 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9755 - lr: 1.0000e-04
# Epoch 65/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2711 - accuracy: 0.8878 - precision: 0.8878 - recall: 0.8878 - auc: 0.9554
# Epoch 65: val_loss improved from 0.17722 to 0.16849, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 65: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 47s 329ms/step - loss: 0.2711 - accuracy: 0.8878 - precision: 0.8878 - recall: 0.8878 - auc: 0.9554 - val_loss: 0.1685 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9839 - lr: 1.0000e-04
# Epoch 66/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2601 - accuracy: 0.8984 - precision: 0.8984 - recall: 0.8984 - auc: 0.9580
# Epoch 66: val_loss improved from 0.16849 to 0.16003, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 66: F1 Score: 0.9467455621301775
# 142/142 [==============================] - 49s 343ms/step - loss: 0.2601 - accuracy: 0.8984 - precision: 0.8984 - recall: 0.8984 - auc: 0.9580 - val_loss: 0.1600 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9887 - lr: 1.0000e-04
# Epoch 67/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2527 - accuracy: 0.9032 - precision: 0.9032 - recall: 0.9032 - auc: 0.9596
# Epoch 67: val_loss did not improve from 0.16003
# Epoch 67: F1 Score: 0.9497041420118343
# 142/142 [==============================] - 48s 335ms/step - loss: 0.2527 - accuracy: 0.9032 - precision: 0.9032 - recall: 0.9032 - auc: 0.9596 - val_loss: 0.1621 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9862 - lr: 1.0000e-04
# Epoch 68/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2523 - accuracy: 0.8948 - precision: 0.8948 - recall: 0.8948 - auc: 0.9609
# Epoch 68: val_loss did not improve from 0.16003
# Epoch 68: F1 Score: 0.9378698224852071
# 142/142 [==============================] - 48s 338ms/step - loss: 0.2523 - accuracy: 0.8948 - precision: 0.8948 - recall: 0.8948 - auc: 0.9609 - val_loss: 0.1801 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9859 - lr: 1.0000e-04
# Epoch 69/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2619 - accuracy: 0.8957 - precision: 0.8957 - recall: 0.8957 - auc: 0.9584
# Epoch 69: val_loss did not improve from 0.16003
# Epoch 69: F1 Score: 0.8994082840236687
# 142/142 [==============================] - 48s 334ms/step - loss: 0.2619 - accuracy: 0.8957 - precision: 0.8957 - recall: 0.8957 - auc: 0.9584 - val_loss: 0.2681 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9540 - lr: 1.0000e-04
# Epoch 70/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2563 - accuracy: 0.8966 - precision: 0.8966 - recall: 0.8966 - auc: 0.9597
# Epoch 70: val_loss did not improve from 0.16003
# Epoch 70: F1 Score: 0.9349112426035503
# 142/142 [==============================] - 47s 329ms/step - loss: 0.2563 - accuracy: 0.8966 - precision: 0.8966 - recall: 0.8966 - auc: 0.9597 - val_loss: 0.1845 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9837 - lr: 1.0000e-04
# Epoch 71/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2520 - accuracy: 0.9032 - precision: 0.9032 - recall: 0.9032 - auc: 0.9617
# Epoch 71: val_loss did not improve from 0.16003
# Epoch 71: F1 Score: 0.9289940828402367
# 142/142 [==============================] - 48s 336ms/step - loss: 0.2520 - accuracy: 0.9032 - precision: 0.9032 - recall: 0.9032 - auc: 0.9617 - val_loss: 0.2242 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9751 - lr: 1.0000e-04
# Epoch 72/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2653 - accuracy: 0.8984 - precision: 0.8984 - recall: 0.8984 - auc: 0.9559
# Epoch 72: val_loss did not improve from 0.16003
# Epoch 72: F1 Score: 0.8816568047337278
# 142/142 [==============================] - 47s 332ms/step - loss: 0.2653 - accuracy: 0.8984 - precision: 0.8984 - recall: 0.8984 - auc: 0.9559 - val_loss: 0.2721 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9553 - lr: 1.0000e-04
# Epoch 73/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2450 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9630
# Epoch 73: val_loss did not improve from 0.16003
# Epoch 73: F1 Score: 0.9467455621301775
# 142/142 [==============================] - 48s 339ms/step - loss: 0.2450 - accuracy: 0.9063 - precision: 0.9063 - recall: 0.9063 - auc: 0.9630 - val_loss: 0.1723 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9848 - lr: 1.0000e-04
# Epoch 74/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2508 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9600
# Epoch 74: val_loss did not improve from 0.16003
# Epoch 74: F1 Score: 0.9171597633136095
# 142/142 [==============================] - 48s 337ms/step - loss: 0.2508 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9600 - val_loss: 0.2016 - val_accuracy: 0.9290 - val_precision: 0.9290 - val_recall: 0.9290 - val_auc: 0.9788 - lr: 1.0000e-04
# Epoch 75/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2521 - accuracy: 0.9028 - precision: 0.9028 - recall: 0.9028 - auc: 0.9604
# Epoch 75: val_loss did not improve from 0.16003
# Epoch 75: F1 Score: 0.9497041420118343
# 142/142 [==============================] - 47s 330ms/step - loss: 0.2521 - accuracy: 0.9028 - precision: 0.9028 - recall: 0.9028 - auc: 0.9604 - val_loss: 0.1962 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9808 - lr: 1.0000e-04
# Epoch 76/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2369 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9645
# Epoch 76: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 76: val_loss did not improve from 0.16003
# Epoch 76: F1 Score: 0.9319526627218935
# 142/142 [==============================] - 47s 328ms/step - loss: 0.2369 - accuracy: 0.9081 - precision: 0.9081 - recall: 0.9081 - auc: 0.9645 - val_loss: 0.1668 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9846 - lr: 1.0000e-04
# Epoch 77/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2292 - accuracy: 0.9138 - precision: 0.9138 - recall: 0.9138 - auc: 0.9676
# Epoch 77: val_loss did not improve from 0.16003
# Epoch 77: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 47s 329ms/step - loss: 0.2292 - accuracy: 0.9138 - precision: 0.9138 - recall: 0.9138 - auc: 0.9676 - val_loss: 0.1716 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9838 - lr: 1.0000e-05
# Epoch 78/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2248 - accuracy: 0.9129 - precision: 0.9129 - recall: 0.9129 - auc: 0.9688
# Epoch 78: val_loss did not improve from 0.16003
# Epoch 78: F1 Score: 0.9467455621301775
# 142/142 [==============================] - 47s 327ms/step - loss: 0.2248 - accuracy: 0.9129 - precision: 0.9129 - recall: 0.9129 - auc: 0.9688 - val_loss: 0.1794 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9833 - lr: 1.0000e-05
# Epoch 79/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2143 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9707
# Epoch 79: val_loss did not improve from 0.16003
# Epoch 79: F1 Score: 0.9497041420118343
# 142/142 [==============================] - 48s 333ms/step - loss: 0.2143 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9707 - val_loss: 0.1740 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9826 - lr: 1.0000e-05
# Epoch 80/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2172 - accuracy: 0.9143 - precision: 0.9143 - recall: 0.9143 - auc: 0.9706
# Epoch 80: val_loss did not improve from 0.16003
# Epoch 80: F1 Score: 0.9408284023668639
# 142/142 [==============================] - 48s 335ms/step - loss: 0.2172 - accuracy: 0.9143 - precision: 0.9143 - recall: 0.9143 - auc: 0.9706 - val_loss: 0.1668 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9856 - lr: 1.0000e-05
# Epoch 81/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2138 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9708
# Epoch 81: val_loss improved from 0.16003 to 0.14456, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 81: F1 Score: 0.9467455621301775
# 142/142 [==============================] - 48s 340ms/step - loss: 0.2138 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9708 - val_loss: 0.1446 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9897 - lr: 1.0000e-05
# Epoch 82/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9227 - precision: 0.9227 - recall: 0.9227 - auc: 0.9705
# Epoch 82: val_loss did not improve from 0.14456
# Epoch 82: F1 Score: 0.9349112426035503
# 142/142 [==============================] - 47s 333ms/step - loss: 0.2131 - accuracy: 0.9227 - precision: 0.9227 - recall: 0.9227 - auc: 0.9705 - val_loss: 0.1736 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9832 - lr: 1.0000e-05
# Epoch 83/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2169 - accuracy: 0.9244 - precision: 0.9244 - recall: 0.9244 - auc: 0.9698
# Epoch 83: val_loss did not improve from 0.14456
# Epoch 83: F1 Score: 0.9349112426035503
# 142/142 [==============================] - 48s 336ms/step - loss: 0.2169 - accuracy: 0.9244 - precision: 0.9244 - recall: 0.9244 - auc: 0.9698 - val_loss: 0.1841 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9782 - lr: 1.0000e-05
# Epoch 84/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2172 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9700
# Epoch 84: val_loss did not improve from 0.14456
# Epoch 84: F1 Score: 0.9408284023668639
# 142/142 [==============================] - 48s 335ms/step - loss: 0.2172 - accuracy: 0.9165 - precision: 0.9165 - recall: 0.9165 - auc: 0.9700 - val_loss: 0.1528 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9879 - lr: 1.0000e-05
# Epoch 85/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2061 - accuracy: 0.9275 - precision: 0.9275 - recall: 0.9275 - auc: 0.9731
# Epoch 85: val_loss did not improve from 0.14456
# Epoch 85: F1 Score: 0.9467455621301775
# 142/142 [==============================] - 47s 327ms/step - loss: 0.2061 - accuracy: 0.9275 - precision: 0.9275 - recall: 0.9275 - auc: 0.9731 - val_loss: 0.1988 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9751 - lr: 1.0000e-05
# Epoch 86/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2201 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9694
# Epoch 86: val_loss did not improve from 0.14456
# Epoch 86: F1 Score: 0.9289940828402367
# 142/142 [==============================] - 47s 332ms/step - loss: 0.2201 - accuracy: 0.9231 - precision: 0.9231 - recall: 0.9231 - auc: 0.9694 - val_loss: 0.1782 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9808 - lr: 1.0000e-05
# Epoch 87/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2177 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9703
# Epoch 87: val_loss did not improve from 0.14456
# Epoch 87: F1 Score: 0.9408284023668639
# 142/142 [==============================] - 48s 336ms/step - loss: 0.2177 - accuracy: 0.9174 - precision: 0.9174 - recall: 0.9174 - auc: 0.9703 - val_loss: 0.1536 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9867 - lr: 1.0000e-05
# Epoch 88/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2086 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9718
# Epoch 88: val_loss did not improve from 0.14456
# Epoch 88: F1 Score: 0.9408284023668639
# 142/142 [==============================] - 47s 327ms/step - loss: 0.2086 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9718 - val_loss: 0.1594 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9863 - lr: 1.0000e-05
# Epoch 89/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2044 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9736
# Epoch 89: val_loss did not improve from 0.14456
# Epoch 89: F1 Score: 0.9349112426035503
# 142/142 [==============================] - 49s 344ms/step - loss: 0.2044 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9736 - val_loss: 0.1481 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9886 - lr: 1.0000e-05
# Epoch 90/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2070 - accuracy: 0.9244 - precision: 0.9244 - recall: 0.9244 - auc: 0.9731
# Epoch 90: val_loss did not improve from 0.14456
# Epoch 90: F1 Score: 0.9497041420118343
# 142/142 [==============================] - 45s 317ms/step - loss: 0.2070 - accuracy: 0.9244 - precision: 0.9244 - recall: 0.9244 - auc: 0.9731 - val_loss: 0.1769 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9811 - lr: 1.0000e-05
# Epoch 91/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2059 - accuracy: 0.9196 - precision: 0.9196 - recall: 0.9196 - auc: 0.9735
# Epoch 91: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 91: val_loss did not improve from 0.14456
# Epoch 91: F1 Score: 0.9437869822485208
# ...
# Epoch 120/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1963 - accuracy: 0.9244 - precision: 0.9244 - recall: 0.9244 - auc: 0.9757
# Epoch 120: val_loss did not improve from 0.14374
# Epoch 120: F1 Score: 0.9260355029585798
# 142/142 [==============================] - 48s 337ms/step - loss: 0.1963 - accuracy: 0.9244 - precision: 0.9244 - recall: 0.9244 - auc: 0.9757 - val_loss: 0.1499 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9890 - lr: 1.0000e-05
# Epoch 121/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1910 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9764
# Epoch 121: val_loss did not improve from 0.14374
# Epoch 121: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 47s 332ms/step - loss: 0.1910 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9764 - val_loss: 0.1752 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9815 - lr: 1.0000e-05
# Epoch 122/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2046 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9737
# Epoch 122: val_loss did not improve from 0.14374
# Epoch 122: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 48s 338ms/step - loss: 0.2046 - accuracy: 0.9187 - precision: 0.9187 - recall: 0.9187 - auc: 0.9737 - val_loss: 0.1526 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9880 - lr: 1.0000e-05
# Epoch 123/150
# 142/142 [==============================] - ETA: 0s - loss: 0.2042 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9736
# Epoch 123: val_loss did not improve from 0.14374
# Epoch 123: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 48s 337ms/step - loss: 0.2042 - accuracy: 0.9213 - precision: 0.9213 - recall: 0.9213 - auc: 0.9736 - val_loss: 0.1572 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9875 - lr: 1.0000e-05
# Epoch 124/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - auc: 0.9771
# Epoch 124: val_loss did not improve from 0.14374
# Epoch 124: F1 Score: 0.9526627218934911
# 142/142 [==============================] - 48s 337ms/step - loss: 0.1921 - accuracy: 0.9284 - precision: 0.9284 - recall: 0.9284 - auc: 0.9771 - val_loss: 0.1538 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9864 - lr: 1.0000e-05
# Epoch 125/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1963 - accuracy: 0.9249 - precision: 0.9249 - recall: 0.9249 - auc: 0.9758
# Epoch 125: val_loss did not improve from 0.14374
# Epoch 125: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 47s 328ms/step - loss: 0.1963 - accuracy: 0.9249 - precision: 0.9249 - recall: 0.9249 - auc: 0.9758 - val_loss: 0.1602 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9855 - lr: 1.0000e-05
# Epoch 126/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1962 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9761
# Epoch 126: val_loss did not improve from 0.14374
# Epoch 126: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 47s 332ms/step - loss: 0.1962 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9761 - val_loss: 0.1662 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9838 - lr: 1.0000e-05
# Epoch 127/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1965 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9754
# Epoch 127: val_loss did not improve from 0.14374
# Epoch 127: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 47s 328ms/step - loss: 0.1965 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9754 - val_loss: 0.1528 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9882 - lr: 1.0000e-05
# Epoch 128/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1958 - accuracy: 0.9236 - precision: 0.9236 - recall: 0.9236 - auc: 0.9763
# Epoch 128: val_loss did not improve from 0.14374
# Epoch 128: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 48s 334ms/step - loss: 0.1958 - accuracy: 0.9236 - precision: 0.9236 - recall: 0.9236 - auc: 0.9763 - val_loss: 0.1777 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9812 - lr: 1.0000e-05
# Epoch 129/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9754
# Epoch 129: val_loss did not improve from 0.14374
# Epoch 129: F1 Score: 0.9319526627218935
# 142/142 [==============================] - 48s 336ms/step - loss: 0.1943 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9754 - val_loss: 0.1602 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9865 - lr: 1.0000e-05
# Epoch 130/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1914 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9756
# Epoch 130: val_loss did not improve from 0.14374
# Epoch 130: F1 Score: 0.9289940828402367
# 142/142 [==============================] - 47s 331ms/step - loss: 0.1914 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9756 - val_loss: 0.1631 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9825 - lr: 1.0000e-05
# Epoch 131/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1993 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9747
# Epoch 131: val_loss did not improve from 0.14374
# Epoch 131: F1 Score: 0.9408284023668639
# 142/142 [==============================] - 47s 333ms/step - loss: 0.1993 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9747 - val_loss: 0.1559 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9865 - lr: 1.0000e-05
# Epoch 132/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1941 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9761
# Epoch 132: val_loss did not improve from 0.14374
# Epoch 132: F1 Score: 0.9526627218934911
# 142/142 [==============================] - 48s 338ms/step - loss: 0.1941 - accuracy: 0.9258 - precision: 0.9258 - recall: 0.9258 - auc: 0.9761 - val_loss: 0.1610 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9836 - lr: 1.0000e-05
# Epoch 133/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9777
# Epoch 133: val_loss improved from 0.14374 to 0.13961, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 133: F1 Score: 0.9585798816568046
# 142/142 [==============================] - 49s 342ms/step - loss: 0.1876 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9777 - val_loss: 0.1396 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9907 - lr: 1.0000e-05
# Epoch 134/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9315 - precision: 0.9315 - recall: 0.9315 - auc: 0.9777
# Epoch 134: val_loss did not improve from 0.13961
# Epoch 134: F1 Score: 0.9497041420118343
# 142/142 [==============================] - 48s 337ms/step - loss: 0.1843 - accuracy: 0.9315 - precision: 0.9315 - recall: 0.9315 - auc: 0.9777 - val_loss: 0.1618 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9848 - lr: 1.0000e-05
# Epoch 135/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9772
# Epoch 135: val_loss did not improve from 0.13961
# Epoch 135: F1 Score: 0.9319526627218935
# 142/142 [==============================] - 48s 337ms/step - loss: 0.1913 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9772 - val_loss: 0.1420 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9892 - lr: 1.0000e-05
# Epoch 136/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1909 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9757
# Epoch 136: val_loss improved from 0.13961 to 0.13935, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 136: F1 Score: 0.9319526627218935
# 142/142 [==============================] - 48s 339ms/step - loss: 0.1909 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9757 - val_loss: 0.1393 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9913 - lr: 1.0000e-05
# Epoch 137/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1916 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9768
# Epoch 137: val_loss did not improve from 0.13935
# Epoch 137: F1 Score: 0.9497041420118343
# 142/142 [==============================] - 48s 336ms/step - loss: 0.1916 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9768 - val_loss: 0.1458 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9890 - lr: 1.0000e-05
# Epoch 138/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9738
# Epoch 138: val_loss did not improve from 0.13935
# Epoch 138: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 48s 335ms/step - loss: 0.1981 - accuracy: 0.9271 - precision: 0.9271 - recall: 0.9271 - auc: 0.9738 - val_loss: 0.1603 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9864 - lr: 1.0000e-05
# Epoch 139/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1882 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9778
# Epoch 139: val_loss did not improve from 0.13935
# Epoch 139: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 48s 336ms/step - loss: 0.1882 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9778 - val_loss: 0.1457 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9888 - lr: 1.0000e-05
# Epoch 140/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1876 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9772
# Epoch 140: val_loss did not improve from 0.13935
# Epoch 140: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 47s 327ms/step - loss: 0.1876 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9772 - val_loss: 0.1444 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9875 - lr: 1.0000e-05
# Epoch 141/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1902 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9777
# Epoch 141: val_loss did not improve from 0.13935
# Epoch 141: F1 Score: 0.9497041420118343
# 142/142 [==============================] - 47s 331ms/step - loss: 0.1902 - accuracy: 0.9262 - precision: 0.9262 - recall: 0.9262 - auc: 0.9777 - val_loss: 0.1504 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9885 - lr: 1.0000e-05
# Epoch 142/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1867 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9781
# Epoch 142: val_loss did not improve from 0.13935
# Epoch 142: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 47s 330ms/step - loss: 0.1867 - accuracy: 0.9319 - precision: 0.9319 - recall: 0.9319 - auc: 0.9781 - val_loss: 0.1699 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9815 - lr: 1.0000e-05
# Epoch 143/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1924 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9761
# Epoch 143: val_loss improved from 0.13935 to 0.13382, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version6-DIR.h5
# Epoch 143: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 48s 340ms/step - loss: 0.1924 - accuracy: 0.9280 - precision: 0.9280 - recall: 0.9280 - auc: 0.9761 - val_loss: 0.1338 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9926 - lr: 1.0000e-05
# Epoch 144/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1850 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9785
# Epoch 144: val_loss did not improve from 0.13382
# Epoch 144: F1 Score: 0.9437869822485208
# 142/142 [==============================] - 48s 337ms/step - loss: 0.1850 - accuracy: 0.9302 - precision: 0.9302 - recall: 0.9302 - auc: 0.9785 - val_loss: 0.1454 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9888 - lr: 1.0000e-05
# Epoch 145/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9774
# Epoch 145: val_loss did not improve from 0.13382
# Epoch 145: F1 Score: 0.9526627218934911
# 142/142 [==============================] - 48s 337ms/step - loss: 0.1857 - accuracy: 0.9359 - precision: 0.9359 - recall: 0.9359 - auc: 0.9774 - val_loss: 0.1605 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9845 - lr: 1.0000e-05
# Epoch 146/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1910 - accuracy: 0.9324 - precision: 0.9324 - recall: 0.9324 - auc: 0.9762
# Epoch 146: val_loss did not improve from 0.13382
# Epoch 146: F1 Score: 0.9289940828402367
# 142/142 [==============================] - 48s 334ms/step - loss: 0.1910 - accuracy: 0.9324 - precision: 0.9324 - recall: 0.9324 - auc: 0.9762 - val_loss: 0.1553 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9882 - lr: 1.0000e-05
# Epoch 147/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1851 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9783
# Epoch 147: val_loss did not improve from 0.13382
# Epoch 147: F1 Score: 0.9378698224852071
# 142/142 [==============================] - 48s 334ms/step - loss: 0.1851 - accuracy: 0.9346 - precision: 0.9346 - recall: 0.9346 - auc: 0.9783 - val_loss: 0.1617 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9849 - lr: 1.0000e-05
# Epoch 148/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9773
# Epoch 148: val_loss did not improve from 0.13382
# Epoch 148: F1 Score: 0.9408284023668639
# 142/142 [==============================] - 48s 337ms/step - loss: 0.1877 - accuracy: 0.9297 - precision: 0.9297 - recall: 0.9297 - auc: 0.9773 - val_loss: 0.1646 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9828 - lr: 1.0000e-05
# Epoch 149/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1891 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9776
# Epoch 149: val_loss did not improve from 0.13382
# Epoch 149: F1 Score: 0.9467455621301775
# 142/142 [==============================] - 47s 333ms/step - loss: 0.1891 - accuracy: 0.9328 - precision: 0.9328 - recall: 0.9328 - auc: 0.9776 - val_loss: 0.1451 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9892 - lr: 1.0000e-05
# Epoch 150/150
# 142/142 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9783
# Epoch 150: val_loss did not improve from 0.13382
# Epoch 150: F1 Score: 0.9526627218934911
# 142/142 [==============================] - 45s 319ms/step - loss: 0.1871 - accuracy: 0.9293 - precision: 0.9293 - recall: 0.9293 - auc: 0.9783 - val_loss: 0.1543 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9868 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

# plt.subplot(2, 3, 5)
# plt.plot(history.history['f1_score'])
# plt.plot(history.history['val_f1_score'])
# plt.title('Model F1-Score')
# plt.xlabel('Epoch')
# plt.ylabel('F1-Score')
# plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(range(1, len(f1_score_callback.f1_scores) + 1), f1_score_callback.f1_scores)
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['F1 Score'], loc='lower right')


plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = DIR.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 1s 78ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9094376768795374
# F1-Score for each class: [0.87830688 0.94056848]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.9238578680203046
# specificity: 0.9120879120879121

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  DIR.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 1s 84ms/step

# %%
# test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = DIR.evaluate(test_generator)
# print('Test loss:', test_loss)
# print('Test accuracy:', test_acc)
# print('Test precision:', test_precision)
# print('Test recall:', test_recall)
# print('Test AUC:', test_auc)
# print('Test F1 Score:', test_f1_score)

test_loss, test_acc, test_precision, test_recall, test_auc = DIR.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)


from sklearn.metrics import f1_score
import numpy as np

# 预测测试集
y_pred = DIR.predict(test_generator)
y_pred = np.argmax(y_pred, axis=1)

# 真实标签
y_true = test_generator.classes

# 计算F1分数
test_f1_score = f1_score(y_true, y_pred, average='micro')  # 或者根据你的需要选择其他average参数
print('Test F1 Score:', test_f1_score)
# Out:
# 19/19 [==============================] - 1s 62ms/step - loss: 0.2229 - accuracy: 0.9169 - precision: 0.9169 - recall: 0.9169 - auc: 0.9689
# Test loss: 0.22290143370628357
# Test accuracy: 0.9169435501098633
# Test precision: 0.9169435501098633
# Test recall: 0.9169435501098633
# Test AUC: 0.968929648399353
# 19/19 [==============================] - 3s 65ms/step
# Test F1 Score: 0.5382059800664452

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = DIR.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 1s 85ms/step
#               precision    recall  f1-score   support
#
#            0       0.85      0.91      0.88        91
#            1       0.96      0.92      0.94       197
#
#     accuracy                           0.92       288
#    macro avg       0.90      0.92      0.91       288
# weighted avg       0.92      0.92      0.92       288

# %%
#delete the model to prevent memory costs

from keras import backend as K
import gc

K.clear_session()
gc.collect()

# del DIR


from numba import cuda

cuda.select_device(0)
cuda.close()
