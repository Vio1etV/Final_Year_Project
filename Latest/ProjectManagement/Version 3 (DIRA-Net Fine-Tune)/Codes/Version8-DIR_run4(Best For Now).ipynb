# %% [markdown]
# 再version 6的基础上，batchsize = 32， stem第一层变为4，用leaky relu，将inception a的函数里面的分支第一层神经元改为8
#
# 在Version 7的及基础上，加入L1正则化

# %%
# import zipfile

# f = zipfile.ZipFile("/root/Breast Cancer/Datasets Backup/40X.zip",'r') # 压缩文件在jupyter中的位置
# for file in f.namelist():
#     f.extract(file,"/root/Breast Cancer/Datasets")               # 解压到的位置
# f.close()

# %%
# !pip install scipy

# %%
# !pip install tensorflow-addons==0.18.0
# !pip install scikit-learn
# !pip install seaborn

# %%
# from tensorflow_addons.metrics import F1Score

# %%
# pip install numba

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, Conv2D, BatchNormalization, Activation, Concatenate, DepthwiseConv2D, Multiply,
    Dropout, GlobalAveragePooling2D, Dense, MaxPooling2D, Flatten, Add, Reshape, AveragePooling2D
)
from tensorflow.keras.regularizers import l2

from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
# Any additional code or custom layers you have can be added here.

# %%
input_shape = (224, 224, 3)

test_dir = '/root/Breast Cancer/Datasets/40XResized/test'
train_dir = '/root/Breast Cancer/Datasets/40XResized/train'


batch_size = 32
num_classes = 2
# filter_factor = 8

# %%
train_BC = '/root/Breast Cancer/Datasets/40XResized/train/benign'

#Show the import original image
train_img_files = os.listdir(train_BC)
# test_img_files = os.listdir(test_dir)
# val_img_files = os.listdir(val_dir)

show_num = 5

plt.figure(figsize = (15, 5))

for i in range(show_num):
    
    img_path = os.path.join(train_BC, train_img_files[i])
    img = plt.imread(img_path)
    plt.subplot(1, show_num, i + 1)
    plt.imshow(img)
    plt.axis('on')
    plt.title("Original Training Pic")
    
plt.tight_layout()
plt.show()

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.13,  # Specify the validation split here
    fill_mode='nearest'
)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training and testing images
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'  # Use 'training' subset for training data
)

validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'  # Use 'validation' subset for validation data
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 2263 images belonging to 2 classes.
# Found 338 images belonging to 2 classes.
# Found 304 images belonging to 2 classes.

# %%
#To show the augmented pictures, after rotation, zoom in, rescale etc

# import scipy

# Extract a batch of images from the train_generator
sample_images, sample_labels = next(train_generator)

plt.figure(figsize = (15, 5))

# Show the original images from the batch
num_images_to_show = 5  # Show three images
for i in range(num_images_to_show):
    plt.subplot(1, num_images_to_show, i + 1)
    plt.imshow(sample_images[i-1])
    plt.title("Augmented")
    plt.axis('off')

# %%
# we reduce # filters by factor of 8 compared to original inception-v4
nb_filters_reduction_factor = 8

l2_reg = 0.001



def attention_block_2(x):
    # 使用卷积层创建一个更复杂的注意力机制
    attention_network = Conv2D(96, (3, 3), padding='same')(x)  # 增加卷积层
    attention_network = Activation('relu')(attention_network)
    attention_network = Conv2D(1, (1, 1), padding='same')(attention_network)  # 生成注意力图
    
    attention_output = Activation('sigmoid')(attention_network)
    scaled_feature = Multiply()([x, attention_output])  # 将注意力图应用于原始特征

    return scaled_feature

def inception_resnet_v2_stem(x):
    # Updated to use Conv2D and correct parameters
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='leaky_relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    x = Conv2D(32 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    
    x = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same', kernel_regularizer = l2(l2_reg))(x)
    x = attention_block_2(x)
    

    a = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)
    
    a = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(a)
    # a = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(64 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(96 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    # b = attention_block_2(x)
    
    x = Concatenate(axis=-1)([a, b])

    a = Conv2D(192 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    b = MaxPooling2D((3, 3), strides=(1, 1), padding='valid')(x)
    x = Concatenate(axis=-1)([a, b])

    x = Activation('relu')(x)
    
    return x

#Depthwise Changed
def inception_resnet_v2_A(x):
    shortcut = x
    
    a = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
                        kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    c = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # c = attention_block_2(x)

    # c = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(64 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    # c = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b, c])
    x = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    shortcut = Conv2D(384 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(shortcut)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

def inception_resnet_v2_reduction_A(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(x)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)    
    c = Conv2D(256 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(c)
    c = Conv2D(384 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    
    x = Concatenate(axis=-1)([a, b, c])
    
    return x
    

def inception_resnet_v2_B(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    b = Conv2D(128 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(160 // nb_filters_reduction_factor, (1, 7), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    b = Conv2D(192 // nb_filters_reduction_factor, (7, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    # b = DepthwiseConv2D((1, 7), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    # b = DepthwiseConv2D((7, 1), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(b)
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    shortcut = Conv2D(1154 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(shortcut)
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x


def inception_resnet_v2_reduction_B(x):
    a = MaxPooling2D((3, 3), strides=(2, 2), padding='valid')(x)
    b = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    b = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(b)
    c = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    c = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(c)
    d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    d = Conv2D(288 // nb_filters_reduction_factor, (3, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(d)
    d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
               kernel_initializer='he_normal', padding='valid')(d)
    
    # d = Conv2D(256 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(x)
    # d = DepthwiseConv2D((3, 3), strides=(1, 1), activation='relu',
    #                     kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(288 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
    #            kernel_initializer='he_normal', padding='same')(d)
    # d = Conv2D(320 // nb_filters_reduction_factor, (3, 3), strides=(2, 2), activation='relu',
    #            kernel_initializer='he_normal', padding='valid')(d)
    
    x = Concatenate(axis=-1)([a, b, c, d])
    
    return x


def inception_resnet_v2_C(x):
    shortcut = x
    
    a = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # a = attention_block_2(x)

    
    b = Conv2D(192 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    # b = attention_block_2(x)

    b = Conv2D(224 // nb_filters_reduction_factor, (1, 3), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)
    
    b = Conv2D(256 // nb_filters_reduction_factor, (3, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(b)
    # b = attention_block_2(x)

    
    x = Concatenate(axis=-1)([a, b])
    x = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(x)
    shortcut = Conv2D(2048 // nb_filters_reduction_factor, (1, 1), strides=(1, 1), activation='relu',
               kernel_initializer='he_normal', padding='same')(shortcut)
    
    
    x = Add()([shortcut, x])
    x = Activation('relu')(x)
    
    return x

# %%
# img_rows, img_cols = 32, 32
# img_channels = 3

# in original inception-resnet-v2, these are 5, 10, 5, respectively
num_A_blocks = 1
num_B_blocks = 2
num_C_blocks = 5

inputs = Input(shape=input_shape)

x = inception_resnet_v2_stem(inputs)
for i in range(num_A_blocks):
    x = inception_resnet_v2_A(x)
x = inception_resnet_v2_reduction_A(x)
for i in range(num_B_blocks):
    x = inception_resnet_v2_B(x)
x = inception_resnet_v2_reduction_B(x)
for i in range(num_C_blocks):
    x = inception_resnet_v2_C(x)

# x = AveragePooling2D(pool_size=(4, 4), strides=(1, 1), padding='valid')(x)
x = Dropout(0.3)(x)
x = GlobalAveragePooling2D()(x)

predictions = Dense(num_classes, activation='softmax')(x)

DIR = Model(inputs=inputs, outputs=predictions)
DIR.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 222, 222, 4)  112         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 222, 222, 96  3552        ['conv2d[0][0]']
#                                 )
#
#  activation (Activation)        (None, 222, 222, 96  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 222, 222, 1)  97          ['activation[0][0]']
#
#  activation_1 (Activation)      (None, 222, 222, 1)  0           ['conv2d_2[0][0]']
#
#  multiply (Multiply)            (None, 222, 222, 4)  0           ['conv2d[0][0]',
#                                                                   'activation_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 220, 220, 4)  148         ['multiply[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 220, 220, 96  3552        ['conv2d_3[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 220, 220, 96  0           ['conv2d_4[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 220, 220, 1)  97          ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 220, 220, 1)  0           ['conv2d_5[0][0]']
#
#  multiply_1 (Multiply)          (None, 220, 220, 4)  0           ['conv2d_3[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 220, 220, 8)  296         ['multiply_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 220, 220, 96  7008        ['conv2d_6[0][0]']
#                                 )
#
#  activation_4 (Activation)      (None, 220, 220, 96  0           ['conv2d_7[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 220, 220, 1)  97          ['activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 220, 220, 1)  0           ['conv2d_8[0][0]']
#
#  multiply_2 (Multiply)          (None, 220, 220, 8)  0           ['conv2d_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 218, 218, 8)  0           ['multiply_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 218, 218, 12  876         ['multiply_2[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 218, 218, 20  0           ['max_pooling2d[0][0]',
#                                 )                                 'conv2d_9[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_12[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 218, 218, 8)  168         ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 218, 218, 8)  456         ['conv2d_13[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_10[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 216, 216, 12  876         ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 216, 216, 24  0           ['conv2d_11[0][0]',
#                                 )                                 'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 214, 214, 24  5208        ['concatenate_1[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 214, 214, 24  0          ['concatenate_1[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 214, 214, 48  0           ['conv2d_16[0][0]',
#                                 )                                 'max_pooling2d_1[0][0]']
#
#  activation_6 (Activation)      (None, 214, 214, 48  0           ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 214, 214, 16  784         ['activation_6[0][0]']
#                                 )
#
#  depthwise_conv2d (DepthwiseCon  (None, 214, 214, 16  160        ['conv2d_18[0][0]']
#  v2D)                           )
#
#  conv2d_20 (Conv2D)             (None, 214, 214, 8)  1160        ['conv2d_19[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 214, 214, 40  0           ['conv2d_17[0][0]',
#                                 )                                 'depthwise_conv2d[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 214, 214, 48  2352        ['activation_6[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 214, 214, 48  1968        ['concatenate_3[0][0]']
#                                 )
#
#  add (Add)                      (None, 214, 214, 48  0           ['conv2d_22[0][0]',
#                                 )                                 'conv2d_21[0][0]']
#
#  activation_7 (Activation)      (None, 214, 214, 48  0           ['add[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 214, 214, 32  1568        ['activation_7[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 214, 214, 32  9248        ['conv2d_24[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 106, 106, 48  0          ['activation_7[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 106, 106, 48  20784       ['activation_7[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 106, 106, 48  13872       ['conv2d_25[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 106, 106, 14  0           ['max_pooling2d_2[0][0]',
#                                 4)                                'conv2d_23[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 106, 106, 16  2320        ['concatenate_4[0][0]']
#                                 )
#
#  conv2d_29 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_28[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_29[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 106, 106, 24  3480        ['concatenate_4[0][0]']
#                                 )
#
#  conv2d_31 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_30[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_27[0][0]',
#                                 )                                 'conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 106, 106, 14  20880       ['concatenate_4[0][0]']
#                                 4)
#
#  conv2d_32 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_5[0][0]']
#                                 4)
#
#  add_1 (Add)                    (None, 106, 106, 14  0           ['conv2d_33[0][0]',
#                                 4)                                'conv2d_32[0][0]']
#
#  activation_8 (Activation)      (None, 106, 106, 14  0           ['add_1[0][0]']
#                                 4)
#
#  conv2d_35 (Conv2D)             (None, 106, 106, 16  2320        ['activation_8[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 106, 106, 20  2260        ['conv2d_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 106, 106, 24  3384        ['conv2d_36[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 106, 106, 24  3480        ['activation_8[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 106, 106, 24  600         ['conv2d_37[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 106, 106, 48  0           ['conv2d_34[0][0]',
#                                 )                                 'conv2d_38[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 106, 106, 14  20880       ['activation_8[0][0]']
#                                 4)
#
#  conv2d_39 (Conv2D)             (None, 106, 106, 14  7056        ['concatenate_6[0][0]']
#                                 4)
#
#  add_2 (Add)                    (None, 106, 106, 14  0           ['conv2d_40[0][0]',
#                                 4)                                'conv2d_39[0][0]']
#
#  activation_9 (Activation)      (None, 106, 106, 14  0           ['add_2[0][0]']
#                                 4)
#
#  conv2d_45 (Conv2D)             (None, 106, 106, 32  4640        ['activation_9[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 106, 106, 32  4640        ['activation_9[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 106, 106, 32  4640        ['activation_9[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 106, 106, 36  10404       ['conv2d_45[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 52, 52, 144)  0          ['activation_9[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 52, 52, 36)   10404       ['conv2d_41[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 52, 52, 36)   10404       ['conv2d_43[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 52, 52, 40)   13000       ['conv2d_46[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 52, 52, 256)  0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_42[0][0]',
#                                                                   'conv2d_44[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 52, 52, 24)   6168        ['concatenate_7[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 52, 52, 28)   2044        ['conv2d_49[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 52, 52, 24)   6168        ['concatenate_7[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 52, 52, 32)   2720        ['conv2d_50[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 52, 52, 56)   0           ['conv2d_48[0][0]',
#                                                                   'conv2d_51[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 52, 52, 256)  65792       ['concatenate_7[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 52, 52, 256)  14592       ['concatenate_8[0][0]']
#
#  add_3 (Add)                    (None, 52, 52, 256)  0           ['conv2d_53[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  activation_10 (Activation)     (None, 52, 52, 256)  0           ['add_3[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 52, 52, 24)   6168        ['activation_10[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 52, 52, 28)   2044        ['conv2d_55[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 52, 52, 24)   6168        ['activation_10[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 52, 52, 32)   2720        ['conv2d_56[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 52, 52, 56)   0           ['conv2d_54[0][0]',
#                                                                   'conv2d_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 52, 52, 256)  65792       ['activation_10[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 52, 52, 256)  14592       ['concatenate_9[0][0]']
#
#  add_4 (Add)                    (None, 52, 52, 256)  0           ['conv2d_59[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  activation_11 (Activation)     (None, 52, 52, 256)  0           ['add_4[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 52, 52, 24)   6168        ['activation_11[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 52, 52, 28)   2044        ['conv2d_61[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 52, 52, 24)   6168        ['activation_11[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 52, 52, 32)   2720        ['conv2d_62[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_60[0][0]',
#                                                                   'conv2d_63[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 52, 52, 256)  65792       ['activation_11[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 52, 52, 256)  14592       ['concatenate_10[0][0]']
#
#  add_5 (Add)                    (None, 52, 52, 256)  0           ['conv2d_65[0][0]',
#                                                                   'conv2d_64[0][0]']
#
#  activation_12 (Activation)     (None, 52, 52, 256)  0           ['add_5[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 52, 52, 24)   6168        ['activation_12[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 52, 52, 28)   2044        ['conv2d_67[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 52, 52, 24)   6168        ['activation_12[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 52, 52, 32)   2720        ['conv2d_68[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_66[0][0]',
#                                                                   'conv2d_69[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 52, 52, 256)  65792       ['activation_12[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 52, 52, 256)  14592       ['concatenate_11[0][0]']
#
#  add_6 (Add)                    (None, 52, 52, 256)  0           ['conv2d_71[0][0]',
#                                                                   'conv2d_70[0][0]']
#
#  activation_13 (Activation)     (None, 52, 52, 256)  0           ['add_6[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 52, 52, 24)   6168        ['activation_13[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 52, 52, 28)   2044        ['conv2d_73[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 52, 52, 24)   6168        ['activation_13[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 52, 52, 32)   2720        ['conv2d_74[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 52, 52, 56)   0           ['conv2d_72[0][0]',
#                                                                   'conv2d_75[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 52, 52, 256)  65792       ['activation_13[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 52, 52, 256)  14592       ['concatenate_12[0][0]']
#
#  add_7 (Add)                    (None, 52, 52, 256)  0           ['conv2d_77[0][0]',
#                                                                   'conv2d_76[0][0]']
#
#  activation_14 (Activation)     (None, 52, 52, 256)  0           ['add_7[0][0]']
#
#  dropout (Dropout)              (None, 52, 52, 256)  0           ['activation_14[0][0]']
#
#  global_average_pooling2d (Glob  (None, 256)         0           ['dropout[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2)            514         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 703,533
# Trainable params: 703,533
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# import numpy as np
# from sklearn.metrics import f1_score
# from tensorflow.keras.callbacks import Callback

# class F1ScoreCallback(Callback):
#     def __init__(self, train_generator, validation_generator, num_classes):
#         super(F1ScoreCallback, self).__init__()
#         self.train_generator = train_generator
#         self.validation_generator = validation_generator
#         self.num_classes = num_classes
#         self.train_f1_scores = []
#         self.val_f1_scores = []

#     def on_epoch_end(self, epoch, logs=None):
#         # 计算训练集F1分数
#         train_predict, train_true = self._get_predictions_and_true_labels(self.train_generator)
#         train_f1 = f1_score(train_true, train_predict, average='micro')
#         self.train_f1_scores.append(train_f1)
        
#         # 计算验证集F1分数
#         val_predict, val_true = self._get_predictions_and_true_labels(self.validation_generator)
#         val_f1 = f1_score(val_true, val_predict, average='micro')
#         self.val_f1_scores.append(val_f1)
        
#         print(f'Epoch {epoch+1}: Training F1 Score: {train_f1}, Validation F1 Score: {val_f1}')

#     def _get_predictions_and_true_labels(self, generator):
#         predictions = []
#         true_labels = []
#         for i in range(len(generator)):
#             x_batch, y_batch_true = next(generator)
#             y_batch_pred = self.model.predict(x_batch, verbose=0)
#             y_batch_pred = np.argmax(y_batch_pred, axis=1)
#             y_true = np.argmax(y_batch_true, axis=1)
#             predictions.extend(y_batch_pred)
#             true_labels.extend(y_true)
#         return predictions, true_labels


# # 继续使用之前的方式将回调添加到你的模型训练中

# %%
lr = 0.001
Optimizer = Adam(learning_rate = lr)

from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow_addons.metrics import F1Score
from tensorflow.keras import backend as K


DIR.compile(
    optimizer='adam',
    loss = "categorical_crossentropy",
    metrics=[
        "accuracy", 
        Precision(), 
        Recall(), 
        AUC(),
        F1Score(num_classes=2, average = 'micro')
    ]
)

MODEL_NAME = "Version8_run4-DIR"  # 用您的模型名替换
# 训练合并后的模型
csv_logger = tf.keras.callbacks.CSVLogger(
    fr"/root/Breast Cancer/CSVHistory/{MODEL_NAME}.csv", 
    separator=",", 
    append=False)


lr_reduction = ReduceLROnPlateau(monitor = 'val_loss', 
                                 factor = 0.1,
                                patience = 10,
                                min_lr = 0.00001,
                                verbose = 1)

# f1_score_callback = F1ScoreCallback(train_generator = train_generator, 
#                                     validation_generator=validation_generator, 
#                                     num_classes=num_classes)


from tensorflow.keras.callbacks import ModelCheckpoint

# 设置模型保存路径
model_checkpoint_path = "/root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5"

# 创建ModelCheckpoint回调，保存最佳模型
model_checkpoint_callback = ModelCheckpoint(
    filepath=model_checkpoint_path,
    save_best_only=True,  # 仅保存在验证集上性能最好的模型
    monitor='val_loss',  # 监控的指标
    mode='min',  # 'min'意味着监控指标的最小值，'val_loss'减小意味着性能改善
    verbose=1  # 日志级别
)

# %%
history = DIR.fit(
    train_generator,
    epochs=150,  # 根据需要调整epochs数
    validation_data=validation_generator,
    callbacks=[csv_logger, lr_reduction, model_checkpoint_callback]  # 确保这里添加了model_checkpoint_callback
)


# history = DIR.fit(
#     train_generator,
#     epochs=150,
#     validation_data=validation_generator,
#     callbacks=[csv_logger, lr_reduction, model_checkpoint_callback, f1_score_callback]
# )
# Out:
# Epoch 1/150
# 2024-03-12 16:54:41.870176: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
# 2024-03-12 16:54:42.696145: W tensorflow/stream_executor/gpu/asm_compiler.cc:230] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2024-03-12 16:54:42.696162: W tensorflow/stream_executor/gpu/asm_compiler.cc:233] Used ptxas at ptxas
# 2024-03-12 16:54:42.696213: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2024-03-12 16:54:43.986133: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 71/71 [==============================] - ETA: 0s - loss: 0.7931 - accuracy: 0.6010 - precision: 0.6010 - recall: 0.6010 - auc: 0.6399 - f1_score: 0.6010
# Epoch 1: val_loss improved from inf to 0.51847, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 50s 570ms/step - loss: 0.7931 - accuracy: 0.6010 - precision: 0.6010 - recall: 0.6010 - auc: 0.6399 - f1_score: 0.6010 - val_loss: 0.5185 - val_accuracy: 0.7367 - val_precision: 0.7367 - val_recall: 0.7367 - val_auc: 0.8747 - val_f1_score: 0.7367 - lr: 0.0010
# Epoch 2/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5783 - accuracy: 0.7375 - precision: 0.7375 - recall: 0.7375 - auc: 0.7967 - f1_score: 0.7375
# Epoch 2: val_loss improved from 0.51847 to 0.37510, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 34s 475ms/step - loss: 0.5783 - accuracy: 0.7375 - precision: 0.7375 - recall: 0.7375 - auc: 0.7967 - f1_score: 0.7375 - val_loss: 0.3751 - val_accuracy: 0.8669 - val_precision: 0.8669 - val_recall: 0.8669 - val_auc: 0.9499 - val_f1_score: 0.8669 - lr: 0.0010
# Epoch 3/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5615 - accuracy: 0.7521 - precision: 0.7521 - recall: 0.7521 - auc: 0.8154 - f1_score: 0.7521
# Epoch 3: val_loss did not improve from 0.37510
# 71/71 [==============================] - 36s 503ms/step - loss: 0.5615 - accuracy: 0.7521 - precision: 0.7521 - recall: 0.7521 - auc: 0.8154 - f1_score: 0.7521 - val_loss: 0.4919 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.8722 - val_f1_score: 0.8166 - lr: 0.0010
# Epoch 4/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5631 - accuracy: 0.7486 - precision: 0.7486 - recall: 0.7486 - auc: 0.8105 - f1_score: 0.7486
# Epoch 4: val_loss did not improve from 0.37510
# 71/71 [==============================] - 34s 475ms/step - loss: 0.5631 - accuracy: 0.7486 - precision: 0.7486 - recall: 0.7486 - auc: 0.8105 - f1_score: 0.7486 - val_loss: 0.4198 - val_accuracy: 0.8166 - val_precision: 0.8166 - val_recall: 0.8166 - val_auc: 0.9241 - val_f1_score: 0.8166 - lr: 0.0010
# Epoch 5/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5220 - accuracy: 0.7738 - precision: 0.7738 - recall: 0.7738 - auc: 0.8425 - f1_score: 0.7738
# Epoch 5: val_loss did not improve from 0.37510
# 71/71 [==============================] - 37s 513ms/step - loss: 0.5220 - accuracy: 0.7738 - precision: 0.7738 - recall: 0.7738 - auc: 0.8425 - f1_score: 0.7738 - val_loss: 0.5030 - val_accuracy: 0.7544 - val_precision: 0.7544 - val_recall: 0.7544 - val_auc: 0.8816 - val_f1_score: 0.7544 - lr: 0.0010
# Epoch 6/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5231 - accuracy: 0.7746 - precision: 0.7746 - recall: 0.7746 - auc: 0.8387 - f1_score: 0.7746
# Epoch 6: val_loss did not improve from 0.37510
# 71/71 [==============================] - 37s 511ms/step - loss: 0.5231 - accuracy: 0.7746 - precision: 0.7746 - recall: 0.7746 - auc: 0.8387 - f1_score: 0.7746 - val_loss: 0.4147 - val_accuracy: 0.8314 - val_precision: 0.8314 - val_recall: 0.8314 - val_auc: 0.9418 - val_f1_score: 0.8314 - lr: 0.0010
# Epoch 7/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5221 - accuracy: 0.7738 - precision: 0.7738 - recall: 0.7738 - auc: 0.8410 - f1_score: 0.7738
# Epoch 7: val_loss did not improve from 0.37510
# 71/71 [==============================] - 35s 489ms/step - loss: 0.5221 - accuracy: 0.7738 - precision: 0.7738 - recall: 0.7738 - auc: 0.8410 - f1_score: 0.7738 - val_loss: 0.3886 - val_accuracy: 0.8343 - val_precision: 0.8343 - val_recall: 0.8343 - val_auc: 0.9337 - val_f1_score: 0.8343 - lr: 0.0010
# Epoch 8/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5257 - accuracy: 0.7760 - precision: 0.7760 - recall: 0.7760 - auc: 0.8410 - f1_score: 0.7760
# Epoch 8: val_loss did not improve from 0.37510
# 71/71 [==============================] - 35s 495ms/step - loss: 0.5257 - accuracy: 0.7760 - precision: 0.7760 - recall: 0.7760 - auc: 0.8410 - f1_score: 0.7760 - val_loss: 0.3862 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9471 - val_f1_score: 0.8550 - lr: 0.0010
# Epoch 9/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5105 - accuracy: 0.7883 - precision: 0.7883 - recall: 0.7883 - auc: 0.8509 - f1_score: 0.7883
# Epoch 9: val_loss did not improve from 0.37510
# 71/71 [==============================] - 36s 505ms/step - loss: 0.5105 - accuracy: 0.7883 - precision: 0.7883 - recall: 0.7883 - auc: 0.8509 - f1_score: 0.7883 - val_loss: 0.5161 - val_accuracy: 0.7485 - val_precision: 0.7485 - val_recall: 0.7485 - val_auc: 0.8783 - val_f1_score: 0.7485 - lr: 0.0010
# Epoch 10/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5215 - accuracy: 0.7751 - precision: 0.7751 - recall: 0.7751 - auc: 0.8409 - f1_score: 0.7751
# Epoch 10: val_loss improved from 0.37510 to 0.33786, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 37s 514ms/step - loss: 0.5215 - accuracy: 0.7751 - precision: 0.7751 - recall: 0.7751 - auc: 0.8409 - f1_score: 0.7751 - val_loss: 0.3379 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9650 - val_f1_score: 0.8964 - lr: 0.0010
# Epoch 11/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4962 - accuracy: 0.7875 - precision: 0.7875 - recall: 0.7875 - auc: 0.8589 - f1_score: 0.7875
# Epoch 11: val_loss did not improve from 0.33786
# 71/71 [==============================] - 35s 484ms/step - loss: 0.4962 - accuracy: 0.7875 - precision: 0.7875 - recall: 0.7875 - auc: 0.8589 - f1_score: 0.7875 - val_loss: 0.3666 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9558 - val_f1_score: 0.8787 - lr: 0.0010
# Epoch 12/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.7839 - precision: 0.7839 - recall: 0.7839 - auc: 0.8569 - f1_score: 0.7839
# Epoch 12: val_loss did not improve from 0.33786
# 71/71 [==============================] - 36s 506ms/step - loss: 0.4976 - accuracy: 0.7839 - precision: 0.7839 - recall: 0.7839 - auc: 0.8569 - f1_score: 0.7839 - val_loss: 0.3740 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9412 - val_f1_score: 0.8609 - lr: 0.0010
# Epoch 13/150
# 71/71 [==============================] - ETA: 0s - loss: 0.5146 - accuracy: 0.7875 - precision: 0.7875 - recall: 0.7875 - auc: 0.8445 - f1_score: 0.7875
# Epoch 13: val_loss did not improve from 0.33786
# 71/71 [==============================] - 35s 491ms/step - loss: 0.5146 - accuracy: 0.7875 - precision: 0.7875 - recall: 0.7875 - auc: 0.8445 - f1_score: 0.7875 - val_loss: 0.3396 - val_accuracy: 0.8846 - val_precision: 0.8846 - val_recall: 0.8846 - val_auc: 0.9535 - val_f1_score: 0.8846 - lr: 0.0010
# Epoch 14/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4876 - accuracy: 0.7950 - precision: 0.7950 - recall: 0.7950 - auc: 0.8612 - f1_score: 0.7950
# Epoch 14: val_loss did not improve from 0.33786
# 71/71 [==============================] - 37s 512ms/step - loss: 0.4876 - accuracy: 0.7950 - precision: 0.7950 - recall: 0.7950 - auc: 0.8612 - f1_score: 0.7950 - val_loss: 0.4384 - val_accuracy: 0.8254 - val_precision: 0.8254 - val_recall: 0.8254 - val_auc: 0.9142 - val_f1_score: 0.8254 - lr: 0.0010
# Epoch 15/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4785 - accuracy: 0.8051 - precision: 0.8051 - recall: 0.8051 - auc: 0.8671 - f1_score: 0.8051
# Epoch 15: val_loss did not improve from 0.33786
# 71/71 [==============================] - 36s 506ms/step - loss: 0.4785 - accuracy: 0.8051 - precision: 0.8051 - recall: 0.8051 - auc: 0.8671 - f1_score: 0.8051 - val_loss: 0.3718 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9587 - val_f1_score: 0.8876 - lr: 0.0010
# Epoch 16/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4791 - accuracy: 0.8047 - precision: 0.8047 - recall: 0.8047 - auc: 0.8669 - f1_score: 0.8047
# Epoch 16: val_loss did not improve from 0.33786
# 71/71 [==============================] - 37s 512ms/step - loss: 0.4791 - accuracy: 0.8047 - precision: 0.8047 - recall: 0.8047 - auc: 0.8669 - f1_score: 0.8047 - val_loss: 0.3419 - val_accuracy: 0.8669 - val_precision: 0.8669 - val_recall: 0.8669 - val_auc: 0.9527 - val_f1_score: 0.8669 - lr: 0.0010
# Epoch 17/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4490 - accuracy: 0.8232 - precision: 0.8232 - recall: 0.8232 - auc: 0.8851 - f1_score: 0.8232
# Epoch 17: val_loss did not improve from 0.33786
# 71/71 [==============================] - 36s 498ms/step - loss: 0.4490 - accuracy: 0.8232 - precision: 0.8232 - recall: 0.8232 - auc: 0.8851 - f1_score: 0.8232 - val_loss: 0.4426 - val_accuracy: 0.7899 - val_precision: 0.7899 - val_recall: 0.7899 - val_auc: 0.9045 - val_f1_score: 0.7899 - lr: 0.0010
# Epoch 18/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4584 - accuracy: 0.8162 - precision: 0.8162 - recall: 0.8162 - auc: 0.8817 - f1_score: 0.8162
# Epoch 18: val_loss did not improve from 0.33786
# 71/71 [==============================] - 36s 508ms/step - loss: 0.4584 - accuracy: 0.8162 - precision: 0.8162 - recall: 0.8162 - auc: 0.8817 - f1_score: 0.8162 - val_loss: 0.3739 - val_accuracy: 0.8462 - val_precision: 0.8462 - val_recall: 0.8462 - val_auc: 0.9376 - val_f1_score: 0.8462 - lr: 0.0010
# Epoch 19/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4430 - accuracy: 0.8166 - precision: 0.8166 - recall: 0.8166 - auc: 0.8901 - f1_score: 0.8166
# Epoch 19: val_loss did not improve from 0.33786
# 71/71 [==============================] - 36s 499ms/step - loss: 0.4430 - accuracy: 0.8166 - precision: 0.8166 - recall: 0.8166 - auc: 0.8901 - f1_score: 0.8166 - val_loss: 0.3689 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9574 - val_f1_score: 0.8787 - lr: 0.0010
# Epoch 20/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4305 - accuracy: 0.8228 - precision: 0.8228 - recall: 0.8228 - auc: 0.8968 - f1_score: 0.8228
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 20: val_loss did not improve from 0.33786
# 71/71 [==============================] - 36s 502ms/step - loss: 0.4305 - accuracy: 0.8228 - precision: 0.8228 - recall: 0.8228 - auc: 0.8968 - f1_score: 0.8228 - val_loss: 0.3932 - val_accuracy: 0.8491 - val_precision: 0.8491 - val_recall: 0.8491 - val_auc: 0.9234 - val_f1_score: 0.8491 - lr: 0.0010
# Epoch 21/150
# 71/71 [==============================] - ETA: 0s - loss: 0.4012 - accuracy: 0.8409 - precision: 0.8409 - recall: 0.8409 - auc: 0.9121 - f1_score: 0.8409
# Epoch 21: val_loss improved from 0.33786 to 0.30717, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 36s 503ms/step - loss: 0.4012 - accuracy: 0.8409 - precision: 0.8409 - recall: 0.8409 - auc: 0.9121 - f1_score: 0.8409 - val_loss: 0.3072 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9665 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 22/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3908 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9166 - f1_score: 0.8462
# Epoch 22: val_loss did not improve from 0.30717
# 71/71 [==============================] - 35s 483ms/step - loss: 0.3908 - accuracy: 0.8462 - precision: 0.8462 - recall: 0.8462 - auc: 0.9166 - f1_score: 0.8462 - val_loss: 0.3822 - val_accuracy: 0.8550 - val_precision: 0.8550 - val_recall: 0.8550 - val_auc: 0.9297 - val_f1_score: 0.8550 - lr: 1.0000e-04
# Epoch 23/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3948 - accuracy: 0.8431 - precision: 0.8431 - recall: 0.8431 - auc: 0.9155 - f1_score: 0.8431
# Epoch 23: val_loss did not improve from 0.30717
# 71/71 [==============================] - 34s 476ms/step - loss: 0.3948 - accuracy: 0.8431 - precision: 0.8431 - recall: 0.8431 - auc: 0.9155 - f1_score: 0.8431 - val_loss: 0.3114 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9618 - val_f1_score: 0.8964 - lr: 1.0000e-04
# Epoch 24/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3941 - accuracy: 0.8445 - precision: 0.8445 - recall: 0.8445 - auc: 0.9148 - f1_score: 0.8445
# Epoch 24: val_loss improved from 0.30717 to 0.29550, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 36s 504ms/step - loss: 0.3941 - accuracy: 0.8445 - precision: 0.8445 - recall: 0.8445 - auc: 0.9148 - f1_score: 0.8445 - val_loss: 0.2955 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9715 - val_f1_score: 0.8994 - lr: 1.0000e-04
# Epoch 25/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3847 - accuracy: 0.8515 - precision: 0.8515 - recall: 0.8515 - auc: 0.9196 - f1_score: 0.8515
# Epoch 25: val_loss did not improve from 0.29550
# 71/71 [==============================] - 36s 500ms/step - loss: 0.3847 - accuracy: 0.8515 - precision: 0.8515 - recall: 0.8515 - auc: 0.9196 - f1_score: 0.8515 - val_loss: 0.3021 - val_accuracy: 0.8964 - val_precision: 0.8964 - val_recall: 0.8964 - val_auc: 0.9656 - val_f1_score: 0.8964 - lr: 1.0000e-04
# Epoch 26/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3895 - accuracy: 0.8383 - precision: 0.8383 - recall: 0.8383 - auc: 0.9175 - f1_score: 0.8383
# Epoch 26: val_loss improved from 0.29550 to 0.26776, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 36s 507ms/step - loss: 0.3895 - accuracy: 0.8383 - precision: 0.8383 - recall: 0.8383 - auc: 0.9175 - f1_score: 0.8383 - val_loss: 0.2678 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9729 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 27/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3802 - accuracy: 0.8498 - precision: 0.8498 - recall: 0.8498 - auc: 0.9214 - f1_score: 0.8498
# Epoch 27: val_loss did not improve from 0.26776
# 71/71 [==============================] - 32s 447ms/step - loss: 0.3802 - accuracy: 0.8498 - precision: 0.8498 - recall: 0.8498 - auc: 0.9214 - f1_score: 0.8498 - val_loss: 0.3504 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9399 - val_f1_score: 0.8787 - lr: 1.0000e-04
# Epoch 28/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3853 - accuracy: 0.8489 - precision: 0.8489 - recall: 0.8489 - auc: 0.9185 - f1_score: 0.8489
# Epoch 28: val_loss did not improve from 0.26776
# 71/71 [==============================] - 34s 480ms/step - loss: 0.3853 - accuracy: 0.8489 - precision: 0.8489 - recall: 0.8489 - auc: 0.9185 - f1_score: 0.8489 - val_loss: 0.2994 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9660 - val_f1_score: 0.8935 - lr: 1.0000e-04
# Epoch 29/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3764 - accuracy: 0.8533 - precision: 0.8533 - recall: 0.8533 - auc: 0.9228 - f1_score: 0.8533
# Epoch 29: val_loss improved from 0.26776 to 0.26248, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 37s 515ms/step - loss: 0.3764 - accuracy: 0.8533 - precision: 0.8533 - recall: 0.8533 - auc: 0.9228 - f1_score: 0.8533 - val_loss: 0.2625 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9762 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 30/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3748 - accuracy: 0.8520 - precision: 0.8520 - recall: 0.8520 - auc: 0.9236 - f1_score: 0.8520
# Epoch 30: val_loss did not improve from 0.26248
# 71/71 [==============================] - 35s 490ms/step - loss: 0.3748 - accuracy: 0.8520 - precision: 0.8520 - recall: 0.8520 - auc: 0.9236 - f1_score: 0.8520 - val_loss: 0.3350 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9490 - val_f1_score: 0.8728 - lr: 1.0000e-04
# Epoch 31/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3728 - accuracy: 0.8559 - precision: 0.8559 - recall: 0.8559 - auc: 0.9245 - f1_score: 0.8559
# Epoch 31: val_loss did not improve from 0.26248
# 71/71 [==============================] - 38s 525ms/step - loss: 0.3728 - accuracy: 0.8559 - precision: 0.8559 - recall: 0.8559 - auc: 0.9245 - f1_score: 0.8559 - val_loss: 0.2830 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9698 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 32/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3689 - accuracy: 0.8568 - precision: 0.8568 - recall: 0.8568 - auc: 0.9253 - f1_score: 0.8568
# Epoch 32: val_loss did not improve from 0.26248
# 71/71 [==============================] - 36s 502ms/step - loss: 0.3689 - accuracy: 0.8568 - precision: 0.8568 - recall: 0.8568 - auc: 0.9253 - f1_score: 0.8568 - val_loss: 0.2787 - val_accuracy: 0.9083 - val_precision: 0.9083 - val_recall: 0.9083 - val_auc: 0.9700 - val_f1_score: 0.9083 - lr: 1.0000e-04
# Epoch 33/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3699 - accuracy: 0.8520 - precision: 0.8520 - recall: 0.8520 - auc: 0.9248 - f1_score: 0.8520
# Epoch 33: val_loss did not improve from 0.26248
# 71/71 [==============================] - 34s 481ms/step - loss: 0.3699 - accuracy: 0.8520 - precision: 0.8520 - recall: 0.8520 - auc: 0.9248 - f1_score: 0.8520 - val_loss: 0.2904 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9673 - val_f1_score: 0.8935 - lr: 1.0000e-04
# Epoch 34/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3721 - accuracy: 0.8502 - precision: 0.8502 - recall: 0.8502 - auc: 0.9246 - f1_score: 0.8502
# Epoch 34: val_loss did not improve from 0.26248
# 71/71 [==============================] - 36s 498ms/step - loss: 0.3721 - accuracy: 0.8502 - precision: 0.8502 - recall: 0.8502 - auc: 0.9246 - f1_score: 0.8502 - val_loss: 0.3106 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9601 - val_f1_score: 0.8994 - lr: 1.0000e-04
# Epoch 35/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3668 - accuracy: 0.8582 - precision: 0.8582 - recall: 0.8582 - auc: 0.9268 - f1_score: 0.8582
# Epoch 35: val_loss did not improve from 0.26248
# 71/71 [==============================] - 35s 483ms/step - loss: 0.3668 - accuracy: 0.8582 - precision: 0.8582 - recall: 0.8582 - auc: 0.9268 - f1_score: 0.8582 - val_loss: 0.2921 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9638 - val_f1_score: 0.8994 - lr: 1.0000e-04
# Epoch 36/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3759 - accuracy: 0.8529 - precision: 0.8529 - recall: 0.8529 - auc: 0.9230 - f1_score: 0.8529
# Epoch 36: val_loss did not improve from 0.26248
# 71/71 [==============================] - 33s 469ms/step - loss: 0.3759 - accuracy: 0.8529 - precision: 0.8529 - recall: 0.8529 - auc: 0.9230 - f1_score: 0.8529 - val_loss: 0.2903 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9685 - val_f1_score: 0.9112 - lr: 1.0000e-04
# Epoch 37/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3671 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9268 - f1_score: 0.8546
# Epoch 37: val_loss did not improve from 0.26248
# 71/71 [==============================] - 35s 494ms/step - loss: 0.3671 - accuracy: 0.8546 - precision: 0.8546 - recall: 0.8546 - auc: 0.9268 - f1_score: 0.8546 - val_loss: 0.2664 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9716 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 38/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3628 - accuracy: 0.8630 - precision: 0.8630 - recall: 0.8630 - auc: 0.9285 - f1_score: 0.8630
# Epoch 38: val_loss did not improve from 0.26248
# 71/71 [==============================] - 36s 502ms/step - loss: 0.3628 - accuracy: 0.8630 - precision: 0.8630 - recall: 0.8630 - auc: 0.9285 - f1_score: 0.8630 - val_loss: 0.2829 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9673 - val_f1_score: 0.8994 - lr: 1.0000e-04
# Epoch 39/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3809 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - auc: 0.9194 - f1_score: 0.8511
# Epoch 39: val_loss improved from 0.26248 to 0.25345, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 36s 500ms/step - loss: 0.3809 - accuracy: 0.8511 - precision: 0.8511 - recall: 0.8511 - auc: 0.9194 - f1_score: 0.8511 - val_loss: 0.2535 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9773 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 40/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.8604 - precision: 0.8604 - recall: 0.8604 - auc: 0.9283 - f1_score: 0.8604
# Epoch 40: val_loss did not improve from 0.25345
# 71/71 [==============================] - 36s 500ms/step - loss: 0.3603 - accuracy: 0.8604 - precision: 0.8604 - recall: 0.8604 - auc: 0.9283 - f1_score: 0.8604 - val_loss: 0.2857 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9665 - val_f1_score: 0.9024 - lr: 1.0000e-04
# Epoch 41/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3705 - accuracy: 0.8621 - precision: 0.8621 - recall: 0.8621 - auc: 0.9254 - f1_score: 0.8621
# Epoch 41: val_loss did not improve from 0.25345
# 71/71 [==============================] - 35s 490ms/step - loss: 0.3705 - accuracy: 0.8621 - precision: 0.8621 - recall: 0.8621 - auc: 0.9254 - f1_score: 0.8621 - val_loss: 0.2629 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9742 - val_f1_score: 0.9112 - lr: 1.0000e-04
# Epoch 42/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3595 - accuracy: 0.8652 - precision: 0.8652 - recall: 0.8652 - auc: 0.9289 - f1_score: 0.8652
# Epoch 42: val_loss did not improve from 0.25345
# 71/71 [==============================] - 36s 497ms/step - loss: 0.3595 - accuracy: 0.8652 - precision: 0.8652 - recall: 0.8652 - auc: 0.9289 - f1_score: 0.8652 - val_loss: 0.3187 - val_accuracy: 0.8787 - val_precision: 0.8787 - val_recall: 0.8787 - val_auc: 0.9525 - val_f1_score: 0.8787 - lr: 1.0000e-04
# Epoch 43/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3589 - accuracy: 0.8630 - precision: 0.8630 - recall: 0.8630 - auc: 0.9284 - f1_score: 0.8630
# Epoch 43: val_loss did not improve from 0.25345
# 71/71 [==============================] - 37s 522ms/step - loss: 0.3589 - accuracy: 0.8630 - precision: 0.8630 - recall: 0.8630 - auc: 0.9284 - f1_score: 0.8630 - val_loss: 0.2731 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9709 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 44/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3588 - accuracy: 0.8630 - precision: 0.8630 - recall: 0.8630 - auc: 0.9287 - f1_score: 0.8630
# Epoch 44: val_loss did not improve from 0.25345
# 71/71 [==============================] - 34s 477ms/step - loss: 0.3588 - accuracy: 0.8630 - precision: 0.8630 - recall: 0.8630 - auc: 0.9287 - f1_score: 0.8630 - val_loss: 0.2749 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9685 - val_f1_score: 0.8994 - lr: 1.0000e-04
# Epoch 45/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3545 - accuracy: 0.8714 - precision: 0.8714 - recall: 0.8714 - auc: 0.9307 - f1_score: 0.8714
# Epoch 45: val_loss improved from 0.25345 to 0.24170, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 37s 522ms/step - loss: 0.3545 - accuracy: 0.8714 - precision: 0.8714 - recall: 0.8714 - auc: 0.9307 - f1_score: 0.8714 - val_loss: 0.2417 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9753 - val_f1_score: 0.9231 - lr: 1.0000e-04
# Epoch 46/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3535 - accuracy: 0.8701 - precision: 0.8701 - recall: 0.8701 - auc: 0.9315 - f1_score: 0.8701
# Epoch 46: val_loss did not improve from 0.24170
# 71/71 [==============================] - 38s 526ms/step - loss: 0.3535 - accuracy: 0.8701 - precision: 0.8701 - recall: 0.8701 - auc: 0.9315 - f1_score: 0.8701 - val_loss: 0.2706 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9703 - val_f1_score: 0.8994 - lr: 1.0000e-04
# Epoch 47/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3466 - accuracy: 0.8732 - precision: 0.8732 - recall: 0.8732 - auc: 0.9335 - f1_score: 0.8732
# Epoch 47: val_loss did not improve from 0.24170
# 71/71 [==============================] - 37s 515ms/step - loss: 0.3466 - accuracy: 0.8732 - precision: 0.8732 - recall: 0.8732 - auc: 0.9335 - f1_score: 0.8732 - val_loss: 0.2748 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9701 - val_f1_score: 0.8994 - lr: 1.0000e-04
# Epoch 48/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3498 - accuracy: 0.8719 - precision: 0.8719 - recall: 0.8719 - auc: 0.9326 - f1_score: 0.8719
# Epoch 48: val_loss improved from 0.24170 to 0.23567, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 35s 483ms/step - loss: 0.3498 - accuracy: 0.8719 - precision: 0.8719 - recall: 0.8719 - auc: 0.9326 - f1_score: 0.8719 - val_loss: 0.2357 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9801 - val_f1_score: 0.9231 - lr: 1.0000e-04
# Epoch 49/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3499 - accuracy: 0.8657 - precision: 0.8657 - recall: 0.8657 - auc: 0.9342 - f1_score: 0.8657
# Epoch 49: val_loss improved from 0.23567 to 0.22154, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 36s 500ms/step - loss: 0.3499 - accuracy: 0.8657 - precision: 0.8657 - recall: 0.8657 - auc: 0.9342 - f1_score: 0.8657 - val_loss: 0.2215 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9820 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 50/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.8657 - precision: 0.8657 - recall: 0.8657 - auc: 0.9343 - f1_score: 0.8657
# Epoch 50: val_loss did not improve from 0.22154
# 71/71 [==============================] - 33s 461ms/step - loss: 0.3473 - accuracy: 0.8657 - precision: 0.8657 - recall: 0.8657 - auc: 0.9343 - f1_score: 0.8657 - val_loss: 0.2765 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9678 - val_f1_score: 0.8994 - lr: 1.0000e-04
# Epoch 51/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3587 - accuracy: 0.8714 - precision: 0.8714 - recall: 0.8714 - auc: 0.9299 - f1_score: 0.8714
# Epoch 51: val_loss did not improve from 0.22154
# 71/71 [==============================] - 38s 528ms/step - loss: 0.3587 - accuracy: 0.8714 - precision: 0.8714 - recall: 0.8714 - auc: 0.9299 - f1_score: 0.8714 - val_loss: 0.2566 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9756 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 52/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3557 - accuracy: 0.8626 - precision: 0.8626 - recall: 0.8626 - auc: 0.9320 - f1_score: 0.8626
# Epoch 52: val_loss did not improve from 0.22154
# 71/71 [==============================] - 34s 470ms/step - loss: 0.3557 - accuracy: 0.8626 - precision: 0.8626 - recall: 0.8626 - auc: 0.9320 - f1_score: 0.8626 - val_loss: 0.3196 - val_accuracy: 0.8876 - val_precision: 0.8876 - val_recall: 0.8876 - val_auc: 0.9512 - val_f1_score: 0.8876 - lr: 1.0000e-04
# Epoch 53/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3424 - accuracy: 0.8745 - precision: 0.8745 - recall: 0.8745 - auc: 0.9362 - f1_score: 0.8745
# Epoch 53: val_loss did not improve from 0.22154
# 71/71 [==============================] - 37s 512ms/step - loss: 0.3424 - accuracy: 0.8745 - precision: 0.8745 - recall: 0.8745 - auc: 0.9362 - f1_score: 0.8745 - val_loss: 0.4100 - val_accuracy: 0.8284 - val_precision: 0.8284 - val_recall: 0.8284 - val_auc: 0.9112 - val_f1_score: 0.8284 - lr: 1.0000e-04
# Epoch 54/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3479 - accuracy: 0.8705 - precision: 0.8705 - recall: 0.8705 - auc: 0.9332 - f1_score: 0.8705
# Epoch 54: val_loss did not improve from 0.22154
# 71/71 [==============================] - 36s 509ms/step - loss: 0.3479 - accuracy: 0.8705 - precision: 0.8705 - recall: 0.8705 - auc: 0.9332 - f1_score: 0.8705 - val_loss: 0.2263 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9814 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 55/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3433 - accuracy: 0.8829 - precision: 0.8829 - recall: 0.8829 - auc: 0.9343 - f1_score: 0.8829
# Epoch 55: val_loss did not improve from 0.22154
# 71/71 [==============================] - 38s 537ms/step - loss: 0.3433 - accuracy: 0.8829 - precision: 0.8829 - recall: 0.8829 - auc: 0.9343 - f1_score: 0.8829 - val_loss: 0.3062 - val_accuracy: 0.8757 - val_precision: 0.8757 - val_recall: 0.8757 - val_auc: 0.9586 - val_f1_score: 0.8757 - lr: 1.0000e-04
# Epoch 56/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3446 - accuracy: 0.8727 - precision: 0.8727 - recall: 0.8727 - auc: 0.9350 - f1_score: 0.8727
# Epoch 56: val_loss improved from 0.22154 to 0.21920, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 39s 551ms/step - loss: 0.3446 - accuracy: 0.8727 - precision: 0.8727 - recall: 0.8727 - auc: 0.9350 - f1_score: 0.8727 - val_loss: 0.2192 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9838 - val_f1_score: 0.9349 - lr: 1.0000e-04
# Epoch 57/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3501 - accuracy: 0.8732 - precision: 0.8732 - recall: 0.8732 - auc: 0.9327 - f1_score: 0.8732
# Epoch 57: val_loss did not improve from 0.21920
# 71/71 [==============================] - 34s 476ms/step - loss: 0.3501 - accuracy: 0.8732 - precision: 0.8732 - recall: 0.8732 - auc: 0.9327 - f1_score: 0.8732 - val_loss: 0.2413 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9778 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 58/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8754 - precision: 0.8754 - recall: 0.8754 - auc: 0.9387 - f1_score: 0.8754
# Epoch 58: val_loss did not improve from 0.21920
# 71/71 [==============================] - 36s 500ms/step - loss: 0.3369 - accuracy: 0.8754 - precision: 0.8754 - recall: 0.8754 - auc: 0.9387 - f1_score: 0.8754 - val_loss: 0.2393 - val_accuracy: 0.9172 - val_precision: 0.9172 - val_recall: 0.9172 - val_auc: 0.9786 - val_f1_score: 0.9172 - lr: 1.0000e-04
# Epoch 59/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3414 - accuracy: 0.8723 - precision: 0.8723 - recall: 0.8723 - auc: 0.9362 - f1_score: 0.8723
# Epoch 59: val_loss did not improve from 0.21920
# 71/71 [==============================] - 40s 555ms/step - loss: 0.3414 - accuracy: 0.8723 - precision: 0.8723 - recall: 0.8723 - auc: 0.9362 - f1_score: 0.8723 - val_loss: 0.2813 - val_accuracy: 0.8935 - val_precision: 0.8935 - val_recall: 0.8935 - val_auc: 0.9675 - val_f1_score: 0.8935 - lr: 1.0000e-04
# Epoch 60/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3411 - accuracy: 0.8758 - precision: 0.8758 - recall: 0.8758 - auc: 0.9362 - f1_score: 0.8758
# Epoch 60: val_loss did not improve from 0.21920
# 71/71 [==============================] - 38s 532ms/step - loss: 0.3411 - accuracy: 0.8758 - precision: 0.8758 - recall: 0.8758 - auc: 0.9362 - f1_score: 0.8758 - val_loss: 0.2597 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9728 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 61/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3346 - accuracy: 0.8785 - precision: 0.8785 - recall: 0.8785 - auc: 0.9381 - f1_score: 0.8785
# Epoch 61: val_loss did not improve from 0.21920
# 71/71 [==============================] - 37s 518ms/step - loss: 0.3346 - accuracy: 0.8785 - precision: 0.8785 - recall: 0.8785 - auc: 0.9381 - f1_score: 0.8785 - val_loss: 0.2875 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9641 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 62/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3358 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9375 - f1_score: 0.8749
# Epoch 62: val_loss did not improve from 0.21920
# 71/71 [==============================] - 37s 524ms/step - loss: 0.3358 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9375 - f1_score: 0.8749 - val_loss: 0.2930 - val_accuracy: 0.9024 - val_precision: 0.9024 - val_recall: 0.9024 - val_auc: 0.9624 - val_f1_score: 0.9024 - lr: 1.0000e-04
# Epoch 63/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3303 - accuracy: 0.8780 - precision: 0.8780 - recall: 0.8780 - auc: 0.9403 - f1_score: 0.8780
# Epoch 63: val_loss improved from 0.21920 to 0.21436, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 36s 501ms/step - loss: 0.3303 - accuracy: 0.8780 - precision: 0.8780 - recall: 0.8780 - auc: 0.9403 - f1_score: 0.8780 - val_loss: 0.2144 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9842 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 64/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3356 - accuracy: 0.8802 - precision: 0.8802 - recall: 0.8802 - auc: 0.9380 - f1_score: 0.8802
# Epoch 64: val_loss did not improve from 0.21436
# 71/71 [==============================] - 33s 464ms/step - loss: 0.3356 - accuracy: 0.8802 - precision: 0.8802 - recall: 0.8802 - auc: 0.9380 - f1_score: 0.8802 - val_loss: 0.2552 - val_accuracy: 0.9231 - val_precision: 0.9231 - val_recall: 0.9231 - val_auc: 0.9722 - val_f1_score: 0.9231 - lr: 1.0000e-04
# Epoch 65/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3401 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9367 - f1_score: 0.8749
# Epoch 65: val_loss did not improve from 0.21436
# 71/71 [==============================] - 35s 484ms/step - loss: 0.3401 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9367 - f1_score: 0.8749 - val_loss: 0.2629 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9727 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 66/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3369 - accuracy: 0.8732 - precision: 0.8732 - recall: 0.8732 - auc: 0.9384 - f1_score: 0.8732
# Epoch 66: val_loss did not improve from 0.21436
# 71/71 [==============================] - 35s 487ms/step - loss: 0.3369 - accuracy: 0.8732 - precision: 0.8732 - recall: 0.8732 - auc: 0.9384 - f1_score: 0.8732 - val_loss: 0.2193 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9815 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 67/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3267 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9420 - f1_score: 0.8820
# Epoch 67: val_loss did not improve from 0.21436
# 71/71 [==============================] - 33s 460ms/step - loss: 0.3267 - accuracy: 0.8820 - precision: 0.8820 - recall: 0.8820 - auc: 0.9420 - f1_score: 0.8820 - val_loss: 0.2172 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9822 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 68/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3315 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9397 - f1_score: 0.8798
# Epoch 68: val_loss did not improve from 0.21436
# 71/71 [==============================] - 34s 477ms/step - loss: 0.3315 - accuracy: 0.8798 - precision: 0.8798 - recall: 0.8798 - auc: 0.9397 - f1_score: 0.8798 - val_loss: 0.2226 - val_accuracy: 0.9260 - val_precision: 0.9260 - val_recall: 0.9260 - val_auc: 0.9824 - val_f1_score: 0.9260 - lr: 1.0000e-04
# Epoch 69/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3220 - accuracy: 0.8856 - precision: 0.8856 - recall: 0.8856 - auc: 0.9441 - f1_score: 0.8856
# Epoch 69: val_loss did not improve from 0.21436
# 71/71 [==============================] - 35s 495ms/step - loss: 0.3220 - accuracy: 0.8856 - precision: 0.8856 - recall: 0.8856 - auc: 0.9441 - f1_score: 0.8856 - val_loss: 0.2309 - val_accuracy: 0.9349 - val_precision: 0.9349 - val_recall: 0.9349 - val_auc: 0.9824 - val_f1_score: 0.9349 - lr: 1.0000e-04
# Epoch 70/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3295 - accuracy: 0.8807 - precision: 0.8807 - recall: 0.8807 - auc: 0.9406 - f1_score: 0.8807
# Epoch 70: val_loss did not improve from 0.21436
# 71/71 [==============================] - 35s 487ms/step - loss: 0.3295 - accuracy: 0.8807 - precision: 0.8807 - recall: 0.8807 - auc: 0.9406 - f1_score: 0.8807 - val_loss: 0.3371 - val_accuracy: 0.8639 - val_precision: 0.8639 - val_recall: 0.8639 - val_auc: 0.9420 - val_f1_score: 0.8639 - lr: 1.0000e-04
# Epoch 71/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3309 - accuracy: 0.8794 - precision: 0.8794 - recall: 0.8794 - auc: 0.9397 - f1_score: 0.8794
# Epoch 71: val_loss did not improve from 0.21436
# 71/71 [==============================] - 34s 476ms/step - loss: 0.3309 - accuracy: 0.8794 - precision: 0.8794 - recall: 0.8794 - auc: 0.9397 - f1_score: 0.8794 - val_loss: 0.2248 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9806 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 72/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3285 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9421 - f1_score: 0.8749
# Epoch 72: val_loss did not improve from 0.21436
# 71/71 [==============================] - 34s 481ms/step - loss: 0.3285 - accuracy: 0.8749 - precision: 0.8749 - recall: 0.8749 - auc: 0.9421 - f1_score: 0.8749 - val_loss: 0.2200 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9828 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 73/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3337 - accuracy: 0.8758 - precision: 0.8758 - recall: 0.8758 - auc: 0.9387 - f1_score: 0.8758
# Epoch 73: val_loss improved from 0.21436 to 0.21235, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 34s 470ms/step - loss: 0.3337 - accuracy: 0.8758 - precision: 0.8758 - recall: 0.8758 - auc: 0.9387 - f1_score: 0.8758 - val_loss: 0.2124 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9838 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 74/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3243 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9424 - f1_score: 0.8860
# Epoch 74: val_loss did not improve from 0.21235
# 71/71 [==============================] - 36s 497ms/step - loss: 0.3243 - accuracy: 0.8860 - precision: 0.8860 - recall: 0.8860 - auc: 0.9424 - f1_score: 0.8860 - val_loss: 0.2238 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9815 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 75/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3264 - accuracy: 0.8807 - precision: 0.8807 - recall: 0.8807 - auc: 0.9417 - f1_score: 0.8807
# Epoch 75: val_loss did not improve from 0.21235
# 71/71 [==============================] - 33s 466ms/step - loss: 0.3264 - accuracy: 0.8807 - precision: 0.8807 - recall: 0.8807 - auc: 0.9417 - f1_score: 0.8807 - val_loss: 0.2861 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9652 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 76/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3309 - accuracy: 0.8802 - precision: 0.8802 - recall: 0.8802 - auc: 0.9412 - f1_score: 0.8802
# Epoch 76: val_loss did not improve from 0.21235
# 71/71 [==============================] - 33s 466ms/step - loss: 0.3309 - accuracy: 0.8802 - precision: 0.8802 - recall: 0.8802 - auc: 0.9412 - f1_score: 0.8802 - val_loss: 0.2558 - val_accuracy: 0.9201 - val_precision: 0.9201 - val_recall: 0.9201 - val_auc: 0.9718 - val_f1_score: 0.9201 - lr: 1.0000e-04
# Epoch 77/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3265 - accuracy: 0.8811 - precision: 0.8811 - recall: 0.8811 - auc: 0.9427 - f1_score: 0.8811
# Epoch 77: val_loss did not improve from 0.21235
# 71/71 [==============================] - 33s 460ms/step - loss: 0.3265 - accuracy: 0.8811 - precision: 0.8811 - recall: 0.8811 - auc: 0.9427 - f1_score: 0.8811 - val_loss: 0.3129 - val_accuracy: 0.8728 - val_precision: 0.8728 - val_recall: 0.8728 - val_auc: 0.9522 - val_f1_score: 0.8728 - lr: 1.0000e-04
# Epoch 78/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3187 - accuracy: 0.8886 - precision: 0.8886 - recall: 0.8886 - auc: 0.9450 - f1_score: 0.8886
# Epoch 78: val_loss did not improve from 0.21235
# 71/71 [==============================] - 33s 460ms/step - loss: 0.3187 - accuracy: 0.8886 - precision: 0.8886 - recall: 0.8886 - auc: 0.9450 - f1_score: 0.8886 - val_loss: 0.2334 - val_accuracy: 0.9112 - val_precision: 0.9112 - val_recall: 0.9112 - val_auc: 0.9758 - val_f1_score: 0.9112 - lr: 1.0000e-04
# Epoch 79/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3145 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9469 - f1_score: 0.8833
# Epoch 79: val_loss did not improve from 0.21235
# 71/71 [==============================] - 36s 502ms/step - loss: 0.3145 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9469 - f1_score: 0.8833 - val_loss: 0.2900 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9644 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 80/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3128 - accuracy: 0.8864 - precision: 0.8864 - recall: 0.8864 - auc: 0.9482 - f1_score: 0.8864
# Epoch 80: val_loss did not improve from 0.21235
# 71/71 [==============================] - 35s 495ms/step - loss: 0.3128 - accuracy: 0.8864 - precision: 0.8864 - recall: 0.8864 - auc: 0.9482 - f1_score: 0.8864 - val_loss: 0.2258 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9782 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 81/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2978 - accuracy: 0.8957 - precision: 0.8957 - recall: 0.8957 - auc: 0.9534 - f1_score: 0.8957
# Epoch 81: val_loss improved from 0.21235 to 0.18353, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 35s 493ms/step - loss: 0.2978 - accuracy: 0.8957 - precision: 0.8957 - recall: 0.8957 - auc: 0.9534 - f1_score: 0.8957 - val_loss: 0.1835 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9857 - val_f1_score: 0.9467 - lr: 1.0000e-04
# Epoch 82/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2984 - accuracy: 0.8970 - precision: 0.8970 - recall: 0.8970 - auc: 0.9535 - f1_score: 0.8970
# Epoch 82: val_loss did not improve from 0.18353
# 71/71 [==============================] - 35s 482ms/step - loss: 0.2984 - accuracy: 0.8970 - precision: 0.8970 - recall: 0.8970 - auc: 0.9535 - f1_score: 0.8970 - val_loss: 0.3018 - val_accuracy: 0.8905 - val_precision: 0.8905 - val_recall: 0.8905 - val_auc: 0.9526 - val_f1_score: 0.8905 - lr: 1.0000e-04
# Epoch 83/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3156 - accuracy: 0.8856 - precision: 0.8856 - recall: 0.8856 - auc: 0.9476 - f1_score: 0.8856
# Epoch 83: val_loss did not improve from 0.18353
# 71/71 [==============================] - 33s 458ms/step - loss: 0.3156 - accuracy: 0.8856 - precision: 0.8856 - recall: 0.8856 - auc: 0.9476 - f1_score: 0.8856 - val_loss: 0.2303 - val_accuracy: 0.9320 - val_precision: 0.9320 - val_recall: 0.9320 - val_auc: 0.9754 - val_f1_score: 0.9320 - lr: 1.0000e-04
# Epoch 84/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2959 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9545 - f1_score: 0.8931
# Epoch 84: val_loss did not improve from 0.18353
# 71/71 [==============================] - 35s 489ms/step - loss: 0.2959 - accuracy: 0.8931 - precision: 0.8931 - recall: 0.8931 - auc: 0.9545 - f1_score: 0.8931 - val_loss: 0.2770 - val_accuracy: 0.9142 - val_precision: 0.9142 - val_recall: 0.9142 - val_auc: 0.9616 - val_f1_score: 0.9142 - lr: 1.0000e-04
# Epoch 85/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.8922 - precision: 0.8922 - recall: 0.8922 - auc: 0.9556 - f1_score: 0.8922
# Epoch 85: val_loss did not improve from 0.18353
# 71/71 [==============================] - 34s 479ms/step - loss: 0.2921 - accuracy: 0.8922 - precision: 0.8922 - recall: 0.8922 - auc: 0.9556 - f1_score: 0.8922 - val_loss: 0.2981 - val_accuracy: 0.8994 - val_precision: 0.8994 - val_recall: 0.8994 - val_auc: 0.9548 - val_f1_score: 0.8994 - lr: 1.0000e-04
# Epoch 86/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2953 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9545 - f1_score: 0.8926
# Epoch 86: val_loss did not improve from 0.18353
# 71/71 [==============================] - 37s 519ms/step - loss: 0.2953 - accuracy: 0.8926 - precision: 0.8926 - recall: 0.8926 - auc: 0.9545 - f1_score: 0.8926 - val_loss: 0.2376 - val_accuracy: 0.9053 - val_precision: 0.9053 - val_recall: 0.9053 - val_auc: 0.9753 - val_f1_score: 0.9053 - lr: 1.0000e-04
# Epoch 87/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.8948 - precision: 0.8948 - recall: 0.8948 - auc: 0.9577 - f1_score: 0.8948
# Epoch 87: val_loss did not improve from 0.18353
# 71/71 [==============================] - 35s 488ms/step - loss: 0.2874 - accuracy: 0.8948 - precision: 0.8948 - recall: 0.8948 - auc: 0.9577 - f1_score: 0.8948 - val_loss: 0.3315 - val_accuracy: 0.8609 - val_precision: 0.8609 - val_recall: 0.8609 - val_auc: 0.9420 - val_f1_score: 0.8609 - lr: 1.0000e-04
# Epoch 88/150
# 71/71 [==============================] - ETA: 0s - loss: 0.3048 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9528 - f1_score: 0.8833
# Epoch 88: val_loss did not improve from 0.18353
# 71/71 [==============================] - 35s 490ms/step - loss: 0.3048 - accuracy: 0.8833 - precision: 0.8833 - recall: 0.8833 - auc: 0.9528 - f1_score: 0.8833 - val_loss: 0.1995 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9835 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 89/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2936 - accuracy: 0.8979 - precision: 0.8979 - recall: 0.8979 - auc: 0.9540 - f1_score: 0.8979
# Epoch 89: val_loss did not improve from 0.18353
# ...
# Epoch 121/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2127 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9777 - f1_score: 0.9289
# Epoch 121: val_loss did not improve from 0.12190
# 71/71 [==============================] - 38s 529ms/step - loss: 0.2127 - accuracy: 0.9289 - precision: 0.9289 - recall: 0.9289 - auc: 0.9777 - f1_score: 0.9289 - val_loss: 0.1874 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9846 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 122/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2170 - accuracy: 0.9218 - precision: 0.9218 - recall: 0.9218 - auc: 0.9770 - f1_score: 0.9218
# Epoch 122: val_loss did not improve from 0.12190
# 71/71 [==============================] - 37s 524ms/step - loss: 0.2170 - accuracy: 0.9218 - precision: 0.9218 - recall: 0.9218 - auc: 0.9770 - f1_score: 0.9218 - val_loss: 0.1813 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9861 - val_f1_score: 0.9438 - lr: 1.0000e-04
# Epoch 123/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2164 - accuracy: 0.9240 - precision: 0.9240 - recall: 0.9240 - auc: 0.9770 - f1_score: 0.9240
# Epoch 123: val_loss did not improve from 0.12190
# 71/71 [==============================] - 36s 500ms/step - loss: 0.2164 - accuracy: 0.9240 - precision: 0.9240 - recall: 0.9240 - auc: 0.9770 - f1_score: 0.9240 - val_loss: 0.1685 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9872 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 124/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2283 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9743 - f1_score: 0.9178
# Epoch 124: val_loss did not improve from 0.12190
# 71/71 [==============================] - 36s 503ms/step - loss: 0.2283 - accuracy: 0.9178 - precision: 0.9178 - recall: 0.9178 - auc: 0.9743 - f1_score: 0.9178 - val_loss: 0.1752 - val_accuracy: 0.9379 - val_precision: 0.9379 - val_recall: 0.9379 - val_auc: 0.9865 - val_f1_score: 0.9379 - lr: 1.0000e-04
# Epoch 125/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2113 - accuracy: 0.9240 - precision: 0.9240 - recall: 0.9240 - auc: 0.9786 - f1_score: 0.9240
# Epoch 125: val_loss did not improve from 0.12190
# 71/71 [==============================] - 36s 509ms/step - loss: 0.2113 - accuracy: 0.9240 - precision: 0.9240 - recall: 0.9240 - auc: 0.9786 - f1_score: 0.9240 - val_loss: 0.1664 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9895 - val_f1_score: 0.9527 - lr: 1.0000e-04
# Epoch 126/150
# 71/71 [==============================] - ETA: 0s - loss: 0.2121 - accuracy: 0.9266 - precision: 0.9266 - recall: 0.9266 - auc: 0.9776 - f1_score: 0.9266
# Epoch 126: val_loss did not improve from 0.12190
# 71/71 [==============================] - 34s 475ms/step - loss: 0.2121 - accuracy: 0.9266 - precision: 0.9266 - recall: 0.9266 - auc: 0.9776 - f1_score: 0.9266 - val_loss: 0.2051 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9810 - val_f1_score: 0.9408 - lr: 1.0000e-04
# Epoch 127/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1988 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9808 - f1_score: 0.9311
# Epoch 127: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 127: val_loss did not improve from 0.12190
# 71/71 [==============================] - 35s 491ms/step - loss: 0.1988 - accuracy: 0.9311 - precision: 0.9311 - recall: 0.9311 - auc: 0.9808 - f1_score: 0.9311 - val_loss: 0.1570 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9871 - val_f1_score: 0.9586 - lr: 1.0000e-04
# Epoch 128/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1823 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9853 - f1_score: 0.9350
# Epoch 128: val_loss did not improve from 0.12190
# 71/71 [==============================] - 36s 500ms/step - loss: 0.1823 - accuracy: 0.9350 - precision: 0.9350 - recall: 0.9350 - auc: 0.9853 - f1_score: 0.9350 - val_loss: 0.1553 - val_accuracy: 0.9586 - val_precision: 0.9586 - val_recall: 0.9586 - val_auc: 0.9905 - val_f1_score: 0.9586 - lr: 1.0000e-05
# Epoch 129/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1634 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9880 - f1_score: 0.9487
# Epoch 129: val_loss did not improve from 0.12190
# 71/71 [==============================] - 36s 503ms/step - loss: 0.1634 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9880 - f1_score: 0.9487 - val_loss: 0.1269 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9945 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 130/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1706 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9871 - f1_score: 0.9421
# Epoch 130: val_loss did not improve from 0.12190
# 71/71 [==============================] - 35s 491ms/step - loss: 0.1706 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9871 - f1_score: 0.9421 - val_loss: 0.1250 - val_accuracy: 0.9763 - val_precision: 0.9763 - val_recall: 0.9763 - val_auc: 0.9933 - val_f1_score: 0.9763 - lr: 1.0000e-05
# Epoch 131/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1672 - accuracy: 0.9412 - precision: 0.9412 - recall: 0.9412 - auc: 0.9874 - f1_score: 0.9412
# Epoch 131: val_loss did not improve from 0.12190
# 71/71 [==============================] - 34s 473ms/step - loss: 0.1672 - accuracy: 0.9412 - precision: 0.9412 - recall: 0.9412 - auc: 0.9874 - f1_score: 0.9412 - val_loss: 0.1384 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9925 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 132/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1737 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9856 - f1_score: 0.9421
# Epoch 132: val_loss did not improve from 0.12190
# 71/71 [==============================] - 35s 487ms/step - loss: 0.1737 - accuracy: 0.9421 - precision: 0.9421 - recall: 0.9421 - auc: 0.9856 - f1_score: 0.9421 - val_loss: 0.1299 - val_accuracy: 0.9704 - val_precision: 0.9704 - val_recall: 0.9704 - val_auc: 0.9931 - val_f1_score: 0.9704 - lr: 1.0000e-05
# Epoch 133/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1764 - accuracy: 0.9461 - precision: 0.9461 - recall: 0.9461 - auc: 0.9853 - f1_score: 0.9461
# Epoch 133: val_loss did not improve from 0.12190
# 71/71 [==============================] - 32s 446ms/step - loss: 0.1764 - accuracy: 0.9461 - precision: 0.9461 - recall: 0.9461 - auc: 0.9853 - f1_score: 0.9461 - val_loss: 0.1507 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9914 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 134/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9443 - precision: 0.9443 - recall: 0.9443 - auc: 0.9864 - f1_score: 0.9443
# Epoch 134: val_loss did not improve from 0.12190
# 71/71 [==============================] - 36s 509ms/step - loss: 0.1710 - accuracy: 0.9443 - precision: 0.9443 - recall: 0.9443 - auc: 0.9864 - f1_score: 0.9443 - val_loss: 0.1644 - val_accuracy: 0.9438 - val_precision: 0.9438 - val_recall: 0.9438 - val_auc: 0.9886 - val_f1_score: 0.9438 - lr: 1.0000e-05
# Epoch 135/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1640 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9880 - f1_score: 0.9487
# Epoch 135: val_loss did not improve from 0.12190
# 71/71 [==============================] - 35s 489ms/step - loss: 0.1640 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9880 - f1_score: 0.9487 - val_loss: 0.1485 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9898 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 136/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1683 - accuracy: 0.9443 - precision: 0.9443 - recall: 0.9443 - auc: 0.9868 - f1_score: 0.9443
# Epoch 136: val_loss did not improve from 0.12190
# 71/71 [==============================] - 35s 487ms/step - loss: 0.1683 - accuracy: 0.9443 - precision: 0.9443 - recall: 0.9443 - auc: 0.9868 - f1_score: 0.9443 - val_loss: 0.1550 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9890 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 137/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1574 - accuracy: 0.9470 - precision: 0.9470 - recall: 0.9470 - auc: 0.9892 - f1_score: 0.9470
# Epoch 137: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 137: val_loss did not improve from 0.12190
# 71/71 [==============================] - 35s 488ms/step - loss: 0.1574 - accuracy: 0.9470 - precision: 0.9470 - recall: 0.9470 - auc: 0.9892 - f1_score: 0.9470 - val_loss: 0.1835 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9828 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 138/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1592 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9887 - f1_score: 0.9505
# Epoch 138: val_loss did not improve from 0.12190
# 71/71 [==============================] - 36s 501ms/step - loss: 0.1592 - accuracy: 0.9505 - precision: 0.9505 - recall: 0.9505 - auc: 0.9887 - f1_score: 0.9505 - val_loss: 0.1476 - val_accuracy: 0.9615 - val_precision: 0.9615 - val_recall: 0.9615 - val_auc: 0.9913 - val_f1_score: 0.9615 - lr: 1.0000e-05
# Epoch 139/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1635 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9875 - f1_score: 0.9487
# Epoch 139: val_loss improved from 0.12190 to 0.12189, saving model to /root/Breast Cancer/Model Code/ModelFileH5/Version8_run4-DIR.h5
# 71/71 [==============================] - 34s 472ms/step - loss: 0.1635 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9875 - f1_score: 0.9487 - val_loss: 0.1219 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9947 - val_f1_score: 0.9734 - lr: 1.0000e-05
# Epoch 140/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1618 - accuracy: 0.9461 - precision: 0.9461 - recall: 0.9461 - auc: 0.9880 - f1_score: 0.9461
# Epoch 140: val_loss did not improve from 0.12189
# 71/71 [==============================] - 37s 518ms/step - loss: 0.1618 - accuracy: 0.9461 - precision: 0.9461 - recall: 0.9461 - auc: 0.9880 - f1_score: 0.9461 - val_loss: 0.1480 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9903 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 141/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1577 - accuracy: 0.9470 - precision: 0.9470 - recall: 0.9470 - auc: 0.9888 - f1_score: 0.9470
# Epoch 141: val_loss did not improve from 0.12189
# 71/71 [==============================] - 34s 475ms/step - loss: 0.1577 - accuracy: 0.9470 - precision: 0.9470 - recall: 0.9470 - auc: 0.9888 - f1_score: 0.9470 - val_loss: 0.1413 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9905 - val_f1_score: 0.9675 - lr: 1.0000e-05
# Epoch 142/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1569 - accuracy: 0.9545 - precision: 0.9545 - recall: 0.9545 - auc: 0.9888 - f1_score: 0.9545
# Epoch 142: val_loss did not improve from 0.12189
# 71/71 [==============================] - 34s 482ms/step - loss: 0.1569 - accuracy: 0.9545 - precision: 0.9545 - recall: 0.9545 - auc: 0.9888 - f1_score: 0.9545 - val_loss: 0.1714 - val_accuracy: 0.9408 - val_precision: 0.9408 - val_recall: 0.9408 - val_auc: 0.9866 - val_f1_score: 0.9408 - lr: 1.0000e-05
# Epoch 143/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1530 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9900 - f1_score: 0.9474
# Epoch 143: val_loss did not improve from 0.12189
# 71/71 [==============================] - 34s 473ms/step - loss: 0.1530 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9900 - f1_score: 0.9474 - val_loss: 0.1661 - val_accuracy: 0.9527 - val_precision: 0.9527 - val_recall: 0.9527 - val_auc: 0.9857 - val_f1_score: 0.9527 - lr: 1.0000e-05
# Epoch 144/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1604 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9877 - f1_score: 0.9487
# Epoch 144: val_loss did not improve from 0.12189
# 71/71 [==============================] - 34s 481ms/step - loss: 0.1604 - accuracy: 0.9487 - precision: 0.9487 - recall: 0.9487 - auc: 0.9877 - f1_score: 0.9487 - val_loss: 0.1445 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9910 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 145/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9452 - precision: 0.9452 - recall: 0.9452 - auc: 0.9876 - f1_score: 0.9452
# Epoch 145: val_loss did not improve from 0.12189
# 71/71 [==============================] - 34s 479ms/step - loss: 0.1658 - accuracy: 0.9452 - precision: 0.9452 - recall: 0.9452 - auc: 0.9876 - f1_score: 0.9452 - val_loss: 0.1635 - val_accuracy: 0.9467 - val_precision: 0.9467 - val_recall: 0.9467 - val_auc: 0.9887 - val_f1_score: 0.9467 - lr: 1.0000e-05
# Epoch 146/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1611 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9878 - f1_score: 0.9474
# Epoch 146: val_loss did not improve from 0.12189
# 71/71 [==============================] - 36s 501ms/step - loss: 0.1611 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9878 - f1_score: 0.9474 - val_loss: 0.1460 - val_accuracy: 0.9645 - val_precision: 0.9645 - val_recall: 0.9645 - val_auc: 0.9893 - val_f1_score: 0.9645 - lr: 1.0000e-05
# Epoch 147/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.9448 - precision: 0.9448 - recall: 0.9448 - auc: 0.9881 - f1_score: 0.9448
# Epoch 147: val_loss did not improve from 0.12189
# 71/71 [==============================] - 35s 483ms/step - loss: 0.1626 - accuracy: 0.9448 - precision: 0.9448 - recall: 0.9448 - auc: 0.9881 - f1_score: 0.9448 - val_loss: 0.1415 - val_accuracy: 0.9556 - val_precision: 0.9556 - val_recall: 0.9556 - val_auc: 0.9913 - val_f1_score: 0.9556 - lr: 1.0000e-05
# Epoch 148/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9893 - f1_score: 0.9474
# Epoch 148: val_loss did not improve from 0.12189
# 71/71 [==============================] - 35s 491ms/step - loss: 0.1541 - accuracy: 0.9474 - precision: 0.9474 - recall: 0.9474 - auc: 0.9893 - f1_score: 0.9474 - val_loss: 0.1671 - val_accuracy: 0.9497 - val_precision: 0.9497 - val_recall: 0.9497 - val_auc: 0.9876 - val_f1_score: 0.9497 - lr: 1.0000e-05
# Epoch 149/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1558 - accuracy: 0.9470 - precision: 0.9470 - recall: 0.9470 - auc: 0.9890 - f1_score: 0.9470
# Epoch 149: val_loss did not improve from 0.12189
# 71/71 [==============================] - 35s 483ms/step - loss: 0.1558 - accuracy: 0.9470 - precision: 0.9470 - recall: 0.9470 - auc: 0.9890 - f1_score: 0.9470 - val_loss: 0.1295 - val_accuracy: 0.9734 - val_precision: 0.9734 - val_recall: 0.9734 - val_auc: 0.9928 - val_f1_score: 0.9734 - lr: 1.0000e-05
# Epoch 150/150
# 71/71 [==============================] - ETA: 0s - loss: 0.1500 - accuracy: 0.9501 - precision: 0.9501 - recall: 0.9501 - auc: 0.9902 - f1_score: 0.9501
# Epoch 150: val_loss did not improve from 0.12189
# 71/71 [==============================] - 35s 493ms/step - loss: 0.1500 - accuracy: 0.9501 - precision: 0.9501 - recall: 0.9501 - auc: 0.9902 - f1_score: 0.9501 - val_loss: 0.1380 - val_accuracy: 0.9675 - val_precision: 0.9675 - val_recall: 0.9675 - val_auc: 0.9911 - val_f1_score: 0.9675 - lr: 1.0000e-05

# %%
plt.figure(figsize=(18, 12))

plt.subplot(2, 3, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Training Accuracy', 'Validation Accuracy'], loc='lower right')

plt.subplot(2, 3, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'], loc='upper right')

plt.subplot(2, 3, 3)
plt.plot(history.history['precision'])
plt.plot(history.history['val_precision'])
plt.title('Model Precision')
plt.xlabel('Epoch')
plt.ylabel('Precision')
plt.legend(['Training Precision', 'Validation Precision'], loc='lower right')


plt.subplot(2, 3, 4)
plt.plot(history.history['recall'])
plt.plot(history.history['val_recall'])
plt.title('Model Recall')
plt.xlabel('Epoch')
plt.ylabel('Recall')
plt.legend(['Training Recall', 'Validation Recall'], loc='lower right')

plt.subplot(2, 3, 5)
plt.plot(history.history['f1_score'])
plt.plot(history.history['val_f1_score'])
plt.title('Model F1-Score')
plt.xlabel('Epoch')
plt.ylabel('F1-Score')
plt.legend(['Training F1-Score', 'Validation F1-Score'], loc='lower right')

# plt.subplot(2, 3, 5)
# plt.plot(range(1, len(f1_score_callback.train_f1_scores) + 1), f1_score_callback.train_f1_scores, label='Training F1 Score')
# plt.plot(range(1, len(f1_score_callback.val_f1_scores) + 1), f1_score_callback.val_f1_scores, label='Validation F1 Score')
# plt.title('Model F1-Score')
# plt.xlabel('Epoch')
# plt.ylabel('F1-Score')
# plt.legend(['F1 Score'], loc='lower right')


plt.subplot(2, 3, 6)
plt.plot(history.history['auc'])
plt.plot(history.history['val_auc'])
plt.title('Model AUC')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend(['Training AUC', 'Validation AUC'], loc='lower right')

plt.tight_layout()
plt.show()

# %%
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix

# 收集图像和真实标签
all_images, all_true_labels = zip(*[next(test_generator) for _ in range(test_generator.samples // test_generator.batch_size)])
all_images = np.concatenate(all_images)
all_true_labels = np.argmax(np.concatenate(all_true_labels), axis=1)

# 进行预测并获取预测标签
predictions = DIR.predict(all_images)
predicted_labels = np.argmax(predictions, axis=1)

# 生成并绘制混淆矩阵
conf_matrix = confusion_matrix(all_true_labels, predicted_labels)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=["Class 0", "Class 1"], yticklabels=["Class 0", "Class 1"])
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 9/9 [==============================] - 1s 66ms/step

# %%
from sklearn.metrics import f1_score


# 计算F1-Score
f1 = f1_score(all_true_labels, predicted_labels, average='macro')

print("F1-Score:", f1)


f1_each_class = f1_score(all_true_labels, predicted_labels, average=None)
print("F1-Score for each class:", f1_each_class)
# Out:
# F1-Score: 0.9430862176048783
# F1-Score for each class: [0.92134831 0.96482412]

# %%
#compute precision-recall score
from sklearn.metrics import roc_curve, auc

#compute precision, recall(sensitivity), and threshold values
fpr, tpr, thresholds = roc_curve(all_true_labels, predicted_labels)

#compute the AUC score
roc_auc= auc(fpr, tpr)

#plot the precision-recall curve
plt.figure(figsize=(8,8))
plt.plot(fpr, tpr, label= 'ROC curve(area =%0.2f)' %roc_auc)
plt.plot([0, 1], [0,1], 'k--')
plt.title('Receiver Operating characteristic')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %%
#compute sensitivity and specificity
sensitivity=tpr[1] #True positive rate 
specificity= 1-fpr[1]

print('sensitivity:', sensitivity)
print('specificity:', specificity)
# Out:
# sensitivity: 0.964824120603015
# specificity: 0.9213483146067416

# %%
from sklearn.metrics import precision_recall_curve

# 计算预测概率
ensemble_pred_probs =  DIR.predict(all_images)

# 获取预测正类的概率
# 假设是二分类问题，并且正类是第二个类别
positive_class_probs = ensemble_pred_probs[:, 1]

# 计算 Precision 和 Recall
precision, recall, thresholds = precision_recall_curve(all_true_labels, positive_class_probs)

plt.figure(figsize=(8, 8))
plt.plot(recall, precision, color='b')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()
# Out:
# 9/9 [==============================] - 1s 66ms/step

# %%
test_loss, test_acc, test_precision, test_recall, test_auc, test_f1_score = DIR.evaluate(test_generator)
print('Test loss:', test_loss)
print('Test accuracy:', test_acc)
print('Test precision:', test_precision)
print('Test recall:', test_recall)
print('Test AUC:', test_auc)
print('Test F1 Score:', test_f1_score)

# test_loss, test_acc, test_precision, test_recall, test_auc = DIR.evaluate(test_generator)
# print('Test loss:', test_loss)
# print('Test accuracy:', test_acc)
# print('Test precision:', test_precision)
# print('Test recall:', test_recall)
# print('Test AUC:', test_auc)


# from sklearn.metrics import f1_score
# import numpy as np

# # 预测测试集
# y_pred = DIR.predict(test_generator)
# y_pred = np.argmax(y_pred, axis=1)

# # 真实标签
# y_true = test_generator.classes

# # 计算F1分数
# test_f1_score = f1_score(y_true, y_pred, average='micro')  # 或者根据你的需要选择其他average参数
# print('Test F1 Score:', test_f1_score)
# Out:
# 10/10 [==============================] - 2s 157ms/step - loss: 0.1862 - accuracy: 0.9539 - precision: 0.9539 - recall: 0.9539 - auc: 0.9814 - f1_score: 0.9539
# Test loss: 0.18621976673603058
# Test accuracy: 0.9539473652839661
# Test precision: 0.9539473652839661
# Test recall: 0.9539473652839661
# Test AUC: 0.9813884496688843
# Test F1 Score: 0.9539473652839661

# %%
from sklearn.metrics import classification_report

# 使用模型对验证集进行预测，获取预测概率
y_pred_probs = DIR.predict(all_images)

# 将预测概率转换为类别标签
y_pred_labels = np.argmax(y_pred_probs, axis=1)

# 假设 y_val 是真实标签，并且也是类别标签形式
# 现在您可以生成分类报告
report = classification_report(all_true_labels, y_pred_labels)
print(report)
# Out:
# 9/9 [==============================] - 1s 66ms/step
#               precision    recall  f1-score   support
#
#            0       0.92      0.92      0.92        89
#            1       0.96      0.96      0.96       199
#
#     accuracy                           0.95       288
#    macro avg       0.94      0.94      0.94       288
# weighted avg       0.95      0.95      0.95       288

# %% [markdown]
# #delete the model to prevent memory costs
#
# from keras import backend as K
# import gc
#
# K.clear_session()
# gc.collect()
#
# # del DIR
#
#
# from numba import cuda
#
# cuda.select_device(0)
# cuda.close()
